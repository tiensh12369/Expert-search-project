# %%
from pymongo import MongoClient
client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
scienceon_aut = client['SCIENCEON']['Author']
ntis_exfa = client['NTIS']['ExpertFactor']
ntis_aut = client['NTIS']['Author']
id_domestic = client['ID']['Domestic']

keyid = 587 #input

ntis_key_query = ntis_exfa.find({ 'keyId' : keyid })

ntis_a_id = [] # A_ID

ntis_name_inst = []
all_name_inst = []

for j in ntis_key_query:
    ntis_a_id.append(j['A_ID'])
    aut_query = ntis_aut.find_one({'_id':j['A_ID']})
    ntis_name_inst.append(aut_query['name'] + '/' + aut_query['inst'].split(' ')[0])

re_Copy_name = []
re_Copy_inst = []
re_Copy = []

for c in ntis_name_inst:
    if c not in re_Copy:
        re_Copy.append(c)
        re_Copy_name.append(c.split('/')[0])
        re_Copy_inst.append(c.split('/')[1])

#print(re_Copy_name, re_Copy_inst)

#print('NTIS 이름과 소속을 중복을 제거한 것을 가지고 NTIS Author에 검색: %d명' % len(re_Copy_name))

for l in range(0, len(re_Copy_name)):

    a_name = re_Copy_name[l]
    a_inst = re_Copy_inst[l]
    
    scienceon_id = []
    ntis_id = ''

    scienceon_query = scienceon_aut.find({'$and':[{'name':a_name},{'inst':{'$regex':a_inst}}]})
    ntis_query = ntis_aut.find({'$and':[{'name':a_name},{'inst':{'$regex':a_inst}}]})
    
    print('name: %s inst: %s' % (a_name, a_inst))
    print('----------------------------------------------------%d번째 시작----------------------------------------------------' % (l+1))
    for x in scienceon_query:
        print(x)
        scienceon_id.append(x['_id'])
    
    for y in ntis_query:
        print(y)
        ntis_id = y['_id']
        
    if scienceon_id == [] and ntis_id == '':
        pass
    else:
        id_domestic.insert({'scienceon': scienceon_id, 'ntis': ntis_id, 'keyid': keyid})

    print('scienceon_id: %s' %scienceon_id)
    print('ntis_id: %s' %ntis_id)
    print('----------------------------------------------------%d번째   끝----------------------------------------------------' % (l+1))
# Out:
# name: 고수정 inst: 부산가톨릭대학교
# ----------------------------------------------------1번째 시작----------------------------------------------------
# {'_id': '10062717', 'name': '고수정', 'inst': '부산가톨릭대학교'}
# scienceon_id: []
# ntis_id: 10062717
# ----------------------------------------------------1번째   끝----------------------------------------------------
# name: 정애란 inst: 건국대학교
# ----------------------------------------------------2번째 시작----------------------------------------------------
# {'_id': '10150476', 'name': '정애란', 'inst': '건국대학교 GLOCAL(글로컬)캠퍼스'}
# scienceon_id: []
# ntis_id: 10150476
# ----------------------------------------------------2번째   끝----------------------------------------------------
# name: 박민재 inst: 경기대학교
# ----------------------------------------------------3번째 시작----------------------------------------------------
# {'_id': '10159510', 'name': '박민재', 'inst': '경기대학교'}
# scienceon_id: []
# ntis_id: 10159510
# ----------------------------------------------------3번째   끝----------------------------------------------------
# name: 김태구 inst: 한밭대학교
# ----------------------------------------------------4번째 시작----------------------------------------------------
# {'_id': 's318415', 'name': '김태구', 'inst': '한밭대학교 산업경영공학과'}
# {'_id': '10188918', 'name': '김태구', 'inst': '한밭대학교'}
# scienceon_id: ['s318415']
# ntis_id: 10188918
# ----------------------------------------------------4번째   끝----------------------------------------------------
# name: 김한성 inst: 한양대학교
# ----------------------------------------------------5번째 시작----------------------------------------------------
# {'_id': '10544810', 'name': '김한성', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 10544810
# ----------------------------------------------------5번째   끝----------------------------------------------------
# name: 오성수 inst: 한양대학교
# ----------------------------------------------------6번째 시작----------------------------------------------------
# {'_id': '10675389', 'name': '오성수', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 10675389
# ----------------------------------------------------6번째   끝----------------------------------------------------
# name: 손동영 inst: 한양대학교
# ----------------------------------------------------7번째 시작----------------------------------------------------
# {'_id': '10965058', 'name': '손동영', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 10965058
# ----------------------------------------------------7번째   끝----------------------------------------------------
# name: 김윤학 inst: 조선대학교
# ----------------------------------------------------8번째 시작----------------------------------------------------
# {'_id': '10970984', 'name': '김윤학', 'inst': '조선대학교'}
# scienceon_id: []
# ntis_id: 10970984
# ----------------------------------------------------8번째   끝----------------------------------------------------
# name: 배준우 inst: 한양대학교
# ----------------------------------------------------9번째 시작----------------------------------------------------
# {'_id': '10977493', 'name': '배준우', 'inst': '한양대학교 에리카산학협력단'}
# scienceon_id: []
# ntis_id: 10977493
# ----------------------------------------------------9번째   끝----------------------------------------------------
# name: 이강희 inst: 숭실대학교
# ----------------------------------------------------10번째 시작----------------------------------------------------
# {'_id': 's266322', 'name': '이강희', 'inst': '숭실대학교 글로벌미디어학부'}
# {'_id': 's136658', 'name': '이강희', 'inst': '숭실대학교 글로벌미디어학부 UU0000851'}
# {'_id': 's274933', 'name': '이강희', 'inst': '숭실대학교 미디어학과'}
# {'_id': 's1049166', 'name': '이강희', 'inst': '숭실대학교 미디어학부'}
# {'_id': 's143082', 'name': '이강희', 'inst': '숭실대학교, 글로벌미디어학부'}
# {'_id': '110608057165', 'name': '이강희', 'inst': '숭실대학교'}
# {'_id': 's140406', 'name': '이강희', 'inst': '숭실대학교'}
# {'_id': '219513527152', 'name': '이강희', 'inst': '숭실대학교 산학협력단'}
# scienceon_id: ['s266322', 's136658', 's274933', 's1049166', 's143082']
# ntis_id: 219513527152
# ----------------------------------------------------10번째   끝----------------------------------------------------
# name: 정우성 inst: 포항공과대학교
# ----------------------------------------------------11번째 시작----------------------------------------------------
# {'_id': '111480047178', 'name': '정우성', 'inst': '포항공과대학교'}
# scienceon_id: []
# ntis_id: 111480047178
# ----------------------------------------------------11번째   끝----------------------------------------------------
# name: 권혁윤 inst: 서울과학기술대학교
# ----------------------------------------------------12번째 시작----------------------------------------------------
# {'_id': '11150858', 'name': '권혁윤', 'inst': '서울과학기술대학교'}
# scienceon_id: []
# ntis_id: 11150858
# ----------------------------------------------------12번째   끝----------------------------------------------------
# name: 이현정 inst: 가천대학교
# ----------------------------------------------------13번째 시작----------------------------------------------------
# {'_id': '112207147168', 'name': '이현정', 'inst': '가천대학교'}
# scienceon_id: []
# ntis_id: 112207147168
# ----------------------------------------------------13번째   끝----------------------------------------------------
# name: 이민혁 inst: 부산대학교
# ----------------------------------------------------14번째 시작----------------------------------------------------
# {'_id': '11317035', 'name': '이민혁', 'inst': '부산대학교'}
# scienceon_id: []
# ntis_id: 11317035
# ----------------------------------------------------14번째   끝----------------------------------------------------
# name: Reyhani Hamedani Masoud inst: 한양대학교
# ----------------------------------------------------15번째 시작----------------------------------------------------
# {'_id': '11321255', 'name': 'Reyhani Hamedani Masoud', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 11321255
# ----------------------------------------------------15번째   끝----------------------------------------------------
# name: 강아름 inst: 순천향대학교
# ----------------------------------------------------16번째 시작----------------------------------------------------
# {'_id': 's262134', 'name': '강아름', 'inst': '순천향대학교 부천병원 마취통증의학과'}
# {'_id': '11324683', 'name': '강아름', 'inst': '순천향대학교'}
# scienceon_id: ['s262134']
# ntis_id: 11324683
# ----------------------------------------------------16번째   끝----------------------------------------------------
# name: 이현병 inst: 원광대학교
# ----------------------------------------------------17번째 시작----------------------------------------------------
# {'_id': '11389799', 'name': '이현병', 'inst': '원광대학교'}
# scienceon_id: []
# ntis_id: 11389799
# ----------------------------------------------------17번째   끝----------------------------------------------------
# name: 신기정 inst: 한국과학기술원
# ----------------------------------------------------18번째 시작----------------------------------------------------
# {'_id': '11419213', 'name': '신기정', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11419213
# ----------------------------------------------------18번째   끝----------------------------------------------------
# name: 백지원 inst: 상지대학교
# ----------------------------------------------------19번째 시작----------------------------------------------------
# {'_id': '11477308', 'name': '백지원', 'inst': '상지대학교'}
# scienceon_id: []
# ntis_id: 11477308
# ----------------------------------------------------19번째   끝----------------------------------------------------
# name: 전주희 inst: 고려대학교의료원안암병원
# ----------------------------------------------------20번째 시작----------------------------------------------------
# {'_id': '11478102', 'name': '전주희', 'inst': '고려대학교의료원안암병원'}
# scienceon_id: []
# ntis_id: 11478102
# ----------------------------------------------------20번째   끝----------------------------------------------------
# name: 김민경 inst: 선문대학교
# ----------------------------------------------------21번째 시작----------------------------------------------------
# {'_id': '11533281', 'name': '김민경', 'inst': '선문대학교'}
# scienceon_id: []
# ntis_id: 11533281
# ----------------------------------------------------21번째   끝----------------------------------------------------
# name: 신보경 inst: 충북대학교산학협력단
# ----------------------------------------------------22번째 시작----------------------------------------------------
# {'_id': '11553827', 'name': '신보경', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11553827
# ----------------------------------------------------22번째   끝----------------------------------------------------
# name: 양연주 inst: 한국과학기술원
# ----------------------------------------------------23번째 시작----------------------------------------------------
# {'_id': '11557117', 'name': '양연주', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11557117
# ----------------------------------------------------23번째   끝----------------------------------------------------
# name: 황지영 inst: 성균관대학교(자연과학캠퍼스)
# ----------------------------------------------------24번째 시작----------------------------------------------------
# scienceon_id: []
# ntis_id:
# ----------------------------------------------------24번째   끝----------------------------------------------------
# name: 이유신 inst: 한양대학교
# ----------------------------------------------------25번째 시작----------------------------------------------------
# C:\Users\Hyeuk\anaconda3\envs\craw\lib\site-packages\ipykernel_launcher.py:60: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# {'_id': '11567924', 'name': '이유신', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 11567924
# ----------------------------------------------------25번째   끝----------------------------------------------------
# name: 홍영재 inst: 충북대학교산학협력단
# ----------------------------------------------------26번째 시작----------------------------------------------------
# {'_id': '11569054', 'name': '홍영재', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11569054
# ----------------------------------------------------26번째   끝----------------------------------------------------
# name: 정종현 inst: 충북대학교산학협력단
# ----------------------------------------------------27번째 시작----------------------------------------------------
# {'_id': '11569082', 'name': '정종현', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11569082
# ----------------------------------------------------27번째   끝----------------------------------------------------
# name: 윤지우 inst: 성균관대학교
# ----------------------------------------------------28번째 시작----------------------------------------------------
# {'_id': '11588079', 'name': '윤지우', 'inst': '성균관대학교'}
# scienceon_id: []
# ntis_id: 11588079
# ----------------------------------------------------28번째   끝----------------------------------------------------
# name: 권영우 inst: 경북대학교
# ----------------------------------------------------29번째 시작----------------------------------------------------
# {'_id': '11593430', 'name': '권영우', 'inst': '경북대학교'}
# {'_id': '682190326949', 'name': '권영우', 'inst': '경북대학교'}
# scienceon_id: []
# ntis_id: 682190326949
# ----------------------------------------------------29번째   끝----------------------------------------------------
# name: 홍소윤 inst: 연세대학교
# ----------------------------------------------------30번째 시작----------------------------------------------------
# {'_id': '11602890', 'name': '홍소윤', 'inst': '연세대학교'}
# scienceon_id: []
# ntis_id: 11602890
# ----------------------------------------------------30번째   끝----------------------------------------------------
# name: 이성원 inst: 건국대학교
# ----------------------------------------------------31번째 시작----------------------------------------------------
# {'_id': '11608838', 'name': '이성원', 'inst': '건국대학교 GLOCAL(글로컬)캠퍼스'}
# scienceon_id: []
# ntis_id: 11608838
# ----------------------------------------------------31번째   끝----------------------------------------------------
# name: 위지원 inst: 충북대학교산학협력단
# ----------------------------------------------------32번째 시작----------------------------------------------------
# {'_id': '11609848', 'name': '위지원', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11609848
# ----------------------------------------------------32번째   끝----------------------------------------------------
# name: 이태건 inst: 충북대학교산학협력단
# ----------------------------------------------------33번째 시작----------------------------------------------------
# {'_id': '11611782', 'name': '이태건', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11611782
# ----------------------------------------------------33번째   끝----------------------------------------------------
# name: 이도엽 inst: 중앙대학교
# ----------------------------------------------------34번째 시작----------------------------------------------------
# {'_id': '11619002', 'name': '이도엽', 'inst': '중앙대학교'}
# scienceon_id: []
# ntis_id: 11619002
# ----------------------------------------------------34번째   끝----------------------------------------------------
# name: 서창원 inst: 단국대학교
# ----------------------------------------------------35번째 시작----------------------------------------------------
# {'_id': '11619906', 'name': '서창원', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11619906
# ----------------------------------------------------35번째   끝----------------------------------------------------
# name: 이태규 inst: 창원대학교
# ----------------------------------------------------36번째 시작----------------------------------------------------
# {'_id': '11620207', 'name': '이태규', 'inst': '창원대학교'}
# scienceon_id: []
# ntis_id: 11620207
# ----------------------------------------------------36번째   끝----------------------------------------------------
# name: 김종범 inst: 충북대학교산학협력단
# ----------------------------------------------------37번째 시작----------------------------------------------------
# {'_id': '11636973', 'name': '김종범', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11636973
# ----------------------------------------------------37번째   끝----------------------------------------------------
# name: 김성민 inst: 한양대학교
# ----------------------------------------------------38번째 시작----------------------------------------------------
# {'_id': 's277113', 'name': '김성민', 'inst': '한양대학교'}
# {'_id': 's666916', 'name': '김성민', 'inst': '한양대학교 건축공학부'}
# {'_id': 's979048', 'name': '김성민', 'inst': '한양대학교 생체의공학과'}
# {'_id': 's1048479', 'name': '김성민', 'inst': '한양대학교 자원환경공학과'}
# {'_id': 's299888', 'name': '김성민', 'inst': '한양대학교 전자공학부'}
# {'_id': 's98965', 'name': '김성민', 'inst': '한양대학교'}
# {'_id': '805171218208', 'name': '김성민', 'inst': '한양대학교'}
# {'_id': '11638621', 'name': '김성민', 'inst': '한양대학교 관광연구소'}
# {'_id': '11804002', 'name': '김성민', 'inst': '한양대학교 산학협력단'}
# {'_id': '11536835', 'name': '김성민', 'inst': '한양대학교산학협력단'}
# {'_id': '11509951', 'name': '김성민', 'inst': '한양대학교에리카산학협력단'}
# scienceon_id: ['s277113', 's666916', 's979048', 's1048479', 's299888']
# ntis_id: 11509951
# ----------------------------------------------------38번째   끝----------------------------------------------------
# name: 이광희 inst: 단국대학교
# ----------------------------------------------------39번째 시작----------------------------------------------------
# {'_id': '11643044', 'name': '이광희', 'inst': '단국대학교 산학협력단'}
# {'_id': '417128918134', 'name': '이광희', 'inst': '단국대학교 천안캠퍼스 산학협력단'}
# scienceon_id: []
# ntis_id: 417128918134
# ----------------------------------------------------39번째   끝----------------------------------------------------
# name: 조희찬 inst: 한양대학교
# ----------------------------------------------------40번째 시작----------------------------------------------------
# {'_id': '11655597', 'name': '조희찬', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 11655597
# ----------------------------------------------------40번째   끝----------------------------------------------------
# name: 김정민 inst: 충북대학교산학협력단
# ----------------------------------------------------41번째 시작----------------------------------------------------
# {'_id': '11680665', 'name': '김정민', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11680665
# ----------------------------------------------------41번째   끝----------------------------------------------------
# name: 이희승 inst: 충북대학교
# ----------------------------------------------------42번째 시작----------------------------------------------------
# {'_id': '11687074', 'name': '이희승', 'inst': '충북대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11687074
# ----------------------------------------------------42번째   끝----------------------------------------------------
# name: 육대범 inst: 충북대학교산학협력단
# ----------------------------------------------------43번째 시작----------------------------------------------------
# {'_id': '11715950', 'name': '육대범', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11715950
# ----------------------------------------------------43번째   끝----------------------------------------------------
# name: 윤준영 inst: 충북대학교산학협력단
# ----------------------------------------------------44번째 시작----------------------------------------------------
# {'_id': '11715951', 'name': '윤준영', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11715951
# ----------------------------------------------------44번째   끝----------------------------------------------------
# name: 이재흠 inst: 충북대학교산학협력단
# ----------------------------------------------------45번째 시작----------------------------------------------------
# {'_id': '11719544', 'name': '이재흠', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11719544
# ----------------------------------------------------45번째   끝----------------------------------------------------
# name: 염주선 inst: 한국과학기술원
# ----------------------------------------------------46번째 시작----------------------------------------------------
# {'_id': '11730197', 'name': '염주선', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11730197
# ----------------------------------------------------46번째   끝----------------------------------------------------
# name: 한지영 inst: 한국과학기술원
# ----------------------------------------------------47번째 시작----------------------------------------------------
# {'_id': '11750566', 'name': '한지영', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11750566
# ----------------------------------------------------47번째   끝----------------------------------------------------
# name: 최윤희 inst: 순천향대학교
# ----------------------------------------------------48번째 시작----------------------------------------------------
# {'_id': '11752871', 'name': '최윤희', 'inst': '순천향대학교'}
# {'_id': '303227038150', 'name': '최윤희', 'inst': '순천향대학교'}
# {'_id': '11718304', 'name': '최윤희', 'inst': '순천향대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11718304
# ----------------------------------------------------48번째   끝----------------------------------------------------
# name: 최지영 inst: 한국과학기술원
# ----------------------------------------------------49번째 시작----------------------------------------------------
# {'_id': '11756673', 'name': '최지영', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11756673
# ----------------------------------------------------49번째   끝----------------------------------------------------
# name: NINH PHONG PHU inst: 충북대학교산학협력단
# ----------------------------------------------------50번째 시작----------------------------------------------------
# {'_id': '11776112', 'name': 'NINH PHONG PHU', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11776112
# ----------------------------------------------------50번째   끝----------------------------------------------------
# name: 이남규 inst: 한국과학기술원
# ----------------------------------------------------51번째 시작----------------------------------------------------
# {'_id': '11778501', 'name': '이남규', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11778501
# ----------------------------------------------------51번째   끝----------------------------------------------------
# name: 김보람 inst: 충북대학교산학협력단
# ----------------------------------------------------52번째 시작----------------------------------------------------
# {'_id': '11781782', 'name': '김보람', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11781782
# ----------------------------------------------------52번째   끝----------------------------------------------------
# name: 조용장 inst: 고려대의료원
# ----------------------------------------------------53번째 시작----------------------------------------------------
# {'_id': '11795785', 'name': '조용장', 'inst': '고려대의료원'}
# scienceon_id: []
# ntis_id: 11795785
# ----------------------------------------------------53번째   끝----------------------------------------------------
# name: 신용민 inst: 단국대학교
# ----------------------------------------------------54번째 시작----------------------------------------------------
# {'_id': '11802546', 'name': '신용민', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11802546
# ----------------------------------------------------54번째   끝----------------------------------------------------
# name: 양한결 inst: 가천대학교
# ----------------------------------------------------55번째 시작----------------------------------------------------
# {'_id': '11804902', 'name': '양한결', 'inst': '가천대학교'}
# scienceon_id: []
# ntis_id: 11804902
# ----------------------------------------------------55번째   끝----------------------------------------------------
# name: 박대훈 inst: 충북대학교산학협력단
# ----------------------------------------------------56번째 시작----------------------------------------------------
# {'_id': '11806058', 'name': '박대훈', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11806058
# ----------------------------------------------------56번째   끝----------------------------------------------------
# name: 김현일 inst: 단국대학교
# ----------------------------------------------------57번째 시작----------------------------------------------------
# {'_id': '11807325', 'name': '김현일', 'inst': '단국대학교'}
# scienceon_id: []
# ntis_id: 11807325
# ----------------------------------------------------57번째   끝----------------------------------------------------
# name: 박정연 inst: 충북대학교산학협력단
# ----------------------------------------------------58번째 시작----------------------------------------------------
# {'_id': '11809268', 'name': '박정연', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11809268
# ----------------------------------------------------58번째   끝----------------------------------------------------
# name: 안상현 inst: 충북대학교산학협력단
# ----------------------------------------------------59번째 시작----------------------------------------------------
# {'_id': '11809576', 'name': '안상현', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11809576
# ----------------------------------------------------59번째   끝----------------------------------------------------
# name: 김연동 inst: 충북대학교산학협력단
# ----------------------------------------------------60번째 시작----------------------------------------------------
# {'_id': '11818859', 'name': '김연동', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11818859
# ----------------------------------------------------60번째   끝----------------------------------------------------
# name: 박수빈 inst: 충북대학교산학협력단
# ----------------------------------------------------61번째 시작----------------------------------------------------
# {'_id': '11818862', 'name': '박수빈', 'inst': '충북대학교산학협력단'}
# {'_id': '12511058', 'name': '박수빈', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12511058
# ----------------------------------------------------61번째   끝----------------------------------------------------
# name: 전준범 inst: 한림대학교
# ----------------------------------------------------62번째 시작----------------------------------------------------
# {'_id': '11819558', 'name': '전준범', 'inst': '한림대학교'}
# scienceon_id: []
# ntis_id: 11819558
# ----------------------------------------------------62번째   끝----------------------------------------------------
# name: 김범수 inst: 충북대학교산학협력단
# ----------------------------------------------------63번째 시작----------------------------------------------------
# {'_id': '11820471', 'name': '김범수', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11820471
# ----------------------------------------------------63번째   끝----------------------------------------------------
# name: 홍석주 inst: 충북대학교산학협력단
# ----------------------------------------------------64번째 시작----------------------------------------------------
# {'_id': '11824323', 'name': '홍석주', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11824323
# ----------------------------------------------------64번째   끝----------------------------------------------------
# name: 홍지운 inst: 충북대학교산학협력단
# ----------------------------------------------------65번째 시작----------------------------------------------------
# {'_id': '11831699', 'name': '홍지운', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11831699
# ----------------------------------------------------65번째   끝----------------------------------------------------
# name: 강지수 inst: 경기대학교산학협력단
# ----------------------------------------------------66번째 시작----------------------------------------------------
# {'_id': '11831904', 'name': '강지수', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11831904
# ----------------------------------------------------66번째   끝----------------------------------------------------
# name: 정형구 inst: 서울시립대학교
# ----------------------------------------------------67번째 시작----------------------------------------------------
# {'_id': '11834711', 'name': '정형구', 'inst': '서울시립대학교'}
# scienceon_id: []
# ntis_id: 11834711
# ----------------------------------------------------67번째   끝----------------------------------------------------
# name: 박송희 inst: 충북대학교
# ----------------------------------------------------68번째 시작----------------------------------------------------
# {'_id': 's262200', 'name': '박송희', 'inst': '충북대학교'}
# {'_id': '11836968', 'name': '박송희', 'inst': '충북대학교 산학협력단'}
# scienceon_id: ['s262200']
# ntis_id: 11836968
# ----------------------------------------------------68번째   끝----------------------------------------------------
# name: 박희찬 inst: 단국대학교
# ----------------------------------------------------69번째 시작----------------------------------------------------
# {'_id': '11855678', 'name': '박희찬', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11855678
# ----------------------------------------------------69번째   끝----------------------------------------------------
# name: 김태현 inst: 서울대학교
# ----------------------------------------------------70번째 시작----------------------------------------------------
# {'_id': 's137003', 'name': '김태현', 'inst': '서울대학교 교육학과 교육공학'}
# {'_id': '814302657124', 'name': '김태현', 'inst': '서울대학교'}
# {'_id': '264107218148', 'name': '김태현', 'inst': '서울대학교'}
# {'_id': '11813370', 'name': '김태현', 'inst': '서울대학교'}
# {'_id': '12638402', 'name': '김태현', 'inst': '서울대학교'}
# {'_id': '228301337291', 'name': '김태현', 'inst': '서울대학교 병원'}
# {'_id': '12528075', 'name': '김태현', 'inst': '서울대학교 산학협력단'}
# {'_id': '603168918951', 'name': '김태현', 'inst': '서울대학교 산학협력단'}
# {'_id': '11861346', 'name': '김태현', 'inst': '서울대학교 산학협력단'}
# {'_id': '11669088', 'name': '김태현', 'inst': '서울대학교 산학협력단'}
# {'_id': '500195918276', 'name': '김태현', 'inst': '서울대학교산학협력단'}
# scienceon_id: ['s137003']
# ntis_id: 500195918276
# ----------------------------------------------------70번째   끝----------------------------------------------------
# name: 민효원 inst: 한국과학기술원
# ----------------------------------------------------71번째 시작----------------------------------------------------
# {'_id': '11891195', 'name': '민효원', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11891195
# ----------------------------------------------------71번째   끝----------------------------------------------------
# name: 이헌우 inst: 한양대학교
# ----------------------------------------------------72번째 시작----------------------------------------------------
# {'_id': '11900619', 'name': '이헌우', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 11900619
# ----------------------------------------------------72번째   끝----------------------------------------------------
# name: 변성우 inst: 단국대학교
# ----------------------------------------------------73번째 시작----------------------------------------------------
# {'_id': '11901683', 'name': '변성우', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11901683
# ----------------------------------------------------73번째   끝----------------------------------------------------
# name: 김현지 inst: 단국대학교
# ----------------------------------------------------74번째 시작----------------------------------------------------
# {'_id': '11906333', 'name': '김현지', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11906333
# ----------------------------------------------------74번째   끝----------------------------------------------------
# name: ibrahem Hatem Hossameldeen Mohamed Kam inst: 충북대학교산학협력단
# ----------------------------------------------------75번째 시작----------------------------------------------------
# {'_id': '11912022', 'name': 'ibrahem Hatem Hossameldeen Mohamed Kam', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11912022
# ----------------------------------------------------75번째   끝----------------------------------------------------
# name: 김정우 inst: 아주대학교산학협력단
# ----------------------------------------------------76번째 시작----------------------------------------------------
# {'_id': '11912466', 'name': '김정우', 'inst': '아주대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11912466
# ----------------------------------------------------76번째   끝----------------------------------------------------
# name: 정장현 inst: 충북대학교
# ----------------------------------------------------77번째 시작----------------------------------------------------
# {'_id': '11918392', 'name': '정장현', 'inst': '충북대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11918392
# ----------------------------------------------------77번째   끝----------------------------------------------------
# name: ISLAM MD MAINUL inst: 국민대학교산학협력단
# ----------------------------------------------------78번째 시작----------------------------------------------------
# {'_id': '11918471', 'name': 'ISLAM MD MAINUL', 'inst': '국민대학교산학협력단'}
# {'_id': '12457164', 'name': 'ISLAM MD MAINUL', 'inst': '국민대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12457164
# ----------------------------------------------------78번째   끝----------------------------------------------------
# name: 김대한 inst: 단국대학교
# ----------------------------------------------------79번째 시작----------------------------------------------------
# {'_id': '11926498', 'name': '김대한', 'inst': '단국대학교 산학협력단'}
# {'_id': '12486287', 'name': '김대한', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12486287
# ----------------------------------------------------79번째   끝----------------------------------------------------
# name: 백연희 inst: 충북대학교산학협력단
# ----------------------------------------------------80번째 시작----------------------------------------------------
# {'_id': '11927409', 'name': '백연희', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11927409
# ----------------------------------------------------80번째   끝----------------------------------------------------
# name: 김희제 inst: 부산대학교
# ----------------------------------------------------81번째 시작----------------------------------------------------
# {'_id': 's570290', 'name': '김희제', 'inst': '부산대학교'}
# {'_id': 's980079', 'name': '김희제', 'inst': '부산대학교 공과대학 전기공학과'}
# {'_id': 's299325', 'name': '김희제', 'inst': '부산대학교 공과대학 전기전자'}
# {'_id': 's299371', 'name': '김희제', 'inst': '부산대학교 전기공학'}
# {'_id': 's309879', 'name': '김희제', 'inst': '부산대학교 전기공학과'}
# {'_id': 's1054227', 'name': '김희제', 'inst': '부산대학교 전기전자컴퓨터공학과'}
# {'_id': 's662993', 'name': '김희제', 'inst': '부산대학교 전자전기공학과'}
# {'_id': 's1037707', 'name': '김희제', 'inst': '부산대학교 전자전기공학부'}
# {'_id': 's662984', 'name': '김희제', 'inst': '전자전기공학과, 부산대학교'}
# {'_id': '123617015159', 'name': '김희제', 'inst': '부산대학교'}
# scienceon_id: ['s570290', 's980079', 's299325', 's299371', 's309879', 's1054227', 's662993', 's1037707', 's662984']
# ntis_id: 123617015159
# ----------------------------------------------------81번째   끝----------------------------------------------------
# name: 지용진 inst: 충북대학교산학협력단
# ----------------------------------------------------82번째 시작----------------------------------------------------
# {'_id': '12390191', 'name': '지용진', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12390191
# ----------------------------------------------------82번째   끝----------------------------------------------------
# name: 김민정 inst: 경기대학교산학협력단
# ----------------------------------------------------83번째 시작----------------------------------------------------
# {'_id': '12401785', 'name': '김민정', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12401785
# ----------------------------------------------------83번째   끝----------------------------------------------------
# name: 이래엽 inst: 국민대학교산학협력단
# ----------------------------------------------------84번째 시작----------------------------------------------------
# {'_id': '12407233', 'name': '이래엽', 'inst': '국민대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12407233
# ----------------------------------------------------84번째   끝----------------------------------------------------
# name: 오준오 inst: 단국대학교
# ----------------------------------------------------85번째 시작----------------------------------------------------
# {'_id': '12417773', 'name': '오준오', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12417773
# ----------------------------------------------------85번째   끝----------------------------------------------------
# name: 김민기 inst: 단국대학교
# ----------------------------------------------------86번째 시작----------------------------------------------------
# {'_id': '12426709', 'name': '김민기', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12426709
# ----------------------------------------------------86번째   끝----------------------------------------------------
# name: 문동혁 inst: 충북대학교산학협력단
# ----------------------------------------------------87번째 시작----------------------------------------------------
# {'_id': '12429310', 'name': '문동혁', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12429310
# ----------------------------------------------------87번째   끝----------------------------------------------------
# name: 길성현 inst: 충북대학교산학협력단
# ----------------------------------------------------88번째 시작----------------------------------------------------
# {'_id': '12429332', 'name': '길성현', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12429332
# ----------------------------------------------------88번째   끝----------------------------------------------------
# name: 김희주 inst: 단국대학교
# ----------------------------------------------------89번째 시작----------------------------------------------------
# {'_id': '12436438', 'name': '김희주', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12436438
# ----------------------------------------------------89번째   끝----------------------------------------------------
# name: Essa Mohammed Essa Fawzy inst: 충북대학교산학협력단
# ----------------------------------------------------90번째 시작----------------------------------------------------
# {'_id': '12443822', 'name': 'Essa Mohammed Essa Fawzy', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12443822
# ----------------------------------------------------90번째   끝----------------------------------------------------
# name: 이명원 inst: 충남대학교산학협력단
# ----------------------------------------------------91번째 시작----------------------------------------------------
# {'_id': '12457712', 'name': '이명원', 'inst': '충남대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12457712
# ----------------------------------------------------91번째   끝----------------------------------------------------
# name: 정경중 inst: 단국대학교
# ----------------------------------------------------92번째 시작----------------------------------------------------
# {'_id': '12468142', 'name': '정경중', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12468142
# ----------------------------------------------------92번째   끝----------------------------------------------------
# name: 구병국 inst: 경기대학교산학협력단
# ----------------------------------------------------93번째 시작----------------------------------------------------
# {'_id': '12486137', 'name': '구병국', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12486137
# ----------------------------------------------------93번째   끝----------------------------------------------------
# name: 이진영 inst: 경기대학교산학협력단
# ----------------------------------------------------94번째 시작----------------------------------------------------
# {'_id': '12488310', 'name': '이진영', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12488310
# ----------------------------------------------------94번째   끝----------------------------------------------------
# name: 박태미 inst: 충북대학교
# ----------------------------------------------------95번째 시작----------------------------------------------------
# {'_id': '12502146', 'name': '박태미', 'inst': '충북대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12502146
# ----------------------------------------------------95번째   끝----------------------------------------------------
# name: 김현진 inst: 고려대학교산학협력단
# ----------------------------------------------------96번째 시작----------------------------------------------------
# {'_id': '11411129', 'name': '김현진', 'inst': '고려대학교산학협력단'}
# {'_id': '608114118831', 'name': '김현진', 'inst': '고려대학교산학협력단'}
# {'_id': '417706939102', 'name': '김현진', 'inst': '고려대학교산학협력단'}
# {'_id': '879112716115', 'name': '김현진', 'inst': '고려대학교산학협력단'}
# {'_id': '12520422', 'name': '김현진', 'inst': '고려대학교산학협력단'}
# {'_id': '11833840', 'name': '김현진', 'inst': '고려대학교산학협력단'}
# scienceon_id: []
# ntis_id: 11833840
# ----------------------------------------------------96번째   끝----------------------------------------------------
# name: 류성은 inst: 경기대학교산학협력단
# ----------------------------------------------------97번째 시작----------------------------------------------------
# {'_id': '12520695', 'name': '류성은', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12520695
# ----------------------------------------------------97번째   끝----------------------------------------------------
# name: 박진덕 inst: 단국대학교
# ----------------------------------------------------98번째 시작----------------------------------------------------
# {'_id': '12524219', 'name': '박진덕', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12524219
# ----------------------------------------------------98번째   끝----------------------------------------------------
# name: 신현식 inst: 충북대학교산학협력단
# ----------------------------------------------------99번째 시작----------------------------------------------------
# {'_id': '12526384', 'name': '신현식', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12526384
# ----------------------------------------------------99번째   끝----------------------------------------------------
# name: 김윤아 inst: 충북대학교산학협력단
# ----------------------------------------------------100번째 시작----------------------------------------------------
# {'_id': '12526447', 'name': '김윤아', 'inst': '충북대학교산학협력단'}
# {'_id': '12570591', 'name': '김윤아', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12570591
# ----------------------------------------------------100번째   끝----------------------------------------------------
# name: 김남영 inst: 충북대학교
# ----------------------------------------------------101번째 시작----------------------------------------------------
# {'_id': '12526454', 'name': '김남영', 'inst': '충북대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12526454
# ----------------------------------------------------101번째   끝----------------------------------------------------
# name: 권희주 inst: 충북대학교산학협력단
# ----------------------------------------------------102번째 시작----------------------------------------------------
# {'_id': '12527277', 'name': '권희주', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12527277
# ----------------------------------------------------102번째   끝----------------------------------------------------
# name: 김기학 inst: 충북대학교산학협력단
# ----------------------------------------------------103번째 시작----------------------------------------------------
# {'_id': '12527457', 'name': '김기학', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12527457
# ----------------------------------------------------103번째   끝----------------------------------------------------
# name: 최소영 inst: 충북대학교산학협력단
# ----------------------------------------------------104번째 시작----------------------------------------------------
# {'_id': '12527463', 'name': '최소영', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12527463
# ----------------------------------------------------104번째   끝----------------------------------------------------
# name: 정진원 inst: 단국대학교
# ----------------------------------------------------105번째 시작----------------------------------------------------
# {'_id': '12531213', 'name': '정진원', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12531213
# ----------------------------------------------------105번째   끝----------------------------------------------------
# name: 편도웅 inst: 충북대학교산학협력단
# ----------------------------------------------------106번째 시작----------------------------------------------------
# {'_id': '12536072', 'name': '편도웅', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12536072
# ----------------------------------------------------106번째   끝----------------------------------------------------
# name: 오영호 inst: 충북대학교
# ----------------------------------------------------107번째 시작----------------------------------------------------
# {'_id': 's1087710', 'name': '오영호', 'inst': '충북대학교 빅데이터학과'}
# {'_id': '12536125', 'name': '오영호', 'inst': '충북대학교'}
# scienceon_id: ['s1087710']
# ntis_id: 12536125
# ----------------------------------------------------107번째   끝----------------------------------------------------
# name: 박지은 inst: 창원대학교
# ----------------------------------------------------108번째 시작----------------------------------------------------
# {'_id': '12537742', 'name': '박지은', 'inst': '창원대학교'}
# scienceon_id: []
# ntis_id: 12537742
# ----------------------------------------------------108번째   끝----------------------------------------------------
# name: 문주철 inst: 단국대학교
# ----------------------------------------------------109번째 시작----------------------------------------------------
# {'_id': '12569567', 'name': '문주철', 'inst': '단국대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 12569567
# ----------------------------------------------------109번째   끝----------------------------------------------------
# name: 박혜원 inst: 경기대학교산학협력단
# ----------------------------------------------------110번째 시작----------------------------------------------------
# {'_id': '12573911', 'name': '박혜원', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12573911
# ----------------------------------------------------110번째   끝----------------------------------------------------
# name: 권혜정 inst: 고려대학교산학협력단
# ----------------------------------------------------111번째 시작----------------------------------------------------
# {'_id': '12593373', 'name': '권혜정', 'inst': '고려대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12593373
# ----------------------------------------------------111번째   끝----------------------------------------------------
# name: 정현모 inst: 경기대학교산학협력단
# ----------------------------------------------------112번째 시작----------------------------------------------------
# {'_id': '12627543', 'name': '정현모', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12627543
# ----------------------------------------------------112번째   끝----------------------------------------------------
# name: 홍수빈 inst: 경기대학교산학협력단
# ----------------------------------------------------113번째 시작----------------------------------------------------
# {'_id': '12666864', 'name': '홍수빈', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12666864
# ----------------------------------------------------113번째   끝----------------------------------------------------
# name: 이민상 inst: 충남대학교산학협력단
# ----------------------------------------------------114번째 시작----------------------------------------------------
# {'_id': '12749026', 'name': '이민상', 'inst': '충남대학교산학협력단'}
# scienceon_id: []
# ntis_id: 12749026
# ----------------------------------------------------114번째   끝----------------------------------------------------
# name: 임형욱 inst: 한양대학교
# ----------------------------------------------------115번째 시작----------------------------------------------------
# {'_id': '12810410', 'name': '임형욱', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 12810410
# ----------------------------------------------------115번째   끝----------------------------------------------------
# name: 곽경섭 inst: 인하대학교
# ----------------------------------------------------116번째 시작----------------------------------------------------
# {'_id': 's311714', 'name': '곽경섭', 'inst': '인하대학교 정보통신공학과'}
# {'_id': 's1047314', 'name': '곽경섭', 'inst': '인하대학교 정보통신공학부'}
# {'_id': 's100801', 'name': '곽경섭', 'inst': '인하대학교 정보통신대학원'}
# {'_id': '169149514114', 'name': '곽경섭', 'inst': '인하대학교'}
# scienceon_id: ['s311714', 's1047314', 's100801']
# ntis_id: 169149514114
# ----------------------------------------------------116번째   끝----------------------------------------------------
# name: 임상준 inst: 서울대학교
# ----------------------------------------------------117번째 시작----------------------------------------------------
# {'_id': 's1009011', 'name': '임상준', 'inst': '서울대학교 농업생명과학대학 산림과학부'}
# {'_id': 's656681', 'name': '임상준', 'inst': '서울대학교 산림과학부'}
# {'_id': '197101816273', 'name': '임상준', 'inst': '서울대학교 산학협력단'}
# scienceon_id: ['s1009011', 's656681']
# ntis_id: 197101816273
# ----------------------------------------------------117번째   끝----------------------------------------------------
# name: 조환규 inst: 부산대학교
# ----------------------------------------------------118번째 시작----------------------------------------------------
# {'_id': 's100383', 'name': '조환규', 'inst': '부산대학교 U-Port 정보기술산학공동 사업부'}
# {'_id': 's1054226', 'name': '조환규', 'inst': '부산대학교 전기전자컴퓨터공학과'}
# {'_id': 's260325', 'name': '조환규', 'inst': '부산대학교 전자전기컴퓨터공학과'}
# {'_id': 's269589', 'name': '조환규', 'inst': '부산대학교 정보컴퓨터공학부'}
# {'_id': 's264145', 'name': '조환규', 'inst': '부산대학교 컴퓨터공학과'}
# {'_id': 's1005208', 'name': '조환규', 'inst': '부산대학교 컴퓨터공학부'}
# {'_id': '210152716209', 'name': '조환규', 'inst': '부산대학교'}
# scienceon_id: ['s100383', 's1054226', 's260325', 's269589', 's264145', 's1005208']
# ntis_id: 210152716209
# ----------------------------------------------------118번째   끝----------------------------------------------------
# name: 최상일 inst: 단국대학교
# ----------------------------------------------------119번째 시작----------------------------------------------------
# {'_id': 's619060', 'name': '최상일', 'inst': '단국대학교 응용컴퓨터공학과'}
# {'_id': 's266739', 'name': '최상일', 'inst': '단국대학교 컴퓨터학과'}
# {'_id': '211807567182', 'name': '최상일', 'inst': '단국대학교 산학협력단'}
# scienceon_id: ['s619060', 's266739']
# ntis_id: 211807567182
# ----------------------------------------------------119번째   끝----------------------------------------------------
# name: 황규영 inst: 한국과학기술원
# ----------------------------------------------------120번째 시작----------------------------------------------------
# {'_id': '212400315114', 'name': '황규영', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 212400315114
# ----------------------------------------------------120번째   끝----------------------------------------------------
# name: 우지영 inst: 순천향대학교
# ----------------------------------------------------121번째 시작----------------------------------------------------
# {'_id': 's262136', 'name': '우지영', 'inst': '순천향대학교 부천병원 마취통증의학과'}
# {'_id': 's61713', 'name': '우지영', 'inst': '순천향대학교 빅데이터공학과'}
# {'_id': 's262131', 'name': '우지영', 'inst': '순천향대학교, 빅데이터공학과'}
# {'_id': '213005557289', 'name': '우지영', 'inst': '순천향대학교'}
# scienceon_id: ['s262136', 's61713', 's262131']
# ntis_id: 213005557289
# ----------------------------------------------------121번째   끝----------------------------------------------------
# name: 오유수 inst: 대구대학교
# ----------------------------------------------------122번째 시작----------------------------------------------------
# {'_id': 's276203', 'name': '오유수', 'inst': '대구대학교'}
# {'_id': '214153547176', 'name': '오유수', 'inst': '대구대학교'}
# scienceon_id: ['s276203']
# ntis_id: 214153547176
# ----------------------------------------------------122번째   끝----------------------------------------------------
# name: 황창하 inst: 단국대학교
# ----------------------------------------------------123번째 시작----------------------------------------------------
# {'_id': 's311212', 'name': '황창하', 'inst': '단국대학교 응용통계학과'}
# {'_id': '214161795195', 'name': '황창하', 'inst': '단국대학교'}
# scienceon_id: ['s311212']
# ntis_id: 214161795195
# ----------------------------------------------------123번째   끝----------------------------------------------------
# name: 김현아 inst: 경기대학교
# ----------------------------------------------------124번째 시작----------------------------------------------------
# {'_id': '215500877283', 'name': '김현아', 'inst': '경기대학교'}
# scienceon_id: []
# ntis_id: 215500877283
# ----------------------------------------------------124번째   끝----------------------------------------------------
# name: 민준기 inst: 한국기술교육대학교
# ----------------------------------------------------125번째 시작----------------------------------------------------
# {'_id': 's258161', 'name': '민준기', 'inst': '한국기술교육대학교 컴퓨터공학부'}
# {'_id': '215901257128', 'name': '민준기', 'inst': '한국기술교육대학교'}
# scienceon_id: ['s258161']
# ntis_id: 215901257128
# ----------------------------------------------------125번째   끝----------------------------------------------------
# name: 최대진 inst: 인천대학교
# ----------------------------------------------------126번째 시작----------------------------------------------------
# {'_id': '216141918175', 'name': '최대진', 'inst': '인천대학교'}
# scienceon_id: []
# ntis_id: 216141918175
# ----------------------------------------------------126번째   끝----------------------------------------------------
# ...
# scienceon_id: []
# ntis_id: 808168618703
# ----------------------------------------------------177번째   끝----------------------------------------------------
# name: 이지현 inst: 한국과학기술원
# ----------------------------------------------------178번째 시작----------------------------------------------------
# {'_id': 's309574', 'name': '이지현', 'inst': '한국과학기술원 문화기술대학원'}
# {'_id': '809210816201', 'name': '이지현', 'inst': '한국과학기술원'}
# {'_id': '12487951', 'name': '이지현', 'inst': '한국과학기술원'}
# scienceon_id: ['s309574']
# ntis_id: 12487951
# ----------------------------------------------------178번째   끝----------------------------------------------------
# name: 강용신 inst: 성균관대학교(자연과학캠퍼스)
# ----------------------------------------------------179번째 시작----------------------------------------------------
# scienceon_id: []
# ntis_id:
# ----------------------------------------------------179번째   끝----------------------------------------------------
# name: 최재영 inst: 한국외국어대학교
# ----------------------------------------------------180번째 시작----------------------------------------------------
# {'_id': '810157318880', 'name': '최재영', 'inst': '한국외국어대학교'}
# {'_id': '407126316794', 'name': '최재영', 'inst': '한국외국어대학교'}
# {'_id': '817803227102', 'name': '최재영', 'inst': '한국외국어대학교(용인캠퍼스)'}
# scienceon_id: []
# ntis_id: 817803227102
# ----------------------------------------------------180번째   끝----------------------------------------------------
# name: 이원진 inst: 단국대학교
# ----------------------------------------------------181번째 시작----------------------------------------------------
# {'_id': 's1084606', 'name': '이원진', 'inst': '단국대학교 미디어콘텐츠연구원'}
# {'_id': 's1053039', 'name': '이원진', 'inst': '단국대학교 소프트웨어학과'}
# {'_id': 's315536', 'name': '이원진', 'inst': '단국대학교 정보문화기술연구원'}
# {'_id': '810577487135', 'name': '이원진', 'inst': '단국대학교 산학협력단'}
# scienceon_id: ['s1084606', 's1053039', 's315536']
# ntis_id: 810577487135
# ----------------------------------------------------181번째   끝----------------------------------------------------
# name: 남권희 inst: 경북대학교
# ----------------------------------------------------182번째 시작----------------------------------------------------
# {'_id': '811063275169', 'name': '남권희', 'inst': '경북대학교'}
# scienceon_id: []
# ntis_id: 811063275169
# ----------------------------------------------------182번째   끝----------------------------------------------------
# name: 홍송남 inst: 한양대학교
# ----------------------------------------------------183번째 시작----------------------------------------------------
# {'_id': '811164577199', 'name': '홍송남', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 811164577199
# ----------------------------------------------------183번째   끝----------------------------------------------------
# name: 서지훈 inst: 인천대학교
# ----------------------------------------------------184번째 시작----------------------------------------------------
# {'_id': '811194018932', 'name': '서지훈', 'inst': '인천대학교'}
# scienceon_id: []
# ntis_id: 811194018932
# ----------------------------------------------------184번째   끝----------------------------------------------------
# name: 박관수 inst: 부산대학교
# ----------------------------------------------------185번째 시작----------------------------------------------------
# {'_id': 's9937', 'name': '박관수', 'inst': '부산대학교'}
# {'_id': 's14306', 'name': '박관수', 'inst': '부산대학교 전기공학과'}
# {'_id': 's292703', 'name': '박관수', 'inst': '부산대학교 전기컴퓨터공학부'}
# {'_id': 's10810', 'name': '박관수', 'inst': '부산대학교 전자전기공학과'}
# {'_id': 's306243', 'name': '박관수', 'inst': '부산대학교 전자전기컴퓨터공학과'}
# {'_id': 's12061', 'name': '박관수', 'inst': '전기공학과, 부산대학교'}
# {'_id': '813180516399', 'name': '박관수', 'inst': '부산대학교'}
# scienceon_id: ['s9937', 's14306', 's292703', 's10810', 's306243', 's12061']
# ntis_id: 813180516399
# ----------------------------------------------------185번째   끝----------------------------------------------------
# name: 권오민 inst: 충북대학교
# ----------------------------------------------------186번째 시작----------------------------------------------------
# {'_id': 's1034158', 'name': '권오민', 'inst': '충북대학교 전기공학과'}
# {'_id': '813863787148', 'name': '권오민', 'inst': '충북대학교'}
# {'_id': '11871343', 'name': '권오민', 'inst': '충북대학교'}
# scienceon_id: ['s1034158']
# ntis_id: 11871343
# ----------------------------------------------------186번째   끝----------------------------------------------------
# name: 박유미 inst: 한국과학기술원
# ----------------------------------------------------187번째 시작----------------------------------------------------
# {'_id': '814957447298', 'name': '박유미', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 814957447298
# ----------------------------------------------------187번째   끝----------------------------------------------------
# name: 김경백 inst: 전남대학교
# ----------------------------------------------------188번째 시작----------------------------------------------------
# {'_id': 's1114504', 'name': '김경백', 'inst': '전남대학교'}
# {'_id': 's1045217', 'name': '김경백', 'inst': '전남대학교 공과대학 전자컴퓨터공학부'}
# {'_id': 's260086', 'name': '김경백', 'inst': '전남대학교 전자컴퓨터공학부'}
# {'_id': 's260790', 'name': '김경백', 'inst': '전자컴퓨터공학부, 전남대학교'}
# {'_id': '815957567160', 'name': '김경백', 'inst': '전남대학교'}
# scienceon_id: ['s1114504', 's1045217', 's260086', 's260790']
# ntis_id: 815957567160
# ----------------------------------------------------188번째   끝----------------------------------------------------
# name: 선호근 inst: 부산대학교
# ----------------------------------------------------189번째 시작----------------------------------------------------
# {'_id': '816202747181', 'name': '선호근', 'inst': '부산대학교'}
# scienceon_id: []
# ntis_id: 816202747181
# ----------------------------------------------------189번째   끝----------------------------------------------------
# name: 이성희 inst: 한국과학기술원
# ----------------------------------------------------190번째 시작----------------------------------------------------
# {'_id': '816701217143', 'name': '이성희', 'inst': '한국과학기술원'}
# {'_id': '11821518', 'name': '이성희', 'inst': '한국과학기술원'}
# scienceon_id: []
# ntis_id: 11821518
# ----------------------------------------------------190번째   끝----------------------------------------------------
# name: 오명훈 inst: 단국대학교
# ----------------------------------------------------191번째 시작----------------------------------------------------
# {'_id': 's274502', 'name': '오명훈', 'inst': '단국대학교 소프트웨어 학과'}
# {'_id': '817780859104', 'name': '오명훈', 'inst': '단국대학교 산학협력단'}
# scienceon_id: ['s274502']
# ntis_id: 817780859104
# ----------------------------------------------------191번째   끝----------------------------------------------------
# name: 현성협 inst: 부산대학교
# ----------------------------------------------------192번째 시작----------------------------------------------------
# {'_id': '819672787178', 'name': '현성협', 'inst': '부산대학교'}
# scienceon_id: []
# ntis_id: 819672787178
# ----------------------------------------------------192번째   끝----------------------------------------------------
# name: 조윤식 inst: 세종대학교
# ----------------------------------------------------193번째 시작----------------------------------------------------
# {'_id': '820931557191', 'name': '조윤식', 'inst': '세종대학교'}
# scienceon_id: []
# ntis_id: 820931557191
# ----------------------------------------------------193번째   끝----------------------------------------------------
# name: 조경록 inst: 충북대학교산학협력단
# ----------------------------------------------------194번째 시작----------------------------------------------------
# {'_id': '820963685155', 'name': '조경록', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 820963685155
# ----------------------------------------------------194번째   끝----------------------------------------------------
# name: 김광훈 inst: 경기대학교
# ----------------------------------------------------195번째 시작----------------------------------------------------
# {'_id': 's269987', 'name': '김광훈', 'inst': '경기대학교 컴퓨터과학과 협업시스템 산학협력연구실'}
# {'_id': '821103016788', 'name': '김광훈', 'inst': '경기대학교'}
# scienceon_id: ['s269987']
# ntis_id: 821103016788
# ----------------------------------------------------195번째   끝----------------------------------------------------
# name: 용환승 inst: 이화여자대학교
# ----------------------------------------------------196번째 시작----------------------------------------------------
# {'_id': 's259258', 'name': '용환승', 'inst': '이화여자대학교 컴퓨터공학과'}
# {'_id': '821196816109', 'name': '용환승', 'inst': '이화여자대학교'}
# scienceon_id: ['s259258']
# ntis_id: 821196816109
# ----------------------------------------------------196번째   끝----------------------------------------------------
# name: 강주영 inst: 한양대학교
# ----------------------------------------------------197번째 시작----------------------------------------------------
# {'_id': 's267521', 'name': '강주영', 'inst': '한양대학교 컴퓨터공학과'}
# {'_id': '823005877263', 'name': '강주영', 'inst': '한양대학교'}
# scienceon_id: ['s267521']
# ntis_id: 823005877263
# ----------------------------------------------------197번째   끝----------------------------------------------------
# name: 최진호 inst: 한양대학교
# ----------------------------------------------------198번째 시작----------------------------------------------------
# {'_id': '824113918776', 'name': '최진호', 'inst': '한양대학교'}
# {'_id': '11703026', 'name': '최진호', 'inst': '한양대학교 에리카산학협력단'}
# {'_id': '871160318294', 'name': '최진호', 'inst': '한양대학교산학협력단'}
# scienceon_id: []
# ntis_id: 871160318294
# ----------------------------------------------------198번째   끝----------------------------------------------------
# name: 정경용 inst: 경기대학교산학협력단
# ----------------------------------------------------199번째 시작----------------------------------------------------
# {'_id': '825309427177', 'name': '정경용', 'inst': '경기대학교산학협력단'}
# scienceon_id: []
# ntis_id: 825309427177
# ----------------------------------------------------199번째   끝----------------------------------------------------
# name: 양현 inst: 충북대학교산학협력단
# ----------------------------------------------------200번째 시작----------------------------------------------------
# {'_id': '826104218973', 'name': '양현', 'inst': '충북대학교산학협력단'}
# scienceon_id: []
# ntis_id: 826104218973
# ----------------------------------------------------200번째   끝----------------------------------------------------
# name: 이하빈 inst: 한양대학교
# ----------------------------------------------------201번째 시작----------------------------------------------------
# {'_id': '828105616939', 'name': '이하빈', 'inst': '한양대학교'}
# scienceon_id: []
# ntis_id: 828105616939
# ----------------------------------------------------201번째   끝----------------------------------------------------
# name: 주길홍 inst: 경인교육대학교
# ----------------------------------------------------202번째 시작----------------------------------------------------
# {'_id': '835309717117', 'name': '주길홍', 'inst': '경인교육대학교'}
# {'_id': 's55116', 'name': '주길홍', 'inst': '경인교육대학교 지식자원개발센터'}
# scienceon_id: []
# ntis_id: s55116
# ----------------------------------------------------202번째   끝----------------------------------------------------
# name: 최종무 inst: 단국대학교
# ----------------------------------------------------203번째 시작----------------------------------------------------
# {'_id': 's274503', 'name': '최종무', 'inst': '단국대학교 소프트웨어 학과'}
# {'_id': 's264452', 'name': '최종무', 'inst': '단국대학교 소프트웨어학과'}
# {'_id': 's137554', 'name': '최종무', 'inst': '단국대학교 정보컴퓨터학부'}
# {'_id': 's1084173', 'name': '최종무', 'inst': '단국대학교 컴퓨터공학과'}
# {'_id': 's273786', 'name': '최종무', 'inst': '단국대학교 컴퓨터학과'}
# {'_id': 's310221', 'name': '최종무', 'inst': '단국대학교 컴퓨터학부'}
# {'_id': '839194036154', 'name': '최종무', 'inst': '단국대학교 산학협력단'}
# scienceon_id: ['s274503', 's264452', 's137554', 's1084173', 's273786', 's310221']
# ntis_id: 839194036154
# ----------------------------------------------------203번째   끝----------------------------------------------------
# name: 이종국 inst: 계명대학교
# ----------------------------------------------------204번째 시작----------------------------------------------------
# {'_id': 's261952', 'name': '이종국', 'inst': '계명대학교 건축토목공학부 건축학전공'}
# {'_id': 's1004101', 'name': '이종국', 'inst': '계명대학교 건축학대학 건축학과'}
# {'_id': '839604275194', 'name': '이종국', 'inst': '계명대학교'}
# scienceon_id: ['s261952', 's1004101']
# ntis_id: 839604275194
# ----------------------------------------------------204번째   끝----------------------------------------------------
# name: 김정은 inst: 공주대학교
# ----------------------------------------------------205번째 시작----------------------------------------------------
# {'_id': '854177518634', 'name': '김정은', 'inst': '공주대학교'}
# {'_id': '820254618393', 'name': '김정은', 'inst': '공주대학교'}
# scienceon_id: []
# ntis_id: 820254618393
# ----------------------------------------------------205번째   끝----------------------------------------------------
# name: 유재수 inst: 충북대학교
# ----------------------------------------------------206번째 시작----------------------------------------------------
# {'_id': 's101957', 'name': '유재수', 'inst': '충북대학교', 'keywords': ''}
# {'_id': 's259243', 'name': '유재수', 'inst': '충북대학교 빅데이터학과'}
# {'_id': 's1045892', 'name': '유재수', 'inst': '충북대학교 전기.전자.정보.컴퓨터학부 정보통신 공학전공'}
# {'_id': 's270145', 'name': '유재수', 'inst': '충북대학교 전기.전자.정보.컴퓨터학부 정보통신공학전공'}
# {'_id': 's263816', 'name': '유재수', 'inst': '충북대학교 전기전자컴퓨터공학부'}
# {'_id': 's264744', 'name': '유재수', 'inst': '충북대학교 전자정보대학 정보통신공학과'}
# {'_id': 's1039040', 'name': '유재수', 'inst': '충북대학교 전자정보대학 정보통신공학부'}
# {'_id': 's258835', 'name': '유재수', 'inst': '충북대학교 정보통신공학'}
# {'_id': 's258057', 'name': '유재수', 'inst': '충북대학교 정보통신공학과'}
# {'_id': 's264187', 'name': '유재수', 'inst': '충북대학교 정보통신공학과 </a'}
# {'_id': 's264378', 'name': '유재수', 'inst': "충북대학교 정보통신공학과<affiliationid type='KI"}
# {'_id': 's259873', 'name': '유재수', 'inst': '충북대학교 정보통신공학부'}
# {'_id': 's258099', 'name': '유재수', 'inst': '충북대학교 정보통신공학부 및 충북BIT연구중심대학육성사업단'}
# {'_id': 's260968', 'name': '유재수', 'inst': '충북대학교 정보통신학과'}
# {'_id': '857111516498', 'name': '유재수', 'inst': '충북대학교'}
# scienceon_id: ['s101957', 's259243', 's1045892', 's270145', 's263816', 's264744', 's1039040', 's258835', 's258057', 's264187', 's264378', 's259873', 's258099', 's260968']
# ntis_id: 857111516498
# ----------------------------------------------------206번째   끝----------------------------------------------------
# name: 노준용 inst: 한국과학기술원
# ----------------------------------------------------207번째 시작----------------------------------------------------
# {'_id': 's534673', 'name': '노준용', 'inst': '한국과학기술원'}
# {'_id': '844604227118', 'name': '노준용', 'inst': '한국과학기술원'}
# {'_id': '874920207511', 'name': '노준용', 'inst': '한국과학기술원'}
# scienceon_id: ['s534673']
# ntis_id: 874920207511
# ----------------------------------------------------207번째   끝----------------------------------------------------
# name: PIAO GENSONG inst: 한양대학교(ERICA캠퍼스)
# ----------------------------------------------------208번째 시작----------------------------------------------------
# scienceon_id: []
# ntis_id:
# ----------------------------------------------------208번째   끝----------------------------------------------------
# name: 송민 inst: 연세대학교
# ----------------------------------------------------209번째 시작----------------------------------------------------
# {'_id': 's264471', 'name': '송민', 'inst': '연세대학교 문과대학 문헌정보학과'}
# {'_id': 's257991', 'name': '송민', 'inst': '연세대학교 문헌정보학과'}
# {'_id': '879556376701', 'name': '송민', 'inst': '연세대학교'}
# scienceon_id: ['s264471', 's257991']
# ntis_id: 879556376701
# ----------------------------------------------------209번째   끝----------------------------------------------------
# name: 이권형 inst: 동의대학교
# ----------------------------------------------------210번째 시작----------------------------------------------------
# {'_id': '894155218533', 'name': '이권형', 'inst': '동의대학교'}
# scienceon_id: []
# ntis_id: 894155218533
# ----------------------------------------------------210번째   끝----------------------------------------------------
# name: 권정혜 inst: 충남대학교산학협력단
# ----------------------------------------------------211번째 시작----------------------------------------------------
# {'_id': 's208675', 'name': '권정혜', 'inst': '충남대학교산학협력단'}
# scienceon_id: []
# ntis_id: s208675
# ----------------------------------------------------211번째   끝----------------------------------------------------
# name: 박은일 inst: 성균관대학교
# ----------------------------------------------------212번째 시작----------------------------------------------------
# {'_id': 's55129', 'name': '박은일', 'inst': '성균관대학교'}
# {'_id': '11299562', 'name': '박은일', 'inst': '성균관대학교 산학협력단'}
# scienceon_id: []
# ntis_id: 11299562
# ----------------------------------------------------212번째   끝----------------------------------------------------

# %%
from pymongo import MongoClient
client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
scienceon_aut = client['SCIENCEON']['Author']
ntis_exfa = client['NTIS']['ExpertFactor']
ntis_aut = client['NTIS']['Author']
id_domestic = client['ID']['Domestic']

class authorinst:
    def __init__(self, keyid):
        self.keyid = keyid #input

    def authorinst_ntis(self):
        ntis_key_query = ntis_exfa.find({ 'keyId' : self.keyid })
        ntis_a_id = [] # A_ID
        ntis_name_inst = []
        all_name_inst = []
        re_Copy_name = []
        re_Copy_inst = []
        re_Copy = []
        scienceon_id = []
        ntis_id = ''
            
        for j in ntis_key_query:
            ntis_a_id.append(j['A_ID'])
            aut_query = ntis_aut.find_one({'_id':j['A_ID']})
            ntis_name_inst.append(aut_query['name'] + '/' + aut_query['inst'].split(' ')[0])

        for c in ntis_name_inst:
            if c not in re_Copy:
                re_Copy.append(c)
                re_Copy_name.append(c.split('/')[0])
                re_Copy_inst.append(c.split('/')[1])
        
        for l in range(0, len(re_Copy_name)):
            a_name = re_Copy_name[l]
            a_inst = re_Copy_inst[l]
        
        scienceon_query = scienceon_aut.find({'$and':[{'name':a_name},{'inst':{'$regex':a_inst}}]})
        ntis_query = ntis_aut.find({'$and':[{'name':a_name},{'inst':{'$regex':a_inst}}]})
        
        print('name: %s inst: %s' % (a_name, a_inst))
        print('----------------------------------------------------%d번째 시작----------------------------------------------------' % (l+1))
        for x in scienceon_query:
            print(x)
            scienceon_id.append(x['_id'])
        
        for y in ntis_query:
            print(y)
            ntis_id = y['_id']
            
        if scienceon_id == [] and ntis_id == '':
            pass
        else:
            id_domestic.insert({'scienceon': scienceon_id, 'ntis': ntis_id, 'keyid': self.keyid})

        print('scienceon_id: %s' %scienceon_id)
        print('ntis_id: %s' %ntis_id)
        print('----------------------------------------------------%d번째   끝----------------------------------------------------' % (l+1))

# %%
a = authorinst(519)
a.authorinst_ntis()
# Out:
# name: 조화순 inst: 연세대학교
# ----------------------------------------------------1061번째 시작----------------------------------------------------
# {'_id': 's270104', 'name': '조화순', 'inst': '연세대학교 정치외교학과'}
# {'_id': 's72544', 'name': '조화순', 'inst': '연세대학교'}
# {'_id': '886290336243', 'name': '조화순', 'inst': '연세대학교'}
# scienceon_id: ['s270104']
# ntis_id: 886290336243
# ----------------------------------------------------1061번째   끝----------------------------------------------------
# C:\Users\Hyeuk\anaconda3\envs\craw\lib\site-packages\ipykernel_launcher.py:54: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
