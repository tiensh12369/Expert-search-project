# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import re

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 653 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if key_query['prdEnd'][:4] in nyear or key_query['prdStart'][:4] in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if (key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        #if site[i] != 'NTIS' :
        A_id = [A_id]
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt) :  # 소속 같을때
#                                if site[i]
                                Answer_dict[tempName][site[i]]['A_id'].extend(A_id)
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1]  or (src != "" and src in tgt):  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가
# Out:
# 5128

# %%
def check_college(univ0):
    univName = client['PUBLIC']['CollegeName']
    univ1 = re.sub("산학협력단|병원","",univ0)
    univ2 = re.sub("대학교","대학교 ",univ1)
    try:

        reg = re.compile(r'[a-zA-Z]')
    
        if reg.match(univ0):
            univ0 = univ0.upper()
            univ = univ0.split(', ')
            
        else:
            univ = univ2.replace(",", "").split()
            univ = list(set(univ))
            
        univs = "{'$or': ["
        for u in range(len(univ)):
            if univ[-1] == univ[u]:
                univs += "{'inputName': '" + univ[u] + "'}"
            else:
                univs += "{'inputName': '" + univ[u] + "'}, "
        univs += "]}"

        univ_query = univName.find_one(eval(univs))

        if univ_query is None:
            print("Search inst None")
            return univ0
        else:
            #print("rawInput:[",univ0,"]","queryOutput:" ,univ_query['originalName'])
            return univ_query['originalName'] #univ0, univ_query
        
    except SyntaxError as e:
        print(e)
        print(univ0)
        return univ0

def filter(name, site, inst, rawdata):
    if site == 'NTIS' :
        #oriinst = rawdata['ldAgency']
        inst = check_college(inst)
        '''
        if inst == None:
            inst = oriinst
        else:
            inst = oriinst.replace(inst['inputName'], inst['originalName'])
        ''' 
        coauthor = rawdata['rsc'].split(";")
        year = int(rawdata['prdStart'][:4])
        keyword = rawdata['koKeyword'].split(",")
        journal = ""
        conference = ""
        title = ""
        mng = rawdata['mng']

    else :
        #oriinst = rawdata['author_inst'].split(";")[rawdata['author'].split(";").index(name)]
        inst = check_college(inst)
        #inst = oriinst
        '''
        if inst == None:
            inst = oriinst
        else:
            inst = oriinst.replace(inst['inputName'], inst['originalName'])
        '''
        coauthor = rawdata['author'].split(";")[1:-1]
        year = int(rawdata['issue_year'][:4])
        
        if rawdata['paper_keyword'] == [] or rawdata['paper_keyword'] == 'None':
            keyword = []
        elif len(rawdata['paper_keyword']) > 1:
            for i in range(0, len(rawdata['paper_keyword'])):
                keyword = []
                keyword.append(rawdata['paper_keyword'][i].replace(" ", "").split("."))            
        else:
            keyword = rawdata['paper_keyword'].replace(" ", "").split(".")

        journal = rawdata['journal']
        conference = rawdata['issue_inst']
        title = rawdata['title']
        mng = rawdata['author'].split(";")[-1]
        #abstract = rawdata['abstract']

    return inst, coauthor, year, keyword, journal, conference, title, mng
    #return inst, coauthor, year, keyword, journal, conference, title, mng, abstract

def Secondary_filter(name, site1, inst1, raw_one1, site2, inst2, raw_one2):

    inst1, coauthor1, year1, keyword1, journal1, conference1, title1, mng1 = filter(name, site1, inst1, raw_one1)
    inst2, coauthor2, year2, keyword2, journal2, conference2, title2, mng2 = filter(name, site2, inst2, raw_one2)
    inst = jaro.jaro_winkler_metric(inst1, inst2)
    weight = 0
    joc = 0
    
    if name in coauthor1:
        coauthor1.remove(name)

    if name in coauthor2:
        coauthor2.remove(name)

    co_author_count = len([i for i in coauthor1 if i in coauthor2])

    if site1 != 'NTIS' and site2 != 'NTIS' :
        if title1 == title2 or inst >= 0.8: #or mng1 == mng2: # 
            weight = 4
            return weight

        else:
            joc = 1 if journal1 == journal2 and conference1 == conference2 else -1
    else:
        if inst >= 0.8:
            weight = 3
            return weight
            
    yop = -(2*(abs(year1-year2)/10)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) > len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
                
    co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    #print(f'joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')

    weight = joc + yop + co_authorship + keyword

    return weight

# %%
data0 = Answer_dict
sites = ['NTIS', 'SCIENCEON', 'KCI']
raw_dbs = {'NTIS' : ntis_raw, 'SCIENCEON' : scion_raw, 'KCI' : kci_raw}

def getRaw(name):
    if 'raws' not in data0[name]:
        raws = []
        for site in sites:
            if site in data0[name]:
                for c in raw_dbs[site].find({"_id": {"$in": data0[name][site]['papers']}}):
                    c['site'] = site
                    raws.append(c)
        
        data0[name]['raws'] = raws

processedList = []
deleteList = []

for data in data0 :
    if '_' in data :
        name = data.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in data0 :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        
        processedList.append(name[0])
        flag = True
        while flag : 
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            
            for pair in pairs:
                pair = list(pair)
                
                '''
                # <2차통합 유사도 함수 자리>
                # 2차통합유사도함수_상혁(data0[pair[0]]['raws'], data0[pair[1]]['raws'])
                # return 값으로 두 명에 대한 유사도 값이 나옴
                # 6 이상이면 통합 / 임시로 result 변수로 사용
                '''
                # pair[0]                  pair[1]
                
                raws1 = data0[pair[0]]['raws']
                
                raws2 = data0[pair[1]]['raws']
                
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = data0[pair[0]][site1]['inst']
                    inst2 = data0[pair[1]][site2]['inst']


                    if Secondary_filter(name[0], site1, inst1, ra1, site2, inst2, ra2) >= 2.5:

                        # print("=================")
                        # print(data0[pair[0]])
                        # print(ra1)
                        # print(data0[pair[1]])
                        # print(ra2)
                        deleteList.append(pair[1])
                        for site in sites:
                            if site in data0[pair[1]]:
                                if site in data0[pair[0]].keys() :                            
                                    data0[pair[0]][site]['A_id'].extend(data0[pair[1]][site]['A_id'])
                                    data0[pair[0]][site]['papers'].extend(data0[pair[1]][site]['papers'])
                                    data0[pair[0]]['raws'].extend(data0[pair[1]]['raws'])
                                else:
                                    data0[pair[0]][site] = data0[pair[1]][site]
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break
        
for d in deleteList:
    del data0[d]

#print(data0)
for d in data0 : 
    if 'raws' in data0[d] :
        del data0[d]['raws']

#print(data0)
# Out:
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# INSTITUTE OF ARTIFICIAL INTELLIGENCE AND ROBOTICS, XI'AN JIAOTONG UNIVERSITY, XI'AN, CHINA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# DEPT. OF COMPUTER SCIENCE, SOOKMYUNG WOMEN'S UNIVERSITY
# invalid syntax (<string>, line 1)
# SOOKMYUNG WOMEN'S UNIVERSITY, SOUTH KOREA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# ASTAR, INSTITUTE FOR INFOCOMM RESEARCH, SINGAPORE, SINGAPORE
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# SCHOOL OF COMPUTER SCIENCE, NORTHWESTERN POLYTECHNICAL UNIVERSITY, XI'AN, CHINA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# STATE KEY LABORATORY OF ALTERNATE ELECTRICAL POWER SYSTEM WITH RENEWABLE ENERGY SOURCES NORTH CHINA ELECTRIC POWER UNIVERSITY BEIJING PEOPLE'S REPUBLIC OF CHINA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# SCHOOL OF ELECTRONIC INFORMATION ENGINEERING, XI'AN TECHNOLOGICAL UNIVERSITY, XI'AN, CHINA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# QUEEN'S UNIVERSITY, KINGSTON, ONTARIO, CANADA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# XI'AN UNIVERSITY OF SCIENCE AND TECHNOLOGY, XI'AN, CHINA
# Search inst None
# invalid syntax (<string>, line 1)
# XI'AN UNIVERSITY OF SCIENCE AND TECHNOLOGY, XI'AN, CHINA
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# XI'AN UNIVERSITY OF SCIENCE AND TECHNOLOGY, XI'AN, CHINA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# AERONAUTICS ENGINEERING COLLEGE, AIR FORCE ENGINEERING UNIVERSITY, XI'AN, CHINA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# DEPARTMENT OF COMPUTER SCIENCE AND ENGINEERING, XI'AN UNIVERSITY OF TECHNOLOGY, XI'AN, CHINA
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# invalid syntax (<string>, line 1)
# DIVISION OF COMPUTER SCIENCE, SOOKMYUNG WOMEN'S UNIVERSITY

# %%
import json
Answer_dict = data0

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter, numInteErr
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
       
        if len(answer[name].keys()) > 1 :
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        else :
            pass
       #    print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name'].split('_')[0]
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            # if name+str(count) not in answer :
            #     print(name)
            while name+str(count) in answer :
                # if name+count in answer :
             #   print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError = 0
    
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError += 1
                
                #print("answer=",key, answer[key])
                '''
                if key not in Answer_dict :
                    count = 0
                    
                    while key+str(count) in Answer_dict :
                        # if name+count in answer :
                        print("result=", Answer_dict[ key+str(count)])                        
                        count += 1
                else :    
                    print("result=", Answer_dict[key])
                '''
            #print(key)|
            #print(answer[key])
        
    print("토탈에러", totalError)   
    print("토탈ㅇ인터그레이션에러", totalInteError)
    print(keyid)    

#print(Answer_dict)
# Out:
# 536
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '배재대학교', 'KCI': '배재대학교'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '정회경', 'SCIENCEON': {'inst': 'National Science & Technology Information Service, KISTI', 'A_id': ['s1087709'], 'papers': [ObjectId('61cea81cde84cb5ab77cc3d1')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of Computer Convergence Software, Korea University', 'KCI': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '정용화', 'SCIENCEON': {'inst': 'Dept of Computer and Convergence Software, Korea University', 'A_id': ['s1412619', 's176705'], 'papers': [ObjectId('61cea829de84cb5ab77cc42d'), ObjectId('61cea838de84cb5ab77cc4f8'), ObjectId('61cea864de84cb5ab77cc6bb')]}, 'KCI': {'inst': '고려대학교', 'A_id': ['s11864', 's11864'], 'papers': [ObjectId('61cea6ff0f91d3fd2b7caf28'), ObjectId('61cea6f10f91d3fd2b7cae62'), ObjectId('61cea6ff0f91d3fd2b7caf28'), ObjectId('61cea6f10f91d3fd2b7cae62')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '부산대학교, 통계학과', 'KCI': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '박소영', 'SCIENCEON': {'inst': '부산대학교, 통계학과', 'A_id': ['s1410999'], 'papers': [ObjectId('61cea7fede84cb5ab77cc262')]}, 'KCI': {'inst': '부산대학교', 'A_id': ['s16878'], 'papers': [ObjectId('61cea6f30f91d3fd2b7cae96')]}, 'NTIS': {'inst': '부경대학교', 'A_id': ['MTAxNTc3MTU='], 'papers': [ObjectId('61cea6f6f8d08a558d7d03b0'), ObjectId('61cea6f1f8d08a558d7d02e7')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'K-water 연구원', 'KCI': 'Korea Water Resources Corporation'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '김연수', 'KCI': {'inst': 'Korea Water Resources Corporation', 'A_id': ['s457942'], 'papers': [ObjectId('61cea6f30f91d3fd2b7cae8a')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'K-water 연구원', 'KCI': 'Korea Water Resources Corporation'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '김연수', 'SCIENCEON': {'inst': 'K-water 연구원', 'A_id': ['s1408695'], 'papers': [ObjectId('61cea7bbde84cb5ab77cbf94')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'KAIST 건설및환경공학과, 건물성능및진단학', 'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '장성주', 'KCI': {'inst': '한국과학기술원', 'A_id': ['s52021'], 'papers': [ObjectId('61cea6ed0f91d3fd2b7cae0e')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'KAIST 건설및환경공학과, 건물성능및진단학', 'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '장성주', 'SCIENCEON': {'inst': 'KAIST 건설및환경공학과, 건물성능및진단학', 'A_id': ['s1410010'], 'papers': [ObjectId('61cea7e1de84cb5ab77cc179')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': "Division of Computer Science, Sookmyung Women's University", 'KCI': '숙명여자대학교'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '이기용', 'KCI': {'inst': '숙명여자대학교', 'A_id': ['s7223'], 'papers': [ObjectId('61cea6ef0f91d3fd2b7cae31'), ObjectId('61cea6ed0f91d3fd2b7cadd1'), ObjectId('61cea6ed0f91d3fd2b7cade2'), ObjectId('61cea6f10f91d3fd2b7cae58')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': "Division of Computer Science, Sookmyung Women's University", 'KCI': '숙명여자대학교'}
#  - Result : {'fid': 0, 'keyId': 653, 'name': '이기용', 'SCIENCEON': {'inst': "Division of Computer Science, Sookmyung Women's University", 'A_id': ['s1062992'], 'papers': [ObjectId('61cea829de84cb5ab77cc42e')]}}
# num코렉트 523
# numEror 17
# numInteEror 9
# answer= 김경환 {'SCIENCEON': '건국대학교 건축학부'}
# answer= 김경환0 {'KCI': '한국해양수산연수원'}
# answer= 김경환1 {'KCI': '건국대학교'}
# answer= 김연수 {'SCIENCEON': 'K-water 연구원', 'KCI': 'Korea Water Resources Corporation'}
# answer= 노원우 {'NTIS': '연세대학교 산학협력단'}
# answer= 박소영0 {'NTIS': '부경대학교'}
# answer= 박소영1 {'SCIENCEON': '부산대학교, 통계학과', 'KCI': '부산대학교'}
# answer= 성연식 {'NTIS': '동국대학교'}
# answer= 이기용 {'SCIENCEON': "Division of Computer Science, Sookmyung Women's University", 'KCI': '숙명여자대학교'}
# answer= 이창진1 {'KCI': '국방과학연구소', 'SCIENCEON': 'The 5th R&D Institute - 1st Directorate, Agency for Defense Development'}
# answer= 장성주 {'SCIENCEON': 'KAIST 건설및환경공학과, 건물성능및진단학', 'KCI': '한국과학기술원'}
# answer= 정용화0 {'SCIENCEON': 'Dept. of Computer Convergence Software, Korea University', 'KCI': '고려대학교'}
# answer= 정윤경 {'NTIS': '성균관대학교'}
# 토탈에러 13
# 토탈ㅇ인터그레이션에러 6
# 653

# %%
a = jaro.jaro_winkler_metric('중앙대학교', '세종대학교')
print(a)
# Out:
# 0.7333333333333334
