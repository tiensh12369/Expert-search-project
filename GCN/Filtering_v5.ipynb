# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 632 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if int(key_query['prdEnd'][:4]) in nyear or int(key_query['prdStart'][:4]) in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if int(key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1]: # or (src != "" and src in tgt) :  # 소속 같을때
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1]: # or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가
# Out:
# 197

# %%
import json

answer = None
numCor = 0
numErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
        print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        #if len(answer[name].keys()) > 1 :
        numErr += 1
    return flag

with open('answer632.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name']
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            # if name+str(count) not in answer :
            #     print(name)
            while name+str(count) in answer :
                # if name+count in answer :
                print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    tempCount = 0
    '''
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            tempCount += 1
            print(key)
            print(answer[key])
    '''     
    print(tempCount)
# Out:
# 187
# Not Correct
#  - Answer : {'SCIENCEON': '조선대학교병원 재활치료팀'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이세훈', 'SCIENCEON': {'inst': '인하공업전문대학교 컴퓨터시스템과', 'A_id': 's102540', 'papers': [ObjectId('61cbf9bf597f83aefb455bcd')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '성균관대학교 일반대학원 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '신성윤', 'SCIENCEON': {'inst': 'Kunsan National University', 'A_id': 's143723', 'papers': [ObjectId('61cbf9bf597f83aefb455bd5')]}}
# Not Correct
#  - Answer : {'NTIS': '중앙대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박상현', 'SCIENCEON': {'inst': '연세대학교 컴퓨터과학과', 'A_id': 's169002', 'papers': [ObjectId('61cbf9a7597f83aefb455bb7')]}}
# Not Correct
#  - Answer : {'KCI': '한남대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '임동혁', 'SCIENCEON': {'inst': '호서대학교 컴퓨터정보공학부', 'A_id': 's258513', 'papers': [ObjectId('61cbf9ca597f83aefb455bdc')]}}
# Check 유재수0
# Not Correct
#  - Answer : {'SCIENCEON': '전자부품연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학부', 'A_id': 's259873', 'papers': [ObjectId('61cbf9b6597f83aefb455bc9')]}}
# Check 유재수1
# Not Correct
#  - Answer : {'SCIENCEON': '경기대학교 컴퓨터과학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학부', 'A_id': 's259873', 'papers': [ObjectId('61cbf9b6597f83aefb455bc9')]}}
# Check 유재수2
# Not Correct
#  - Answer : {'SCIENCEON': '전북대학교 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학부', 'A_id': 's259873', 'papers': [ObjectId('61cbf9b6597f83aefb455bc9')]}}
# Check 유재수3
# Not Correct
#  - Answer : {'SCIENCEON': 'Kunsan National University'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학부', 'A_id': 's259873', 'papers': [ObjectId('61cbf9b6597f83aefb455bc9')]}}
# Check 유재수0
# Not Correct
#  - Answer : {'SCIENCEON': '전자부품연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학과', 'A_id': 's258057', 'papers': [ObjectId('61cbf9a7597f83aefb455bb3'), ObjectId('61cbf9ab597f83aefb455bbe')]}}
# Check 유재수1
# Not Correct
#  - Answer : {'SCIENCEON': '경기대학교 컴퓨터과학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학과', 'A_id': 's258057', 'papers': [ObjectId('61cbf9a7597f83aefb455bb3'), ObjectId('61cbf9ab597f83aefb455bbe')]}}
# Check 유재수2
# Not Correct
#  - Answer : {'SCIENCEON': '전북대학교 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학과', 'A_id': 's258057', 'papers': [ObjectId('61cbf9a7597f83aefb455bb3'), ObjectId('61cbf9ab597f83aefb455bbe')]}}
# Check 유재수3
# Not Correct
#  - Answer : {'SCIENCEON': 'Kunsan National University'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학과', 'A_id': 's258057', 'papers': [ObjectId('61cbf9a7597f83aefb455bb3'), ObjectId('61cbf9ab597f83aefb455bbe')]}}
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김학수', 'SCIENCEON': {'inst': '강원대학교 컴퓨터정보통신공학과', 'A_id': 's260098', 'papers': [ObjectId('61cbf9ba597f83aefb455bcb')]}}
# Not Correct
#  - Answer : {'NTIS': '국립강원대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '류범종', 'SCIENCEON': {'inst': '한국과학기술정보연구원', 'A_id': 's264308', 'papers': [ObjectId('61cbf9ab597f83aefb455bba')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '충북대학교 정보통신공학부'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '신동렬', 'SCIENCEON': {'inst': '성균관대학교 정보통신학부', 'A_id': 's264350', 'papers': [ObjectId('61cbf9a7597f83aefb455bb9')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '세한대학교 작업치료학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '신용학', 'SCIENCEON': {'inst': 'LS 산전 스마트솔루션 연구팀', 'A_id': 's265129', 'papers': [ObjectId('61cbf9af597f83aefb455bc2')]}}
# Not Correct
#  - Answer : {'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '임태범', 'SCIENCEON': {'inst': '전자부품연구원', 'A_id': 's265682', 'papers': [ObjectId('61cbf9b3597f83aefb455bc5')]}}
# Check 정은경0
# Not Correct
#  - Answer : {'KCI': '서울시립대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'SCIENCEON': {'inst': '이화여자대학교 사회과학대학 문헌정보학과', 'A_id': 's267872', 'papers': [ObjectId('61cbf9bf597f83aefb455bcf')]}}
# Check 정은경1
# Not Correct
#  - Answer : {'KCI': '을지대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'SCIENCEON': {'inst': '이화여자대학교 사회과학대학 문헌정보학과', 'A_id': 's267872', 'papers': [ObjectId('61cbf9bf597f83aefb455bcf')]}}
# Check 정은경2
# Not Correct
#  - Answer : {'KCI': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'SCIENCEON': {'inst': '이화여자대학교 사회과학대학 문헌정보학과', 'A_id': 's267872', 'papers': [ObjectId('61cbf9bf597f83aefb455bcf')]}}
# Check 정은경0
# Not Correct
#  - Answer : {'KCI': '서울시립대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'SCIENCEON': {'inst': '이화여자대학교 사회과학대학 문헌정보전공', 'A_id': 's264554', 'papers': [ObjectId('61cbf9ab597f83aefb455bbc')]}}
# Check 정은경1
# Not Correct
#  - Answer : {'KCI': '을지대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'SCIENCEON': {'inst': '이화여자대학교 사회과학대학 문헌정보전공', 'A_id': 's264554', 'papers': [ObjectId('61cbf9ab597f83aefb455bbc')]}}
# Check 정은경2
# Not Correct
#  - Answer : {'KCI': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'SCIENCEON': {'inst': '이화여자대학교 사회과학대학 문헌정보전공', 'A_id': 's264554', 'papers': [ObjectId('61cbf9ab597f83aefb455bbc')]}}
# Not Correct
#  - Answer : {'KCI': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '진성일', 'SCIENCEON': {'inst': '충남대학교 컴퓨터공학과', 'A_id': 's268085', 'papers': [ObjectId('61cbf9bf597f83aefb455bd3'), ObjectId('61cbf9bf597f83aefb455bd4')]}}
# Not Correct
#  - Answer : {'KCI': '이화여자대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정유경', 'SCIENCEON': {'inst': '연세대학교 문헌정보학과', 'A_id': 's268131', 'papers': [ObjectId('61cbf9c3597f83aefb455bd6')]}}
# Not Correct
#  - Answer : {'NTIS': '한양대학교 에리카산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '류근호', 'SCIENCEON': {'inst': '충북대학교 데이터베이스/바이오인포매틱스 연구실', 'A_id': 's268135', 'papers': [ObjectId('61cbf9c3597f83aefb455bd7')]}}
# Check 황혜경0
# Not Correct
#  - Answer : {'KCI': '대구가톨릭대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황혜경', 'SCIENCEON': {'inst': '한국과학기술정보연구원', 'A_id': 's268759', 'papers': [ObjectId('61cbf9c7597f83aefb455bd9')]}, 'KCI': {'inst': '한국과학기술정보연구원', 'A_id': 's53658', 'papers': [ObjectId('61cbf9c5f72c82d20d455bd6')]}}
# Check 황혜경1
# Not Correct
#  - Answer : {'KCI': '한국과학기술정보연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황혜경', 'SCIENCEON': {'inst': '한국과학기술정보연구원', 'A_id': 's268759', 'papers': [ObjectId('61cbf9c7597f83aefb455bd9')]}, 'KCI': {'inst': '한국과학기술정보연구원', 'A_id': 's53658', 'papers': [ObjectId('61cbf9c5f72c82d20d455bd6')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '전남대학교 전기및반도체공학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이우진', 'SCIENCEON': {'inst': '국민대학교 글로벌창업벤처대학원', 'A_id': 's269379', 'papers': [ObjectId('61cbf9cd597f83aefb455bde')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '연세대학교 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유창동', 'NTIS': {'inst': '한국과학기술원', 'A_id': '103110916125', 'papers': [ObjectId('61cbf9bb3b642afa40455c98'), ObjectId('61cbf9bb3b642afa40455c70')]}}
# Not Correct
#  - Answer : {'NTIS': '목원대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김종완', 'NTIS': {'inst': '삼육대학교', 'A_id': '106164916026', 'papers': [ObjectId('61cbf9af3b642afa40455c00'), ObjectId('61cbf9af3b642afa40455bf0'), ObjectId('61cbf9af3b642afa40455be5')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '호서대학교 컴퓨터정보공학부'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이상준', 'NTIS': {'inst': '숭실대학교', 'A_id': '112292207130', 'papers': [ObjectId('61cbf9bb3b642afa40455c9e')]}}
# Not Correct
#  - Answer : {'SCIENCEON': 'LS 산전 스마트솔루션 연구팀'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '심창범', 'NTIS': {'inst': '고려대학교', 'A_id': '11436282', 'papers': [ObjectId('61cbf9af3b642afa40455bde')]}}
# Not Correct
#  - Answer : {'KCI': '전자부품연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이재홍', 'NTIS': {'inst': '원광대학교', 'A_id': '11467814', 'papers': [ObjectId('61cbf9af3b642afa40455bf4'), ObjectId('61cbf9af3b642afa40455be6'), ObjectId('61cbf9af3b642afa40455bda')]}}
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김경옥', 'NTIS': {'inst': '서울과학기술대학교 산학협력단', 'A_id': '11561235', 'papers': [ObjectId('61cbf9b53b642afa40455c2b')]}}
# Not Correct
#  - Answer : {'KCI': '전남대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황지은', 'NTIS': {'inst': '서울대학교', 'A_id': '11650435', 'papers': [ObjectId('61cbf9af3b642afa40455be9'), ObjectId('61cbf9af3b642afa40455bdd')]}}
# Not Correct
#  - Answer : {'KCI': '청암대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황재성', 'NTIS': {'inst': '경희대학교(용인) 산학협력단', 'A_id': '129113916252', 'papers': [ObjectId('61cbf9bb3b642afa40455ca2')]}}
# Not Correct
#  - Answer : {'NTIS': '한국기술교육대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김진영', 'NTIS': {'inst': '경희대학교', 'A_id': '207180114194', 'papers': [ObjectId('61cbf9bb3b642afa40455c9a')]}}
# Not Correct
#  - Answer : {'NTIS': '경희대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김건형', 'NTIS': {'inst': '부산대학교', 'A_id': '212118567178', 'papers': [ObjectId('61cbf9af3b642afa40455be1'), ObjectId('61cbf9af3b642afa40455bd8')]}}
# Not Correct
#  - Answer : {'KCI': '군산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이재길', 'NTIS': {'inst': '한국과학기술원', 'A_id': '212349877150', 'papers': [ObjectId('61cbf9b53b642afa40455c3e'), ObjectId('61cbf9b53b642afa40455c24'), ObjectId('61cbf9af3b642afa40455c04')]}}
# Not Correct
#  - Answer : {'KCI': '충북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이윤준', 'NTIS': {'inst': '한국과학기술원', 'A_id': '213709915147', 'papers': [ObjectId('61cbf9bb3b642afa40455c86'), ObjectId('61cbf9bb3b642afa40455c71')]}}
# Not Correct
#  - Answer : {'NTIS': '성균관대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박윤배', 'NTIS': {'inst': '경북대학교', 'A_id': '213963585151', 'papers': [ObjectId('61cbf9b53b642afa40455c26')]}}
# Not Correct
#  - Answer : {'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황승원', 'NTIS': {'inst': '포항공과대학교', 'A_id': '215007737264', 'papers': [ObjectId('61cbf9bb3b642afa40455c85')]}}
# Not Correct
#  - Answer : {'NTIS': '한국외국어대학교(용인캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '민준기', 'NTIS': {'inst': '한국기술교육대학교', 'A_id': '215901257128', 'papers': [ObjectId('61cbf9b53b642afa40455c3c'), ObjectId('61cbf9b53b642afa40455c1a'), ObjectId('61cbf9af3b642afa40455c08')]}}
# Not Correct
#  - Answer : {'KCI': '군산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정기홍', 'NTIS': {'inst': '경희대학교 산학협력단', 'A_id': '225489887104', 'papers': [ObjectId('61cbf9bb3b642afa40455c9f'), ObjectId('61cbf9bb3b642afa40455c8a'), ObjectId('61cbf9b53b642afa40455c5b'), ObjectId('61cbf9b53b642afa40455c39'), ObjectId('61cbf9bb3b642afa40455c7a')]}}
# Not Correct
#  - Answer : {'KCI': '경기대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '임희석', 'NTIS': {'inst': '고려대학교산학협력단', 'A_id': '249175846247', 'papers': [ObjectId('61cbf9b53b642afa40455c49'), ObjectId('61cbf9b53b642afa40455c2d')]}}
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '고영만', 'NTIS': {'inst': '성균관대학교', 'A_id': '313400205198', 'papers': [ObjectId('61cbf9bb3b642afa40455c84'), ObjectId('61cbf9b53b642afa40455c4a'), ObjectId('61cbf9b53b642afa40455c61'), ObjectId('61cbf9b53b642afa40455c44')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '충북대학교 정보통신공학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '오정미', 'NTIS': {'inst': '서울대학교', 'A_id': '313650086503', 'papers': [ObjectId('61cbf9bb3b642afa40455c77')]}}
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김종익', 'NTIS': {'inst': '전북대학교', 'A_id': '313839177157', 'papers': [ObjectId('61cbf9af3b642afa40455bf3'), ObjectId('61cbf9af3b642afa40455be8'), ObjectId('61cbf9af3b642afa40455bd9')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '서울대학교의생명연구원 연구실험부'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이상근', 'NTIS': {'inst': '고려대학교', 'A_id': '315567197111', 'papers': [ObjectId('61cbf9bb3b642afa40455c97'), ObjectId('61cbf9bb3b642afa40455c6d')]}}
# Not Correct
#  - Answer : {'KCI': '동덕여자대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정하림', 'NTIS': {'inst': '성균관대학교(자연과학캠퍼스)', 'A_id': '400192418853', 'papers': [ObjectId('61cbf9bb3b642afa40455c6c'), ObjectId('61cbf9b53b642afa40455c4e'), ObjectId('61cbf9b53b642afa40455c3d'), ObjectId('61cbf9b53b642afa40455c1c'), ObjectId('61cbf9af3b642afa40455c0e'), ObjectId('61cbf9af3b642afa40455bfb'), ObjectId('61cbf9af3b642afa40455bed')]}}
# Check 장재우0
# Not Correct
#  - Answer : {'KCI': '대전보건대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장재우', 'NTIS': {'inst': '전북대학교', 'A_id': '401143516963', 'papers': [ObjectId('61cbf9b53b642afa40455c64'), ObjectId('61cbf9b53b642afa40455c41'), ObjectId('61cbf9b53b642afa40455c25')]}, 'KCI': {'inst': '전북대학교', 'A_id': 's46746', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc4')]}}
# Check 장재우1
# Not Correct
#  - Answer : {'KCI': '호남대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장재우', 'NTIS': {'inst': '전북대학교', 'A_id': '401143516963', 'papers': [ObjectId('61cbf9b53b642afa40455c64'), ObjectId('61cbf9b53b642afa40455c41'), ObjectId('61cbf9b53b642afa40455c25')]}, 'KCI': {'inst': '전북대학교', 'A_id': 's46746', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc4')]}}
# Not Correct
#  - Answer : {'NTIS': '인하대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '노웅기', 'NTIS': {'inst': '가천대학교', 'A_id': '408192536839', 'papers': [ObjectId('61cbf9af3b642afa40455bfa'), ObjectId('61cbf9af3b642afa40455bf6'), ObjectId('61cbf9af3b642afa40455bdf')]}}
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '고대식', 'NTIS': {'inst': '목원대학교 산학협력단', 'A_id': '414121435194', 'papers': [ObjectId('61cbf9bb3b642afa40455c93')]}}
# Not Correct
#  - Answer : {'KCI': '수원시정연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정우식', 'NTIS': {'inst': '경상대학교', 'A_id': '414693227108', 'papers': [ObjectId('61cbf9bb3b642afa40455ca3')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '충남대학교 컴퓨터공학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '오병모', 'NTIS': {'inst': '서울대학교병원', 'A_id': '417118617140', 'papers': [ObjectId('61cbf9af3b642afa40455beb')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '한국과학기술정보연구원 정보서비스센터 국내정보팀'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유영선', 'NTIS': {'inst': '경희대학교', 'A_id': '418160575281', 'papers': [ObjectId('61cbf9bb3b642afa40455c9d')]}}
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박석', 'NTIS': {'inst': '서강대학교', 'A_id': '418879305165', 'papers': [ObjectId('61cbf9bb3b642afa40455c7d'), ObjectId('61cbf9b53b642afa40455c55'), ObjectId('61cbf9b53b642afa40455c38'), ObjectId('61cbf9bb3b642afa40455c68')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '인하대학교 정보통신공학부'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '윤희용', 'NTIS': {'inst': '성균관대학교 산학협력단', 'A_id': '427109605151', 'papers': [ObjectId('61cbf9bb3b642afa40455c65')]}}
# Not Correct
#  - Answer : {'KCI': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '홍봉희', 'NTIS': {'inst': '부산대학교', 'A_id': '427631255191', 'papers': [ObjectId('61cbf9bb3b642afa40455c8d'), ObjectId('61cbf9bb3b642afa40455c8c'), ObjectId('61cbf9bb3b642afa40455c76'), ObjectId('61cbf9b53b642afa40455c5c')]}}
# Check 박기남0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박기남', 'NTIS': {'inst': '순천향대학교', 'A_id': '461104328442', 'papers': [ObjectId('61cbf9b53b642afa40455c5a')]}}
# Check 박기남1
# Not Correct
#  - Answer : {'NTIS': '성균관대학교(자연과학캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박기남', 'NTIS': {'inst': '순천향대학교', 'A_id': '461104328442', 'papers': [ObjectId('61cbf9b53b642afa40455c5a')]}}
# Check 박기남0
# Not Correct
#  - Answer : {'SCIENCEON': 'Department of Computer Engineering, Chungnam National University'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '은창수', 'NTIS': {'inst': '한양대학교', 'A_id': '468193116517', 'papers': [ObjectId('61cbf9b53b642afa40455c53'), ObjectId('61cbf9b53b642afa40455c3a'), ObjectId('61cbf9b53b642afa40455c18')]}}
# Check 최원익0
# Not Correct
#  - Answer : {'KCI': '경상대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'NTIS': {'inst': '인하대학교 산학협력단', 'A_id': '489175026305', 'papers': [ObjectId('61cbf9bb3b642afa40455c95'), ObjectId('61cbf9bb3b642afa40455c89'), ObjectId('61cbf9b53b642afa40455c51'), ObjectId('61cbf9bb3b642afa40455c79')]}}
# Check 최원익1
# Not Correct
#  - Answer : {'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'NTIS': {'inst': '인하대학교 산학협력단', 'A_id': '489175026305', 'papers': [ObjectId('61cbf9bb3b642afa40455c95'), ObjectId('61cbf9bb3b642afa40455c89'), ObjectId('61cbf9b53b642afa40455c51'), ObjectId('61cbf9bb3b642afa40455c79')]}}
# Check 최원익2
# Not Correct
#  - Answer : {'KCI': '한국고전번역원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'NTIS': {'inst': '인하대학교 산학협력단', 'A_id': '489175026305', 'papers': [ObjectId('61cbf9bb3b642afa40455c95'), ObjectId('61cbf9bb3b642afa40455c89'), ObjectId('61cbf9b53b642afa40455c51'), ObjectId('61cbf9bb3b642afa40455c79')]}}
# Check 최원익0
# Not Correct
#  - Answer : {'KCI': '경상대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'SCIENCEON': {'inst': '인하대학교 정보통신공학', 'A_id': 's266120', 'papers': [ObjectId('61cbf9b3597f83aefb455bc6')]}}
# Check 최원익1
# Not Correct
#  - Answer : {'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'SCIENCEON': {'inst': '인하대학교 정보통신공학', 'A_id': 's266120', 'papers': [ObjectId('61cbf9b3597f83aefb455bc6')]}}
# Check 최원익2
# Not Correct
#  - Answer : {'KCI': '한국고전번역원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'SCIENCEON': {'inst': '인하대학교 정보통신공학', 'A_id': 's266120', 'papers': [ObjectId('61cbf9b3597f83aefb455bc6')]}}
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김한준', 'NTIS': {'inst': '서울시립대학교', 'A_id': '497153316825', 'papers': [ObjectId('61cbf9b53b642afa40455c2c')]}}
# Not Correct
#  - Answer : {'NTIS': '삼육대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김용혁', 'NTIS': {'inst': '광운대학교 산학협력단', 'A_id': '517140197163', 'papers': [ObjectId('61cbf9b53b642afa40455c2e'), ObjectId('61cbf9b53b642afa40455c16'), ObjectId('61cbf9af3b642afa40455c09')]}}
# Not Correct
#  - Answer : {'KCI': '세한대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정연돈', 'NTIS': {'inst': '고려대학교산학협력단', 'A_id': '558737247115', 'papers': [ObjectId('61cbf9bb3b642afa40455c96'), ObjectId('61cbf9bb3b642afa40455c88'), ObjectId('61cbf9b53b642afa40455c5f'), ObjectId('61cbf9b53b642afa40455c46'), ObjectId('61cbf9b53b642afa40455c21'), ObjectId('61cbf9af3b642afa40455c05'), ObjectId('61cbf9af3b642afa40455bf8'), ObjectId('61cbf9af3b642afa40455bf2'), ObjectId('61cbf9af3b642afa40455be7')]}}
# Not Correct
#  - Answer : {'NTIS': '서강대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '배창석', 'NTIS': {'inst': '대전대학교', 'A_id': '564119216101', 'papers': [ObjectId('61cbf9b53b642afa40455c1f'), ObjectId('61cbf9af3b642afa40455c0b'), ObjectId('61cbf9af3b642afa40455bfd'), ObjectId('61cbf9af3b642afa40455bec')]}}
# Not Correct
#  - Answer : {'KCI': '안양대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '조강희', 'NTIS': {'inst': '부산대학교', 'A_id': '593122126215', 'papers': [ObjectId('61cbf9bb3b642afa40455c9c')]}}
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김회린', 'NTIS': {'inst': '한국과학기술원', 'A_id': '601115926385', 'papers': [ObjectId('61cbf9bb3b642afa40455ca0')]}}
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김원구', 'NTIS': {'inst': '군산대학교', 'A_id': '604184316465', 'papers': [ObjectId('61cbf9bb3b642afa40455c8b'), ObjectId('61cbf9b53b642afa40455c58'), ObjectId('61cbf9bb3b642afa40455c6e')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '을지대학교 임상병리학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이병엽', 'NTIS': {'inst': '배재대학교', 'A_id': '609116416180', 'papers': [ObjectId('61cbf9b53b642afa40455c52'), ObjectId('61cbf9b53b642afa40455c32'), ObjectId('61cbf9b53b642afa40455c20'), ObjectId('61cbf9af3b642afa40455c02'), ObjectId('61cbf9af3b642afa40455bf9'), ObjectId('61cbf9af3b642afa40455bf5')]}}
# Not Correct
#  - Answer : {'NTIS': '가천대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '소민호', 'NTIS': {'inst': '한국과학기술원', 'A_id': '641158916414', 'papers': [ObjectId('61cbf9bb3b642afa40455c69'), ObjectId('61cbf9b53b642afa40455c48')]}}
# Not Correct
#  - Answer : {'NTIS': '고려대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '문양세', 'NTIS': {'inst': '국립강원대학교 산학협력단', 'A_id': '649109116902', 'papers': [ObjectId('61cbf9b53b642afa40455c62'), ObjectId('61cbf9b53b642afa40455c42')]}}
# Not Correct
#  - Answer : {'NTIS': '성균관대학교(자연과학캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박호현', 'NTIS': {'inst': '중앙대학교', 'A_id': '684159816692', 'papers': [ObjectId('61cbf9b53b642afa40455c59'), ObjectId('61cbf9b53b642afa40455c37'), ObjectId('61cbf9b53b642afa40455c19')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '한국과학기술정보연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '윤일동', 'NTIS': {'inst': '한국외국어대학교(용인캠퍼스)', 'A_id': '805186116796', 'papers': [ObjectId('61cbf9b53b642afa40455c47')]}}
# Not Correct
#  - Answer : {'KCI': '순천향대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이지현', 'NTIS': {'inst': '한국과학기술원', 'A_id': '809210816201', 'papers': [ObjectId('61cbf9bb3b642afa40455ca1')]}}
# Not Correct
#  - Answer : {'NTIS': '경희대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박희민', 'NTIS': {'inst': '상명대학교(천안캠퍼스)', 'A_id': '810907457119', 'papers': [ObjectId('61cbf9bb3b642afa40455c6b'), ObjectId('61cbf9bb3b642afa40455c66'), ObjectId('61cbf9b53b642afa40455c3f')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '군산대학교 전파공학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이기용', 'NTIS': {'inst': '숙명여자대학교', 'A_id': '814500937150', 'papers': [ObjectId('61cbf9b53b642afa40455c40'), ObjectId('61cbf9b53b642afa40455c23'), ObjectId('61cbf9af3b642afa40455c03')]}}
# Not Correct
#  - Answer : {'KCI': '한국건설기술연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '한욱신', 'NTIS': {'inst': '포항공과대학교', 'A_id': '818563287125', 'papers': [ObjectId('61cbf9bb3b642afa40455c73'), ObjectId('61cbf9b53b642afa40455c60'), ObjectId('61cbf9b53b642afa40455c45'), ObjectId('61cbf9b53b642afa40455c22'), ObjectId('61cbf9af3b642afa40455bd5')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '이화여자대학교 사회과학대학 문헌정보전공'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '우종우', 'NTIS': {'inst': '국민대학교산학협력단', 'A_id': '818706935137', 'papers': [ObjectId('61cbf9bb3b642afa40455c6f')]}}
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '고영준', 'NTIS': {'inst': '서울과학기술대학교 산학협력단', 'A_id': '819117315171', 'papers': [ObjectId('61cbf9bb3b642afa40455ca4')]}}
# Not Correct
#  - Answer : {'NTIS': '안양대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김선호', 'NTIS': {'inst': '서강대학교', 'A_id': '819953677205', 'papers': [ObjectId('61cbf9af3b642afa40455be0'), ObjectId('61cbf9af3b642afa40455bd6')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '인하공업전문대학교 컴퓨터시스템과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이동호', 'NTIS': {'inst': '한양대학교 에리카산학협력단', 'A_id': '820007937127', 'papers': [ObjectId('61cbf9bb3b642afa40455c6a')]}}
# Not Correct
#  - Answer : {'NTIS': '성결대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박광진', 'NTIS': {'inst': '원광대학교', 'A_id': '827901307111', 'papers': [ObjectId('61cbf9b53b642afa40455c57'), ObjectId('61cbf9b53b642afa40455c34'), ObjectId('61cbf9b53b642afa40455c1d'), ObjectId('61cbf9b53b642afa40455c63'), ObjectId('61cbf9bb3b642afa40455c7c')]}}
# Check 김문기0
# Not Correct
#  - Answer : {'NTIS': '서울과학기술대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김문기', 'NTIS': {'inst': '경북대학교', 'A_id': '835860495106', 'papers': [ObjectId('61cbf9bb3b642afa40455c9b'), ObjectId('61cbf9bb3b642afa40455c81')]}}
# Check 김문기1
# Not Correct
#  - Answer : {'NTIS': '경희대학교(용인) 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김문기', 'NTIS': {'inst': '경북대학교', 'A_id': '835860495106', 'papers': [ObjectId('61cbf9bb3b642afa40455c9b'), ObjectId('61cbf9bb3b642afa40455c81')]}}
# Not Correct
#  - Answer : {'KCI': '건국대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최동완', 'NTIS': {'inst': '인하대학교 산학협력단', 'A_id': '853175318104', 'papers': [ObjectId('61cbf9af3b642afa40455bdc')]}}
# Check 유재수0
# Not Correct
#  - Answer : {'SCIENCEON': '전자부품연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'NTIS': {'inst': '충북대학교', 'A_id': '857111516498', 'papers': [ObjectId('61cbf9bb3b642afa40455c74'), ObjectId('61cbf9bb3b642afa40455c74')]}, 'KCI': {'inst': '충북대학교', 'A_id': 's20760', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc1')]}}
# Check 유재수1
# Not Correct
#  - Answer : {'SCIENCEON': '경기대학교 컴퓨터과학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'NTIS': {'inst': '충북대학교', 'A_id': '857111516498', 'papers': [ObjectId('61cbf9bb3b642afa40455c74'), ObjectId('61cbf9bb3b642afa40455c74')]}, 'KCI': {'inst': '충북대학교', 'A_id': 's20760', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc1')]}}
# Check 유재수2
# Not Correct
#  - Answer : {'SCIENCEON': '전북대학교 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'NTIS': {'inst': '충북대학교', 'A_id': '857111516498', 'papers': [ObjectId('61cbf9bb3b642afa40455c74'), ObjectId('61cbf9bb3b642afa40455c74')]}, 'KCI': {'inst': '충북대학교', 'A_id': 's20760', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc1')]}}
# Check 유재수3
# Not Correct
#  - Answer : {'SCIENCEON': 'Kunsan National University'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '유재수', 'NTIS': {'inst': '충북대학교', 'A_id': '857111516498', 'papers': [ObjectId('61cbf9bb3b642afa40455c74'), ObjectId('61cbf9bb3b642afa40455c74')]}, 'KCI': {'inst': '충북대학교', 'A_id': 's20760', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc1')]}}
# Not Correct
#  - Answer : {'NTIS': '국민대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '강재우', 'NTIS': {'inst': '고려대학교', 'A_id': '859116116166', 'papers': [ObjectId('61cbf9bb3b642afa40455c8e'), ObjectId('61cbf9bb3b642afa40455c72'), ObjectId('61cbf9b53b642afa40455c5d'), ObjectId('61cbf9b53b642afa40455c5e'), ObjectId('61cbf9b53b642afa40455c43')]}}
# Not Correct
#  - Answer : {'KCI': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정순영', 'NTIS': {'inst': '고려대학교', 'A_id': '893183916722', 'papers': [ObjectId('61cbf9b53b642afa40455c54'), ObjectId('61cbf9b53b642afa40455c33'), ObjectId('61cbf9bb3b642afa40455c7b')]}}
# Not Correct
#  - Answer : {'NTIS': '동국대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박수상', 'NTIS': {'inst': '서울대학교산학협력단', 'A_id': '899120918318', 'papers': [ObjectId('61cbf9bb3b642afa40455c67')]}}
# Not Correct
#  - Answer : {'NTIS': '숭실대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김동성', 'NTIS': {'inst': '이화여자대학교', 'A_id': 's55172', 'papers': [ObjectId('61cbf9af3b642afa40455c11')]}}
# Not Correct
#  - Answer : {'NTIS': '서강대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박명수', 'NTIS': {'inst': '서울신학대학교', 'A_id': 's72099', 'papers': [ObjectId('61cbf9b53b642afa40455c29')]}}
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '설문원', 'NTIS': {'inst': '부산대학교', 'A_id': 's72135', 'papers': [ObjectId('61cbf9b53b642afa40455c13'), ObjectId('61cbf9af3b642afa40455c06')]}}
# Not Correct
#  - Answer : {'NTIS': '서울과학기술대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '강명숙', 'NTIS': {'inst': '배재대학교', 'A_id': 's72154', 'papers': [ObjectId('61cbf9b53b642afa40455c27'), ObjectId('61cbf9af3b642afa40455c10')]}}
# Not Correct
#  - Answer : {'NTIS': '이화여자대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김정빈', 'NTIS': {'inst': '한국기술교육대학교', 'A_id': 's72168', 'papers': [ObjectId('61cbf9bb3b642afa40455c91'), ObjectId('61cbf9af3b642afa40455c0f')]}}
# Not Correct
#  - Answer : {'NTIS': '경희대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박일우', 'NTIS': {'inst': '계명대학교', 'A_id': 's72215', 'papers': [ObjectId('61cbf9bb3b642afa40455c7f')]}}
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '권경득', 'NTIS': {'inst': '선문대학교', 'A_id': 's72278', 'papers': [ObjectId('61cbf9b53b642afa40455c2a')]}}
# Not Correct
#  - Answer : {'KCI': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이준서', 'NTIS': {'inst': '성결대학교', 'A_id': 's72296', 'papers': [ObjectId('61cbf9b53b642afa40455c28')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '충북대학교 데이터베이스/바이오인포매틱스 연구실'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이경철', 'NTIS': {'inst': '동국대학교', 'A_id': 's72339', 'papers': [ObjectId('61cbf9b53b642afa40455c4c')]}}
# Not Correct
#  - Answer : {'NTIS': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김정우', 'NTIS': {'inst': '한국신학정보연구원', 'A_id': 's72351', 'papers': [ObjectId('61cbf9b53b642afa40455c4d')]}}
# Not Correct
#  - Answer : {'NTIS': '경상대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '남승호', 'NTIS': {'inst': '서울대학교', 'A_id': 's72357', 'papers': [ObjectId('61cbf9bb3b642afa40455c82'), ObjectId('61cbf9b53b642afa40455c4b')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '전주대학교 보건관리학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '심경호', 'NTIS': {'inst': '고려대학교', 'A_id': 's72406', 'papers': [ObjectId('61cbf9bb3b642afa40455c83')]}}
# Not Correct
#  - Answer : {'KCI': '가톨릭대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '탁성숙', 'NTIS': {'inst': '가천대학교', 'A_id': 's72415', 'papers': [ObjectId('61cbf9bb3b642afa40455c80')]}}
# Not Correct
#  - Answer : {'KCI': '재단법인 동국문화재연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장완호', 'KCI': {'inst': '연세대학교', 'A_id': 's1016', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf2')]}}
# Not Correct
#  - Answer : {'KCI': '순천향대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '하민정', 'KCI': {'inst': '이화여자대학교 법학연구소', 'A_id': 's125021', 'papers': [ObjectId('61cbf9def72c82d20d455c08')]}}
# Not Correct
#  - Answer : {'NTIS': '상명대학교(천안캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김태희', 'KCI': {'inst': '순천향대학교', 'A_id': 's15147', 'papers': [ObjectId('61cbf9d4f72c82d20d455bef')]}}
# Check 배영철0
# Not Correct
#  - Answer : {'NTIS': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '배영철', 'KCI': {'inst': '전남대학교', 'A_id': 's16945', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd4')]}}
# Check 배영철1
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '배영철', 'KCI': {'inst': '전남대학교', 'A_id': 's16945', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd4')]}}
# Check 배영철0
# Not Correct
#  - Answer : {'NTIS': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '배영철', 'SCIENCEON': {'inst': '전남대학교 전기및반도체공학과', 'A_id': 's268415', 'papers': [ObjectId('61cbf9c7597f83aefb455bd8')]}}
# Check 배영철1
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '배영철', 'SCIENCEON': {'inst': '전남대학교 전기및반도체공학과', 'A_id': 's268415', 'papers': [ObjectId('61cbf9c7597f83aefb455bd8')]}}
# Not Correct
#  - Answer : {'NTIS': '서울대학교병원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '남광우', 'KCI': {'inst': '군산대학교', 'A_id': 's29105', 'papers': [ObjectId('61cbf9bcf72c82d20d455bcb')]}}
# Not Correct
#  - Answer : {'KCI': '진주보건대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '전성현', 'KCI': {'inst': '동아대학교', 'A_id': 's296349', 'papers': [ObjectId('61cbf9e2f72c82d20d455c09')]}}
# Not Correct
#  - Answer : {'KCI': '서강대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '홍영의', 'KCI': {'inst': '국민대학교', 'A_id': 's33889', 'papers': [ObjectId('61cbf9def72c82d20d455c06')]}}
# Check 최원익0
# Not Correct
#  - Answer : {'KCI': '경상대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'KCI': {'inst': '인하대학교', 'A_id': 's38799', 'papers': [ObjectId('61cbf9cff72c82d20d455be2'), ObjectId('61cbf9cff72c82d20d455be2')]}}
# Check 최원익1
# Not Correct
#  - Answer : {'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'KCI': {'inst': '인하대학교', 'A_id': 's38799', 'papers': [ObjectId('61cbf9cff72c82d20d455be2'), ObjectId('61cbf9cff72c82d20d455be2')]}}
# Check 최원익2
# Not Correct
#  - Answer : {'KCI': '한국고전번역원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최원익', 'KCI': {'inst': '인하대학교', 'A_id': 's38799', 'papers': [ObjectId('61cbf9cff72c82d20d455be2'), ObjectId('61cbf9cff72c82d20d455be2')]}}
# Check 장석우0
# Not Correct
#  - Answer : {'KCI': '명지대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장석우', 'KCI': {'inst': '안양대학교', 'A_id': 's39040', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc5')]}}
# Check 장석우1
# Not Correct
#  - Answer : {'KCI': '조선대학교병원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장석우', 'KCI': {'inst': '안양대학교', 'A_id': 's39040', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc5')]}}
# Check 장석우0
# Not Correct
#  - Answer : {'KCI': '명지대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장석우', 'SCIENCEON': {'inst': '안양대학교 디지털미디어학과', 'A_id': 's100270', 'papers': [ObjectId('61cbf9ba597f83aefb455bcc')]}}
# Check 장석우1
# Not Correct
#  - Answer : {'KCI': '조선대학교병원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장석우', 'SCIENCEON': {'inst': '안양대학교 디지털미디어학과', 'A_id': 's100270', 'papers': [ObjectId('61cbf9ba597f83aefb455bcc')]}}
# Check 김유성0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김유성', 'KCI': {'inst': '인하대학교', 'A_id': 's4080', 'papers': [ObjectId('61cbf9cbf72c82d20d455bda')]}}
# Check 김유성1
# Not Correct
#  - Answer : {'NTIS': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김유성', 'KCI': {'inst': '인하대학교', 'A_id': 's4080', 'papers': [ObjectId('61cbf9cbf72c82d20d455bda')]}}
# Check 김유성0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김유성', 'SCIENCEON': {'inst': '인하대학교 정보통신공학부', 'A_id': 's264859', 'papers': [ObjectId('61cbf9ab597f83aefb455bc1')]}}
# Check 김유성1
# Not Correct
#  - Answer : {'NTIS': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김유성', 'SCIENCEON': {'inst': '인하대학교 정보통신공학부', 'A_id': 's264859', 'papers': [ObjectId('61cbf9ab597f83aefb455bc1')]}}
# Not Correct
#  - Answer : {'KCI': '안양대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '주진열', 'KCI': {'inst': '부산대학교', 'A_id': 's41609', 'papers': [ObjectId('61cbf9d4f72c82d20d455be4')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '국민대학교 글로벌창업벤처대학원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이경영', 'KCI': {'inst': '경기대학교', 'A_id': 's45501', 'papers': [ObjectId('61cbf9dbf72c82d20d455c03')]}}
# Not Correct
#  - Answer : {'NTIS': '가천대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김범수', 'KCI': {'inst': '한국건설기술연구원', 'A_id': 's46499', 'papers': [ObjectId('61cbf9bff72c82d20d455bcf'), ObjectId('61cbf9bcf72c82d20d455bca')]}}
# Not Correct
#  - Answer : {'KCI': '한국과학기술정보연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최준영', 'KCI': {'inst': '청암대학교', 'A_id': 's48376', 'papers': [ObjectId('61cbf9bcf72c82d20d455bce')]}}
# Check 정은경0
# Not Correct
#  - Answer : {'KCI': '서울시립대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'KCI': {'inst': '이화여자대학교', 'A_id': 's48380', 'papers': [ObjectId('61cbf9cff72c82d20d455bdc'), ObjectId('61cbf9d4f72c82d20d455bee'), ObjectId('61cbf9d6f72c82d20d455bfa'), ObjectId('61cbf9cff72c82d20d455bdc'), ObjectId('61cbf9d4f72c82d20d455bee'), ObjectId('61cbf9d6f72c82d20d455bfa')]}}
# Check 정은경1
# Not Correct
#  - Answer : {'KCI': '을지대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'KCI': {'inst': '이화여자대학교', 'A_id': 's48380', 'papers': [ObjectId('61cbf9cff72c82d20d455bdc'), ObjectId('61cbf9d4f72c82d20d455bee'), ObjectId('61cbf9d6f72c82d20d455bfa'), ObjectId('61cbf9cff72c82d20d455bdc'), ObjectId('61cbf9d4f72c82d20d455bee'), ObjectId('61cbf9d6f72c82d20d455bfa')]}}
# Check 정은경2
# Not Correct
#  - Answer : {'KCI': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은경', 'KCI': {'inst': '이화여자대학교', 'A_id': 's48380', 'papers': [ObjectId('61cbf9cff72c82d20d455bdc'), ObjectId('61cbf9d4f72c82d20d455bee'), ObjectId('61cbf9d6f72c82d20d455bfa'), ObjectId('61cbf9cff72c82d20d455bdc'), ObjectId('61cbf9d4f72c82d20d455bee'), ObjectId('61cbf9d6f72c82d20d455bfa')]}}
# Check 변시우0
# Not Correct
#  - Answer : {'NTIS': '서울과학기술대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '변시우', 'KCI': {'inst': '안양대학교', 'A_id': 's50287', 'papers': [ObjectId('61cbf9bcf72c82d20d455bc9')]}}
# Check 변시우1
# Not Correct
#  - Answer : {'NTIS': '경북대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '변시우', 'KCI': {'inst': '안양대학교', 'A_id': 's50287', 'papers': [ObjectId('61cbf9bcf72c82d20d455bc9')]}}
# Check 변시우0
# Not Correct
#  - Answer : {'NTIS': '서울과학기술대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '변시우', 'NTIS': {'inst': '안양대학교 산학협력단', 'A_id': '376152016809', 'papers': [ObjectId('61cbf9bb3b642afa40455c94'), ObjectId('61cbf9bb3b642afa40455c90'), ObjectId('61cbf9b53b642afa40455c56'), ObjectId('61cbf9b53b642afa40455c3b'), ObjectId('61cbf9b53b642afa40455c31'), ObjectId('61cbf9b53b642afa40455c15'), ObjectId('61cbf9af3b642afa40455c07'), ObjectId('61cbf9bb3b642afa40455c78')]}}
# Check 변시우1
# Not Correct
#  - Answer : {'NTIS': '경북대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '변시우', 'NTIS': {'inst': '안양대학교 산학협력단', 'A_id': '376152016809', 'papers': [ObjectId('61cbf9bb3b642afa40455c94'), ObjectId('61cbf9bb3b642afa40455c90'), ObjectId('61cbf9b53b642afa40455c56'), ObjectId('61cbf9b53b642afa40455c3b'), ObjectId('61cbf9b53b642afa40455c31'), ObjectId('61cbf9b53b642afa40455c15'), ObjectId('61cbf9af3b642afa40455c07'), ObjectId('61cbf9bb3b642afa40455c78')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '동덕여자대학교 컴퓨터학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '송석일', 'KCI': {'inst': '한국교통대학교', 'A_id': 's50596', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf5')]}}
# Check 정지나0
# Not Correct
#  - Answer : {'KCI': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정지나', 'KCI': {'inst': '전주대학교', 'A_id': 's51203', 'papers': [ObjectId('61cbf9cbf72c82d20d455bdb')]}}
# Check 정지나1
# Not Correct
#  - Answer : {'KCI': '고려대'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정지나', 'KCI': {'inst': '전주대학교', 'A_id': 's51203', 'papers': [ObjectId('61cbf9cbf72c82d20d455bdb')]}}
# Check 정지나0
# Not Correct
#  - Answer : {'KCI': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정지나', 'SCIENCEON': {'inst': '전주대학교 보건관리학과', 'A_id': 's260493', 'papers': [ObjectId('61cbf9bf597f83aefb455bd2')]}}
# Check 정지나1
# Not Correct
#  - Answer : {'KCI': '고려대'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정지나', 'SCIENCEON': {'inst': '전주대학교 보건관리학과', 'A_id': 's260493', 'papers': [ObjectId('61cbf9bf597f83aefb455bd2')]}}
# Not Correct
#  - Answer : {'KCI': '경기대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이종학', 'KCI': {'inst': '대구가톨릭대학교', 'A_id': 's52143', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc6'), ObjectId('61cbf9bcf72c82d20d455bcd')]}}
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박우전', 'KCI': {'inst': '한남대학교', 'A_id': 's52190', 'papers': [ObjectId('61cbf9d4f72c82d20d455bed')]}}
# Not Correct
#  - Answer : {'KCI': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정순일', 'KCI': {'inst': '명지대학교', 'A_id': 's52245', 'papers': [ObjectId('61cbf9daf72c82d20d455bfb')]}}
# Not Correct
#  - Answer : {'KCI': '동아대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '허선', 'KCI': {'inst': '한림대학교', 'A_id': 's52489', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc3')]}}
# Not Correct
#  - Answer : {'KCI': '국민대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '차상인', 'KCI': {'inst': '위버피플', 'A_id': 's52496', 'papers': [ObjectId('61cbf9daf72c82d20d455bfd')]}}
# Not Correct
#  - Answer : {'KCI': '한남대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황규영', 'KCI': {'inst': '한국과학기술원', 'A_id': 's52623', 'papers': [ObjectId('61cbf9e2f72c82d20d455c0a')]}}
# Not Correct
#  - Answer : {'KCI': '한국보건사회연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '주용진', 'KCI': {'inst': '서울시립대학교', 'A_id': 's52709', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf9')]}}
# Check 이용주0
# Not Correct
#  - Answer : {'SCIENCEON': '서강대학교 컴퓨터학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이용주', 'KCI': {'inst': '경북대학교', 'A_id': 's52981', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf6')]}}
# Check 이용주1
# Not Correct
#  - Answer : {'SCIENCEON': '이화여자대학교 사회과학대학 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이용주', 'KCI': {'inst': '경북대학교', 'A_id': 's52981', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf6')]}}
# Check 이용주0
# Not Correct
#  - Answer : {'SCIENCEON': '서강대학교 컴퓨터학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이용주', 'NTIS': {'inst': '경북대학교 산학협력단', 'A_id': '880154216608', 'papers': [ObjectId('61cbf9b53b642afa40455c1e'), ObjectId('61cbf9af3b642afa40455c0d'), ObjectId('61cbf9af3b642afa40455bff'), ObjectId('61cbf9af3b642afa40455bee'), ObjectId('61cbf9af3b642afa40455be4'), ObjectId('61cbf9af3b642afa40455bd7')]}}
# Check 이용주1
# Not Correct
#  - Answer : {'SCIENCEON': '이화여자대학교 사회과학대학 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이용주', 'NTIS': {'inst': '경북대학교 산학협력단', 'A_id': '880154216608', 'papers': [ObjectId('61cbf9b53b642afa40455c1e'), ObjectId('61cbf9af3b642afa40455c0d'), ObjectId('61cbf9af3b642afa40455bff'), ObjectId('61cbf9af3b642afa40455bee'), ObjectId('61cbf9af3b642afa40455be4'), ObjectId('61cbf9af3b642afa40455bd7')]}}
# Check 차광호0
# Not Correct
#  - Answer : {'KCI': '삼성전자'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '차광호', 'KCI': {'inst': '서울과학기술대학교', 'A_id': 's53118', 'papers': [ObjectId('61cbf9caf72c82d20d455bd8')]}}
# Check 차광호1
# Not Correct
#  - Answer : {'KCI': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '차광호', 'KCI': {'inst': '서울과학기술대학교', 'A_id': 's53118', 'papers': [ObjectId('61cbf9caf72c82d20d455bd8')]}}
# Check 차광호0
# Not Correct
#  - Answer : {'KCI': '삼성전자'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '차광호', 'NTIS': {'inst': '서울과학기술대학교 산학협력단', 'A_id': '612162916325', 'papers': [ObjectId('61cbf9bb3b642afa40455c99'), ObjectId('61cbf9bb3b642afa40455c8f'), ObjectId('61cbf9bb3b642afa40455c75'), ObjectId('61cbf9b53b642afa40455c4f'), ObjectId('61cbf9b53b642afa40455c35'), ObjectId('61cbf9b53b642afa40455c1b'), ObjectId('61cbf9af3b642afa40455c0c'), ObjectId('61cbf9af3b642afa40455bfc'), ObjectId('61cbf9af3b642afa40455bef'), ObjectId('61cbf9af3b642afa40455be2')]}}
# Check 차광호1
# Not Correct
#  - Answer : {'KCI': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '차광호', 'NTIS': {'inst': '서울과학기술대학교 산학협력단', 'A_id': '612162916325', 'papers': [ObjectId('61cbf9bb3b642afa40455c99'), ObjectId('61cbf9bb3b642afa40455c8f'), ObjectId('61cbf9bb3b642afa40455c75'), ObjectId('61cbf9b53b642afa40455c4f'), ObjectId('61cbf9b53b642afa40455c35'), ObjectId('61cbf9b53b642afa40455c1b'), ObjectId('61cbf9af3b642afa40455c0c'), ObjectId('61cbf9af3b642afa40455bfc'), ObjectId('61cbf9af3b642afa40455bef'), ObjectId('61cbf9af3b642afa40455be2')]}}
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '권동섭', 'KCI': {'inst': '명지대학교', 'A_id': 's53218', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd2')]}}
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '권동섭', 'SCIENCEON': {'inst': '명지대학교 컴퓨터공학과', 'A_id': 's263765', 'papers': [ObjectId('61cbf9a7597f83aefb455bb6')]}}
# Check 정성원0
# Not Correct
#  - Answer : {'KCI': '구로구 발달장애인평생교육센터'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정성원', 'KCI': {'inst': '서강대학교', 'A_id': 's53220', 'papers': [ObjectId('61cbf9cff72c82d20d455bdd')]}}
# Check 정성원1
# Not Correct
#  - Answer : {'KCI': '계명대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정성원', 'KCI': {'inst': '서강대학교', 'A_id': 's53220', 'papers': [ObjectId('61cbf9cff72c82d20d455bdd')]}}
# Check 정성원0
# Not Correct
#  - Answer : {'KCI': '구로구 발달장애인평생교육센터'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정성원', 'SCIENCEON': {'inst': '서강대학교 컴퓨터학과', 'A_id': 's267910', 'papers': [ObjectId('61cbf9bf597f83aefb455bd1')]}}
# Check 정성원1
# Not Correct
#  - Answer : {'KCI': '계명대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정성원', 'SCIENCEON': {'inst': '서강대학교 컴퓨터학과', 'A_id': 's267910', 'papers': [ObjectId('61cbf9bf597f83aefb455bd1')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '성균관대학교 정보통신학부'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이승은', 'KCI': {'inst': '순천향대학교', 'A_id': 's53246', 'papers': [ObjectId('61cbf9c0f72c82d20d455bd0')]}}
# Not Correct
#  - Answer : {'NTIS': '충북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김동건', 'KCI': {'inst': '경희대학교', 'A_id': 's53284', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc0')]}}
# Check 김명호0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김명호', 'KCI': {'inst': '한국과학기술원', 'A_id': 's53370', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd5')]}}
# Check 김명호1
# Not Correct
#  - Answer : {'NTIS': '군산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김명호', 'KCI': {'inst': '한국과학기술원', 'A_id': 's53370', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd5')]}}
# Check 김명호0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김명호', 'SCIENCEON': {'inst': 'KIST 전산학과', 'A_id': 's264784', 'papers': [ObjectId('61cbf9ab597f83aefb455bc0')]}}
# Check 김명호1
# Not Correct
#  - Answer : {'NTIS': '군산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김명호', 'SCIENCEON': {'inst': 'KIST 전산학과', 'A_id': 's264784', 'papers': [ObjectId('61cbf9ab597f83aefb455bc0')]}}
# Not Correct
#  - Answer : {'KCI': '경희대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '차순철', 'KCI': {'inst': '재단법인 동국문화재연구원', 'A_id': 's53458', 'papers': [ObjectId('61cbf9d4f72c82d20d455be6')]}}
# Not Correct
#  - Answer : {'NTIS': '배재대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김병규', 'KCI': {'inst': '한국과학기술정보연구원', 'A_id': 's53946', 'papers': [ObjectId('61cbf9bcf72c82d20d455bcc')]}}
# Not Correct
#  - Answer : {'NTIS': '배재대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김병규', 'SCIENCEON': {'inst': '한국과학기술정보연구원 정보서비스센터 국내정보팀', 'A_id': 's264701', 'papers': [ObjectId('61cbf9ab597f83aefb455bbf')]}}
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '백우진', 'KCI': {'inst': '건국대학교', 'A_id': 's54047', 'papers': [ObjectId('61cbf9cff72c82d20d455be0')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '인하대학교 정보통신공학'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '스기모토 시게오', 'KCI': {'inst': 'University of Tsukuba', 'A_id': 's54111', 'papers': [ObjectId('61cbf9def72c82d20d455c05')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '강원대학교 컴퓨터정보통신공학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이성호', 'KCI': {'inst': '수원시정연구원', 'A_id': 's541566', 'papers': [ObjectId('61cbf9daf72c82d20d455bfc')]}}
# Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of Data-Centric Problem Solving Research, KISTI'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '연영란', 'KCI': {'inst': '가톨릭대학교', 'A_id': 's54162', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf8')]}}
# Not Correct
#  - Answer : {'KCI': '서울대학교의생명연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '장정수', 'KCI': {'inst': '고려대학교', 'A_id': 's54339', 'papers': [ObjectId('61cbf9c8f72c82d20d455bd7')]}}
# Not Correct
#  - Answer : {'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '차병헌', 'KCI': {'inst': '을지대학교', 'A_id': 's54353', 'papers': [ObjectId('61cbf9cff72c82d20d455be1')]}}
# Check 이승준0
# Not Correct
#  - Answer : {'SCIENCEON': '성균관대학교 정보관리연구소'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이승준', 'KCI': {'inst': '성균관대학교', 'A_id': 's54401', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc2')]}}
# Check 이승준1
# Not Correct
#  - Answer : {'SCIENCEON': 'Korea Institute of Science and Technology Information, Dept. of Knowledge Resources Knowledge Information Center'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이승준', 'KCI': {'inst': '성균관대학교', 'A_id': 's54401', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc2')]}}
# Check 이승준0
# Not Correct
#  - Answer : {'NTIS': '원광대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '노정순', 'KCI': {'inst': '한남대학교', 'A_id': 's54423', 'papers': [ObjectId('61cbf9cbf72c82d20d455bd9')]}}
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '문동오', 'KCI': {'inst': '대구대학교', 'A_id': 's544422', 'papers': [ObjectId('61cbf9d4f72c82d20d455bea')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '계명대학교 사회과학대학 문헌정보학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '송효숙', 'KCI': {'inst': '대전보건대학교', 'A_id': 's54590', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf3')]}}
# Check 최상기0
# Not Correct
#  - Answer : {'KCI': '한국춤문화자료원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최상기', 'KCI': {'inst': '전북대학교', 'A_id': 's54914', 'papers': [ObjectId('61cbf9def72c82d20d455c07')]}}
# Check 최상기1
# Not Correct
#  - Answer : {'KCI': '경기대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최상기', 'KCI': {'inst': '전북대학교', 'A_id': 's54914', 'papers': [ObjectId('61cbf9def72c82d20d455c07')]}}
# Check 최상기0
# Not Correct
#  - Answer : {'KCI': '한국춤문화자료원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최상기', 'SCIENCEON': {'inst': '전북대학교 문헌정보학과', 'A_id': 's264636', 'papers': [ObjectId('61cbf9ab597f83aefb455bbd')]}}
# Check 최상기1
# Not Correct
#  - Answer : {'KCI': '경기대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최상기', 'SCIENCEON': {'inst': '전북대학교 문헌정보학과', 'A_id': 's264636', 'papers': [ObjectId('61cbf9ab597f83aefb455bbd')]}}
# Not Correct
#  - Answer : {'KCI': '대구대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이재윤', 'KCI': {'inst': '경기대학교', 'A_id': 's55147', 'papers': [ObjectId('61cbf9dbf72c82d20d455bfe')]}}
# Check 양만길0
# Not Correct
#  - Answer : {'SCIENCEON': 'KIST 전산학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '양만길', 'KCI': {'inst': '서울대학교의생명연구원', 'A_id': 's55216', 'papers': [ObjectId('61cbf9cff72c82d20d455bde')]}}
# Check 양만길1
# Not Correct
#  - Answer : {'SCIENCEON': '한국전자부품연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '양만길', 'KCI': {'inst': '서울대학교의생명연구원', 'A_id': 's55216', 'papers': [ObjectId('61cbf9cff72c82d20d455bde')]}}
# Check 양만길0
# Not Correct
#  - Answer : {'SCIENCEON': 'KIST 전산학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '양만길', 'SCIENCEON': {'inst': '서울대학교의생명연구원 연구실험부', 'A_id': 's267795', 'papers': [ObjectId('61cbf9bf597f83aefb455bce')]}}
# Check 양만길1
# Not Correct
#  - Answer : {'SCIENCEON': '한국전자부품연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '양만길', 'SCIENCEON': {'inst': '서울대학교의생명연구원 연구실험부', 'A_id': 's267795', 'papers': [ObjectId('61cbf9bf597f83aefb455bce')]}}
# Check 이종설0
# Not Correct
#  - Answer : {'KCI': '한림대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이종설', 'KCI': {'inst': '전자부품연구원', 'A_id': 's55246', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc7')]}}
# Check 이종설1
# Not Correct
#  - Answer : {'KCI': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이종설', 'KCI': {'inst': '전자부품연구원', 'A_id': 's55246', 'papers': [ObjectId('61cbf9bbf72c82d20d455bc7')]}}
# Check 이종설0
# Not Correct
#  - Answer : {'KCI': '한림대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이종설', 'SCIENCEON': {'inst': '한국전자부품연구원', 'A_id': 's263664', 'papers': [ObjectId('61cbf9a7597f83aefb455bb4')]}}
# Check 이종설1
# Not Correct
#  - Answer : {'KCI': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이종설', 'SCIENCEON': {'inst': '한국전자부품연구원', 'A_id': 's263664', 'papers': [ObjectId('61cbf9a7597f83aefb455bb4')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '한국과학기술정보연구원'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이대욱', 'KCI': {'inst': '연세대학교', 'A_id': 's55666', 'papers': [ObjectId('61cbf9d4f72c82d20d455beb')]}}
# Check 김응모0
# Not Correct
#  - Answer : {'NTIS': '광운대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김응모', 'KCI': {'inst': '성균관대학교', 'A_id': 's55735', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd3')]}}
# Check 김응모1
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김응모', 'KCI': {'inst': '성균관대학교', 'A_id': 's55735', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd3')]}}
# Check 김응모0
# Not Correct
#  - Answer : {'NTIS': '광운대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김응모', 'NTIS': {'inst': '성균관대학교(자연과학캠퍼스)', 'A_id': '425902655179', 'papers': [ObjectId('61cbf9bb3b642afa40455c7e'), ObjectId('61cbf9b53b642afa40455c50'), ObjectId('61cbf9b53b642afa40455c2f'), ObjectId('61cbf9b53b642afa40455c36'), ObjectId('61cbf9b53b642afa40455c17'), ObjectId('61cbf9af3b642afa40455c0a'), ObjectId('61cbf9af3b642afa40455bfe'), ObjectId('61cbf9af3b642afa40455bf1'), ObjectId('61cbf9af3b642afa40455be3'), ObjectId('61cbf9af3b642afa40455bdb')]}}
# Check 김응모1
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김응모', 'NTIS': {'inst': '성균관대학교(자연과학캠퍼스)', 'A_id': '425902655179', 'papers': [ObjectId('61cbf9bb3b642afa40455c7e'), ObjectId('61cbf9b53b642afa40455c50'), ObjectId('61cbf9b53b642afa40455c2f'), ObjectId('61cbf9b53b642afa40455c36'), ObjectId('61cbf9b53b642afa40455c17'), ObjectId('61cbf9af3b642afa40455c0a'), ObjectId('61cbf9af3b642afa40455bfe'), ObjectId('61cbf9af3b642afa40455bf1'), ObjectId('61cbf9af3b642afa40455be3'), ObjectId('61cbf9af3b642afa40455bdb')]}}
# Check 황재정0
# Not Correct
#  - Answer : {'KCI': '이화여자대학교 법학연구소'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황재정', 'KCI': {'inst': '군산대학교', 'A_id': 's55740', 'papers': [ObjectId('61cbf9bbf72c82d20d455bbf')]}}
# Check 황재정1
# Not Correct
#  - Answer : {'KCI': 'University of Tsukuba'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황재정', 'KCI': {'inst': '군산대학교', 'A_id': 's55740', 'papers': [ObjectId('61cbf9bbf72c82d20d455bbf')]}}
# Check 황재정0
# Not Correct
#  - Answer : {'KCI': '이화여자대학교 법학연구소'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황재정', 'SCIENCEON': {'inst': '군산대학교 전파공학과', 'A_id': 's264421', 'papers': [ObjectId('61cbf9ab597f83aefb455bbb')]}}
# Check 황재정1
# Not Correct
#  - Answer : {'KCI': 'University of Tsukuba'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '황재정', 'SCIENCEON': {'inst': '군산대학교 전파공학과', 'A_id': 's264421', 'papers': [ObjectId('61cbf9ab597f83aefb455bbb')]}}
# Not Correct
#  - Answer : {'KCI': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정면숙', 'KCI': {'inst': '경상대학교', 'A_id': 's55765', 'papers': [ObjectId('61cbf9d4f72c82d20d455be9'), ObjectId('61cbf9d6f72c82d20d455bf4')]}}
# Check 박영주0
# Not Correct
#  - Answer : {'NTIS': '한국기술교육대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박영주', 'KCI': {'inst': '세한대학교', 'A_id': 's55990', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf1')]}}
# Check 박영주1
# Not Correct
#  - Answer : {'NTIS': '순천향대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박영주', 'KCI': {'inst': '세한대학교', 'A_id': 's55990', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf1')]}}
# Check 박영주0
# Not Correct
#  - Answer : {'NTIS': '한국기술교육대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박영주', 'SCIENCEON': {'inst': '세한대학교 작업치료학과', 'A_id': 's267425', 'papers': [ObjectId('61cbf9c7597f83aefb455bdb')]}}
# Check 박영주1
# Not Correct
#  - Answer : {'NTIS': '순천향대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박영주', 'SCIENCEON': {'inst': '세한대학교 작업치료학과', 'A_id': 's267425', 'papers': [ObjectId('61cbf9c7597f83aefb455bdb')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '연세대학교 컴퓨터과학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '우해봉', 'KCI': {'inst': '한국보건사회연구원', 'A_id': 's56004', 'papers': [ObjectId('61cbf9dbf72c82d20d455c00')]}}
# Check 박창섭0
# Not Correct
#  - Answer : {'NTIS': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박창섭', 'KCI': {'inst': '동덕여자대학교', 'A_id': 's56040', 'papers': [ObjectId('61cbf9d3f72c82d20d455be3')]}}
# Check 박창섭1
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박창섭', 'KCI': {'inst': '동덕여자대학교', 'A_id': 's56040', 'papers': [ObjectId('61cbf9d3f72c82d20d455be3')]}}
# Check 박창섭0
# Not Correct
#  - Answer : {'NTIS': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박창섭', 'SCIENCEON': {'inst': '동덕여자대학교 컴퓨터학과', 'A_id': 's265225', 'papers': [ObjectId('61cbf9af597f83aefb455bc3')]}}
# Check 박창섭1
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박창섭', 'SCIENCEON': {'inst': '동덕여자대학교 컴퓨터학과', 'A_id': 's265225', 'papers': [ObjectId('61cbf9af597f83aefb455bc3')]}}
# Not Correct
#  - Answer : {'KCI': '건국대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '조성민', 'KCI': {'inst': '호남대학교', 'A_id': 's56231', 'papers': [ObjectId('61cbf9dbf72c82d20d455c02')]}}
# Check 김민정0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김민정', 'KCI': {'inst': '성균관대학교', 'A_id': 's56360', 'papers': [ObjectId('61cbf9d4f72c82d20d455bf0')]}}
# Check 김민정1
# Not Correct
#  - Answer : {'NTIS': '원광대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김민정', 'KCI': {'inst': '성균관대학교', 'A_id': 's56360', 'papers': [ObjectId('61cbf9d4f72c82d20d455bf0')]}}
# Check 김민정0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김민정', 'SCIENCEON': {'inst': '성균관대학교 일반대학원 문헌정보학과', 'A_id': 's265273', 'papers': [ObjectId('61cbf9af597f83aefb455bc4')]}}
# Check 김민정1
# Not Correct
#  - Answer : {'NTIS': '원광대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김민정', 'SCIENCEON': {'inst': '성균관대학교 일반대학원 문헌정보학과', 'A_id': 's265273', 'papers': [ObjectId('61cbf9af597f83aefb455bc4')]}}
# Check 최기복0
# Not Correct
#  - Answer : {'KCI': '전주대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최기복', 'KCI': {'inst': '조선대학교병원', 'A_id': 's56392', 'papers': [ObjectId('61cbf9d4f72c82d20d455bec')]}}
# Check 최기복1
# Not Correct
#  - Answer : {'KCI': '위버피플'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최기복', 'KCI': {'inst': '조선대학교병원', 'A_id': 's56392', 'papers': [ObjectId('61cbf9d4f72c82d20d455bec')]}}
# Check 최기복0
# Not Correct
#  - Answer : {'KCI': '전주대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최기복', 'SCIENCEON': {'inst': '조선대학교병원 재활치료팀', 'A_id': 's156643', 'papers': [ObjectId('61cbf9ca597f83aefb455bdd')]}}
# Check 최기복1
# Not Correct
#  - Answer : {'KCI': '위버피플'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최기복', 'SCIENCEON': {'inst': '조선대학교병원 재활치료팀', 'A_id': 's156643', 'papers': [ObjectId('61cbf9ca597f83aefb455bdd')]}}
# Not Correct
#  - Answer : {'KCI': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정은정', 'KCI': {'inst': '건국대학교', 'A_id': 's56542', 'papers': [ObjectId('61cbf9d4f72c82d20d455be5')]}}
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박미진', 'KCI': {'inst': '구로구 발달장애인평생교육센터', 'A_id': 's56603', 'papers': [ObjectId('61cbf9d4f72c82d20d455be7')]}}
# Not Correct
#  - Answer : {'KCI': '명지대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '이종율', 'KCI': {'inst': '진주보건대학교', 'A_id': 's56774', 'papers': [ObjectId('61cbf9d4f72c82d20d455be8')]}}
# Not Correct
#  - Answer : {'KCI': '한국교통대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '정수현', 'KCI': {'inst': '고려대', 'A_id': 's57372', 'papers': [ObjectId('61cbf9d6f72c82d20d455bf7')]}}
# Not Correct
#  - Answer : {'NTIS': '고려대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '박상태', 'KCI': {'inst': '성균관대학교', 'A_id': 's57379', 'papers': [ObjectId('61cbf9def72c82d20d455c04')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '명지대학교 컴퓨터공학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '양기정', 'KCI': {'inst': '한국고전번역원', 'A_id': 's57657', 'papers': [ObjectId('61cbf9c4f72c82d20d455bd1')]}}
# Not Correct
#  - Answer : {'NTIS': '서울시립대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김강욱', 'KCI': {'inst': '삼성전자', 'A_id': 's58122', 'papers': [ObjectId('61cbf9cff72c82d20d455bdf')]}}
# Not Correct
#  - Answer : {'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '최해리', 'KCI': {'inst': '한국춤문화자료원', 'A_id': 's58149', 'papers': [ObjectId('61cbf9bcf72c82d20d455bc8')]}}
# Check 오동근0
# Not Correct
#  - Answer : {'SCIENCEON': '안양대학교 디지털미디어학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '오동근', 'KCI': {'inst': '계명대학교', 'A_id': 's58372', 'papers': [ObjectId('61cbf9dbf72c82d20d455bff')]}}
# Check 오동근1
# Not Correct
#  - Answer : {'SCIENCEON': '중앙대학교 컴퓨터공학부'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '오동근', 'KCI': {'inst': '계명대학교', 'A_id': 's58372', 'papers': [ObjectId('61cbf9dbf72c82d20d455bff')]}}
# Check 오동근0
# Not Correct
#  - Answer : {'SCIENCEON': '안양대학교 디지털미디어학과'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '오동근', 'SCIENCEON': {'inst': '계명대학교 사회과학대학 문헌정보학과', 'A_id': 's1351879', 'papers': [ObjectId('61cbf9ce597f83aefb455bdf'), ObjectId('61cbf9ce597f83aefb455be0')]}}
# Check 오동근1
# Not Correct
#  - Answer : {'SCIENCEON': '중앙대학교 컴퓨터공학부'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '오동근', 'SCIENCEON': {'inst': '계명대학교 사회과학대학 문헌정보학과', 'A_id': 's1351879', 'papers': [ObjectId('61cbf9ce597f83aefb455bdf'), ObjectId('61cbf9ce597f83aefb455be0')]}}
# Check 김인철0
# Not Correct
#  - Answer : {'NTIS': '대전대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김인철', 'KCI': {'inst': '경기대학교', 'A_id': 's5923', 'papers': [ObjectId('61cbf9dbf72c82d20d455c01')]}}
# Check 김인철1
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김인철', 'KCI': {'inst': '경기대학교', 'A_id': 's5923', 'papers': [ObjectId('61cbf9dbf72c82d20d455c01')]}}
# Check 김인철0
# Not Correct
#  - Answer : {'NTIS': '대전대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김인철', 'SCIENCEON': {'inst': '경기대학교 컴퓨터과학과', 'A_id': 's265385', 'papers': [ObjectId('61cbf9b6597f83aefb455bca'), ObjectId('61cbf9b6597f83aefb455bc7')]}}
# Check 김인철1
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'fid': 0, 'keyId': 632, 'name': '김인철', 'SCIENCEON': {'inst': '경기대학교 컴퓨터과학과', 'A_id': 's265385', 'papers': [ObjectId('61cbf9b6597f83aefb455bca'), ObjectId('61cbf9b6597f83aefb455bc7')]}}
# num코렉트 2
# numEror 249
# 0
