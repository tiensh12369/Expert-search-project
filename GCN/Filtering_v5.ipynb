# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경
# '''

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 641 #keyid

nyear = []
pyear = []

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata

id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if int(key_query['prdEnd'][:4]) in nyear or int(key_query['prdStart'][:4]) in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if int(key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1]: # or (src != "" and src in tgt) :  # 소속 같을때
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1]: # or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가
# Out:
# 128

# %%
import json

answer = None
numCor = 0
numErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
        print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        #if len(answer[name].keys()) > 1 :
        numErr += 1
    return flag

with open('answerset588.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name']
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            if name+str(count) not in answer :
                print(name)
            while name+str(count) in answer :
                # if name+count in answer :
                print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    tempCount = 0
    '''
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            tempCount += 1
            print(key)
            print(answer[key])
    '''     
    print(tempCount)
# Out:
# 314
# Not Correct
#  - Answer : {'NTIS': '충북대학교', 'SCIENCEON': '충북대학교 정보통신공학과'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학부', 'A_id': 's259873', 'papers': [ObjectId('61cd5fd8de84cb5ab77ca6df')]}}
# Not Correct
#  - Answer : {'NTIS': '충북대학교', 'SCIENCEON': '충북대학교 정보통신공학과'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교 정보통신공학과', 'A_id': 's258057', 'papers': [ObjectId('61cd5fd0de84cb5ab77ca6c4')]}}
# Check 이광희0
# Not Correct
#  - Answer : {'NTIS': '단국대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '이광희', 'SCIENCEON': {'inst': '한국연구재단 인재양성실', 'A_id': 's261733', 'papers': [ObjectId('61cd5fd0de84cb5ab77ca6c6')]}}
# Check 이광희1
# Check 복경수0
# Not Correct
#  - Answer : {'NTIS': '충북대학교', 'SCIENCEON': '충북대학교 정보통신공학과'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '복경수', 'SCIENCEON': {'inst': '원광대학교 SW융합학과', 'A_id': 's261881', 'papers': [ObjectId('61cd5fd4de84cb5ab77ca6da')]}}
# Check 복경수1
# Not Correct
#  - Answer : {'SCIENCEON': '한국건설기술연구원 돌발홍수연구센터'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '황석환', 'SCIENCEON': {'inst': '한국건설기술연구원', 'A_id': 's262097', 'papers': [ObjectId('61cd5fd0de84cb5ab77ca6cf')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '한양대학교 의류학과 휴먼테크융합전공'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '이규혜', 'SCIENCEON': {'inst': '한양대학교 의류학과', 'A_id': 's262343', 'papers': [ObjectId('61cd5fd4de84cb5ab77ca6d2')]}}
# Oh, Chang Song
# Jin, Chan-Yong
# Check 김민수0
# Not Correct
#  - Answer : {'NTIS': '부산가톨릭대학교 응용과학연구소'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '김민수', 'NTIS': {'inst': '전남대학교', 'A_id': '459115816127', 'papers': [ObjectId('61cd5fd5f8d08a558d7c941f'), ObjectId('61cd5fd3f8d08a558d7c93fb'), ObjectId('61cd5fd2f8d08a558d7c93dd')]}}
# Check 김민수1
# 여진영
# 김근형
# Not Correct
#  - Answer : {'NTIS': '충북대학교', 'SCIENCEON': '충북대학교 정보통신공학과'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '유재수', 'NTIS': {'inst': '충북대학교', 'A_id': '857111516498', 'papers': [ObjectId('61cd5fd5f8d08a558d7c9434'), ObjectId('61cd5fd5f8d08a558d7c9434')]}}
# PIAO GENSONG
# 남성욱
# 윤선희
# Not Correct
#  - Answer : {'SCIENCEON': '국립산림과학원 산림복지연구과', 'KCI': '국립산림과학원 산림정책연구부 산림복지연구과'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '이정희', 'KCI': {'inst': '국립산림과학원 산림정책연구부 산림복지연구과', 'A_id': 's50161', 'papers': [ObjectId('61cd5fe80f91d3fd2b7c93d2')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '국립산림과학원 산림복지연구과', 'KCI': '국립산림과학원 산림정책연구부 산림복지연구과'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '이정희', 'SCIENCEON': {'inst': '국립산림과학원 산림복지연구과', 'A_id': 's261933', 'papers': [ObjectId('61cd5fd0de84cb5ab77ca6cc')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '덕성여자대학교 경영학과', 'KCI': '덕성여자대학교'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '노태협', 'KCI': {'inst': '덕성여자대학교', 'A_id': 's50766', 'papers': [ObjectId('61cd5fe80f91d3fd2b7c93d1')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '덕성여자대학교 경영학과', 'KCI': '덕성여자대학교'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '노태협', 'SCIENCEON': {'inst': '덕성여자대학교 경영학과', 'A_id': 's262467', 'papers': [ObjectId('61cd5fd4de84cb5ab77ca6d5')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '부경대학교 신문방송학과', 'KCI': '부경대학교'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '남인용', 'KCI': {'inst': '부경대학교', 'A_id': 's56824', 'papers': [ObjectId('61cd5feb0f91d3fd2b7c93d9')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '부경대학교 신문방송학과', 'KCI': '부경대학교'}
#  - Result : {'fid': 0, 'keyId': 641, 'name': '남인용', 'SCIENCEON': {'inst': '부경대학교 신문방송학과', 'A_id': 's1087981', 'papers': [ObjectId('61cd5fd8de84cb5ab77ca6dd')]}}
# num코렉트 109
# numEror 14
# 0
