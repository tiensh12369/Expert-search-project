# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 646 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if key_query['prdEnd'][:4] in nyear or key_query['prdStart'][:4] in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if (key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt) :  # 소속 같을때
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1]  or (src != "" and src in tgt):  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가
# Out:
# 388

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter, numInteErr
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
       
        if len(answer[name].keys()) > 1 :
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        else :
            print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        numErr += 1
    return flag

with open('answer646.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name']
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            # if name+str(count) not in answer :
            #     print(name)
            while name+str(count) in answer :
                # if name+count in answer :
                print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError = 0
    
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            totalError += 1
            if len(answer[key].keys()) > 1 :
                totalInteError += 1
            #print(key)
            #print(answer[key])
        
    print("토탈에러", totalError)
    print("토탈ㅇ인터그레이션에러", totalInteError)
# Out:
# 336
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '충북대학교', 'SCIENCEON': '충북대학교 정보통신공학부'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '유재수', 'SCIENCEON': {'inst': '충북대학교', 'A_id': 's101957', 'papers': [ObjectId('61ce7abede84cb5ab77cb008'), ObjectId('61ce7ab7de84cb5ab77cafce'), ObjectId('61ce7abbde84cb5ab77cafea'), ObjectId('61ce7abbde84cb5ab77cafdc'), ObjectId('61ce7abbde84cb5ab77cafdd'), ObjectId('61ce7abede84cb5ab77caffd'), ObjectId('61ce7abede84cb5ab77caffe'), ObjectId('61ce7abede84cb5ab77cafff'), ObjectId('61ce7abede84cb5ab77caff6'), ObjectId('61ce7ac0de84cb5ab77cb00c'), ObjectId('61ce7abede84cb5ab77cb007'), ObjectId('61ce7abede84cb5ab77cb004'), ObjectId('61ce7abbde84cb5ab77cafec'), ObjectId('61ce7abede84cb5ab77caff5'), ObjectId('61ce7abcde84cb5ab77cafef'), ObjectId('61ce7abbde84cb5ab77cafed'), ObjectId('61ce7ab7de84cb5ab77cafd9'), ObjectId('61ce7ac6de84cb5ab77cb027'), ObjectId('61ce7abbde84cb5ab77cafda'), ObjectId('61ce7ab7de84cb5ab77cafd5'), ObjectId('61ce7abede84cb5ab77caff7')]}, 'NTIS': {'inst': '충북대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg1NzExMTUxNjQ5OA==', 'papers': [ObjectId('61ce7ab6f8d08a558d7cd1ec'), ObjectId('61ce7ab6f8d08a558d7cd1d5'), ObjectId('61ce7ab4f8d08a558d7cd1a5'), ObjectId('61ce7ab2f8d08a558d7cd183'), ObjectId('61ce7ab4f8d08a558d7cd1a9'), ObjectId('61ce7ab4f8d08a558d7cd188'), ObjectId('61ce7ab0f8d08a558d7cd12c'), ObjectId('61ce7aaef8d08a558d7cd0d8'), ObjectId('61ce7aaef8d08a558d7cd09e'), ObjectId('61ce7aacf8d08a558d7cd082'), ObjectId('61ce7ab6f8d08a558d7cd1e0')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '한양대학교 의류학과'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이규혜', 'SCIENCEON': {'inst': '한양대학교 의류학과 휴먼테크융합전공', 'A_id': 's1087974', 'papers': [ObjectId('61ce7ac2de84cb5ab77cb01f'), ObjectId('61ce7ac2de84cb5ab77cb01a')]}}
# Check 정교민0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '정교민', 'SCIENCEON': {'inst': '서울대학교', 'A_id': 's258565', 'papers': [ObjectId('61ce7ab3de84cb5ab77cafae'), ObjectId('61ce7ab3de84cb5ab77cafb0')]}, 'NTIS': {'inst': '서울대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQzMDI0Mjc2NzE3MQ==', 'papers': [ObjectId('61ce7ab6f8d08a558d7cd1ed'), ObjectId('61ce7ab6f8d08a558d7cd1d4'), ObjectId('61ce7ab4f8d08a558d7cd1ae')]}}
# Check 정교민1
# Not Correct
#  - Answer : {'SCIENCEON': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '정교민', 'SCIENCEON': {'inst': '서울대학교', 'A_id': 's258565', 'papers': [ObjectId('61ce7ab3de84cb5ab77cafae'), ObjectId('61ce7ab3de84cb5ab77cafb0')]}, 'NTIS': {'inst': '서울대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQzMDI0Mjc2NzE3MQ==', 'papers': [ObjectId('61ce7ab6f8d08a558d7cd1ed'), ObjectId('61ce7ab6f8d08a558d7cd1d4'), ObjectId('61ce7ab4f8d08a558d7cd1ae')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '숙명여자대학교 컴퓨터과학부'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김윤희', 'SCIENCEON': {'inst': "Dept. of Computer Science, Sookmyung Women's Univ.", 'A_id': 's257954', 'papers': [ObjectId('61ce7aafde84cb5ab77caf97')]}}
# Not Correct
#  - Answer : {'SCIENCEON': 'Department of Computer Science and Engineering, The Catholic University of Korea'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '황병연', 'SCIENCEON': {'inst': '가톨릭대학교 컴퓨터공학과', 'A_id': 's257890', 'papers': [ObjectId('61ce7aafde84cb5ab77caf95')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '숙명여자대학교 컴퓨터과학부'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김윤희', 'SCIENCEON': {'inst': "Department of Computer Science, Sookmyung Women's University", 'A_id': 's259841', 'papers': [ObjectId('61ce7ab7de84cb5ab77cafd2'), ObjectId('61ce7ab7de84cb5ab77cafd2')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '서울시립대학교 전자전기컴퓨터공학부'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김한준', 'SCIENCEON': {'inst': '서울시립대학교 전자전기컴퓨터공학과', 'A_id': 's260138', 'papers': [ObjectId('61ce7abbde84cb5ab77cafde')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '울산과학기술원 융합경영대학원'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '정윤혁', 'SCIENCEON': {'inst': '울산과학기술원(UNIST) 경영학부', 'A_id': 's260578', 'papers': [ObjectId('61ce7abbde84cb5ab77cafe7')]}}
# Not Correct
#  - Answer : {'SCIENCEON': 'Wonkwang University (Institute of Convergence and Creativity)'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '진찬용', 'SCIENCEON': {'inst': '원광대학교(융복합창의연구소)', 'A_id': 's260801', 'papers': [ObjectId('61ce7abcde84cb5ab77caff1'), ObjectId('61ce7abcde84cb5ab77caff4'), ObjectId('61ce7abcde84cb5ab77caff2')]}}
# Not Correct
#  - Answer : {'SCIENCEON': 'Wonkwang University (Institute of Convergence and Creativity)'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '진찬용', 'SCIENCEON': {'inst': 'Wonkwang University', 'A_id': 's143722', 'papers': [ObjectId('61ce7ac0de84cb5ab77cb016'), ObjectId('61ce7abede84cb5ab77cb003'), ObjectId('61ce7abcde84cb5ab77caff0'), ObjectId('61ce7abcde84cb5ab77cafee')]}}
# Not Correct
#  - Answer : {'SCIENCEON': '국민대학교 경영대학/비즈니스 IT 전문대학원'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '박도형', 'SCIENCEON': {'inst': '국민대학교 경영대학/비즈니스IT전문대학원', 'A_id': 's260307', 'papers': [ObjectId('61ce7abbde84cb5ab77cafe4')]}}
# Not Correct
#  - Answer : {'NTIS': '경희대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이승룡', 'NTIS': {'inst': '경희대학교(국제캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxMTAwMzMyNTE1NA==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd1b5'), ObjectId('61ce7ab0f8d08a558d7cd112')]}}
# Not Correct
#  - Answer : {'NTIS': '숭실대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이수원', 'NTIS': {'inst': '숭실대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxNjA2MDY5NTE5NA==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd1be')]}}
# Check 김민수0
# Check 김민수0
# Not Correct
#  - Answer : {'NTIS': '전남대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김민수', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjEyNjEwNzI2NzE1NA==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd1b2'), ObjectId('61ce7ab2f8d08a558d7cd17f'), ObjectId('61ce7ab0f8d08a558d7cd130')]}}
# Check 김민수1
# Not Correct
#  - Answer : {'NTIS': '대구경북과학기술원'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김민수', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjEyNjEwNzI2NzE1NA==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd1b2'), ObjectId('61ce7ab2f8d08a558d7cd17f'), ObjectId('61ce7ab0f8d08a558d7cd130')]}}
# Not Correct
#  - Answer : {'NTIS': '경희대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '홍충선', 'NTIS': {'inst': '경희대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwMDE4NDAzNjM2NQ==', 'papers': [ObjectId('61ce7ab0f8d08a558d7cd13a')]}}
# Not Correct
#  - Answer : {'NTIS': '한양대학교(ERICA캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '한진영', 'NTIS': {'inst': '성균관대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwMjExODYzODIwMw==', 'papers': [ObjectId('61ce7aaef8d08a558d7cd0b5'), ObjectId('61ce7aacf8d08a558d7cd071'), ObjectId('61ce7aaaf8d08a558d7cd049'), ObjectId('61ce7aaef8d08a558d7cd0d7')]}}
# Not Correct
#  - Answer : {'NTIS': '인천대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김관호', 'NTIS': {'inst': '인천대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxMTk0NjI3NzE5NA==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd1bb')]}}
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '주재걸', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxMjQ3NjgyNzE4OQ==', 'papers': [ObjectId('61ce7ab2f8d08a558d7cd150')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '성균관대학교(자연과학캠퍼스)', 'SCIENCEON': '성균관대학교 사회과학대학 소비자가족학과 / 소프트웨어대학'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김응모', 'NTIS': {'inst': '성균관대학교(자연과학캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQyNTkwMjY1NTE3OQ==', 'papers': [ObjectId('61ce7ab6f8d08a558d7cd1e4'), ObjectId('61ce7ab4f8d08a558d7cd19c'), ObjectId('61ce7ab2f8d08a558d7cd172'), ObjectId('61ce7ab2f8d08a558d7cd171'), ObjectId('61ce7ab0f8d08a558d7cd121'), ObjectId('61ce7ab0f8d08a558d7cd0f1')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '성균관대학교(자연과학캠퍼스)', 'SCIENCEON': '성균관대학교 사회과학대학 소비자가족학과 / 소프트웨어대학'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '김응모', 'SCIENCEON': {'inst': '성균관대학교 사회과학대학 소비자가족학과 / 소프트웨어대학', 'A_id': 's262794', 'papers': [ObjectId('61ce7ac6de84cb5ab77cb024')]}}
# Not Correct
#  - Answer : {'NTIS': '단국대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '신원용', 'NTIS': {'inst': '연세대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQyODkwNTY4NzE5Mw==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd19b'), ObjectId('61ce7ab2f8d08a558d7cd176'), ObjectId('61ce7ab0f8d08a558d7cd120'), ObjectId('61ce7ab0f8d08a558d7cd0ee'), ObjectId('61ce7aaef8d08a558d7cd0af'), ObjectId('61ce7aacf8d08a558d7cd075'), ObjectId('61ce7aaaf8d08a558d7cd054'), ObjectId('61ce7ab4f8d08a558d7cd187'), ObjectId('61ce7ab0f8d08a558d7cd132'), ObjectId('61ce7aaaf8d08a558d7cd03a')]}}
# Not Correct
#  - Answer : {'NTIS': '세종대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '유성준', 'NTIS': {'inst': '세종대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUxODkwOTAwNTE5Ng==', 'papers': [ObjectId('61ce7ab6f8d08a558d7cd1c8'), ObjectId('61ce7ab2f8d08a558d7cd161'), ObjectId('61ce7ab2f8d08a558d7cd167')]}}
# Check 강장묵0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '강장묵', 'NTIS': {'inst': '남서울대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjcxMDYxMTMyNzEyMA==', 'papers': [ObjectId('61ce7aaef8d08a558d7cd0c9')]}}
# Check 강장묵1
# Check 강장묵0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '강장묵', 'SCIENCEON': {'inst': '고려대학교 정보대학 컴퓨터학과', 'A_id': 's259112', 'papers': [ObjectId('61ce7ab5de84cb5ab77cafbd')]}, 'NTIS': {'inst': '고려대학교', 'A_id': 's55197', 'papers': [ObjectId('61ce7ab0f8d08a558d7cd119'), ObjectId('61ce7aaef8d08a558d7cd0e0')]}}
# Check 강장묵1
# Not Correct
#  - Answer : {'NTIS': '남서울대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '강장묵', 'SCIENCEON': {'inst': '고려대학교 정보대학 컴퓨터학과', 'A_id': 's259112', 'papers': [ObjectId('61ce7ab5de84cb5ab77cafbd')]}, 'NTIS': {'inst': '고려대학교', 'A_id': 's55197', 'papers': [ObjectId('61ce7ab0f8d08a558d7cd119'), ObjectId('61ce7aaef8d08a558d7cd0e0')]}}
# Check 강장묵2
# Not Correct
#  - Answer : {'SCIENCEON': '고려대학교 정보대학 컴퓨터학과'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '강장묵', 'SCIENCEON': {'inst': '고려대학교 정보대학 컴퓨터학과', 'A_id': 's259112', 'papers': [ObjectId('61ce7ab5de84cb5ab77cafbd')]}, 'NTIS': {'inst': '고려대학교', 'A_id': 's55197', 'papers': [ObjectId('61ce7ab0f8d08a558d7cd119'), ObjectId('61ce7aaef8d08a558d7cd0e0')]}}
# Not Correct
#  - Answer : {'NTIS': '서강대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '양지훈', 'NTIS': {'inst': '서강대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg0NTExMDcxNjI1OQ==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd1bf')]}}
# Not Correct
#  - Answer : {'NTIS': '전남대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '양형정', 'NTIS': {'inst': '전남대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg0OTI1ODUxNjIwNg==', 'papers': [ObjectId('61ce7ab0f8d08a558d7cd107')]}}
# Not Correct
#  - Answer : {'NTIS': '중원대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '최재영', 'NTIS': {'inst': '한국외국어대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxMDE1NzMxODg4MA==', 'papers': [ObjectId('61ce7ab2f8d08a558d7cd174'), ObjectId('61ce7ab0f8d08a558d7cd122'), ObjectId('61ce7ab0f8d08a558d7cd116'), ObjectId('61ce7aaef8d08a558d7cd0ad'), ObjectId('61ce7aacf8d08a558d7cd06d'), ObjectId('61ce7aaaf8d08a558d7cd055'), ObjectId('61ce7aaaf8d08a558d7cd02f')]}}
# Not Correct
#  - Answer : {'NTIS': '한양대학교(ERICA캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이동호', 'NTIS': {'inst': '한양대학교 에리카산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgyMDAwNzkzNzEyNw==', 'papers': [ObjectId('61ce7ab6f8d08a558d7cd1de'), ObjectId('61ce7ab4f8d08a558d7cd1a3'), ObjectId('61ce7ab2f8d08a558d7cd173')]}}
# Not Correct
#  - Answer : {'NTIS': '상지대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '정경용', 'NTIS': {'inst': '경기대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgyNTMwOTQyNzE3Nw==', 'papers': [ObjectId('61ce7ab4f8d08a558d7cd1ba'), ObjectId('61ce7aaaf8d08a558d7cd04e'), ObjectId('61ce7aaaf8d08a558d7cd020')]}}
# Check 이종국0
# Check 이종국0
# Not Correct
#  - Answer : {'NTIS': '계명대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이종국', 'SCIENCEON': {'inst': '국립재난안전연구원 재난정보분석센터', 'A_id': 's258277', 'papers': [ObjectId('61ce7ab3de84cb5ab77cafa7')]}}
# Check 이종국1
# Check 노승민0
# Not Correct
#  - Answer : {'NTIS': '세종대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '노승민', 'KCI': {'inst': '성결대학교', 'A_id': 's15284', 'papers': [ObjectId('61ce7ad90f91d3fd2b7ca6f1')]}}
# Check 노승민1
# Check 노승민0
# Check 이미경0
# Not Correct
#  - Answer : {'NTIS': '계명대학교'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이미경', 'KCI': {'inst': '영남대학교', 'A_id': 's47653', 'papers': [ObjectId('61ce7ac00f91d3fd2b7ca6ca')]}}
# Check 이미경1
# Check 이미경0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '국립산림과학원 산림복지연구과', 'KCI': '국립산림과학원 산림정책연구부 산림복지연구과'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이정희', 'KCI': {'inst': '국립산림과학원 산림정책연구부 산림복지연구과', 'A_id': 's50161', 'papers': [ObjectId('61ce7ad30f91d3fd2b7ca6ea')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '국립산림과학원 산림복지연구과', 'KCI': '국립산림과학원 산림정책연구부 산림복지연구과'}
#  - Result : {'fid': 0, 'keyId': 646, 'name': '이정희', 'SCIENCEON': {'inst': '국립산림과학원 산림복지연구과', 'A_id': 's261933', 'papers': [ObjectId('61ce7ac0de84cb5ab77cb014')]}}
# num코렉트 313
# numEror 38
# numInteEror 5
# 토탈에러 23
# 토탈ㅇ인터그레이션에러 3
