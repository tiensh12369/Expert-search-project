# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 651 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if key_query['prdEnd'][:4] in nyear or key_query['prdStart'][:4] in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if (key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt) :  # 소속 같을때
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1]  or (src != "" and src in tgt):  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가
# Out:
# 2129

# %%
def getRaw(name):
    if 'raws' not in data0[name]:
        raws = []
        for site in sites:
            if site in data0[name]:
                for c in raw_dbs[site].find({"_id": {"$in": data0[name][site]['papers']}}):
                    c['site'] = site
                    raws.append(c)
        
        data0[name]['raws'] = raws

processedList = []
deleteList = []

for data in data0 :
    if '_' in data :
        name = data.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in data0 :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        
        processedList.append(name[0])
        flag = True
        while flag : 
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            result = 6
            
            for pair in pairs:
                pair = list(pair)
                '''
                # <2차통합 유사도 함수 자리>
                # 2차통합유사도함수_상혁(data0[pair[0]]['raws'], data0[pair[1]]['raws'])
                # return 값으로 두 명에 대한 유사도 값이 나옴
                # 6 이상이면 통합 / 임시로 result 변수로 사용
                '''
                
                if result >= 6:
                    deleteList.append(pair[1])
                    for site in sites:
                        if site in data0[pair[1]]:
                            if site in data0[pair[0]].keys() :                            
                                data0[pair[0]][site]['A_id'].extend(data0[pair[1]][site]['A_id'])
                                data0[pair[0]][site]['papers'].extend(data0[pair[1]][site]['papers'])
                                data0[pair[0]]['raws'].extend(data0[pair[1]]['raws'])
                            else:
                                data0[pair[0]][site] = data0[pair[1]][site]
                    flag = True
                    
                    preprocessedList.remove(pair[1])
                    break
        
for d in deleteList:
    del data0[d]
print(data0.keys())

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter, numInteErr
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
       
        if len(answer[name].keys()) > 1 :
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        else :
            print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        numErr += 1
    return flag

with open('answer651.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name']
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            # if name+str(count) not in answer :
            #     print(name)
            while name+str(count) in answer :
                # if name+count in answer :
                print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError = 0
    
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            totalError += 1
            if len(answer[key].keys()) > 1 :
                totalInteError += 1
            #print(key)
            #print(answer[key])
        
    print("토탈에러", totalError)
    print("토탈ㅇ인터그레이션에러", totalInteError)
# Out:
# 2010
# Check 이승은0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of Electronic Engineering, Seoul National University of Science and Technology', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이승은', 'SCIENCEON': {'inst': 'Dept. of Electronic Engineering, Seoul National University of Science and Technology', 'A_id': 's136326', 'papers': [ObjectId('61ce9881de84cb5ab77cb588')]}}
# Check 이승은1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '서울과학기술대학교', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이승은', 'SCIENCEON': {'inst': 'Dept. of Electronic Engineering, Seoul National University of Science and Technology', 'A_id': 's136326', 'papers': [ObjectId('61ce9881de84cb5ab77cb588')]}}
# Check 이승은0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of Electronic Engineering, Seoul National University of Science and Technology', 'KCI': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이승은', 'SCIENCEON': {'inst': '서울과학기술대학교', 'A_id': 's1353917', 'papers': [ObjectId('61ce9887de84cb5ab77cb5c7')]}, 'KCI': {'inst': '서울과학기술대학교', 'A_id': 's7288', 'papers': [ObjectId('61ce98a20f91d3fd2b7cab32')]}}
# Check 이승은1
# Check 김수진0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김수진', 'NTIS': {'inst': '전주대학교', 'A_id': 'MTAxNzE3OTE=', 'papers': [ObjectId('61ce98e0f8d08a558d7cfc25')]}}
# Check 김수진1
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김수진', 'NTIS': {'inst': '전주대학교', 'A_id': 'MTAxNzE3OTE=', 'papers': [ObjectId('61ce98e0f8d08a558d7cfc25')]}}
# Check 김수진2
# Check 김수진0
# Check 정민영0
# Check 정민영0
# Not Correct
#  - Answer : {'NTIS': '고신대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정민영', 'NTIS': {'inst': '서울대학교', 'A_id': 'MTE0Mzg5MzA=', 'papers': [ObjectId('61ce9888f8d08a558d7cf3a4')]}}
# Check 정민영1
# Check 이지현0
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '중앙대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이지현', 'SCIENCEON': {'inst': '전북대학교 소프트웨어공학과', 'A_id': 's1354169', 'papers': [ObjectId('61ce9887de84cb5ab77cb5d3')]}}
# Check 이지현1
# Check 황미경0
# Check 황미경0
# Not Correct
#  - Answer : {'NTIS': '동의대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '황미경', 'SCIENCEON': {'inst': 'Dept. of Digital Media, College of Arts, Kyungsung University', 'A_id': 's1336197', 'papers': [ObjectId('61ce9886de84cb5ab77cb59a')]}}
# Check 황미경1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of Digital Media, College of Arts, Kyungsung University', 'KCI': '경성대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '황미경', 'SCIENCEON': {'inst': 'Dept. of Digital Media, College of Arts, Kyungsung University', 'A_id': 's1336197', 'papers': [ObjectId('61ce9886de84cb5ab77cb59a')]}}
# Check 김혜정0
# Check 김혜정0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김혜정', 'NTIS': {'inst': '경일대학교', 'A_id': 'MTA2NjQ4OTM=', 'papers': [ObjectId('61ce98def8d08a558d7cfbac'), ObjectId('61ce9884f8d08a558d7cf2df')]}}
# Check 김혜정1
# Check 송창근0
# Not Correct
#  - Answer : {'NTIS': '울산과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '송창근', 'NTIS': {'inst': '한림대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjExODEwMDAxNTE4MA==', 'papers': [ObjectId('61ce9894f8d08a558d7cf553')]}}
# Check 송창근1
# Check 송창근0
# Check 김종욱0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김종욱', 'NTIS': {'inst': '동아대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjEyNDg4MjAxNzEwMw==', 'papers': [ObjectId('61ce98def8d08a558d7cfba1'), ObjectId('61ce98e0f8d08a558d7cfbf5'), ObjectId('61ce988ef8d08a558d7cf46e')]}}
# Check 김종욱1
# Check 김종욱0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '고려대학교산학협력단', 'SCIENCEON': '고려대학교 컴퓨터학과'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '임희석', 'NTIS': {'inst': '고려대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjI0OTE3NTg0NjI0Nw==', 'papers': [ObjectId('61ce98ddf8d08a558d7cfb5a'), ObjectId('61ce98daf8d08a558d7cfb23'), ObjectId('61ce98bdf8d08a558d7cf8d2'), ObjectId('61ce98bbf8d08a558d7cf8c4')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '고려대학교산학협력단', 'SCIENCEON': '고려대학교 컴퓨터학과'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '임희석', 'SCIENCEON': {'inst': '고려대학교 컴퓨터학과', 'A_id': 's9279', 'papers': [ObjectId('61ce9887de84cb5ab77cb5d0')]}}
# Check 정성훈0
# Check 정성훈0
# Not Correct
#  - Answer : {'NTIS': '동국대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정성훈', 'NTIS': {'inst': '연세대학교(미래캠퍼스)', 'A_id': 'MTE1NjUwNDE=', 'papers': [ObjectId('61ce98ccf8d08a558d7cf9e8')]}}
# Check 정성훈1
# Check 김영철0
# Check 김영철0
# Not Correct
#  - Answer : {'NTIS': '전남대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영철', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxMjIwMDg3NzE5Mg==', 'papers': [ObjectId('61ce98e5f8d08a558d7cfce0'), ObjectId('61ce98e8f8d08a558d7cfd6b'), ObjectId('61ce9896f8d08a558d7cf577')]}}
# Check 김영철1
# Not Correct
#  - Answer : {'NTIS': '홍익대학교(세종캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영철', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxMjIwMDg3NzE5Mg==', 'papers': [ObjectId('61ce98e5f8d08a558d7cfce0'), ObjectId('61ce98e8f8d08a558d7cfd6b'), ObjectId('61ce9896f8d08a558d7cf577')]}}
# Check 김영철2
# Check 김영민0
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영민', 'NTIS': {'inst': '홍익대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxNDE5ODcyNzEzMA==', 'papers': [ObjectId('61ce98c6f8d08a558d7cf96f'), ObjectId('61ce98d8f8d08a558d7cfb0e'), ObjectId('61ce98c8f8d08a558d7cf98a'), ObjectId('61ce9884f8d08a558d7cf2ed'), ObjectId('61ce988df8d08a558d7cf436')]}}
# Check 김영민1
# Check 김영민0
# Check 김태정0
# Not Correct
#  - Answer : {'NTIS': '인하대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김태정', 'NTIS': {'inst': '가톨릭대학교(성의교정)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyNzgwNTUwNzEyMg==', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc65'), ObjectId('61ce989af8d08a558d7cf5eb')]}}
# Check 김태정1
# Check 김태정0
# Check 김종훈0
# Not Correct
#  - Answer : {'NTIS': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김종훈', 'NTIS': {'inst': '성균관대학교(자연과학캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjMwODEzNjAxODQ0OQ==', 'papers': [ObjectId('61ce98aaf8d08a558d7cf77d')]}}
# Check 김종훈1
# Check 김종훈0
# Not Correct
#  - Answer : {'NTIS': '충남대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김종훈', 'SCIENCEON': {'inst': '제주대학교', 'A_id': 's359039', 'papers': [ObjectId('61ce9887de84cb5ab77cb5bf'), ObjectId('61ce9886de84cb5ab77cb5a8'), ObjectId('61ce9886de84cb5ab77cb5b7')]}, 'KCI': {'inst': '제주대학교', 'A_id': 's81303', 'papers': [ObjectId('61ce98cb0f91d3fd2b7cab7a'), ObjectId('61ce98c10f91d3fd2b7cab66'), ObjectId('61ce98fc0f91d3fd2b7caba6')]}}
# Check 김종훈1
# Not Correct
#  - Answer : {'NTIS': '성균관대학교(자연과학캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김종훈', 'SCIENCEON': {'inst': '제주대학교', 'A_id': 's359039', 'papers': [ObjectId('61ce9887de84cb5ab77cb5bf'), ObjectId('61ce9886de84cb5ab77cb5a8'), ObjectId('61ce9886de84cb5ab77cb5b7')]}, 'KCI': {'inst': '제주대학교', 'A_id': 's81303', 'papers': [ObjectId('61ce98cb0f91d3fd2b7cab7a'), ObjectId('61ce98c10f91d3fd2b7cab66'), ObjectId('61ce98fc0f91d3fd2b7caba6')]}}
# Check 김종훈2
# Check 김영민0
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영민', 'NTIS': {'inst': '한양대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjMxMTI4MTI0NzI1NQ==', 'papers': [ObjectId('61ce98bdf8d08a558d7cf8e5'), ObjectId('61ce98e5f8d08a558d7cfcd4'), ObjectId('61ce9892f8d08a558d7cf4fc'), ObjectId('61ce98bdf8d08a558d7cf8e5'), ObjectId('61ce98e5f8d08a558d7cfcd4'), ObjectId('61ce9892f8d08a558d7cf4fc')]}}
# Check 김영민1
# Not Correct
#  - Answer : {'NTIS': '홍익대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영민', 'NTIS': {'inst': '한양대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjMxMTI4MTI0NzI1NQ==', 'papers': [ObjectId('61ce98bdf8d08a558d7cf8e5'), ObjectId('61ce98e5f8d08a558d7cfcd4'), ObjectId('61ce9892f8d08a558d7cf4fc'), ObjectId('61ce98bdf8d08a558d7cf8e5'), ObjectId('61ce98e5f8d08a558d7cfcd4'), ObjectId('61ce9892f8d08a558d7cf4fc')]}}
# Check 김영민2
# Check 김도완0
# Check 김도완0
# Not Correct
#  - Answer : {'NTIS': '한밭대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김도완', 'NTIS': {'inst': '전남대학교', 'A_id': 'MTE2ODIzMTE=', 'papers': [ObjectId('61ce98aaf8d08a558d7cf773'), ObjectId('61ce988df8d08a558d7cf420')]}}
# Check 김도완1
# Check 이의진0
# Check 이의진0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이의진', 'NTIS': {'inst': '서울과학기술대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjEwMTI0MjcxODA1NA==', 'papers': [ObjectId('61ce98d6f8d08a558d7cfad3'), ObjectId('61ce988df8d08a558d7cf427')]}}
# Check 이의진1
# Check 김종호0
# Check 김종호0
# Not Correct
#  - Answer : {'NTIS': '강원대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김종호', 'NTIS': {'inst': '순천대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjMxODk4OTA0NzE1Ng==', 'papers': [ObjectId('61ce98aaf8d08a558d7cf767')]}}
# Check 김종호1
# Check 이성학0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이성학', 'NTIS': {'inst': '가톨릭대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjMyNzEwMDAwNzE1OA==', 'papers': [ObjectId('61ce98a6f8d08a558d7cf71f')]}}
# Check 이성학1
# Check 이성학0
# Check 박신형0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박신형', 'NTIS': {'inst': '계명대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjMyNzExOTIwNzE2MQ==', 'papers': [ObjectId('61ce98e5f8d08a558d7cfccb')]}}
# Check 박신형1
# Check 박신형0
# Check 박성민0
# Check 박성민0
# Not Correct
#  - Answer : {'NTIS': '이화여자대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박성민', 'NTIS': {'inst': '포항공과대학교', 'A_id': 'MTE1ODk3MTc=', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc75'), ObjectId('61ce988ef8d08a558d7cf445')]}}
# Check 박성민1
# Check 윤명근0
# Check 윤명근0
# Not Correct
#  - Answer : {'NTIS': '고려대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '윤명근', 'NTIS': {'inst': '국민대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyODQwNjEzNzEzNg==', 'papers': [ObjectId('61ce98d0f8d08a558d7cfa13'), ObjectId('61ce98bdf8d08a558d7cf8eb')]}}
# Check 윤명근1
# Check 김성일0
# Not Correct
#  - Answer : {'NTIS': '울산과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김성일', 'NTIS': {'inst': '경남대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQ2OTExNzAxNjU0Mw==', 'papers': [ObjectId('61ce98d6f8d08a558d7cfae7'), ObjectId('61ce988df8d08a558d7cf439')]}}
# Check 김성일1
# Check 김성일0
# Check 이상혁0
# Check 이상혁0
# Not Correct
#  - Answer : {'NTIS': '이화여자대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상혁', 'NTIS': {'inst': '차의과학대학교 분당차병원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyNzkwNTIyNzEwNg==', 'papers': [ObjectId('61ce98e8f8d08a558d7cfd84'), ObjectId('61ce98b4f8d08a558d7cf853')]}}
# Check 이상혁1
# Check 김진호0
# Not Correct
#  - Answer : {'NTIS': '강원대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김진호', 'NTIS': {'inst': '분당서울대학교병원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQ5MDE3MDYxODE0NA==', 'papers': [ObjectId('61ce98ccf8d08a558d7cf9d3')]}}
# Check 김진호1
# Check 김진호0
# Check 최우영0
# Not Correct
#  - Answer : {'NTIS': '서강대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '최우영', 'NTIS': {'inst': '연세대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwMzEyMDAxNjg5Mw==', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc2c'), ObjectId('61ce9890f8d08a558d7cf4cf')]}}
# Check 최우영1
# Check 최우영0
# Check 이상엽0
# Not Correct
#  - Answer : {'NTIS': '한밭대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상엽', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwNDE1MjIxNjQ1NQ==', 'papers': [ObjectId('61ce98a2f8d08a558d7cf6c5')]}}
# Check 이상엽1
# Check 이상엽0
# Check 유재현0
# Not Correct
#  - Answer : {'NTIS': '한경대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '유재현', 'NTIS': {'inst': '가톨릭대학교(성의교정)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwNDE4NjUxODI1NA==', 'papers': [ObjectId('61ce98d4f8d08a558d7cfa8b'), ObjectId('61ce988ef8d08a558d7cf452')]}}
# Check 유재현1
# Check 유재현0
# Check 민창기0
# Not Correct
#  - Answer : {'NTIS': '가톨릭대학교(성의교정)'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '민창기', 'NTIS': {'inst': '중부대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwNTEyNzAxODc5MQ==', 'papers': [ObjectId('61ce98d6f8d08a558d7cfaf2'), ObjectId('61ce9886f8d08a558d7cf325')]}}
# Check 민창기1
# Check 민창기0
# Check 김형진0
# Not Correct
#  - Answer : {'NTIS': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김형진', 'NTIS': {'inst': '고려대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwOTE4NDYxODM3NQ==', 'papers': [ObjectId('61ce98d4f8d08a558d7cfa95')]}}
# Check 김형진1
# Not Correct
#  - Answer : {'NTIS': '서울대학교병원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김형진', 'NTIS': {'inst': '고려대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwOTE4NDYxODM3NQ==', 'papers': [ObjectId('61ce98d4f8d08a558d7cfa95')]}}
# Check 김형진2
# Not Correct
#  - Answer : {'NTIS': '명지대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김형진', 'NTIS': {'inst': '고려대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwOTE4NDYxODM3NQ==', 'papers': [ObjectId('61ce98d4f8d08a558d7cfa95')]}}
# Check 김형진3
# Check 김형진0
# Not Correct
#  - Answer : {'NTIS': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김형진', 'NTIS': {'inst': '명지대학교', 'A_id': 'MTExODA1MDA=', 'papers': [ObjectId('61ce98a0f8d08a558d7cf688')]}}
# Check 김형진1
# Not Correct
#  - Answer : {'NTIS': '서울대학교병원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김형진', 'NTIS': {'inst': '명지대학교', 'A_id': 'MTExODA1MDA=', 'papers': [ObjectId('61ce98a0f8d08a558d7cf688')]}}
# Check 김형진2
# Check 김종훈0
# Check 박준영0
# Check 박준영0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박준영', 'NTIS': {'inst': '한양대학교 에리카산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjE1NDE4NTExODEyNw==', 'papers': [ObjectId('61ce98d8f8d08a558d7cfb0b'), ObjectId('61ce98b7f8d08a558d7cf874')]}}
# Check 박준영1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '동의대학교 e비즈니스학과, 인공지능그랜드ICT연구센터, 부산IT융합부품연구소', 'KCI': '동의대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정석찬', 'NTIS': {'inst': '동의대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxNTEzMTAxNjI3Mg==', 'papers': [ObjectId('61ce98d8f8d08a558d7cfb0c'), ObjectId('61ce9898f8d08a558d7cf584')]}}
# Check 한창수0
# Check 한창수0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '한창수', 'NTIS': {'inst': '한양대학교 에리카 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxMTMwODU2NTE1Mw==', 'papers': [ObjectId('61ce98ddf8d08a558d7cfb56')]}}
# Check 한창수1
# Check 이웅희0
# Check 이웅희0
# Not Correct
#  - Answer : {'NTIS': '고려대학교세종캠퍼스'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이웅희', 'NTIS': {'inst': '한성대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyODE2MDIxODAxMA==', 'papers': [ObjectId('61ce98a0f8d08a558d7cf69b')]}}
# Check 이웅희1
# Check 김범준0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김범준', 'NTIS': {'inst': '서울아산병원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwMDE5NzMzODI2MA==', 'papers': [ObjectId('61ce98d2f8d08a558d7cfa4d')]}}
# Check 김범준1
# Check 김범준0
# Check 김성환0
# Not Correct
#  - Answer : {'NTIS': '한림대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김성환', 'NTIS': {'inst': '중앙대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwMjEyNzMzODI2Mw==', 'papers': [ObjectId('61ce98a0f8d08a558d7cf68b')]}}
# Check 김성환1
# Check 김성환0
# Check 이정우0
# Not Correct
#  - Answer : {'NTIS': '동국대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이정우', 'NTIS': {'inst': '서울대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwNDE2NDUxNjE2Ng==', 'papers': [ObjectId('61ce98b2f8d08a558d7cf844')]}}
# Check 이정우1
# Check 이정우0
# Not Correct
#  - Answer : {'NTIS': '동국대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이정우', 'NTIS': {'inst': '경희대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxNzMxNzI3NzE3OA==', 'papers': [ObjectId('61ce98dbf8d08a558d7cfb41'), ObjectId('61ce98b5f8d08a558d7cf867')]}}
# Check 이정우1
# Not Correct
#  - Answer : {'NTIS': '서울대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이정우', 'NTIS': {'inst': '경희대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxNzMxNzI3NzE3OA==', 'papers': [ObjectId('61ce98dbf8d08a558d7cfb41'), ObjectId('61ce98b5f8d08a558d7cf867')]}}
# Check 이정우2
# Check 최상현0
# Not Correct
#  - Answer : {'NTIS': '울산대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '최상현', 'NTIS': {'inst': '한국교통대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwNzE1MDUxNjIxMw==', 'papers': [ObjectId('61ce98bdf8d08a558d7cf8e1')]}}
# Check 최상현1
# Check 최상현0
# Check 김경아0
# Not Correct
#  - Answer : {'NTIS': '충북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김경아', 'NTIS': {'inst': '성균관대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwOTIxMjMxNjA1MA==', 'papers': [ObjectId('61ce98eaf8d08a558d7cfd97'), ObjectId('61ce98b4f8d08a558d7cf864')]}}
# Check 김경아1
# Check 김경아0
# Check 김철홍0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김철홍', 'NTIS': {'inst': '숭실대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUxMDE1NzE2NzE1Mg==', 'papers': [ObjectId('61ce988af8d08a558d7cf3bd')]}}
# Check 김철홍1
# Check 김철홍0
# Check 노승민0
# Check 노승민0
# Not Correct
#  - Answer : {'NTIS': '세종대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '노승민', 'SCIENCEON': {'inst': 'Department of Industrial Security, Chung-Ang University', 'A_id': 's1353459', 'papers': [ObjectId('61ce9886de84cb5ab77cb59e')]}}
# Check 노승민1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Industrial Security, Chung-Ang University', 'KCI': '중앙대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '노승민', 'SCIENCEON': {'inst': 'Department of Industrial Security, Chung-Ang University', 'A_id': 's1353459', 'papers': [ObjectId('61ce9886de84cb5ab77cb59e')]}}
# Check 이상원0
# Not Correct
#  - Answer : {'NTIS': '성균관대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상원', 'NTIS': {'inst': '연세대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUxMzYwMTA0NzE2Nw==', 'papers': [ObjectId('61ce98dbf8d08a558d7cfb39'), ObjectId('61ce9886f8d08a558d7cf339')]}}
# Check 이상원1
# Not Correct
#  - Answer : {'NTIS': '성균관대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상원', 'NTIS': {'inst': '연세대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUxMzYwMTA0NzE2Nw==', 'papers': [ObjectId('61ce98dbf8d08a558d7cfb39'), ObjectId('61ce9886f8d08a558d7cf339')]}}
# Check 이상원2
# Check 이상원0
# Check 박현태0
# Check 박현태0
# Not Correct
#  - Answer : {'NTIS': '동아대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박현태', 'NTIS': {'inst': '고려대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxMTEwMTI0NzE0NQ==', 'papers': [ObjectId('61ce98a0f8d08a558d7cf675')]}}
# Check 박현태1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한국과학기술원', 'SCIENCEON': '한국해양과학기술원 해양방위안전연구센터', 'KCI': '한국해양과학기술원 해양방위연구센터'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '조성호', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUxNzEwNzI1NzE0MQ==', 'papers': [ObjectId('61ce98c6f8d08a558d7cf971'), ObjectId('61ce989af8d08a558d7cf60c')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한국과학기술원', 'SCIENCEON': '한국해양과학기술원 해양방위안전연구센터', 'KCI': '한국해양과학기술원 해양방위연구센터'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '조성호', 'SCIENCEON': {'inst': '한국해양과학기술원 해양방위안전연구센터', 'A_id': 's1353058', 'papers': [ObjectId('61ce9881de84cb5ab77cb573')]}}
# Check 신동준0
# Not Correct
#  - Answer : {'NTIS': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '신동준', 'NTIS': {'inst': '중앙대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUxOTEwNzA0NzE2Nw==', 'papers': [ObjectId('61ce988af8d08a558d7cf3d3')]}}
# Check 신동준1
# Check 신동준0
# Check 김상희0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김상희', 'NTIS': {'inst': '경북대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUzMTIzNjQxODExMQ==', 'papers': [ObjectId('61ce98a0f8d08a558d7cf69c')]}}
# Check 김상희1
# Check 김상희0
# Check 이동환0
# Check 이동환0
# Not Correct
#  - Answer : {'NTIS': '성균관대학교(자연과학캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이동환', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwMDE1MjExODEzMg==', 'papers': [ObjectId('61ce98b0f8d08a558d7cf7fe')]}}
# Check 이동환1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한국해양대학교 산학협력단', 'SCIENCEON': '한국해양대학교 항해학부'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '문성배', 'NTIS': {'inst': '한국해양대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjY0ODE0ODgyNjU5Ng==', 'papers': [ObjectId('61ce98d8f8d08a558d7cfb1d')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한국해양대학교 산학협력단', 'SCIENCEON': '한국해양대학교 항해학부'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '문성배', 'SCIENCEON': {'inst': '한국해양대학교 항해학부', 'A_id': 's305538', 'papers': [ObjectId('61ce9881de84cb5ab77cb593')]}}
# Check 김병수0
# Check 김병수0
# Not Correct
#  - Answer : {'NTIS': '명지대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김병수', 'NTIS': {'inst': '경북대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjE4NTEzMjExNjExNA==', 'papers': [ObjectId('61ce988af8d08a558d7cf3cc')]}}
# Check 김병수1
# Check 김경환0
# Not Correct
#  - Answer : {'NTIS': '서울대학교병원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김경환', 'NTIS': {'inst': '건국대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjY2NzExNzEzNjUzOA==', 'papers': [ObjectId('61ce98aef8d08a558d7cf7ce')]}}
# Check 김경환1
# Check 김경환0
# Not Correct
#  - Answer : {'NTIS': '서울대학교병원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김경환', 'NTIS': {'inst': '연세대학교(미래캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyNDAwMDYzNzEzNw==', 'papers': [ObjectId('61ce98e8f8d08a558d7cfd51'), ObjectId('61ce9892f8d08a558d7cf53f')]}}
# Check 김경환1
# Not Correct
#  - Answer : {'NTIS': '건국대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김경환', 'NTIS': {'inst': '연세대학교(미래캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIyNDAwMDYzNzEzNw==', 'papers': [ObjectId('61ce98e8f8d08a558d7cfd51'), ObjectId('61ce9892f8d08a558d7cf53f')]}}
# Check 김경환2
# Check 박준홍0
# Not Correct
#  - Answer : {'NTIS': '전북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박준홍', 'NTIS': {'inst': '한양대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjY2OTE1NDIxNjU2MA==', 'papers': [ObjectId('61ce98d0f8d08a558d7cfa15')]}}
# Check 박준홍1
# Check 박준홍0
# Check 김현0
# Not Correct
#  - Answer : {'NTIS': '서울과학기술대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김현', 'NTIS': {'inst': '국립한국교통대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjY2OTE3NjMyNjg4NA==', 'papers': [ObjectId('61ce98c2f8d08a558d7cf93f')]}}
# Check 김현1
# Check 김현0
# Check 이재욱0
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이재욱', 'NTIS': {'inst': '세종대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjY2OTExNzUzNjkwNQ==', 'papers': [ObjectId('61ce98def8d08a558d7cfb8b')]}}
# Check 이재욱1
# Check 이재욱0
# Check 김수진0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김수진', 'NTIS': {'inst': '서울대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYwMDI5NzQyODY1NA==', 'papers': [ObjectId('61ce98def8d08a558d7cfb90'), ObjectId('61ce989af8d08a558d7cf5df'), ObjectId('61ce98def8d08a558d7cfb90'), ObjectId('61ce989af8d08a558d7cf5df')]}}
# Check 김수진1
# Check 이상민0
# Check 이상민0
# Not Correct
#  - Answer : {'NTIS': '광운대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상민', 'NTIS': {'inst': '서울아산병원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxMDUwOTQwNzE1MQ==', 'papers': [ObjectId('61ce98c0f8d08a558d7cf900')]}}
# Check 이상민1
# Check 김현준0
# Check 김현준0
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김현준', 'NTIS': {'inst': '아주대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwOTExMDAxNjE5MQ==', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc7a')]}}
# Check 김현준1
# Check 김영진0
# Check 김영진0
# Not Correct
#  - Answer : {'NTIS': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영진', 'NTIS': {'inst': '인천대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQ0NTE0NDcxODE2Nw==', 'papers': [ObjectId('61ce98e6f8d08a558d7cfd0a'), ObjectId('61ce989af8d08a558d7cf5d1')]}}
# Check 김영진1
# Check 김태영0
# Check 김태영0
# Not Correct
#  - Answer : {'NTIS': '서경대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김태영', 'NTIS': {'inst': '서울과학기술대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYwMjE5NDcxODI3MA==', 'papers': [ObjectId('61ce98e4f8d08a558d7cfcb0'), ObjectId('61ce989ef8d08a558d7cf64f')]}}
# Check 김태영1
# Check 김민정0
# Not Correct
#  - Answer : {'NTIS': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김민정', 'NTIS': {'inst': '서울대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYxMzI5ODcyODEzNw==', 'papers': [ObjectId('61ce98dcf8d08a558d7cfb53')]}}
# Check 김민정1
# Check 김민정0
# Check 김형진0
# Check 김준수0
# Check 김준수0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김준수', 'NTIS': {'inst': '한국산업기술대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjExNjQ0MTA3NzE3Ng==', 'papers': [ObjectId('61ce9888f8d08a558d7cf35a')]}}
# Check 김준수1
# Check 김현진0
# Not Correct
#  - Answer : {'NTIS': '단국대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김현진', 'NTIS': {'inst': '서울대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYyODE2MzExNjMxNw==', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc85'), ObjectId('61ce98a4f8d08a558d7cf6ee')]}}
# Check 김현진1
# Check 김현진0
# Check 이승훈0
# Not Correct
#  - Answer : {'NTIS': '경희학원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이승훈', 'NTIS': {'inst': '서강대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjcxMDIwMzk5NTE2OA==', 'papers': [ObjectId('61ce98ddf8d08a558d7cfb5c'), ObjectId('61ce98bbf8d08a558d7cf8c3')]}}
# Check 이승훈1
# Check 이승훈0
# Not Correct
#  - Answer : {'NTIS': '건국대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김남수', 'NTIS': {'inst': '서울대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUwNTE2NDgxNjA2NA==', 'papers': [ObjectId('61ce9886f8d08a558d7cf313'), ObjectId('61ce98daf8d08a558d7cfb24')]}}
# Check 이상헌0
# Check 이상헌0
# Not Correct
#  - Answer : {'NTIS': '국민대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상헌', 'NTIS': {'inst': '부산대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjUxMDY4NTIzNzExNA==', 'papers': [ObjectId('61ce98a0f8d08a558d7cf6a3')]}}
# Check 이상헌1
# Not Correct
#  - Answer : {'KCI': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김재일', 'NTIS': {'inst': '경북대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg1MTE4NDUxODc3Ng==', 'papers': [ObjectId('61ce98caf8d08a558d7cf9ab'), ObjectId('61ce98b7f8d08a558d7cf876')]}, 'KCI': {'inst': '경북대학교', 'A_id': 's17748', 'papers': [ObjectId('61ce98a10f91d3fd2b7cab2c')]}}
# Not Correct
#  - Answer : {'KCI': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김재일', 'SCIENCEON': {'inst': 'School of Computer Science and Engineering, Kyungpook National University', 'A_id': 's1353563', 'papers': [ObjectId('61ce9886de84cb5ab77cb5aa')]}}
# Check 박준석0
# Not Correct
#  - Answer : {'NTIS': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박준석', 'NTIS': {'inst': '한국과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg1MTExNjkxODk4Mg==', 'papers': [ObjectId('61ce9888f8d08a558d7cf390')]}}
# Check 박준석1
# Check 박준석0
# Check 이해정0
# Check 이해정0
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이해정', 'NTIS': {'inst': '가천대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxNTkwMzQ5NzIwNw==', 'papers': [ObjectId('61ce9896f8d08a558d7cf57e')]}}
# Check 이해정1
# Check 이종민0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교 정보통신연구소'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이종민', 'NTIS': {'inst': '한양대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg2OTExODgyNjEzMA==', 'papers': [ObjectId('61ce98d2f8d08a558d7cfa34'), ObjectId('61ce98a2f8d08a558d7cf6d6')]}}
# Check 이종민1
# Check 이종민0
# Check 김재곤0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국항공대학교 항공전자정보공학부', 'NTIS': '한국항공대학교산학협력단', 'KCI': '한국항공대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김재곤', 'NTIS': {'inst': '한국항공대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg3NzE0ODYxNjc4MA==', 'papers': [ObjectId('61ce98b9f8d08a558d7cf87f'), ObjectId('61ce98d8f8d08a558d7cfb01'), ObjectId('61ce9886f8d08a558d7cf31d')]}}
# Check 김재곤1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국항공대학교', 'NTIS': '한국항공대학교산학협력단', 'KCI': '한국항공대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김재곤', 'NTIS': {'inst': '한국항공대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjg3NzE0ODYxNjc4MA==', 'papers': [ObjectId('61ce98b9f8d08a558d7cf87f'), ObjectId('61ce98d8f8d08a558d7cfb01'), ObjectId('61ce9886f8d08a558d7cf31d')]}}
# Check 김재곤0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국항공대학교 항공전자정보공학부', 'NTIS': '한국항공대학교산학협력단', 'KCI': '한국항공대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김재곤', 'SCIENCEON': {'inst': '한국항공대학교 항공전자정보공학부', 'A_id': 's169751', 'papers': [ObjectId('61ce9881de84cb5ab77cb576'), ObjectId('61ce9881de84cb5ab77cb596')]}, 'KCI': {'inst': '한국항공대학교', 'A_id': 's28693', 'papers': [ObjectId('61ce98f50f91d3fd2b7cab9c')]}}
# Check 김재곤1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국항공대학교', 'NTIS': '한국항공대학교산학협력단', 'KCI': '한국항공대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김재곤', 'SCIENCEON': {'inst': '한국항공대학교 항공전자정보공학부', 'A_id': 's169751', 'papers': [ObjectId('61ce9881de84cb5ab77cb576'), ObjectId('61ce9881de84cb5ab77cb596')]}, 'KCI': {'inst': '한국항공대학교', 'A_id': 's28693', 'papers': [ObjectId('61ce98f50f91d3fd2b7cab9c')]}}
# Check 박성현0
# Check 박성현0
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박성현', 'NTIS': {'inst': '국민대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjU2NjE4NDIxODExNA==', 'papers': [ObjectId('61ce98b9f8d08a558d7cf8b7')]}}
# Check 박성현1
# Check 김동구0
# Check 김성신0
# Not Correct
#  - Answer : {'NTIS': '한양대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김성신', 'NTIS': {'inst': '부산대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwMDEyMDgxNjgwMg==', 'papers': [ObjectId('61ce98d2f8d08a558d7cfa6a'), ObjectId('61ce988af8d08a558d7cf3bf')]}}
# Check 김성신1
# Check 김성신0
# Check 김은영0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김은영', 'NTIS': {'inst': '가천대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwMDIxMTkxODI5Ng==', 'papers': [ObjectId('61ce98eaf8d08a558d7cfd98'), ObjectId('61ce98b7f8d08a558d7cf86c'), ObjectId('61ce98e4f8d08a558d7cfcaf'), ObjectId('61ce989ef8d08a558d7cf638')]}}
# Check 김은영1
# Check 김은영0
# Check 이은지0
# Not Correct
#  - Answer : {'NTIS': '순천향대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이은지', 'NTIS': {'inst': '숭실대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwMTI0NDkxODc3MQ==', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc3a'), ObjectId('61ce9894f8d08a558d7cf561')]}}
# Check 이은지1
# Check 이은지0
# Check 김성민0
# Check 김성민0
# Not Correct
#  - Answer : {'NTIS': '동국대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김성민', 'NTIS': {'inst': '한양대학교', 'A_id': 'MTAxMjM2Mzk=', 'papers': [ObjectId('61ce9886f8d08a558d7cf329')]}}
# Check 김성민1
# Check 이강윤0
# Check 이강윤0
# Not Correct
#  - Answer : {'NTIS': '가천대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이강윤', 'NTIS': {'inst': '성균관대학교(자연과학캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxNDY1NjUzNzEyMQ==', 'papers': [ObjectId('61ce98dbf8d08a558d7cfb2e')]}}
# Check 이강윤1
# Check 정영수0
# Check 정영수0
# Not Correct
#  - Answer : {'NTIS': '명지대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정영수', 'NTIS': {'inst': '숙명여자대학교산학협력단', 'A_id': 'MTE2Njg4MjY=', 'papers': [ObjectId('61ce98b9f8d08a558d7cf8bb')]}}
# Check 정영수1
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김주영', 'NTIS': {'inst': '우석대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwMjEzMzgxODk3NQ==', 'papers': [ObjectId('61ce98aaf8d08a558d7cf770')]}}
# Check 김형진0
# Not Correct
#  - Answer : {'NTIS': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김형진', 'NTIS': {'inst': '서울대학교병원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwNDE0MjkxODkzNQ==', 'papers': [ObjectId('61ce98e6f8d08a558d7cfd19'), ObjectId('61ce98e6f8d08a558d7cfd19')]}}
# Check 김형진1
# Not Correct
#  - Answer : {'NTIS': '한양대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김미정', 'NTIS': {'inst': '고려대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwNDIxNDIxNjMxNg==', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc89'), ObjectId('61ce9898f8d08a558d7cf5cb')]}}
# Check 이희석0
# Check 이희석0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이희석', 'NTIS': {'inst': '중앙대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQwMTE4NTUxODU2NQ==', 'papers': [ObjectId('61ce9896f8d08a558d7cf57f')]}}
# Check 이희석1
# Check 김경환0
# Check 김대진0
# Check 김대진0
# Not Correct
#  - Answer : {'NTIS': '가톨릭대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김대진', 'NTIS': {'inst': '포항공과대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjEzODUwMzI5NTE3Mg==', 'papers': [ObjectId('61ce98ecf8d08a558d7cfdb1')]}}
# Check 김대진1
# Check 이주현0
# Not Correct
#  - Answer : {'NTIS': '울산과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이주현', 'NTIS': {'inst': '한양대학교(ERICA캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwNzEwODIyODEwNQ==', 'papers': [ObjectId('61ce98e0f8d08a558d7cfbf3'), ObjectId('61ce98a2f8d08a558d7cf6d4'), ObjectId('61ce988af8d08a558d7cf3d7')]}}
# Check 이주현1
# Check 이주현0
# Check 문현준0
# Not Correct
#  - Answer : {'NTIS': '세종대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '문현준', 'NTIS': {'inst': '단국대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwODE1NTgxNjg3NA==', 'papers': [ObjectId('61ce9896f8d08a558d7cf580'), ObjectId('61ce9888f8d08a558d7cf357')]}}
# Check 문현준1
# Check 문현준0
# Check 김재현0
# Check 김재현0
# Not Correct
#  - Answer : {'NTIS': '아주대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김재현', 'NTIS': {'inst': '홍익대학교(세종캠퍼스)', 'A_id': 'MTE2NjIyMjE=', 'papers': [ObjectId('61ce98e2f8d08a558d7cfc2f'), ObjectId('61ce989af8d08a558d7cf60b')]}}
# Check 김재현1
# Check 최재영0
# Not Correct
#  - Answer : {'NTIS': '가천대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '최재영', 'NTIS': {'inst': '한국외국어대학교(글로벌캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxMDE1NzMxODg4MA==', 'papers': [ObjectId('61ce98b2f8d08a558d7cf846'), ObjectId('61ce98a2f8d08a558d7cf6aa')]}}
# Check 최재영1
# Check 최재영0
# Check 김동근0
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김동근', 'NTIS': {'inst': '상명대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxMDE1OTY1NzE1MQ==', 'papers': [ObjectId('61ce98acf8d08a558d7cf78e')]}}
# Check 김동근1
# Check 김동근0
# Check 김태환0
# Check 김태환0
# Not Correct
#  - Answer : {'NTIS': '한국항공대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김태환', 'NTIS': {'inst': '한양대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQxNTI3MjY3NTE3OQ==', 'papers': [ObjectId('61ce98e4f8d08a558d7cfcad'), ObjectId('61ce98a4f8d08a558d7cf6f6')]}}
# Check 김태환1
# Check 김영철0
# Not Correct
#  - Answer : {'NTIS': '전남대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영철', 'NTIS': {'inst': '홍익대학교(세종캠퍼스)', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxMTU1MDU3NjkwMQ==', 'papers': [ObjectId('61ce98aaf8d08a558d7cf761'), ObjectId('61ce98aaf8d08a558d7cf761')]}}
# Check 김영철1
# Check 이상현0
# Check 이상현0
# Not Correct
#  - Answer : {'NTIS': '고려대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상현', 'NTIS': {'inst': '단국대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjcxMDM1Mjk1NzEyNA==', 'papers': [ObjectId('61ce98acf8d08a558d7cf7a7')]}}
# Check 이상현1
# Check 이정우0
# Check 김성준0
# Not Correct
#  - Answer : {'NTIS': '동국대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김성준', 'NTIS': {'inst': '연세대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxMjQwODgzNzEwMA==', 'papers': [ObjectId('61ce98aaf8d08a558d7cf752'), ObjectId('61ce98c1f8d08a558d7cf936')]}}
# Check 김성준1
# Check 김성준0
# Check 이상철0
# Not Correct
#  - Answer : {'NTIS': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상철', 'NTIS': {'inst': '분당서울대학교병원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxMzMzMDU1NzE3OQ==', 'papers': [ObjectId('61ce98c1f8d08a558d7cf90f')]}}
# Check 이상철1
# Check 이상철0
# Check 김태완0
# Check 김태완0
# Not Correct
#  - Answer : {'NTIS': '인천대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김태완', 'NTIS': {'inst': '서울대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYwMjExMTkxNjE5MQ==', 'papers': [ObjectId('61ce98def8d08a558d7cfb81'), ObjectId('61ce9898f8d08a558d7cf5b0'), ObjectId('61ce98d8f8d08a558d7cfb1e'), ObjectId('61ce989cf8d08a558d7cf62d'), ObjectId('61ce98c8f8d08a558d7cf983'), ObjectId('61ce9898f8d08a558d7cf5ad')]}}
# Check 김태완1
# Check 이성주0
# Check 이성주0
# Not Correct
#  - Answer : {'NTIS': '세종대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이성주', 'NTIS': {'inst': '성균관대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYwNzE0MTMxNjQyMA==', 'papers': [ObjectId('61ce98c8f8d08a558d7cf98c'), ObjectId('61ce9892f8d08a558d7cf52b')]}}
# Check 이성주1
# Check 김태훈0
# Not Correct
#  - Answer : {'NTIS': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김태훈', 'NTIS': {'inst': '고려대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxNTk0MDI5NzE0Mw==', 'papers': [ObjectId('61ce98e0f8d08a558d7cfbf4'), ObjectId('61ce9886f8d08a558d7cf34e')]}}
# Check 김태훈1
# Check 김태훈0
# Check 김대원0
# Not Correct
#  - Answer : {'NTIS': '가톨릭대학교(성의교정)'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김대원', 'NTIS': {'inst': '중앙대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxNjE4ODE5NzE1OA==', 'papers': [ObjectId('61ce98def8d08a558d7cfb93')]}}
# Check 김대원1
# Check 김대원0
# Check 한정희0
# Check 한정희0
# Not Correct
#  - Answer : {'NTIS': '한국항공대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '한정희', 'NTIS': {'inst': '홍익대학교 세종캠퍼스 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQ0MzE3NjExNjk3Mg==', 'papers': [ObjectId('61ce98bdf8d08a558d7cf8e8')]}}
# Check 한정희1
# Check 이수현0
# Check 이수현0
# Not Correct
#  - Answer : {'NTIS': '건양대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이수현', 'NTIS': {'inst': '창원대학교산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQ2MzEyNzUxNjgwNg==', 'papers': [ObjectId('61ce98caf8d08a558d7cf9ac'), ObjectId('61ce98b4f8d08a558d7cf85f')]}}
# Check 이수현1
# Check 김진태0
# Check 김진태0
# Not Correct
#  - Answer : {'NTIS': '건국대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김진태', 'NTIS': {'inst': '한국교통대학교 산학협력단', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIwOTExNjcxNjE4Nw==', 'papers': [ObjectId('61ce98d8f8d08a558d7cfb0d'), ObjectId('61ce9898f8d08a558d7cf585')]}}
# Check 김진태1
# Check 김경원0
# Check 김경원0
# Not Correct
#  - Answer : {'NTIS': '울산대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김경원', 'NTIS': {'inst': '서울아산병원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxMTcxMjE2NzE4Ng==', 'papers': [ObjectId('61ce98ddf8d08a558d7cfb71'), ObjectId('61ce98e2f8d08a558d7cfc4a')]}}
# Check 김경원1
# Check 이인호0
# Not Correct
#  - Answer : {'NTIS': '부산대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이인호', 'NTIS': {'inst': '한경대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxODkxNTk1NzE3MA==', 'papers': [ObjectId('61ce98def8d08a558d7cfb9d'), ObjectId('61ce9894f8d08a558d7cf560')]}}
# Check 이인호1
# Check 이인호0
# Check 임성훈0
# Check 임성훈0
# Not Correct
#  - Answer : {'NTIS': '한림대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '임성훈', 'NTIS': {'inst': '울산과학기술원', 'A_id': 'MTAxNzMyOTk=', 'papers': [ObjectId('61ce98aef8d08a558d7cf7ef')]}}
# Check 임성훈1
# Check 강현욱0
# Check 강현욱0
# Not Correct
#  - Answer : {'NTIS': '부경대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '강현욱', 'NTIS': {'inst': '전남대학교 산학협력단', 'A_id': 'MTA2NTA2Nzg=', 'papers': [ObjectId('61ce98c3f8d08a558d7cf945'), ObjectId('61ce989ef8d08a558d7cf63b')]}}
# Check 강현욱1
# Check 이종욱0
# Check 이종욱0
# Not Correct
#  - Answer : {'NTIS': '고려대학교세종캠퍼스'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이종욱', 'NTIS': {'inst': '성균관대학교 산학협력단', 'A_id': 'MTAxOTgyNjE=', 'papers': [ObjectId('61ce98a4f8d08a558d7cf701')]}}
# Check 이종욱1
# Check 박태준0
# Not Correct
#  - Answer : {'NTIS': '한양대학교 에리카 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박태준', 'NTIS': {'inst': '숭실대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgyNDUwMTk0NzExNg==', 'papers': [ObjectId('61ce98ddf8d08a558d7cfb79')]}}
# Check 박태준1
# Check 박태준0
# Check 김지환0
# Not Correct
#  - Answer : {'NTIS': '가천대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김지환', 'NTIS': {'inst': '연세대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgyNzY3Nzk5NzExOA==', 'papers': [ObjectId('61ce98acf8d08a558d7cf7a5')]}}
# Check 김지환1
# Check 김지환0
# Check 이상준0
# Check 이상준0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이상준', 'NTIS': {'inst': '숭실대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjExMjI5MjIwNzEzMA==', 'papers': [ObjectId('61ce98acf8d08a558d7cf7bf')]}}
# Check 이상준1
# Check 김준하0
# Check 김준하0
# Not Correct
#  - Answer : {'NTIS': '경희대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김준하', 'NTIS': {'inst': '광주과학기술원', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgxNjIwNjUzNzExOQ==', 'papers': [ObjectId('61ce98e8f8d08a558d7cfd66'), ObjectId('61ce9890f8d08a558d7cf4b2')]}}
# Check 김준하1
# Check 장진수0
# Check 장진수0
# Not Correct
#  - Answer : {'NTIS': '전북대학교산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '장진수', 'NTIS': {'inst': '충남대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgwMjEyMTc0ODEyNw==', 'papers': [ObjectId('61ce98d6f8d08a558d7cfade'), ObjectId('61ce988df8d08a558d7cf435')]}}
# Check 장진수1
# Check 김희영0
# Check 김희영0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김희영', 'NTIS': {'inst': '대구한의대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIxOTE0MTM3NzE1Ng==', 'papers': [ObjectId('61ce98a8f8d08a558d7cf748'), ObjectId('61ce98c1f8d08a558d7cf91a')]}}
# Check 김희영1
# Check 정재호0
# Not Correct
#  - Answer : {'NTIS': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정재호', 'NTIS': {'inst': '가천대학교', 'A_id': 'bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjgzMjE2NTcxODkwOQ==', 'papers': [ObjectId('61ce98ccf8d08a558d7cf9db'), ObjectId('61ce9890f8d08a558d7cf49f')]}}
# Check 정재호1
# Check 정재호0
# Check 정해준0
# Check 정해준0
# Not Correct
#  - Answer : {'NTIS': '숭실대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정해준', 'NTIS': {'inst': '인천대학교', 'A_id': 'MTE0NzY1Nzg=', 'papers': [ObjectId('61ce98d0f8d08a558d7cfa26'), ObjectId('61ce989af8d08a558d7cf5ec')]}}
# Check 정해준1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'KCC Corporation', 'KCI': 'KCC건설'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김동식', 'KCI': {'inst': 'KCC건설', 'A_id': 's120741', 'papers': [ObjectId('61ce990a0f91d3fd2b7cabcb')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'KCC Corporation', 'KCI': 'KCC건설'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김동식', 'SCIENCEON': {'inst': 'KCC Corporation', 'A_id': 's287068', 'papers': [ObjectId('61ce9887de84cb5ab77cb5be')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of AI.Software, Gachon University', 'KCI': '가천대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정옥란', 'KCI': {'inst': '가천대학교', 'A_id': 's13247', 'papers': [ObjectId('61ce99020f91d3fd2b7cabb6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of AI.Software, Gachon University', 'KCI': '가천대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '정옥란', 'SCIENCEON': {'inst': 'Dept. of AI.Software, Gachon University', 'A_id': 's820719', 'papers': [ObjectId('61ce9881de84cb5ab77cb570')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'School of Management, Kyung Hee University', 'KCI': '경희대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '권오병', 'KCI': {'inst': '경희대학교', 'A_id': 's14349', 'papers': [ObjectId('61ce98c80f91d3fd2b7cab72'), ObjectId('61ce990f0f91d3fd2b7cabd6')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'School of Management, Kyung Hee University', 'KCI': '경희대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '권오병', 'SCIENCEON': {'inst': 'School of Management, Kyung Hee University', 'A_id': 's258587', 'papers': [ObjectId('61ce9886de84cb5ab77cb5b6')]}}
# Check 이정민0
# Not Correct
#  - Answer : {'NTIS': '서울대학교병원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이정민', 'KCI': {'inst': '이화여자대학교', 'A_id': 's1578', 'papers': [ObjectId('61ce98d50f91d3fd2b7cab88')]}}
# Check 이정민1
# Check 이정민0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Aerospace Engineering, Seoul National University', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '윤군진', 'KCI': {'inst': '서울대학교', 'A_id': 's16451', 'papers': [ObjectId('61ce98ab0f91d3fd2b7cab4f')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Aerospace Engineering, Seoul National University', 'KCI': '서울대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '윤군진', 'SCIENCEON': {'inst': 'Department of Aerospace Engineering, Seoul National University', 'A_id': 's296473', 'papers': [ObjectId('61ce9881de84cb5ab77cb57c')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'K-Water Institute, Korea Water Resources Corporation', 'KCI': '한국수자원공사'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '신강욱', 'KCI': {'inst': '한국수자원공사', 'A_id': 's16556', 'papers': [ObjectId('61ce99060f91d3fd2b7cabc3')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'K-Water Institute, Korea Water Resources Corporation', 'KCI': '한국수자원공사'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '신강욱', 'SCIENCEON': {'inst': 'K-Water Institute, Korea Water Resources Corporation', 'A_id': 's1353249', 'papers': [ObjectId('61ce9881de84cb5ab77cb589')]}}
# Check 박진호0
# Not Correct
#  - Answer : {'NTIS': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박진호', 'KCI': {'inst': '숭실대학교', 'A_id': 's17147', 'papers': [ObjectId('61ce98ea0f91d3fd2b7cab91')]}}
# Check 박진호1
# Check 박진호0
# Check 김현수0
# Not Correct
#  - Answer : {'NTIS': '연세대학교(미래캠퍼스)'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김현수', 'KCI': {'inst': '국민대학교', 'A_id': 's20234', 'papers': [ObjectId('61ce98d50f91d3fd2b7cab89')]}}
# Check 김현수1
# Check 김현수0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '대구경북과학기술원', 'KCI': '국방과학연구소'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박상현', 'KCI': {'inst': '국방과학연구소', 'A_id': 's299134', 'papers': [ObjectId('61ce99190f91d3fd2b7cabe0')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '대구경북과학기술원', 'KCI': '국방과학연구소'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박상현', 'NTIS': {'inst': '대구경북과학기술원', 'A_id': 'MTE0NDIwOTI=', 'papers': [ObjectId('61ce98e6f8d08a558d7cfce8'), ObjectId('61ce9890f8d08a558d7cf4c4')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '(주)프로다임', 'KCI': '㈜프로다임'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김유진', 'KCI': {'inst': '㈜프로다임', 'A_id': 's323191', 'papers': [ObjectId('61ce98950f91d3fd2b7cab0e')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '(주)프로다임', 'KCI': '㈜프로다임'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김유진', 'SCIENCEON': {'inst': '(주)프로다임', 'A_id': 's355088', 'papers': [ObjectId('61ce9881de84cb5ab77cb574')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Naval Architecture and Ocean Engineering, Busan University', 'KCI': '부산대학교 조선해양공학과'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '오상진', 'KCI': {'inst': '부산대학교 조선해양공학과', 'A_id': 's361195', 'papers': [ObjectId('61ce989c0f91d3fd2b7cab1d')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Naval Architecture and Ocean Engineering, Busan University', 'KCI': '부산대학교 조선해양공학과'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '오상진', 'SCIENCEON': {'inst': 'Department of Naval Architecture and Ocean Engineering, Busan University', 'A_id': 's833549', 'papers': [ObjectId('61ce9886de84cb5ab77cb5ba')]}}
# Check 박혜진0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박혜진', 'KCI': {'inst': '김ㆍ장 법률사무소', 'A_id': 's369725', 'papers': [ObjectId('61ce991e0f91d3fd2b7cabeb')]}}
# Check 박혜진1
# Check 박혜진0
# Check 박진호0
# Not Correct
#  - Answer : {'NTIS': '인하대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박진호', 'KCI': {'inst': '동국대학교', 'A_id': 's383205', 'papers': [ObjectId('61ce98ca0f91d3fd2b7cab74'), ObjectId('61ce98ca0f91d3fd2b7cab74')]}}
# Check 박진호1
# Not Correct
#  - Answer : {'KCI': '숭실대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박진호', 'KCI': {'inst': '동국대학교', 'A_id': 's383205', 'papers': [ObjectId('61ce98ca0f91d3fd2b7cab74'), ObjectId('61ce98ca0f91d3fd2b7cab74')]}}
# Check 박진호2
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'U1대학교', 'KCI': '유원(U1)대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박충식', 'KCI': {'inst': '유원(U1)대학교', 'A_id': 's39545', 'papers': [ObjectId('61ce98ce0f91d3fd2b7cab7d')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'U1대학교', 'KCI': '유원(U1)대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박충식', 'SCIENCEON': {'inst': 'U1대학교', 'A_id': 's1353787', 'papers': [ObjectId('61ce9886de84cb5ab77cb5bd')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국건설기술연구원 노후인프라센터, 복합재난대응연구센터', 'KCI': '한국건설기술연구원 복합재난대응연구센터'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영록', 'KCI': {'inst': '한국건설기술연구원 복합재난대응연구센터', 'A_id': 's397366', 'papers': [ObjectId('61ce98a20f91d3fd2b7cab33')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': '한국건설기술연구원 노후인프라센터, 복합재난대응연구센터', 'KCI': '한국건설기술연구원 복합재난대응연구센터'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김영록', 'SCIENCEON': {'inst': '한국건설기술연구원 노후인프라센터, 복합재난대응연구센터', 'A_id': 's832656', 'papers': [ObjectId('61ce9886de84cb5ab77cb5a3')]}}
# Check 김진우0
# Not Correct
#  - Answer : {'NTIS': '경상대학교 산학협력단'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김진우', 'KCI': {'inst': '연세대학교', 'A_id': 's4281', 'papers': [ObjectId('61ce98c10f91d3fd2b7cab64')]}}
# Check 김진우1
# Check 김진우0
# Check 이남용0
# Check 이남용0
# Not Correct
#  - Answer : {'KCI': '숭실대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이남용', 'KCI': {'inst': '서울과학기술대학교 기계자동차공학과', 'A_id': 's12631', 'papers': [ObjectId('61ce98c80f91d3fd2b7cab70')]}}
# Check 이남용1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '한국과학기술원', 'SCIENCEON': '한국해양과학기술원 해양방위안전연구센터', 'KCI': '한국해양과학기술원 해양방위연구센터'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '조성호', 'KCI': {'inst': '한국해양과학기술원 해양방위연구센터', 'A_id': 's445902', 'papers': [ObjectId('61ce98b00f91d3fd2b7cab55'), ObjectId('61ce98b00f91d3fd2b7cab55')]}}
# Check 김혜정0
# Not Correct
#  - Answer : {'NTIS': '경북대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김혜정', 'KCI': {'inst': '영남대학교', 'A_id': 's4665', 'papers': [ObjectId('61ce98c80f91d3fd2b7cab71'), ObjectId('61ce98c80f91d3fd2b7cab71')]}}
# Check 김혜정1
# Not Correct
#  - Answer : {'NTIS': '경일대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김혜정', 'KCI': {'inst': '영남대학교', 'A_id': 's4665', 'papers': [ObjectId('61ce98c80f91d3fd2b7cab71'), ObjectId('61ce98c80f91d3fd2b7cab71')]}}
# Check 김혜정2
# Check 김희숙0
# Check 김희숙0
# Not Correct
#  - Answer : {'KCI': '전남대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김희숙', 'KCI': {'inst': '광주과학기술원', 'A_id': 's388318', 'papers': [ObjectId('61ce98c10f91d3fd2b7cab65'), ObjectId('61ce98d90f91d3fd2b7cab8d')]}}
# Check 김희숙1
# Check 황미경0
# Not Correct
#  - Answer : {'NTIS': '동의대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '황미경', 'KCI': {'inst': '경성대학교', 'A_id': 's541699', 'papers': [ObjectId('61ce989e0f91d3fd2b7cab24'), ObjectId('61ce989e0f91d3fd2b7cab24')]}}
# Check 황미경1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept. of Digital Media, College of Arts, Kyungsung University', 'KCI': '경성대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '황미경', 'KCI': {'inst': '경성대학교', 'A_id': 's541699', 'papers': [ObjectId('61ce989e0f91d3fd2b7cab24'), ObjectId('61ce989e0f91d3fd2b7cab24')]}}
# Check 김경민0
# Not Correct
#  - Answer : {'NTIS': '연세대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김경민', 'KCI': {'inst': '강원대학교 신산업개발 T-EMS 융합학과', 'A_id': 's541974', 'papers': [ObjectId('61ce98b90f91d3fd2b7cab5c')]}}
# Check 김경민1
# Check 김경민0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Korea IT Business Promotion Association', 'KCI': '한국IT비즈니스진흥협회'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '백필호', 'KCI': {'inst': '한국IT비즈니스진흥협회', 'A_id': 's542025', 'papers': [ObjectId('61ce98c10f91d3fd2b7cab68')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Korea IT Business Promotion Association', 'KCI': '한국IT비즈니스진흥협회'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '백필호', 'SCIENCEON': {'inst': 'Korea IT Business Promotion Association', 'A_id': 's1052418', 'papers': [ObjectId('61ce9886de84cb5ab77cb59b')]}}
# Check 김정선0
# Not Correct
#  - Answer : {'NTIS': '국립암센터국제암대학원대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '김정선', 'KCI': {'inst': '부동산인공지능연구소', 'A_id': 's542026', 'papers': [ObjectId('61ce98c50f91d3fd2b7cab69')]}}
# Check 김정선1
# Check 김정선0
# Check 노승민0
# Not Correct
#  - Answer : {'NTIS': '세종대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '노승민', 'KCI': {'inst': '중앙대학교', 'A_id': 's542137', 'papers': [ObjectId('61ce98d60f91d3fd2b7cab8a'), ObjectId('61ce98d60f91d3fd2b7cab8a')]}}
# Check 노승민1
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Department of Industrial Security, Chung-Ang University', 'KCI': '중앙대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '노승민', 'KCI': {'inst': '중앙대학교', 'A_id': 's542137', 'papers': [ObjectId('61ce98d60f91d3fd2b7cab8a'), ObjectId('61ce98d60f91d3fd2b7cab8a')]}}
# Check 조영준0
# Not Correct
#  - Answer : {'NTIS': '건양대학교병원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '조영준', 'KCI': {'inst': '전남대학교', 'A_id': 's545079', 'papers': [ObjectId('61ce98d10f91d3fd2b7cab82')]}}
# Check 조영준1
# Check 조영준0
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'INFOWORKS Corp.', 'KCI': '인포웍스'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박현주', 'KCI': {'inst': '인포웍스', 'A_id': 's85002', 'papers': [ObjectId('61ce98ab0f91d3fd2b7cab50')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'INFOWORKS Corp.', 'KCI': '인포웍스'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '박현주', 'SCIENCEON': {'inst': 'INFOWORKS Corp.', 'A_id': 's1353034', 'papers': [ObjectId('61ce9881de84cb5ab77cb56f')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept of Computer Software Engineering, Soonchunhyang University', 'KCI': '순천향대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '홍민', 'KCI': {'inst': '순천향대학교', 'A_id': 's8988', 'papers': [ObjectId('61ce98fc0f91d3fd2b7cabac')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'SCIENCEON': 'Dept of Computer Software Engineering, Soonchunhyang University', 'KCI': '순천향대학교'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '홍민', 'SCIENCEON': {'inst': 'Dept of Computer Software Engineering, Soonchunhyang University', 'A_id': 's269329', 'papers': [ObjectId('61ce9881de84cb5ab77cb58b')]}}
# Check 이영준0
# Not Correct
#  - Answer : {'NTIS': '분당서울대학교병원'}
#  - Result : {'fid': 0, 'keyId': 651, 'name': '이영준', 'KCI': {'inst': '한국교원대학교', 'A_id': 's93055', 'papers': [ObjectId('61ce98a40f91d3fd2b7cab38')]}}
# Check 이영준1
# Check 이영준0
# num코렉트 1985
# numEror 182
# numInteEror 45
# 토탈에러 25
# 토탈ㅇ인터그레이션에러 21
