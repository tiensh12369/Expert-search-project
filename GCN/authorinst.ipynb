# %%
from pymongo import MongoClient
client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
scienceon_exfa = client['SCIENCEON']['ExpertFactor']
scienceon_aut = client['SCIENCEON']['Author']

ntis_exfa = client['NTIS']['ExpertFactor']
ntis_aut = client['NTIS']['Author']

id_domestic = client['ID']['Domestic']

scienceon_key_query = scienceon_exfa.find({ 'keyId' : 519 })
ntis_key_query = ntis_exfa.find({ 'keyId' : 519 })

scienceon_a_id = [] # A_ID
ntis_a_id = [] # A_ID

scienceon_name_inst = []
ntis_name_inst = []
all_name_inst = []

re_Copy_name = []
re_Copy_inst = []
re_Copy = []

a_name = []
a_inst = []
scienceon_id = []
ntis_id = ''

for i in scienceon_key_query:
    scienceon_a_id.append(i['A_ID'])
    scienceon_aut_query = scienceon_aut.find_one({'_id':i['A_ID']})
    scienceon_name_inst.append(scienceon_aut_query['name'] + '/' + scienceon_aut_query['inst'].split(' ')[0])

for j in ntis_key_query:
    ntis_a_id.append(j['A_ID'])
    aut_query = ntis_aut.find_one({'_id':j['A_ID']})
    ntis_name_inst.append(aut_query['name'] + '/' + aut_query['inst'].split(' ')[0])

all_name_inst = scienceon_name_inst + ntis_name_inst
#print(all_name_inst)

for c in all_name_inst:
    if c not in re_Copy:
        re_Copy.append(c)
        re_Copy_name.append(c.split('/')[0])
        re_Copy_inst.append(c.split('/')[1])

#print(re_Copy_name, re_Copy_inst)

#print('SCIENCEON/NTIS 이름과 소속을 중복을 제거한 것을 가지고 SCIENCEON/NTIS Author에 검색: %d명' % len(re_Copy_name))
for l in range(0, len(re_Copy_name)):

    a_name = re_Copy_name[l]
    a_inst = re_Copy_inst[l]

    scienceon_query = scienceon_aut.find({'$and':[{'name':a_name},{'inst':{'$regex':a_inst}}]})
    ntis_query = ntis_aut.find({'$and':[{'name':a_name},{'inst':{'$regex':a_inst}}]})
    
    print('name: %s inst: %s' % (a_name, a_inst))
    print('----------------------------------------------------%d번째 시작----------------------------------------------------' % (l+1))
    for x in scienceon_query:
        print(x)
        scienceon_id.append(x['_id'])
    
    for y in ntis_query:
        print(y)
        ntis_id = y['_id']
        
    if scienceon_id == [] and ntis_id == '':
        id_domestic.insert({'scienceon': scienceon_id, 'ntis': ntis_id})

    print('scienceon_id: %s' %scienceon_id)
    print('ntis_id: %s' %ntis_id)


    print('----------------------------------------------------%d번째   끝----------------------------------------------------' % (l+1))
    scienceon_id = []
    ntis_id = ''
# Out:
# name: 유재수 inst: 충북대학교
# ----------------------------------------------------1번째 시작----------------------------------------------------
# {'name': '유재수', 'keywords': '벤치마킹; nosql; 논문에서는; 스토리지; 빅데이터', '_id': 's101957', 'inst': '충북대학교'}
# {'name': '유재수', '_id': 's259243', 'inst': '충북대학교 빅데이터학과'}
# {'name': '유재수', '_id': 's1045892', 'inst': '충북대학교 전기.전자.정보.컴퓨터학부 정보통신 공학전공'}
# {'name': '유재수', '_id': 's270145', 'inst': '충북대학교 전기.전자.정보.컴퓨터학부 정보통신공학전공'}
# {'name': '유재수', '_id': 's263816', 'inst': '충북대학교 전기전자컴퓨터공학부'}
# {'name': '유재수', '_id': 's264744', 'inst': '충북대학교 전자정보대학 정보통신공학과'}
# {'name': '유재수', '_id': 's1039040', 'inst': '충북대학교 전자정보대학 정보통신공학부'}
# {'name': '유재수', '_id': 's258835', 'inst': '충북대학교 정보통신공학'}
# {'name': '유재수', '_id': 's258057', 'inst': '충북대학교 정보통신공학과'}
# {'name': '유재수', '_id': 's264187', 'inst': '충북대학교 정보통신공학과 </a'}
# {'name': '유재수', '_id': 's264378', 'inst': "충북대학교 정보통신공학과<affiliationid type='KI"}
# {'name': '유재수', '_id': 's259873', 'inst': '충북대학교 정보통신공학부'}
# {'name': '유재수', '_id': 's258099', 'inst': '충북대학교 정보통신공학부 및 충북BIT연구중심대학육성사업단'}
# {'name': '유재수', '_id': 's260968', 'inst': '충북대학교 정보통신학과'}
# {'name': '유재수', '_id': '857111516498', 'inst': '충북대학교'}
# scienceon_id: ['s101957', 's259243', 's1045892', 's270145', 's263816', 's264744', 's1039040', 's258835', 's258057', 's264187', 's264378', 's259873', 's258099', 's260968']
# ntis_id: 857111516498
# ----------------------------------------------------1번째   끝----------------------------------------------------
# name: 권영우 inst: 동의대학교
# ----------------------------------------------------2번째 시작----------------------------------------------------
# {'name': '권영우', '_id': 's102059', 'inst': '동의대학교'}
# scienceon_id: ['s102059']
# ntis_id:
# ----------------------------------------------------2번째   끝----------------------------------------------------
# name: 송재오 inst: (주)케이아이씨티
# ----------------------------------------------------3번째 시작----------------------------------------------------
# scienceon_id: []
# ntis_id:
# ----------------------------------------------------3번째   끝----------------------------------------------------
# name: 정윤수 inst: 목원대학교
# ----------------------------------------------------4번째 시작----------------------------------------------------
# {'name': '정윤수', '_id': 's258778', 'inst': '목원대학교 UU0000545'}
# {'name': '정윤수', '_id': 's258002', 'inst': '목원대학교 정보통신공학과'}
# {'name': '정윤수', '_id': 's102413', 'inst': '목원대학교 정보통신융합공학부'}
# {'name': '정윤수', '_id': 's264491', 'inst': '목원대학교 정보통신학과'}
# scienceon_id: ['s258778', 's258002', 's102413', 's264491']
# ntis_id:
# ----------------------------------------------------4번째   끝----------------------------------------------------
# name: 이상문 inst: 한국교통대학교
# ----------------------------------------------------5번째 시작----------------------------------------------------
# {'name': '이상문', '_id': 's102555', 'inst': '한국교통대학교 컴퓨터정보공학과'}
# {'name': '이상문', '_id': '822609625144', 'inst': '한국교통대학교산학협력단'}
# scienceon_id: ['s102555']
# ntis_id: 822609625144
# ----------------------------------------------------5번째   끝----------------------------------------------------
# name: 천탠이 inst: 한양대학교
# ----------------------------------------------------6번째 시작----------------------------------------------------
# {'name': '천탠이', '_id': 's1087973', 'inst': '한양대학교 의류학과'}
# scienceon_id: ['s1087973']
# ntis_id:
# ----------------------------------------------------6번째   끝----------------------------------------------------
# name: 이규혜 inst: 한양대학교
# ----------------------------------------------------7번째 시작----------------------------------------------------
# {'name': '이규혜', '_id': 's262343', 'inst': '한양대학교 의류학과'}
# {'name': '이규혜', '_id': 's1087974', 'inst': '한양대학교 의류학과 휴먼테크융합전공'}
# scienceon_id: ['s262343', 's1087974']
# ntis_id:
# ----------------------------------------------------7번째   끝----------------------------------------------------
# name: 김동현 inst: Dept
# ----------------------------------------------------8번째 시작----------------------------------------------------
# {'name': '김동현', '_id': 's1087975', 'inst': 'Dept of Software, Dongseo University'}
# {'name': '김동현', '_id': 's1054987', 'inst': 'Dept. of Electrical and Computer Engineering, Pusan National University'}
# scienceon_id: ['s1087975', 's1054987']
# ntis_id:
# ----------------------------------------------------8번째   끝----------------------------------------------------
# name: 김기현 inst: 성신여자대학교
# ----------------------------------------------------9번째 시작----------------------------------------------------
# {'name': '김기현', '_id': 's1087976', 'inst': '성신여자대학교 정보시스템공학과'}
# scienceon_id: ['s1087976']
# ntis_id:
# ----------------------------------------------------9번째   끝----------------------------------------------------
# name: 변혜원 inst: 성신여자대학교
# ----------------------------------------------------10번째 시작----------------------------------------------------
# C:\Users\Hyeuk\anaconda3\envs\gcn\lib\site-packages\ipykernel_launcher.py:70: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# {'name': '변혜원', '_id': 's1087977', 'inst': '성신여자대학교 정보시스템공학과'}
# {'name': '변혜원', '_id': '207226916035', 'inst': '성신여자대학교 산학협력단'}
# scienceon_id: ['s1087977']
# ntis_id: 207226916035
# ----------------------------------------------------10번째   끝----------------------------------------------------
# name: 김영미 inst: 서원대학교
# ----------------------------------------------------11번째 시작----------------------------------------------------
# {'name': '김영미', '_id': 's1087978', 'inst': '서원대학교 레저스포츠학과'}
# scienceon_id: ['s1087978']
# ntis_id:
# ----------------------------------------------------11번째   끝----------------------------------------------------
# name: 양재식 inst: 서원대학교
# ----------------------------------------------------12번째 시작----------------------------------------------------
# {'name': '양재식', '_id': 's1087979', 'inst': '서원대학교 레저스포츠학과'}
# scienceon_id: ['s1087979']
# ntis_id:
# ----------------------------------------------------12번째   끝----------------------------------------------------
# name: 륙치금 inst: 부경대학교
# ----------------------------------------------------13번째 시작----------------------------------------------------
# {'name': '륙치금', '_id': 's1087980', 'inst': '부경대학교 신문방송학과'}
# scienceon_id: ['s1087980']
# ntis_id:
# ----------------------------------------------------13번째   끝----------------------------------------------------
# name: 남인용 inst: 부경대학교
# ----------------------------------------------------14번째 시작----------------------------------------------------
# {'name': '남인용', '_id': 's1087981', 'inst': '부경대학교 신문방송학과'}
# scienceon_id: ['s1087981']
# ntis_id:
# ----------------------------------------------------14번째   끝----------------------------------------------------
# name: 한정섭 inst: 남서울대학교
# ----------------------------------------------------15번째 시작----------------------------------------------------
# {'name': '한정섭', '_id': 's1087982', 'inst': '남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과'}
# scienceon_id: ['s1087982']
# ntis_id:
# ----------------------------------------------------15번째   끝----------------------------------------------------
# name: 권두순 inst: 청운대학교
# ----------------------------------------------------16번째 시작----------------------------------------------------
# {'name': '권두순', '_id': 's1087983', 'inst': '청운대학교 교양대학'}
# scienceon_id: ['s1087983']
# ntis_id:
# ----------------------------------------------------16번째   끝----------------------------------------------------
# name: 김성준 inst: 남서울대학교
# ----------------------------------------------------17번째 시작----------------------------------------------------
# {'name': '김성준', '_id': 's303301', 'inst': '남서울대학교'}
# {'name': '김성준', '_id': 's1087984', 'inst': '남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과'}
# {'name': '김성준', '_id': 's270362', 'inst': '남서울대학교 복지경영대학원 산업보안학과'}
# {'name': '김성준', '_id': 's303296', 'inst': '남서울대학교 산업보안학과'}
# {'name': '김성준', '_id': 's260960', 'inst': '남서울대학교대학원 빅데이터산업보안학과'}
# {'name': '김성준', '_id': '214813327170', 'inst': '남서울대학교 산학협력단'}
# scienceon_id: ['s303301', 's1087984', 's270362', 's303296', 's260960']
# ntis_id: 214813327170
# ----------------------------------------------------17번째   끝----------------------------------------------------
# name: 백연희 inst: 충북대학교
# ----------------------------------------------------18번째 시작----------------------------------------------------
# {'name': '백연희', '_id': 's262201', 'inst': '충북대학교'}
# {'name': '백연희', '_id': 's1087985', 'inst': '충북대학교 빅데이터 협동과정'}
# {'name': '백연희', '_id': '11927409', 'inst': '충북대학교산학협력단'}
# scienceon_id: ['s262201', 's1087985']
# ntis_id: 11927409
# ----------------------------------------------------18번째   끝----------------------------------------------------
# name: 권혜민 inst: 서울여자대학교
# ----------------------------------------------------19번째 시작----------------------------------------------------
# {'name': '권혜민', '_id': 's1087986', 'inst': '서울여자대학교 정보보호학과'}
# scienceon_id: ['s1087986']
# ntis_id:
# ----------------------------------------------------19번째   끝----------------------------------------------------
# name: 이인수 inst: 대검찰청
# ----------------------------------------------------20번째 시작----------------------------------------------------
# {'name': '이인수', '_id': 's1087987', 'inst': '대검찰청 디지털수사과'}
# scienceon_id: ['s1087987']
# ntis_id:
# ----------------------------------------------------20번째   끝----------------------------------------------------
# name: 이승훈 inst: 대검찰청
# ----------------------------------------------------21번째 시작----------------------------------------------------
# {'name': '이승훈', '_id': 's1087988', 'inst': '대검찰청 디지털수사과'}
# scienceon_id: ['s1087988']
# ntis_id:
# ----------------------------------------------------21번째   끝----------------------------------------------------
# name: 정주익 inst: 인천국제공항공사
# ----------------------------------------------------22번째 시작----------------------------------------------------
# {'name': '정주익', '_id': 's1087989', 'inst': '인천국제공항공사 공항산업기술연구원'}
# scienceon_id: ['s1087989']
# ntis_id:
# ----------------------------------------------------22번째   끝----------------------------------------------------
# name: 손석현 inst: 인천국제공항공사
# ----------------------------------------------------23번째 시작----------------------------------------------------
# {'name': '손석현', '_id': 's1087990', 'inst': '인천국제공항공사 공항산업기술연구원'}
# scienceon_id: ['s1087990']
# ntis_id:
# ----------------------------------------------------23번째   끝----------------------------------------------------
# name: 차희준 inst: 인천국제공항공사
# ----------------------------------------------------24번째 시작----------------------------------------------------
# {'name': '차희준', '_id': 's1087991', 'inst': '인천국제공항공사 공항산업기술연구원'}
# scienceon_id: ['s1087991']
# ntis_id:
# ----------------------------------------------------24번째   끝----------------------------------------------------
# name: 서봉군 inst: 국민대학교
# ----------------------------------------------------25번째 시작----------------------------------------------------
# {'name': '서봉군', '_id': 's120637', 'inst': '국민대학교 비즈니스 IT 전문대학원'}
# {'name': '서봉군', '_id': '11639408', 'inst': '국민대학교'}
# scienceon_id: ['s120637']
# ntis_id: 11639408
# ----------------------------------------------------25번째   끝----------------------------------------------------
# name: 노영희 inst: 건국대학교
# ----------------------------------------------------26번째 시작----------------------------------------------------
# {'name': '노영희', '_id': 's122643', 'inst': '건국대학교 문헌정보학과'}
# {'name': '노영희', '_id': 's265281', 'inst': '건국대학교 인문과학대학 문헌정보학과'}
# {'name': '노영희', '_id': 's72312', 'inst': '건국대학교 GLOCAL(글로컬)캠퍼스'}
# {'name': '노영희', '_id': '269225516177', 'inst': '건국대학교 GLOCAL(글로컬)캠퍼스'}
# scienceon_id: ['s122643', 's265281']
# ntis_id: 269225516177
# ----------------------------------------------------26번째   끝----------------------------------------------------
# name: 김창수 inst: Department
# ----------------------------------------------------27번째 시작----------------------------------------------------
# {'name': '김창수', '_id': 's266207', 'inst': 'Department of Computer Engineering, Paichai University'}
# {'name': '김창수', '_id': 's123122', 'inst': 'Department of IT Convergence and Application Engineering, Pukyong National University'}
# scienceon_id: ['s266207', 's123122']
# ntis_id:
# ----------------------------------------------------27번째   끝----------------------------------------------------
# name: 염희균 inst: 대전대학교
# ----------------------------------------------------28번째 시작----------------------------------------------------
# {'name': '염희균', '_id': 's136814', 'inst': '대전대학교 컴퓨터공학과'}
# {'name': '염희균', '_id': 's136929', 'inst': '대전대학교 컴퓨터공학과 강의전담'}
# scienceon_id: ['s136814', 's136929']
# ntis_id:
# ----------------------------------------------------28번째   끝----------------------------------------------------
# name: 진찬용 inst: Wonkwang
# ----------------------------------------------------29번째 시작----------------------------------------------------
# {'name': '진찬용', '_id': 's143722', 'inst': 'Wonkwang University'}
# {'name': '진찬용', '_id': 's260761', 'inst': 'Wonkwang University (Institute of Convergence and Creativity)'}
# scienceon_id: ['s143722', 's260761']
# ntis_id:
# ----------------------------------------------------29번째   끝----------------------------------------------------
# name: 신성윤 inst: Kunsan
# ----------------------------------------------------30번째 시작----------------------------------------------------
# {'name': '신성윤', '_id': 's258846', 'inst': 'Department of Computer Information Engineering, Kunsan National University'}
# {'name': '신성윤', '_id': 's1017046', 'inst': 'Department of Computer and Information Communication Engineering, Kunsan National University'}
# {'name': '신성윤', '_id': 's1015319', 'inst': 'Department of Computer and Information Engineering, Kunsan National University'}
# {'name': '신성윤', '_id': 's143723', 'inst': 'Kunsan National University'}
# {'name': '신성윤', '_id': 's179915', 'inst': 'School of Com. Inf. & Comm. Eng., Kunsan National University'}
# {'name': '신성윤', '_id': 's258921', 'inst': 'School of Computer & Information Communication Engineering, Kunsan National University'}
# {'name': '신성윤', '_id': 's502778', 'inst': 'School of Computer Inf. & Comm. Eng., Kunsan Nat. Univ.'}
# {'name': '신성윤', '_id': 's180318', 'inst': 'School of Computer Information & Communication Eng. Kunsan National University'}
# {'name': '신성윤', '_id': 's315898', 'inst': 'School of Computer Information & Communication Engineering, Kunsan National University'}
# scienceon_id: ['s258846', 's1017046', 's1015319', 's143723', 's179915', 's258921', 's502778', 's180318', 's315898']
# ntis_id:
# ----------------------------------------------------30번째   끝----------------------------------------------------
# name: 남수태 inst: Wonkwang
# ----------------------------------------------------31번째 시작----------------------------------------------------
# {'name': '남수태', '_id': 's143724', 'inst': 'Wonkwang University'}
# {'name': '남수태', '_id': 's260759', 'inst': 'Wonkwang University (Institute of Convergence and Creativity)'}
# scienceon_id: ['s143724', 's260759']
# ntis_id:
# ----------------------------------------------------31번째   끝----------------------------------------------------
# name: 서주환 inst: 경희대학교
# ----------------------------------------------------32번째 시작----------------------------------------------------
# {'name': '서주환', '_id': 's259682', 'inst': '경희대학교 예술.디자인 환경조경디자인학과'}
# {'name': '서주환', '_id': 's152628', 'inst': '경희대학교 예술.디자인대학 환경조경디자인학과'}
# {'name': '서주환', '_id': '413702755184', 'inst': '경희대학교(용인) 산학협력단'}
# scienceon_id: ['s259682', 's152628']
# ntis_id: 413702755184
# ----------------------------------------------------32번째   끝----------------------------------------------------
# name: 강민식 inst: 남서울대학교
# ----------------------------------------------------33번째 시작----------------------------------------------------
# {'name': '강민식', '_id': 's183789', 'inst': '남서울대학교 산업경영공학과'}
# {'name': '강민식', '_id': 's525588', 'inst': '남서울대학교 산업공학경영학과'}
# {'name': '강민식', '_id': '463164226459', 'inst': '남서울대학교산학협력단'}
# scienceon_id: ['s183789', 's525588']
# ntis_id: 463164226459
# ----------------------------------------------------33번째   끝----------------------------------------------------
# name: 박희준 inst: 연세대학교
# ----------------------------------------------------34번째 시작----------------------------------------------------
# {'name': '박희준', '_id': 's190742', 'inst': '연세대학교 정보산업공학과'}
# {'name': '박희준', '_id': '809136916434', 'inst': '연세대학교'}
# scienceon_id: ['s190742']
# ntis_id: 809136916434
# ----------------------------------------------------34번째   끝----------------------------------------------------
# name: 한소월 inst: 이화여자대학교
# ----------------------------------------------------35번째 시작----------------------------------------------------
# {'name': '한소월', '_id': 's257761', 'inst': '이화여자대학교 컴퓨터공학과'}
# scienceon_id: ['s257761']
# ntis_id:
# ----------------------------------------------------35번째   끝----------------------------------------------------
# name: 이민수 inst: 이화여자대학교
# ----------------------------------------------------36번째 시작----------------------------------------------------
# {'name': '이민수', '_id': 's257762', 'inst': '이화여자대학교 컴퓨터공학과'}
# {'name': '이민수', '_id': 's264996', 'inst': '이화여자대학교 컴퓨터공학과 UU0001056'}
# {'name': '이민수', '_id': '548120816280', 'inst': '이화여자대학교'}
# scienceon_id: ['s257762', 's264996']
# ntis_id: 548120816280
# ----------------------------------------------------36번째   끝----------------------------------------------------
# name: 박석천 inst: 가천대학교
# ----------------------------------------------------37번째 시작----------------------------------------------------
# {'name': '박석천', '_id': 's258807', 'inst': '가천대학교 IT대학 컴퓨터공학과'}
# {'name': '박석천', '_id': 's259285', 'inst': '가천대학교 컴퓨터 공학과'}
# {'name': '박석천', '_id': 's257866', 'inst': '가천대학교 컴퓨터공학과'}
# {'name': '박석천', '_id': '111680205130', 'inst': '가천대학교'}
# scienceon_id: ['s258807', 's259285', 's257866']
# ntis_id: 111680205130
# ----------------------------------------------------37번째   끝----------------------------------------------------
# name: 윤진영 inst: 가톨릭대학교
# ----------------------------------------------------38번째 시작----------------------------------------------------
# {'name': '윤진영', '_id': 's257887', 'inst': '가톨릭대학교 컴퓨터공학과'}
# scienceon_id: ['s257887']
# ntis_id:
# ----------------------------------------------------38번째   끝----------------------------------------------------
# name: 김석중 inst: 가톨릭대학교
# ----------------------------------------------------39번째 시작----------------------------------------------------
# {'name': '김석중', '_id': 's257888', 'inst': '가톨릭대학교 컴퓨터공학과'}
# scienceon_id: ['s257888']
# ntis_id:
# ----------------------------------------------------39번째   끝----------------------------------------------------
# name: 이범석 inst: 가톨릭대학교
# ----------------------------------------------------40번째 시작----------------------------------------------------
# {'name': '이범석', '_id': 's270022', 'inst': '가톨릭대학교'}
# {'name': '이범석', '_id': 's257889', 'inst': '가톨릭대학교 컴퓨터공학과'}
# scienceon_id: ['s270022', 's257889']
# ntis_id:
# ----------------------------------------------------40번째   끝----------------------------------------------------
# name: 황병연 inst: 가톨릭대학교
# ----------------------------------------------------41번째 시작----------------------------------------------------
# {'name': '황병연', '_id': 's257890', 'inst': '가톨릭대학교 컴퓨터공학과'}
# {'name': '황병연', '_id': 's264008', 'inst': '가톨릭대학교 컴퓨터정보공학부'}
# {'name': '황병연', '_id': '813117916177', 'inst': '가톨릭대학교 산학협력단'}
# scienceon_id: ['s257890', 's264008']
# ntis_id: 813117916177
# ----------------------------------------------------41번째   끝----------------------------------------------------
# name: 최광선 inst: 솔트룩스
# ----------------------------------------------------42번째 시작----------------------------------------------------
# {'name': '최광선', '_id': 's1087247', 'inst': '솔트룩스 CDS사업본부'}
# {'name': '최광선', '_id': 's257922', 'inst': '솔트룩스 전략사업본부'}
# scienceon_id: ['s1087247', 's257922']
# ntis_id:
# ----------------------------------------------------42번째   끝----------------------------------------------------
# name: 공효순 inst: 남서울대학교
# ----------------------------------------------------43번째 시작----------------------------------------------------
# {'name': '공효순', '_id': 's257950', 'inst': '남서울대학교 호텔경영학과'}
# scienceon_id: ['s257950']
# ntis_id:
# ----------------------------------------------------43번째   끝----------------------------------------------------
# name: 송은지 inst: 남서울대학교
# ----------------------------------------------------44번째 시작----------------------------------------------------
# {'name': '송은지', '_id': 's531472', 'inst': '남서울대학교'}
# {'name': '송은지', '_id': 's264257', 'inst': '남서울대학교 UU0000327'}
# {'name': '송은지', '_id': 's525848', 'inst': '남서울대학교 영상예술디자인학과'}
# {'name': '송은지', '_id': 's274822', 'inst': '남서울대학교 컴퓨터소프트웨어학과'}
# {'name': '송은지', '_id': 's257951', 'inst': '남서울대학교 컴퓨터학과'}
# {'name': '송은지', '_id': 's264280', 'inst': '남서울대학교 컴퓨터학과 UU0000327'}
# scienceon_id: ['s531472', 's264257', 's525848', 's274822', 's257951', 's264280']
# ntis_id:
# ----------------------------------------------------44번째   끝----------------------------------------------------
# name: 서정민 inst: (주)디엘커뮤니케이션즈
# ----------------------------------------------------45번째 시작----------------------------------------------------
# scienceon_id: []
# ntis_id:
# ----------------------------------------------------45번째   끝----------------------------------------------------
# name: 허서연 inst: Dept.
# ----------------------------------------------------46번째 시작----------------------------------------------------
# {'name': '허서연', '_id': 's257953', 'inst': "Dept. of Computer Science, Sookmyung Women's Univ."}
# scienceon_id: ['s257953']
# ntis_id:
# ----------------------------------------------------46번째   끝----------------------------------------------------
# name: 김윤희 inst: Dept.
# ----------------------------------------------------47번째 시작----------------------------------------------------
# {'name': '김윤희', '_id': 's257954', 'inst': "Dept. of Computer Science, Sookmyung Women's Univ."}
# scienceon_id: ['s257954']
# ntis_id:
# ----------------------------------------------------47번째   끝----------------------------------------------------
# name: 정익래 inst: 고려대학교
# ----------------------------------------------------48번째 시작----------------------------------------------------
# {'name': '정익래', '_id': 's168995', 'inst': '고려대학교'}
# {'name': '정익래', '_id': 's279120', 'inst': '고려대학교 정보경영공학전문대학원'}
# {'name': '정익래', '_id': 's257983', 'inst': '고려대학교 정보보호대학원'}
# {'name': '정익래', '_id': '410769537135', 'inst': '고려대학교'}
# scienceon_id: ['s168995', 's279120', 's257983']
# ntis_id: 410769537135
# ----------------------------------------------------48번째   끝----------------------------------------------------
# name: 배정환 inst: 연세대학교
# ----------------------------------------------------49번째 시작----------------------------------------------------
# {'name': '배정환', '_id': 's270284', 'inst': '연세대학교 문과대학 문헌정보학과'}
# {'name': '배정환', '_id': 's257989', 'inst': '연세대학교 문헌정보학과 대학원'}
# scienceon_id: ['s270284', 's257989']
# ntis_id:
# ----------------------------------------------------49번째   끝----------------------------------------------------
# name: 손지은 inst: 연세대학교
# ----------------------------------------------------50번째 시작----------------------------------------------------
# {'name': '손지은', '_id': 's257990', 'inst': '연세대학교 문헌정보학과 대학원'}
# scienceon_id: ['s257990']
# ntis_id:
# ----------------------------------------------------50번째   끝----------------------------------------------------
# name: 송민 inst: 연세대학교
# ----------------------------------------------------51번째 시작----------------------------------------------------
# {'name': '송민', '_id': 's264471', 'inst': '연세대학교 문과대학 문헌정보학과'}
# {'name': '송민', '_id': 's257991', 'inst': '연세대학교 문헌정보학과'}
# {'name': '송민', '_id': '879556376701', 'inst': '연세대학교'}
# scienceon_id: ['s264471', 's257991']
# ntis_id: 879556376701
# ----------------------------------------------------51번째   끝----------------------------------------------------
# name: 한군희 inst: 백석대학교
# ----------------------------------------------------52번째 시작----------------------------------------------------
# {'name': '한군희', '_id': 's258003', 'inst': '백석대학교 정보통신공학과'}
# {'name': '한군희', '_id': 's260337', 'inst': '백석대학교 정보통신학부'}
# scienceon_id: ['s258003', 's260337']
# ntis_id:
# ----------------------------------------------------52번째   끝----------------------------------------------------
# name: 김희영 inst: 부산대학교
# ----------------------------------------------------53번째 시작----------------------------------------------------
# {'name': '김희영', '_id': 's258012', 'inst': '부산대학교 영화연구소'}
# {'name': '김희영', '_id': 's72574', 'inst': '부산대학교'}
# {'name': '김희영', '_id': '618290418394', 'inst': '부산대학교 산학협력단'}
# {'name': '김희영', '_id': '11826649', 'inst': '부산대학교한방병원'}
# scienceon_id: ['s258012']
# ntis_id: 11826649
# ----------------------------------------------------53번째   끝----------------------------------------------------
# name: 신창옥 inst: 경성대학교
# ----------------------------------------------------54번째 시작----------------------------------------------------
# {'name': '신창옥', '_id': 's258013', 'inst': '경성대학교 디지털 콘텐츠학부'}
# scienceon_id: ['s258013']
# ntis_id:
# ----------------------------------------------------54번째   끝----------------------------------------------------
# name: 박선 inst: 목포대학교
# ----------------------------------------------------55번째 시작----------------------------------------------------
# {'name': '박선', '_id': 's258202', 'inst': '국립목포대학교'}
# {'name': '박선', '_id': 's1068177', 'inst': '목포대학교'}
# {'name': '박선', '_id': 's1086898', 'inst': '목포대학교 MTRC 센터 정보산업연구소'}
# {'name': '박선', '_id': 's258039', 'inst': '목포대학교 정보산업연구소'}
# scienceon_id: ['s258202', 's1068177', 's1086898', 's258039']
# ntis_id:
# ----------------------------------------------------55번째   끝----------------------------------------------------
# name: 김용일 inst: 호남대학교
# ----------------------------------------------------56번째 시작----------------------------------------------------
# {'name': '김용일', '_id': 's1068042', 'inst': '호남대학교'}
# {'name': '김용일', '_id': 's1045544', 'inst': '호남대학교 인터넷 소프트웨어학과'}
# {'name': '김용일', '_id': 's103412', 'inst': '호남대학교 인터넷소프트웨어학과'}
# {'name': '김용일', '_id': 's258040', 'inst': '호남대학교 인터넷콘텐츠학과'}
# {'name': '김용일', '_id': '813151157110', 'inst': '호남대학교'}
# scienceon_id: ['s1068042', 's1045544', 's103412', 's258040']
# ntis_id: 813151157110
# ----------------------------------------------------56번째   끝----------------------------------------------------
# name: 이성로 inst: 목포대학교
# ----------------------------------------------------57번째 시작----------------------------------------------------
# {'name': '이성로', '_id': 's258209', 'inst': '국립목포대학교'}
# {'name': '이성로', '_id': 's136792', 'inst': '목포대학교'}
# {'name': '이성로', '_id': 's1857', 'inst': '목포대학교 공과대학 정보공학부 정보전자공학'}
# {'name': '이성로', '_id': 's525281', 'inst': '목포대학교 전자공학과'}
# {'name': '이성로', '_id': 's1034317', 'inst': '목포대학교 전자정보공학과'}
# {'name': '이성로', '_id': 's137873', 'inst': '목포대학교 정보공학부 멀티미디어통신연구실'}
# {'name': '이성로', '_id': 's258041', 'inst': '목포대학교 정보전자공학과'}
# {'name': '이성로', '_id': 's1037749', 'inst': '목포대학교 정보전자공학과과'}
# {'name': '이성로', '_id': '118465025198', 'inst': '목포대학교 산학협력단'}
# scienceon_id: ['s258209', 's136792', 's1857', 's525281', 's1034317', 's137873', 's258041', 's1037749']
# ntis_id: 118465025198
# ----------------------------------------------------57번째   끝----------------------------------------------------
# name: 복경수 inst: 충북대학교
# ----------------------------------------------------58번째 시작----------------------------------------------------
# {'name': '복경수', '_id': 's258540', 'inst': '충북대학교'}
# {'name': '복경수', '_id': 's1046257', 'inst': '충북대학교 전기.전자.정보.컴퓨터학부 정보통신 공학전공'}
# {'name': '복경수', '_id': 's258834', 'inst': '충북대학교 정보통신공학'}
# {'name': '복경수', '_id': 's258056', 'inst': '충북대학교 정보통신공학과'}
# {'name': '복경수', '_id': 's259872', 'inst': '충북대학교 정보통신공학부'}
# {'name': '복경수', '_id': 's260967', 'inst': '충북대학교 정보통신학과'}
# scienceon_id: ['s258540', 's1046257', 's258834', 's258056', 's259872', 's260967']
# ntis_id:
# ----------------------------------------------------58번째   끝----------------------------------------------------
# name: 이환수 inst: 카이스트
# ----------------------------------------------------59번째 시작----------------------------------------------------
# {'name': '이환수', '_id': 's258077', 'inst': '카이스트 경영과학과'}
# scienceon_id: ['s258077']
# ntis_id:
# ----------------------------------------------------59번째   끝----------------------------------------------------
# name: 임동원 inst: 카이스트
# ----------------------------------------------------60번째 시작----------------------------------------------------
# {'name': '임동원', '_id': 's258078', 'inst': '카이스트 경영과학과'}
# scienceon_id: ['s258078']
# ntis_id:
# ----------------------------------------------------60번째   끝----------------------------------------------------
# name: 조항정 inst: 카이스트
# ----------------------------------------------------61번째 시작----------------------------------------------------
# {'name': '조항정', '_id': 's258079', 'inst': '카이스트 경영과학과'}
# scienceon_id: ['s258079']
# ntis_id:
# ----------------------------------------------------61번째   끝----------------------------------------------------
# name: 김유두 inst: School
# ----------------------------------------------------62번째 시작----------------------------------------------------
# {'name': '김유두', '_id': 's258151', 'inst': 'School of Computer Science and Engineering, Korea University of Technology and Education'}
# scienceon_id: ['s258151']
# ntis_id:
# ----------------------------------------------------62번째   끝----------------------------------------------------
# name: 주인학 inst: Knowledge
# ----------------------------------------------------63번째 시작----------------------------------------------------
# {'name': '주인학', '_id': 's258152', 'inst': 'Knowledge Convergence Service Research Section, IT Convergence Technology Research Laboratory, Electronics and Telecommunications Research Institute(ETRI)'}
# scienceon_id: ['s258152']
# ntis_id:
# ----------------------------------------------------63번째   끝----------------------------------------------------
# name: 박윤경 inst: Knowledge
# ----------------------------------------------------64번째 시작----------------------------------------------------
# {'name': '박윤경', '_id': 's258153', 'inst': 'Knowledge Convergence Service Research Section, IT Convergence Technology Research Laboratory, Electronics and Telecommunications Research Institute(ETRI)'}
# scienceon_id: ['s258153']
# ntis_id:
# ----------------------------------------------------64번째   끝----------------------------------------------------
# name: 문일영 inst: School
# ----------------------------------------------------65번째 시작----------------------------------------------------
# {'name': '문일영', '_id': 's258154', 'inst': 'School of Computer Science and Engineering, Korea University of Technology and Education'}
# scienceon_id: ['s258154']
# ntis_id:
# ----------------------------------------------------65번째   끝----------------------------------------------------
# name: 권오영 inst: School
# ----------------------------------------------------66번째 시작----------------------------------------------------
# {'name': '권오영', '_id': 's258155', 'inst': 'School of Computer Science and Engineering, Korea University of Technology and Education'}
# {'name': '권오영', '_id': 's313532', 'inst': 'School of Computer Science and Engineering, University of Technology and Education'}
# scienceon_id: ['s258155', 's313532']
# ntis_id:
# ----------------------------------------------------66번째   끝----------------------------------------------------
# name: 노현호 inst: 한국기술교육대학교
# ----------------------------------------------------67번째 시작----------------------------------------------------
# {'name': '노현호', '_id': 's258160', 'inst': '한국기술교육대학교 컴퓨터공학부'}
# scienceon_id: ['s258160']
# ntis_id:
# ----------------------------------------------------67번째   끝----------------------------------------------------
# name: 민준기 inst: 한국기술교육대학교
# ----------------------------------------------------68번째 시작----------------------------------------------------
# {'name': '민준기', '_id': 's258161', 'inst': '한국기술교육대학교 컴퓨터공학부'}
# {'name': '민준기', '_id': '215901257128', 'inst': '한국기술교육대학교'}
# scienceon_id: ['s258161']
# ntis_id: 215901257128
# ----------------------------------------------------68번째   끝----------------------------------------------------
# name: 박소현 inst: 고려대학교
# ----------------------------------------------------69번째 시작----------------------------------------------------
# {'name': '박소현', '_id': 's1067124', 'inst': '고려대학교 안암병원 핵의학과'}
# {'name': '박소현', '_id': 's258170', 'inst': '고려대학교 정보보호대학원'}
# {'name': '박소현', '_id': '11695051', 'inst': '고려대학교'}
# {'name': '박소현', '_id': '484280918467', 'inst': '고려대학교 산학협력단'}
# {'name': '박소현', '_id': '11907687', 'inst': '고려대학교산학협력단'}
# {'name': '박소현', '_id': '509221518205', 'inst': '고려대학교산학협력단'}
# scienceon_id: ['s1067124', 's258170']
# ntis_id: 509221518205
# ----------------------------------------------------69번째   끝----------------------------------------------------
# name: 엄세진 inst: 한국외국어대학교
# ----------------------------------------------------70번째 시작----------------------------------------------------
# {'name': '엄세진', '_id': 's258210', 'inst': '한국외국어대학교 디지털정보공학과'}
# scienceon_id: ['s258210']
# ntis_id:
# ----------------------------------------------------70번째   끝----------------------------------------------------
# name: 임승호 inst: 한국외국어대학교
# ----------------------------------------------------71번째 시작----------------------------------------------------
# {'name': '임승호', '_id': 's1042248', 'inst': '한국외국어대학교 공과대학 디지털정보공학과'}
# {'name': '임승호', '_id': 's258211', 'inst': '한국외국어대학교 디지털정보공학과'}
# {'name': '임승호', '_id': 's1036664', 'inst': '한국외국어대학교 전자정보공학부'}
# {'name': '임승호', '_id': 's286865', 'inst': '한국외국어대학교 컴퓨터.전자시스템공학부'}
# {'name': '임승호', '_id': 's273868', 'inst': '한국외국어대학교 컴퓨터전자시스템공학부'}
# {'name': '임승호', '_id': '413580557198', 'inst': '한국외국어대학교 연구산학협력단'}
# scienceon_id: ['s1042248', 's258211', 's1036664', 's286865', 's273868']
# ntis_id: 413580557198
# ----------------------------------------------------71번째   끝----------------------------------------------------
# name: 홍석우 inst: 화이트정보통신
# ----------------------------------------------------72번째 시작----------------------------------------------------
# {'name': '홍석우', '_id': 's258232', 'inst': '화이트정보통신 사업총괄'}
# scienceon_id: ['s258232']
# ntis_id:
# ----------------------------------------------------72번째   끝----------------------------------------------------
# name: 김태엽 inst: 화이트정보통신
# ----------------------------------------------------73번째 시작----------------------------------------------------
# {'name': '김태엽', '_id': 's257946', 'inst': '화이트정보통신 R&D 센터'}
# {'name': '김태엽', '_id': 's258233', 'inst': '화이트정보통신 제품개발팀'}
# scienceon_id: ['s257946', 's258233']
# ntis_id:
# ----------------------------------------------------73번째   끝----------------------------------------------------
# name: 양승연 inst: 가천대학교
# ----------------------------------------------------74번째 시작----------------------------------------------------
# {'name': '양승연', '_id': 's258238', 'inst': '가천대학교 모바일소프트웨어학과'}
# {'name': '양승연', '_id': 's265594', 'inst': '가천대학교 일반대학원 모바일소프트웨어학과'}
# scienceon_id: ['s258238', 's265594']
# ntis_id:
# ----------------------------------------------------74번째   끝----------------------------------------------------
# name: 조현성 inst: 가천대학교
# ----------------------------------------------------75번째 시작----------------------------------------------------
# {'name': '조현성', '_id': 's258239', 'inst': '가천대학교 모바일소프트웨어학과'}
# scienceon_id: ['s258239']
# ntis_id:
# ----------------------------------------------------75번째   끝----------------------------------------------------
# name: 이천희 inst: 가천대학교
# ----------------------------------------------------76번째 시작----------------------------------------------------
# {'name': '이천희', '_id': 's258240', 'inst': '가천대학교 모바일소프트웨어학과'}
# scienceon_id: ['s258240']
# ntis_id:
# ----------------------------------------------------76번째   끝----------------------------------------------------
# name: 박기성 inst: 경희대학교
# ----------------------------------------------------77번째 시작----------------------------------------------------
# {'name': '박기성', '_id': 's269675', 'inst': '경희대학교 컴퓨터공학'}
# {'name': '박기성', '_id': 's258254', 'inst': '경희대학교 컴퓨터공학과'}
# scienceon_id: ['s269675', 's258254']
# ntis_id:
# ----------------------------------------------------77번째   끝----------------------------------------------------
# name: 윤영선 inst: 경희대학교
# ----------------------------------------------------78번째 시작----------------------------------------------------
# {'name': '윤영선', '_id': 's258255', 'inst': '경희대학교 컴퓨터공학과'}
# scienceon_id: ['s258255']
# ntis_id:
# ----------------------------------------------------78번째   끝----------------------------------------------------
# name: 김태연 inst: 경희대학교
# ----------------------------------------------------79번째 시작----------------------------------------------------
# {'name': '김태연', '_id': 's528596', 'inst': '경희대학교 생체의공학과'}
# {'name': '김태연', '_id': 's266911', 'inst': '경희대학교 컴퓨터공학'}
# {'name': '김태연', '_id': 's258256', 'inst': '경희대학교 컴퓨터공학과'}
# {'name': '김태연', '_id': '429112718294', 'inst': '경희대학교 산학협력단'}
# scienceon_id: ['s528596', 's266911', 's258256']
# ntis_id: 429112718294
# ----------------------------------------------------79번째   끝----------------------------------------------------
# name: 이영구 inst: 경희대학교
# ----------------------------------------------------80번째 시작----------------------------------------------------
# {'name': '이영구', '_id': 's266913', 'inst': '경희대학교 컴퓨터공학'}
# {'name': '이영구', '_id': 's258257', 'inst': '경희대학교 컴퓨터공학과'}
# {'name': '이영구', '_id': '217446297110', 'inst': '경희대학교 산학협력단'}
# scienceon_id: ['s266913', 's258257']
# ntis_id: 217446297110
# ----------------------------------------------------80번째   끝----------------------------------------------------
# name: 김경환 inst: 제주대학교
# ----------------------------------------------------81번째 시작----------------------------------------------------
# {'name': '김경환', '_id': 's258265', 'inst': '제주대학교 과학기술사회연구센터'}
# {'name': '김경환', '_id': '550166518007', 'inst': '제주대학교산학협력단'}
# {'name': '김경환', '_id': '411612967187', 'inst': '제주대학교산학협력단'}
# scienceon_id: ['s258265']
# ntis_id: 411612967187
# ----------------------------------------------------81번째   끝----------------------------------------------------
# name: 박남제 inst: 제주대학교
# ----------------------------------------------------82번째 시작----------------------------------------------------
# {'name': '박남제', '_id': 's709660', 'inst': '제주대학교'}
# {'name': '박남제', '_id': 's258266', 'inst': '제주대학교 과학기술사회연구센터'}
# {'name': '박남제', '_id': 's104186', 'inst': '제주대학교 교육대학 초등컴퓨터교육전공'}
# {'name': '박남제', '_id': 's814226', 'inst': '제주대학교 사이버보안인재교육원'}
# {'name': '박남제', '_id': 's262283', 'inst': '제주대학교 융합정보보안학과'}
# {'name': '박남제', '_id': 's303407', 'inst': '제주대학교 일반대학원 컴퓨터교육전공'}
# {'name': '박남제', '_id': 's448307', 'inst': '제주대학교 초등컴퓨터교육과'}
# {'name': '박남제', '_id': 's261215', 'inst': '제주대학교 초등컴퓨터교육전공'}
# {'name': '박남제', '_id': '117585047156', 'inst': '제주대학교'}
# {'name': '박남제', '_id': 's133620', 'inst': '제주대학교'}
# scienceon_id: ['s709660', 's258266', 's104186', 's814226', 's262283', 's303407', 's448307', 's261215']
# ntis_id: s133620
# ----------------------------------------------------82번째   끝----------------------------------------------------
# name: 김현욱 inst: 경희대학교
# ----------------------------------------------------83번째 시작----------------------------------------------------
# {'name': '김현욱', '_id': 's258267', 'inst': '경희대학교 컴퓨터공학과'}
# {'name': '김현욱', '_id': '11436771', 'inst': '경희대학교 산학협력단'}
# scienceon_id: ['s258267']
# ntis_id: 11436771
# ----------------------------------------------------83번째   끝----------------------------------------------------
# name: 최선화 inst: 국립재난안전연구원
# ----------------------------------------------------84번째 시작----------------------------------------------------
# {'name': '최선화', '_id': 's258816', 'inst': '국립재난안전연구원'}
# {'name': '최선화', '_id': 's258275', 'inst': '국립재난안전연구원 재난정보분석센터'}
# {'name': '최선화', '_id': 's258819', 'inst': '국립재난안전연구원 재난정보연구실'}
# {'name': '최선화', '_id': 's258813', 'inst': '국립재난안전연구원 재난정보연구실 CC0187424'}
# {'name': '최선화', '_id': 's258470', 'inst': '안전행정부 국립재난안전연구원'}
# scienceon_id: ['s258816', 's258275', 's258819', 's258813', 's258470']
# ntis_id:
# ----------------------------------------------------84번째   끝----------------------------------------------------
# name: 최우정 inst: 국립재난안전연구원
# ----------------------------------------------------85번째 시작----------------------------------------------------
# {'name': '최우정', '_id': 's267998', 'inst': '국립재난안전연구원'}
# {'name': '최우정', '_id': 's258276', 'inst': '국립재난안전연구원 재난정보분석센터'}
# scienceon_id: ['s267998', 's258276']
# ntis_id:
# ----------------------------------------------------85번째   끝----------------------------------------------------
# name: 이종국 inst: 국립재난안전연구원
# ----------------------------------------------------86번째 시작----------------------------------------------------
# {'name': '이종국', '_id': 's258277', 'inst': '국립재난안전연구원 재난정보분석센터'}
# scienceon_id: ['s258277']
# ntis_id:
# ----------------------------------------------------86번째   끝----------------------------------------------------
# name: 남윤호 inst: 성균관대학교
# ----------------------------------------------------87번째 시작----------------------------------------------------
# {'name': '남윤호', '_id': 's258283', 'inst': '성균관대학교 정보보호연구소'}
# {'name': '남윤호', '_id': '415150218763', 'inst': '성균관대학교 산학협력단'}
# {'name': '남윤호', '_id': '11860254', 'inst': '성균관대학교산학협력단'}
# scienceon_id: ['s258283']
# ntis_id: 11860254
# ----------------------------------------------------87번째   끝----------------------------------------------------
# name: 조승현 inst: 성균관대학교
# ----------------------------------------------------88번째 시작----------------------------------------------------
# {'name': '조승현', '_id': 's258284', 'inst': '성균관대학교 정보보호연구소'}
# {'name': '조승현', '_id': 's1042197', 'inst': '성균관대학교 정보보호연구실'}
# {'name': '조승현', '_id': '605116518633', 'inst': '성균관대학교 산학협력단'}
# {'name': '조승현', '_id': '11444231', 'inst': '성균관대학교산학협력단'}
# {'name': '조승현', '_id': '12398381', 'inst': '성균관대학교산학협력단'}
# scienceon_id: ['s258284', 's1042197']
# ntis_id: 12398381
# ----------------------------------------------------88번째   끝----------------------------------------------------
# name: 문종호 inst: 성균관대학교
# ----------------------------------------------------89번째 시작----------------------------------------------------
# {'name': '문종호', '_id': 's258285', 'inst': '성균관대학교 정보보호연구소'}
# {'name': '문종호', '_id': 's708621', 'inst': '성균관대학교 정보통신대학'}
# {'name': '문종호', '_id': '10237810', 'inst': '성균관대학교 산학협력단'}
# {'name': '문종호', '_id': '584113618112', 'inst': '성균관대학교 산학협력단'}
# scienceon_id: ['s258285', 's708621']
# ntis_id: 584113618112
# ----------------------------------------------------89번째   끝----------------------------------------------------
# name: 정재욱 inst: 성균관대학교
# ----------------------------------------------------90번째 시작----------------------------------------------------
# {'name': '정재욱', '_id': 's270162', 'inst': '성균관대학교'}
# {'name': '정재욱', '_id': 's712361', 'inst': '성균관대학교 기계공학부'}
# {'name': '정재욱', '_id': 's258286', 'inst': '성균관대학교 정보보호연구소'}
# {'name': '정재욱', '_id': 's1042198', 'inst': '성균관대학교 정보보호연구실'}
# {'name': '정재욱', '_id': '816136818826', 'inst': '성균관대학교 산학협력단'}
# scienceon_id: ['s270162', 's712361', 's258286', 's1042198']
# ntis_id: 816136818826
# ----------------------------------------------------90번째   끝----------------------------------------------------
# name: 전웅렬 inst: 성균관대학교
# ----------------------------------------------------91번째 시작----------------------------------------------------
# {'name': '전웅렬', '_id': 's270164', 'inst': '성균관대학교'}
# {'name': '전웅렬', '_id': 's258287', 'inst': '성균관대학교 정보보호연구소'}
# {'name': '전웅렬', '_id': 's709489', 'inst': '성균관대학교 정보통신공학부'}
# {'name': '전웅렬', '_id': 's1036282', 'inst': '성균관대학교 정보통신공학부 정보보호연구소'}
# scienceon_id: ['s270164', 's258287', 's709489', 's1036282']
# ntis_id:
# ----------------------------------------------------91번째   끝----------------------------------------------------
# name: 원동호 inst: 성균관대학교
# ----------------------------------------------------92번째 시작----------------------------------------------------
# {'name': '원동호', '_id': 's270165', 'inst': '성균관대학교'}
# {'name': '원동호', '_id': 's168958', 'inst': '성균관대학교 소프트웨어학과'}
# {'name': '원동호', '_id': 's258288', 'inst': '성균관대학교 정보보호연구소'}
# {'name': '원동호', '_id': 's1042199', 'inst': '성균관대학교 정보보호연구실'}
# {'name': '원동호', '_id': 's308283', 'inst': '성균관대학교 정보통신공학부'}
# {'name': '원동호', '_id': 's1036283', 'inst': '성균관대학교 정보통신공학부 정보보호연구소'}
# {'name': '원동호', '_id': 's1044917', 'inst': '성균관대학교 컴퓨터공학과'}
# {'name': '원동호', '_id': '809116314937', 'inst': '성균관대학교 산학협력단'}
# scienceon_id: ['s270165', 's168958', 's258288', 's1042199', 's308283', 's1036283', 's1044917']
# ntis_id: 809116314937
# ----------------------------------------------------92번째   끝----------------------------------------------------
# name: 홍지혜 inst: 경희대학교
# ----------------------------------------------------93번째 시작----------------------------------------------------
# {'name': '홍지혜', '_id': 's258292', 'inst': '경희대학교 컴퓨터공학과'}
# scienceon_id: ['s258292']
# ntis_id:
# ----------------------------------------------------93번째   끝----------------------------------------------------
# name: 한용구 inst: 경희대학교
# ----------------------------------------------------94번째 시작----------------------------------------------------
# {'name': '한용구', '_id': 's269676', 'inst': '경희대학교 컴퓨터공학'}
# {'name': '한용구', '_id': 's258293', 'inst': '경희대학교 컴퓨터공학과'}
# {'name': '한용구', '_id': '812829847181', 'inst': '경희대학교산학협력단'}
# scienceon_id: ['s269676', 's258293']
# ntis_id: 812829847181
# ----------------------------------------------------94번째   끝----------------------------------------------------
# name: 김용우 inst: 가천대학교
# ----------------------------------------------------95번째 시작----------------------------------------------------
# {'name': '김용우', '_id': 's258296', 'inst': '가천대학교 일반대학원 모바일소프트웨어학과'}
# scienceon_id: ['s258296']
# ntis_id:
# ----------------------------------------------------95번째   끝----------------------------------------------------
# name: 정교성 inst: 솔트룩스
# ----------------------------------------------------96번째 시작----------------------------------------------------
# {'name': '정교성', '_id': 's258331', 'inst': '솔트룩스 전략사업본부'}
# scienceon_id: ['s258331']
# ntis_id:
# ----------------------------------------------------96번째   끝----------------------------------------------------
# name: 김수동 inst: 숭실대학교
# ----------------------------------------------------97번째 시작----------------------------------------------------
# {'name': '김수동', '_id': 's136330', 'inst': '숭실대학교 소프트웨어학과'}
# {'name': '김수동', '_id': 's258332', 'inst': '숭실대학교 컴퓨터학과'}
# {'name': '김수동', '_id': 's296962', 'inst': '숭실대학교 컴퓨터학부'}
# {'name': '김수동', '_id': '818061295184', 'inst': '숭실대학교'}
# scienceon_id: ['s136330', 's258332', 's296962']
# ntis_id: 818061295184
# ----------------------------------------------------97번째   끝----------------------------------------------------
# name: 임종태 inst: 충북대학교
# ----------------------------------------------------98번째 시작----------------------------------------------------
# {'name': '임종태', '_id': 's262205', 'inst': '충북대학교'}
# {'name': '임종태', '_id': 's258826', 'inst': '충북대학교 정보통신공학'}
# {'name': '임종태', '_id': 's258361', 'inst': '충북대학교 정보통신공학과'}
# {'name': '임종태', '_id': 's259871', 'inst': '충북대학교 정보통신공학부'}
# {'name': '임종태', '_id': 's258098', 'inst': '충북대학교 정보통신공학부 및 충북BIT연구중심대학육성사업단'}
# {'name': '임종태', '_id': 's260966', 'inst': '충북대학교 정보통신학과'}
# scienceon_id: ['s262205', 's258826', 's258361', 's259871', 's258098', 's260966']
# ntis_id:
# ----------------------------------------------------98번째   끝----------------------------------------------------
# name: 이민호 inst: 한국과학기술정보연구원
# ----------------------------------------------------99번째 시작----------------------------------------------------
# {'name': '이민호', '_id': 's258364', 'inst': '한국과학기술정보연구원'}
# {'name': '이민호', '_id': 's187621', 'inst': '한국과학기술정보연구원 생명의료HPC연구센터'}
# {'name': '이민호', '_id': 's259555', 'inst': '한국과학기술정보연구원 생명의료HPC연구센터/과학기술연합대학원대학교 빅데이터과학'}
# {'name': '이민호', '_id': 's1067795', 'inst': '한국과학기술정보연구원 소프트웨어 연구실'}
# {'name': '이민호', '_id': 's258440', 'inst': '한국과학기술정보연구원 소프트웨어연구센터 과학기술마이닝팀'}
# {'name': '이민호', '_id': 's257824', 'inst': '한국과학기술정보연구원 소프트웨어연구실'}
# {'name': '이민호', '_id': 's263592', 'inst': '한국과학기술정보연구원 정보기술연구실'}
# scienceon_id: ['s258364', 's187621', 's259555', 's1067795', 's258440', 's257824', 's263592']
# ntis_id:
# ----------------------------------------------------99번째   끝----------------------------------------------------
# name: 김지은 inst: 국민대학교
# ----------------------------------------------------100번째 시작----------------------------------------------------
# {'name': '김지은', '_id': 's258434', 'inst': '국민대학교 Business IT 전문대학원'}
# {'name': '김지은', '_id': '601211518791', 'inst': '국민대학교 산학협력단'}
# {'name': '김지은', '_id': '12531773', 'inst': '국민대학교산학협력단'}
# ...
# scienceon_id: []
# ntis_id: s55140
# ----------------------------------------------------1343번째   끝----------------------------------------------------
# name: 최윤선 inst: 경희대학교
# ----------------------------------------------------1344번째 시작----------------------------------------------------
# {'name': '최윤선', '_id': 's55170', 'inst': '경희대학교 관광산업연구원'}
# scienceon_id: []
# ntis_id: s55170
# ----------------------------------------------------1344번째   끝----------------------------------------------------
# name: 홍태호 inst: 부산대학교
# ----------------------------------------------------1345번째 시작----------------------------------------------------
# {'name': '홍태호', '_id': 's259065', 'inst': '부산대학교 경영대학'}
# {'name': '홍태호', '_id': 's270327', 'inst': '부산대학교 경영학과'}
# {'name': '홍태호', '_id': 's55171', 'inst': '부산대학교'}
# {'name': '홍태호', '_id': '820402747102', 'inst': '부산대학교'}
# scienceon_id: ['s259065', 's270327']
# ntis_id: 820402747102
# ----------------------------------------------------1345번째   끝----------------------------------------------------
# name: 정경희 inst: 전남대학교
# ----------------------------------------------------1346번째 시작----------------------------------------------------
# {'name': '정경희', '_id': 's55208', 'inst': '전남대학교'}
# scienceon_id: []
# ntis_id: s55208
# ----------------------------------------------------1346번째   끝----------------------------------------------------
# name: 이건학 inst: 서울대학교
# ----------------------------------------------------1347번째 시작----------------------------------------------------
# {'name': '이건학', '_id': 's258499', 'inst': '서울대학교 지리학과, 국토문제연구소'}
# {'name': '이건학', '_id': 's55209', 'inst': '서울대학교'}
# {'name': '이건학', '_id': '217780137170', 'inst': '서울대학교'}
# {'name': '이건학', '_id': '839111129112', 'inst': '서울대학교산학협력단'}
# scienceon_id: ['s258499']
# ntis_id: 839111129112
# ----------------------------------------------------1347번째   끝----------------------------------------------------
# name: 주하연 inst: 서강대학교
# ----------------------------------------------------1348번째 시작----------------------------------------------------
# {'name': '주하연', '_id': 's55211', 'inst': '서강대학교'}
# {'name': '주하연', '_id': '214606537271', 'inst': '서강대학교산학협력단'}
# scienceon_id: []
# ntis_id: 214606537271
# ----------------------------------------------------1348번째   끝----------------------------------------------------
# name: 조용란 inst: 한서대학교
# ----------------------------------------------------1349번째 시작----------------------------------------------------
# {'name': '조용란', '_id': 's55212', 'inst': '한서대학교'}
# scienceon_id: []
# ntis_id: s55212
# ----------------------------------------------------1349번째   끝----------------------------------------------------
# name: 이미경 inst: 계명대학교
# ----------------------------------------------------1350번째 시작----------------------------------------------------
# {'name': '이미경', '_id': 's55229', 'inst': '계명대학교'}
# scienceon_id: []
# ntis_id: s55229
# ----------------------------------------------------1350번째   끝----------------------------------------------------
# name: 강보라 inst: 한국예술종합학교
# ----------------------------------------------------1351번째 시작----------------------------------------------------
# {'name': '강보라', '_id': 's55234', 'inst': '한국예술종합학교'}
# scienceon_id: []
# ntis_id: s55234
# ----------------------------------------------------1351번째   끝----------------------------------------------------
# name: 이태원 inst: 경남과학기술대학교
# ----------------------------------------------------1352번째 시작----------------------------------------------------
# {'name': '이태원', '_id': 's55242', 'inst': '경남과학기술대학교'}
# scienceon_id: []
# ntis_id: s55242
# ----------------------------------------------------1352번째   끝----------------------------------------------------
# name: 이홍주 inst: 가톨릭대학교
# ----------------------------------------------------1353번째 시작----------------------------------------------------
# {'name': '이홍주', '_id': 's822537', 'inst': '가톨릭대학교'}
# {'name': '이홍주', '_id': 's597125', 'inst': '가톨릭대학교 경영학'}
# {'name': '이홍주', '_id': 's91305', 'inst': '가톨릭대학교 경영학과'}
# {'name': '이홍주', '_id': 's270427', 'inst': '가톨릭대학교 경영학부'}
# {'name': '이홍주', '_id': 's352395', 'inst': '가톨릭대학교 경영학전공'}
# {'name': '이홍주', '_id': 's55244', 'inst': '가톨릭대학교'}
# scienceon_id: ['s822537', 's597125', 's91305', 's270427', 's352395']
# ntis_id: s55244
# ----------------------------------------------------1353번째   끝----------------------------------------------------
# name: 김은미 inst: 부산대학교
# ----------------------------------------------------1354번째 시작----------------------------------------------------
# {'name': '김은미', '_id': 's259064', 'inst': '부산대학교 경영대학'}
# {'name': '김은미', '_id': 's55248', 'inst': '부산대학교'}
# {'name': '김은미', '_id': 's55350', 'inst': '부산대학교 중국연구소'}
# scienceon_id: ['s259064']
# ntis_id: s55350
# ----------------------------------------------------1354번째   끝----------------------------------------------------
# name: 한진수 inst: 경희대학교
# ----------------------------------------------------1355번째 시작----------------------------------------------------
# {'name': '한진수', '_id': 's55249', 'inst': '경희대학교'}
# scienceon_id: []
# ntis_id: s55249
# ----------------------------------------------------1355번째   끝----------------------------------------------------
# name: 안순태 inst: 이화여자대학교
# ----------------------------------------------------1356번째 시작----------------------------------------------------
# {'name': '안순태', '_id': 's55251', 'inst': '이화여자대학교'}
# scienceon_id: []
# ntis_id: s55251
# ----------------------------------------------------1356번째   끝----------------------------------------------------
# name: 이성민 inst: 한국해양대학교
# ----------------------------------------------------1357번째 시작----------------------------------------------------
# {'name': '이성민', '_id': 's55255', 'inst': '한국해양대학교'}
# scienceon_id: []
# ntis_id: s55255
# ----------------------------------------------------1357번째   끝----------------------------------------------------
# name: 김연종 inst: 경상대학교
# ----------------------------------------------------1358번째 시작----------------------------------------------------
# {'name': '김연종', '_id': 's315956', 'inst': '경상대학교 경영대학 경영정보학과'}
# {'name': '김연종', '_id': 's1027946', 'inst': '경상대학교 경영정보학과'}
# {'name': '김연종', '_id': 's55264', 'inst': '경상대학교'}
# scienceon_id: ['s315956', 's1027946']
# ntis_id: s55264
# ----------------------------------------------------1358번째   끝----------------------------------------------------
# name: 정남호 inst: 경희대학교
# ----------------------------------------------------1359번째 시작----------------------------------------------------
# {'name': '정남호', '_id': 's304253', 'inst': '경희대학교 호텔경영학과'}
# {'name': '정남호', '_id': 's525246', 'inst': '경희대학교 호텔관광대학'}
# {'name': '정남호', '_id': 's55278', 'inst': '경희대학교'}
# {'name': '정남호', '_id': '416501617112', 'inst': '경희대학교 산학협력단'}
# scienceon_id: ['s304253', 's525246']
# ntis_id: 416501617112
# ----------------------------------------------------1359번째   끝----------------------------------------------------
# name: 장원호 inst: 서울시립대학교
# ----------------------------------------------------1360번째 시작----------------------------------------------------
# {'name': '장원호', '_id': 's55280', 'inst': '서울시립대학교'}
# scienceon_id: []
# ntis_id: s55280
# ----------------------------------------------------1360번째   끝----------------------------------------------------
# name: 김학선 inst: 경성대학교
# ----------------------------------------------------1361번째 시작----------------------------------------------------
# {'name': '김학선', '_id': 's261103', 'inst': '경성대학교 호텔관광외식경영학과'}
# {'name': '김학선', '_id': 's260226', 'inst': '경성대학교 호텔관광외식경영학부'}
# {'name': '김학선', '_id': 's55286', 'inst': '경성대학교'}
# scienceon_id: ['s261103', 's260226']
# ntis_id: s55286
# ----------------------------------------------------1361번째   끝----------------------------------------------------
# name: 이제욱 inst: 중앙대학교
# ----------------------------------------------------1362번째 시작----------------------------------------------------
# {'name': '이제욱', '_id': 's55290', 'inst': '중앙대학교'}
# scienceon_id: []
# ntis_id: s55290
# ----------------------------------------------------1362번째   끝----------------------------------------------------
# name: 백욱인 inst: 서울과학기술대학교
# ----------------------------------------------------1363번째 시작----------------------------------------------------
# {'name': '백욱인', '_id': 's55292', 'inst': '서울과학기술대학교'}
# {'name': '백욱인', '_id': '818700735170', 'inst': '서울과학기술대학교'}
# scienceon_id: []
# ntis_id: 818700735170
# ----------------------------------------------------1363번째   끝----------------------------------------------------
# name: 김재훈 inst: 한국해양대학교
# ----------------------------------------------------1364번째 시작----------------------------------------------------
# {'name': '김재훈', '_id': 's258306', 'inst': '한국해양대학교'}
# {'name': '김재훈', '_id': 's593846', 'inst': '한국해양대학교 IT공학부'}
# {'name': '김재훈', '_id': 's269949', 'inst': '한국해양대학교 컴퓨터공학과'}
# {'name': '김재훈', '_id': 's579568', 'inst': '한국해양대학교, NLP연구실'}
# {'name': '김재훈', '_id': 's264155', 'inst': '한국해양대학교, 컴퓨터공학과'}
# {'name': '김재훈', '_id': 's1056781', 'inst': '한국해양대학교, 컴퓨터정보공학과'}
# {'name': '김재훈', '_id': 's55300', 'inst': '한국해양대학교'}
# {'name': '김재훈', '_id': '115170117177', 'inst': '한국해양대학교산학협력단'}
# scienceon_id: ['s258306', 's593846', 's269949', 's579568', 's264155', 's1056781']
# ntis_id: 115170117177
# ----------------------------------------------------1364번째   끝----------------------------------------------------
# name: 허진희 inst: 서울대학교
# ----------------------------------------------------1365번째 시작----------------------------------------------------
# {'name': '허진희', '_id': 's55304', 'inst': '서울대학교'}
# scienceon_id: []
# ntis_id: s55304
# ----------------------------------------------------1365번째   끝----------------------------------------------------
# name: 이계희 inst: 경희대학교
# ----------------------------------------------------1366번째 시작----------------------------------------------------
# {'name': '이계희', '_id': 's55307', 'inst': '경희대학교'}
# scienceon_id: []
# ntis_id: s55307
# ----------------------------------------------------1366번째   끝----------------------------------------------------
# name: 남궁영 inst: 경희대학교
# ----------------------------------------------------1367번째 시작----------------------------------------------------
# {'name': '남궁영', '_id': 's55311', 'inst': '경희대학교'}
# scienceon_id: []
# ntis_id: s55311
# ----------------------------------------------------1367번째   끝----------------------------------------------------
# name: 김태경 inst: 수원대학교
# ----------------------------------------------------1368번째 시작----------------------------------------------------
# {'name': '김태경', '_id': 's694202', 'inst': '수원대학교'}
# {'name': '김태경', '_id': 's55316', 'inst': '수원대학교'}
# scienceon_id: ['s694202']
# ntis_id: s55316
# ----------------------------------------------------1368번째   끝----------------------------------------------------
# name: 김경재 inst: 동국대학교
# ----------------------------------------------------1369번째 시작----------------------------------------------------
# {'name': '김경재', '_id': 's564205', 'inst': '동국대학교 경영정보학과'}
# {'name': '김경재', '_id': 's178572', 'inst': '동국대학교_서울 경영대학 경영정보학과'}
# {'name': '김경재', '_id': 's1087164', 'inst': '동국대학교_서울 경영대학 경영학부'}
# {'name': '김경재', '_id': 's653726', 'inst': '동국대학교_서울 경영정보학과'}
# {'name': '김경재', '_id': 's582535', 'inst': '동국대학교_서울 경영학부'}
# {'name': '김경재', '_id': 's55323', 'inst': '동국대학교'}
# {'name': '김경재', '_id': '110216107100', 'inst': '동국대학교 산학협력단'}
# {'name': '김경재', '_id': '12638052', 'inst': '동국대학교산학협력단'}
# scienceon_id: ['s564205', 's178572', 's1087164', 's653726', 's582535']
# ntis_id: 12638052
# ----------------------------------------------------1369번째   끝----------------------------------------------------
# name: 전여선 inst: 서울대학교
# ----------------------------------------------------1370번째 시작----------------------------------------------------
# {'name': '전여선', '_id': 's55337', 'inst': '서울대학교 생활과학연구소'}
# scienceon_id: []
# ntis_id: s55337
# ----------------------------------------------------1370번째   끝----------------------------------------------------
# name: 신동희 inst: 중앙대학교
# ----------------------------------------------------1371번째 시작----------------------------------------------------
# {'name': '신동희', '_id': 's480461', 'inst': '중앙대학교 미디어커뮤니케이션학부'}
# {'name': '신동희', '_id': 's55340', 'inst': '중앙대학교'}
# scienceon_id: ['s480461']
# ntis_id: s55340
# ----------------------------------------------------1371번째   끝----------------------------------------------------
# name: 장완규 inst: 용인송담대학교
# ----------------------------------------------------1372번째 시작----------------------------------------------------
# {'name': '장완규', '_id': 's55343', 'inst': '용인송담대학교'}
# scienceon_id: []
# ntis_id: s55343
# ----------------------------------------------------1372번째   끝----------------------------------------------------
# name: 조은경 inst: 경북대학교
# ----------------------------------------------------1373번째 시작----------------------------------------------------
# {'name': '조은경', '_id': 's1028511', 'inst': '경북대학교 농업생명과학대학 임학과'}
# {'name': '조은경', '_id': 's55345', 'inst': '경북대학교'}
# scienceon_id: ['s1028511']
# ntis_id: s55345
# ----------------------------------------------------1373번째   끝----------------------------------------------------
# name: 김기홍 inst: 한국외국어대학교
# ----------------------------------------------------1374번째 시작----------------------------------------------------
# {'name': '김기홍', '_id': 's55346', 'inst': '한국외국어대학교'}
# scienceon_id: []
# ntis_id: s55346
# ----------------------------------------------------1374번째   끝----------------------------------------------------
# name: 황용석 inst: 건국대학교
# ----------------------------------------------------1375번째 시작----------------------------------------------------
# {'name': '황용석', '_id': 's55352', 'inst': '건국대학교'}
# scienceon_id: []
# ntis_id: s55352
# ----------------------------------------------------1375번째   끝----------------------------------------------------
# name: 박경옥 inst: 부산대학교
# ----------------------------------------------------1376번째 시작----------------------------------------------------
# {'name': '박경옥', '_id': 's55367', 'inst': '부산대학교'}
# scienceon_id: []
# ntis_id: s55367
# ----------------------------------------------------1376번째   끝----------------------------------------------------
# name: 강상훈 inst: 부산대학교
# ----------------------------------------------------1377번째 시작----------------------------------------------------
# {'name': '강상훈', '_id': 's55375', 'inst': '부산대학교'}
# scienceon_id: []
# ntis_id: s55375
# ----------------------------------------------------1377번째   끝----------------------------------------------------
# name: 이금실 inst: 세종대학교
# ----------------------------------------------------1378번째 시작----------------------------------------------------
# {'name': '이금실', '_id': 's55378', 'inst': '세종대학교'}
# scienceon_id: []
# ntis_id: s55378
# ----------------------------------------------------1378번째   끝----------------------------------------------------
# name: 박주석 inst: 경희대학교
# ----------------------------------------------------1379번째 시작----------------------------------------------------
# {'name': '박주석', '_id': 's260343', 'inst': '경희대학교'}
# {'name': '박주석', '_id': 's259645', 'inst': '경희대학교 경영대학'}
# {'name': '박주석', '_id': 's259431', 'inst': '경희대학교 경영학과'}
# {'name': '박주석', '_id': 's55387', 'inst': '경희대학교'}
# scienceon_id: ['s260343', 's259645', 's259431']
# ntis_id: s55387
# ----------------------------------------------------1379번째   끝----------------------------------------------------
# name: 한상용 inst: 중앙대학교
# ----------------------------------------------------1380번째 시작----------------------------------------------------
# {'name': '한상용', '_id': 's55391', 'inst': '중앙대학교'}
# {'name': '한상용', '_id': '312008065127', 'inst': '중앙대학교'}
# {'name': '한상용', '_id': 's72557', 'inst': '중앙대학교 산학협력단'}
# scienceon_id: []
# ntis_id: s72557
# ----------------------------------------------------1380번째   끝----------------------------------------------------
# name: 조화순 inst: 연세대학교
# ----------------------------------------------------1381번째 시작----------------------------------------------------
# {'name': '조화순', '_id': 's270104', 'inst': '연세대학교 정치외교학과'}
# {'name': '조화순', '_id': 's72544', 'inst': '연세대학교'}
# {'name': '조화순', '_id': '886290336243', 'inst': '연세대학교'}
# scienceon_id: ['s270104']
# ntis_id: 886290336243
# ----------------------------------------------------1381번째   끝----------------------------------------------------

# %%
ab = scienceon_aut.find({'$and':[{'name': '송재오'},{'inst':{'$regex':'(주)케이아이씨티'}}]})

for a in ab:
    print(a)
