# %%
from pymongo import MongoClient

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
sco_exfa = client['SCIENCEON']['ExpertFactor']
sco_aut = client['SCIENCEON']['Author']

ntis_exfa = client['NTIS']['ExpertFactor']
ntis_aut = client['NTIS']['Author']
ntis_row = client['NTIS']['Rawdata']

dbpia_exfa = client['DBPIA']['ExpertFactor']
dbpia_aut = client['DBPIA']['Author']

id_domestic = client['ID']['Domestic']

keyid = 588 #input

sco_key_query = sco_exfa.find({ 'keyId' : keyid })
ntis_key_query = ntis_exfa.find({ 'keyId' : keyid })
dbpia_key_query = dbpia_exfa.find({ 'keyId' : keyid })

key_querys = [sco_key_query, ntis_key_query, dbpia_key_query]
#key_querys = [ntis_key_query]
auts = [sco_aut, ntis_aut, dbpia_aut]
site = ['Scienceon', 'NTIS', 'DBPIA']

a_id = []
all_name_inst = []
all_name = []
all_inst = []
all_site = []
reCopy = []
reCopy_site = []
reCopy_aid = []
Answer_list = []
Answer_dict = {}

for i in range(len(key_querys)):
    #print(key_querys[i])
    for key_query in key_querys[i]:
        a_id.append(key_query['A_ID'])


        if site[i] == 'NTIS' : 
            # if "11638621" == a_id[-1] :
            #print("check")
            ntis_key_query1 = ntis_row.find_one({'$and':[{'keyId':keyid},{'mngId':a_id[-1]}]})
            #print(ntis_key_query1)

            if ntis_key_query1 == None :
            #print("check2")
                continue
            
        aut_query = auts[i].find_one({'_id':key_query['A_ID']})
        #print(aut_query)
        a_id.append(key_query['A_ID'])
        #all_name_inst.append(aut_query['name'] + '/' + aut_query['inst'])
        all_name.append(aut_query['name'])
        all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_site.append(site[i])
        if all_name[-1] == '송재오' :
            print(aut_query['inst'])
        Answer = {'name' : all_name[-1], site[i] : all_inst[-1] }
   
        if all_name[-1] not in Answer_dict and all_name[-1]+'0' not in Answer_dict :
            Answer_dict[all_name[-1]] = Answer
         #   print("insert")
        else :
            
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]

              
                if tempName in Answer_dict :        # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+str(count)  # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                       # print(tempName)
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]):
                            src = temp[key]
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]):
                            src = all_inst[-1]
                            tgt = temp[key]
                        # if tempName == '김영미' :
                        #     print(all_inst[-1], temp[key])
                        #     print(ssrc, ttgt)


                        if key == site[i] :# 사이트가 동일할때
                            if temp[key] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                                flag = False
                                break
                            elif all_name[-1]+str(count+1) not in Answer_dict :
                                Answer_dict[all_name[-1]+str(count+1)] = Answer
                                #if tempName != all_name[-1] :
                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key] == all_inst[-1] or (src != "" and src in tgt):  # 소속 같을때
                                #if len(src) == 0:
                                 #   flag = False
                                #else:
                                    Answer_dict[tempName][site[i]] = all_inst[-1]
                                    flag = False
                                    break
                            
                            elif all_name[-1]+str(count+1) not in Answer_dict :
                                Answer_dict[all_name[-1]+str(count+1)] = Answer
                                #if tempName != all_name[-1] :
                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'0'] = temp
                                    del Answer_dict[all_name[-1]]   

                count += 1


        # Answer_list.append(Answer)

#Answer_list.sort()
#print(len(Answer_dict))
print(Answer_dict)
#print(sorted(Answer_dict.items()))
# Out:
# (주) 제오시스 기업부설연구소
# 제오시스 기업부설연구소
# {'천탠이': {'name': '천탠이', 'Scienceon': '한양대학교'}, '이규혜': {'name': '이규혜', 'Scienceon': '한양대학교'}, '김기현': {'name': '김기현', 'Scienceon': '성신여자대학교'}, '변혜원': {'name': '변혜원', 'Scienceon': '성신여자대학교'}, '양재식': {'name': '양재식', 'Scienceon': '서원대학교'}, '륙치금': {'name': '륙치금', 'Scienceon': '부경대학교'}, '남인용': {'name': '남인용', 'Scienceon': '부경대학교'}, '한정섭': {'name': '한정섭', 'Scienceon': '남서울대학교'}, '권두순': {'name': '권두순', 'Scienceon': '청운대학교'}, '김성준': {'name': '김성준', 'Scienceon': '남서울대학교'}, '권혜민': {'name': '권혜민', 'Scienceon': '서울여자대학교'}, '이인수': {'name': '이인수', 'Scienceon': '대검찰청'}, '이승훈': {'name': '이승훈', 'Scienceon': '대검찰청'}, '노영희': {'name': '노영희', 'Scienceon': '건국대학교'}, '진찬용': {'name': '진찬용', 'Scienceon': 'Wonkwang'}, '남수태': {'name': '남수태', 'Scienceon': 'Wonkwang'}, '박재열': {'name': '박재열', 'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}, '이준기': {'name': '이준기', 'Scienceon': '연세대학교'}, '최도진': {'name': '최도진', 'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}, '우경숙': {'name': '우경숙', 'Scienceon': '경희대학교'}, 'Shin, Seong-Yoon': {'name': 'Shin, Seong-Yoon', 'Scienceon': 'School'}, '서동민': {'name': '서동민', 'Scienceon': '한국과학기술정보연구원', 'DBPIA': '한국과학기술정보연구원'}, '최은정': {'name': '최은정', 'Scienceon': '서울여자대학교'}, '김명주': {'name': '김명주', 'Scienceon': '서울여자대학교'}, '정영섭': {'name': '정영섭', 'Scienceon': '순천향대학교'}, '문재영': {'name': '문재영', 'Scienceon': '동서대학교'}, '설상훈': {'name': '설상훈', 'Scienceon': 'Interdisciplinary'}, '성기훈': {'name': '성기훈', 'Scienceon': 'Department'}, '박수빈': {'name': '박수빈', 'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}, '송재오': {'name': '송재오', 'Scienceon': '제오시스', 'DBPIA': '제오시스'}, '남윤재': {'name': '남윤재', 'Scienceon': '경희대학교'}, '박진홍': {'name': '박진홍', 'Scienceon': '경희대학교', 'DBPIA': '경희대학교'}, '김홍광': {'name': '김홍광', 'Scienceon': '건국대학교'}, '안종욱': {'name': '안종욱', 'Scienceon': '안양대학교'}, '김태연': {'name': '김태연', 'Scienceon': '건국대학교'}, '정대근': {'name': '정대근', 'Scienceon': '전남대학교'}, '이광희': {'name': '이광희', 'Scienceon': '한국연구재단'}, '신현보': {'name': '신현보', 'Scienceon': '연세대학교'}, '선형주': {'name': '선형주', 'Scienceon': '연세대학교'}, '복경수1': {'name': '복경수', 'Scienceon': '원광대학교', 'DBPIA': '원광대학교'}, '복경수0': {'name': '복경수', 'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}, '홍주현': {'name': '홍주현', 'Scienceon': '국민대학교', 'DBPIA': '국민대학교'}, '김경희': {'name': '김경희', 'Scienceon': '한림대학교'}, '김아연': {'name': '김아연', 'Scienceon': '서울시립대학교', 'DBPIA': '서울시립대학교'}, '김한나': {'name': '김한나', 'Scienceon': '순천향대학교'}, '장윤선': {'name': '장윤선', 'Scienceon': '국립산림과학원'}, '유리화': {'name': '유리화', 'Scienceon': '국립산림과학원'}, '황석환': {'name': '황석환', 'Scienceon': '한국건설기술연구원', 'DBPIA': '한국건설기술연구원'}, '이정하1': {'name': '이정하', 'Scienceon': '한국건설기술연구원', 'DBPIA': '한국건설기술연구원'}, '이정하0': {'name': '이정하', 'Scienceon': '과학기술연합대학원대학교'}, '최호성': {'name': '최호성', 'Scienceon': '한국산학연협회'}, '이수련': {'name': '이수련', 'Scienceon': '서울여자대학교'}, '최영현': {'name': '최영현', 'Scienceon': '한양대학교'}, 'Sim, Ji-Soo': {'name': 'Sim, Ji-Soo', 'Scienceon': '국토연구원'}, 'Oh, Chang Song': {'name': 'Oh, Chang Song', 'Scienceon': '영남대학교'}, '하상현': {'name': '하상현', 'Scienceon': '비투인'}, '노태협': {'name': '노태협', 'Scienceon': '덕성여자대학교'}, '서일정': {'name': '서일정', 'Scienceon': '경기대학교'}, '조재희': {'name': '조재희', 'Scienceon': '광운대학교', 'DBPIA': '광운대학교'}, '김유나': {'name': '김유나', 'Scienceon': '서울예술대학교'}, '한상필': {'name': '한상필', 'Scienceon': '한양대학교'}, '김도형': {'name': '김도형', 'Scienceon': '성균관대학교'}, '구자환': {'name': '구자환', 'Scienceon': '성균관대학교'}, '김응모': {'name': '김응모', 'Scienceon': '성균관대학교'}, 'Nam, Soo-Tai': {'name': 'Nam, Soo-Tai', 'Scienceon': 'Institute'}, 'Jin, Chan-Yong': {'name': 'Jin, Chan-Yong', 'Scienceon': 'Division'}, '이새봄': {'name': '이새봄', 'Scienceon': '경희대학교'}, '김태구': {'name': '김태구', 'NTIS': '한밭대학교'}, '김윤학': {'name': '김윤학', 'NTIS': '조선대학교'}, '이강희': {'name': '이강희', 'NTIS': '숭실대학교'}, '권혁윤': {'name': '권혁윤', 'NTIS': '서울과학기술대학교', 'DBPIA': '서울과학기술대학교'}, '강상우': {'name': '강상우', 'NTIS': '가천대학교'}, '이민혁': {'name': '이민혁', 'NTIS': '부산대학교'}, '신기정': {'name': '신기정', 'NTIS': '한국과학기술원'}, '황지영': {'name': '황지영', 'NTIS': '성균관대학교(자연과학캠퍼스)', 'DBPIA': '성균관대학교'}, '권영우': {'name': '권영우', 'NTIS': '경북대학교'}, '홍소윤': {'name': '홍소윤', 'NTIS': '연세대학교'}, '김성민': {'name' ...

# %%
import json

answer = None
numCor = 0
numErr = 0
answerCounter = {}


def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter
    flag = True

    numK = len(result.keys())   
    if numK-1 != len(answer[name].keys()) : #site 개수 다르면 false
        flag = False
    else :
        for site in result.keys() :
            if site != 'name' : # site name이 다르면
                if site not in answer[name].keys() or result[site] not in answer[name][site] : #answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]): # result key와 answer key가 다르면
                    flag = False
                # elif answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]: 
                #     flag = False
                    # if numK > 2: # site가 2개 이상이면(name 포함 3개이상이면)
                    # if answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0] :
                    #         flag = False
                    # else :
                    #     if answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]:
                    #         flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
        print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        if len(answer[name].keys()) > 1 :
            numErr += 1
    return flag

with open('answer.json', 'r',encoding='UTF8') as a_json :


    answer = json.load(a_json)
    numAns = print(len(answer))
    
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        #print(test)

        name = Answer_dict[test]['name']
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            while name+str(count) in answer :
                # if name+count in answer :
                print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")

    tempCount = 0
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            tempCount += 1
            print(key)
            print(answer[key])
    print(tempCount)
# Out:
# 1802
# Check 복경수0
# Check 복경수0
# Not Correct
#  - Answer : {'Scienceon': '원광대학교', 'DBPIA': '원광대학교'}
#  - Result : {'name': '복경수', 'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
# Check 복경수1
# Check 이정하0
# Not Correct
#  - Answer : {'Scienceon': '과학기술연합대학원대학교 건설환경공학과'}
#  - Result : {'name': '이정하', 'Scienceon': '한국건설기술연구원', 'DBPIA': '한국건설기술연구원'}
# Check 이정하1
# Check 이정하0
# Check 구철모0
# Check 서주환0
# Not Correct
#  - Answer : {'Scienceon': '경희대학교 예술.디자인대학 환경조경디자인학과'}
#  - Result : {'name': '서주환', 'DBPIA': '한국과학기술정보연구원'}
# Check 서주환1
# Check 서주환0
# Not Correct
#  - Answer : {'Scienceon': 'Department of IT Management, Kosin University', 'DBPIA': '고신대학교'}
#  - Result : {'name': '반재훈', 'DBPIA': '고신대학교'}
# Not Correct
#  - Answer : {'Scienceon': 'Department of IT Management, Kosin University', 'DBPIA': '고신대학교'}
#  - Result : {'name': '반재훈', 'Scienceon': 'Department'}
# Check 이정하0
# Not Correct
#  - Answer : {'Scienceon': '과학기술연합대학원대학교 건설환경공학과'}
#  - Result : {'name': '이정하', 'DBPIA': '세명대학교'}
# Check 이정하1
# Not Correct
#  - Answer : {'Scienceon': '한국건설기술연구원', 'DBPIA': '한국건설기술연구원'}
#  - Result : {'name': '이정하', 'DBPIA': '세명대학교'}
# Check 이정하2
# Check 이승헌0
# Check 이승헌0
# Not Correct
#  - Answer : {'DBPIA': '육군 종합정비창 정비기술연구소'}
#  - Result : {'name': '이승헌', 'DBPIA': '한국HCI학회'}
# Check 이승헌1
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '창원대학교'}
# Check 이지현1
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 사범대학 교직과'}
#  - Result : {'name': '이지현', 'DBPIA': '창원대학교'}
# Check 이지현2
# Not Correct
#  - Answer : {'DBPIA': '대한토목학회'}
#  - Result : {'name': '이지현', 'DBPIA': '창원대학교'}
# Check 이지현3
# Check 이지현0
# Not Correct
#  - Answer : {'Scienceon': 'Department of Broadcasting & Image, Kyungnam College of Information & Technology', 'DBPIA': '경남정보대학교'}
#  - Result : {'name': '하종수', 'DBPIA': '경남정보대학교'}
# Not Correct
#  - Answer : {'Scienceon': 'Department of Broadcasting & Image, Kyungnam College of Information & Technology', 'DBPIA': '경남정보대학교'}
#  - Result : {'name': '하종수', 'Scienceon': 'Department'}
# Check 김민정0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김민정', 'DBPIA': '한국외국어대학교'}
# Check 김민정1
# Not Correct
#  - Answer : {'DBPIA': '법학평론 사회과학대학 미디어커뮤니케이션 학부'}
#  - Result : {'name': '김민정', 'DBPIA': '한국외국어대학교'}
# Check 김민정2
# Check 김민정0
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은2
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 글로벌혁신전략연구본부'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은3
# Not Correct
#  - Answer : {'DBPIA': '성균관대학교 인터랙션사이언스학과'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은4
# Not Correct
#  - Answer : {'DBPIA': '숙명여자대학교 법학부'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은5
# Check 김지은0
# Check 김정은0
# Not Correct
#  - Answer : {'NTIS': '공주대학교'}
#  - Result : {'name': '김정은', 'DBPIA': '한국교통연구원'}
# Check 김정은1
# Check 김정은0
# Check 이정민0
# Not Correct
#  - Answer : {'DBPIA': '부경대학교 대학원 신문방송학과'}
#  - Result : {'name': '이정민', 'DBPIA': '한국농촌경제연구원'}
# Check 이정민1
# Check 이정민0
# Check 조정현0
# Not Correct
#  - Answer : {'DBPIA': '인제대학교 간호학과･건강과학연구소'}
#  - Result : {'name': '조정현', 'DBPIA': '제오시스'}
# Check 조정현1
# Check 조정현0
# Check 김경회0
# Not Correct
#  - Answer : {'DBPIA': '국제디지털대학교'}
#  - Result : {'name': '김경회', 'DBPIA': '국제사이버대학교'}
# Check 김경회1
# Check 김경회0
# Check 정우성0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'name': '정우성', 'DBPIA': '국토연구원'}
# Check 정우성1
# Check 정우성0
# Check 김민정0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김민정', 'DBPIA': '법학평론'}
# Check 김민정1
# Check 이지은0
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 행정문제연구소'}
#  - Result : {'name': '이지은', 'DBPIA': '중앙대학교'}
# Check 이지은1
# Check 이지은0
# Check 김호용0
# Not Correct
#  - Answer : {'Scienceon': '한국과학기술정보연구원'}
#  - Result : {'name': '김호용', 'DBPIA': 'Yeungjin'}
# Check 김호용1
# Check 김호용0
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '경기대학교'}
# Check 김민경1
# Check 김민경0
# Check 김정훈0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김정훈', 'DBPIA': '한국방송광고진흥공사'}
# Check 김정훈1
# Check 김정훈0
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '서울대학교'}
# Check 김지영1
# Not Correct
#  - Answer : {'DBPIA': '동아대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '서울대학교'}
# Check 김지영2
# Not Correct
#  - Answer : {'DBPIA': '상명대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '서울대학교'}
# Check 김지영3
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영1
# Not Correct
#  - Answer : {'DBPIA': '동아대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영2
# Not Correct
#  - Answer : {'DBPIA': '상명대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영3
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 국제문제연구소'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영4
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '건국대학교'}
# Check 이지현1
# Check 한정훈0
# Check 한정훈0
# Not Correct
#  - Answer : {'DBPIA': '한국농촌경제연구원'}
#  - Result : {'name': '한정훈', 'DBPIA': '한국사회체육학회'}
# Check 한정훈1
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '소노엠'}
# Check 김민경1
# Not Correct
#  - Answer : {'DBPIA': '경기대학교 외식조리학과'}
#  - Result : {'name': '김민경', 'DBPIA': '소노엠'}
# Check 김민경2
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '숙명여자대학교'}
# Check 김민경1
# Not Correct
#  - Answer : {'DBPIA': '경기대학교 외식조리학과'}
#  - Result : {'name': '김민경', 'DBPIA': '숙명여자대학교'}
# Check 김민경2
# Not Correct
#  - Answer : {'DBPIA': '소노엠 Department of Research&Development Center'}
#  - Result : {'name': '김민경', 'DBPIA': '숙명여자대학교'}
# Check 김민경3
# Check 김지현0
# Check 김지현0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지현', 'DBPIA': '과학기술정책연구원'}
# Check 김지현1
# Check 이희정0
# Check 이희정0
# Not Correct
#  - Answer : {'DBPIA': '중앙대학교 사회학과 BK21플러스 사업팀'}
#  - Result : {'name': '이희정', 'DBPIA': '한양대학교'}
# Check 이희정1
# Not Correct
#  - Answer : {'DBPIA': '전북대'}
#  - Result : {'name': '손현주', 'DBPIA': '전북대학교'}
# Check 김민수0
# Not Correct
#  - Answer : {'NTIS': '전남대학교'}
#  - Result : {'name': '김민수', 'DBPIA': '한국스포츠정책과학원'}
# Check 김민수1
# Check 김민수0
# Check 김민선0
# Not Correct
#  - Answer : {'DBPIA': '경기연구원'}
#  - Result : {'name': '김민선', 'DBPIA': '총신대학교'}
# Check 김민선1
# Check 김민선0
# Not Correct
#  - Answer : {'DBPIA': '경기연구원'}
#  - Result : {'name': '김민선', 'DBPIA': '협성대학교'}
# Check 김민선1
# Not Correct
#  - Answer : {'DBPIA': '총신대학교 일반대학원'}
#  - Result : {'name': '김민선', 'DBPIA': '협성대학교'}
# Check 김민선2
# Check 김하영0
# Not Correct
#  - Answer : {'DBPIA': '부산대학교 디자인학과'}
#  - Result : {'name': '김하영', 'DBPIA': '서울연구원'}
# Check 김하영1
# Check 김하영0
# Check 김성희0
# Check 김성희0
# Not Correct
#  - Answer : {'DBPIA': '동의대학교 Industrial of ICT Engineering'}
#  - Result : {'name': '김성희', 'DBPIA': '한양대'}
# Check 김성희1
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경1
# Not Correct
#  - Answer : {'DBPIA': '경기대학교 외식조리학과'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경2
# Not Correct
#  - Answer : {'DBPIA': '소노엠 Department of Research&Development Center'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경3
# Not Correct
#  - Answer : {'DBPIA': '숙명여자대학교 원격대학원 향장미용'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경4
# Check 김상균0
# Check 김상균0
# Not Correct
#  - Answer : {'DBPIA': '강원대학교 산업공학'}
#  - Result : {'name': '김상균', 'DBPIA': '서울연구원'}
# Check 김상균1
# Check 김동호0
# Not Correct
#  - Answer : {'DBPIA': '서울과학기술대학교'}
#  - Result : {'name': '김동호', 'DBPIA': '한국교통연구원'}
# Check 김동호1
# Check 김동호0
# Check 강지원0
# Not Correct
#  - Answer : {'DBPIA': '경희대학교 일반대학원 조리외식경영학과'}
#  - Result : {'name': '강지원', 'DBPIA': '한국교통연구원'}
# Check 강지원1
# Check 강지원0
# Check 최재영0
# Not Correct
#  - Answer : {'NTIS': '한국외국어대학교'}
#  - Result : {'name': '최재영', 'DBPIA': '한양대학교'}
# Check 최재영1
# Check 최재영0
# Check 변혜민0
# Check 변혜민0
# Not Correct
#  - Answer : {'DBPIA': '경희대학교 간호과학대학'}
#  - Result : {'name': '변혜민', 'DBPIA': '한국광고홍보학회'}
# Check 변혜민1
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '과학기술정책연구원'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '과학기술정책연구원'}
# Check 김지은2
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': ''}
# Check 김지은1
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 조경학과', 'DBPIA': ''}
#  - Result : {'name': '박찬', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 조경학과', 'DBPIA': ''}
#  - Result : {'name': '박찬', 'Scienceon': '서울시립대학교'}
# Not Correct
#  - Answer : {'Scienceon': '청주대학교 휴먼환경디자인학부 조경도시계획전공', 'DBPIA': ''}
#  - Result : {'name': '김호걸', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '청주대학교 휴먼환경디자인학부 조경도시계획전공', 'DBPIA': ''}
#  - Result : {'name': '김호걸', 'Scienceon': '청주대학교'}
# Check 김은주0
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 Global Training Program Team, Office of STI ODA Project (IICC)'}
#  - Result : {'name': '김은주', 'DBPIA': '관광경영학회'}
# Check 김은주1
# Check 김은주0
# Check 김영국0
# Check 김영국0
# Not Correct
#  - Answer : {'DBPIA': '농촌진흥청'}
#  - Result : {'name': '김영국', 'DBPIA': '법조협회'}
# Check 김영국1
# Check 김호용0
# Not Correct
#  - Answer : {'Scienceon': '한국과학기술정보연구원'}
#  - Result : {'name': '김호용', 'DBPIA': '아주대학교'}
# Check 김호용1
# Not Correct
#  - Answer : {'DBPIA': 'Yeungjin College School of Computer Information'}
#  - Result : {'name': '김호용', 'DBPIA': '아주대학교'}
# Check 김호용2
# Check 윤영진0
# Not Correct
#  - Answer : {'DBPIA': '상명대학교 경영학부'}
#  - Result : {'name': '윤영진', 'DBPIA': '특허청'}
# Check 윤영진1
# Check 윤영진0
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '상명대학교'}
# Check 김지영1
# Not Correct
#  - Answer : {'DBPIA': '동아대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '상명대학교'}
# Check 김지영2
# Check 김성연0
# Check 김성연0
# Not Correct
#  - Answer : {'DBPIA': '인사혁신처 국가공무원인재개발원 연구개발센터'}
#  - Result : {'name': '김성연', 'DBPIA': '인천대학교'}
# Check 김성연1
# Check 김성훈0
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 기계항공공학부'}
#  - Result : {'name': '김성훈', 'DBPIA': '성균관대학교'}
# Check 김성훈1
# Check 김성훈0
# Check 송지성0
# Check 박재현0
# Not Correct
#  - Answer : {'DBPIA': 'Korea National Sport University'}
#  - Result : {'name': '박재현', 'DBPIA': '동국대학교'}
# Check 박재현1
# Check 박재현0
# Check 김진주0
# Not Correct
#  - Answer : {'DBPIA': '명지대학교(서울) 정치외교학과'}
#  - Result : {'name': '김진주', 'DBPIA': '한양대학교'}
# Check 김진주1
# Check 김진주0
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은2
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 글로벌혁신전략연구본부'}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은3
# Not Correct
#  - Answer : {'DBPIA': '성균관대학교 인터랙션사이언스학과'}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은4
# Check 이지연0
# Not Correct
#  - Answer : {'DBPIA': '한국복식학회'}
#  - Result : {'name': '이지연', 'DBPIA': '한국브랜드디자인학회'}
# Check 이지연1
# Check 이지연0
# Check 김태형0
# Check 김태형0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김태형', 'DBPIA': '한국교통연구원'}
# Check 김태형1
# Check 김주일0
# Not Correct
#  - Answer : {'DBPIA': '전라남도문화관광재단 관광연구개발팀'}
#  - Result : {'name': '김주일', 'DBPIA': '한동대학교'}
# Check 김주일1
# Check 김주일0
# Check 김동현0
# Not Correct
#  - Answer : {'DBPIA': '동서대학교 소프트웨어학과'}
#  - Result : {'name': '김동현', 'DBPIA': '바론'}
# Check 김동현1
# Check 김동현0
# Not Correct
#  - Answer : {'DBPIA': '동서대학교 소프트웨어학과'}
#  - Result : {'name': '김동현', 'Scienceon': 'Dept'}
# Check 김동현1
# Not Correct
#  - Answer : {'DBPIA': '바론'}
#  - Result : {'name': '김동현', 'Scienceon': 'Dept'}
# Check 김동현2
# Check 복경수0
# Not Correct
#  - Answer : {'Scienceon': '원광대학교', 'DBPIA': '원광대학교'}
#  - Result : {'name': '복경수', 'DBPIA': 'Wonkwang'}
# Check 복경수1
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
#  - Result : {'name': '복경수', 'DBPIA': 'Wonkwang'}
# Check 이주희0
# Check 이주희0
# Not Correct
#  - Answer : {'DBPIA': 'Kyung Hee University Department of Korean Language and Literature'}
#  - Result : {'name': '이주희', 'DBPIA': '숙명여자대학교'}
# Check 이주희1
# Check 배수진0
# Not Correct
#  - Answer : {'DBPIA': '강원대학교 삼척캠퍼스 교양학부'}
#  - Result : {'name': '배수진', 'DBPIA': '동의대학교'}
# Check 배수진1
# Check 배수진0
# Check 신성윤0
# Not Correct
#  - Answer : {'Scienceon': 'Kunsan National University'}
#  - Result : {'name': '신성윤', 'DBPIA': '아주대학교'}
# Check 신성윤1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '신성윤', 'DBPIA': '아주대학교'}
# Check 신성윤2
# Check 신성윤0
# Check 손형섭0
# Not Correct
#  - Answer : {'DBPIA': '경성대학교 법정대학'}
#  - Result : {'name': '손형섭', 'DBPIA': '한밭대학교'}
# Check 손형섭1
# Check 손형섭0
# Check 김동현0
# Check 이은선0
# Check 이은선0
# Not Correct
#  - Answer : {'DBPIA': '경남과학기술대학교 경제학과'}
#  - Result : {'name': '이은선', 'DBPIA': '홍익대학교'}
# Check 이은선1
# Check 박은정0
# Not Correct
#  - Answer : {'DBPIA': '부경대학교 기술경영전문대학원'}
#  - Result : {'name': '박은정', 'DBPIA': '한국형사정책연구원'}
# Check 박은정1
# Check 박은정0
# Check 김성진0
# Not Correct
#  - Answer : {'DBPIA': '강릉원주대학교 멀티미디어공학과'}
#  - Result : {'name': '김성진', 'DBPIA': '한국체육측정평가학회'}
# Check 김성진1
# Check 김성진0
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '동아대학교'}
# Check 김지영1
# Check 김영미0
# Not Correct
#  - Answer : {'Scienceon': '서원대학교 레저스포츠학과'}
#  - Result : {'name': '김영미', 'DBPIA': '강원대학교'}
# Check 김영미1
# Check 김영미0
# Check 김태현0
# Not Correct
#  - Answer : {'DBPIA': 'National Nanofab Center'}
#  - Result : {'name': '김태현', 'DBPIA': '서울기술연구원'}
# Check 김태현1
# Check 김태현0
# Check 정혜정0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '정혜정', 'DBPIA': '한국브랜드디자인학회'}
# Check 정혜정1
# Check 정혜정0
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '성균관대학교'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '성균관대학교'}
# Check 김지은2
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 글로벌혁신전략연구본부'}
#  - Result : {'name': '김지은', 'DBPIA': '성균관대학교'}
# Check 김지은3
# Check 이재문0
# Check 이재문0
# Not Correct
#  - Answer : {'DBPIA': '경희대학교 체육학과'}
#  - Result : {'name': '이재문', 'DBPIA': '국민체육진흥공단체육과학연구원'}
# Check 이재문1
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현1
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 사범대학 교직과'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현2
# Not Correct
#  - Answer : {'DBPIA': '대한토목학회'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현3
# Not Correct
#  - Answer : {'DBPIA': '창원대학교 전자공학과'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현4
# Check 김정호0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김정호', 'DBPIA': '과학기술정책연구원'}
# Check 김정호1
# Check 김정호0
# Check 이정우0
# Not Correct
#  - Answer : {'DBPIA': '한국기술혁신학회'}
#  - Result : {'name': '이정우', 'DBPIA': '한국연기금연구원'}
# Check 이정우1
# Not Correct
#  - Answer : {'DBPIA': '한국에너지기술평가원 인적자원실'}
#  - Result : {'name': '이정우', 'DBPIA': '한국연기금연구원'}
# Check 이정우2
# Check 이정우0
# Not Correct
#  - Answer : {'DBPIA': '한국기술혁신학회'}
#  - Result : {'name': '이정우', 'DBPIA': '한국에너지기술평가원'}
# Check 이정우1
# Check 이상훈0
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원'}
#  - Result : {'name': '이상훈', 'DBPIA': '한국한의학연구원'}
# Check 이상훈1
# Check 이상훈0
# Check 유한나0
# Not Correct
#  - Answer : {'DBPIA': '서울여자대학교 디자인학과'}
#  - Result : {'name': '유한나', 'DBPIA': '연세대학교'}
# Check 유한나1
# Check 유한나0
# Check 홍성표0
# Check 홍성표0
# Not Correct
#  - Answer : {'DBPIA': '조선대학교 SW중신대학사업단'}
#  - Result : {'name': '홍성표', 'DBPIA': '한국교통연구원'}
# Check 홍성표1
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '정주익', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '정주익', 'Scienceon': '인천국제공항공사'}
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '차희준', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '차희준', 'Scienceon': '인천국제공항공사'}
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': ''}
#  - Result : {'name': '백연희', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': ''}
#  - Result : {'name': '백연희', 'Scienceon': '충북대학교'}
# Check 김은미0
# Check 김은미0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김은미', 'DBPIA': '충남대학교'}
# Check 김은미1
# Check 조은경0
# Check 조은경0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '조은경', 'DBPIA': '동국대'}
# Check 조은경1
# Check 김영우0
# Check 김영우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김영우', 'DBPIA': '환경부'}
# Check 김영우1
# Not Correct
#  - Answer : {'DBPIA': '경북대학교'}
#  - Result : {'name': '김영우', 'DBPIA': '환경부'}
# Check 김영우2
# Check 신성윤0
# Not Correct
#  - Answer : {'Scienceon': 'Kunsan National University'}
#  - Result : {'name': '신성윤', 'DBPIA': ''}
# Check 신성윤1
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
#  - Result : {'name': '임종태', 'DBPIA': ''}
# Check 복경수0
# Not Correct
#  - Answer : {'Scienceon': '원광대학교', 'DBPIA': '원광대학교'}
#  - Result : {'name': '복경수', 'DBPIA': ''}
# Check 복경수1
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
#  - Result : {'name': '복경수', 'DBPIA': ''}
# Not Correct
#  - Answer : {'NTIS': '충북대학교', 'DBPIA': '충북대학교', 'Scienceon': '충북대학교'}
#  - Result : {'name': '유재수', 'DBPIA': ''}
# Check 김재현0
# Check 김재현0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김재현', 'DBPIA': '세종대학교'}
# Check 김재현1
# Check 김준영0
# Check 김준영0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김준영', 'DBPIA': '순천대학교'}
# Check 김준영1
# Check 조영복0
# Check 조영복0
# Not Correct
#  - Answer : {'DBPIA': '대전대학교 정보보안학과'}
#  - Result : {'name': '조영복', 'DBPIA': '부산대학교'}
# Check 조영복1
# Check 손석현0
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원'}
#  - Result : {'name': '손석현', 'DBPIA': '부산대학교'}
# Check 손석현1
# Check 손석현0
# Check 박현정0
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 교육학과'}
#  - Result : {'name': '박현정', 'DBPIA': '충북대학교'}
# Check 박현정1
# Not Correct
#  - Answer : {'DBPIA': '이화여자대학교 경영연구소'}
#  - Result : {'name': '박현정', 'DBPIA': '충북대학교'}
# Check 박현정2
# Check 박현정0
# Check 이승우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '이승우', 'DBPIA': '한국과학기술정보연구원'}
# Check 이승우1
# Check 이승우0
# Check 이영주0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '이영주', 'DBPIA': '서울과학기술대학교'}
# Check 이영주1
# Check 이영주0
# Check 윤영민0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '윤영민', 'DBPIA': '고려대학교'}
# Check 윤영민1
# Check 윤영민0
# Check 김미경0
# Check 김미경0
# Not Correct
#  - Answer : {'DBPIA': '청운대학교 미디어커뮤니케이션학과'}
#  - Result : {'name': '김미경', 'DBPIA': '홍익대학교'}
# Check 김미경1
# Check 박현정0
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 교육학과'}
#  - Result : {'name': '박현정', 'DBPIA': '이화여자대학교'}
# Check 박현정1
# Check 이재용0
# Check 이재용0
# Not Correct
#  - Answer : {'DBPIA': '국토연구원 스마트·녹색도시연구센터'}
#  - Result : {'name': '이재용', 'DBPIA': '도쿄대학교'}
# Check 이재용1
# Check 김경민0
# Not Correct
#  - Answer : {'DBPIA': '부산대학교 소프트웨어교육센터'}
#  - Result : {'name': '김경민', 'DBPIA': '서울대'}
# Check 김경민1
# Check 김경민0
# Check 이정우0
# Check 김선우0
# Not Correct
#  - Answer : {'DBPIA': '고려대학교 School of Advanced Materials Science & Engineering'}
#  - Result : {'name': '김선우', 'DBPIA': '과학기술정책연구원'}
# Check 김선우1
# Check 김선우0
# Check 이성우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '이성우', 'DBPIA': '서울대학교'}
# Check 이성우1
# Check 이성우0
# Check 박찬식0
# Not Correct
#  - Answer : {'NTIS': '중앙대학교'}
#  - Result : {'name': '박찬식', 'DBPIA': '한국도로협회'}
# Check 박찬식1
# Check 박찬식0
# Check 서호준0
# Not Correct
#  - Answer : {'DBPIA': '신용보증기금'}
#  - Result : {'name': '서호준', 'DBPIA': '충남대'}
# Check 서호준1
# Check 서호준0
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '대한토목학회'}
# Check 이지현1
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 사범대학 교직과'}
#  - Result : {'name': '이지현', 'DBPIA': '대한토목학회'}
# Check 이지현2
# Check 김영우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김영우', 'DBPIA': '경북대학교'}
# Check 김영우1
# Check 김세진0
# Check 김세진0
# Not Correct
#  - Answer : {'DBPIA': 'Sungkyunkwan University School of Pharmacy'}
#  - Result : {'name': '김세진', 'DBPIA': '숙명여자대학교'}
# Check 김세진1
# Check 김지영0
# Check 김일중0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김일중', 'DBPIA': '한양대학교'}
# Check 김일중1
# Check 김일중0
# Check 이기영0
# Check 이기영0
# Not Correct
#  - Answer : {'DBPIA': '경기연구원 생태환경연구실'}
#  - Result : {'name': '이기영', 'DBPIA': '인천대학교'}
# Check 이기영1
# Check 김은경0
# Not Correct
#  - Answer : {'DBPIA': '강릉원주대학교 식품영양학과'}
#  - Result : {'name': '김은경', 'DBPIA': '경기연구원'}
# Check 김은경1
# Check 김은경0
# Check 이정희0
# Not Correct
#  - Answer : {'Scienceon': '국립산림과학원 산림복지연구과'}
#  - Result : {'name': '이정희', 'DBPIA': '경기연구원'}
# Check 이정희1
# Check 이정희0
# Check 박현길0
# Check 박현길0
# Not Correct
#  - Answer : {'DBPIA': 'GMCOM'}
#  - Result : {'name': '박현길', 'DBPIA': '동아기술공사'}
# Check 박현길1
# Check 김민선0
# Check 이수진0
# Not Correct
#  - Answer : {'DBPIA': 'Université Paris IV 지리학'}
#  - Result : {'name': '이수진', 'DBPIA': '경기연구원'}
# Check 이수진1
# Check 이수진0
# Check 박광서0
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 국제무역학과'}
#  - Result : {'name': '박광서', 'DBPIA': '한국해양수산개발원'}
# Check 박광서1
# Check 박광서0
# Check 김태경0
# Not Correct
#  - Answer : {'DBPIA': '공감도시연구실 연구위원'}
#  - Result : {'name': '김태경', 'DBPIA': '광운대학교'}
# Check 김태경1
# Check 김태경0
# Not Correct
#  - Answer : {'DBPIA': 'Kyung Hee University College of Hotel & Tourism Management'}
#  - Result : {'name': '정남호', 'DBPIA': '경희대학교'}
# Check 김민지0
# Not Correct
#  - Answer : {'DBPIA': '국토연구원'}
#  - Result : {'name': '김민지', 'DBPIA': '숙명여자대학교'}
# Check 김민지1
# Check 김민지0
# Check 권혁인0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '권혁인', 'DBPIA': '중앙대학교'}
# Check 권혁인1
# Check 권혁인0
# Check 김상욱0
# Not Correct
#  - Answer : {'NTIS': '한양대학교'}
#  - Result : {'name': '김상욱', 'DBPIA': '경북대학교'}
# Check 김상욱1
# Check 김상욱0
# Check 김범석0
# Check 김범석0
# Not Correct
#  - Answer : {'DBPIA': '지방공기업평가원'}
#  - Result : {'name': '김범석', 'DBPIA': '한국과학기술원'}
# Check 김범석1
# num코렉트 1792
# numEror 22
# 김호걸
# {'Scienceon': '청주대학교 휴먼환경디자인학부 조경도시계획전공', 'DBPIA': ''}
# 박찬
# {'Scienceon': '서울시립대학교 조경학과', 'DBPIA': ''}
# 반재훈
# {'Scienceon': 'Department of IT Management, Kosin University', 'DBPIA': '고신대학교'}
# 백연희
# {'Scienceon': '충북대학교', 'DBPIA': ''}
# 정주익
# {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
# 차희준
# {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
# 하종수
# {'Scienceon': 'Department of Broadcasting & Image, Kyungnam College of Information & Technology', 'DBPIA': '경남정보대학교'}
# 구철모1
# {'DBPIA': '경희대학교 컨벤션경영학과'}
# 손현주
# {'DBPIA': '전북대'}
# 송지성1
# {'DBPIA': '한양대학교 디자인대학 커뮤니케이션디자인학과'}
# 10

# %%
print("(주) 제오시스 기업부설연구소".replace("(주) ",""))
# Out:
# 제오시스 기업부설연구소
