# %%
from pymongo import MongoClient

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
sco_exfa = client['SCIENCEON']['ExpertFactor']
sco_aut = client['SCIENCEON']['Author']

ntis_exfa = client['NTIS']['ExpertFactor']
ntis_aut = client['NTIS']['Author']
ntis_raw = client['NTIS']['Rawdata']

dbpia_exfa = client['DBPIA']['ExpertFactor']
dbpia_aut = client['DBPIA']['Author']

id_domestic = client['ID']['Domestic']

keyid = 588 #input

sco_key_query = sco_exfa.find({ 'keyId' : keyid })
ntis_key_query = ntis_exfa.find({ 'keyId' : keyid })
dbpia_key_query = dbpia_exfa.find({ 'keyId' : keyid })

key_querys = [sco_key_query, ntis_key_query, dbpia_key_query]
#key_querys = [ntis_key_query]
auts = [sco_aut, ntis_aut, dbpia_aut]
site = ['Scienceon', 'NTIS', 'DBPIA']

a_id = []
all_name_inst = []
all_name = []
all_inst = []
all_site = []
reCopy = []
reCopy_site = []
reCopy_aid = []
Answer_list = []
Answer_dict = {}

for i in range(len(key_querys)):
    #print(key_querys[i])
    for key_query in key_querys[i]:
        a_id.append(key_query['A_ID'])

        if site[i] == 'NTIS' : 
            # if "11638621" == a_id[-1] :
            #print("check")
            ntis_raw_query = ntis_raw.find_one({'$and':[{'keyId':keyid},{'mngId':a_id[-1]}]})
            
            if ntis_raw_query == None :
            #print("check2")
                continue
    
        aut_query = auts[i].find_one({'_id':key_query['A_ID']})
        #print(aut_query)
        #all_name_inst.append(aut_query['name'] + '/' + aut_query['inst'])
        all_name.append(aut_query['name'])
        all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_site.append(site[i])


        #if all_name[-1] == '송재오' :
        #    print(aut_query['inst'])
        Answer = {'name' : all_name[-1], site[i] : all_inst[-1],  }

   
        if all_name[-1] not in Answer_dict and all_name[-1]+'0' not in Answer_dict :
            Answer_dict[all_name[-1]] = Answer
         #   print("insert")
        else :
            
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]

              
                if tempName in Answer_dict :        # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+str(count)  # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                       # print(tempName)
                        break
                    temp = Answer_dict[tempName]

                
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]):
                            src = temp[key]
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]):
                            src = all_inst[-1]
                            tgt = temp[key]
                        # if tempName == '김영미' :
                        #     print(all_inst[-1], temp[key])
                        #     print(ssrc, ttgt)


                        if key == site[i] :# 사이트가 동일할때
                            if temp[key] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                                flag = False
                                break
                            elif all_name[-1]+str(count+1) not in Answer_dict :
                                Answer_dict[all_name[-1]+str(count+1)] = Answer
                                #if tempName != all_name[-1] :
                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key] == all_inst[-1] or (src != "" and src in tgt):  # 소속 같을때
                                #if len(src) == 0:
                                 #   flag = False
                                #else:
                                    Answer_dict[tempName][site[i]] = all_inst[-1]
                                    flag = False
                                    break
                            
                            elif all_name[-1]+str(count+1) not in Answer_dict :
                                Answer_dict[all_name[-1]+str(count+1)] = Answer
                                #if tempName != all_name[-1] :
                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'0'] = temp
                                    del Answer_dict[all_name[-1]]   

                count += 1


        # Answer_list.append(Answer)

#Answer_dict.sort()
#print(len(Answer_dict))
#print(Answer_dict)
print(sorted(Answer_dict.items()))
# Out:
# {'_id': ObjectId('61939447e9b04a9d64abe067'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 13, 'issue_inst': '한국디지털정책학회', 'journal': '디지털융복합연구 = Journal of digital convergence', 'issue_year': '2020', 'id': 'JAKO202008540580214', 'title': 'K-POP 아이돌 그룹 신한복 스타일에 대한 글로벌 반응: 블랙핑크 패션 사례', 'english_title': "The global response to K-POP idol group's New Hanbok: The case of Black Pink Fashion", 'abstract': "본 연구는 K-POP 가수의 신한복 스타일에 대한 국내&#183;외 소비자들의 반응을 알아보는 것을 목적으로 한다. '블랙핑크 한복'을 키워드로 포함하는 유튜브 영상과 사용자 댓글을 수집했으며, 소셜 네트워크 분석과 감성분석을 적용했다. 첫째, 블랙핑크의 신한복 스타일은 안무하기 편하도록 미니드레스 형태로 제작되었으며, 전통적 요소를 더해 현대적으로 재해석한 것으로 나타났다. 둘째, 블랙핑크의 신한복 패션에 대해 국내 반응에서는 노출에 대한 이슈가 논란이 된 키워드로 등장한 반면, 해외 반응에서는 나타나지 않았다. 셋째, 감성분석 결과 국내보다 해외 반응에서 신한복 스타일에 대해 더 긍정적인 평가를 보였다. 본 연구는 광범위한 소비자들의 반응을 알아보고 신한복에 대한 긍부정 요소를 파악하여, 신한복이 나아가야 할 방향을 제시했다는데 의의가 있다.", 'english_abstract': '', 'citation': 0, 'author': '최영현;천탠이;이규혜;', 'author_inst': '한양대학교 의류학과;한양대학교 의류학과;한양대학교 의류학과 휴먼테크융합전공;', 'start_page': '533', 'end_page': '541', 'paper_keyword': '한류 . 케이팝 . 신한복 스타일 . 소셜 빅데이터 분석 . 감성분석 . 글로벌 반응', 'issue_lang': 'kor', 'progress': 0.355, 'author_id': 's262342;s1087973;s1087974'}
# {'_id': ObjectId('61939447e9b04a9d64abe067'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 13, 'issue_inst': '한국디지털정책학회', 'journal': '디지털융복합연구 = Journal of digital convergence', 'issue_year': '2020', 'id': 'JAKO202008540580214', 'title': 'K-POP 아이돌 그룹 신한복 스타일에 대한 글로벌 반응: 블랙핑크 패션 사례', 'english_title': "The global response to K-POP idol group's New Hanbok: The case of Black Pink Fashion", 'abstract': "본 연구는 K-POP 가수의 신한복 스타일에 대한 국내&#183;외 소비자들의 반응을 알아보는 것을 목적으로 한다. '블랙핑크 한복'을 키워드로 포함하는 유튜브 영상과 사용자 댓글을 수집했으며, 소셜 네트워크 분석과 감성분석을 적용했다. 첫째, 블랙핑크의 신한복 스타일은 안무하기 편하도록 미니드레스 형태로 제작되었으며, 전통적 요소를 더해 현대적으로 재해석한 것으로 나타났다. 둘째, 블랙핑크의 신한복 패션에 대해 국내 반응에서는 노출에 대한 이슈가 논란이 된 키워드로 등장한 반면, 해외 반응에서는 나타나지 않았다. 셋째, 감성분석 결과 국내보다 해외 반응에서 신한복 스타일에 대해 더 긍정적인 평가를 보였다. 본 연구는 광범위한 소비자들의 반응을 알아보고 신한복에 대한 긍부정 요소를 파악하여, 신한복이 나아가야 할 방향을 제시했다는데 의의가 있다.", 'english_abstract': '', 'citation': 0, 'author': '최영현;천탠이;이규혜;', 'author_inst': '한양대학교 의류학과;한양대학교 의류학과;한양대학교 의류학과 휴먼테크융합전공;', 'start_page': '533', 'end_page': '541', 'paper_keyword': '한류 . 케이팝 . 신한복 스타일 . 소셜 빅데이터 분석 . 감성분석 . 글로벌 반응', 'issue_lang': 'kor', 'progress': 0.355, 'author_id': 's262342;s1087973;s1087974'}
# {'_id': ObjectId('61939447e9b04a9d64abe068'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 14, 'issue_inst': '한국정보통신학회', 'journal': '한국정보통신학회논문지 = Journal of the Korea Institute of Information and Communication Engineering', 'issue_year': '2020', 'id': 'JAKO202005653789488', 'title': '빅데이터 분석도구 R을 이용한 성경 데이터의 빈도와 소셜 네트워크 분석', 'english_title': 'Frequency and Social Network Analysis of the Bible Data using Big Data Analytics Tools R', 'abstract': '데이터를 저장하고 분석하여 새로운 지식을 얻을 수 있는 빅데이터 처리기술은 사회의 여러 분야에서 중요성이 강조되고 있으며 정보통신기술 분야의 핵심 이슈로 부각되면서 관련 기술에 대한 관심이 증가하고 있다. 이러한 빅데이터를 분석할 수 있는 도구인 R은 통계 기반의 정보 분석을 가능하게 하는 언어와 환경이다. 본 논문에서는 이를 이용하여 성경데이터를 분석한다. 성경 중에서 신약성경의 4복음서의 데이터를 분석한다. 먼저 성경데이터를 수집하고 분석을 위한 필터링을 수행한다. 이후 R을 이용하여 어떠한 텍스트가 분포되어 있는지를 빈도 조사를 수행하며 정확한 데이터의 분석을 위해 한 문장에서 나오는 단어들을 쌍으로 표현하고 단어 간의 관계성을 분석하는 소셜 네트워크 분석을 통해 성경을 분석한다.', 'english_abstract': '', 'citation': 0, 'author': '반재훈;하종수;김동현;', 'author_inst': 'Department of IT Management, Kosin University;Department of Broadcasting & Image, Kyungnam College of Information & Technology;Dept of Software, Dongseo University;', 'start_page': '166', 'end_page': '171', 'paper_keyword': '빅데이터 . 성경 . 소셜 네트워크 분석 . 텍스트 마이닝', 'issue_lang': 'kor', 'progress': 0.35666666666666663, 'author_id': 's260982;s260983;s1087975'}
# {'_id': ObjectId('61939447e9b04a9d64abe063'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 7, 'issue_inst': '한국융합학회', 'journal': '한국융합학회논문지 = Journal of the Korea Convergence Society', 'issue_year': '2020', 'id': 'JAKO202008337072094', 'title': '패션 트렌드의 주기적 순환성에 관한 빅데이터 융합 분석', 'english_title': 'The Analysis of Fashion Trend Cycle using Big Data', 'abstract': '본 논문은 과거와 현재의 패션 트렌드와 패션 유행 주기에 관한 빅데이터 분석을 실시하였다. 패션 전문가나 패션쇼가 아닌 일반 사람들의 데일리룩을 위한 패션 트렌드를 분석하는데 집중하였다. 소셜 매트릭스 도구인 텍스톰을 활용하여 빈도수 분석, N-gram 분석, 네트워크 분석 및 구조적 등위성 분석을 수행하였다. 분석 결과, 첫째, 패션 전문가가 아닌 일반 사람들의 데일리 룩을 대상으로 과거(1980년대, 1990년대)와 현재(2019년, 2020년)의 패션 키워드를 도출하였다. 둘째, 과거의 패션이 현재의 패션으로 재현되는 순환성과 순환 주기가 30-40년 정도로 짧아졌음을 빅데이터 분석을 통해 과학적으로 검증하였다. 셋째, 도출된 패션 키워드들의 구조적 등위성 분석을 수행한 결과, 과거 패션에서는 청바지 패션, 레트로 코디, 애슬레저룩, 연예인 복고패션의 4개의 군집으로, 현재 패션에서는 레트로 청바지, 뉴트로, 레이디 쉬크, 레트로 퓨처리즘의 4개의 군집을 확인하였다. 넷째, 과거의 패션이 현재의 패션으로 재현되고 진화하는 네트워크 연결 관계를 확인하고 그 배경에 관한 이슈를 고찰하였다. 이와 같은 연구결과는 과거와 현재의 패션 키워드를 도출하고 이로부터 패션 유행의 순환 주기를 확인함으로써 과거를 통해 미래 패션을 예측하도록 하는데 의의가 있다.', 'english_abstract': '', 'citation': 0, 'author': '김기현;변혜원;', 'author_inst': '성신여자대학교 정보시스템공학과;성신여자대학교 정보시스템공학과;', 'start_page': '113', 'end_page': '123', 'paper_keyword': '융합 . 패션 트렌드 . 패션 순환성 . 패션 유행 주기 . 레트로 . 뉴트로 . 빅데이터 . 텍스트 마이닝 . 텍스트 출현 빈도 . 네트워크 분석 . 구조적 등위성 분석', 'issue_lang': 'kor', 'progress': 0.345, 'author_id': 's1087976;s1087977'}
# {'_id': ObjectId('61939447e9b04a9d64abe063'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 7, 'issue_inst': '한국융합학회', 'journal': '한국융합학회논문지 = Journal of the Korea Convergence Society', 'issue_year': '2020', 'id': 'JAKO202008337072094', 'title': '패션 트렌드의 주기적 순환성에 관한 빅데이터 융합 분석', 'english_title': 'The Analysis of Fashion Trend Cycle using Big Data', 'abstract': '본 논문은 과거와 현재의 패션 트렌드와 패션 유행 주기에 관한 빅데이터 분석을 실시하였다. 패션 전문가나 패션쇼가 아닌 일반 사람들의 데일리룩을 위한 패션 트렌드를 분석하는데 집중하였다. 소셜 매트릭스 도구인 텍스톰을 활용하여 빈도수 분석, N-gram 분석, 네트워크 분석 및 구조적 등위성 분석을 수행하였다. 분석 결과, 첫째, 패션 전문가가 아닌 일반 사람들의 데일리 룩을 대상으로 과거(1980년대, 1990년대)와 현재(2019년, 2020년)의 패션 키워드를 도출하였다. 둘째, 과거의 패션이 현재의 패션으로 재현되는 순환성과 순환 주기가 30-40년 정도로 짧아졌음을 빅데이터 분석을 통해 과학적으로 검증하였다. 셋째, 도출된 패션 키워드들의 구조적 등위성 분석을 수행한 결과, 과거 패션에서는 청바지 패션, 레트로 코디, 애슬레저룩, 연예인 복고패션의 4개의 군집으로, 현재 패션에서는 레트로 청바지, 뉴트로, 레이디 쉬크, 레트로 퓨처리즘의 4개의 군집을 확인하였다. 넷째, 과거의 패션이 현재의 패션으로 재현되고 진화하는 네트워크 연결 관계를 확인하고 그 배경에 관한 이슈를 고찰하였다. 이와 같은 연구결과는 과거와 현재의 패션 키워드를 도출하고 이로부터 패션 유행의 순환 주기를 확인함으로써 과거를 통해 미래 패션을 예측하도록 하는데 의의가 있다.', 'english_abstract': '', 'citation': 0, 'author': '김기현;변혜원;', 'author_inst': '성신여자대학교 정보시스템공학과;성신여자대학교 정보시스템공학과;', 'start_page': '113', 'end_page': '123', 'paper_keyword': '융합 . 패션 트렌드 . 패션 순환성 . 패션 유행 주기 . 레트로 . 뉴트로 . 빅데이터 . 텍스트 마이닝 . 텍스트 출현 빈도 . 네트워크 분석 . 구조적 등위성 분석', 'issue_lang': 'kor', 'progress': 0.345, 'author_id': 's1087976;s1087977'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06d'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 2, 'issue_inst': '한국디지털정책학회', 'journal': '디지털융복합연구 = Journal of digital convergence', 'issue_year': '2021', 'id': 'JAKO202123157275845', 'title': '스포츠 경기의 특성에 따른 스포츠 감정 유형 분석 : 소셜 빅데이터를 중심으로', 'english_title': 'The Analysis on Sport Emotion Type by Sport Game Characteristics: with Social Big-Data', 'abstract': '본 연구는 스포츠 경기의 특성에 따른 스포츠 감정 유형을 분석하였다. 이를 위해 2018년 아시안게임 중, 대한민국 대표팀이 출전한 축구 7경기, 야구 6경기를 선정한 후, 이에 대한 소셜 네트워크 서비스 상 기사와 그 댓글을 조사대상으로 선정하였다. Python을 이용하여 수집된 댓글은 전문가 회의를 통해 해당 감정을 분석하였다. 스포츠 경기의 승패, 상대 팀의 수준 및 대한민국 대표팀의 경기력에 따른 스포츠 감정을 분석한 결과, 첫째, 승패와 상대 팀 수준은 특정한 유형의 스포츠 감정을 형성한다고 보기 어려웠다. 둘째, 스포츠 경기의 경기력은 좋다는 평가를 받을 경우 만족, 열광, 기쁨 등의 긍정적 감정을, 나쁘다는 평가를 받을 경우 실망, 분노, 창피의 부정적 감정을 형성하였다. 셋째, 스포츠 경기와 연관된 사회&#x00B7;문화적 배경이나 해당 경기의 특정한 사건 또한 스포츠 감정의 유형에 영향을 미쳤다. 추후, 본 연구에서 다루지 못한 다양한 스포츠 경기의 특성을 추가하여 보다 많은 스포츠 경기를 대상으로 분석하는 연구가 필요할 것이다.', 'english_abstract': '', 'citation': 0, 'author': '김영미;양재식;', 'author_inst': '서원대학교 레저스포츠학과;서원대학교 레저스포츠학과;', 'start_page': '371', 'end_page': '377', 'paper_keyword': '스포츠 경기 . 경기 특성 . 스포츠 감정 . 감정 유형 . 빅데이터', 'issue_lang': 'kor', 'progress': 0.6699999999999999, 'author_id': 's1087978;s1087979'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06d'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 2, 'issue_inst': '한국디지털정책학회', 'journal': '디지털융복합연구 = Journal of digital convergence', 'issue_year': '2021', 'id': 'JAKO202123157275845', 'title': '스포츠 경기의 특성에 따른 스포츠 감정 유형 분석 : 소셜 빅데이터를 중심으로', 'english_title': 'The Analysis on Sport Emotion Type by Sport Game Characteristics: with Social Big-Data', 'abstract': '본 연구는 스포츠 경기의 특성에 따른 스포츠 감정 유형을 분석하였다. 이를 위해 2018년 아시안게임 중, 대한민국 대표팀이 출전한 축구 7경기, 야구 6경기를 선정한 후, 이에 대한 소셜 네트워크 서비스 상 기사와 그 댓글을 조사대상으로 선정하였다. Python을 이용하여 수집된 댓글은 전문가 회의를 통해 해당 감정을 분석하였다. 스포츠 경기의 승패, 상대 팀의 수준 및 대한민국 대표팀의 경기력에 따른 스포츠 감정을 분석한 결과, 첫째, 승패와 상대 팀 수준은 특정한 유형의 스포츠 감정을 형성한다고 보기 어려웠다. 둘째, 스포츠 경기의 경기력은 좋다는 평가를 받을 경우 만족, 열광, 기쁨 등의 긍정적 감정을, 나쁘다는 평가를 받을 경우 실망, 분노, 창피의 부정적 감정을 형성하였다. 셋째, 스포츠 경기와 연관된 사회&#x00B7;문화적 배경이나 해당 경기의 특정한 사건 또한 스포츠 감정의 유형에 영향을 미쳤다. 추후, 본 연구에서 다루지 못한 다양한 스포츠 경기의 특성을 추가하여 보다 많은 스포츠 경기를 대상으로 분석하는 연구가 필요할 것이다.', 'english_abstract': '', 'citation': 0, 'author': '김영미;양재식;', 'author_inst': '서원대학교 레저스포츠학과;서원대학교 레저스포츠학과;', 'start_page': '371', 'end_page': '377', 'paper_keyword': '스포츠 경기 . 경기 특성 . 스포츠 감정 . 감정 유형 . 빅데이터', 'issue_lang': 'kor', 'progress': 0.6699999999999999, 'author_id': 's1087978;s1087979'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06e'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 3, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2021', 'id': 'JAKO202116153182268', 'title': "웨이보 인기뉴스에 관한 감정표현에 영향을 미치는 요인 - '중국 산시성 린펀시 반점 붕괴 사건'을 중심으로 -", 'english_title': "Influencing Factors on the Emotional Expression in Weibo Hot News - Focusing on 'Restaurant Collapse in Linfen City, Shanxi Province' -", 'abstract': "본 연구는 시나 웨이보(Sina Weibo)에 게재된 '산시성 린펀시 반점 붕괴 사건'이라는 인기뉴스(hot news)에 대한 댓글에 나타난 감정표현에 영향을 미치는 요인들을 살펴보았다. 연구결과, 첫째, 성별에 따라 감정표현에 차이가 나타났다. 여성은 남성보다 더 강한 분노, 실망, 슬픔, 비난 감정을 표현하였다. 둘째, 동부지역 이용자들의 감정표현 강도가 중부지역과 서부지역에 비하여 유의하게 높았다. 셋째, 이용자가 댓글에 참여하고 감정표현을 게시한 블로그의 총수량인 웨이보 수가 많을수록 감정표현이 더욱 강하게 나타났다. 넷째, 미인증 이용자는 인증된 이용자보다 실망, 슬픔의 감정표현이 더욱 강하였다. 본 연구는 중국의 온라인 여론형성 과정에서 감정표현의 영향 요인을 살펴봄으로써 서양의 트위터나 페이스북과 같은 소셜네트워크와 비교할 수 있다는 점에서 의의가 있으며, 온라인 뉴스분석에서 빅데이터 분석방법을 사용했다는 점에서도 의의가 있다.", 'english_abstract': '', 'citation': 0, 'author': '륙치금;남인용;', 'author_inst': '부경대학교 신문방송학과;부경대학교 신문방송학과;', 'start_page': '105', 'end_page': '117', 'paper_keyword': '웨이보 . 인기뉴스 . 온라인 여론 . 감정유형 . 감정표현', 'issue_lang': 'kor', 'progress': 0.6716666666666666, 'author_id': 's1087980;s1087981'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06e'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 3, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2021', 'id': 'JAKO202116153182268', 'title': "웨이보 인기뉴스에 관한 감정표현에 영향을 미치는 요인 - '중국 산시성 린펀시 반점 붕괴 사건'을 중심으로 -", 'english_title': "Influencing Factors on the Emotional Expression in Weibo Hot News - Focusing on 'Restaurant Collapse in Linfen City, Shanxi Province' -", 'abstract': "본 연구는 시나 웨이보(Sina Weibo)에 게재된 '산시성 린펀시 반점 붕괴 사건'이라는 인기뉴스(hot news)에 대한 댓글에 나타난 감정표현에 영향을 미치는 요인들을 살펴보았다. 연구결과, 첫째, 성별에 따라 감정표현에 차이가 나타났다. 여성은 남성보다 더 강한 분노, 실망, 슬픔, 비난 감정을 표현하였다. 둘째, 동부지역 이용자들의 감정표현 강도가 중부지역과 서부지역에 비하여 유의하게 높았다. 셋째, 이용자가 댓글에 참여하고 감정표현을 게시한 블로그의 총수량인 웨이보 수가 많을수록 감정표현이 더욱 강하게 나타났다. 넷째, 미인증 이용자는 인증된 이용자보다 실망, 슬픔의 감정표현이 더욱 강하였다. 본 연구는 중국의 온라인 여론형성 과정에서 감정표현의 영향 요인을 살펴봄으로써 서양의 트위터나 페이스북과 같은 소셜네트워크와 비교할 수 있다는 점에서 의의가 있으며, 온라인 뉴스분석에서 빅데이터 분석방법을 사용했다는 점에서도 의의가 있다.", 'english_abstract': '', 'citation': 0, 'author': '륙치금;남인용;', 'author_inst': '부경대학교 신문방송학과;부경대학교 신문방송학과;', 'start_page': '105', 'end_page': '117', 'paper_keyword': '웨이보 . 인기뉴스 . 온라인 여론 . 감정유형 . 감정표현', 'issue_lang': 'kor', 'progress': 0.6716666666666666, 'author_id': 's1087980;s1087981'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06c'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 1, 'issue_inst': '디지털산업정보학회', 'journal': '디지털산업정보학회논문지 = Journal of the Korea Society of Digital Industry and Information Management', 'issue_year': '2021', 'id': 'JAKO202111735183455', 'title': '소셜 네트워크 서비스 이용자의 자기결정성 요인이 자기존중감과 만족을 통해 심리적 안녕감에 미치는 영향', 'english_title': 'The Effect of Self-Deterministic Factors of Social Network Service Users on Psychological Well-Being by Self-Esteem and Satisfaction', 'abstract': 'In this study, we would like to consider the main factors that influence psychological well-being by using social network service. suggest ways to use healthy social network services, and empirically verify how behavioral approaches, in other words self-determination theory, that deals with human psychological needs, affect psychological well-being by self-esteem and satisfaction to comprehensively examine the characteristics of service and user individuals and social influences, etc. First research result, it has been confirmed that the autonomy has a positive effect on self-esteem. Second, it has been confirmed that the autonomy does not have a positive effect on satisfaction. Third, it has been confirmed that the competence has a positive effect on self-esteem. Fourth, it has been confirmed that the competence does not have a positive effect on satisfaction. Fifth, it has been confirmed that the relationship has a positive effect on self-esteem. Sixth, it has been confirmed that the relationship does not have a positive effect on satisfaction. Seventh, it has been confirmed that self-esteem has a positive effect on psychological well-being. Eighth, it has been confirmed that self-esteem has a positive effect on satisfaction. Ninth, it has been confirmed that satisfaction has a positive effect on psychological well-being. These results mean that meeting basic human psychological needs has a significant impact on psychological well-being of the social network service users. In addition, it was confirmed that increasing the desire for autonomy, competence, relationship, which are factors of self-determination, is an important factor to enhance psychological well-being.', 'english_abstract': '', 'citation': 0, 'author': '한정섭;권두순;김성준;', 'author_inst': '남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과;청운대학교 교양대학;남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과;', 'start_page': '85', 'end_page': '108', 'paper_keyword': 'Social Network Service . Self-Esteem . Satisfaction . Psychological Well-Being . Self-Determination Theory', 'issue_lang': 'kor', 'progress': 0.6683333333333333, 'author_id': 's1087982;s1087983;s1087984'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06c'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 1, 'issue_inst': '디지털산업정보학회', 'journal': '디지털산업정보학회논문지 = Journal of the Korea Society of Digital Industry and Information Management', 'issue_year': '2021', 'id': 'JAKO202111735183455', 'title': '소셜 네트워크 서비스 이용자의 자기결정성 요인이 자기존중감과 만족을 통해 심리적 안녕감에 미치는 영향', 'english_title': 'The Effect of Self-Deterministic Factors of Social Network Service Users on Psychological Well-Being by Self-Esteem and Satisfaction', 'abstract': 'In this study, we would like to consider the main factors that influence psychological well-being by using social network service. suggest ways to use healthy social network services, and empirically verify how behavioral approaches, in other words self-determination theory, that deals with human psychological needs, affect psychological well-being by self-esteem and satisfaction to comprehensively examine the characteristics of service and user individuals and social influences, etc. First research result, it has been confirmed that the autonomy has a positive effect on self-esteem. Second, it has been confirmed that the autonomy does not have a positive effect on satisfaction. Third, it has been confirmed that the competence has a positive effect on self-esteem. Fourth, it has been confirmed that the competence does not have a positive effect on satisfaction. Fifth, it has been confirmed that the relationship has a positive effect on self-esteem. Sixth, it has been confirmed that the relationship does not have a positive effect on satisfaction. Seventh, it has been confirmed that self-esteem has a positive effect on psychological well-being. Eighth, it has been confirmed that self-esteem has a positive effect on satisfaction. Ninth, it has been confirmed that satisfaction has a positive effect on psychological well-being. These results mean that meeting basic human psychological needs has a significant impact on psychological well-being of the social network service users. In addition, it was confirmed that increasing the desire for autonomy, competence, relationship, which are factors of self-determination, is an important factor to enhance psychological well-being.', 'english_abstract': '', 'citation': 0, 'author': '한정섭;권두순;김성준;', 'author_inst': '남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과;청운대학교 교양대학;남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과;', 'start_page': '85', 'end_page': '108', 'paper_keyword': 'Social Network Service . Self-Esteem . Satisfaction . Psychological Well-Being . Self-Determination Theory', 'issue_lang': 'kor', 'progress': 0.6683333333333333, 'author_id': 's1087982;s1087983;s1087984'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06c'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 1, 'issue_inst': '디지털산업정보학회', 'journal': '디지털산업정보학회논문지 = Journal of the Korea Society of Digital Industry and Information Management', 'issue_year': '2021', 'id': 'JAKO202111735183455', 'title': '소셜 네트워크 서비스 이용자의 자기결정성 요인이 자기존중감과 만족을 통해 심리적 안녕감에 미치는 영향', 'english_title': 'The Effect of Self-Deterministic Factors of Social Network Service Users on Psychological Well-Being by Self-Esteem and Satisfaction', 'abstract': 'In this study, we would like to consider the main factors that influence psychological well-being by using social network service. suggest ways to use healthy social network services, and empirically verify how behavioral approaches, in other words self-determination theory, that deals with human psychological needs, affect psychological well-being by self-esteem and satisfaction to comprehensively examine the characteristics of service and user individuals and social influences, etc. First research result, it has been confirmed that the autonomy has a positive effect on self-esteem. Second, it has been confirmed that the autonomy does not have a positive effect on satisfaction. Third, it has been confirmed that the competence has a positive effect on self-esteem. Fourth, it has been confirmed that the competence does not have a positive effect on satisfaction. Fifth, it has been confirmed that the relationship has a positive effect on self-esteem. Sixth, it has been confirmed that the relationship does not have a positive effect on satisfaction. Seventh, it has been confirmed that self-esteem has a positive effect on psychological well-being. Eighth, it has been confirmed that self-esteem has a positive effect on satisfaction. Ninth, it has been confirmed that satisfaction has a positive effect on psychological well-being. These results mean that meeting basic human psychological needs has a significant impact on psychological well-being of the social network service users. In addition, it was confirmed that increasing the desire for autonomy, competence, relationship, which are factors of self-determination, is an important factor to enhance psychological well-being.', 'english_abstract': '', 'citation': 0, 'author': '한정섭;권두순;김성준;', 'author_inst': '남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과;청운대학교 교양대학;남서울대학교 복지경영대학원 빅데이터콘텐츠융합학과;', 'start_page': '85', 'end_page': '108', 'paper_keyword': 'Social Network Service . Self-Esteem . Satisfaction . Psychological Well-Being . Self-Determination Theory', 'issue_lang': 'kor', 'progress': 0.6683333333333333, 'author_id': 's1087982;s1087983;s1087984'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06f'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 5, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2021', 'id': 'JAKO202112054772449', 'title': '소셜 사물 인터넷 환경에서 차량 간 정보 공유를 위한 신뢰도 판별', 'english_title': 'Vehicle Trust Evaluation for Sharing Data among Vehicles in Social Internet of Things', 'abstract': '소셜 사물 인터넷(SIoT)에서 차량들이 다양한 정보를 생성하고 이를 다른 차량과 공유하고 피드백을 주고 받는 소셜 행위가 이루어진다. 차량 간에 신뢰성 있는 정보를 공유하기 위해서는 차량의 신뢰성을 판별하는 것이 중요하다. 본 논문에서는 차량들 간에 신뢰성 있는 정보를 공유하기 위한 차량 신뢰도 계산 기법을 제안한다. 제안하는 기법은 차량 간 소셜 행위에 기반한 사용자 평판과 네트워크 신뢰도를 고려하여 차량 신뢰도를 판별한다. 차량은 점수 부여, 무시, 재배포 등의 행위를 선택할 수 있으며 이에 따라 사용자 평판이 계산된다. 네트워크 신뢰도를 계산하기 위해 다른 차량과의 거리와 패킷 전송률을 이용한다. 사용자 평판과 네트워크 신뢰도를 이용하여 지역 신뢰도가 계산된다. 이때, 전달되는 데이터의 중복 배포를 방지한다. RSU(Road Side Unit)의 데이터를 활용하여 지역적인 데이터의 한계를 극복하고 전역적인 데이터를 활용하여 보다 더 정확한 차량 신뢰도 계산이 가능하다. 다양한 성능평가를 통해 제안하는 기법이 기존 기법에 비해서 성능이 우수함을 보인다.', 'english_abstract': '', 'citation': 0, 'author': '백연희;복경수;유재수;', 'author_inst': '충북대학교 빅데이터 협동과정;원광대학교 SW 융합학과;충북대학교 정보통신공학부;', 'start_page': '68', 'end_page': '79', 'paper_keyword': '소셜사물인터넷 . 소셜 행위 . 차량 신뢰도 . 네트워크 신뢰도 . 사용자 평판', 'issue_lang': 'kor', 'progress': 0.6749999999999999, 'author_id': 's1087985;s269933;s259873'}
# {'_id': ObjectId('6193944ce9b04a9d64abe070'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 6, 'issue_inst': '한국디지털정책학회', 'journal': '디지털융복합연구 = Journal of digital convergence', 'issue_year': '2021', 'id': 'JAKO202110650791281', 'title': 'SNS 빅데이터 및 검색포털 트렌드와 마약류 사건 통계간의 비교 및 의미분석 연구', 'english_title': 'A Study on the Comparison and Semantic Analysis between SNS Big Data, Search Portal Trends and Drug Case Statistics', 'abstract': 'SNS는 데이터를 통해 사용자의 생각이나 행동을 파악할 수 있고 검색포털의 트렌드는 사용자들의 관심사와 그 변화를 파악할 수 있는 대표적인 서비스이다. 본 논문에서는 SNS의 트윗과 검색포털 트렌드에 마약류관련 단어 노출정도와 마약류 사건 통계와의 비교분석을 수행하여 관계를 분석하였다. SNS와 검색 포털 트렌드의 추이가 일정한 시차를 두고 검찰청 통계에도 동일하게 나타난 것을 확인할 수 있었다. 또한 마약류관련 단어들이 언급된 트윗들에 대한 의미를 파악하기 위해 군집분석을 수행하였다. 2020년 10월에 수집된 5만건 트윗에서는 실제 마약류의 판매에 관련된 의미를 찾을 수 있었다. 이를 통해 SNS모니터링만으로도 마약류관련 사건에 대한 모니터링이 가능하고 구체적 판매 또는 구매관련한 정보를 찾을 수 있고 수사과정에 활용할 수 있다. 추후에는 텍스트뿐 아니라 이미지로 나타나는 관련 범죄사항을 파악할 수 있고 범죄모니터링 및 예측시스템을 제안할 수 있다.', 'english_abstract': '', 'citation': 0, 'author': '최은정;이수련;권혜민;김명주;이인수;이승훈;', 'author_inst': '서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;대검찰청 디지털수사과;대검찰청 디지털수사과;', 'start_page': '231', 'end_page': '238', 'paper_keyword': '소셜네트워크 . 빅데이터 분석 . 군집분석 . 의미분석 . 비교분석', 'issue_lang': 'kor', 'progress': 0.6766666666666666, 'author_id': 's260237;s262239;s1087986;s260240;s1087987;s1087988'}
# {'_id': ObjectId('6193944ce9b04a9d64abe070'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 6, 'issue_inst': '한국디지털정책학회', 'journal': '디지털융복합연구 = Journal of digital convergence', 'issue_year': '2021', 'id': 'JAKO202110650791281', 'title': 'SNS 빅데이터 및 검색포털 트렌드와 마약류 사건 통계간의 비교 및 의미분석 연구', 'english_title': 'A Study on the Comparison and Semantic Analysis between SNS Big Data, Search Portal Trends and Drug Case Statistics', 'abstract': 'SNS는 데이터를 통해 사용자의 생각이나 행동을 파악할 수 있고 검색포털의 트렌드는 사용자들의 관심사와 그 변화를 파악할 수 있는 대표적인 서비스이다. 본 논문에서는 SNS의 트윗과 검색포털 트렌드에 마약류관련 단어 노출정도와 마약류 사건 통계와의 비교분석을 수행하여 관계를 분석하였다. SNS와 검색 포털 트렌드의 추이가 일정한 시차를 두고 검찰청 통계에도 동일하게 나타난 것을 확인할 수 있었다. 또한 마약류관련 단어들이 언급된 트윗들에 대한 의미를 파악하기 위해 군집분석을 수행하였다. 2020년 10월에 수집된 5만건 트윗에서는 실제 마약류의 판매에 관련된 의미를 찾을 수 있었다. 이를 통해 SNS모니터링만으로도 마약류관련 사건에 대한 모니터링이 가능하고 구체적 판매 또는 구매관련한 정보를 찾을 수 있고 수사과정에 활용할 수 있다. 추후에는 텍스트뿐 아니라 이미지로 나타나는 관련 범죄사항을 파악할 수 있고 범죄모니터링 및 예측시스템을 제안할 수 있다.', 'english_abstract': '', 'citation': 0, 'author': '최은정;이수련;권혜민;김명주;이인수;이승훈;', 'author_inst': '서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;대검찰청 디지털수사과;대검찰청 디지털수사과;', 'start_page': '231', 'end_page': '238', 'paper_keyword': '소셜네트워크 . 빅데이터 분석 . 군집분석 . 의미분석 . 비교분석', 'issue_lang': 'kor', 'progress': 0.6766666666666666, 'author_id': 's260237;s262239;s1087986;s260240;s1087987;s1087988'}
# {'_id': ObjectId('6193944ce9b04a9d64abe070'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 6, 'issue_inst': '한국디지털정책학회', 'journal': '디지털융복합연구 = Journal of digital convergence', 'issue_year': '2021', 'id': 'JAKO202110650791281', 'title': 'SNS 빅데이터 및 검색포털 트렌드와 마약류 사건 통계간의 비교 및 의미분석 연구', 'english_title': 'A Study on the Comparison and Semantic Analysis between SNS Big Data, Search Portal Trends and Drug Case Statistics', 'abstract': 'SNS는 데이터를 통해 사용자의 생각이나 행동을 파악할 수 있고 검색포털의 트렌드는 사용자들의 관심사와 그 변화를 파악할 수 있는 대표적인 서비스이다. 본 논문에서는 SNS의 트윗과 검색포털 트렌드에 마약류관련 단어 노출정도와 마약류 사건 통계와의 비교분석을 수행하여 관계를 분석하였다. SNS와 검색 포털 트렌드의 추이가 일정한 시차를 두고 검찰청 통계에도 동일하게 나타난 것을 확인할 수 있었다. 또한 마약류관련 단어들이 언급된 트윗들에 대한 의미를 파악하기 위해 군집분석을 수행하였다. 2020년 10월에 수집된 5만건 트윗에서는 실제 마약류의 판매에 관련된 의미를 찾을 수 있었다. 이를 통해 SNS모니터링만으로도 마약류관련 사건에 대한 모니터링이 가능하고 구체적 판매 또는 구매관련한 정보를 찾을 수 있고 수사과정에 활용할 수 있다. 추후에는 텍스트뿐 아니라 이미지로 나타나는 관련 범죄사항을 파악할 수 있고 범죄모니터링 및 예측시스템을 제안할 수 있다.', 'english_abstract': '', 'citation': 0, 'author': '최은정;이수련;권혜민;김명주;이인수;이승훈;', 'author_inst': '서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;서울여자대학교 정보보호학과;대검찰청 디지털수사과;대검찰청 디지털수사과;', 'start_page': '231', 'end_page': '238', 'paper_keyword': '소셜네트워크 . 빅데이터 분석 . 군집분석 . 의미분석 . 비교분석', 'issue_lang': 'kor', 'progress': 0.6766666666666666, 'author_id': 's260237;s262239;s1087986;s260240;s1087987;s1087988'}
# {'_id': ObjectId('6193944de9b04a9d64abe072'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 14, 'issue_inst': '한국컴퓨터정보학회', 'journal': '한국컴퓨터정보학회 2021년도 제63차 동계학술대회논문집 29권1호', 'issue_year': '2021', 'id': 'NPAP13342660', 'title': '빅데이터 기반 항공 수요예측 통합 플랫폼 설계 및 실증', 'english_title': 'P-TAF: A Big Data-based Platform for Total Air Traffic Forecast', 'abstract': '본 논문에서는 항공 수요예측을 위한 빅데이터 기반 플랫폼의 설계 및 실증 결과를 제시한다. 항공 수요예측 통합 플랫폼은 항공산업 관련 데이터를 Open API, RSS Feed, 웹크롤러(Web Crawler) 등을 이용하여 수집 및 분석하여 자체 개발한 항공 수요예측 알고리즘을 기반으로 결과를 시각화하여 보여주도록 구현되어 있다. 또한, 제안하는 플랫폼의 사용자 인터페이스를 통해 변수 설정을 하여 단위별(Global, National 등), 기간별(단기, 중장기 등), 유형별(여객, 화물 등) 예측 통계 자료를 도출할 수 있다. 플랫폼의 성능 검증을 위해 정형화된 데이터를 비롯하여 소셜네트워크서비스(SNS), 검색엔진 등에서 수집한 비정형 데이터까지 활용하여 특정 키워드의 빈도와 특정 노선에 대한 항공 수요간 상관관계를 분석하였다. 개발한 통합 플랫폼의 지능형 항공 수요예측 알고리즘을 통해 전반적인 공항 운영 및 공항 운영 정책 수립에 기여할 것으로 예상한다.', 'english_abstract': '', 'citation': 0, 'author': '정주익;손석현;차희준;', 'author_inst': '인천국제공항공사 공항산업기술연구원;인천국제공항공사 공항산업기술연구원;인천국제공항공사 공항산업기술연구원;', 'start_page': '281', 'end_page': '282', 'paper_keyword': '빅데이터 . 항공 수요예측 . 데이터 마이닝 . Big Data . Air Traffic Forecast . Data Mining', 'issue_lang': 'kor', 'progress': 0.69, 'author_id': 's1087989;s1087990;s1087991'}
# {'_id': ObjectId('6193944de9b04a9d64abe072'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 14, 'issue_inst': '한국컴퓨터정보학회', 'journal': '한국컴퓨터정보학회 2021년도 제63차 동계학술대회논문집 29권1호', 'issue_year': '2021', 'id': 'NPAP13342660', 'title': '빅데이터 기반 항공 수요예측 통합 플랫폼 설계 및 실증', 'english_title': 'P-TAF: A Big Data-based Platform for Total Air Traffic Forecast', 'abstract': '본 논문에서는 항공 수요예측을 위한 빅데이터 기반 플랫폼의 설계 및 실증 결과를 제시한다. 항공 수요예측 통합 플랫폼은 항공산업 관련 데이터를 Open API, RSS Feed, 웹크롤러(Web Crawler) 등을 이용하여 수집 및 분석하여 자체 개발한 항공 수요예측 알고리즘을 기반으로 결과를 시각화하여 보여주도록 구현되어 있다. 또한, 제안하는 플랫폼의 사용자 인터페이스를 통해 변수 설정을 하여 단위별(Global, National 등), 기간별(단기, 중장기 등), 유형별(여객, 화물 등) 예측 통계 자료를 도출할 수 있다. 플랫폼의 성능 검증을 위해 정형화된 데이터를 비롯하여 소셜네트워크서비스(SNS), 검색엔진 등에서 수집한 비정형 데이터까지 활용하여 특정 키워드의 빈도와 특정 노선에 대한 항공 수요간 상관관계를 분석하였다. 개발한 통합 플랫폼의 지능형 항공 수요예측 알고리즘을 통해 전반적인 공항 운영 및 공항 운영 정책 수립에 기여할 것으로 예상한다.', 'english_abstract': '', 'citation': 0, 'author': '정주익;손석현;차희준;', 'author_inst': '인천국제공항공사 공항산업기술연구원;인천국제공항공사 공항산업기술연구원;인천국제공항공사 공항산업기술연구원;', 'start_page': '281', 'end_page': '282', 'paper_keyword': '빅데이터 . 항공 수요예측 . 데이터 마이닝 . Big Data . Air Traffic Forecast . Data Mining', 'issue_lang': 'kor', 'progress': 0.69, 'author_id': 's1087989;s1087990;s1087991'}
# {'_id': ObjectId('6193944de9b04a9d64abe072'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 14, 'issue_inst': '한국컴퓨터정보학회', 'journal': '한국컴퓨터정보학회 2021년도 제63차 동계학술대회논문집 29권1호', 'issue_year': '2021', 'id': 'NPAP13342660', 'title': '빅데이터 기반 항공 수요예측 통합 플랫폼 설계 및 실증', 'english_title': 'P-TAF: A Big Data-based Platform for Total Air Traffic Forecast', 'abstract': '본 논문에서는 항공 수요예측을 위한 빅데이터 기반 플랫폼의 설계 및 실증 결과를 제시한다. 항공 수요예측 통합 플랫폼은 항공산업 관련 데이터를 Open API, RSS Feed, 웹크롤러(Web Crawler) 등을 이용하여 수집 및 분석하여 자체 개발한 항공 수요예측 알고리즘을 기반으로 결과를 시각화하여 보여주도록 구현되어 있다. 또한, 제안하는 플랫폼의 사용자 인터페이스를 통해 변수 설정을 하여 단위별(Global, National 등), 기간별(단기, 중장기 등), 유형별(여객, 화물 등) 예측 통계 자료를 도출할 수 있다. 플랫폼의 성능 검증을 위해 정형화된 데이터를 비롯하여 소셜네트워크서비스(SNS), 검색엔진 등에서 수집한 비정형 데이터까지 활용하여 특정 키워드의 빈도와 특정 노선에 대한 항공 수요간 상관관계를 분석하였다. 개발한 통합 플랫폼의 지능형 항공 수요예측 알고리즘을 통해 전반적인 공항 운영 및 공항 운영 정책 수립에 기여할 것으로 예상한다.', 'english_abstract': '', 'citation': 0, 'author': '정주익;손석현;차희준;', 'author_inst': '인천국제공항공사 공항산업기술연구원;인천국제공항공사 공항산업기술연구원;인천국제공항공사 공항산업기술연구원;', 'start_page': '281', 'end_page': '282', 'paper_keyword': '빅데이터 . 항공 수요예측 . 데이터 마이닝 . Big Data . Air Traffic Forecast . Data Mining', 'issue_lang': 'kor', 'progress': 0.69, 'author_id': 's1087989;s1087990;s1087991'}
# {'_id': ObjectId('61939443e9b04a9d64abe057'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 7, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2019', 'id': 'JAKO201909469054625', 'title': '소셜 빅데이터 기반 융합연구 동향 분석', 'english_title': 'Trend Analysis of Convergence Research based on Social Big Data', 'abstract': '본 연구는 4차 산업혁명과 함께 학제간 융합연구의 중요성이 부각되는 시점에서 소셜미디어 빅데이터 분석을 통하여 학술적 연구를 넘어 융합연구 전반에 대한 동향을 분석하고자 하였다. 이를 위해 텍스트마이닝 기법을 활용하여 소셜미디어에서 융합연구와 관련하여 2009년 1월부터 2018년 9월까지 약 10년간 게시된 글과 제목 등 약 150,000건을 수집하였으며, 이를 바탕으로 기간별로 워드클라우드와 네트워크 분석을 실시하였다. 분석결과, 각 기간별로 활발하게 진행된 연구분야는 2009년과 2010년에는 친환경, 2011년과 2012년에는 스마트, 2013년과 2014년에는 정보통신, 2015년과 2016년에는 로봇, 2017년과 2018년에는 인공지능이다. 또한 약 10년간 지속적으로 수행되고 있는 연구분야는 문화, 디자인, 화학, 나노, 바이오, 로봇, IT, 정보통신이다. 본 연구에서는 기간별 융합연구 동향을 파악하므로 써, 융합연구를 기획하고 있는 연구자들에게 연구방향을 설정하는데 있어 도움이 될 수 있다.', 'english_abstract': '', 'citation': 0, 'author': '노영희;김태연;정대근;이광희;', 'author_inst': '건국대학교 문헌정보학과;건국대학교 지식콘텐츠연구소;전남대학교 문헌정보학과;한국연구재단 인재양성실;', 'start_page': '135', 'end_page': '146', 'paper_keyword': '소셜미디어 . 빅데이터 . 융합연구 . 워드클라우드 . 네트워크 분석', 'issue_lang': 'kor', 'progress': 0.011666666666666667, 'author_id': 's122643;s261731;s261732;s261733'}
# {'_id': ObjectId('61939443e9b04a9d64abe05e'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 17, 'issue_inst': 'The Korea Institute of Information and Commucation Engineering', 'journal': '한국정보통신학회 2019년도 춘계학술대회', 'issue_year': '2019', 'id': 'NPAP12901185', 'title': 'Big Data Analysis Using on Based Social Network Service Data', 'english_title': '소셜네트워크서비스 기반 데이터를 이용한 빅데이터 분석', 'abstract': '빅데이터 분석은 기존 데이터베이스 관리 도구로부터 데이터를 수집, 저장, 관리, 분석할 수 있는 역량을 말한다. 빅데이터는 디지털 환경에서 생성되는 데이터로 그 규모가 방대하고, 생성 주기도 짧고, 형태도 수치 데이터뿐만 아니라 문자와 영상 데이터를 포함하는 대규모 데이터를 말한다. 빅데이터는 기존 방식으로는 관리와 분석이 어려운 데이터를 의미하며, 거대한 크기(Volume), 다양한 형태(Variety), 빠른 생성 및 유통속도(Velocity)의 특징을 가지고 있다. 따라서 대부분의 산업에서 기업들은 빅데이터의 적용을 통해 가치 창출을 위한 노력을 기하고 있다. 본 연구에서는 다음 커뮤니케이션의 빅데이터 분석도구인 소셜 매트릭스를 활용하여 키워드 의미를 분석하였다. 또한, 분석결과를 바탕으로 이론적 실무적 시사점을 제시하고자 한다.', 'english_abstract': '', 'citation': 0, 'author': '남수태;신성윤;진찬용;', 'author_inst': 'Wonkwang University;Kunsan National University;Wonkwang University;', 'start_page': '165', 'end_page': '166', 'paper_keyword': [], 'issue_lang': 'eng', 'progress': 0.028333333333333335, 'author_id': 's143724;s143723;s143722'}
# {'_id': ObjectId('61939443e9b04a9d64abe05e'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 17, 'issue_inst': 'The Korea Institute of Information and Commucation Engineering', 'journal': '한국정보통신학회 2019년도 춘계학술대회', 'issue_year': '2019', 'id': 'NPAP12901185', 'title': 'Big Data Analysis Using on Based Social Network Service Data', 'english_title': '소셜네트워크서비스 기반 데이터를 이용한 빅데이터 분석', 'abstract': '빅데이터 분석은 기존 데이터베이스 관리 도구로부터 데이터를 수집, 저장, 관리, 분석할 수 있는 역량을 말한다. 빅데이터는 디지털 환경에서 생성되는 데이터로 그 규모가 방대하고, 생성 주기도 짧고, 형태도 수치 데이터뿐만 아니라 문자와 영상 데이터를 포함하는 대규모 데이터를 말한다. 빅데이터는 기존 방식으로는 관리와 분석이 어려운 데이터를 의미하며, 거대한 크기(Volume), 다양한 형태(Variety), 빠른 생성 및 유통속도(Velocity)의 특징을 가지고 있다. 따라서 대부분의 산업에서 기업들은 빅데이터의 적용을 통해 가치 창출을 위한 노력을 기하고 있다. 본 연구에서는 다음 커뮤니케이션의 빅데이터 분석도구인 소셜 매트릭스를 활용하여 키워드 의미를 분석하였다. 또한, 분석결과를 바탕으로 이론적 실무적 시사점을 제시하고자 한다.', 'english_abstract': '', 'citation': 0, 'author': '남수태;신성윤;진찬용;', 'author_inst': 'Wonkwang University;Kunsan National University;Wonkwang University;', 'start_page': '165', 'end_page': '166', 'paper_keyword': [], 'issue_lang': 'eng', 'progress': 0.028333333333333335, 'author_id': 's143724;s143723;s143722'}
# {'_id': ObjectId('61939443e9b04a9d64abe05e'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 17, 'issue_inst': 'The Korea Institute of Information and Commucation Engineering', 'journal': '한국정보통신학회 2019년도 춘계학술대회', 'issue_year': '2019', 'id': 'NPAP12901185', 'title': 'Big Data Analysis Using on Based Social Network Service Data', 'english_title': '소셜네트워크서비스 기반 데이터를 이용한 빅데이터 분석', 'abstract': '빅데이터 분석은 기존 데이터베이스 관리 도구로부터 데이터를 수집, 저장, 관리, 분석할 수 있는 역량을 말한다. 빅데이터는 디지털 환경에서 생성되는 데이터로 그 규모가 방대하고, 생성 주기도 짧고, 형태도 수치 데이터뿐만 아니라 문자와 영상 데이터를 포함하는 대규모 데이터를 말한다. 빅데이터는 기존 방식으로는 관리와 분석이 어려운 데이터를 의미하며, 거대한 크기(Volume), 다양한 형태(Variety), 빠른 생성 및 유통속도(Velocity)의 특징을 가지고 있다. 따라서 대부분의 산업에서 기업들은 빅데이터의 적용을 통해 가치 창출을 위한 노력을 기하고 있다. 본 연구에서는 다음 커뮤니케이션의 빅데이터 분석도구인 소셜 매트릭스를 활용하여 키워드 의미를 분석하였다. 또한, 분석결과를 바탕으로 이론적 실무적 시사점을 제시하고자 한다.', 'english_abstract': '', 'citation': 0, 'author': '남수태;신성윤;진찬용;', 'author_inst': 'Wonkwang University;Kunsan National University;Wonkwang University;', 'start_page': '165', 'end_page': '166', 'paper_keyword': [], 'issue_lang': 'eng', 'progress': 0.028333333333333335, 'author_id': 's143724;s143723;s143722'}
# {'_id': ObjectId('61939447e9b04a9d64abe069'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 15, 'issue_inst': '한국조경학회', 'journal': '한국조경학회지 = Journal of Korean institute of landscape architecture', 'issue_year': '2020', 'id': 'JAKO202007636555367', 'title': '서울로 7017 방문자들의 이용행태 분석 -텍스트 마이닝과 소셜 네트워크 분석을 중심으로-', 'english_title': 'Analysis of Behavior of Seoullo 7017 Visitors - With a Focus on Text Mining and Social Network Analysis -', 'abstract': "본 연구는 국내 최초의 공중보행로인 서울로 7017의 이용행태를 이용객이 자율적으로 서술한 블로그를 분석하여 이용현황을 파악하고, 서울로 7017의 이용행태 및 개선방안을 제시하는 것을 목적으로 하였다. 이에 서울로 7017이 시민에게 개방된 2017년 6월부터 2020년 5월까지로 검색엔진 NAVER&#183;DAUM의 블로그 제목과 원문에 '서울로 7017'이 포함된 텍스트 데이터를 빅데이터 기법인 텍스트 마이닝(Text Mining)과 소셜 네트워크(Social Network; 사회연결망)분석을 활용하여 분석하였다. 연구결과의 요약은 다음과 같다. 먼저 서울로 7017의 주요 행태는 '야경'과 '걷다'이고, 영향을 미치는 요소는 문화&#183;예술과 관련된 요소로 여러 가지 프로그램 및 축제를 이용객의 요구에 맞는 프로그램을 개설하고 적극적으로 알린다면 주요 행태가 더 활발하게 일어나게 할 수 있을 것이다. 한편, 서울로 7017의 이용객들이 원하는 주요행태는 정적 행태인 '앉다'인데, 앉는 행태가 일어나기에 물리적인 조건이 충분하지 않으므로 그늘, 벤치 등 앉는 행태가 일어날 수 있는 시설을 개선하여 방문객의 요구를 충족시킬 수 있을 것이다. 서울로 7017의 행태변화의 특이점으로 코로나19로 인하여 공공다중이용시설 및 집단 활동이 제한되면서 혼자 여행하기 좋은 곳, 혼자 산책하기 좋은 곳으로 인식되고 있다는 점이다. 이에 코로나19와 같은 상황에서 사람들이 산책 등을 할 수 있는 시설, 여러 가지 볼거리 증대 등을 통하여 더 다양한 행태가 도출될 수 있고, 이용객의 만족도를 높일 수 있다. 서울로 7017은 국내 최초의 공중보행로서 공공공간의 의미를 넘어 주변 지역의 도시재생 및 도시자원의 효율적 활용을 위하여 조성되었으며, 역사, 자연, 복지, 문화, 관광자원 등 다양한 가치를 지니고 있는 장소이다. 그러나 이용행태 분석 결과, 서울로 7017에서 다양한 행태가 일어나지 않고 있으며, 주요 행태를 방해하는 요소가 도출되었다. 이러한 연구 결과를 참고하여 서울로 7017의 이용행태를 파악하고, 공간체계 및 시설 개선의 계획을 수립하여 서울로 7017이 도시민들에게 중요한 장소이자 도시를 활성화하는 동력이 될 수 있도록 발전시켜 나가야 할 것이다.", 'english_abstract': '', 'citation': 0, 'author': '우경숙;서주환;', 'author_inst': '경희대학교 일반대학원 환경조경학과;경희대학교 예술.디자인대학 환경조경디자인학과;', 'start_page': '16', 'end_page': '24', 'paper_keyword': '서울로 7017 . 이용행태 . 텍스트 마이닝 . 소셜 네트워크 분석', 'issue_lang': 'kor', 'progress': 0.35833333333333334, 'author_id': 's259681;s152628'}
# {'_id': ObjectId('61939443e9b04a9d64abe055'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 4, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2019', 'id': 'JAKO201909469054948', 'title': '온라인 쇼핑몰에서 상품 신뢰도를 고려한 개인화 추천', 'english_title': 'Personalized Recommendation Considering Item Confidence in E-Commerce', 'abstract': '온라인 쇼핑몰의 대중화로 인해 소비자는 폭 넓은 소비의 기회를 제공받고 있다. 소비자들은 온라인 쇼핑몰에서 제공되는 실제 상품을 구매한 사용자의 리뷰, 상품의 자세한 정보와 같은 정보를 활용하여 상품의 구매 여부를 결정한다. 방대한 정보가 신뢰할 수 있는 정보인지는 소비자들이 스스로 판단해야만하기 때문에 객관적이며 신뢰할 수 있는 정보의 제공이 필요하다. 본 논문에서는 신뢰할 수 있는 상품의 추천을 위해서 상품의 신뢰도를 고려한 개인화된 추천 기법을 제안한다. 제안하는 추천 기법은 개인화 추천을 위해서 사용자의 다양한 행위를 기반으로 사용자의 선호도를 판별한다. 또한, 최신의 성향을 반영하기 위해서 시간 가중치를 고려한 사용자 선호도 계산 방법을 제안한다. 마지막으로 사용자가 사용하지 않았던 상품에 대한 선호 점수를 예측하고 예측 점수가 높은 상품 중 신뢰도가 높은 상품들을 추천한다.', 'english_abstract': '', 'citation': 0, 'author': '최도진;박재열;박수빈;임종태;송재오;복경수;유재수;', 'author_inst': '충북대학교 정보통신공학과;충북대학교 정보통신공학과;충북대학교 빅데이터협동과정;충북대학교 정보통신공학과;(주) 제오시스 기업부설연구소;충북대학교 정보통신공학과;충북대학교 정보통신공학과;', 'start_page': '171', 'end_page': '182', 'paper_keyword': '온라인 쇼핑몰 . 상품 신뢰도 . 개인화 추천 . 협업 필터링 . 소셜 네트워크 서비스', 'issue_lang': 'kor', 'progress': 0.006666666666666667, 'author_id': 's259546;s258762;s261641;s258361;s261642;s258056;s258057'}
# {'_id': ObjectId('61939443e9b04a9d64abe055'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 4, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2019', 'id': 'JAKO201909469054948', 'title': '온라인 쇼핑몰에서 상품 신뢰도를 고려한 개인화 추천', 'english_title': 'Personalized Recommendation Considering Item Confidence in E-Commerce', 'abstract': '온라인 쇼핑몰의 대중화로 인해 소비자는 폭 넓은 소비의 기회를 제공받고 있다. 소비자들은 온라인 쇼핑몰에서 제공되는 실제 상품을 구매한 사용자의 리뷰, 상품의 자세한 정보와 같은 정보를 활용하여 상품의 구매 여부를 결정한다. 방대한 정보가 신뢰할 수 있는 정보인지는 소비자들이 스스로 판단해야만하기 때문에 객관적이며 신뢰할 수 있는 정보의 제공이 필요하다. 본 논문에서는 신뢰할 수 있는 상품의 추천을 위해서 상품의 신뢰도를 고려한 개인화된 추천 기법을 제안한다. 제안하는 추천 기법은 개인화 추천을 위해서 사용자의 다양한 행위를 기반으로 사용자의 선호도를 판별한다. 또한, 최신의 성향을 반영하기 위해서 시간 가중치를 고려한 사용자 선호도 계산 방법을 제안한다. 마지막으로 사용자가 사용하지 않았던 상품에 대한 선호 점수를 예측하고 예측 점수가 높은 상품 중 신뢰도가 높은 상품들을 추천한다.', 'english_abstract': '', 'citation': 0, 'author': '최도진;박재열;박수빈;임종태;송재오;복경수;유재수;', 'author_inst': '충북대학교 정보통신공학과;충북대학교 정보통신공학과;충북대학교 빅데이터협동과정;충북대학교 정보통신공학과;(주) 제오시스 기업부설연구소;충북대학교 정보통신공학과;충북대학교 정보통신공학과;', 'start_page': '171', 'end_page': '182', 'paper_keyword': '온라인 쇼핑몰 . 상품 신뢰도 . 개인화 추천 . 협업 필터링 . 소셜 네트워크 서비스', 'issue_lang': 'kor', 'progress': 0.006666666666666667, 'author_id': 's259546;s258762;s261641;s258361;s261642;s258056;s258057'}
# {'_id': ObjectId('61939443e9b04a9d64abe055'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 4, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2019', 'id': 'JAKO201909469054948', 'title': '온라인 쇼핑몰에서 상품 신뢰도를 고려한 개인화 추천', 'english_title': 'Personalized Recommendation Considering Item Confidence in E-Commerce', 'abstract': '온라인 쇼핑몰의 대중화로 인해 소비자는 폭 넓은 소비의 기회를 제공받고 있다. 소비자들은 온라인 쇼핑몰에서 제공되는 실제 상품을 구매한 사용자의 리뷰, 상품의 자세한 정보와 같은 정보를 활용하여 상품의 구매 여부를 결정한다. 방대한 정보가 신뢰할 수 있는 정보인지는 소비자들이 스스로 판단해야만하기 때문에 객관적이며 신뢰할 수 있는 정보의 제공이 필요하다. 본 논문에서는 신뢰할 수 있는 상품의 추천을 위해서 상품의 신뢰도를 고려한 개인화된 추천 기법을 제안한다. 제안하는 추천 기법은 개인화 추천을 위해서 사용자의 다양한 행위를 기반으로 사용자의 선호도를 판별한다. 또한, 최신의 성향을 반영하기 위해서 시간 가중치를 고려한 사용자 선호도 계산 방법을 제안한다. 마지막으로 사용자가 사용하지 않았던 상품에 대한 선호 점수를 예측하고 예측 점수가 높은 상품 중 신뢰도가 높은 상품들을 추천한다.', 'english_abstract': '', 'citation': 0, 'author': '최도진;박재열;박수빈;임종태;송재오;복경수;유재수;', 'author_inst': '충북대학교 정보통신공학과;충북대학교 정보통신공학과;충북대학교 빅데이터협동과정;충북대학교 정보통신공학과;(주) 제오시스 기업부설연구소;충북대학교 정보통신공학과;충북대학교 정보통신공학과;', 'start_page': '171', 'end_page': '182', 'paper_keyword': '온라인 쇼핑몰 . 상품 신뢰도 . 개인화 추천 . 협업 필터링 . 소셜 네트워크 서비스', 'issue_lang': 'kor', 'progress': 0.006666666666666667, 'author_id': 's259546;s258762;s261641;s258361;s261642;s258056;s258057'}
# {'_id': ObjectId('61939443e9b04a9d64abe055'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 4, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2019', 'id': 'JAKO201909469054948', 'title': '온라인 쇼핑몰에서 상품 신뢰도를 고려한 개인화 추천', 'english_title': 'Personalized Recommendation Considering Item Confidence in E-Commerce', 'abstract': '온라인 쇼핑몰의 대중화로 인해 소비자는 폭 넓은 소비의 기회를 제공받고 있다. 소비자들은 온라인 쇼핑몰에서 제공되는 실제 상품을 구매한 사용자의 리뷰, 상품의 자세한 정보와 같은 정보를 활용하여 상품의 구매 여부를 결정한다. 방대한 정보가 신뢰할 수 있는 정보인지는 소비자들이 스스로 판단해야만하기 때문에 객관적이며 신뢰할 수 있는 정보의 제공이 필요하다. 본 논문에서는 신뢰할 수 있는 상품의 추천을 위해서 상품의 신뢰도를 고려한 개인화된 추천 기법을 제안한다. 제안하는 추천 기법은 개인화 추천을 위해서 사용자의 다양한 행위를 기반으로 사용자의 선호도를 판별한다. 또한, 최신의 성향을 반영하기 위해서 시간 가중치를 고려한 사용자 선호도 계산 방법을 제안한다. 마지막으로 사용자가 사용하지 않았던 상품에 대한 선호 점수를 예측하고 예측 점수가 높은 상품 중 신뢰도가 높은 상품들을 추천한다.', 'english_abstract': '', 'citation': 0, 'author': '최도진;박재열;박수빈;임종태;송재오;복경수;유재수;', 'author_inst': '충북대학교 정보통신공학과;충북대학교 정보통신공학과;충북대학교 빅데이터협동과정;충북대학교 정보통신공학과;(주) 제오시스 기업부설연구소;충북대학교 정보통신공학과;충북대학교 정보통신공학과;', 'start_page': '171', 'end_page': '182', 'paper_keyword': '온라인 쇼핑몰 . 상품 신뢰도 . 개인화 추천 . 협업 필터링 . 소셜 네트워크 서비스', 'issue_lang': 'kor', 'progress': 0.006666666666666667, 'author_id': 's259546;s258762;s261641;s258361;s261642;s258056;s258057'}
# {'_id': ObjectId('61939443e9b04a9d64abe059'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 10, 'issue_inst': '한국빅데이터학회', 'journal': 'The journal of Bigdata = 한국빅데이터학회지', 'issue_year': '2019', 'id': 'JAKO201919163740652', 'title': '소셜 미디어 참여에 관한 연구 동향과 쟁점의 변화: 네트워크 분석과 클러스터링 기법을 활용한 메타 분석을 중심으로', 'english_title': 'Trends in Social Media Participation and Change in ssues with Meta Analysis Using Network Analysis and Clustering Technique', 'abstract': '본 연구는 소셜 미디어 참여 관련 연구 베타분석을 위해 네트워크 분석과 클러스터링 기법을 활용하였다. 주경로 분석 결과 37개의 주요 연구가 추출되었고 커뮤니티 관련 네트워크와 뉴 미디어 관련 네트워크 두 가지로 구분되었다. 연결망 분석과 클러스터링 결과 네가지 클러스터가 형성되었다. 본 연구는 학술 데이터를 활용해 연구 동향을 거시적으로 파악하며 그 방법론으로 네트워크 분석과 기계학습을 활용하였다는 학술적 의의를 가진다.', 'english_abstract': '', 'citation': 0, 'author': '신현보;선형주;이준기;', 'author_inst': '연세대학교 정보대학원;연세대학교 정보대학원;연세대학교 정보대학원;', 'start_page': '99', 'end_page': '118', 'paper_keyword': '소셜 미디어 참여 . 온라인 참여 . 메타분석 . 주경로 분석 . 사회 연결망 분석 . 머신러닝 . 클러스터링 . 자연어 처리', 'issue_lang': 'kor', 'progress': 0.016666666666666666, 'author_id': 's261869;s261870;s259510'}
# {'_id': ObjectId('61939443e9b04a9d64abe055'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 4, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2019', 'id': 'JAKO201909469054948', 'title': '온라인 쇼핑몰에서 상품 신뢰도를 고려한 개인화 추천', 'english_title': 'Personalized Recommendation Considering Item Confidence in E-Commerce', 'abstract': '온라인 쇼핑몰의 대중화로 인해 소비자는 폭 넓은 소비의 기회를 제공받고 있다. 소비자들은 온라인 쇼핑몰에서 제공되는 실제 상품을 구매한 사용자의 리뷰, 상품의 자세한 정보와 같은 정보를 활용하여 상품의 구매 여부를 결정한다. 방대한 정보가 신뢰할 수 있는 정보인지는 소비자들이 스스로 판단해야만하기 때문에 객관적이며 신뢰할 수 있는 정보의 제공이 필요하다. 본 논문에서는 신뢰할 수 있는 상품의 추천을 위해서 상품의 신뢰도를 고려한 개인화된 추천 기법을 제안한다. 제안하는 추천 기법은 개인화 추천을 위해서 사용자의 다양한 행위를 기반으로 사용자의 선호도를 판별한다. 또한, 최신의 성향을 반영하기 위해서 시간 가중치를 고려한 사용자 선호도 계산 방법을 제안한다. 마지막으로 사용자가 사용하지 않았던 상품에 대한 선호 점수를 예측하고 예측 점수가 높은 상품 중 신뢰도가 높은 상품들을 추천한다.', 'english_abstract': '', 'citation': 0, 'author': '최도진;박재열;박수빈;임종태;송재오;복경수;유재수;', 'author_inst': '충북대학교 정보통신공학과;충북대학교 정보통신공학과;충북대학교 빅데이터협동과정;충북대학교 정보통신공학과;(주) 제오시스 기업부설연구소;충북대학교 정보통신공학과;충북대학교 정보통신공학과;', 'start_page': '171', 'end_page': '182', 'paper_keyword': '온라인 쇼핑몰 . 상품 신뢰도 . 개인화 추천 . 협업 필터링 . 소셜 네트워크 서비스', 'issue_lang': 'kor', 'progress': 0.006666666666666667, 'author_id': 's259546;s258762;s261641;s258361;s261642;s258056;s258057'}
# {'_id': ObjectId('61939447e9b04a9d64abe069'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 15, 'issue_inst': '한국조경학회', 'journal': '한국조경학회지 = Journal of Korean institute of landscape architecture', 'issue_year': '2020', 'id': 'JAKO202007636555367', 'title': '서울로 7017 방문자들의 이용행태 분석 -텍스트 마이닝과 소셜 네트워크 분석을 중심으로-', 'english_title': 'Analysis of Behavior of Seoullo 7017 Visitors - With a Focus on Text Mining and Social Network Analysis -', 'abstract': "본 연구는 국내 최초의 공중보행로인 서울로 7017의 이용행태를 이용객이 자율적으로 서술한 블로그를 분석하여 이용현황을 파악하고, 서울로 7017의 이용행태 및 개선방안을 제시하는 것을 목적으로 하였다. 이에 서울로 7017이 시민에게 개방된 2017년 6월부터 2020년 5월까지로 검색엔진 NAVER&#183;DAUM의 블로그 제목과 원문에 '서울로 7017'이 포함된 텍스트 데이터를 빅데이터 기법인 텍스트 마이닝(Text Mining)과 소셜 네트워크(Social Network; 사회연결망)분석을 활용하여 분석하였다. 연구결과의 요약은 다음과 같다. 먼저 서울로 7017의 주요 행태는 '야경'과 '걷다'이고, 영향을 미치는 요소는 문화&#183;예술과 관련된 요소로 여러 가지 프로그램 및 축제를 이용객의 요구에 맞는 프로그램을 개설하고 적극적으로 알린다면 주요 행태가 더 활발하게 일어나게 할 수 있을 것이다. 한편, 서울로 7017의 이용객들이 원하는 주요행태는 정적 행태인 '앉다'인데, 앉는 행태가 일어나기에 물리적인 조건이 충분하지 않으므로 그늘, 벤치 등 앉는 행태가 일어날 수 있는 시설을 개선하여 방문객의 요구를 충족시킬 수 있을 것이다. 서울로 7017의 행태변화의 특이점으로 코로나19로 인하여 공공다중이용시설 및 집단 활동이 제한되면서 혼자 여행하기 좋은 곳, 혼자 산책하기 좋은 곳으로 인식되고 있다는 점이다. 이에 코로나19와 같은 상황에서 사람들이 산책 등을 할 수 있는 시설, 여러 가지 볼거리 증대 등을 통하여 더 다양한 행태가 도출될 수 있고, 이용객의 만족도를 높일 수 있다. 서울로 7017은 국내 최초의 공중보행로서 공공공간의 의미를 넘어 주변 지역의 도시재생 및 도시자원의 효율적 활용을 위하여 조성되었으며, 역사, 자연, 복지, 문화, 관광자원 등 다양한 가치를 지니고 있는 장소이다. 그러나 이용행태 분석 결과, 서울로 7017에서 다양한 행태가 일어나지 않고 있으며, 주요 행태를 방해하는 요소가 도출되었다. 이러한 연구 결과를 참고하여 서울로 7017의 이용행태를 파악하고, 공간체계 및 시설 개선의 계획을 수립하여 서울로 7017이 도시민들에게 중요한 장소이자 도시를 활성화하는 동력이 될 수 있도록 발전시켜 나가야 할 것이다.", 'english_abstract': '', 'citation': 0, 'author': '우경숙;서주환;', 'author_inst': '경희대학교 일반대학원 환경조경학과;경희대학교 예술.디자인대학 환경조경디자인학과;', 'start_page': '16', 'end_page': '24', 'paper_keyword': '서울로 7017 . 이용행태 . 텍스트 마이닝 . 소셜 네트워크 분석', 'issue_lang': 'kor', 'progress': 0.35833333333333334, 'author_id': 's259681;s152628'}
# {'_id': ObjectId('6193944ce9b04a9d64abe071'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 7, 'issue_inst': 'The Korea Institute of Information and Commucation Engineering', 'journal': '한국정보통신학회논문지 = Journal of the Korea Institute of Information and Communication Engineering', 'issue_year': '2021', 'id': 'JAKO202128640525157', 'title': '빅데이터 분석 도구 R을 이용한 비정형 데이터 텍스트 마이닝과 시각화', 'english_title': 'Text Mining and Visualization of Unstructured Data Using Big Data Analytical Tool R', 'abstract': "빅데이터 시대에는 단순히 데이터베이스에 잘 정리된 정형 데이터뿐만 아니라 인터넷, 소셜 네트워크 서비스, 모바일 환경에서 실시간 생성되는 웹 문서, 이메일, 소셜 데이터 등 비정형 빅데이터를 효과적으로 분석하는 것이 매우 중요하다. 빅데이터 분석은 데이터 저장소에 저장된 빅데이터 속에서 의미 있는 새로운 상관관계, 패턴, 추세를 발견하여 새로운 가치를 창출하는 과정이다. 빅데이터 분석 도구인 R 언어를 이용하여 비정형 논문 데이터를 빈도분석을 통해 분석결과를 요약과 시각화하고자 한다. 본 연구에서 사용된 데이터는 한국정보통신학회 학회지 논문 중에서 2021년 1월호-5월호 총 논문 104편을 대상으로 분석하였다. 최종 분석결과 가장 많이 언급된 키워드는 '데이터'가 1,538회로 1위를 차지하였다. 따라서 분석결과를 바탕으로 연구의 한계와 이론적 실무적 시사점을 제시하고자 한다.", 'english_abstract': '', 'citation': 0, 'author': 'Nam, Soo-Tai;Shin, Seong-Yoon;Jin, Chan-Yong;', 'author_inst': 'Institute of General Education, Pusan National University;School of Computer Information & Communication Engineering, Kunsan National University;Division of Information & Electronic Commerce, Wonkwang University;', 'start_page': '1199', 'end_page': '1205', 'paper_keyword': '네트워크 분석 . 비정형 데이터 . 빅데이터 . 연관성 분석 . 텍스트 마이닝', 'issue_lang': 'kor', 'progress': 0.6783333333333333, 'author_id': 's640916;s259765;s640917'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06f'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 5, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2021', 'id': 'JAKO202112054772449', 'title': '소셜 사물 인터넷 환경에서 차량 간 정보 공유를 위한 신뢰도 판별', 'english_title': 'Vehicle Trust Evaluation for Sharing Data among Vehicles in Social Internet of Things', 'abstract': '소셜 사물 인터넷(SIoT)에서 차량들이 다양한 정보를 생성하고 이를 다른 차량과 공유하고 피드백을 주고 받는 소셜 행위가 이루어진다. 차량 간에 신뢰성 있는 정보를 공유하기 위해서는 차량의 신뢰성을 판별하는 것이 중요하다. 본 논문에서는 차량들 간에 신뢰성 있는 정보를 공유하기 위한 차량 신뢰도 계산 기법을 제안한다. 제안하는 기법은 차량 간 소셜 행위에 기반한 사용자 평판과 네트워크 신뢰도를 고려하여 차량 신뢰도를 판별한다. 차량은 점수 부여, 무시, 재배포 등의 행위를 선택할 수 있으며 이에 따라 사용자 평판이 계산된다. 네트워크 신뢰도를 계산하기 위해 다른 차량과의 거리와 패킷 전송률을 이용한다. 사용자 평판과 네트워크 신뢰도를 이용하여 지역 신뢰도가 계산된다. 이때, 전달되는 데이터의 중복 배포를 방지한다. RSU(Road Side Unit)의 데이터를 활용하여 지역적인 데이터의 한계를 극복하고 전역적인 데이터를 활용하여 보다 더 정확한 차량 신뢰도 계산이 가능하다. 다양한 성능평가를 통해 제안하는 기법이 기존 기법에 비해서 성능이 우수함을 보인다.', 'english_abstract': '', 'citation': 0, 'author': '백연희;복경수;유재수;', 'author_inst': '충북대학교 빅데이터 협동과정;원광대학교 SW 융합학과;충북대학교 정보통신공학부;', 'start_page': '68', 'end_page': '79', 'paper_keyword': '소셜사물인터넷 . 소셜 행위 . 차량 신뢰도 . 네트워크 신뢰도 . 사용자 평판', 'issue_lang': 'kor', 'progress': 0.6749999999999999, 'author_id': 's1087985;s269933;s259873'}
# ...
# {'_id': ObjectId('61939447e9b04a9d64abe060'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 1, 'issue_inst': '한국융합학회', 'journal': '한국융합학회논문지 = Journal of the Korea Convergence Society', 'issue_year': '2020', 'id': 'JAKO202025465016365', 'title': '빅데이터 분석을 통한 유명인 모델의 광고효과 예측 모형 개발', 'english_title': 'Development of a Prediction Model for Advertising Effects of Celebrity Models using Big data Analysis', 'abstract': '본 연구는 소셜 빅데이터에 기반을 둔 유명인과 브랜드의 이미지 유사도가 광고효과를 예측할 수 있는 결정변수가 될 수 있는지를 파악하기 위해, 광고효과 예측모형을 생성하고 빅데이터 분석기법인 기계학습 방법을 통해 그 타당도를 검증하는 것을 목적으로 하였다. 이를 위해 SNS상의 키워드 네트워크 구조에 기반하여 유명인-브랜드 이미지 유사도를 정량화하고, 학습 데이터를 통해 이미지 유사도를 독립변수로, 광고효과 데이터를 종속변수로 하는 다중회귀모형을 반복 실시하여 광고효과 예측모형을 생성하였다. 이렇게 생성된 예측모형의 정확도를 판단하기 위해 예측 데이터에서 얻은 광고효과 예측값과 비교 기준으로서의 서베이값을 비교한 결과, 타당도를 판단하는 기준치인 75%의 분류 정확도를 보였으므로 본 광고효과 예측 모델링의 타당성은 확보된 것으로 입증되었다. 본 연구는 유명인-브랜드 이미지 유사성 구조를 소셜 네트워크 구조로 설명하고 그 효과를 기계학습을 통한 예측 모델링으로 검증하여 빅데이터 기반 모델링 연구에 새로운 방법론적 대안과 방향을 제시하였다.', 'english_abstract': '', 'citation': 0, 'author': '김유나;한상필;', 'author_inst': '서울예술대학교 광고창작과;한양대학교 광고홍보학과;', 'start_page': '99', 'end_page': '106', 'paper_keyword': '유명인-브랜드 이미지 유사성 . 광고효과 예측모형 . 기계학습(머신러닝) . 소셜 빅데이터 . 연상 네트워크 이론', 'issue_lang': 'kor', 'progress': 0.33499999999999996, 'author_id': 's262611;s262612'}
# {'_id': ObjectId('61939447e9b04a9d64abe060'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 1, 'issue_inst': '한국융합학회', 'journal': '한국융합학회논문지 = Journal of the Korea Convergence Society', 'issue_year': '2020', 'id': 'JAKO202025465016365', 'title': '빅데이터 분석을 통한 유명인 모델의 광고효과 예측 모형 개발', 'english_title': 'Development of a Prediction Model for Advertising Effects of Celebrity Models using Big data Analysis', 'abstract': '본 연구는 소셜 빅데이터에 기반을 둔 유명인과 브랜드의 이미지 유사도가 광고효과를 예측할 수 있는 결정변수가 될 수 있는지를 파악하기 위해, 광고효과 예측모형을 생성하고 빅데이터 분석기법인 기계학습 방법을 통해 그 타당도를 검증하는 것을 목적으로 하였다. 이를 위해 SNS상의 키워드 네트워크 구조에 기반하여 유명인-브랜드 이미지 유사도를 정량화하고, 학습 데이터를 통해 이미지 유사도를 독립변수로, 광고효과 데이터를 종속변수로 하는 다중회귀모형을 반복 실시하여 광고효과 예측모형을 생성하였다. 이렇게 생성된 예측모형의 정확도를 판단하기 위해 예측 데이터에서 얻은 광고효과 예측값과 비교 기준으로서의 서베이값을 비교한 결과, 타당도를 판단하는 기준치인 75%의 분류 정확도를 보였으므로 본 광고효과 예측 모델링의 타당성은 확보된 것으로 입증되었다. 본 연구는 유명인-브랜드 이미지 유사성 구조를 소셜 네트워크 구조로 설명하고 그 효과를 기계학습을 통한 예측 모델링으로 검증하여 빅데이터 기반 모델링 연구에 새로운 방법론적 대안과 방향을 제시하였다.', 'english_abstract': '', 'citation': 0, 'author': '김유나;한상필;', 'author_inst': '서울예술대학교 광고창작과;한양대학교 광고홍보학과;', 'start_page': '99', 'end_page': '106', 'paper_keyword': '유명인-브랜드 이미지 유사성 . 광고효과 예측모형 . 기계학습(머신러닝) . 소셜 빅데이터 . 연상 네트워크 이론', 'issue_lang': 'kor', 'progress': 0.33499999999999996, 'author_id': 's262611;s262612'}
# {'_id': ObjectId('6193944be9b04a9d64abe06b'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 22, 'issue_inst': '한국정보처리학회', 'journal': '한국정보처리학회 2020년도 춘계학술발표대회', 'issue_year': '2020', 'id': 'NPAP13264164', 'title': '자동화된 트위터 데이터 수집 시스템 설계 및 구현 : 환경 데이터를 중심으로', 'english_title': 'Design and Implementation of Automated Twitter Data Collecting System : Focus on Environmental Data', 'abstract': '소셜 네트워크 서비스의 사용자가 늘어나면서, 소셜 네트워크 서비스상에서 발생하는 빅데이터를 활용한 서비스가 늘어나고 있다. 소셜 네트워크 서비스 데이터는 실시간으로 생성되며, 따라서 데이터 수집 시스템 역시 자동화하여 준 실시간으로 데이터를 수집할 필요가 있다. 본 논문에서는 대표적인 소셜 네트워크 서비스인 트위터의 데이터를 지속적으로 수집하기 위한 자동 수집 시스템을 제안한다. 수집 시스템은 Twitter API 를 활용하는 Python 라이브러리를 통해 내용 및 메타데이터를 수집하며, 수집된 데이터를 재 검증한 뒤 저장한다. 또한 구현된 시스템에 환경 데이터를 주제로 하는 쿼리를 입력하여 실제 트위터 데이터를 수집하며 구현된 시스템을 검증해보았다.', 'english_abstract': '', 'citation': 0, 'author': '김도형;구자환;김응모;', 'author_inst': '성균관대학교 소프트웨어대학;성균관대학교 사회과학대학;성균관대학교 사회과학대학 소비자가족학과 / 소프트웨어대학;', 'start_page': '361', 'end_page': '364', 'paper_keyword': [], 'issue_lang': 'kor', 'progress': 0.37, 'author_id': 's262792;s262793;s262794'}
# {'_id': ObjectId('6193944be9b04a9d64abe06b'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 22, 'issue_inst': '한국정보처리학회', 'journal': '한국정보처리학회 2020년도 춘계학술발표대회', 'issue_year': '2020', 'id': 'NPAP13264164', 'title': '자동화된 트위터 데이터 수집 시스템 설계 및 구현 : 환경 데이터를 중심으로', 'english_title': 'Design and Implementation of Automated Twitter Data Collecting System : Focus on Environmental Data', 'abstract': '소셜 네트워크 서비스의 사용자가 늘어나면서, 소셜 네트워크 서비스상에서 발생하는 빅데이터를 활용한 서비스가 늘어나고 있다. 소셜 네트워크 서비스 데이터는 실시간으로 생성되며, 따라서 데이터 수집 시스템 역시 자동화하여 준 실시간으로 데이터를 수집할 필요가 있다. 본 논문에서는 대표적인 소셜 네트워크 서비스인 트위터의 데이터를 지속적으로 수집하기 위한 자동 수집 시스템을 제안한다. 수집 시스템은 Twitter API 를 활용하는 Python 라이브러리를 통해 내용 및 메타데이터를 수집하며, 수집된 데이터를 재 검증한 뒤 저장한다. 또한 구현된 시스템에 환경 데이터를 주제로 하는 쿼리를 입력하여 실제 트위터 데이터를 수집하며 구현된 시스템을 검증해보았다.', 'english_abstract': '', 'citation': 0, 'author': '김도형;구자환;김응모;', 'author_inst': '성균관대학교 소프트웨어대학;성균관대학교 사회과학대학;성균관대학교 사회과학대학 소비자가족학과 / 소프트웨어대학;', 'start_page': '361', 'end_page': '364', 'paper_keyword': [], 'issue_lang': 'kor', 'progress': 0.37, 'author_id': 's262792;s262793;s262794'}
# {'_id': ObjectId('6193944be9b04a9d64abe06b'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 22, 'issue_inst': '한국정보처리학회', 'journal': '한국정보처리학회 2020년도 춘계학술발표대회', 'issue_year': '2020', 'id': 'NPAP13264164', 'title': '자동화된 트위터 데이터 수집 시스템 설계 및 구현 : 환경 데이터를 중심으로', 'english_title': 'Design and Implementation of Automated Twitter Data Collecting System : Focus on Environmental Data', 'abstract': '소셜 네트워크 서비스의 사용자가 늘어나면서, 소셜 네트워크 서비스상에서 발생하는 빅데이터를 활용한 서비스가 늘어나고 있다. 소셜 네트워크 서비스 데이터는 실시간으로 생성되며, 따라서 데이터 수집 시스템 역시 자동화하여 준 실시간으로 데이터를 수집할 필요가 있다. 본 논문에서는 대표적인 소셜 네트워크 서비스인 트위터의 데이터를 지속적으로 수집하기 위한 자동 수집 시스템을 제안한다. 수집 시스템은 Twitter API 를 활용하는 Python 라이브러리를 통해 내용 및 메타데이터를 수집하며, 수집된 데이터를 재 검증한 뒤 저장한다. 또한 구현된 시스템에 환경 데이터를 주제로 하는 쿼리를 입력하여 실제 트위터 데이터를 수집하며 구현된 시스템을 검증해보았다.', 'english_abstract': '', 'citation': 0, 'author': '김도형;구자환;김응모;', 'author_inst': '성균관대학교 소프트웨어대학;성균관대학교 사회과학대학;성균관대학교 사회과학대학 소비자가족학과 / 소프트웨어대학;', 'start_page': '361', 'end_page': '364', 'paper_keyword': [], 'issue_lang': 'kor', 'progress': 0.37, 'author_id': 's262792;s262793;s262794'}
# {'_id': ObjectId('6193944ce9b04a9d64abe06f'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 5, 'issue_inst': '한국콘텐츠학회', 'journal': '한국콘텐츠학회논문지 = The Journal of the Korea Contents Association', 'issue_year': '2021', 'id': 'JAKO202112054772449', 'title': '소셜 사물 인터넷 환경에서 차량 간 정보 공유를 위한 신뢰도 판별', 'english_title': 'Vehicle Trust Evaluation for Sharing Data among Vehicles in Social Internet of Things', 'abstract': '소셜 사물 인터넷(SIoT)에서 차량들이 다양한 정보를 생성하고 이를 다른 차량과 공유하고 피드백을 주고 받는 소셜 행위가 이루어진다. 차량 간에 신뢰성 있는 정보를 공유하기 위해서는 차량의 신뢰성을 판별하는 것이 중요하다. 본 논문에서는 차량들 간에 신뢰성 있는 정보를 공유하기 위한 차량 신뢰도 계산 기법을 제안한다. 제안하는 기법은 차량 간 소셜 행위에 기반한 사용자 평판과 네트워크 신뢰도를 고려하여 차량 신뢰도를 판별한다. 차량은 점수 부여, 무시, 재배포 등의 행위를 선택할 수 있으며 이에 따라 사용자 평판이 계산된다. 네트워크 신뢰도를 계산하기 위해 다른 차량과의 거리와 패킷 전송률을 이용한다. 사용자 평판과 네트워크 신뢰도를 이용하여 지역 신뢰도가 계산된다. 이때, 전달되는 데이터의 중복 배포를 방지한다. RSU(Road Side Unit)의 데이터를 활용하여 지역적인 데이터의 한계를 극복하고 전역적인 데이터를 활용하여 보다 더 정확한 차량 신뢰도 계산이 가능하다. 다양한 성능평가를 통해 제안하는 기법이 기존 기법에 비해서 성능이 우수함을 보인다.', 'english_abstract': '', 'citation': 0, 'author': '백연희;복경수;유재수;', 'author_inst': '충북대학교 빅데이터 협동과정;원광대학교 SW 융합학과;충북대학교 정보통신공학부;', 'start_page': '68', 'end_page': '79', 'paper_keyword': '소셜사물인터넷 . 소셜 행위 . 차량 신뢰도 . 네트워크 신뢰도 . 사용자 평판', 'issue_lang': 'kor', 'progress': 0.6749999999999999, 'author_id': 's1087985;s269933;s259873'}
# {'_id': ObjectId('6193944ce9b04a9d64abe071'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 7, 'issue_inst': 'The Korea Institute of Information and Commucation Engineering', 'journal': '한국정보통신학회논문지 = Journal of the Korea Institute of Information and Communication Engineering', 'issue_year': '2021', 'id': 'JAKO202128640525157', 'title': '빅데이터 분석 도구 R을 이용한 비정형 데이터 텍스트 마이닝과 시각화', 'english_title': 'Text Mining and Visualization of Unstructured Data Using Big Data Analytical Tool R', 'abstract': "빅데이터 시대에는 단순히 데이터베이스에 잘 정리된 정형 데이터뿐만 아니라 인터넷, 소셜 네트워크 서비스, 모바일 환경에서 실시간 생성되는 웹 문서, 이메일, 소셜 데이터 등 비정형 빅데이터를 효과적으로 분석하는 것이 매우 중요하다. 빅데이터 분석은 데이터 저장소에 저장된 빅데이터 속에서 의미 있는 새로운 상관관계, 패턴, 추세를 발견하여 새로운 가치를 창출하는 과정이다. 빅데이터 분석 도구인 R 언어를 이용하여 비정형 논문 데이터를 빈도분석을 통해 분석결과를 요약과 시각화하고자 한다. 본 연구에서 사용된 데이터는 한국정보통신학회 학회지 논문 중에서 2021년 1월호-5월호 총 논문 104편을 대상으로 분석하였다. 최종 분석결과 가장 많이 언급된 키워드는 '데이터'가 1,538회로 1위를 차지하였다. 따라서 분석결과를 바탕으로 연구의 한계와 이론적 실무적 시사점을 제시하고자 한다.", 'english_abstract': '', 'citation': 0, 'author': 'Nam, Soo-Tai;Shin, Seong-Yoon;Jin, Chan-Yong;', 'author_inst': 'Institute of General Education, Pusan National University;School of Computer Information & Communication Engineering, Kunsan National University;Division of Information & Electronic Commerce, Wonkwang University;', 'start_page': '1199', 'end_page': '1205', 'paper_keyword': '네트워크 분석 . 비정형 데이터 . 빅데이터 . 연관성 분석 . 텍스트 마이닝', 'issue_lang': 'kor', 'progress': 0.6783333333333333, 'author_id': 's640916;s259765;s640917'}
# {'_id': ObjectId('6193944ce9b04a9d64abe071'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 7, 'issue_inst': 'The Korea Institute of Information and Commucation Engineering', 'journal': '한국정보통신학회논문지 = Journal of the Korea Institute of Information and Communication Engineering', 'issue_year': '2021', 'id': 'JAKO202128640525157', 'title': '빅데이터 분석 도구 R을 이용한 비정형 데이터 텍스트 마이닝과 시각화', 'english_title': 'Text Mining and Visualization of Unstructured Data Using Big Data Analytical Tool R', 'abstract': "빅데이터 시대에는 단순히 데이터베이스에 잘 정리된 정형 데이터뿐만 아니라 인터넷, 소셜 네트워크 서비스, 모바일 환경에서 실시간 생성되는 웹 문서, 이메일, 소셜 데이터 등 비정형 빅데이터를 효과적으로 분석하는 것이 매우 중요하다. 빅데이터 분석은 데이터 저장소에 저장된 빅데이터 속에서 의미 있는 새로운 상관관계, 패턴, 추세를 발견하여 새로운 가치를 창출하는 과정이다. 빅데이터 분석 도구인 R 언어를 이용하여 비정형 논문 데이터를 빈도분석을 통해 분석결과를 요약과 시각화하고자 한다. 본 연구에서 사용된 데이터는 한국정보통신학회 학회지 논문 중에서 2021년 1월호-5월호 총 논문 104편을 대상으로 분석하였다. 최종 분석결과 가장 많이 언급된 키워드는 '데이터'가 1,538회로 1위를 차지하였다. 따라서 분석결과를 바탕으로 연구의 한계와 이론적 실무적 시사점을 제시하고자 한다.", 'english_abstract': '', 'citation': 0, 'author': 'Nam, Soo-Tai;Shin, Seong-Yoon;Jin, Chan-Yong;', 'author_inst': 'Institute of General Education, Pusan National University;School of Computer Information & Communication Engineering, Kunsan National University;Division of Information & Electronic Commerce, Wonkwang University;', 'start_page': '1199', 'end_page': '1205', 'paper_keyword': '네트워크 분석 . 비정형 데이터 . 빅데이터 . 연관성 분석 . 텍스트 마이닝', 'issue_lang': 'kor', 'progress': 0.6783333333333333, 'author_id': 's640916;s259765;s640917'}
# {'_id': ObjectId('61939447e9b04a9d64abe05f'), 'qryKeyword': ['빅데이터', '소셜네트워크'], 'qryTime': '202111162021', 'keyId': 588, 'loop': 18, 'issue_inst': '한국컴퓨터정보학회', 'journal': '한국컴퓨터정보학회 2019년도 제59차 동계학술대회논문집 27권1호', 'issue_year': '2019', 'id': 'NPAP12899861', 'title': '고등학생의 온라인 커뮤니티 지속사용의도에 대한 연구', 'english_title': 'A Study on the Intention of Continuing Use of Online Community in High School Students', 'abstract': '온라인 커뮤니티는 사용자들의 상호작용을 기반으로 생성된 컨텐츠(member-generated content)를 그 핵심가치로 제시하고 있으며, 이용자들은 소통의 장으로써 온라인 커뮤니티 내에서 정보획득, 교육자료 공유 등 다양한 혜택을 누릴 수 있다. 최근 2년 페이스북과 카카오스토리, 밴드 등과 같은 대표적인 소셜 네트워크 서비스(SNS) 이용자 수가 감소한 반면, 온라인 커뮤니티만 상승세를 보이고 있다. 따라서 본 연구에서는 여자고등학생들을 대상으로 고등학생들의 온라인커뮤니티 이용 실태와 이용하는 의도를 살펴보고자 한다. 연구를 위해 정보품질, 커뮤니티 정보의 신뢰성, 학습 혜택, 사회적 혜택, 자아존중감 혜택, 쾌락적 혜택, 경제적 혜택, 신뢰, 몰입 그리고 지속사용의도와 관련된 설문을 실시하였다.', 'english_abstract': '', 'citation': 0, 'author': '문재영;이새봄;최호성;', 'author_inst': '동서대학교 글로벌경영학부;경희대학교 빅데이터연구센터;한국산학연협회;', 'start_page': '195', 'end_page': '196', 'paper_keyword': [], 'issue_lang': 'kor', 'progress': 0.03, 'author_id': 's261536;s82703;s262104'}
# [('Byeongwon Park', {'name': 'Byeongwon Park', 'DBPIA': '과학기술정책연구원'}), ('Chaebeen Yoon', {'name': 'Chaebeen Yoon', 'DBPIA': 'Korea'}), ('Chan-Yong Jin', {'name': 'Chan-Yong Jin', 'DBPIA': 'Wonkwang'}), ('Chen Kaka', {'name': 'Chen Kaka', 'DBPIA': '부경대학교'}), ('Cheon, Jooyoung', {'name': 'Cheon, Jooyoung', 'DBPIA': 'Sungshin'}), ('Chi Ung Song', {'name': 'Chi Ung Song', 'DBPIA': '과학기술정책연구원'}), ('Chung, Kyu-Yup', {'name': 'Chung, Kyu-Yup', 'DBPIA': '세종대학교'}), ('Dae-Shik Kim', {'name': 'Dae-Shik Kim', 'DBPIA': '카이스트'}), ('Deok Soon Yim', {'name': 'Deok Soon Yim', 'DBPIA': '과학기술정책연구원'}), ('Dong Jin Kim', {'name': 'Dong Jin Kim', 'DBPIA': '영남대학교'}), ('Eun-ji Lee', {'name': 'Eun-ji Lee', 'DBPIA': ''}), ('Hayoung Oh', {'name': 'Hayoung Oh', 'DBPIA': '아주대학교'}), ('Hyoun Jong Kim', {'name': 'Hyoun Jong Kim', 'DBPIA': '한국신재생에너지학회'}), ('Jaesoo Yoo', {'name': 'Jaesoo Yoo', 'DBPIA': '충북대학교'}), ('Jang Hyun Kim', {'name': 'Jang Hyun Kim', 'DBPIA': 'Sungkyunkwan'}), ('Jeeyoung Choi', {'name': 'Jeeyoung Choi', 'DBPIA': '한국에너지기술연구원'}), ('Ji Sun Kim', {'name': 'Ji Sun Kim', 'DBPIA': '과학기술정책연구원'}), ('Ji Yong An', {'name': 'Ji Yong An', 'DBPIA': '과학기술정책연구원'}), ('Ji-Hong Kim', {'name': 'Ji-Hong Kim', 'DBPIA': '서울대학교'}), ('Ji-Yun Jang', {'name': 'Ji-Yun Jang', 'DBPIA': ''}), ('Jin, Chan-Yong', {'name': 'Jin, Chan-Yong', 'Scienceon': 'Division'}), ('Jin-Hui Chen', {'name': 'Jin-Hui Chen', 'DBPIA': 'Wonkwang'}), ('Jinmu Choi', {'name': 'Jinmu Choi', 'DBPIA': '경희대학교'}), ('Jiseok Ahn', {'name': 'Jiseok Ahn', 'DBPIA': 'Korea'}), ('Jiyoung Lim', {'name': 'Jiyoung Lim', 'DBPIA': 'WIPS'}), ('Jiyoung Lyu', {'name': 'Jiyoung Lyu', 'DBPIA': ''}), ('Jong Woo Kim', {'name': 'Jong Woo Kim', 'DBPIA': '한양대학교'}), ('Jong Yun Lee', {'name': 'Jong Yun Lee', 'DBPIA': '충북대학교'}), ('Jong-in Choi', {'name': 'Jong-in Choi', 'DBPIA': '한밭대학교'}), ('Jongtae Lim', {'name': 'Jongtae Lim', 'DBPIA': '충북대학교'}), ('Joong In Kim', {'name': 'Joong In Kim', 'DBPIA': '홍익대학교'}), ('Jung Kyu Kim', {'name': 'Jung Kyu Kim', 'DBPIA': '호남대학교'}), ('Jung Won Lee', {'name': 'Jung Won Lee', 'DBPIA': '과학기술정책연구원'}), ('Jungin Choi', {'name': 'Jungin Choi', 'DBPIA': 'Seoul'}), ('Ki Kook Kim', {'name': 'Ki Kook Kim', 'DBPIA': '과학기술정책연구원'}), ('Kim, Kyung-ah', {'name': 'Kim, Kyung-ah', 'DBPIA': 'Honam'}), ('Kyoungsoo Bok', {'name': 'Kyoungsoo Bok', 'DBPIA': '충북대학교'}), ('Kyung-Shik Shin', {'name': 'Kyung-Shik Shin', 'DBPIA': '이화여자대학교'}), ('Lee Myoungki', {'name': 'Lee Myoungki', 'DBPIA': '한국농촌경제연구원'}), ('Lee, Ji Hyun', {'name': 'Lee, Ji Hyun', 'DBPIA': '서울여자대학교'}), ('Lee, Soon-A', {'name': 'Lee, Soon-A', 'DBPIA': '경성대학교'}), ('MINH NHAT TRAN', {'name': 'MINH NHAT TRAN', 'DBPIA': ''}), ('Min Jung Kim', {'name': 'Min Jung Kim', 'DBPIA': '성균관대학교'}), ('Min-Sook Park', {'name': 'Min-Sook Park', 'DBPIA': '부산가톨릭대학교'}), ('Minseok Kim', {'name': 'Minseok Kim', 'DBPIA': 'KAIST'}), ('NakJin Choi', {'name': 'NakJin Choi', 'DBPIA': ''}), ('Nam, Soo-Tai', {'name': 'Nam, Soo-Tai', 'Scienceon': 'Institute'}), ('Namuk Ko', {'name': 'Namuk Ko', 'DBPIA': '건국대학교'}), ('Oh, Chang Song', {'name': 'Oh, Chang Song', 'Scienceon': '영남대학교'}), ('Ohbyung Kwon', {'name': 'Ohbyung Kwon', 'DBPIA': '경희대학교'}), ('PIAO GENSONG', {'name': 'PIAO GENSONG', 'NTIS': '한양대학교(ERICA캠퍼스)'}), ('Park Jiyun', {'name': 'Park Jiyun', 'DBPIA': '한국농촌경제연구원'}), ('Paul Aniruddha', {'name': 'Paul Aniruddha', 'DBPIA': '충북대학교'}), ('QUYNH HOANG NGAN NGUYEN', {'name': 'QUYNH HOANG NGAN NGUYEN', 'DBPIA': ''}), ('RETITI DIOP EMANE CHRISTOPHER', {'name': 'RETITI DIOP EMANE CHRISTOPHER', 'DBPIA': ''}), ('Ran Yoo', {'name': 'Ran Yoo', 'DBPIA': '한국에너지기술연구원'}), ('Ryu Seung Eui', {'name': 'Ryu Seung Eui', 'DBPIA': 'Dong-A'}), ('Sang Moon Lee', {'name': 'Sang Moon Lee', 'DBPIA': '한국교통대학교'}), ('Sangbum Kim', {'name': 'Sangbum Kim', 'DBPIA': 'WIPS'}), ('Seong-Yoon Shin', {'name': 'Seong-Yoon Shin', 'DBPIA': ''}), ('Seung-Min Noh', {'name': 'Seung-Min Noh', 'DBPIA': ''}), ('Seunghee Park', {'name': 'Seunghee Park', 'DBPIA': '성균관대학교'}), ('Seungjee Hong', {'name': 'Seungjee Hong', 'DBP ...

# %%
import json

answer = None
numCor = 0
numErr = 0
answerCounter = {}


def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter
    flag = True

    numK = len(result.keys())   
    if numK-1 != len(answer[name].keys()) : #site 개수 다르면 false
        flag = False
    else :
        for site in result.keys() :
            if site != 'name' : # site name이 다르면
                if site not in answer[name].keys() or result[site] not in answer[name][site] : #answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]): # result key와 answer key가 다르면
                    flag = False
                # elif answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]: 
                #     flag = False
                    # if numK > 2: # site가 2개 이상이면(name 포함 3개이상이면)
                    # if answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0] :
                    #         flag = False
                    # else :
                    #     if answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]:
                    #         flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
        print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        if len(answer[name].keys()) > 1 :
            numErr += 1
    return flag

with open('answer.json', 'r',encoding='UTF8') as a_json :


    answer = json.load(a_json)
    numAns = print(len(answer))
    
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        #print(test)

        name = Answer_dict[test]['name']
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            while name+str(count) in answer :
                # if name+count in answer :
                print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")

    tempCount = 0
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            tempCount += 1
            print(key)
            print(answer[key])
    print(tempCount)
# Out:
# 1802
# Check 복경수0
# Check 복경수0
# Not Correct
#  - Answer : {'Scienceon': '원광대학교', 'DBPIA': '원광대학교'}
#  - Result : {'name': '복경수', 'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
# Check 복경수1
# Check 이정하0
# Not Correct
#  - Answer : {'Scienceon': '과학기술연합대학원대학교 건설환경공학과'}
#  - Result : {'name': '이정하', 'Scienceon': '한국건설기술연구원', 'DBPIA': '한국건설기술연구원'}
# Check 이정하1
# Check 이정하0
# Check 구철모0
# Check 서주환0
# Not Correct
#  - Answer : {'Scienceon': '경희대학교 예술.디자인대학 환경조경디자인학과'}
#  - Result : {'name': '서주환', 'DBPIA': '한국과학기술정보연구원'}
# Check 서주환1
# Check 서주환0
# Not Correct
#  - Answer : {'Scienceon': 'Department of IT Management, Kosin University', 'DBPIA': '고신대학교'}
#  - Result : {'name': '반재훈', 'DBPIA': '고신대학교'}
# Not Correct
#  - Answer : {'Scienceon': 'Department of IT Management, Kosin University', 'DBPIA': '고신대학교'}
#  - Result : {'name': '반재훈', 'Scienceon': 'Department'}
# Check 이정하0
# Not Correct
#  - Answer : {'Scienceon': '과학기술연합대학원대학교 건설환경공학과'}
#  - Result : {'name': '이정하', 'DBPIA': '세명대학교'}
# Check 이정하1
# Not Correct
#  - Answer : {'Scienceon': '한국건설기술연구원', 'DBPIA': '한국건설기술연구원'}
#  - Result : {'name': '이정하', 'DBPIA': '세명대학교'}
# Check 이정하2
# Check 이승헌0
# Check 이승헌0
# Not Correct
#  - Answer : {'DBPIA': '육군 종합정비창 정비기술연구소'}
#  - Result : {'name': '이승헌', 'DBPIA': '한국HCI학회'}
# Check 이승헌1
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '창원대학교'}
# Check 이지현1
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 사범대학 교직과'}
#  - Result : {'name': '이지현', 'DBPIA': '창원대학교'}
# Check 이지현2
# Not Correct
#  - Answer : {'DBPIA': '대한토목학회'}
#  - Result : {'name': '이지현', 'DBPIA': '창원대학교'}
# Check 이지현3
# Check 이지현0
# Not Correct
#  - Answer : {'Scienceon': 'Department of Broadcasting & Image, Kyungnam College of Information & Technology', 'DBPIA': '경남정보대학교'}
#  - Result : {'name': '하종수', 'DBPIA': '경남정보대학교'}
# Not Correct
#  - Answer : {'Scienceon': 'Department of Broadcasting & Image, Kyungnam College of Information & Technology', 'DBPIA': '경남정보대학교'}
#  - Result : {'name': '하종수', 'Scienceon': 'Department'}
# Check 김민정0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김민정', 'DBPIA': '한국외국어대학교'}
# Check 김민정1
# Not Correct
#  - Answer : {'DBPIA': '법학평론 사회과학대학 미디어커뮤니케이션 학부'}
#  - Result : {'name': '김민정', 'DBPIA': '한국외국어대학교'}
# Check 김민정2
# Check 김민정0
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은2
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 글로벌혁신전략연구본부'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은3
# Not Correct
#  - Answer : {'DBPIA': '성균관대학교 인터랙션사이언스학과'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은4
# Not Correct
#  - Answer : {'DBPIA': '숙명여자대학교 법학부'}
#  - Result : {'name': '김지은', 'DBPIA': '한국건설기술연구원'}
# Check 김지은5
# Check 김지은0
# Check 김정은0
# Not Correct
#  - Answer : {'NTIS': '공주대학교'}
#  - Result : {'name': '김정은', 'DBPIA': '한국교통연구원'}
# Check 김정은1
# Check 김정은0
# Check 이정민0
# Not Correct
#  - Answer : {'DBPIA': '부경대학교 대학원 신문방송학과'}
#  - Result : {'name': '이정민', 'DBPIA': '한국농촌경제연구원'}
# Check 이정민1
# Check 이정민0
# Check 조정현0
# Not Correct
#  - Answer : {'DBPIA': '인제대학교 간호학과･건강과학연구소'}
#  - Result : {'name': '조정현', 'DBPIA': '제오시스'}
# Check 조정현1
# Check 조정현0
# Check 김경회0
# Not Correct
#  - Answer : {'DBPIA': '국제디지털대학교'}
#  - Result : {'name': '김경회', 'DBPIA': '국제사이버대학교'}
# Check 김경회1
# Check 김경회0
# Check 정우성0
# Not Correct
#  - Answer : {'NTIS': '포항공과대학교'}
#  - Result : {'name': '정우성', 'DBPIA': '국토연구원'}
# Check 정우성1
# Check 정우성0
# Check 김민정0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김민정', 'DBPIA': '법학평론'}
# Check 김민정1
# Check 이지은0
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 행정문제연구소'}
#  - Result : {'name': '이지은', 'DBPIA': '중앙대학교'}
# Check 이지은1
# Check 이지은0
# Check 김호용0
# Not Correct
#  - Answer : {'Scienceon': '한국과학기술정보연구원'}
#  - Result : {'name': '김호용', 'DBPIA': 'Yeungjin'}
# Check 김호용1
# Check 김호용0
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '경기대학교'}
# Check 김민경1
# Check 김민경0
# Check 김정훈0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김정훈', 'DBPIA': '한국방송광고진흥공사'}
# Check 김정훈1
# Check 김정훈0
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '서울대학교'}
# Check 김지영1
# Not Correct
#  - Answer : {'DBPIA': '동아대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '서울대학교'}
# Check 김지영2
# Not Correct
#  - Answer : {'DBPIA': '상명대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '서울대학교'}
# Check 김지영3
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영1
# Not Correct
#  - Answer : {'DBPIA': '동아대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영2
# Not Correct
#  - Answer : {'DBPIA': '상명대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영3
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 국제문제연구소'}
#  - Result : {'name': '김지영', 'DBPIA': '한국디자인문화학회'}
# Check 김지영4
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '건국대학교'}
# Check 이지현1
# Check 한정훈0
# Check 한정훈0
# Not Correct
#  - Answer : {'DBPIA': '한국농촌경제연구원'}
#  - Result : {'name': '한정훈', 'DBPIA': '한국사회체육학회'}
# Check 한정훈1
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '소노엠'}
# Check 김민경1
# Not Correct
#  - Answer : {'DBPIA': '경기대학교 외식조리학과'}
#  - Result : {'name': '김민경', 'DBPIA': '소노엠'}
# Check 김민경2
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '숙명여자대학교'}
# Check 김민경1
# Not Correct
#  - Answer : {'DBPIA': '경기대학교 외식조리학과'}
#  - Result : {'name': '김민경', 'DBPIA': '숙명여자대학교'}
# Check 김민경2
# Not Correct
#  - Answer : {'DBPIA': '소노엠 Department of Research&Development Center'}
#  - Result : {'name': '김민경', 'DBPIA': '숙명여자대학교'}
# Check 김민경3
# Check 김지현0
# Check 김지현0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지현', 'DBPIA': '과학기술정책연구원'}
# Check 김지현1
# Check 이희정0
# Check 이희정0
# Not Correct
#  - Answer : {'DBPIA': '중앙대학교 사회학과 BK21플러스 사업팀'}
#  - Result : {'name': '이희정', 'DBPIA': '한양대학교'}
# Check 이희정1
# Not Correct
#  - Answer : {'DBPIA': '전북대'}
#  - Result : {'name': '손현주', 'DBPIA': '전북대학교'}
# Check 김민수0
# Not Correct
#  - Answer : {'NTIS': '전남대학교'}
#  - Result : {'name': '김민수', 'DBPIA': '한국스포츠정책과학원'}
# Check 김민수1
# Check 김민수0
# Check 김민선0
# Not Correct
#  - Answer : {'DBPIA': '경기연구원'}
#  - Result : {'name': '김민선', 'DBPIA': '총신대학교'}
# Check 김민선1
# Check 김민선0
# Not Correct
#  - Answer : {'DBPIA': '경기연구원'}
#  - Result : {'name': '김민선', 'DBPIA': '협성대학교'}
# Check 김민선1
# Not Correct
#  - Answer : {'DBPIA': '총신대학교 일반대학원'}
#  - Result : {'name': '김민선', 'DBPIA': '협성대학교'}
# Check 김민선2
# Check 김하영0
# Not Correct
#  - Answer : {'DBPIA': '부산대학교 디자인학과'}
#  - Result : {'name': '김하영', 'DBPIA': '서울연구원'}
# Check 김하영1
# Check 김하영0
# Check 김성희0
# Check 김성희0
# Not Correct
#  - Answer : {'DBPIA': '동의대학교 Industrial of ICT Engineering'}
#  - Result : {'name': '김성희', 'DBPIA': '한양대'}
# Check 김성희1
# Check 김민경0
# Not Correct
#  - Answer : {'NTIS': '선문대학교'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경1
# Not Correct
#  - Answer : {'DBPIA': '경기대학교 외식조리학과'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경2
# Not Correct
#  - Answer : {'DBPIA': '소노엠 Department of Research&Development Center'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경3
# Not Correct
#  - Answer : {'DBPIA': '숙명여자대학교 원격대학원 향장미용'}
#  - Result : {'name': '김민경', 'DBPIA': '홍익대학교(세종캠퍼스)'}
# Check 김민경4
# Check 김상균0
# Check 김상균0
# Not Correct
#  - Answer : {'DBPIA': '강원대학교 산업공학'}
#  - Result : {'name': '김상균', 'DBPIA': '서울연구원'}
# Check 김상균1
# Check 김동호0
# Not Correct
#  - Answer : {'DBPIA': '서울과학기술대학교'}
#  - Result : {'name': '김동호', 'DBPIA': '한국교통연구원'}
# Check 김동호1
# Check 김동호0
# Check 강지원0
# Not Correct
#  - Answer : {'DBPIA': '경희대학교 일반대학원 조리외식경영학과'}
#  - Result : {'name': '강지원', 'DBPIA': '한국교통연구원'}
# Check 강지원1
# Check 강지원0
# Check 최재영0
# Not Correct
#  - Answer : {'NTIS': '한국외국어대학교'}
#  - Result : {'name': '최재영', 'DBPIA': '한양대학교'}
# Check 최재영1
# Check 최재영0
# Check 변혜민0
# Check 변혜민0
# Not Correct
#  - Answer : {'DBPIA': '경희대학교 간호과학대학'}
#  - Result : {'name': '변혜민', 'DBPIA': '한국광고홍보학회'}
# Check 변혜민1
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '과학기술정책연구원'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '과학기술정책연구원'}
# Check 김지은2
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': ''}
# Check 김지은1
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 조경학과', 'DBPIA': ''}
#  - Result : {'name': '박찬', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 조경학과', 'DBPIA': ''}
#  - Result : {'name': '박찬', 'Scienceon': '서울시립대학교'}
# Not Correct
#  - Answer : {'Scienceon': '청주대학교 휴먼환경디자인학부 조경도시계획전공', 'DBPIA': ''}
#  - Result : {'name': '김호걸', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '청주대학교 휴먼환경디자인학부 조경도시계획전공', 'DBPIA': ''}
#  - Result : {'name': '김호걸', 'Scienceon': '청주대학교'}
# Check 김은주0
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 Global Training Program Team, Office of STI ODA Project (IICC)'}
#  - Result : {'name': '김은주', 'DBPIA': '관광경영학회'}
# Check 김은주1
# Check 김은주0
# Check 김영국0
# Check 김영국0
# Not Correct
#  - Answer : {'DBPIA': '농촌진흥청'}
#  - Result : {'name': '김영국', 'DBPIA': '법조협회'}
# Check 김영국1
# Check 김호용0
# Not Correct
#  - Answer : {'Scienceon': '한국과학기술정보연구원'}
#  - Result : {'name': '김호용', 'DBPIA': '아주대학교'}
# Check 김호용1
# Not Correct
#  - Answer : {'DBPIA': 'Yeungjin College School of Computer Information'}
#  - Result : {'name': '김호용', 'DBPIA': '아주대학교'}
# Check 김호용2
# Check 윤영진0
# Not Correct
#  - Answer : {'DBPIA': '상명대학교 경영학부'}
#  - Result : {'name': '윤영진', 'DBPIA': '특허청'}
# Check 윤영진1
# Check 윤영진0
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '상명대학교'}
# Check 김지영1
# Not Correct
#  - Answer : {'DBPIA': '동아대학교'}
#  - Result : {'name': '김지영', 'DBPIA': '상명대학교'}
# Check 김지영2
# Check 김성연0
# Check 김성연0
# Not Correct
#  - Answer : {'DBPIA': '인사혁신처 국가공무원인재개발원 연구개발센터'}
#  - Result : {'name': '김성연', 'DBPIA': '인천대학교'}
# Check 김성연1
# Check 김성훈0
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 기계항공공학부'}
#  - Result : {'name': '김성훈', 'DBPIA': '성균관대학교'}
# Check 김성훈1
# Check 김성훈0
# Check 송지성0
# Check 박재현0
# Not Correct
#  - Answer : {'DBPIA': 'Korea National Sport University'}
#  - Result : {'name': '박재현', 'DBPIA': '동국대학교'}
# Check 박재현1
# Check 박재현0
# Check 김진주0
# Not Correct
#  - Answer : {'DBPIA': '명지대학교(서울) 정치외교학과'}
#  - Result : {'name': '김진주', 'DBPIA': '한양대학교'}
# Check 김진주1
# Check 김진주0
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은2
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 글로벌혁신전략연구본부'}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은3
# Not Correct
#  - Answer : {'DBPIA': '성균관대학교 인터랙션사이언스학과'}
#  - Result : {'name': '김지은', 'DBPIA': '숙명여자대학교'}
# Check 김지은4
# Check 이지연0
# Not Correct
#  - Answer : {'DBPIA': '한국복식학회'}
#  - Result : {'name': '이지연', 'DBPIA': '한국브랜드디자인학회'}
# Check 이지연1
# Check 이지연0
# Check 김태형0
# Check 김태형0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김태형', 'DBPIA': '한국교통연구원'}
# Check 김태형1
# Check 김주일0
# Not Correct
#  - Answer : {'DBPIA': '전라남도문화관광재단 관광연구개발팀'}
#  - Result : {'name': '김주일', 'DBPIA': '한동대학교'}
# Check 김주일1
# Check 김주일0
# Check 김동현0
# Not Correct
#  - Answer : {'DBPIA': '동서대학교 소프트웨어학과'}
#  - Result : {'name': '김동현', 'DBPIA': '바론'}
# Check 김동현1
# Check 김동현0
# Not Correct
#  - Answer : {'DBPIA': '동서대학교 소프트웨어학과'}
#  - Result : {'name': '김동현', 'Scienceon': 'Dept'}
# Check 김동현1
# Not Correct
#  - Answer : {'DBPIA': '바론'}
#  - Result : {'name': '김동현', 'Scienceon': 'Dept'}
# Check 김동현2
# Check 복경수0
# Not Correct
#  - Answer : {'Scienceon': '원광대학교', 'DBPIA': '원광대학교'}
#  - Result : {'name': '복경수', 'DBPIA': 'Wonkwang'}
# Check 복경수1
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
#  - Result : {'name': '복경수', 'DBPIA': 'Wonkwang'}
# Check 이주희0
# Check 이주희0
# Not Correct
#  - Answer : {'DBPIA': 'Kyung Hee University Department of Korean Language and Literature'}
#  - Result : {'name': '이주희', 'DBPIA': '숙명여자대학교'}
# Check 이주희1
# Check 배수진0
# Not Correct
#  - Answer : {'DBPIA': '강원대학교 삼척캠퍼스 교양학부'}
#  - Result : {'name': '배수진', 'DBPIA': '동의대학교'}
# Check 배수진1
# Check 배수진0
# Check 신성윤0
# Not Correct
#  - Answer : {'Scienceon': 'Kunsan National University'}
#  - Result : {'name': '신성윤', 'DBPIA': '아주대학교'}
# Check 신성윤1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '신성윤', 'DBPIA': '아주대학교'}
# Check 신성윤2
# Check 신성윤0
# Check 손형섭0
# Not Correct
#  - Answer : {'DBPIA': '경성대학교 법정대학'}
#  - Result : {'name': '손형섭', 'DBPIA': '한밭대학교'}
# Check 손형섭1
# Check 손형섭0
# Check 김동현0
# Check 이은선0
# Check 이은선0
# Not Correct
#  - Answer : {'DBPIA': '경남과학기술대학교 경제학과'}
#  - Result : {'name': '이은선', 'DBPIA': '홍익대학교'}
# Check 이은선1
# Check 박은정0
# Not Correct
#  - Answer : {'DBPIA': '부경대학교 기술경영전문대학원'}
#  - Result : {'name': '박은정', 'DBPIA': '한국형사정책연구원'}
# Check 박은정1
# Check 박은정0
# Check 김성진0
# Not Correct
#  - Answer : {'DBPIA': '강릉원주대학교 멀티미디어공학과'}
#  - Result : {'name': '김성진', 'DBPIA': '한국체육측정평가학회'}
# Check 김성진1
# Check 김성진0
# Check 김지영0
# Not Correct
#  - Answer : {'DBPIA': 'Seoul National University Institute of Construction and Environmental Engineering'}
#  - Result : {'name': '김지영', 'DBPIA': '동아대학교'}
# Check 김지영1
# Check 김영미0
# Not Correct
#  - Answer : {'Scienceon': '서원대학교 레저스포츠학과'}
#  - Result : {'name': '김영미', 'DBPIA': '강원대학교'}
# Check 김영미1
# Check 김영미0
# Check 김태현0
# Not Correct
#  - Answer : {'DBPIA': 'National Nanofab Center'}
#  - Result : {'name': '김태현', 'DBPIA': '서울기술연구원'}
# Check 김태현1
# Check 김태현0
# Check 정혜정0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '정혜정', 'DBPIA': '한국브랜드디자인학회'}
# Check 정혜정1
# Check 정혜정0
# Check 김지은0
# Not Correct
#  - Answer : {'Scienceon': '서울시립대학교 일반대학원 조경학과 대학원'}
#  - Result : {'name': '김지은', 'DBPIA': '성균관대학교'}
# Check 김지은1
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김지은', 'DBPIA': '성균관대학교'}
# Check 김지은2
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원 글로벌혁신전략연구본부'}
#  - Result : {'name': '김지은', 'DBPIA': '성균관대학교'}
# Check 김지은3
# Check 이재문0
# Check 이재문0
# Not Correct
#  - Answer : {'DBPIA': '경희대학교 체육학과'}
#  - Result : {'name': '이재문', 'DBPIA': '국민체육진흥공단체육과학연구원'}
# Check 이재문1
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현1
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 사범대학 교직과'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현2
# Not Correct
#  - Answer : {'DBPIA': '대한토목학회'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현3
# Not Correct
#  - Answer : {'DBPIA': '창원대학교 전자공학과'}
#  - Result : {'name': '이지현', 'DBPIA': '한국체육대학교'}
# Check 이지현4
# Check 김정호0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김정호', 'DBPIA': '과학기술정책연구원'}
# Check 김정호1
# Check 김정호0
# Check 이정우0
# Not Correct
#  - Answer : {'DBPIA': '한국기술혁신학회'}
#  - Result : {'name': '이정우', 'DBPIA': '한국연기금연구원'}
# Check 이정우1
# Not Correct
#  - Answer : {'DBPIA': '한국에너지기술평가원 인적자원실'}
#  - Result : {'name': '이정우', 'DBPIA': '한국연기금연구원'}
# Check 이정우2
# Check 이정우0
# Not Correct
#  - Answer : {'DBPIA': '한국기술혁신학회'}
#  - Result : {'name': '이정우', 'DBPIA': '한국에너지기술평가원'}
# Check 이정우1
# Check 이상훈0
# Not Correct
#  - Answer : {'DBPIA': '과학기술정책연구원'}
#  - Result : {'name': '이상훈', 'DBPIA': '한국한의학연구원'}
# Check 이상훈1
# Check 이상훈0
# Check 유한나0
# Not Correct
#  - Answer : {'DBPIA': '서울여자대학교 디자인학과'}
#  - Result : {'name': '유한나', 'DBPIA': '연세대학교'}
# Check 유한나1
# Check 유한나0
# Check 홍성표0
# Check 홍성표0
# Not Correct
#  - Answer : {'DBPIA': '조선대학교 SW중신대학사업단'}
#  - Result : {'name': '홍성표', 'DBPIA': '한국교통연구원'}
# Check 홍성표1
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '정주익', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '정주익', 'Scienceon': '인천국제공항공사'}
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '차희준', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
#  - Result : {'name': '차희준', 'Scienceon': '인천국제공항공사'}
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': ''}
#  - Result : {'name': '백연희', 'DBPIA': ''}
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': ''}
#  - Result : {'name': '백연희', 'Scienceon': '충북대학교'}
# Check 김은미0
# Check 김은미0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김은미', 'DBPIA': '충남대학교'}
# Check 김은미1
# Check 조은경0
# Check 조은경0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '조은경', 'DBPIA': '동국대'}
# Check 조은경1
# Check 김영우0
# Check 김영우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김영우', 'DBPIA': '환경부'}
# Check 김영우1
# Not Correct
#  - Answer : {'DBPIA': '경북대학교'}
#  - Result : {'name': '김영우', 'DBPIA': '환경부'}
# Check 김영우2
# Check 신성윤0
# Not Correct
#  - Answer : {'Scienceon': 'Kunsan National University'}
#  - Result : {'name': '신성윤', 'DBPIA': ''}
# Check 신성윤1
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
#  - Result : {'name': '임종태', 'DBPIA': ''}
# Check 복경수0
# Not Correct
#  - Answer : {'Scienceon': '원광대학교', 'DBPIA': '원광대학교'}
#  - Result : {'name': '복경수', 'DBPIA': ''}
# Check 복경수1
# Not Correct
#  - Answer : {'Scienceon': '충북대학교', 'DBPIA': '충북대학교'}
#  - Result : {'name': '복경수', 'DBPIA': ''}
# Not Correct
#  - Answer : {'NTIS': '충북대학교', 'DBPIA': '충북대학교', 'Scienceon': '충북대학교'}
#  - Result : {'name': '유재수', 'DBPIA': ''}
# Check 김재현0
# Check 김재현0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김재현', 'DBPIA': '세종대학교'}
# Check 김재현1
# Check 김준영0
# Check 김준영0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김준영', 'DBPIA': '순천대학교'}
# Check 김준영1
# Check 조영복0
# Check 조영복0
# Not Correct
#  - Answer : {'DBPIA': '대전대학교 정보보안학과'}
#  - Result : {'name': '조영복', 'DBPIA': '부산대학교'}
# Check 조영복1
# Check 손석현0
# Not Correct
#  - Answer : {'Scienceon': '인천국제공항공사 공항산업기술연구원'}
#  - Result : {'name': '손석현', 'DBPIA': '부산대학교'}
# Check 손석현1
# Check 손석현0
# Check 박현정0
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 교육학과'}
#  - Result : {'name': '박현정', 'DBPIA': '충북대학교'}
# Check 박현정1
# Not Correct
#  - Answer : {'DBPIA': '이화여자대학교 경영연구소'}
#  - Result : {'name': '박현정', 'DBPIA': '충북대학교'}
# Check 박현정2
# Check 박현정0
# Check 이승우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '이승우', 'DBPIA': '한국과학기술정보연구원'}
# Check 이승우1
# Check 이승우0
# Check 이영주0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '이영주', 'DBPIA': '서울과학기술대학교'}
# Check 이영주1
# Check 이영주0
# Check 윤영민0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '윤영민', 'DBPIA': '고려대학교'}
# Check 윤영민1
# Check 윤영민0
# Check 김미경0
# Check 김미경0
# Not Correct
#  - Answer : {'DBPIA': '청운대학교 미디어커뮤니케이션학과'}
#  - Result : {'name': '김미경', 'DBPIA': '홍익대학교'}
# Check 김미경1
# Check 박현정0
# Not Correct
#  - Answer : {'DBPIA': '서울대학교 교육학과'}
#  - Result : {'name': '박현정', 'DBPIA': '이화여자대학교'}
# Check 박현정1
# Check 이재용0
# Check 이재용0
# Not Correct
#  - Answer : {'DBPIA': '국토연구원 스마트·녹색도시연구센터'}
#  - Result : {'name': '이재용', 'DBPIA': '도쿄대학교'}
# Check 이재용1
# Check 김경민0
# Not Correct
#  - Answer : {'DBPIA': '부산대학교 소프트웨어교육센터'}
#  - Result : {'name': '김경민', 'DBPIA': '서울대'}
# Check 김경민1
# Check 김경민0
# Check 이정우0
# Check 김선우0
# Not Correct
#  - Answer : {'DBPIA': '고려대학교 School of Advanced Materials Science & Engineering'}
#  - Result : {'name': '김선우', 'DBPIA': '과학기술정책연구원'}
# Check 김선우1
# Check 김선우0
# Check 이성우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '이성우', 'DBPIA': '서울대학교'}
# Check 이성우1
# Check 이성우0
# Check 박찬식0
# Not Correct
#  - Answer : {'NTIS': '중앙대학교'}
#  - Result : {'name': '박찬식', 'DBPIA': '한국도로협회'}
# Check 박찬식1
# Check 박찬식0
# Check 서호준0
# Not Correct
#  - Answer : {'DBPIA': '신용보증기금'}
#  - Result : {'name': '서호준', 'DBPIA': '충남대'}
# Check 서호준1
# Check 서호준0
# Check 이지현0
# Not Correct
#  - Answer : {'NTIS': '한국과학기술원'}
#  - Result : {'name': '이지현', 'DBPIA': '대한토목학회'}
# Check 이지현1
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 사범대학 교직과'}
#  - Result : {'name': '이지현', 'DBPIA': '대한토목학회'}
# Check 이지현2
# Check 김영우0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김영우', 'DBPIA': '경북대학교'}
# Check 김영우1
# Check 김세진0
# Check 김세진0
# Not Correct
#  - Answer : {'DBPIA': 'Sungkyunkwan University School of Pharmacy'}
#  - Result : {'name': '김세진', 'DBPIA': '숙명여자대학교'}
# Check 김세진1
# Check 김지영0
# Check 김일중0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '김일중', 'DBPIA': '한양대학교'}
# Check 김일중1
# Check 김일중0
# Check 이기영0
# Check 이기영0
# Not Correct
#  - Answer : {'DBPIA': '경기연구원 생태환경연구실'}
#  - Result : {'name': '이기영', 'DBPIA': '인천대학교'}
# Check 이기영1
# Check 김은경0
# Not Correct
#  - Answer : {'DBPIA': '강릉원주대학교 식품영양학과'}
#  - Result : {'name': '김은경', 'DBPIA': '경기연구원'}
# Check 김은경1
# Check 김은경0
# Check 이정희0
# Not Correct
#  - Answer : {'Scienceon': '국립산림과학원 산림복지연구과'}
#  - Result : {'name': '이정희', 'DBPIA': '경기연구원'}
# Check 이정희1
# Check 이정희0
# Check 박현길0
# Check 박현길0
# Not Correct
#  - Answer : {'DBPIA': 'GMCOM'}
#  - Result : {'name': '박현길', 'DBPIA': '동아기술공사'}
# Check 박현길1
# Check 김민선0
# Check 이수진0
# Not Correct
#  - Answer : {'DBPIA': 'Université Paris IV 지리학'}
#  - Result : {'name': '이수진', 'DBPIA': '경기연구원'}
# Check 이수진1
# Check 이수진0
# Check 박광서0
# Not Correct
#  - Answer : {'DBPIA': '건국대학교 국제무역학과'}
#  - Result : {'name': '박광서', 'DBPIA': '한국해양수산개발원'}
# Check 박광서1
# Check 박광서0
# Check 김태경0
# Not Correct
#  - Answer : {'DBPIA': '공감도시연구실 연구위원'}
#  - Result : {'name': '김태경', 'DBPIA': '광운대학교'}
# Check 김태경1
# Check 김태경0
# Not Correct
#  - Answer : {'DBPIA': 'Kyung Hee University College of Hotel & Tourism Management'}
#  - Result : {'name': '정남호', 'DBPIA': '경희대학교'}
# Check 김민지0
# Not Correct
#  - Answer : {'DBPIA': '국토연구원'}
#  - Result : {'name': '김민지', 'DBPIA': '숙명여자대학교'}
# Check 김민지1
# Check 김민지0
# Check 권혁인0
# Not Correct
#  - Answer : {'DBPIA': ''}
#  - Result : {'name': '권혁인', 'DBPIA': '중앙대학교'}
# Check 권혁인1
# Check 권혁인0
# Check 김상욱0
# Not Correct
#  - Answer : {'NTIS': '한양대학교'}
#  - Result : {'name': '김상욱', 'DBPIA': '경북대학교'}
# Check 김상욱1
# Check 김상욱0
# Check 김범석0
# Check 김범석0
# Not Correct
#  - Answer : {'DBPIA': '지방공기업평가원'}
#  - Result : {'name': '김범석', 'DBPIA': '한국과학기술원'}
# Check 김범석1
# num코렉트 1792
# numEror 22
# 김호걸
# {'Scienceon': '청주대학교 휴먼환경디자인학부 조경도시계획전공', 'DBPIA': ''}
# 박찬
# {'Scienceon': '서울시립대학교 조경학과', 'DBPIA': ''}
# 반재훈
# {'Scienceon': 'Department of IT Management, Kosin University', 'DBPIA': '고신대학교'}
# 백연희
# {'Scienceon': '충북대학교', 'DBPIA': ''}
# 정주익
# {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
# 차희준
# {'Scienceon': '인천국제공항공사 공항산업기술연구원', 'DBPIA': ''}
# 하종수
# {'Scienceon': 'Department of Broadcasting & Image, Kyungnam College of Information & Technology', 'DBPIA': '경남정보대학교'}
# 구철모1
# {'DBPIA': '경희대학교 컨벤션경영학과'}
# 손현주
# {'DBPIA': '전북대'}
# 송지성1
# {'DBPIA': '한양대학교 디자인대학 커뮤니케이션디자인학과'}
# 10

# %%
print("(주) 제오시스 기업부설연구소".replace("(주) ",""))
# Out:
# 제오시스 기업부설연구소
