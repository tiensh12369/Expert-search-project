# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import re

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 633 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if key_query['prdEnd'][:4] in nyear or key_query['prdStart'][:4] in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if (key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        #all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        #if site[i] != 'NTIS' :
        A_id = [A_id]
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]
              
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt) :  # 소속 같을때
#                                if site[i]
                                Answer_dict[tempName][site[i]]['A_id'].extend(A_id)
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1]  or (src != "" and src in tgt):  # 소속 같을때
                            # if temp[key]['inst'] == all_inst[-1] : #or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]

                count += 1

#print(sorted(Answer_dict.items()))
print(len(all_name))
#id_domestic.insert_many(Answer_dict.values()) #mongodb 추가
# Out:
# 789

# %%
def check_college(univ0):
    univName = client['PUBLIC']['CollegeName']
    univ1 = re.sub("산학협력단|병원","",univ0)
    univ2 = re.sub("대학교","대학교 ",univ1)
    try:

        reg = re.compile(r'[a-zA-Z]')
    
        if reg.match(univ0):
            univ0 = univ0.upper()
            univ = univ0.split(', ')
            
        else:
            univ = univ2.replace(",", "").split()
            univ = list(set(univ))
            
        univs = "{'$or': ["
        for u in range(len(univ)):
            if univ[-1] == univ[u]:
                univs += "{'inputName': '" + univ[u] + "'}"
            else:
                univs += "{'inputName': '" + univ[u] + "'}, "
        univs += "]}"

        univ_query = univName.find_one(eval(univs))

        if univ_query is None:
            print("Search inst None")
            return univ0, False
        else:
            #print("rawInput:[",univ0,"]","queryOutput:" ,univ_query['originalName'])
            return univ_query['originalName'], True #univ0, univ_query
        
    except SyntaxError as e:
        print(e)
        print(univ0)
        return univ0, False

def filter(name, site, inst, rawdata):
    instbool = False
    if site == 'NTIS' :
        oriinst = rawdata['ldAgency']
        inst, instbool = check_college(inst)
        #inst = oriinst

        '''
        if inst == None:
            inst = oriinst
        else:
            inst = oriinst.replace(inst['inputName'], inst['originalName'])
        ''' 
        coauthor = rawdata['rsc'].split(";")
        year = int(rawdata['prdStart'][:4])
        keyword = rawdata['koKeyword'].split(",")
        journal = ""
        conference = ""
        title = ""
        mng = rawdata['mng']

    else :
        oriinst = rawdata['author_inst'].split(";")[rawdata['author'].split(";").index(name)]
        inst, instbool = check_college(inst)
        #inst = oriinst

        '''
        if inst == None:
            inst = oriinst
        else:
            inst = oriinst.replace(inst['inputName'], inst['originalName'])
        '''
        coauthor = rawdata['author'].split(";")[1:-1]
        year = int(rawdata['issue_year'][:4])
        
        if rawdata['paper_keyword'] == [] or rawdata['paper_keyword'] == 'None':
            keyword = []
        elif len(rawdata['paper_keyword']) > 1:
            for i in range(0, len(rawdata['paper_keyword'])):
                keyword = []
                keyword.append(rawdata['paper_keyword'][i].replace(" ", "").split("."))            
        else:
            keyword = rawdata['paper_keyword'].replace(" ", "").split(".")

        journal = rawdata['journal']
        conference = rawdata['issue_inst']
        title = rawdata['title']
        mng = rawdata['author'].split(";")[-1]
        #abstract = rawdata['abstract']

    return inst, coauthor, year, keyword, journal, conference, title, instbool
    #return inst, coauthor, year, keyword, journal, conference, title, mng, abstract

def Secondary_filter(name, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst = 0
    inst1, coauthor1, year1, keyword1, journal1, conference1, title1, instbool1 = filter(name, site1, inst1, raw_one1)
    inst2, coauthor2, year2, keyword2, journal2, conference2, title2, instbool2 = filter(name, site2, inst2, raw_one2)

    if instbool1 and instbool2:
        if inst1 == inst2:
            inst = 1
    else:
        inst = jaro.jaro_winkler_metric(inst1, inst2)
        
    weight = 0
    joc = 0
    
    if name in coauthor1:
        coauthor1.remove(name)

    if name in coauthor2:
        coauthor2.remove(name)

    

    co_author_count = len([i for i in coauthor1 if i in coauthor2])

    if site1 != 'NTIS' and site2 != 'NTIS' :
        if title1 == title2 or inst >= 0.8: #or mng1 == mng2: # 
            weight = 4
            return weight

        else:
            joc = 1 if journal1 == journal2 and conference1 == conference2 else -1
    else:
        if inst >= 0.8:
            weight = 3
            return weight
            
    yop = -(2*(abs(year1-year2)/10)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) > len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
                
    co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    #print(f'joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')

    weight = joc + yop + co_authorship + keyword

    return weight

# %%
data0 = Answer_dict
sites = ['NTIS', 'SCIENCEON', 'KCI']
raw_dbs = {'NTIS' : ntis_raw, 'SCIENCEON' : scion_raw, 'KCI' : kci_raw}

def getRaw(name):
    if 'raws' not in data0[name]:
        raws = []
        for site in sites:
            if site in data0[name]:
                for c in raw_dbs[site].find({"_id": {"$in": data0[name][site]['papers']}}):
                    c['site'] = site
                    raws.append(c)
        
        data0[name]['raws'] = raws

processedList = []
deleteList = []

for data in data0 :
    if '_' in data :
        name = data.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in data0 :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        
        processedList.append(name[0])
        flag = True
        while flag : 
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            
            for pair in pairs:
                pair = list(pair)
                
                '''
                # <2차통합 유사도 함수 자리>
                # 2차통합유사도함수_상혁(data0[pair[0]]['raws'], data0[pair[1]]['raws'])
                # return 값으로 두 명에 대한 유사도 값이 나옴
                # 6 이상이면 통합 / 임시로 result 변수로 사용
                '''
                # pair[0]                  pair[1]
                
                raws1 = data0[pair[0]]['raws']
                
                raws2 = data0[pair[1]]['raws']
                
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = data0[pair[0]][site1]['inst']
                    inst2 = data0[pair[1]][site2]['inst']


                    if Secondary_filter(name[0], site1, inst1, ra1, site2, inst2, ra2) >= 3:

                        # print("=================")
                        # print(data0[pair[0]])
                        # print(ra1)
                        # print(data0[pair[1]])
                        # print(ra2)
                        deleteList.append(pair[1])
                        for site in sites:
                            if site in data0[pair[1]]:
                                if site in data0[pair[0]].keys() :                            
                                    data0[pair[0]][site]['A_id'].extend(data0[pair[1]][site]['A_id'])
                                    data0[pair[0]][site]['papers'].extend(data0[pair[1]][site]['papers'])
                                    data0[pair[0]]['raws'].extend(data0[pair[1]]['raws'])
                                else:
                                    data0[pair[0]][site] = data0[pair[1]][site]
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break
        
for d in deleteList:
    del data0[d]

#print(data0)
for d in data0 : 
    if 'raws' in data0[d] :
        del data0[d]['raws']

#print(data0)
# Out:
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None
# Search inst None

# %%
import json
Answer_dict = data0

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter, numInteErr
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
       
        if len(answer[name].keys()) > 1 :
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        else :
            pass
       #    print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name'].split('_')[0]
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            # if name+str(count) not in answer :
            #     print(name)
            while name+str(count) in answer :
                # if name+count in answer :
             #   print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError = 0
    
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError += 1
                
                #print("answer=",key, answer[key])
                '''
                if key not in Answer_dict :
                    count = 0
                    
                    while key+str(count) in Answer_dict :
                        # if name+count in answer :
                        print("result=", Answer_dict[ key+str(count)])                        
                        count += 1
                else :    
                    print("result=", Answer_dict[key])
                '''
            #print(key)|
            #print(answer[key])
        
    print("토탈에러", totalError)   
    print("토탈ㅇ인터그레이션에러", totalInteError)
    print(keyid)    

print(Answer_dict)
# Out:
# 653
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울시립대학교산학협력단', 'SCIENCEON': 'School of Electrical and Computer Engineering, University of Seoul', 'KCI': '서울시립대학교'}
#  - Result : {'fid': 0, 'keyId': 644, 'name': '이용우', 'NTIS': {'inst': '서울시립대학교산학협력단', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjIzMzMwNDcyNTE3OQ=='], 'papers': [ObjectId('61ce6f37f8d08a558d7cb8c3')]}, 'KCI': {'inst': '서울시립대학교', 'A_id': ['s48282'], 'papers': [ObjectId('61ce6f6c0f91d3fd2b7ca322')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '서울시립대학교산학협력단', 'SCIENCEON': 'School of Electrical and Computer Engineering, University of Seoul', 'KCI': '서울시립대학교'}
#  - Result : {'fid': 0, 'keyId': 644, 'name': '이용우', 'SCIENCEON': {'inst': 'School of Electrical and Computer Engineering, University of Seoul', 'A_id': ['s260355'], 'papers': [ObjectId('61ce6f25de84cb5ab77cad88')]}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : {'NTIS': '광운대학교', 'SCIENCEON': '광운대학교 컴퓨터정보공학부', 'KCI': '광운대학교'}
#  - Result : {'fid': 0, 'keyId': 644, 'name': '신영주', 'KCI': {'inst': '고려대학교', 'A_id': ['s545062'], 'papers': [ObjectId('61ce6f5e0f91d3fd2b7ca2ee')]}}
# num코렉트 617
# numEror 51
# numInteEror 3
# answer= 강수용 {'NTIS': '한양대학교'}
# answer= 고정길 {'NTIS': '아주대학교'}
# answer= 김민수 {'NTIS': '대구경북과학기술원'}
# answer= 김상현 {'KCI': '경북대학교'}
# answer= 김원석 {'NTIS': '안동대학교'}
# answer= 김원석0 {'KCI': '부산대학교 전기전자컴퓨터공학과'}
# answer= 김원석1 {'KCI': '안동대학교'}
# answer= 김중헌 {'NTIS': '고려대학교'}
# answer= 남해운 {'NTIS': '한양대학교 에리카산학협력단'}
# answer= 문형진0 {'SCIENCEON': '성결대학교 정보통신공학과'}
# answer= 문형진1 {'KCI': '독립연구자'}
# answer= 박종웅 {'NTIS': '중앙대학교산학협력단'}
# answer= 박호성 {'NTIS': '전남대학교'}
# answer= 서영호 {'NTIS': '광운대학교'}
# answer= 서종원 {'NTIS': '한양대학교산학협력단'}
# answer= 서주연0 {'NTIS': '경상대학교'}
# answer= 서주연1 {'KCI': '부산경상대학교'}
# answer= 손미애 {'NTIS': '성균관대학교(자연과학캠퍼스)'}
# answer= 안성용 {'NTIS': '부산대학교'}
# answer= 안성훈 {'NTIS': '서울대학교'}
# answer= 이상근1 {'NTIS': '한양대학교(ERICA캠퍼스)'}
# answer= 이승용 {'NTIS': '포항공과대학교 산학협력단'}
# answer= 이승현 {'NTIS': '광운대학교 산학협력단'}
# answer= 이용우 {'NTIS': '서울시립대학교산학협력단', 'SCIENCEON': 'School of Electrical and Computer Engineering, University of Seoul', 'KCI': '서울시립대학교'}
# answer= 임종범 {'NTIS': '평택대학교'}
# answer= 장영민 {'NTIS': '국민대학교산학협력단'}
# answer= 정세훈 {'NTIS': '영산대학교'}
# answer= 정연돈 {'NTIS': '고려대학교산학협력단'}
# answer= 정원기 {'NTIS': '울산과학기술원'}
# answer= 정은성 {'NTIS': '홍익대학교(세종캠퍼스)'}
# answer= 조기환 {'NTIS': '전북대학교산학협력단'}
# answer= 조성현 {'NTIS': '한양대학교 에리카산학협력단'}
# answer= 최동완 {'NTIS': '인하대학교 산학협력단'}
# answer= 최문택 {'NTIS': '성균관대학교(자연과학캠퍼스)'}
# answer= 최영리 {'NTIS': '울산과학기술원'}
# answer= 황인철 {'NTIS': '국립강원대학교 산학협력단'}
# 토탈에러 36
# 토탈ㅇ인터그레이션에러 1
# 644
# {'Kim, Won-Tae': {'fid': 0, 'keyId': 644, 'name': 'Kim, Won-Tae', 'SCIENCEON': {'inst': '한국기술교육대학교 컴퓨터공학부', 'A_id': ['s101699'], 'papers': [ObjectId('61ce6f2ade84cb5ab77cadab')]}}, '권순동': {'fid': 0, 'keyId': 644, 'name': '권순동', 'SCIENCEON': {'inst': '충북대학교 경영정보학과', 'A_id': ['s101714'], 'papers': [ObjectId('61ce6f25de84cb5ab77cad79')]}}, '민홍': {'fid': 0, 'keyId': 644, 'name': '민홍', 'SCIENCEON': {'inst': '호서대학교 컴퓨터정보공학부', 'A_id': ['s101964'], 'papers': [ObjectId('61ce6f25de84cb5ab77cad7d')]}, 'KCI': {'inst': '호서대학교', 'A_id': ['s82749'], 'papers': [ObjectId('61ce6f3b0f91d3fd2b7ca26f')]}}, '장시웅': {'fid': 0, 'keyId': 644, 'name': '장시웅', 'SCIENCEON': {'inst': '동의대학교', 'A_id': ['s102062'], 'papers': [ObjectId('61ce6f25de84cb5ab77cad96')]}}, '신병춘': {'fid': 0, 'keyId': 644, 'name': '신병춘', 'SCIENCEON': {'inst': '전남대학교 수학과', 'A_id': ['s103313'], 'papers': [ObjectId('61ce6f2fde84cb5ab77cade2')]}, 'KCI': {'inst': '전남대학교', 'A_id': ['s49469'], 'papers': [ObjectId('61ce6f5e0f91d3fd2b7ca2ed')]}}, '김종원': {'fid': 0, 'keyId': 644, 'name': '김종원', 'SCIENCEON': {'inst': '광주과학기술원 전기전자컴퓨터공학부', 'A_id': ['s103413'], 'papers': [ObjectId('61ce6f25de84cb5ab77cad82')]}, 'KCI': {'inst': '광주과학기술원 전기전자컴퓨터공학부', 'A_id': ['s49552'], 'papers': [ObjectId('61ce6f3e0f91d3fd2b7ca286'), ObjectId('61ce6f350f91d3fd2b7ca223')]}}, '오명훈': {'fid': 0, 'keyId': 644, 'name': '오명훈', 'SCIENCEON': {'inst': '한국전자통신연구원 클라우드컴퓨팅연구그룹', 'A_id': ['s1062769'], 'papers': [ObjectId('61ce6f2ade84cb5ab77cad9d')]}}, 'Woo, Tae Ho': {'fid': 0, 'keyId': 644, 'name': 'Woo, Tae Ho', 'SCIENCEON': {'inst': '고려사이버대학교 기계제어공학과', 'A_id': ['s1067357'], 'papers': [ObjectId('61ce6f2fde84cb5ab77cadeb')]}}, '이승윤': {'fid': 0, 'keyId': 644, 'name': '이승윤', 'SCIENCEON': {'inst': '오픈소스센터', 'A_id': ['s106768'], 'papers': [ObjectId('61ce6f2cde84cb5ab77cadca')]}}, '오인하': {'fid': 0, 'keyId': 644, 'name': '오인하', 'SCIENCEON': {'inst': '건국대학교 신산업융합학과', 'A_id': ['s1084289'], 'papers': [ObjectId('61ce6f2fde84cb5ab77cade6')]}, 'KCI': {'inst': '건국대학교', 'A_id': ['s351759'], 'papers': [ObjectId('61ce6f380f91d3fd2b7ca237')]}}, 'Zhao, Yongjiang': {'fid': 0, 'keyId': 644, 'name': 'Zhao, Yongjiang', 'SCIENCEON': {'inst': '전남대학교 대학원 컴퓨터공학과', 'A_id': ['s1085663'], 'papers': [ObjectId('61ce6f2fde84cb5ab77caded')]}}, '안상현': {'fid': 0, 'keyId': 644, 'name': '안상현', 'SCIENCEON': {'inst': '서울시립대학교 컴퓨터과학부', 'A_id': ['s111051'], 'papers': [ObjectId('61ce6f2cde84cb5ab77cadcd')]}, 'KCI': {'inst': '서울시립대학교', 'A_id': ['s93783'], 'papers': [ObjectId('61ce6f4d0f91d3fd2b7ca2ae')]}}, '박원형': {'fid': 0, 'keyId': 644, 'name': '박원형', 'SCIENCEON': {'inst': '상명대학교 정보보안공학과', 'A_id': ['s1127194', 's1401796'], 'papers': [ObjectId('61ce6f2fde84cb5ab77cadf6'), ObjectId('61ce6f2fde84cb5ab77cadfa')]}, 'KCI': {'inst': '상명대학교', 'A_id': ['s538595'], 'papers': [ObjectId('61ce6f560f91d3fd2b7ca2b9')]}}, 'Choo, Hyunseung': {'fid': 0, 'keyId': 644, 'name': 'Choo, Hyunseung', 'SCIENCEON': {'inst': 'College of Computing, Sungkyunkwan University', 'A_id': ['s113050'], 'papers': [ObjectId('61ce6f2cde84cb5ab77cadd1')]}}, '허진': {'fid': 0, 'keyId': 644, 'name': '허진', 'SCIENCEON': {'inst': '한세대학교 ICT환경공학과 대학원', 'A_id': ['s113352'], 'papers': [ObjectId('61ce6f2cde84cb5ab77cadd2')]}, 'KCI': {'inst': '한세대학교', 'A_id': ['s544046'], 'papers': [ObjectId('61ce6f350f91d3fd2b7ca228')]}}, '박수희': {'fid': 0, 'keyId': 644, 'name': '박수희', 'SCIENCEON': {'inst': '동덕여자대학교 컴퓨터학과', 'A_id': ['s115224'], 'papers': [ObjectId('61ce6f2cde84cb5ab77cadd0')]}, 'KCI': {'inst': '동덕여자대학교', 'A_id': ['s81587'], 'papers': [ObjectId('61ce6f4d0f91d3fd2b7ca2ad')]}}, '김상현': {'fid': 0, 'keyId': 644, 'name': '김상현', 'SCIENCEON': {'inst': '경북대학교 경영학부', 'A_id': ['s115242'], 'papers': [ObjectId('61ce6f2cde84cb5ab77cadd4')]}, 'NTIS': {'inst': '경북대학교', 'A_id': ['s3816'], 'papers': [ObjectId('61ce6f47f8d08a558d7cbac7')]}, 'KCI': {'inst': '경북대학교', 'A_id': ['s51096'], 'papers': [ObjectId('61ce6f350f91d3fd2b7ca224')]}}, '김경일': {'fid': 0, 'keyId': 644, 'name': '김경일', 'SCIENCEON': {'inst': '한국교통대학교 융합경영전공', 'A_id': ['s115258'], ...

# %%
a = jaro.jaro_winkler_metric('대학교', '인하대학교')
print(a)
# Out:
# 0.9333333333333332
