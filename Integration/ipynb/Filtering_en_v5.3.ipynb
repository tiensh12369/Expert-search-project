# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# v5.3: 중복논문 수정, flag 삭제
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 914 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []
plang = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']
            plang = fid_key_query[key]['lang']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}
f_plang = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst) and simple_filter(paper_lang, plang):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }
        
        if pre_name == 'herrerafrancisco' and site == 'SCOPUS':
            print(Answer)
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

print(f'2차 통합: {savetime2}')
print(Inte_name)
print(len(Answer_dict))
# Out:
# DB 수집: WOS, 0.21163296699523926
# 전체 저자 수: 149
# DB 수집: SCOPUS, 0.2956080436706543
# 전체 저자 수: 260
# 2차 통합: 0.5082414150238037
# []
# 409

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    if site == "WOS":
        email.extend(rawdata['emails'].replace(" ", "").split(";"))
        funding_text.append(rawdata['funding text'])
        
    elif site == "SCOPUS":
        emails = rawdata['correspondence_address'].split(" ")
        for i in emails:
            if "@" in i:
                email.append(i)

        for funding in  rawdata.keys():
            if "funding_text_" in funding:
                funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
    
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2:
                funding_exact = 0
                # print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
        
        
    if paper_sim >= 0.8 or inst_sim >= 0.83 or email_exact == 1 or funding_exact == 1:
        weight = 4
        print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
        print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
        print(f'weigth: {weight}')
        print('------------------------------------------------------------구분선2------------------------------------------------------------')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    # print(f'weigth: {weight} | joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')
    # print(f'name1: {name1} | site1: {site1} | year: {year1} | coauthor: {coauthor1} | keyword: {keyword1} | journal1: {journal1}')
    # print(f'name2: {name2} | site1: {site2} | year: {year2} | coauthor: {coauthor2} | keyword: {keyword2} | journal2: {journal2}')
    # print(f'paper_sim: {paper_sim}')
    # print(f'title1: {title1}')
    # print(f'title2: {title2}')
    # print(f'inst_sim: {inst_sim}')
    # print(f'inst1: {inst1}')
    # print(f'inst2: {inst2}')
    # print(f'email_exact: {email_exact}')
    # print(f'emails1: {emails1}')
    # print(f'emails2: {emails2}')
    # print(raw_one1)
    # print(raw_one2)
    print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
    print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
    print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
    print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
    print(f'weigth: {weight}')
    print('------------------------------------------------------------구분선------------------------------------------------------------')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['Chemistry', ' Engineering', ' Materials Science', ' Physics'] | journal1: SOFTWAREX | journal2: APPL SCI-BASEL
# name1: Otaegui, Oihana | inst1: Basque Res & Technol Alliance BRTA, Vicomtech Fdn, Mikeletegi 57, San Sebastian 20009, Spain | title1: Boosting AI applications: Labeling format for complex datasets | site1: WOS
# name2: Otaegui, Oihana | inst2: Vicomtech, Parque Cient & Tecnol Gipuzkoa, Donostia San Sebastian 20009, Spain | title2: Design and Implementation of an Ontology for Semantic Labeling and Testing: Automotive Global Ontology (AGO) | site1: WOS
# inst: 0.6927722036417688 | title: 0.6533307990297237 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['AD', ' ADAS', ' Graph database', ' Labeling', ' Neo4j', ' Ontology', ' Scenario-based testing', ' Semantics'] | journal1: SOFTWAREX | journal2: MDPI AG
# name1: Otaegui, Oihana | inst1: Basque Res & Technol Alliance BRTA, Vicomtech Fdn, Mikeletegi 57, San Sebastian 20009, Spain | title1: Boosting AI applications: Labeling format for complex datasets | site1: WOS
# name2: Otaegui, Oihana | inst2: Vicomtech Foundation Basque Research and Technology Alliance (BRTA) Mikeletegi 57 San Sebastian 20009 Spain | title2: Design and implementation of an ontology for semantic labeling and testing: Automotive global ontology (ago | site1: SCOPUS
# inst: 0.7624906394154948 | title: 0.654917276472899 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2022 | co_author_count: 3 | keyword: ['Computer Science', ' Telecommunications'], ['Computer Science'] | journal1: PERVASIVE MOB COMPUT | journal2: IEEE TETCI
# name1: Khan, Shahzad | inst1: Gnowit Inc, 200-308 Legett Dr, Kanata, ON, Canada | title1: AI-driven autonomous vehicles as COVID-19 assessment centers: A novel crowdsensing-enabled strategy | site1: WOS
# name2: Khan, Shahzad | inst2: Gnowit Inc, Kanata, ON K2W0B5, Canada | title2: Machine Learning-Backed Planning of Rapid COVID-19 Tests With Autonomous Vehicles With Zero-Day Considerations | site1: WOS
# inst: 0.8706480135051564 | title: 0.7241632006337889 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Social Sciences - Other Topics'], ['Ai4people', ' Autonomous driving', ' Autonomous vehicle ethics', ' Ethics of ai', ' Fundamental rights', ' Governance', ' Override', ' Regulation', ' Self-driving cars', ' Transparency'] | journal1: INT J TECHNOETHICS | journal2: IGI Global
# name1: Naseer, Aisha | inst1: Fujitsu Labs Europe, Birmingham, W Midlands, England | title1: AI4People: Ethical Guidelines for the Automotive Sector - Fundamental Requirements and Practical Recommendations | site1: WOS
# name2: Naseer, Aisha | inst2: Fujitsu Laboratories of Europe United Kingdom | title2: AI4people: Ethical guidelines for the automotive sector-fundamental requirements and practical recommendations | site1: SCOPUS
# inst: 0.6984071484071483 | title: 0.9491774891774891 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['automation of everything (AoE)', ' Autonomous vehicles', ' cloud platform', ' crowdsourcing', ' driverless vehicles', ' fog platform', ' Internet of Everything (IoE)', ' mobile-edge computing (MEC)', ' smart city'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Khan, Wasiq | inst1: Liverpool John Moores Univ, Fac Engn & Technol, Liverpool L3 5UZ, Merseyside, England | title1: A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles With Smart City | site1: WOS
# name2: Khan, Wasiq | inst2: Faculty of Engineering and Technology Liverpool John Moores University Liverpool United Kingdom | title2: A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles with Smart City | site1: SCOPUS
# inst: 0.7059579354351081 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Engineering'], [''] | journal1: IEEE IND ELECTRON M | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Wen-Huang | inst1: Natl Chiao Tung Univ, Inst Elect, Hsinchu, Taiwan | title1: A Human-Like Traffic Scene Understanding System: A Survey | site1: WOS
# name2: Cheng, Wen Huang | inst2: Department of Electronics Engineering National Chiao Tung University Hsinchu Taiwan | title2: A Human-Like Traffic Scene Understanding System: A Survey | site1: SCOPUS
# inst: 0.6185138250542725 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['5G', ' AMP', ' CNN', ' Image segmentation', ' K-Means', ' Speed Range Analyser'] | journal1: COMPUT NETW | journal2: Elsevier B.V.
# name1: Tanwar, Sudeep | inst1: Nirma Univ, Inst Technol, Dept Comp Sci Engn, Ahmadabad 382481, Gujarat, India | title1: An AI-driven object segmentation and speed control scheme for autonomous moving platforms | site1: WOS
# name2: Tanwar, Sudeep | inst2: Department of Computer Science Engineering Institute of Technology Nirma University Ahmedabad 382481 India | title2: An AI-driven object segmentation and speed control scheme for autonomous moving platforms | site1: SCOPUS
# inst: 0.6764671387312896 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['low light', ' modified perceptual CycleGAN', ' perceptual loss', ' road scene open database', ' Semantic segmentation'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Park, Kang Ryoung | inst1: Dongguk Univ, Div Elect & Elect Engn, Seoul 04620, South Korea | title1: Modified Perceptual Cycle Generative Adversarial Network-Based Image Enhancement for Improving Accuracy of Low Light Image Segmentation | site1: WOS
# name2: Park, Kang-ryoung | inst2: Division of Electronics and Electrical Engineering Dongguk University Seoul 04620 South Korea | title2: Modified Perceptual Cycle Generative Adversarial Network-Based Image Enhancement for Improving Accuracy of Low Light Image Segmentation | site1: SCOPUS
# inst: 0.6628833134209479 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 3 | keyword: ['Engineering', ' Transportation'], ['deep learning', ' Lane changing', ' reinforcement learning'] | journal1: IEEE T INTELL TRANSP | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Li, Li | inst1: Tsinghua Univ, Dept Automat, BNRist, Beijing 100084, Peoples R China | title1: Harmonious Lane Changing via Deep Reinforcement Learning | site1: WOS
# name2: Li, Li | inst2: Department of Automation BNRist Tsinghua University Beijing 100084 China | title2: Harmonious Lane Changing via Deep Reinforcement Learning | site1: SCOPUS
# inst: 0.7375050773605111 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 6 | keyword: ['Engineering', ' Transportation'], ['actuation redundancy', ' data-learning', ' Energy planning', ' over-actuated unmanned road vehicle'] | journal1: IEEE T INTELL TRANSP | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Merzouki, Rochdi | inst1: Ecole Mil Polytech, Dept Mech Engn, Algiers 16111, Algeria | title1: Energy Planning for Autonomous Driving of an Over-Actuated Road Vehicle | site1: WOS
# name2: Merzouki, Rochdi | inst2: Laboratory Centre de Recherche en Informatique Signal et Automatique de Lille (CRIStAL) Polytech Lille University of Lille Lille 59655 France | title2: Energy Planning for Autonomous Driving of an Over-Actuated Road Vehicle | site1: SCOPUS
# inst: 0.5195507677747356 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Telecommunications'], ['ADMM', ' edge learning', ' mobile edge computing', ' Reconfigurable intelligent surface'] | journal1: IEEE T COGN COMMUN | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Huang, Kaibin | inst1: South China Univ Technol, Sch Elect & Informat Engn, Guangzhou 510641, Peoples R China | title1: Reconfigurable Intelligent Surface Assisted Mobile Edge Computing With Heterogeneous Learning Tasks | site1: WOS
# name2: Huang, Kaibin | inst2: Department of Electrical and Electronic Engineering University of Hong Kong Hong Kong | title2: Reconfigurable Intelligent Surface Assisted Mobile Edge Computing with Heterogeneous Learning Tasks | site1: SCOPUS
# inst: 0.5849591357115297 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Robotics'], ['AI-based methods', ' autonomous vehicle navigation', ' intelligent transportation systems', ' learning from demonstration'] | journal1: IEEE ROBOT AUTOM LET | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Shim, David Hyunchul | inst1: Korea Adv Inst Sci & Technol, Sch Elect Engn, KS015, Daejeon, South Korea | title1: Incorporating Multi-Context Into the Traversability Map for Urban Autonomous Driving Using Deep Inverse Reinforcement Learning | site1: WOS
# name2: Shim, David Hyunchul | inst2: School of Electrical Engineering Korea Advanced Institute of Science and Technology Daejeon South Korea | title2: Incorporating Multi-Context into the Traversability Map for Urban Autonomous Driving Using Deep Inverse Reinforcement Learning | site1: SCOPUS
# inst: 0.6611716268606984 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Transportation'], ['Artificial intelligence (AI)', ' Autonomous vehicle (AV) control', ' Mixed autonomy'] | journal1: TRANSPORT RES C-EMER | journal2: Elsevier Ltd
# name1: Shi, Rongye | inst1: Columbia Univ, Dept Civil Engn & Engn Mech, New York, NY 10027 USA | title1: A survey on autonomous vehicle control in the era of mixed-autonomy: From physics-based to AI-guided driving policy learning | site1: WOS
# name2: Shi, Rongye | inst2: Department of Civil Engineering and Engineering Mechanics Columbia University United States | title2: A survey on autonomous vehicle control in the era of mixed-autonomy: From physics-based to AI-guided driving policy learning | site1: SCOPUS
# inst: 0.5803640803640803 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Construction & Building Technology'], ['4th Industrial Revolution', ' Industry 4.0. future of work', ' smart infrastructure', ' smart technology', ' urban transformation'] | journal1: INTELL BUILD INT | journal2: Taylor and Francis Ltd.
# name1: Maynard, Kasia | inst1: WORKTECH Acad, Kingston Upon Thames, Surrey, England | title1: Towards a 4th industrial revolution | site1: WOS
# name2: Maynard, Kasia | inst2: WORKTECH Academy Kingston upon Thames United Kingdom Department of Urban Studies and Planning University of Sheffield Sheffield United Kingdom | title2: Towards a 4th industrial revolution | site1: SCOPUS
# inst: 0.6356461418081136 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Business & Economics'], ['Case study', ' Decision-making', ' Europe', ' Information technology', ' Performance measurements', ' Retail logistics'] | journal1: INT J LOGIST MANAG | journal2: Emerald Group Holdings Ltd.
# name1: Klumpp, Matthias | inst1: FOM Univ Appl Sci, Inst Logist & Serv Management, Essen, Germany | title1: Intelligent and efficient? An empirical analysis of human-AI collaboration for truck drivers in retail logistics | site1: WOS
# name2: Klumpp, Matthias | inst2: Institute for Logistics and Service Management FOM University of Applied Sciences Essen Germany Chair for Production and Logistics Faculty of Business and Economics Georg-August-University of Göttingen Göttingen Germany Fraunhofer IML Dortmund Germany | title2: Intelligent and efficient? An empirical analysis of human–AI collaboration for truck drivers in retail logistics | site1: SCOPUS
# inst: 0.5699590526781763 | title: 0.9964285714285714 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Computer Science', ' Engineering', ' Transportation'], ['autonomous vehicles', ' deep learning', ' Feature extraction', ' Image segmentation', ' Lane detection', ' Lane detection', ' Reliability', ' Roads', ' scene understanding', ' semantic segmentation', ' Semantics', ' Training'] | journal1: IEEE T INTELL VEHICL | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Wang, Fan | inst1: Seres Inc, Santa Clara, CA 95054 USA | title1: SUPER: A Novel Lane Detection System | site1: WOS
# name2: Wang, Fan | inst2: SF Motors Inc SF Motors Inc Santa Clara California United States (e-mail: fan.wang@driveseres.com) | title2: SUPER: A Novel Lane Detection System | site1: SCOPUS
# inst: 0.5031821617535903 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Computer vision', ' Object detection', ' Road transportation', ' Safety management'] | journal1: APPL SCI-BASEL | journal2: MDPI AG
# name1: Abdelgawad, Hossam | inst1: Cairo Univ, Traff & Highway Engn Dept, Cairo 12613, Egypt | title1: Automatic Roadway Features Detection with Oriented Object Detection | site1: WOS
# name2: Abdelgawad, Hossam | inst2: Traffic and Highway Engineering Department Cairo University Cairo 12613 Egypt | title2: Automatic roadway features detection with oriented object detection | site1: SCOPUS
# inst: 0.6891471101997416 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Computer Science'], ['Autonomous driving', ' Deep learning', ' Multi-task learning'] | journal1: NEURAL COMPUT APPL | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Mahmood, Arif | inst1: Informat Technol Univ, Dept Comp Sci, Lahore, Pakistan | title1: Statistically correlated multi-task learning for autonomous driving | site1: WOS
# name2: Mahmood, Arif | inst2: Department of Computer Science Information Technology University Lahore Pakistan | title2: Statistically correlated multi-task learning for autonomous driving | site1: SCOPUS
# inst: 0.7103213507625273 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Physics'], ['Autonomous systems', ' Data collection and annotation', ' Gamification', ' Self-driving vehicles', ' Simulation', ' Training systems', ' Transfer learning'] | journal1: ELECTRONICS-SWITZ | journal2: MDPI AG
# name1: Sun, Yongbin | inst1: MIT, Dept Mech Engn, 77 Massachusetts Ave, Cambridge, MA 02139 USA | title1: A Gamified Simulator and Physical Platform for Self-Driving Algorithm Training and Validation | site1: WOS
# name2: Sun, Yongbin | inst2: Department of Mechanical Engineering Massachusetts Institute of Technology Cambridge MA  02139 United States | title2: A gamified simulator and physical platform for self-driving algorithm training and validation | site1: SCOPUS
# inst: 0.6293490460157126 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 5 | keyword: ['Physical Geography', ' Geology', ' Remote Sensing', ' Imaging Science & Photographic Technology'], ['Adversarial learning', ' Domain adaptation', ' Multi-modal learning', ' Point cloud', ' Semantic segmentation'] | journal1: ISPRS J PHOTOGRAMM | journal2: Elsevier B.V.
# name1: Li, Jonathan | inst1: Univ Fed Mato Grosso do Sul, BR-79070900 Campo Grande, MS, Brazil | title1: Adversarial unsupervised domain adaptation for 3D semantic segmentation with multi-modal learning | site1: WOS
# name2: Li, Jonathan | inst2: University of Waterloo Waterloo N2L 3G1 Canada | title2: Adversarial unsupervised domain adaptation for 3D semantic segmentation with multi-modal learning | site1: SCOPUS
# inst: 0.6045707915273132 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Artificial intelligence', ' Autonomous vehicles', ' Intelligent transportation system', ' Road safety', ' Urban transport system'] | journal1: APPL SCI-BASEL | journal2: MDPI AG
# name1: Pau, Giovanni | inst1: Kore Univ Enna, Fac Engn & Architecture, I-94100 Enna, Italy | title1: Autonomous Vehicles: An Analysis Both on Their Distinctiveness and the Potential Impact on Urban Transport Systems | site1: WOS
# name2: Pau, Giovanni | inst2: Faculty of Engineering and Architecture Kore University of Enna Enna 94100 Italy | title2: Autonomous vehicles: An analysis both on their distinctiveness and the potential impact on urban transport systems | site1: SCOPUS
# inst: 0.6919117647058823 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Engineering', ' Transportation'], ['Artificial intelligence', ' Artificial intelligence', ' autonomous driving', ' Autonomous vehicles', ' Companies', ' Computer architecture', ' hybrid human-artificial intelligence', ' Man-machine systems', ' Roads', ' Testing', ' theoretical architecture.'] | journal1: IEEE T INTELL TRANSP | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Shi, Feifei | inst1: Natl Univ Modern Languages, Dept Comp Sci, Islamabad 44000, Pakistan | title1: A Survey on Hybrid Human-Artificial Intelligence for Autonomous Driving | site1: WOS
# name2: Shi, Feifei | inst2: School of Computer and Communication Engineering University of Science and Technology Beijing Beijing 100083 China. | title2: A Survey on Hybrid Human-Artificial Intelligence for Autonomous Driving | site1: SCOPUS
# inst: 0.554980107985223 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['autonomous vehicles testing', ' mutation testing', ' self-driving cars', ' test oracles'] | journal1: J SOFTW-EVOL PROC | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Tonella, Paolo | inst1: USI, Software Inst, Lugano, Switzerland | title1: Confidence-driven weighted retraining for predicting safety-critical failures in autonomous driving systems | site1: WOS
# name2: Tonella, Paolo | inst2: Software Institute - Università della Svizzera Italiana Lugano Switzerland | title2: Quality Metrics and Oracles for Autonomous Vehicles Testing | site1: SCOPUS
# inst: 0.6457803957803958 | title: 0.6578316028973402 | email: 0, funding: 0
# weigth: 2.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Mathematical & Computational Biology'], [''] | journal1: NPJ SYST BIOL APPL | journal2: Nature Research
# name1: Kitano, Hiroaki | inst1: Syst Biol Inst, Tokyo, Japan | title1: Nobel Turing Challenge: creating the engine for scientific discovery | site1: WOS
# name2: Kitano, Hiroaki | inst2: The Systems Biology Institute Tokyo Japan Okinawa Institute of Science and Technology Graduate School Okinawa Japan Sony Computer Science Laboratories Inc. Tokyo Japan Sony AI Inc. Tokyo Japan The Alan Turing Institute London United Kingdom | title2: Nobel Turing Challenge: creating the engine for scientific discovery | site1: SCOPUS
# inst: 0.5635836385836387 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Engineering', ' Instruments & Instrumentation'], ['Autonomous driving', ' Genetic algorithm (GA)', ' Logistics system', ' Multi-sensor fusion', ' Simultaneous localization and mapping (SLAM)'] | journal1: ACTUATORS | journal2: MDPI AG
# name1: Zhang, Juan | inst1: Univ Exeter, Coll Engn Math & Phys Sci, Exeter EX4 4QF, Devon, England | title1: An Intelligent Actuator of an Indoor Logistics System Based on Multi-Sensor Fusion | site1: WOS
# name2: Zhang, Juan | inst2: College of Engineering Mathematics and Physical Sciences University of Exeter Exeter EX4 4QF United Kingdom | title2: An intelligent actuator of an indoor logistics system based on multi-sensor fusion | site1: SCOPUS
# inst: 0.6559635068980864 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['Autonomous driving', ' CNN', ' Deep learning', ' ImageNet', ' MobileNetV2', ' Nvidia model', ' Self-driving', ' Simulator'] | journal1: SOFT COMPUT | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Al-Turjman, Fadi | inst1: Near East Univ, Res Ctr AI & IoT, Dept Artificial Intelligence Engn, Mersin 10, Nicosia, Turkey | title1: Implementation of autonomous driving using Ensemble-M in simulated environment | site1: WOS
# name2: Al-Turjman, Fadi | inst2: Department of Artificial Intelligence Engineering Research Centre for AI and IoT Near East University Nicosia Mersin 10 Turkey | title2: Implementation of autonomous driving using Ensemble-M in simulated environment | site1: SCOPUS
# inst: 0.6995839271381067 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering'], ['Autonomous driving', ' CNN', ' End-to-end learning', ' LSTM'] | journal1: J SUPERCOMPUT | journal2: Springer
# name1: Ha, Young-guk | inst1: Konkuk Univ, Seoul, South Korea | title1: End-to-end deep learning-based autonomous driving control for high-speed environment | site1: WOS
# name2: Ha, Youngguk | inst2: Konkuk University Seoul South Korea | title2: End-to-end deep learning-based autonomous driving control for high-speed environment | site1: SCOPUS
# inst: 0.8976386461147307 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Engineering', ' Transportation'], ['Artificial intelligence', ' artificial intelligence', ' Autonomous vehicles', ' Collision avoidance', ' Collision avoidance', ' connected autonomous vehicle.', ' edge computing', ' Reliability', ' Sensors', ' Trajectory', ' vehicle-to-everything (V2X)', ' Vehicles'] | journal1: IEEE T INTELL TRANSP | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhang, Yao | inst1: Xidian Univ, Sch Cyber Engn, Xian 710071, Peoples R China | title1: A Survey of Driving Safety With Sensing, Vehicular Communications, and Artificial Intelligence-Based Collision Avoidance | site1: WOS
# name2: Zhang, Yao | inst2: State Key Laboratory of Integrated Services Networks Xidian University Xi'an 710071 China and also with the Research Institute of Smart Transportation Xidian University Xi'an 710071 China. | title2: A Survey of Driving Safety With Sensing, Vehicular Communications, and Artificial Intelligence-Based Collision Avoidance | site1: SCOPUS
# inst: 0.5543834764215503 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 5 | keyword: ['Chemistry', ' Science & Technology - Other Topics', ' Materials Science'], ['artificial intelligence', ' automated experiments', ' autonomous', ' Bayesian optimization', ' Gaussian process regression', ' machine learning', ' reinforcement learning', ' scanning probe microscopy', ' scanning transmission electron microscopy'] | journal1: ACS NANO | journal2: American Chemical Society
# name1: Vasudevan, Rama K. | inst1: Oak Ridge Natl Lab, Computat Sci & Engn Div, Oak Ridge, TN 37831 USA | title1: Automated and Autonomous Experiments in Electron and Scanning Probe Microscopy | site1: WOS
# name2: Vasudevan, Rama K. | inst2: Center for Nanophase Materials Sciences Oak Ridge National Laboratory Oak Ridge TN  37831 United States | title2: Automated and Autonomous Experiments in Electron and Scanning Probe Microscopy | site1: SCOPUS
# inst: 0.6451643338309604 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Health Care Sciences & Services', ' Public, Environmental & Occupational Health'], ['Aftercare', ' Artificial intelligence', ' Cataract', ' Cell phone', ' Chatbot', ' Conversational agent', ' Delivery of health care', ' Dialogue system', ' Expert systems', ' Health communication', ' Health services', ' Internet', ' Medical informatics', ' Mental health', ' Natural language processing', ' Patient acceptance of health care', ' Relational agent', ' Speech recognition software', ' Telemedicine'] | journal1: JMIR RES PROTOC | journal2: JMIR Publications Inc.
# name1: Meinert, Edward | inst1: Univ Oxford, Oxford, England | title1: Safety and Acceptability of a Natural Language Artificial Intelligence Assistant to Deliver Clinical Follow-up to Cataract Surgery Patients: Proposal | site1: WOS
# name2: Meinert, Edward | inst2: Centre for Health Technology University of Plymouth Plymouth United Kingdom Department of Primary Care and Public Health Imperial College London London United Kingdom | title2: Safety and acceptability of a natural language artificial intelligence assistant to deliver clinical follow-up to cataract surgery patients: Proposal | site1: SCOPUS
# inst: 0.48264486517498567 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Engineering', ' Transportation'], ['Artificial intelligence', ' autonomous vehicles', ' connected vehicles', ' electric mobility', ' Europe', ' intelligent transportation systems', ' Internet of Things', ' open data', ' Real-time systems', ' Roads', ' routing vehicle', ' Safety', ' smart mobility.', ' Statistics', ' Urban areas', ' Vehicles'] | journal1: IEEE T INTELL TRANSP | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Sadik, Mohamed | inst1: Wireless VT, Blacksburg, VA 24061 USA | title1: Smart Urban Mobility: When Mobility Systems Meet Smart Data | site1: WOS
# name2: Sadik, Mohamed | inst2: Wireless@VT Blacksburg VA 24061 USA and also with the Department of Electrical and Computer Engineering Virginia Tech Blacksburg VA 24061 USA. | title2: Smart Urban Mobility: When Mobility Systems Meet Smart Data | site1: SCOPUS
# inst: 0.6069987492522704 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Chemistry', ' Materials Science'], [''] | journal1: MATER HORIZ | journal2: Royal Society of Chemistry
# name1: Ceder, Gerbrand | inst1: Lawrence Berkeley Natl Lab, Mat Sci Div, Berkeley, CA 94720 USA | title1: Toward autonomous design and synthesis of novel inorganic materials | site1: WOS
# name2: Ceder, Gerbrand | inst2: Department of Materials Science and Engineering UC Berkeley Berkeley CA  94720 United States Materials Sciences Division Lawrence Berkeley National Laboratory Berkeley CA  94720 United States | title2: Toward autonomous design and synthesis of novel inorganic materials | site1: SCOPUS
# inst: 0.5589674690896332 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Business & Economics'], ['Business process management', ' Data science', ' Hybrid intelligence', ' Machine learning', ' Process science'] | journal1: IJISPM-INT J INF SYS | journal2: SciKA
# name1: van der Aalst, Wil M. P. | inst1: Rhein Westfal TH Aachen, Fraunhofer Inst Angew Informat Tech, Ahornstr 55, D-52074 Aachen, Germany | title1: Hybrid Intelligence: to automate or not to automate, that is the question | site1: WOS
# name2: van der Aalst, Wil M.P. | inst2: RWTH Aachen University Fraunhofer Institut für Angewandte Informationstechnik Ahornstr. 55 Aachen D-52074 Germany | title2: Hybrid intelligence: to automate or not to automate, that is the question | site1: SCOPUS
# inst: 0.7744482571789778 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Engineering', ' Operations Research & Management Science', ' Mathematics'], ['AI assurance', ' deep learning', ' design of experiments', ' distribution shift', ' safety of AI systems'] | journal1: J QUAL TECHNOL | journal2: Taylor and Francis Ltd.
# name1: Deng, Xinwei | inst1: Virginia Tech, Dept Stat, Blacksburg, VA 24061 USA | title1: Robustness with respect to class imbalance in artificial intelligence classification algorithms | site1: WOS
# name2: Deng, Xinwei | inst2: Department of Statistics Virginia Tech Blacksburg VA United States | title2: Robustness with respect to class imbalance in artificial intelligence classification algorithms | site1: SCOPUS
# inst: 0.6673959103227395 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science', ' Telecommunications'], ['Audio video bridge', ' Autonomous', ' AVB', ' In-vehicle network', ' Video streaming'] | journal1: KSII T INTERNET INF | journal2: Korean Society for Internet Information
# name1: Kim, Youngseop | inst1: Dankook Univ, Elect & Elect Engn, 152 Jukjeon Ro, Yongin 16890, Gyeonggi Do, South Korea | title1: Real-time Camera and Video Streaming Through Optimized Settings of Ethernet AVB in Vehicle Network System | site1: WOS
# name2: Kim, Youngseop | inst2: Electronic and Electrical Engineerin Dankook University 152 Jukjeon-ro Suji-gu Gyeonggi-do Yongin-si 16890 South Korea | title2: Real-time camera and video streaming through optimized settings of ethernet AVB in vehicle network system | site1: SCOPUS
# inst: 0.7164990930545532 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Telecommunications', ' Transportation'], ['6G', ' Artificial intelligence (AI)', ' Edge computing', ' Vehicular communications', ' Vehicular network'] | journal1: VEH COMMUN | journal2: Elsevier Inc.
# name1: Zhang, Yanning | inst1: Xidian Univ, Sch Cyber Engn, Xian 710071, Peoples R China | title1: Vehicular intelligence in 6G: Networking, communications, and computing | site1: WOS
# name2: Zhang, Yanning | inst2: National Engineering Laboratory for Integrated Aero-Space-Ground-Ocean Big Data Application Technology School of Cybersecurity Northwestern Polytechnical University Xi'an 710072 China | title2: Vehicular intelligence in 6G: Networking, communications, and computing | site1: SCOPUS
# inst: 0.5014391904057091 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['AI CCTV', ' Autonomous driving', ' Deep learning', ' Real-time notification', ' Secondary accident', ' Traffic congestion'] | journal1: APPL SCI-BASEL | journal2: MDPI
# name1: Doo, Illchul | inst1: Hankuk Univ Foreign Studies, Artificial Intelligence Educ, Yongin 17035, South Korea | title1: A Study on Building a Real-Time Vehicle Accident and Road Obstacle Notification Model Using AI CCTV | site1: WOS
# name2: Doo, Illchul | inst2: Artificial Intelligence Education Hankuk University of Foreign Studies Yongin 17035 South Korea | title2: A study on building a “real-time vehicle accident and road obstacle notification model” using ai cctv | site1: SCOPUS
# inst: 0.782593830254649 | title: 0.994059405940594 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Engineering', ' Transportation'], ['CAV adoption', ' Connected and autonomous vehicles', ' Fuzzy logic', ' Machine learning'] | journal1: IEEE T INTELL TRANSP | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Amin, Saad Ali | inst1: Coventry Univ, Ctr Computat Sci & Math Modelling, Coventry CV1 5FB, W Midlands, England | title1: Predicting the Public Adoption of Connected and Autonomous Vehicles | site1: WOS
# name2: Amin, Saad Ali | inst2: College of Engineering and It University of Dubai Dubai CV1 5FB United Arab Emirates | title2: Predicting the Public Adoption of Connected and Autonomous Vehicles | site1: SCOPUS
# inst: 0.6609555497940253 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Computer Science'], ['asynchronous advantage actor-critic', ' reinforcement learning', ' robustness assessment', ' skewness', ' sparseness'] | journal1: J COMPUT SCI TECH-CH | journal2: Springer
# name1: Li, Gang | inst1: Deakin Univ, Ctr Cyber Secur Res & Innovat, Geelong, Vic 3216, Australia | title1: Robustness Assessment of Asynchronous Advantage Actor-Critic Based on Dynamic Skewness and Sparseness Computation: A Parallel Computing View | site1: WOS
# name2: Li, Gang | inst2: Centre for Cyber Security Research and Innovation Deakin University Geelong VIC  3216 Australia | title2: Robustness Assessment of Asynchronous Advantage Actor-Critic Based on Dynamic Skewness and Sparseness Computation: A Parallel Computing View | site1: SCOPUS
# inst: 0.6979410331384015 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Geography', ' Transportation'], ['Automation', ' Automobility', ' Decisions', ' Intervention', ' Microwork', ' Mundanity', ' Speculation'] | journal1: MOBILITIES-UK | journal2: Routledge
# name1: Hind, Sam | inst1: Univ Siegen, SFB Media Of Cooperat 1187, Siegen, Germany | title1: Making decisions: the normal interventions of Nissan 'mobility managers' | site1: WOS
# name2: Hind, Sam | inst2: SFB 1187 Media of Cooperation University of Siegen Siegen Germany | title2: Making decisions: the normal interventions of Nissan ‘mobility managers | site1: SCOPUS
# inst: 0.7611883214824391 | title: 0.9916275430359938 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Optics'], [''] | journal1: LIGHT-SCI APPL | journal2: Springer Nature
# name1: Zou, Weiwen | inst1: Chinese Acad Sci, Inst Semicond, Beijing 100083, Peoples R China | title1: Optical coherent dot-product chip for sophisticated deep learning regression | site1: WOS
# name2: Zou, Weiwen | inst2: State Key Laboratory of Advanced Optical Communication Systems and Networks Intelligent Microwave Lightwave Integration Innovation Center (imLic) Department of Electronic Engineering Shanghai Jiao Tong University 800 Dongchuan Road Shanghai 200240 China | title2: Optical coherent dot-product chip for sophisticated deep learning regression | site1: SCOPUS
# inst: 0.5027533164122039 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 5 | keyword: ['Computer Science', ' Engineering'], ['3D data', ' Deep learning', ' instance segmentation', ' object detection', ' object tracking', ' part segmentation', ' point clouds', ' scene flow', ' semantic segmentation', ' shape classification', ' shape retrieval'] | journal1: IEEE T PATTERN ANAL | journal2: IEEE Computer Society
# name1: Bennamoun, Mohammed | inst1: Univ Western Australia, Dept Comp Sci & Software Engn, Crawley, WA 6009, Australia | title1: Deep Learning for 3D Point Clouds: A Survey | site1: WOS
# name2: Bennamoun, Mohammed | inst2: Department of Computer Science and Software Engineering University of Western Australia Crawley WA Australia | title2: Deep Learning for 3D Point Clouds: A Survey | site1: SCOPUS
# inst: 0.6582523246459662 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Imaging Science & Photographic Technology'], ['6-DoF relative pose estimation', ' AI-based navigation algorithms', ' Automated data acquisition', ' UAS'] | journal1: J IMAGING | journal2: MDPI
# name1: Perko, Roland | inst1: Infineon Technol Austria AG, A-9500 Villach, Austria | title1: Automated Data Annotation for 6-DoF AI-Based Navigation Algorithm Development | site1: WOS
# name2: Perko, Roland | inst2: JOANNEUM RESEARCH Forschungsgesellschaft mbH DIGITAL Remote Sensing and Geoinformation Graz 8010 Austria | title2: Automated data annotation for 6-dof ai-based navigation algorithm development | site1: SCOPUS
# inst: 0.5495951417004048 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['5G technologies', ' Artificial Intelligence', ' Vehicle to everything'], ['Classification', ' Dynamic graph convolution', ' Point cloud', ' Segmentation', ' Spatial attention(SA)'] | journal1: Springer | journal2: Editorial and Publishing Board of JIG
# name1: Li W. | inst1: Information Technology and Cultural Management Institute Hebei Institute of Communications Shijiazhuang 051430 China | title1: Vehicle Artificial Intelligence System Based on Intelligent Image Analysis and 5G Network | site1: SCOPUS
# name2: Li W. | inst2: Polar Research Institute of China Shanghai 200136 China | title2: Dynamic graph convolution with spatial attention for point cloud classification and segmentation [结合动态图卷积和空间注意力的点云分类与分割 | site1: SCOPUS
# inst: 0.5798153953326367 | title: 0.6392030969691248 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2021 | co_author_count: 3 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science', ' Physics'], ['autonomous discovery', ' batteries', ' explainable AI', ' interface dynamics', ' multi-sourced multi-scaling'] | journal1: ADV ENERGY MATER | journal2: John Wiley and Sons Inc
# name1: Vegge, Tejs | inst1: Helmholtz Inst UIm, Helmholtzstr 11, D-89081 Ulm, Germany | title1: Implications of the BATTERY 2030+AI-Assisted Toolkit on Future Low-TRL Battery Discoveries and Chemistries | site1: WOS
# name2: Vegge, Tejs | inst2: Department of Energy Conversion and Storage Anker Engelunds Vej Building 301 Kgs Lyngby DK-2800 Denmark Alistore ERI Amiens France | title2: Implications of the BATTERY 2030+ AI-Assisted Toolkit on Future Low-TRL Battery Discoveries and Chemistries | site1: SCOPUS
# inst: 0.4594160225739173 | title: 0.9434138599894198 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Government & Law'], [''] | journal1: WASH LAW REV | journal2: University of Washington School of Law
# name1: Reyes, Carla L. | inst1: Southern Methodist Univ, Dedman Sch Law, Law, Dallas, TX 75275 USA | title1: Autonomous Corporate Personhood | site1: WOS
# name2: Reyes, Carla L. | inst2: Southern Methodist University Dedman School of Law United States Indiana University Bloomington United States | title2: AUTONOMOUS CORPORATE PERSONHOOD | site1: SCOPUS
# inst: 0.6619050733999466 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['AI', ' API development', ' Autonomous vehicles', ' Cloud computing', ' Cloud storage performance', ' Cyber-physical systems', ' Machine learning', ' Multi-cloud', ' Neural networks', ' Resource management', ' Self-driving cars'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Miclea, Liviu-Cristian | inst1: Tech Univ Cluj Napoca, Fac Automat & Comp Sci, Dept Automat, 28 Memorandumului St, Cluj Napoca 400114, Romania | title1: Multi-Cloud Resource Management Techniques for Cyber-Physical Systems | site1: WOS
# name2: Míclea, Liviu Cristian | inst2: Department of Automation Faculty of Automation and Computer Science Technical University Cluj-Napoca 28 Memorandumului Street Cluj-Napoca 400114 Romania | title2: Multi-cloud resource management techniques for cyber-physical systems | site1: SCOPUS
# inst: 0.7157816555649372 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Robotics'], ['AI-Based methods', ' computer vision for transportation', ' human trajectory prediction', ' intelligent transportation systems', ' normalizing flows'] | journal1: IEEE ROBOT AUTOM LET | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Lu, Cewu | inst1: Shanghai Jiao Tong Univ, Dept Comp Sci & Engn, Shanghai 201100, Peoples R China | title1: Unified and Fast Human Trajectory Prediction Via Conditionally Parameterized Normalizing Flow | site1: WOS
# name2: Lu, Cewu | inst2: Department of Computer Science and Engineering Shanghai Jiao Tong University Shanghai China | title2: Unified and Fast Human Trajectory Prediction Via Conditionally Parameterized Normalizing Flow | site1: SCOPUS
# inst: 0.6353408703910667 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Artificial intelligence', ' Artificial intelligence', ' computer vision', ' machine learning', ' Maintenance engineering', ' predictive maintenance.', ' Rail transportation', ' Rails', ' railway transport', ' Safety', ' Software', ' Taxonomy', ' traffic management'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Vittorini, Valeria | inst1: Univ Napoli Federico II, Dept Elect Engn & Informat Technol, I-80125 Naples, Italy | title1: Software Verification and Validation of Safe Autonomous Cars: A Systematic Literature Review | site1: WOS
# name2: Vittorini, Valeria | inst2: Department of Electrical Engineering and Information Technology University of Naples Federico II 80125 Naples Italy. | title2: Artificial Intelligence in Railway Transport: Taxonomy, Regulations and Applications | site1: SCOPUS
# inst: 0.6940239229978507 | title: 0.6879038835560575 | email: 0, funding: 0
# weigth: 1.4827269460809456
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Mathematical & Computational Biology', ' Neurosciences & Neurology'], [''] | journal1: COMPUT INTEL NEUROSC | journal2: Hindawi Limited
# name1: Yu, Naigong | inst1: Beijing Univ Technol, Fac Informat Technol, Beijing, Peoples R China | title1: End-to-End Autonomous Exploration with Deep Reinforcement Learning and Intrinsic Motivation | site1: WOS
# name2: Yu, Naigong | inst2: Faculty of Information Technology Beijing University of Technology Beijing China Beijing Key Laboratory of Computational Intelligence and Intelligent System Beijing China | title2: End-to-End Autonomous Exploration with Deep Reinforcement Learning and Intrinsic Motivation | site1: SCOPUS
# inst: 0.6122471210706505 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ...
# name1: Antunes, Miguel | inst1: Univ Alcala UAH, Dept Elect, Madrid, Spain | title1: 360 degrees real-time and power-efficient 3D DAMOT for autonomous driving applications | site1: WOS
# name2: Antunes, Miguel | inst2: Department of Electronics University of Alcalá (UAH) Madrid Spain | title2: 360 ∘ real-time and power-efficient 3D DAMOT for autonomous driving applications | site1: SCOPUS
# inst: 0.6206708324355383 | title: 0.8547774997546855 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['AI', ' Autonomous driving', ' C-V2X', ' OBU', ' PC5', ' RSU', ' VRUCW'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Hua, Kai-Lung | inst1: Natl Taiwan Univ Sci & Technol, Dept Ind Management, Taipei 106, Taiwan | title1: How Does C-V2X Help Autonomous Driving to Avoid Accidents? | site1: WOS
# name2: Hua, Kailung | inst2: Department of Computer Science and Information Engineering National Taiwan University of Science and Technology Taipei 106 Taiwan | title2: How Does C-V2X Help Autonomous Driving to Avoid Accidents | site1: SCOPUS
# inst: 0.649041536037933 | title: 0.9959770114942529 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Geology'], ['AI component', ' data metamodeling', ' domain knowledge', ' LSTM', ' spatio-temporal trajectory data', ' vehicle behavior prediction'] | journal1: FRONT EARTH SCI-PRC | journal2: Higher Education Press Limited Company
# name1: Du, Dehui | inst1: East China Normal Univ, Sch Software & Engn, Shanghai 200062, Peoples R China | title1: A novel spatio-temporal trajectory data-driven development approach for autonomous vehicles | site1: WOS
# name2: Du, Dehui | inst2: School of Software and Engineering East China Normal University Shanghai 200062 China Shanghai Key Laboratory of Trustworthy Computing East China Normal University Shanghai 200062 China MOE International Joint Lab of Trustworthy Software East China Normal University Shanghai 200062 China | title2: A novel spatio-temporal trajectory data-driven development approach for autonomous vehicles | site1: SCOPUS
# inst: 0.5632441534730267 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Autonomous vessels', ' Horizon targeted loss', ' Style transfer'] | journal1: APPL SCI-BASEL | journal2: MDPI
# name1: Cho, Kyungeun | inst1: Dongguk Univ, Dept Multimedia Engn, 30 Pildong Ro 1 Gil, Seoul 04620, South Korea | title1: Horizon Targeted Loss-Based Diverse Realistic Marine Image Generation Method Using a Multimodal Style Transfer Network for Training Autonomous Vessels | site1: WOS
# name2: Cho, Kyungeun | inst2: Department of Multimedia Engineering Dongguk University-Seoul 30 Pildong-ro 1-gil Jung-gu Seoul 04620 South Korea | title2: Horizon Targeted Loss-Based Diverse Realistic Marine Image Generation Method Using a Multimodal Style Transfer Network for Training Autonomous Vessels | site1: SCOPUS
# inst: 0.7328928220255655 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Blind spot', ' Data logging', ' Gesture recognition algorithm', ' micro e-mobility vehicle (MEV)'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Lee, Kyujin | inst1: Semyung Univ, Dept Elect Engn, 65 Semyung Ro, Jecheon Si 27136, Chungcheongbuk, South Korea | title1: Multi-Sensor-Based Blind-Spot Reduction Technology and a Data-Logging Method Using a Gesture Recognition Algorithm Based on Micro E-Mobility in an IoT Environment | site1: WOS
# name2: Lee, Kyujin | inst2: Department of Electronic Engineering Semyung University 65 Semyung-ro Chungcheongbuk-do Jecheon-si 27136 South Korea | title2: Multi-Sensor-Based Blind-Spot Reduction Technology and a Data-Logging Method Using a Gesture Recognition Algorithm Based on Micro E-Mobility in an IoT Environment | site1: SCOPUS
# inst: 0.7152258142079496 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Robotics'], ['AI-based methods', ' autonomous agents', ' continual learning'] | journal1: IEEE ROBOT AUTOM LET | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Choromanska, Anna | inst1: NYU, Dept Elect & Comp Engn, Learning Syst Lab, 5 MetroTech Ctr, Brooklyn, NY 11201 USA | title1: DNN Patching: Progressive Fixing and Augmenting the Functionalities of DNNs for Autonomous Vehicles | site1: WOS
# name2: Choromanska, Anna | inst2: Learning Systems Laboratory Department of Electrical and Computer Engineering New York University 5 MetroTech Center Brooklyn NY  11201 United States | title2: DNN Patching: Progressive Fixing and Augmenting the Functionalities of DNNs for Autonomous Vehicles | site1: SCOPUS
# inst: 0.6404388380782734 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Engineering', ' Transportation'], [''] | journal1: TRANSPORT RES REC | journal2: SAGE Publications Ltd
# name1: Peeta, Srinivas | inst1: Georgia Inst Technol, Sch Civil & Environm Engn, Atlanta, GA 30332 USA | title1: Review of Learning-Based Longitudinal Motion Planning for Autonomous Vehicles: Research Gaps Between Self-Driving and Traffic Congestion | site1: WOS
# name2: Peeta, Srinivas | inst2: School of Civil and Environmental Engineering Georgia Institue of Technology Atlanta GA United States | title2: Review of Learning-Based Longitudinal Motion Planning for Autonomous Vehicles: Research Gaps Between Self-Driving and Traffic Congestion | site1: SCOPUS
# inst: 0.6677622483798017 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Imaging Science & Photographic Technology'], ['Convolutional neural network', ' Explainable AI', ' Network compression'] | journal1: J IMAGING | journal2: MDPI
# name1: Ozols, Kaspars | inst1: Inst Elect & Comp Sci, Dzerbenes Str 14, LV-1006 Riga, Latvia | title1: Improving Performance of the PRYSTINE Traffic Sign Classification by Using a Perturbation-Based Explainability Approach | site1: WOS
# name2: Ozols, Kaspars | inst2: Institute of Electronics and Computer Science Dzerbenes Str.14 Riga LV-1006 Latvia | title2: Improving Performance of the PRYSTINE Traffic Sign Classification by Using a Perturbation-Based Explainability Approach | site1: SCOPUS
# inst: 0.8416991098297524 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Engineering'], ['CEEMDAN', ' Eye blink detection', ' Millimeter wave radar', ' STFT', ' SVD'] | journal1: EURASIP J ADV SIG PR | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Tian, Zengshan | inst1: Chongqing Univ Posts & Telecommun, Sch Commun & Informat Engn, Chongqing, Peoples R China | title1: An improved denoising method for eye blink detection using automotive millimeter wave radar | site1: WOS
# name2: Tian, Zengshan | inst2: School of Communication and Information Engineering Chongqing University of Posts and Telecommunications Chongqing China | title2: An improved denoising method for eye blink detection using automotive millimeter wave radar | site1: SCOPUS
# inst: 0.6968476903870161 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Engineering', ' Transportation'], ['autonomous vehicle', ' dynamic spatial attention', ' Dynamic temporal attention', ' human-inspired AI.', ' model fusion'] | journal1: IEEE T INTELL TRANSP | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Yin, Zhaozheng | inst1: SUNY Stony Brook, Dept Biomed Informat, Dept Comp Sci, Stony Brook, NY 11794 USA | title1: A Dynamic Spatial-Temporal Attention Network for Early Anticipation of Traffic Accidents | site1: WOS
# name2: Yin, Zhaozheng | inst2: Department of Biomedical Informatics the Department of Computer Science and the AI Institute Stony Brook University Stony Brook NY 11794 USA. | title2: A Dynamic Spatial-Temporal Attention Network for Early Anticipation of Traffic Accidents | site1: SCOPUS
# inst: 0.6341954466029397 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['artificial intelligence', ' autonomous systems', ' Behavioral cloning', ' end-to-end learning', ' intelligent systems', ' machine learning', ' neural networks', ' vehicle control'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Nam, Haewoon | inst1: Hanyang Univ, Div Elect Engn, Ansan 15588, South Korea | title1: Incremental End-to-End Learning for Lateral Control in Autonomous Driving | site1: WOS
# name2: Nam, Haewoon | inst2: Division of Electrical Engineering Hanyang University Ansan 15588 South Korea | title2: Incremental End-to-End Learning for Lateral Control in Autonomous Driving | site1: SCOPUS
# inst: 0.7251365192541662 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Behavioral Sciences', ' Engineering', ' Psychology'], ['autonomous driving', ' healthcare', ' human factors', ' robotics', ' technology adoption'] | journal1: HUM FACTORS | journal2: SAGE Publications Inc.
# name1: Kim, Sang-Ho | inst1: Kumoh Natl Inst Technol, Dept Ind Engn, 61 Daehak Ro, Gumi 39177, Gyeongbuk, South Korea | title1: Review of the Factors Affecting Acceptance of AI-Infused Systems | site1: WOS
# name2: Kim, Sang-ho | inst2: Department of Industrial Engineering Kumoh National Institute of Technology South Korea | title2: Review of the Factors Affecting Acceptance of AI-Infused Systems | site1: SCOPUS
# inst: 0.649815732407501 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Physics'], ['adversarial defense', ' adversarial example', ' black-box attack', ' deep neural network', ' smart city', ' white-box attack'] | journal1: ELECTRONICS-SWITZ | journal2: MDPI
# name1: Li, Hao | inst1: Sci & Technol Commun Networks Lab, Shijiazhuang 050081, Hebei, Peoples R China | title1: Adversarial Attack and Defense: A Survey | site1: WOS
# name2: Li, Hao | inst2: Science and Technology on Communication Networks Laboratory Shijiazhuang 050081 China | title2: Adversarial Attack and Defense: A Survey | site1: SCOPUS
# inst: 0.6962665628699783 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Mathematics'], ['disengagement events', ' fractional random weight bootstrap', ' Gompertz model', ' monotonic splines', ' self-driving cars', ' software reliability'] | journal1: J R STAT SOC C-APPL | journal2: John Wiley and Sons Inc
# name1: Meeker, William Q. | inst1: Iowa State Univ, Dept Stat, Ames, IA USA | title1: Reliability analysis of artificial intelligence systems using recurrent events data from autonomous vehicles | site1: WOS
# name2: Meeker, William Q. | inst2: Department of Statistics Iowa State University Ames IA United States | title2: Reliability analysis of artificial intelligence systems using recurrent events data from autonomous vehicles | site1: SCOPUS
# inst: 0.6616557734204793 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science'], ['ADAS', ' Autonomous vehicles', ' Operating conditions', ' Regulation', ' Standards', ' Transparency'] | journal1: AI SOC | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Zeleznikow, John | inst1: La Trobe Univ, Melbourne, Vic, Australia | title1: The importance of transparency in naming conventions, designs, and operations of safety features: from modern ADAS to fully autonomous driving functions | site1: WOS
# name2: Zeleznikow, John | inst2: La Trobe University Melbourne Australia | title2: The importance of transparency in naming conventions, designs, and operations of safety features: from modern ADAS to fully autonomous driving functions | site1: SCOPUS
# inst: 0.8630668677727502 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Engineering', ' Instruments & Instrumentation'], [''] | journal1: J SENSORS | journal2: Hindawi Limited
# name1: Qureshi, Muhammad Aasim | inst1: Bahria Univ, Dept Comp Sci, Lahore Campus, Lahore 54000, Pakistan | title1: Intelligence of Autonomous Vehicles: A Concise Revisit | site1: WOS
# name2: Qureshi, Muhammad Aasim | inst2: Department Of Computer Sciences Bahria University Lahore Campus Lahore 54000 Pakistan | title2: Intelligence of Autonomous Vehicles: A Concise Revisit | site1: SCOPUS
# inst: 0.7323640679474815 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['otaeguioihana_1', 'otaeguioihana_2', 'khanshahzad_1', 'naseeraisha_1', 'khanwasiq_1', 'chengwenhuang_1', 'tanwarsudeep_1', 'parkkangryoung_1', 'lili_1', 'merzoukirochdi_1', 'huangkaibin_1', 'shimdavidhyunchul_1', 'shirongye_1', 'maynardkasia_1', 'klumppmatthias_1', 'wangfan_1', 'abdelgawadhossam_1', 'mahmoodarif_1', 'sunyongbin_1', 'lijonathan_1', 'paugiovanni_1', 'shifeifei_1', 'kitanohiroaki_1', 'zhangjuan_1', 'alturjmanfadi_1', 'hayoungguk_1', 'zhangyao_1', 'vasudevanramak_1', 'meinertedward_1', 'sadikmohamed_1', 'cedergerbrand_1', 'vanderaalstwilmp_1', 'dengxinwei_1', 'kimyoungseop_1', 'zhangyanning_1', 'dooillchul_1', 'aminsaadali_1', 'ligang_1', 'hindsam_1', 'zouweiwen_1', 'bennamounmohammed_1', 'perkoroland_1', 'veggetejs_1', 'reyescarlal_1', 'miclealiviucristian_1', 'lucewu_1', 'yunaigong_1', 'yangqiang_1', 'antunesmiguel_1', 'huakailung_1', 'dudehui_1', 'chokyungeun_1', 'leekyujin_1', 'choromanskaanna_1', 'peetasrinivas_1', 'ozolskaspars_1', 'tianzengshan_1', 'yinzhaozheng_1', 'namhaewoon_1', 'kimsangho_1', 'lihao_1', 'meekerwilliamq_1', 'zeleznikowjohn_1', 'qureshimuhammadaasim_1']

# %%
deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        
        if name_sim >= 0.82 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                print(name_sim)
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
                    flag = True
                    break
            if flag :
                break
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# 0.9230769230769231
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Information Science & Library Science', ' Social Sciences - Other Topics'], ['AI ethics', ' autonomous vehicle', ' Moral Machine', ' self-driving car', ' trolley problem'] | journal1: SOC SCI COMPUT REV | journal2: SAGE Publications Inc.
# name1: Etienne, Hubert | inst1: Ecole Normale Super, 45 Rue Ulm, F-75005 Paris, France | title1: When AI Ethics Goes Astray: A Case Study of Autonomous Vehicles | site1: WOS
# name2: Etienne H. | inst2: Ecole Normale Supérieure Paris France | title2: When AI Ethics Goes Astray: A Case Study of Autonomous Vehicles | site1: SCOPUS
# inst: 0.8861802979450039 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8727272727272728
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science'], ['Convolutional neural network', ' Deep learning', ' GTSRB', ' Traffic sign recognition'] | journal1: INT J MACH LEARN CYB | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Yao, Hongyang | inst1: Shanghai Univ, Sch Comp Engn & Sci, Shanghai 200444, Peoples R China | title1: Improved VGG model-based efficient traffic sign recognition for safe driving in 5G scenarios | site1: WOS
# name2: Yao H. | inst2: College of Computer Science and Technology Shanghai University of Electric Power Shanghai 200090 China | title2: Improved VGG model-based efficient traffic sign recognition for safe driving in 5G scenarios | site1: SCOPUS
# inst: 0.6577642551273383 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9333333333333333
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['explainable AI', ' explainable recommender systems', ' interpretable machine learning', ' neural-symbolic reasoning'], ['Computer Science'] | journal1: Wiley-Blackwell | journal2: WIRES DATA MIN KNOWL
# name1: Besold, Tarek Richard | inst1: Neurocat GmbH Berlin Germany | title1: A historical perspective of explainable Artificial Intelligence | site1: SCOPUS
# name2: Besold, Tarek R. | inst2: Neurocat GmbH, Berlin, Germany | title2: A historical perspective of explainable Artificial Intelligence | site1: WOS
# inst: 0.9866666666666667 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9333333333333333
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: [''], ['Science & Technology - Other Topics'] | journal1: Nature Research | journal2: NATURE
# name1: Bhaskaran, Harish | inst1: Department of Materials University of Oxford Oxford United Kingdom | title1: Parallel convolutional processing using an integrated photonic tensor core | site1: SCOPUS
# name2: Bhaskaran, H. | inst2: Univ Exeter, Dept Engn, Exeter, Devon, England | title2: Parallel convolutional processing using an integrated photonic tensor core | site1: WOS
# inst: 0.574751724821851 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9555555555555556
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Convolutional neural nets', ' Explainable AI', ' Image classification', ' Semantic segmentation'] | journal1: APPL SCI-BASEL | journal2: MDPI AG
# name1: Dahmen, Tim | inst1: German Res Ctr Artificial Intelligence, D-66123 Saarbrucken, Germany | title1: Neuroscope: An Explainable AI Toolbox for Semantic Segmentation and Image Classification of Convolutional Neural Nets | site1: WOS
# name2: Dahmen T. | inst2: German Research Centre for Artificial Intelligence Saarbrucken 66123 Germany | title2: Neuroscope: An explainable ai toolbox for semantic segmentation and image classification of convolutional neural nets | site1: SCOPUS
# inst: 0.8785313467492261 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8448148148148149
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science'], [''] | journal1: J SYST SOFTWARE | journal2: USENIX Association
# name1: Lee, Seok-Won | inst1: Ajou Univ, Dept Artificial Intelligence, Suwon 16499, South Korea | title1: Multilayered review of safety approaches for machine learning-based systems in the days of AI | site1: WOS
# name2: Lee, Jaewoo | inst2: Seoul National University South Korea | title2: FlashNeuron: SSD-Enabled large-Batch training of very deep neural networks | site1: SCOPUS
# inst: 0.6210493371783694 | title: 0.673740636458775 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9874999999999999
# joc: 0 | yop: 2021, 2021 | co_author_count: 6 | keyword: ['Autonomous vehicle', ' camera', ' dataset', ' GPS', ' IMU', ' lidar', ' winter weather'], ['Robotics'] | journal1: SAGE Publications Inc. | journal2: INT J ROBOT RES
# name1: Waslander, Steven L. | inst1: Institute for Aerospace Studies University of Toronto Canada | title1: Canadian Adverse Driving Conditions dataset | site1: SCOPUS
# name2: Waslander, Steven | inst2: Univ Waterloo, Waterloo, ON, Canada | title2: Canadian Adverse Driving Conditions dataset | site1: WOS
# inst: 0.5497239475500345 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Transportation'], ['Autonomous vehicles', ' Path planning', ' Vehicle characteristic'] | journal1: SAE INT J COMMER VEH | journal2: SAE International
# name1: Yan, Weiqi | inst1: Auckland Univ Technol, Auckland, New Zealand | title1: A Survey of Path Planning Algorithms for Autonomous Vehicles | site1: WOS
# name2: Yan W. | inst2: Auckland University of Technology New Zealand | title2: A Survey of Path Planning Algorithms for Autonomous Vehicles | site1: SCOPUS
# inst: 0.8468330362448009 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8575757575757577
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Computer Science'], ['Artificial Intelligence', ' Autonomous Vehicles', ' Connected Vehicles', ' Supply Chain'] | journal1: EXPERT SYST | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Gupta, Rajesh | inst1: Nirma Univ, Inst Technol, Dept Comp Sci & Engn, Ahmadabad 382481, Gujarat, India | title1: Anomaly detection in autonomous electric vehicles using AI techniques: A comprehensive survey | site1: WOS
# name2: Gupta K. | inst2: Striim Inc. | title2: The Evolution of Artificial Intelligence in the Automotive Industry | site1: SCOPUS
# inst: 0.5113636363636364 | title: 0.6857928328106143 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9400000000000001
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Psychology'], ['Human-agent interaction', ' Human-autonomy teaming', ' Implicit coordination', ' Team cognition', ' Teamwork'] | journal1: COMPUT HUM BEHAV | journal2: Elsevier Ltd
# name1: Henke, Jonn B. | inst1: Univ Calgary, Dept Psychol, 2500 Univ Dr NW, Calgary, AB T2N 1N4, Canada | title1: What Happens When Humans Believe Their Teammate is an AI? An Investigation into Humans Teaming with Autonomy | site1: WOS
# name2: Henke J.B. | inst2: University of Calgary Department of Psychology 2500 University Dr NW Calgary AB  T2N 1N4 Canada | title2: What Happens When Humans Believe Their Teammate is an AI? An Investigation into Humans Teaming with Autonomy | site1: SCOPUS
# inst: 0.8376115038840883 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Engineering'], ['cybersecurity', ' Higher-order Local Auto Correlation (HLAC)', ' IoT edge computing', ' malware', ' pattern match accelerator', ' texture image'] | journal1: ELECTR ENG JPN | journal2: John Wiley and Sons Inc
# name1: Hosono, Hiroyuki | inst1: Nihon Univ, Coll Sci & Technol, Funabashi, Chiba, Japan | title1: Study on cyber-security for IoT edge utilizing pattern match accelerator | site1: WOS
# name2: Hosono H. | inst2: College of Science and Technology Nihon University Funabashi Chiba Japan | title2: Study on cyber-security for IoT edge utilizing pattern match accelerator | site1: SCOPUS
# inst: 0.7211784511784511 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9714285714285714
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['artificial intelligence', ' Autonomous driving (AD)', ' decision making', ' deep learning (DL)', ' intelligent sensors', ' vehicular safety', ' vehicular technology'], ['Engineering', ' Transportation'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: IEEE T INTELL TRANSP
# name1: de Albuquerque, Victor Hugo Costa | inst1: LAPISCO Federal Institute of Education Science and Technology of Ceará Fortaleza/CE Brazil ARMTEC Tecnologia em Robótica Fortaleza/CE 60811-341 Brazil | title1: Deep Learning for Safe Autonomous Driving: Current Challenges and Future Directions | site1: SCOPUS
# name2: de Albuquerque, Victor Hugo C. | inst2: Fed Inst Educ Sci & Technol Ceara, LAPISCO, BR-60040215 Fortaleza, CE, Brazil | title2: Deep Learning for Safe Autonomous Driving: Current Challenges and Future Directions | site1: WOS
# inst: 0.5926214526214526 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9142857142857143
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science'], ['Answer set programming', ' Autonomous driving', ' Cognitive vision', ' Commonsense reasoning', ' Declarative spatial reasoning', ' Deep semantics', ' Human-centred computing and design', ' Knowledge representation and reasoning', ' Spatial cognition and AI', ' Standardisation in driving technology', ' Visual abduction'] | journal1: ARTIF INTELL | journal2: Elsevier B.V.
# name1: Varadarajan, Srikrishna | inst1: Cognit Vis, CoDesign Lab EU, Stockholm, Sweden | title1: Commonsense visual sensemaking for autonomous driving-On generalised neurosymbolic online abduction integrating vision and semantics | site1: WOS
# name2: Varadarajan S. | inst2: CoDesign Lab (EU) Cognitive Vision Sweden | title2: Commonsense visual sensemaking for autonomous driving – On generalised neurosymbolic online abduction integrating vision and semantics | site1: SCOPUS
# inst: 0.7672592685006134 | title: 0.943625557155237 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9166666666666667
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], [''] | journal1: IEEE NETWORK | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Guizan, Mohsen | inst1: Qatar Univ, Dept Comp Sci & Engn, Doha, Qatar | title1: AI-Enabled Object Detection in UAVs: Challenges, Design Choices, and Research Directions | site1: WOS
# name2: Guizan M. | inst2: Qatar University Qatar | title2: AI-Enabled Object Detection in UAVs: Challenges, Design Choices, and Research Directions | site1: SCOPUS
# inst: 0.6734427609427609 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9090909090909091
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Automated driving', ' Autonomous racing vehicle', ' Control', ' Model predictive control', ' Perception', ' Processor-in-the-loop', ' RRT algorithm', ' Trajectory planning'] | journal1: APPL SCI-BASEL | journal2: MDPI AG
# name1: Amati, Nicola | inst1: Politecn Torino, Dept Mech & Aerosp Engn, I-10129 Turin, Italy | title1: Processor-in-the-Loop Architecture Design and Experimental Validation for an Autonomous Racing Vehicle | site1: WOS
# name2: Amati, N. | inst2: Department of Mechanical and Aerospace Engineering Politecnico di Torino Torino 10129 Italy | title2: Processor-in-the-loop architecture design and experimental validation for an autonomous racing vehicle | site1: SCOPUS
# inst: 0.6614753678052522 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9857142857142858
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['5G', ' 6G', ' AI', ' Blockchain', ' Internet of Things', ' volunteer computing'], ['Computer Science'] | journal1: Association for Computing Machinery | journal2: ACM T INTERNET TECHN
# name1: Jararweh, Yaser I. | inst1: Jordan University of Science and Technology Jordan | title1: An Incentive-based Mechanism for Volunteer Computing Using Blockchain | site1: SCOPUS
# name2: Jararweh, Yaser | inst2: Jordan Univ Sci & Technol, Dept Comp Sci, Irbid, Jordan | title2: An Incentive-based Mechanism for Volunteer Computing Using Blockchain | site1: WOS
# inst: 0.832287081339713 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.96
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Information Science & Library Science'], ['Ai ethics', ' Artificial intelligence', ' Autonomous weapons systems', ' Just war theory', ' Military ethics', ' Self-driving cars'] | journal1: INF TARSAD | journal2: Infonia
# name1: Dombrovszki, Aron | inst1: Eatvos Lorand Univ ELTE, Budapest, Hungary | title1: The Unfounded Bias Against Autonomous Weapons Systems | site1: WOS
# name2: Dombrovszki A. | inst2: Eötvös Loránd University (ELTE) Mta Lendület Values and Science Research Group Hungary | title2: The Unfounded Bias against Autonomous Weapons Systems | site1: SCOPUS
# inst: 0.5943890734588408 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9555555555555556
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Business & Economics', ' Public Administration'], ['Artificial intelligence', ' Autonomy', ' Culture', ' Personality', ' Self-concept', ' Technology'] | journal1: TECHNOL FORECAST SOC | journal2: Elsevier Inc.
# name1: Schvaneveldt, Shane J. | inst1: Weber State Univ, Goddard Sch Business & Econ, 1337 Edvalson St Dept 3805, Ogden, UT 84408 USA | title1: The AI-extended consumer: Technology, consumer, country differences in the formation of demand for AI-empowered consumer products | site1: WOS
# name2: Schvaneveldt S.J. | inst2: Goddard School of Business and Economics Weber State University 1337 Edvalson St Dept 3805 Ogden UT  84408-3805 United States | title2: The AI-extended consumer: Technology, consumer, country differences in the formation of demand for AI-empowered consumer products | site1: SCOPUS
# inst: 0.7323294648613797 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9111111111111111
# joc: 0 | yop: 2022, 2022 | co_author_count: 3 | keyword: ['Automation industry', ' Autonomous electric vehicle', ' Connected vehicles', ' Seep learning', ' Traffic flow predictive'], ['Computer Science', ' Materials Science'] | journal1: Tech Science Press | journal2: CMC-COMPUT MATER CON
# name1: Pustokhin, Denis Alexandrovich | inst1: Department of Logistics State University of Management Moscow 109542 Russian Federation | title1: AI based traffic flow prediction model for connected and autonomous electric vehicles | site1: SCOPUS
# name2: Pustokhin, Denis A. | inst2: State Univ Management, Dept Logist, Moscow 109542, Russia | title2: AI Based Traffic Flow Prediction Model for Connected and Autonomous Electric Vehicles | site1: WOS
# inst: 0.7078712105935336 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.925
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Transportation'], ['AI safety test', ' deep neural network (DNN)', ' end-to-end model', ' Intelligent vehicles', ' multimodality fusion', ' object detection'] | journal1: IEEE T INTELL VEHICL | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Meng, Qian | inst1: Univ OsloMet, Inst Informat Technol, N-0167 Oslo, Norway | title1: A Multimodality Fusion Deep Neural Network and Safety Test Strategy for Intelligent Vehicles | site1: WOS
# name2: Meng Q. | inst2: Institute of Information Technology University OsloMet Oslo 0167 Norway | title2: A Multimodality Fusion Deep Neural Network and Safety Test Strategy for Intelligent Vehicles | site1: SCOPUS
# inst: 0.677724146296217 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.853968253968254
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Transportation'], ['Engineering', ' Oceanography'] | journal1: IEEE T INTELL VEHICL | journal2: J MAR SCI ENG
# name1: Wang, Fan | inst1: Seres Inc, Santa Clara, CA 95054 USA | title1: SUPER: A Novel Lane Detection System | site1: WOS
# name2: Wang, Jin | inst2: Liverpool John Moores Univ, Sch Engn, Liverpool L3 3AF, Merseyside, England | title2: A Novel Ship Collision Avoidance Awareness Approach for Cooperating Ships Using Multi-Agent Deep Reinforcement Learning | site1: WOS
# inst: 0.47407407407407404 | title: 0.5899117222646635 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8833333333333334
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['artificial intelligence', ' Autonomous driving', ' high-precision map', ' neural network', ' unmanned system'] | journal1: J INTELL FUZZY SYST | journal2: IOS Press BV
# name1: Bian, Xueliang | inst1: Hebei Univ Technol, Sch Mech Engn, Tianjin, Peoples R China | title1: Autonomous driving of vehicles based on artificial intelligence | site1: WOS
# name2: Bian X. | inst2: School of Mechanical Engineering Hebei University of Technology Tianjin China | title2: Autonomous driving of vehicles based on artificial intelligence | site1: SCOPUS
# inst: 0.7047909717401243 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9111111111111111
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science'], ['Agent', ' Autonomous driving', ' Cloud', ' Edge', ' Fog', ' Simulation'] | journal1: CLUSTER COMPUT | journal2: Springer
# name1: Niar, Smail | inst1: Univ Polytech Hauts de France, UMR 8201, CNRS, LAMIH, F-59313 Valenciennes, France | title1: Simulating multi-agent-based computation offloading for autonomous cars | site1: WOS
# name2: Niar S. | inst2: University Polytechnique Hauts-de-France LAMIH CNRS UMR 8201 Valenciennes F-59313 France INSA Hauts-de-France Valenciennes F-59313 France | title2: Simulating multi-agent-based computation offloading for autonomous cars | site1: SCOPUS
# inst: 0.6865032481019663 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9230769230769231
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Engineering', ' Business & Economics', ' Operations Research & Management Science'], ['Artificial intelligence', ' Hedonism', ' Privacy concerns', ' Self-driving cars', ' Social recognition', ' Technology acceptance model', ' Technology trust', ' User well-being'] | journal1: TECHNOVATION | journal2: Elsevier Ltd
# name1: Cloarec, Julien | inst1: Univ Jean Moulin Lyon 3, Iaelyon Sch Management, Lyon, France | title1: Baby, you can drive my car: Psychological antecedents that drive consumers' adoption of AI-powered autonomous vehicles | site1: WOS
# name2: Cloarec J. | inst2: iaelyon School of Management Université Jean Moulin Lyon 3 Magellan Lyon France | title2: “Baby, you can drive my car”: Psychological antecedents that drive consumers’ adoption of AI-powered autonomous vehicles | site1: SCOPUS
# inst: 0.7391162418739663 | title: 0.9888418079096045 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8222222222222222
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Robotics'], [''] | journal1: IEEE ROBOT AUTOM LET | journal2: USENIX Association
# name1: Lee, Jin Han | inst1: Hanyang Univ, CLE Inc, Seoul 04763, South Korea | title1: Goal- Driven Autonomous Exploration Through Deep Reinforcement Learning | site1: WOS
# name2: Lee, Jaewoo | inst2: Seoul National University South Korea | title2: FlashNeuron: SSD-Enabled large-Batch training of very deep neural networks | site1: SCOPUS
# inst: 0.6158635230975656 | title: 0.6937344789457466 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8290909090909091
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Computer Science'], ['Computer Science'] | journal1: ACM T INTEL SYST TEC | journal2: SOFTW SYST MODEL
# name1: Yang, Qiang | inst1: China UnionPay, Shanghai, Peoples R China | title1: StarFL: Hybrid Federated Learning Architecture for Smart Urban Computing | site1: WOS
# name2: Yang, Shufan | inst2: Edinburgh Napier Univ, Sch Comp, Edinburgh, Midlothian, Scotland | title2: Event-driven temporal models for explanations-ETeMoX: explaining reinforcement learning | site1: WOS
# inst: 0.6070392407553108 | title: 0.6371147497530062 | email: 0, funding: 0
# weigth: 1.5321205588285576
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8435314685314685
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Computer Science'], ['Computer Science', ' Engineering', ' Telecommunications'] | journal1: IEEE TETCI | journal2: IEEE ACCESS
# name1: Khan, Shahzad | inst1: Gnowit Inc, 200-308 Legett Dr, Kanata, ON, Canada | title1: Machine Learning-Backed Planning of Rapid COVID-19 Tests With Autonomous Vehicles With Zero-Day Considerations | site1: WOS
# name2: Khan, Wasiq | inst2: Liverpool John Moores Univ, Fac Engn & Technol, Liverpool L3 5UZ, Merseyside, England | title2: A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles With Smart City | site1: WOS
# inst: 0.47113922492073756 | title: 0.7064593301435407 | email: 0, funding: 0
# weigth: 1.5321205588285576
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8435314685314685
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Telecommunications'], ['automation of everything (AoE)', ' Autonomous vehicles', ' cloud platform', ' crowdsourcing', ' driverless vehicles', ' fog platform', ' Internet of Everything (IoE)', ' mobile-edge computing (MEC)', ' smart city'] | journal1: PERVASIVE MOB COMPUT | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Khan, Shahzad | inst1: Gnowit Inc, 200-308 Legett Dr, Kanata, ON, Canada | title1: AI-driven autonomous vehicles as COVID-19 assessment centers: A novel crowdsensing-enabled strategy | site1: WOS
# name2: Khan, Wasiq | inst2: Faculty of Engineering and Technology Liverpool John Moores University Liverpool United Kingdom | title2: A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles with Smart City | site1: SCOPUS
# inst: 0.4419202768826829 | title: 0.6489252692039069 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9111111111111111
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Chemistry', ' Science & Technology - Other Topics', ' Materials Science', ' Physics'], ['Autonomous nanoma-terials discovery', ' Data flow model', ' Data-centric architecture', ' Self-driving laboratory'] | journal1: NANOMATERIALS-BASEL | journal2: MDPI
# name1: Soldatov, Alexander V. | inst1: Southern Fed Univ, Smart Mat Res Inst, 178-24 Sladkova, Rostov Na Donu 344090, Russia | title1: Data-Centric Architecture for Self-Driving Laboratories with Autonomous Discovery of New Nanomaterials | site1: WOS
# name2: Soldatov, A. V. | inst2: The Smart Materials Research Institute Southern Federal University 178/24 Sladkova Rostov-on-Don 344090 Russian Federation | title2: Data-centric architecture for self-driving laboratories with autonomous discovery of new nanomaterials | site1: SCOPUS
# inst: 0.7156380585020893 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Science & Technology - Other Topics'], [''] | journal1: PLOS ONE | journal2: Public Library of Science
# name1: Kahn, Lauren | inst1: Council Foreign Relat, Washington, DC USA | title1: What influences attitudes about artificial intelligence adoption: Evidence from US local officials | site1: WOS
# name2: Kahn L. | inst2: Council on Foreign Relations Washington D.C. United States | title2: What influences attitudes about artificial intelligence adoption: Evidence from U.S. local officials | site1: SCOPUS
# inst: 0.8427161258908414 | title: 0.996 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9666666666666667
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['affordance', ' agency', ' artificial intelligence (AI)', ' artificial life (ALife)', ' evolution', ' organizational closure', ' radical emergence', ' universal turing machine'], ['Environmental Sciences & Ecology'] | journal1: Frontiers Media S.A. | journal2: FRONT ECOL EVOL
# name1: Kauffman, Stuart Alan | inst1: Institute for Systems Biology Seattle WA United States | title1: How Organisms Come to Know the World: Fundamental Limits on Artificial General Intelligence | site1: SCOPUS
# name2: Kauffman, Stuart A. | inst2: Inst Syst Biol, Seattle, WA USA | title2: How Organisms Come to Know the World: Fundamental Limits on Artificial General Intelligence | site1: WOS
# inst: 0.6762957273709961 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8875
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], [''] | journal1: IEEE NETWORK | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Imran, Muhammad Ali | inst1: AiDrivers Ltd, London, England | title1: Smart and Secure CAV Networks Empowered by AI-Enabled Blockchain: The Next Frontier for Intelligent Safe Driving Assessment | site1: WOS
# name2: Imran M.A. | inst2: University of Glasgow United Kingdom | title2: Smart and Secure CAV Networks Empowered by AI-Enabled Blockchain: The Next Frontier for Intelligent Safe Driving Assessment | site1: SCOPUS
# inst: 0.6074074074074075 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.95
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Transportation'], ['Artificial Intelligence (AI)', ' Automatic driving', ' Connected Autonomous Vehicles (CAVs)', ' Out of the loop', ' Self-driving car', ' Turing test'] | journal1: TRANSPORT RES C-EMER | journal2: Elsevier Ltd
# name1: Di Francesco, Lungi | inst1: Univ Campania Luigi Vanvitelli, Dept Engn, Via Roma 29, I-81031 Aversa, Caserta, Italy | title1: Do autonomous vehicles drive like humans? A Turing approach and an application to SAE automation Level 2 cars | site1: WOS
# name2: Di Francesco L. | inst2: Department of Engineering University of Campania “Luigi Vanvitelli” Via Roma 29 Aversa Caserta  81031 Italy | title2: Do autonomous vehicles drive like humans? A Turing approach and an application to SAE automation Level 2 cars | site1: SCOPUS
# inst: 0.721083840698729 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9230769230769231
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Information Science & Library Science', ' Social Sciences - Other Topics'], ['AI ethics', ' autonomous vehicle', ' Moral Machine', ' self-driving car', ' trolley problem'] | journal1: SOC SCI COMPUT REV | journal2: SAGE Publications Inc.
# name1: Etienne, Hubert | inst1: Ecole Normale Super, 45 Rue Ulm, F-75005 Paris, France | title1: When AI Ethics Goes Astray: A Case Study of Autonomous Vehicles | site1: WOS
# name2: Etienne H. | inst2: Ecole Normale Supérieure Paris France | title2: When AI Ethics Goes Astray: A Case Study of Autonomous Vehicles | site1: SCOPUS
# inst: 0.8861802979450039 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8727272727272728
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science'], ['Convolutional neural network', ' Deep learning', ' GTSRB', ' Traffic sign recognition'] | journal1: INT J MACH LEARN CYB | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Yao, Hongyang | inst1: Shanghai Univ, Sch Comp Engn & Sci, Shanghai 200444, Peoples R China | title1: Improved VGG model-based efficient traffic sign recognition for safe driving in 5G scenarios | site1: WOS
# name2: Yao H. | inst2: College of Computer Science and Technology Shanghai University of Electric Power Shanghai 200090 China | title2: Improved VGG model-based efficient traffic sign recognition for safe driving in 5G scenarios | site1: SCOPUS
# inst: 0.6577642551273383 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9333333333333333
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['explainable AI', ' explainable recommender systems', ' interpretable machine learning', ' neural-symbolic reasoning'], ['Computer Science'] | journal1: Wiley-Blackwell | journal2: WIRES DATA MIN KNOWL
# name1: Besold, Tarek Richard | inst1: Neurocat GmbH Berlin Germany | title1: A historical perspective of explainable Artificial Intelligence | site1: SCOPUS
# name2: Besold, Tarek R. | inst2: Neurocat GmbH, Berlin, Germany | title2: A historical perspective of explainable Artificial Intelligence | site1: WOS
# inst: 0.9866666666666667 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9714285714285714
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['artificial intelligence', ' Autonomous driving (AD)', ' decision making', ' deep learning (DL)', ' intelligent sensors', ' vehicular safety', ' vehicular technology'], ['Engineering', ' Transportation'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: IEEE T INTELL TRANSP
# name1: de Albuquerque, Victor Hugo Costa | inst1: LAPISCO Federal Institute of Education Science and Technology of Ceará Fortaleza/CE Brazil ARMTEC Tecnologia em Robótica Fortaleza/CE 60811-341 Brazil | title1: Deep Learning for Safe Autonomous Driving: Current Challenges and Future Directions | site1: SCOPUS
# name2: de Albuquerque, Victor Hugo C. | inst2: Fed Inst Educ Sci & Technol Ceara, LAPISCO, BR-60040215 Fortaleza, CE, Brazil | title2: Deep Learning for Safe Autonomous Driving: Current Challenges and Future Directions | site1: WOS
# inst: 0.5926214526214526 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.9874999999999999
# joc: 0 | yop: 2021, 2021 | co_author_count: 6 | keyword: ['Autonomous vehicle', ' camera', ' dataset', ' GPS', ' IMU', ' lidar', ' winter weather'], ['Robotics'] | journal1: SAGE Publications Inc. | journal2: INT J ROBOT RES
# name1: Waslander, Steven L. | inst1: Institute for Aerospace Studies University of Toronto Canada | title1: Canadian Adverse Driving Conditions dataset | site1: SCOPUS
# name2: Waslander, Steven | inst2: Univ Waterloo, Waterloo, ON, Canada | title2: Canadian Adverse Driving Conditions dataset | site1: WOS
# inst: 0.5497239475500345 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8435314685314685
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Computer Science'], ['Computer Science', ' Engineering', ' Telecommunications'] | journal1: IEEE TETCI | journal2: IEEE ACCESS
# name1: Khan, Shahzad | inst1: Gnowit Inc, 200-308 Legett Dr, Kanata, ON, Canada | title1: Machine Learning-Backed Planning of Rapid COVID-19 Tests With Autonomous Vehicles With Zero-Day Considerations | site1: WOS
# name2: Khan, Wasiq | inst2: Liverpool John Moores Univ, Fac Engn & Technol, Liverpool L3 5UZ, Merseyside, England | title2: A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles With Smart City | site1: WOS
# inst: 0.47113922492073756 | title: 0.7064593301435407 | email: 0, funding: 0
# weigth: 1.5321205588285576
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8435314685314685
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Telecommunications'], ['automation of everything (AoE)', ' Autonomous vehicles', ' cloud platform', ' crowdsourcing', ' driverless vehicles', ' fog platform', ' Internet of Everything (IoE)', ' mobile-edge computing (MEC)', ' smart city'] | journal1: PERVASIVE MOB COMPUT | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Khan, Shahzad | inst1: Gnowit Inc, 200-308 Legett Dr, Kanata, ON, Canada | title1: AI-driven autonomous vehicles as COVID-19 assessment centers: A novel crowdsensing-enabled strategy | site1: WOS
# name2: Khan, Wasiq | inst2: Faculty of Engineering and Technology Liverpool John Moores University Liverpool United Kingdom | title2: A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles with Smart City | site1: SCOPUS
# inst: 0.4419202768826829 | title: 0.6489252692039069 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9333333333333333
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: [''], ['Science & Technology - Other Topics'] | journal1: Nature Research | journal2: NATURE
# name1: Bhaskaran, Harish | inst1: Department of Materials University of Oxford Oxford United Kingdom | title1: Parallel convolutional processing using an integrated photonic tensor core | site1: SCOPUS
# name2: Bhaskaran, H. | inst2: Univ Exeter, Dept Engn, Exeter, Devon, England | title2: Parallel convolutional processing using an integrated photonic tensor core | site1: WOS
# inst: 0.574751724821851 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8577777777777779
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Engineering', ' Transportation'], ['5G technologies', ' Artificial Intelligence', ' Vehicle to everything'] | journal1: IEEE T INTELL TRANSP | journal2: Springer
# name1: Li, Li | inst1: Tsinghua Univ, Dept Automat, BNRist, Beijing 100084, Peoples R China | title1: Harmonious Lane Changing via Deep Reinforcement Learning | site1: WOS
# name2: Li W. | inst2: Information Technology and Cultural Management Institute Hebei Institute of Communications Shijiazhuang 051430 China | title2: Vehicle Artificial Intelligence System Based on Intelligent Image Analysis and 5G Network | site1: SCOPUS
# inst: 0.553780707685373 | title: 0.658860735305358 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8605982905982907
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Telecommunications'], ['Chemistry', ' Engineering', ' Instruments & Instrumentation'] | journal1: IEEE T COGN COMMUN | journal2: SENSORS-BASEL
# name1: Huang, Kaibin | inst1: South China Univ Technol, Sch Elect & Informat Engn, Guangzhou 510641, Peoples R China | title1: Reconfigurable Intelligent Surface Assisted Mobile Edge Computing With Heterogeneous Learning Tasks | site1: WOS
# name2: Hua, Kai-Lung | inst2: Natl Taiwan Univ Sci & Technol, Dept Ind Management, Taipei 106, Taiwan | title2: How Does C-V2X Help Autonomous Driving to Avoid Accidents? | site1: WOS
# inst: 0.649221201128079 | title: 0.5979914083362359 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8605982905982907
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['ADMM', ' edge learning', ' mobile edge computing', ' Reconfigurable intelligent surface'], ['AI', ' Autonomous driving', ' C-V2X', ' OBU', ' PC5', ' RSU', ' VRUCW'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: MDPI
# name1: Huang, Kaibin | inst1: Department of Electrical and Electronic Engineering University of Hong Kong Hong Kong | title1: Reconfigurable Intelligent Surface Assisted Mobile Edge Computing with Heterogeneous Learning Tasks | site1: SCOPUS
# name2: Hua, Kai-Lung | inst2: Department of Computer Science and Information Engineering National Taiwan University of Science and Technology Taipei 106 Taiwan | title2: How Does C-V2X Help Autonomous Driving to Avoid Accidents | site1: SCOPUS
# inst: 0.6931222604273221 | title: 0.6024277866383129 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8483333333333334
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Adaptation models', ' Autonomous driving', ' Autonomous vehicles', ' Computational modeling', ' Data models', ' Intelligence networking', ' Multi-access edge computing', ' Roads', ' Task analysis', ' Training'], [''] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Liu P.X. | inst1: Systems and Computer Engineering Carleton University Ottawa Ontario Canada | title1: Intelligence Networking for Autonomous Driving in Beyond 5G Networks with Multi-access Edge Computing | site1: SCOPUS
# name2: Liu J. | inst2: Baidu Beijing China | title2: Kunlun: A 14nm High-Performance AI Processor for Diversified Workloads | site1: SCOPUS
# inst: 0.5307254623044096 | title: 0.6313017015987312 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8833333333333334
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: [''], ['Explainable AI', ' Saliency method', ' Visual explanation'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Kim, Namsung | inst1: Samsung Electronics Hwaseong South Korea | title1: 25.4 A 20nm 6GB Function-In-Memory DRAM, Based on HBM2 with a 1.2TFLOPS Programmable Computing Unit Using Bank-Level Parallelism, for Machine Learning Applications | site1: SCOPUS
# name2: Kim M.S. | inst2: AI Advanced Research Lab. Samsung SDS Seoul 06765 South Korea | title2: Jointly Optimize Positive and Negative Saliencies for Black Box Classifiers | site1: SCOPUS
# inst: 0.6028233151183972 | title: 0.6226540759453064 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9555555555555556
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Convolutional neural nets', ' Explainable AI', ' Image classification', ' Semantic segmentation'] | journal1: APPL SCI-BASEL | journal2: MDPI AG
# name1: Dahmen, Tim | inst1: German Res Ctr Artificial Intelligence, D-66123 Saarbrucken, Germany | title1: Neuroscope: An Explainable AI Toolbox for Semantic Segmentation and Image Classification of Convolutional Neural Nets | site1: WOS
# name2: Dahmen T. | inst2: German Research Centre for Artificial Intelligence Saarbrucken 66123 Germany | title2: Neuroscope: An explainable ai toolbox for semantic segmentation and image classification of convolutional neural nets | site1: SCOPUS
# inst: 0.8785313467492261 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8448148148148149
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science'], [''] | journal1: J SYST SOFTWARE | journal2: USENIX Association
# name1: Lee, Seok-Won | inst1: Ajou Univ, Dept Artificial Intelligence, Suwon 16499, South Korea | title1: Multilayered review of safety approaches for machine learning-based systems in the days of AI | site1: WOS
# name2: Lee, Jaewoo | inst2: Seoul National University South Korea | title2: FlashNeuron: SSD-Enabled large-Batch training of very deep neural networks | site1: SCOPUS
# inst: 0.6210493371783694 | title: 0.673740636458775 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.853968253968254
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Transportation'], ['Engineering', ' Oceanography'] | journal1: IEEE T INTELL VEHICL | journal2: J MAR SCI ENG
# name1: Wang, Fan | inst1: Seres Inc, Santa Clara, CA 95054 USA | title1: SUPER: A Novel Lane Detection System | site1: WOS
# name2: Wang, Jin | inst2: Liverpool John Moores Univ, Sch Engn, Liverpool L3 3AF, Merseyside, England | title2: A Novel Ship Collision Avoidance Awareness Approach for Cooperating Ships Using Multi-Agent Deep Reinforcement Learning | site1: WOS
# inst: 0.47407407407407404 | title: 0.5899117222646635 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8833333333333334
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: [''], ['Explainable AI', ' Saliency method', ' Visual explanation'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Kim, Namsung | inst1: Samsung Electronics Hwaseong South Korea | title1: 25.4 A 20nm 6GB Function-In-Memory DRAM, Based on HBM2 with a 1.2TFLOPS Programmable Computing Unit Using Bank-Level Parallelism, for Machine Learning Applications | site1: SCOPUS
# name2: Kim M.S. | inst2: AI Advanced Research Lab. Samsung SDS Seoul 06765 South Korea | title2: Jointly Optimize Positive and Negative Saliencies for Black Box Classifiers | site1: SCOPUS
# inst: 0.6028233151183972 | title: 0.6226540759453064 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8205128205128205
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Computer Science'], ['Artificial intelligence', ' Federated learning', ' Future transportation network', ' Machine learning', ' Markov decision process', ' Meta-learning', ' Reinforcement learning', ' Semi-supervised learning', ' Supervised learning', ' Transfer learning', ' Unmanned aerial vehicle', ' Unsupervised learning', ' Vehicles to anything', ' Vehicular ad hoc networks', ' Vehicular edge network'] | journal1: NEURAL COMPUT APPL | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Mahmood, Arif | inst1: Informat Technol Univ, Dept Comp Sci, Lahore, Pakistan | title1: Statistically correlated multi-task learning for autonomous driving | site1: WOS
# name2: Ma H. | inst2: University of Electronic Science and Technology of China Chengdu China | title2: Artificial Intelligence: Need, Evolution, and Applications for Transportation Systems | site1: SCOPUS
# inst: 0.6059422059422058 | title: 0.7117898638900441 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8507936507936509
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Physical Geography', ' Geology', ' Remote Sensing', ' Imaging Science & Photographic Technology'], ['Computer Science', ' Engineering', ' Physics'] | journal1: ISPRS J PHOTOGRAMM | journal2: ELECTRONICS-SWITZ
# name1: Li, Jonathan | inst1: Univ Fed Mato Grosso do Sul, BR-79070900 Campo Grande, MS, Brazil | title1: Adversarial unsupervised domain adaptation for 3D semantic segmentation with multi-modal learning | site1: WOS
# name2: Li, Hao | inst2: Sci & Technol Commun Networks Lab, Shijiazhuang 050081, Hebei, Peoples R China | title2: Adversarial Attack and Defense: A Survey | site1: WOS
# inst: 0.6012210012210012 | title: 0.6787243428996006 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8507936507936509
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Adversarial learning', ' Domain adaptation', ' Multi-modal learning', ' Point cloud', ' Semantic segmentation'], ['adversarial defense', ' adversarial example', ' black-box attack', ' deep neural network', ' smart city', ' white-box attack'] | journal1: Elsevier B.V. | journal2: MDPI
# name1: Li, Jonathan | inst1: University of Waterloo Waterloo N2L 3G1 Canada | title1: Adversarial unsupervised domain adaptation for 3D semantic segmentation with multi-modal learning | site1: SCOPUS
# name2: Li, Hao | inst2: Science and Technology on Communication Networks Laboratory Shijiazhuang 050081 China | title2: Adversarial Attack and Defense: A Survey | site1: SCOPUS
# inst: 0.593394161424852 | title: 0.6787243428996006 | email: 0, funding: 0
# weigth: 0.9
# ...
# 0.8250000000000001
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: [''], ['Autonomous Driving', ' Criteria', ' Heterogeneous Multicore AI Accelerator', ' Reinforcement Learning', ' Scheduling'] | journal1: International Joint Conferences on Artificial Intelligence | journal2: Elsevier Ltd
# name1: Sharon, Guni | inst1: Texas A&M University Computer Science and Engineering | title1: Alleviating Road Traffic Congestion with Artificial Intelligence | site1: SCOPUS
# name2: Fan, Dongrui | inst2: SKLCA Institute of Computing Technology Chinese Academy of Sciences Beijing China | title2: A synergistic reinforcement learning-based framework design in driving automation | site1: SCOPUS
# inst: 0.6334414957105222 | title: 0.6650440268700073 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9466666666666665
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['attention mechanism', ' Autonomous driving', ' Computational modeling', ' Data models', ' Graph Attention Networks', ' Hidden Markov models', ' History', ' Numerical models', ' Predictive models', ' Trajectory', ' trajectory prediction'], ['AI-Native.', ' Artificial intelligence', ' Artificial intelligence', ' Autonomous vehicles', ' Games', ' Internet', ' Machine Learning', ' Network Management', ' Network O&#x0026', 'M', ' Software', ' Springs', ' Taxonomy'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zheng, Liang | inst1: School of Traffic and Transportation Engineering Central South University 12570 Changsha Hunan China | title1: AI-TP: Attention-based Interaction-aware Trajectory Prediction for Autonomous Driving | site1: SCOPUS
# name2: Zhang, Liang | inst2: Huawei Technologies co. Ltd Nanjing Research and Development Center | title2: Landing AI on Networks: An equipment vendor viewpoint on Autonomous Driving Networks | site1: SCOPUS
# inst: 0.5771824550715808 | title: 0.682717388030481 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8875
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], [''] | journal1: IEEE NETWORK | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Imran, Muhammad Ali | inst1: AiDrivers Ltd, London, England | title1: Smart and Secure CAV Networks Empowered by AI-Enabled Blockchain: The Next Frontier for Intelligent Safe Driving Assessment | site1: WOS
# name2: Imran M.A. | inst2: University of Glasgow United Kingdom | title2: Smart and Secure CAV Networks Empowered by AI-Enabled Blockchain: The Next Frontier for Intelligent Safe Driving Assessment | site1: SCOPUS
# inst: 0.6074074074074075 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8205128205128205
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Augmented reality (AR)', ' Autonomous vehicles (AV)', ' Knowledge-based risk assessment', ' Risk assessment', ' Virtual reality (VR)'], ['Artificial intelligence', ' Federated learning', ' Future transportation network', ' Machine learning', ' Markov decision process', ' Meta-learning', ' Reinforcement learning', ' Semi-supervised learning', ' Supervised learning', ' Transfer learning', ' Unmanned aerial vehicle', ' Unsupervised learning', ' Vehicles to anything', ' Vehicular ad hoc networks', ' Vehicular edge network'] | journal1: Springer Science and Business Media Deutschland GmbH | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Mahato, Shalini | inst1: Amity Institute of Information Technology Amity University Ranchi Jharkhand Ranchi India | title1: AR/VR Technology for Autonomous Vehicles and Knowledge-Based Risk Assessment | site1: SCOPUS
# name2: Ma H. | inst2: University of Electronic Science and Technology of China Chengdu China | title2: Artificial Intelligence: Need, Evolution, and Applications for Transportation Systems | site1: SCOPUS
# inst: 0.652056277056277 | title: 0.6447931325640304 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8742857142857143
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Engineering', ' Oceanography'], ['Auto-generated map', ' Autonomous driving', ' Bezier Curve', ' Python'] | journal1: J MAR SCI ENG | journal2: Association for Computing Machinery
# name1: Wang, Jin | inst1: Liverpool John Moores Univ, Sch Engn, Liverpool L3 3AF, Merseyside, England | title1: A Novel Ship Collision Avoidance Awareness Approach for Cooperating Ships Using Multi-Agent Deep Reinforcement Learning | site1: WOS
# name2: Wang L. | inst2: Department of Robotics Engineering University of California Santa Cruz Santa Cruz CA United States | title2: Autonomous Driving's Testing Map Generating System | site1: SCOPUS
# inst: 0.5831425903694811 | title: 0.5960597572362278 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8444444444444443
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Autonomous braking', ' cosine similarity', ' federated learning', ' neural network'], [''] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Li, Changle | inst1: Xidian University State Key Laboratory of Integrated Services Networks Shaanxi Xian 710071 China Research Institute of Smart Transportation Xidian University Shaanxi Xian 710071 China | title1: Autonomous Braking Algorithm for Rear-End Collision via Communication-Efficient Federated Learning | site1: SCOPUS
# name2: Li C. | inst2: Australian National University Australia | title2: Investigating Attention Mechanism in 3D Point Cloud Object Detection | site1: SCOPUS
# inst: 0.5315386263795135 | title: 0.670421501934107 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8483164983164984
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Telecommunications'], ['Behavioral Sciences', ' Engineering', ' Psychology'] | journal1: KSII T INTERNET INF | journal2: HUM FACTORS
# name1: Kim, Youngseop | inst1: Dankook Univ, Elect & Elect Engn, 152 Jukjeon Ro, Yongin 16890, Gyeonggi Do, South Korea | title1: Real-time Camera and Video Streaming Through Optimized Settings of Ethernet AVB in Vehicle Network System | site1: WOS
# name2: Kim, Sang-Ho | inst2: Kumoh Natl Inst Technol, Dept Ind Engn, 61 Daehak Ro, Gumi 39177, Gyeongbuk, South Korea | title2: Review of the Factors Affecting Acceptance of AI-Infused Systems | site1: WOS
# inst: 0.6975524475524475 | title: 0.6489402958152958 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8483164983164984
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science'], ['autonomous driving', ' healthcare', ' human factors', ' robotics', ' technology adoption'] | journal1: J WEB ENG | journal2: SAGE Publications Inc.
# name1: Kim, Youngseop | inst1: Dankook Univ, Elect & Elect Engn, 152 Jukjeon Ro, Yongin 16890, Gyeonggi Do, South Korea | title1: Image Link Through Adaptive Encoding Data Base and Optimized GPU Algorithm for Real-time Image Processing of Artificial Intelligence | site1: WOS
# name2: Kim, Sang-Ho | inst2: Department of Industrial Engineering Kumoh National Institute of Technology South Korea | title2: Review of the Factors Affecting Acceptance of AI-Infused Systems | site1: SCOPUS
# inst: 0.6028000309609505 | title: 0.6027988215488216 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8483333333333334
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Adaptation models', ' Autonomous driving', ' Autonomous vehicles', ' Computational modeling', ' Data models', ' Intelligence networking', ' Multi-access edge computing', ' Roads', ' Task analysis', ' Training'], [''] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Liu P.X. | inst1: Systems and Computer Engineering Carleton University Ottawa Ontario Canada | title1: Intelligence Networking for Autonomous Driving in Beyond 5G Networks with Multi-access Edge Computing | site1: SCOPUS
# name2: Liu J. | inst2: Baidu Beijing China | title2: Kunlun: A 14nm High-Performance AI Processor for Diversified Workloads | site1: SCOPUS
# inst: 0.5307254623044096 | title: 0.6313017015987312 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8507936507936509
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Physical Geography', ' Geology', ' Remote Sensing', ' Imaging Science & Photographic Technology'], ['Computer Science', ' Engineering', ' Physics'] | journal1: ISPRS J PHOTOGRAMM | journal2: ELECTRONICS-SWITZ
# name1: Li, Jonathan | inst1: Univ Fed Mato Grosso do Sul, BR-79070900 Campo Grande, MS, Brazil | title1: Adversarial unsupervised domain adaptation for 3D semantic segmentation with multi-modal learning | site1: WOS
# name2: Li, Hao | inst2: Sci & Technol Commun Networks Lab, Shijiazhuang 050081, Hebei, Peoples R China | title2: Adversarial Attack and Defense: A Survey | site1: WOS
# inst: 0.6012210012210012 | title: 0.6787243428996006 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8507936507936509
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Adversarial learning', ' Domain adaptation', ' Multi-modal learning', ' Point cloud', ' Semantic segmentation'], ['adversarial defense', ' adversarial example', ' black-box attack', ' deep neural network', ' smart city', ' white-box attack'] | journal1: Elsevier B.V. | journal2: MDPI
# name1: Li, Jonathan | inst1: University of Waterloo Waterloo N2L 3G1 Canada | title1: Adversarial unsupervised domain adaptation for 3D semantic segmentation with multi-modal learning | site1: SCOPUS
# name2: Li, Hao | inst2: Science and Technology on Communication Networks Laboratory Shijiazhuang 050081 China | title2: Adversarial Attack and Defense: A Survey | site1: SCOPUS
# inst: 0.593394161424852 | title: 0.6787243428996006 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8742857142857143
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Engineering', ' Oceanography'], ['Accelerator', ' Architecture', ' Artificial intelligence', ' Neural network'] | journal1: J MAR SCI ENG | journal2: Science Press (China)
# name1: Wang, Jin | inst1: Liverpool John Moores Univ, Sch Engn, Liverpool L3 3AF, Merseyside, England | title1: A Novel Ship Collision Avoidance Awareness Approach for Cooperating Ships Using Multi-Agent Deep Reinforcement Learning | site1: WOS
# name2: Wang Y. | inst2: Department of Electrical and Computer Engineering Duke University Durham NC  27708 United States | title2: A survey of architectures of neural network accelerators [神经网络加速器架构概述 | site1: SCOPUS
# inst: 0.5758333333333333 | title: 0.591848333536313 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8742857142857143
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Engineering', ' Oceanography'], ['Artificial Intelligence', ' Autonomous driving', ' Machine Learning', ' Maintenance', ' Railways', ' Smart mobility', ' Traffic management', ' Train control', ' Transportation'] | journal1: J MAR SCI ENG | journal2: Elsevier Ltd
# name1: Wang, Jin | inst1: Liverpool John Moores Univ, Sch Engn, Liverpool L3 3AF, Merseyside, England | title1: A Novel Ship Collision Avoidance Awareness Approach for Cooperating Ships Using Multi-Agent Deep Reinforcement Learning | site1: WOS
# name2: Wang Z. | inst2: Department of Transport and Planning Delft University of Technology P.O. Box 5048 Delft 2600 GA Netherlands | title2: A literature review of Artificial Intelligence applications in railway systems | site1: SCOPUS
# inst: 0.5934094842506058 | title: 0.68138582077201 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8672727272727273
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Engineering', ' Instruments & Instrumentation'], ['AI-Native.', ' Artificial intelligence', ' Artificial intelligence', ' Autonomous vehicles', ' Games', ' Internet', ' Machine Learning', ' Network Management', ' Network O&#x0026', 'M', ' Software', ' Springs', ' Taxonomy'] | journal1: ACTUATORS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhang, Juan | inst1: Univ Exeter, Coll Engn Math & Phys Sci, Exeter EX4 4QF, Devon, England | title1: An Intelligent Actuator of an Indoor Logistics System Based on Multi-Sensor Fusion | site1: WOS
# name2: Zhang, Liang | inst2: Huawei Technologies co. Ltd Nanjing Research and Development Center | title2: Landing AI on Networks: An equipment vendor viewpoint on Autonomous Driving Networks | site1: SCOPUS
# inst: 0.594340145960095 | title: 0.6912141889276034 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8205128205128205
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Computer Science'], ['Artificial intelligence', ' Federated learning', ' Future transportation network', ' Machine learning', ' Markov decision process', ' Meta-learning', ' Reinforcement learning', ' Semi-supervised learning', ' Supervised learning', ' Transfer learning', ' Unmanned aerial vehicle', ' Unsupervised learning', ' Vehicles to anything', ' Vehicular ad hoc networks', ' Vehicular edge network'] | journal1: NEURAL COMPUT APPL | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Mahmood, Arif | inst1: Informat Technol Univ, Dept Comp Sci, Lahore, Pakistan | title1: Statistically correlated multi-task learning for autonomous driving | site1: WOS
# name2: Ma H. | inst2: University of Electronic Science and Technology of China Chengdu China | title2: Artificial Intelligence: Need, Evolution, and Applications for Transportation Systems | site1: SCOPUS
# inst: 0.6059422059422058 | title: 0.7117898638900441 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# ['etienneh', 'yaoh', 'besoldtarekr', 'bhaskaranh', 'dahment', 'waslandersteven', 'yanw', 'henkejb', 'hosonoh', 'dealbuquerquevictorhugoc', 'varadarajans', 'guizanm', 'amatin', 'jararwehyaser', 'dombrovszkia', 'schvaneveldtsj', 'pustokhindenisa', 'mengq', 'bianx', 'niars', 'cloarecj', 'soldatovav', 'kahnl', 'kauffmanstuarta', 'imranma', 'difrancescol', 'etienneh', 'yaoh', 'besoldtarekr', 'dealbuquerquevictorhugoc', 'waslandersteven', 'bhaskaranh', 'dahment', 'henkejb', 'varadarajans', 'mengq', 'hosonoh', 'yanw', 'cloarecj', 'schvaneveldtsj', 'amatin', 'guizanm', 'pustokhindenisa', 'wangj', 'jararwehyaser', 'dombrovszkia', 'kahnl', 'bianx', 'niars', 'difrancescol', 'soldatovav', 'kauffmanstuarta', 'imranma']
# 117
# 186

# %%
for check_name in set(Inte_name): #통합저자
    paper_check = {} #paper_id : title : co_author
    
    if check_name in Answer_dict.keys():
        for site_one in site:
            if site_one in Answer_dict[check_name]:
                for raw_one in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[check_name][site_one]['papers']}}):
                    if raw_one['title'] not in paper_check.keys(): #중복 title이 아니면
                        
                        for key_check in paper_check: #paper_chck에 있는 title과 유사도 비교
                            paper_sim = jaro.jaro_winkler_metric(key_check, raw_one['title'])

                            if paper_sim >= 0.8: #유사도가 80% 이상이면
                                if len(paper_check[key_check]['co_author']) == len(raw_one['author'].split(';')[:-1]): #공동저자 비교
                                    print(key_check)
                                    print(raw_one['title'])
                                    print(paper_check[key_check]['co_author'])
                                    print(raw_one['author'].split(';')[:-1])
                                    if raw_one['_id'] in Answer_dict[check_name][site_one]['papers']:
                                        Answer_dict[check_name][site_one]['papers'].remove(raw_one['_id'])
                                        if raw_one['_id'] in fp_dict:
                                            print('del_1')
                                            del fp_dict[raw_one['_id']]
                                        break

                        paper_check[raw_one['title']] = {'paper_id' : raw_one['_id'], 'co_author' : raw_one['author'].split(';')[:-1]}
                        
                    else: #중복 title이면
                        Answer_dict[check_name][site_one]['papers'].remove(raw_one['_id'])
                        if raw_one['_id'] in fp_dict:
                            print('del_2')
                            del fp_dict[raw_one['_id']]
                         
                if Answer_dict[check_name][site_one]['papers'] == []: #site에 papers가 비어있으면 site 삭제
                    del Answer_dict[check_name][site_one]
# Out:
# Processor-in-the-Loop Architecture Design and Experimental Validation for an Autonomous Racing Vehicle
# Processor-in-the-loop architecture design and experimental validation for an autonomous racing vehicle
# ['Tramacere, Eugenio', 'Luciani, Sara', 'Feraco, Stefano', 'Bonfitto, Angelo', 'Amati, Nicola']
# ['Tramacere E.', 'Luciani S.', 'Feraco S.', 'Bonfitto, Angelo', 'Amati, N.']
# del_1
# del_2
# Automated Data Annotation for 6-DoF AI-Based Navigation Algorithm Development
# Automated data annotation for 6-dof ai-based navigation algorithm development
# ['Baca, Javier Gibran Apud', 'Jantos, Thomas', 'Theuermann, Mario', 'Hamdad, Mohamed Amin', 'Steinbrener, Jan', 'Weiss, Stephan', 'Almer, Alexander', 'Perko, Roland']
# ['Apud Baca J.G.', 'Jantos T.', 'Theuermann M.', 'Hamdad M.A.', 'Steinbrener, Jan', 'Weiss, Stephan', 'Almer, Alexander', 'Perko, Roland']
# del_1
# del_2
# Baby, you can drive my car: Psychological antecedents that drive consumers' adoption of AI-powered autonomous vehicles
# “Baby, you can drive my car”: Psychological antecedents that drive consumers’ adoption of AI-powered autonomous vehicles
# ['Meyer-Waarden, Lars', 'Cloarec, Julien']
# ['Meyer?Waarden, Lars', 'Cloarec J.']
# del_1
# del_2
# del_2
# del_2
# del_2
# An Intelligent Actuator of an Indoor Logistics System Based on Multi-Sensor Fusion
# An intelligent actuator of an indoor logistics system based on multi-sensor fusion
# ['Wang, Pangwei', 'Wang, Yunfeng', 'Wang, Xu', 'Liu, Ying', 'Zhang, Juan']
# ['Wang, Pangwei', 'Wang, Yunfeng', 'Wang, Xu', 'Liu, Ying', 'Zhang, Juan']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# Incorporating Multi-Context Into the Traversability Map for Urban Autonomous Driving Using Deep Inverse Reinforcement Learning
# Incorporating Multi-Context into the Traversability Map for Urban Autonomous Driving Using Deep Inverse Reinforcement Learning
# ['Jung, Chanyoung', 'Shim, David Hyunchul']
# ['Jung, Chanyoung', 'Shim, David Hyunchul']
# del_1
# del_2
# Commonsense visual sensemaking for autonomous driving-On generalised neurosymbolic online abduction integrating vision and semantics
# Commonsense visual sensemaking for autonomous driving – On generalised neurosymbolic online abduction integrating vision and semantics
# ['Suchan, Jakob', 'Bhatt, Mehul', 'Varadarajan, Srikrishna']
# ['Suchan, Jakob', 'Bhatt, Mehul', 'Varadarajan S.']
# del_1
# del_2
# Autonomous Vehicles: An Analysis Both on Their Distinctiveness and the Potential Impact on Urban Transport Systems
# Autonomous vehicles: An analysis both on their distinctiveness and the potential impact on urban transport systems
# ['Severino, Alessandro', 'Curto, Salvatore', 'Barberi, Salvatore', 'Arena, Fabio', 'Pau, Giovanni']
# ['Severino, Alessandro', 'Curto, Salvatore', 'Barberi S.', 'Arena, Fabio', 'Pau, Giovanni']
# del_1
# del_2
# del_2
# del_2
# del_2
# 360 degrees real-time and power-efficient 3D DAMOT for autonomous driving applications
# 360 ∘ real-time and power-efficient 3D DAMOT for autonomous driving applications
# ['Gomez-Huelamo, Carlos', 'Del Egido, Javier', 'Miguel Bergasa, Luis', 'Barea, Rafael', 'Lopez-Guillen, Elena', 'Araluce, Javier', 'Antunes, Miguel']
# ['Gómez-Huélamo, Carlos', 'del Egido, Javier', 'Bergasa, Luis Miguel', 'Barea, R.', 'López-Guillén, Elena', 'Araluce, Javier', 'Antunes, Miguel']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# Reconfigurable Intelligent Surface Assisted Mobile Edge Computing With Heterogeneous Learning Tasks
# Reconfigurable Intelligent Surface Assisted Mobile Edge Computing with Heterogeneous Learning Tasks
# ['Huang, Shanfeng', 'Wang, Shuai', 'Wang, Rui', 'Wen, Miaowen', 'Huang, Kaibin']
# ['Huang, Shanfeng', 'Wang, Shuai', 'Wang, Rui', 'Wen, Miaowen', 'Huang, Kaibin']
# del_1
# del_2
# del_2
# Neuroscope: An Explainable AI Toolbox for Semantic Segmentation and Image Classification of Convolutional Neural Nets
# Neuroscope: An explainable ai toolbox for semantic segmentation and image classification of convolutional neural nets
# ['Schorr, Christian', 'Goodarzi, Payman', 'Chen, Fei', 'Dahmen, Tim']
# ['Schorr, Christian', 'Goodarzi P.', 'Chen F.', 'Dahmen T.']
# del_1
# del_2
# del_2
# Intelligent and efficient? An empirical analysis of human-AI collaboration for truck drivers in retail logistics
# Intelligent and efficient? An empirical analysis of human–AI collaboration for truck drivers in retail logistics
# ['Loske, Dominic', 'Klumpp, Matthias']
# ['Loske, Dominic', 'Klumpp, Matthias']
# del_1
# Implications of the BATTERY 2030+AI-Assisted Toolkit on Future Low-TRL Battery Discoveries and Chemistries
# Implications of the BATTERY 2030+ AI-Assisted Toolkit on Future Low-TRL Battery Discoveries and Chemistries
# ['Bhowmik, Arghya', 'Berecibar, Maitane', 'Casas-Cabanas, Montse', 'Csanyi, Gabor', 'Dominko, Robert', 'Hermansson, Kersti', 'Palacin, M. Rosa', 'Stein, Helge S.', 'Vegge, Tejs']
# ['Bhowmik, Arghya', 'Berecibar, Maitane', 'Casas-Cabanas, Montse', 'Csányi, Gábor', 'Dominko R.', 'Hermansson, Kersti G.', 'Palacín, Rosa', 'Stein, H. S.', 'Vegge, Tejs']
# del_1
# Design and Implementation of an Ontology for Semantic Labeling and Testing: Automotive Global Ontology (AGO)
# Design and implementation of an ontology for semantic labeling and testing: Automotive global ontology (ago
# ['Urbieta, Itziar', 'Nieto, Marcos', 'Garcia, Mikel', 'Otaegui, Oihana']
# ['Urbieta I.', 'Nieto, Marcos', 'García M.', 'Otaegui, Oihana']
# del_1
# del_2
# del_2
# A Gamified Simulator and Physical Platform for Self-Driving Algorithm Training and Validation
# A gamified simulator and physical platform for self-driving algorithm training and validation
# ['Pappas, Georgios', 'Siegel, Joshua E.', 'Politopoulos, Konstantinos', 'Sun, Yongbin']
# ['Pappas G.', 'Siegel, Joshua E.', 'Politopoulos K.', 'Sun, Yongbin']
# del_1
# Multi-Cloud Resource Management Techniques for Cyber-Physical Systems
# Multi-cloud resource management techniques for cyber-physical systems
# ['Bucur, Vlad', 'Miclea, Liviu-Cristian']
# ['Bucur, Vlad', 'Míclea, Liviu Cristian']
# del_1
# del_2
# del_2
# del_2
# del_2
# Hybrid Intelligence: to automate or not to automate, that is the question
# Hybrid intelligence: to automate or not to automate, that is the question
# ['van der Aalst, Wil M. P.']
# ['van der Aalst, Wil M.P.']
# del_1
# del_2
# AI Based Traffic Flow Prediction Model for Connected and Autonomous Electric Vehicles
# AI based traffic flow prediction model for connected and autonomous electric vehicles
# ['Thamizhazhagan, P.', 'Sujatha, M.', 'Umadevi, S.', 'Priyadarshini, K.', 'Parvathy, Velmurugan Subbiah', 'Pustokhina, Irina V.', 'Pustokhin, Denis A.']
# ['Thamizhazhagan, P.', 'Sujatha, M.', 'Umadevi, S.', 'Priyadarshini K.', 'Subbiah Parvathy, Velmurugan', 'Pustokhina, Irina Valeryevna', 'Pustokhin, Denis Alexandrovich']
# del_1
# del_2
# del_2
# Making decisions: the normal interventions of Nissan 'mobility managers'
# Making decisions: the normal interventions of Nissan ‘mobility managers
# ['Hind, Sam']
# ['Hind, Sam']
# del_1
# del_2
# del_2
# Real-time Camera and Video Streaming Through Optimized Settings of Ethernet AVB in Vehicle Network System
# Real-time camera and video streaming through optimized settings of ethernet AVB in vehicle network system
# ['An, Byoungman', 'Kim, Youngseop']
# ['An, Byoungman', 'Kim, Youngseop']
# del_1
# del_2
# What influences attitudes about artificial intelligence adoption: Evidence from US local officials
# What influences attitudes about artificial intelligence adoption: Evidence from U.S. local officials
# ['Horowitz, Michael C.', 'Kahn, Lauren']
# ['Horowitz, Michael C.', 'Kahn L.']
# del_1
# del_2
# del_2
# del_2
# del_2
# Data-Centric Architecture for Self-Driving Laboratories with Autonomous Discovery of New Nanomaterials
# Data-centric architecture for self-driving laboratories with autonomous discovery of new nanomaterials
# ['Butakova, Maria A.', 'Chernov, Andrey V.', 'Kartashov, Oleg O.', 'Soldatov, Alexander V.']
# ['Butakova, M. A.', 'Chernov Andrey, V.', 'Kartashov, Oleg O.', 'Soldatov, A. V.']
# del_1
# del_2
# del_2
# del_2
# A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles With Smart City
# A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles with Smart City
# ['Kuru, Kaya', 'Khan, Wasiq']
# ['Kuru, Kaya', 'Khan, Wasiq']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# The Unfounded Bias Against Autonomous Weapons Systems
# The Unfounded Bias against Autonomous Weapons Systems
# ['Dombrovszki, Aron']
# ['Dombrovszki A.']
# del_1
# Safety and Acceptability of a Natural Language Artificial Intelligence Assistant to Deliver Clinical Follow-up to Cataract Surgery Patients: Proposal
# Safety and acceptability of a natural language artificial intelligence assistant to deliver clinical follow-up to cataract surgery patients: Proposal
# ['de Pennington, Nick', 'Mole, Guy', 'Lim, Ernest', 'Milne-Ives, Madison', 'Normando, Eduardo', 'Xue, Kanmin', 'Meinert, Edward']
# ['De Pennington, Nicholas', 'Mole, Guy', 'Lim, Ernest', 'Milne-Ives, Madison', 'Normando, Eduardo Maria', 'Xue, K.', 'Meinert, Edward']
# del_1
# del_2
# AI4People: Ethical Guidelines for the Automotive Sector - Fundamental Requirements and Practical Recommendations
# AI4people: Ethical guidelines for the automotive sector-fundamental requirements and practical recommendations
# ['Luetge, Christoph', 'Poszler, Franziska', 'Acosta, Aida Joaquin', 'Danks, David', 'Gottehrer, Gail', 'Mihet-Popa, Lucian', 'Naseer, Aisha']
# ['Luetge, Christoph', 'Poszler F.', 'Acosta A.J.', 'Danks, David J.', 'Gottehrer G.', 'Mihet-Popa, Lucian', 'Naseer, Aisha']
# del_1
# How Does C-V2X Help Autonomous Driving to Avoid Accidents?
# How Does C-V2X Help Autonomous Driving to Avoid Accidents
# ['Miao, Lili', 'Chen, Shang-Fu', 'Hsu, Yu-Ling', 'Hua, Kai-Lung']
# ['Miao L.', 'Chen S.-F.', 'Hsu Y.-L.', 'Hua, Kailung']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# del_2
# del_2
# Automatic Roadway Features Detection with Oriented Object Detection
# Automatic roadway features detection with oriented object detection
# ['Eraqi, Hesham M.', 'Soliman, Karim', 'Said, Dalia', 'Elezaby, Omar R.', 'Moustafa, Mohamed N.', 'Abdelgawad, Hossam']
# ['Eraqi, Hesham M.', 'Soliman K.', 'Said D.', 'Elezaby O.R.', 'Moustafa, Mohamed N.', 'Abdelgawad, Hossam']
# del_1
# del_2
# del_2
# del_2

# %%
for fp in fp_dict:
    f_pyear = fc_simple_filter(fp_dict[fp]['year'], f_pyear)
    f_pinst = fc_simple_filter(fp_dict[fp]['inst'].replace(".", "^"), f_pinst)
    f_pjournal = fc_simple_filter(fp_dict[fp]['journal'].replace(".", "^"), f_pjournal)
    f_plang = fc_simple_filter(fp_dict[fp]['lang'], f_plang)
    
filter_dict= {'keyId': keyid, 'fId': f_id, 'paper': { 
                'year': {'list': f_pyear, 'k': 'year', 'v': '연도' },
                'inst': {'k': 'inst', 'list': f_pinst, 'v': '소속', 'f': 'false' },
                'journal': {'list': f_pjournal, 'k': 'journal', 'v': '저널'},
                'lang': {'list': f_plang, 'k': 'lang', 'v': '언어' }
            },
            'project': {
                'year': {'list': [], 'k': 'year', 'v': '연도' },
                'inst': {'list': [], 'k': 'inst', 'v': '소속' },
                'fund': {'k': 'fund', 'v': '과제수주비', 'list': []},
                'rsc': {'k': 'rsc', 'v': '참여인원', 'list': [] }
            }}

# %%
# if len(Answer_dict) != 0:
#     filters_category.insert_one(filter_dict)
#     id_international.insert_many(Answer_dict.values()) #mongodb 추가
#     analyzer = multicpu_international.run_factor_integration(keyid, f_id)
#     analyzer.run()
#     print("Integration OK", time.time() - start1)
# else:
#     print("No Data")
