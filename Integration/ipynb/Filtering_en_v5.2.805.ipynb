# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 805 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []
plang = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']
            plang = fid_key_query[key]['lang']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}
f_plang = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst) and simple_filter(paper_lang, plang):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }
        
        if pre_name == 'herrerafrancisco' and site == 'SCOPUS':
            print(Answer)
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

print(f'2차 통합: {savetime2}')
print(Inte_name)
print(len(Answer_dict))
# Out:
# DB 수집: WOS, 0.010350942611694336
# 전체 저자 수: 2
# DB 수집: SCOPUS, 0.06281232833862305
# 전체 저자 수: 163
# 2차 통합: 0.07416296005249023
# []
# 165

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    # if site == "WOS":
    #     email.extend(rawdata['emails'].replace(" ", "").split(";"))
    #     funding_text.append(rawdata['funding text'])
        
    # elif site == "SCOPUS":
    #     emails = rawdata['correspondence_address'].split(" ")
    #     for i in emails:
    #         if "@" in i:
    #             email.append(i)

    #     for funding in  rawdata.keys():
    #         if "funding_text_" in funding:
    #             funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
    
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2 and funding1 != "":
                funding_exact = 1
                # print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
        
        
    if paper_sim >= 0.8 or inst_sim >= 0.83 or email_exact == 1 or funding_exact == 1:
        weight = 4
        print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
        print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
        print(f'weigth: {weight}')
        print('------------------------------------------------------------구분선2------------------------------------------------------------')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    if weight < 3:
    # print(f'weigth: {weight} | joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')
    # print(f'name1: {name1} | site1: {site1} | year: {year1} | coauthor: {coauthor1} | keyword: {keyword1} | journal1: {journal1}')
    # print(f'name2: {name2} | site1: {site2} | year: {year2} | coauthor: {coauthor2} | keyword: {keyword2} | journal2: {journal2}')
    # print(f'paper_sim: {paper_sim}')
    # print(f'title1: {title1}')
    # print(f'title2: {title2}')
    # print(f'inst_sim: {inst_sim}')
    # print(f'inst1: {inst1}')
    # print(f'inst2: {inst2}')
    # print(f'email_exact: {email_exact}')
    # print(f'emails1: {emails1}')
    # print(f'emails2: {emails2}')
        print(raw_one1)
        print(raw_one2)
        print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
        print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
        print(f'weigth: {weight}')
        print('------------------------------------------------------------구분선------------------------------------------------------------')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Artificial intelligence', ' avatar', ' cyber world', ' extended reality', ' metaverse'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Kim, Young-Gab | inst1: Sejong Univ, Dept Comp & Informat Secur & Convergence Engn Int, Seoul 05006, South Korea | title1: A Metaverse: Taxonomy, Components, Applications, and Open Challenges | site1: WOS
# name2: Kim, Young-gab | inst2: Department of Computer and Information Security Convergence Engineering for Intelligent Drone Sejong University Seoul 05006 South Korea | title2: A Metaverse: Taxonomy, Components, Applications, and Open Challenges | site1: SCOPUS
# inst: 0.6878881406659184 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Psychology'], ['Attitude', ' Constructivism', ' Educational experience', ' Educational technology', ' Metaverse'] | journal1: J INTELL-BASEL | journal2: MDPI
# name1: Ahn, Seongjin | inst1: Sungkyunkwan Univ, Dept Comp Educ, 25-2 Sungkyunkwan Ro, Seoul 03063, South Korea | title1: Utilizing the Metaverse for Learner-Centered Constructivist Education in the Post-Pandemic Era: An Analysis of Elementary School Students | site1: WOS
# name2: Ahn, Seongjin | inst2: Department of Computer Education Sungkyunkwan University 25-2 Sungkyunkwan-Ro Jongno-Gu Seoul 03063 South Korea | title2: Utilizing the Metaverse for Learner-Centered Constructivist Education in the Post-Pandemic Era: An Analysis of Elementary School Students | site1: SCOPUS
# inst: 0.7212638323749435 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['kimyounggab_1', 'ahnseongjin_1']

# %%
deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        
        if name_sim >= 0.82 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                print(name_sim)
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
            #         flag = True
            #         break
            # if flag :
            #     break
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# 0.8327272727272728
# {'_id': ObjectId('626b50cd3247eaee55f8ab5c'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85113817252', 'title': 'Differences in learning motivation among bartle’s player types and measures for the delivery of sustainable gameful experiences', 'author': 'Park S.;Min K.;Kim, Sangkyun;', 'journal': 'MDPI', 'issue_inst': 'Department of Industrial Engineering, Kangwon National University, Chuncheon, 24341, South Korea', 'issue_year': '2021', 'issue_lang': 'English', 'start_page': 0, 'end_page': 0, 'paper_keyword': 'Experience; Gameful experience; Gamification; Human–computer interface; Metaverse', 'abstract': 'Gamification is one of the methods used for delivering gameful experiences to Generation Z learners. The player-type theory must be reflected to effectively design gamification. This study aims to analyze the differences in learning motivation among different player types and to propose methods that can deliver effective gameful experiences. The study was conducted on 91 university students who were instructed to attend a class that utilized gamification. Based on the results, there were no statistical differences in the motivation among the different player types. Accordingly, constructing environments that can establish gameful experiences, rules, and strategies preferred by each type of player is proposed as an important factor in gamification design. © 2021 by the authors. Licensee MDPI, Basel, Switzerland.', 'author_inst': 'Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;', 'author_id': '57193955118;57216883872;55812910700', 'citation': '1', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85113817252&doi=10.3390%2fsu13169121&partnerID=40&md5=26e8892ff1cd1f238b7fb7bed6d122df', 'source_title': 'Sustainability (Switzerland)', 'index_keywords': 'design method; student; sustainability; university sector', 'funding_details': 'Ministry of Science, ICT and Future Planning,\xa0MSIP: 2020R1A2B501001810;\xa0National Research Foundation of Korea,\xa0NRF', 'correspondence_address': 'Kim, S.; Department of Industrial Engineering, South Korea; email: Saviour@kangwon.ac.kr', 'editors': '', 'funding_text_1': 'Acknowledgments: This study was supported by a grant from the National Research Foundation of Korea and funded by the Korean Government (Ministry of Science and ICT; #2020R1A2B501001810).', 'funding_text_2': '', 'publisher': 'MDPI', 'ISSN': '20711050', 'abbreviated_source_title': 'Sustainability', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.3626943005181347, 'originalName': 'DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;', 'mngId': '55812910700', 'site': 'SCOPUS'}
# {'_id': ObjectId('626b50ca3247eaee55f8ab39'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '84965025979', 'title': 'A content service deployment plan for metaverse museum exhibitions—Centering on the combination of beacons and HMDs', 'author': 'Choi, Heesoo;Kim S.-H.;', 'journal': 'Elsevier Ltd', 'issue_inst': 'Dept. of History and Historical Content, Sangmyung University, 20, Hongjimun 2-gil, Jongno-gu, Seoul, 03016, South Korea', 'issue_year': '2017', 'issue_lang': 'English', 'start_page': '1519', 'end_page': '1527', 'paper_keyword': 'Augmented reality; Beacon; Exhibition content; HMD; Metaverse; Museum; Virtual reality', 'abstract': 'Today, methods of museum exhibition are rapidly changing. While focusing on visitors’ museum experience, new display methods employ a variety of digital technologies to provide exhibition content in ways that allow visitors to better understand artifacts on display. However, the majority of such methods rely on one-way means of delivering information. The lack of interaction with visitors and the use of lighting that clearly separates real and virtual spaces have made museums inadequate as experiential spaces. To resolve those problems, this article suggests a plan to deploy content services for visitors’ museum experiences by combining beacons and HMDs. This study establishes the concept of a service, which provides a virtual world experience by connecting a beacon installed in real space, that is, an exhibition room, to an HMD (head-mounted display). Furthermore, the service also incorporates a storytelling feature to diversify user experience by presenting the characteristics of and stories about artifacts. The service design will make both online and on-site museum experiences meaningful. Ultimately, this article presents the exhibition content thus created as Metaverse exhibition content made through an effective combination of augmented reality and a virtual world. © 2016 Elsevier Ltd', 'author_inst': 'Dept. of History and Historical Content Sangmyung University 20 Hongjimun 2-gil Jongno-gu Seoul 03016 South Korea;Dept. of History and Historical Content Sangmyung University 20 Hongjimun 2-gil Jongno-gu Seoul 03016 South Korea;', 'author_id': '55516099100;57189071826', 'citation': '37', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-84965025979&doi=10.1016%2fj.ijinfomgt.2016.04.017&partnerID=40&md5=bc36f45def3f193fb89b30f7e033d555', 'source_title': 'International Journal of Information Management', 'index_keywords': 'Augmented reality; Helmet mounted displays; Museums; Virtual reality; Beacon; Content services; Digital technologies; Head mounted displays; Metaverse; Service design; User experience; Virtual worlds; Exhibitions', 'funding_details': '', 'correspondence_address': 'Choi, H.-S.; Dept. of History and Historical Content, 20, Hongjimun 2-gil, Jongno-gu, South Korea; email: choice@smu.ac.kr', 'editors': '', 'publisher': 'Elsevier Ltd', 'ISSN': '02684012', 'abbreviated_source_title': 'Int J Inf Manage', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.18134715025906736, 'originalName': 'DEPT. OF HISTORY AND HISTORICAL CONTENT SANGMYUNG UNIVERSITY 20 HONGJIMUN 2-GIL JONGNO-GU SEOUL 03016 SOUTH KOREA;DEPT. OF HISTORY AND HISTORICAL CONTENT SANGMYUNG UNIVERSITY 20 HONGJIMUN 2-GIL JONGNO-GU SEOUL 03016 SOUTH KOREA;', 'mngId': '57189071826', 'site': 'SCOPUS'}
# joc: 0 | yop: 2021, 2017 | co_author_count: 0 | keyword: ['Experience', ' Gameful experience', ' Gamification', ' Human–computer interface', ' Metaverse'], ['Augmented reality', ' Beacon', ' Exhibition content', ' HMD', ' Metaverse', ' Museum', ' Virtual reality'] | journal1: MDPI | journal2: Elsevier Ltd
# name1: Kim, Sangkyun | inst1: Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea | title1: Differences in learning motivation among bartle’s player types and measures for the delivery of sustainable gameful experiences | site1: SCOPUS
# name2: Kim S.-H. | inst2: Dept. of History and Historical Content Sangmyung University 20 Hongjimun 2-gil Jongno-gu Seoul 03016 South Korea | title2: A content service deployment plan for metaverse museum exhibitions—Centering on the combination of beacons and HMDs | site1: SCOPUS
# inst: 0.7936808446138958 | title: 0.7178831803353133 | email: 0, funding: 0
# weigth: 1.2321205588285578
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8515151515151516
# {'_id': ObjectId('626b50cd3247eaee55f8ab5c'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85113817252', 'title': 'Differences in learning motivation among bartle’s player types and measures for the delivery of sustainable gameful experiences', 'author': 'Park S.;Min K.;Kim, Sangkyun;', 'journal': 'MDPI', 'issue_inst': 'Department of Industrial Engineering, Kangwon National University, Chuncheon, 24341, South Korea', 'issue_year': '2021', 'issue_lang': 'English', 'start_page': 0, 'end_page': 0, 'paper_keyword': 'Experience; Gameful experience; Gamification; Human–computer interface; Metaverse', 'abstract': 'Gamification is one of the methods used for delivering gameful experiences to Generation Z learners. The player-type theory must be reflected to effectively design gamification. This study aims to analyze the differences in learning motivation among different player types and to propose methods that can deliver effective gameful experiences. The study was conducted on 91 university students who were instructed to attend a class that utilized gamification. Based on the results, there were no statistical differences in the motivation among the different player types. Accordingly, constructing environments that can establish gameful experiences, rules, and strategies preferred by each type of player is proposed as an important factor in gamification design. © 2021 by the authors. Licensee MDPI, Basel, Switzerland.', 'author_inst': 'Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;', 'author_id': '57193955118;57216883872;55812910700', 'citation': '1', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85113817252&doi=10.3390%2fsu13169121&partnerID=40&md5=26e8892ff1cd1f238b7fb7bed6d122df', 'source_title': 'Sustainability (Switzerland)', 'index_keywords': 'design method; student; sustainability; university sector', 'funding_details': 'Ministry of Science, ICT and Future Planning,\xa0MSIP: 2020R1A2B501001810;\xa0National Research Foundation of Korea,\xa0NRF', 'correspondence_address': 'Kim, S.; Department of Industrial Engineering, South Korea; email: Saviour@kangwon.ac.kr', 'editors': '', 'funding_text_1': 'Acknowledgments: This study was supported by a grant from the National Research Foundation of Korea and funded by the Korean Government (Ministry of Science and ICT; #2020R1A2B501001810).', 'funding_text_2': '', 'publisher': 'MDPI', 'ISSN': '20711050', 'abbreviated_source_title': 'Sustainability', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.3626943005181347, 'originalName': 'DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;', 'mngId': '55812910700', 'site': 'SCOPUS'}
# {'_id': ObjectId('626b50d23247eaee55f8abbe'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85125836218', 'title': 'Metaverse in journal publishing', 'author': 'Kim K.;', 'journal': 'Korean Council of Science Editors', 'issue_inst': 'Department of Physics, Ajou University, Suwon, South Korea', 'issue_year': '2022', 'issue_lang': 'English', 'start_page': 0, 'end_page': 0, 'paper_keyword': '', 'abstract': 'Recently, the word metaverse has appeared more and more frequently in media reports and public discourses. Most of them are predictions of the future in the science fiction style that a new kind of world will come when the metaverse technology is successfully implemented and they do not give a sense of reality yet. Lectures on metaverse are frequently held in many academic disciplines. At the annual general meeting of the Korean Council of Science Editors held last month, an introductory talk on metaverse was given as a plenary lecture. According to the Amazon site, there are 821 books published after January 2020 with “metaverse” in their titles. According to the Kyobo Books website, there are 238 Korean books that contain the word metaverse in Korean in their titles. That such a tremendous amount of interest is being given to a technology that has not yet been realized is a very unusual and unprecedented phenomenon. The rapid development of information technology over the past few decades is thought to convince people that the metaverse can be implemented in a short period. © 2022 Korean Council of Science Editors', 'author_inst': 'Department of Physics Ajou University Suwon South Korea;', 'author_id': '7409318537', 'citation': 0, 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85125836218&doi=10.6087%2fKCSE.256&partnerID=40&md5=a2f69a4e5e73ddc60dfefbd7ef80e542', 'source_title': 'Science Editing', 'index_keywords': '', 'funding_details': '', 'correspondence_address': 'Kim, K.; Department of Physics, South Korea; email: khkim@ajou.ac.kr', 'editors': '', 'funding_text_1': '', 'funding_text_2': '', 'funding_text_3': '', 'funding_text_4': '', 'funding_text_5': '', 'funding_text_6': '', 'funding_text_7': '', 'funding_text_8': '', 'funding_text_9': '', 'funding_text_10': '', 'publisher': 'Korean Council of Science Editors', 'ISSN': '22888063', 'abbreviated_source_title': 'Sci. Ed.', 'document_type': 'Editorial', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.8704663212435233, 'originalName': 'DEPARTMENT OF PHYSICS AJOU UNIVERSITY SUWON SOUTH KOREA;', 'mngId': '7409318537', 'site': 'SCOPUS'}
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Experience', ' Gameful experience', ' Gamification', ' Human–computer interface', ' Metaverse'], [''] | journal1: MDPI | journal2: Korean Council of Science Editors
# name1: Kim, Sangkyun | inst1: Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea | title1: Differences in learning motivation among bartle’s player types and measures for the delivery of sustainable gameful experiences | site1: SCOPUS
# name2: Kim K. | inst2: Department of Physics Ajou University Suwon South Korea | title2: Metaverse in journal publishing | site1: SCOPUS
# inst: 0.8220191741653351 | title: 0.5718514885305632 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8545454545454545
# {'_id': ObjectId('626b50cd3247eaee55f8ab5c'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85113817252', 'title': 'Differences in learning motivation among bartle’s player types and measures for the delivery of sustainable gameful experiences', 'author': 'Park S.;Min K.;Kim, Sangkyun;', 'journal': 'MDPI', 'issue_inst': 'Department of Industrial Engineering, Kangwon National University, Chuncheon, 24341, South Korea', 'issue_year': '2021', 'issue_lang': 'English', 'start_page': 0, 'end_page': 0, 'paper_keyword': 'Experience; Gameful experience; Gamification; Human–computer interface; Metaverse', 'abstract': 'Gamification is one of the methods used for delivering gameful experiences to Generation Z learners. The player-type theory must be reflected to effectively design gamification. This study aims to analyze the differences in learning motivation among different player types and to propose methods that can deliver effective gameful experiences. The study was conducted on 91 university students who were instructed to attend a class that utilized gamification. Based on the results, there were no statistical differences in the motivation among the different player types. Accordingly, constructing environments that can establish gameful experiences, rules, and strategies preferred by each type of player is proposed as an important factor in gamification design. © 2021 by the authors. Licensee MDPI, Basel, Switzerland.', 'author_inst': 'Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea;', 'author_id': '57193955118;57216883872;55812910700', 'citation': '1', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85113817252&doi=10.3390%2fsu13169121&partnerID=40&md5=26e8892ff1cd1f238b7fb7bed6d122df', 'source_title': 'Sustainability (Switzerland)', 'index_keywords': 'design method; student; sustainability; university sector', 'funding_details': 'Ministry of Science, ICT and Future Planning,\xa0MSIP: 2020R1A2B501001810;\xa0National Research Foundation of Korea,\xa0NRF', 'correspondence_address': 'Kim, S.; Department of Industrial Engineering, South Korea; email: Saviour@kangwon.ac.kr', 'editors': '', 'funding_text_1': 'Acknowledgments: This study was supported by a grant from the National Research Foundation of Korea and funded by the Korean Government (Ministry of Science and ICT; #2020R1A2B501001810).', 'funding_text_2': '', 'publisher': 'MDPI', 'ISSN': '20711050', 'abbreviated_source_title': 'Sustainability', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.3626943005181347, 'originalName': 'DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;DEPARTMENT OF INDUSTRIAL ENGINEERING KANGWON NATIONAL UNIVERSITY CHUNCHEON 24341 SOUTH KOREA;', 'mngId': '55812910700', 'site': 'SCOPUS'}
# {'_id': ObjectId('626b50d13247eaee55f8abaa'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85128296371', 'title': 'An 80×60 Flash LiDAR Sensor with In-Pixel Histogramming TDC Based on Quaternary Search and Time-Gated Δ-Intensity Phase Detection for 45m Detectable Range and Background Light Cancellation', 'author': 'Park S.;Kim B.;Cho J.;Chun, Jung-hoon;Choi, Jaehyuk;Kim, Seong-Jin;', 'journal': 'Institute of Electrical and Electronics Engineers Inc.', 'issue_inst': 'Ulsan National Institute of Science and Technology, Ulsan, South Korea; SolidVue, Suwon, South Korea; Sungkyunkwan University, Suwon, South Korea', 'issue_year': '2022', 'issue_lang': 'English', 'start_page': '98', 'end_page': '100', 'paper_keyword': '', 'abstract': 'Light detection and ranging (LiDAR) sensors have become one of the key building blocks to realize metaverse applications with VR/AR in mobile devices and level-5 automotive vehicles. In particular, SPAD-based direct time-of-flight (D-ToF) sensors have emerged as LiDAR sensors because they offer a longer maximum detectable range and higher background light immunity than indirect time-of-flight (I-ToF) sensors with photon-mixing devices [1]. However, their complicated front- and back-end blocks to resolve ToF values as short as 100ps require high-resolution TDCs and several memories, limiting the spatial resolution and the depth accuracy in short ranges. To address this issue, alternative architectures combining both D-ToF and I-ToF techniques have been reported [2, 3]. Direct-indirect-mixed frame synthesis provides accurate depth information by detecting phases in short ranges while creating a sparse depth map with counting photons in long ranges [2]. A two-step histogramming TDC is used in [3] where a coarse D-ToF discriminates distance roughly and a fine I-ToF extracts depth precisely. However, these approaches still suffer from limited depth accuracy [2] or low spatial resolution [3]. © 2022 IEEE.', 'author_inst': 'Ulsan National Institute of Science and Technology Ulsan South Korea;Ulsan National Institute of Science and Technology Ulsan South Korea;SolidVue Suwon South Korea;SolidVue Suwon South Korea Sungkyunkwan University Suwon South Korea;SolidVue Suwon South Korea Sungkyunkwan University Suwon South Korea;Ulsan National Institute of Science and Technology Ulsan South Korea;', 'author_id': '57222346070;57203861712;57578047100;7202588598;56815901900;57070769200', 'citation': 0, 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85128296371&doi=10.1109%2fISSCC42614.2022.9731112&partnerID=40&md5=4a032050b61fb7bbcef4dd2071d870e3', 'source_title': 'Digest of Technical Papers - IEEE International Solid-State Circuits Conference', 'index_keywords': 'Graphic methods; Image resolution; Light; Photons; Signal detection; Background light; Detection sensors; Flash light; Histogramming; Indirect time of flights; Light detection and ranging; Ranging sensors; Spatial resolution; Time-of flight; Time-of-flight sensor; Optical radar', 'funding_details': '20015989;\xa0Ministry of Trade, Industry and Energy,\xa0MOTIE', 'correspondence_address': '', 'editors': '', 'funding_text_1': 'This work was supported in part by NRF-2021R1A2C2012045 funded by the Ministry of Science and ICT & Future Planning (MSIT, Korea), and in part by the K-Fabless Program (No. 20015989) funded by the Ministry of Trade, Industry and Energy (MOTIE, Korea).', 'funding_text_2': '', 'funding_text_3': '', 'funding_text_4': '', 'funding_text_5': '', 'funding_text_6': '', 'funding_text_7': '', 'funding_text_8': '', 'funding_text_9': '', 'funding_text_10': '', 'publisher': 'Institute of Electrical and Electronics Engineers Inc.', 'ISSN': '01936530', 'abbreviated_source_title': 'Dig Tech Pap IEEE Int Solid State Circuits Conf', 'document_type': 'Conference Paper', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.7668393782383419, 'originalName': 'ULSAN NATIONAL INSTITUTE OF SCIENCE AND T ...
# joc: 0 | yop: 2021, 2022 | co_author_count: 1 | keyword: ['Experience', ' Gameful experience', ' Gamification', ' Human–computer interface', ' Metaverse'], [''] | journal1: MDPI | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Kim, Sangkyun | inst1: Department of Industrial Engineering Kangwon National University Chuncheon 24341 South Korea | title1: Differences in learning motivation among bartle’s player types and measures for the delivery of sustainable gameful experiences | site1: SCOPUS
# name2: Kim, Seong-Jin | inst2: Ulsan National Institute of Science and Technology Ulsan South Korea | title2: An 80×60 Flash LiDAR Sensor with In-Pixel Histogramming TDC Based on Quaternary Search and Time-Gated Δ-Intensity Phase Detection for 45m Detectable Range and Background Light Cancellation | site1: SCOPUS
# inst: 0.6892867291844275 | title: 0.6969173103178683 | email: 0, funding: 0
# weigth: 1.466060279414279
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8666666666666667
# {'_id': ObjectId('626b50d13247eaee55f8ab82'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85083724716', 'title': 'Application of Metaverses as an Evaluation Tool in the Baccalaureate', 'author': 'Alvaro-Farfan A.;Sánchez-Guerrero, Javier;Gavilanes-Lopez W.;Santiago-Chávez N.;', 'journal': 'Springer', 'issue_inst': 'Educational Informatics, Technical University of Ambato, Ambato, Ecuador; Facultad de Ciencias Humanas y de la Educación, Universidad Técnica de Ambato, Ambato, Ecuador; Universidad Técnica de Ambato, Ambato, Ecuador', 'issue_year': '2020', 'issue_lang': 'English', 'start_page': '598', 'end_page': '606', 'paper_keyword': 'Education; Evaluation; Metaverse; OpenSim; Sloodle', 'abstract': 'Based on the technological development and the possibility to take advance of the capabilities that it offers on education, the purpose of this article is to study the usage of virtual worlds (Metaverses) as evaluational tool on students cursing the unified general bachelorship, appraisal applied to the third-year pupils at (Unidad Educativa Santa Mariana de Jesús) in the subjects of Mathematics, Language-Literature, and Chemistry, considering the stratified groups with parallels A, B, and C, performing the evaluations in the classroom, as well in the Metaverse, through a theoretical conceptualization of the main aspects and the creation of a virtual world in “OpenSim” with its own server both for the Metaverse and for “Moodle” and its connection with “Sloodle”, in this way contributing with statistical data on the obtained results. © 2020, Springer Nature Switzerland AG.', 'author_inst': 'Educational Informatics Technical University of Ambato Ambato Ecuador;Facultad de Ciencias Humanas y de la Educación Universidad Técnica de Ambato Ambato Ecuador;Facultad de Ciencias Humanas y de la Educación Universidad Técnica de Ambato Ambato Ecuador;Universidad Técnica de Ambato Ambato Ecuador;', 'author_id': '57216510924;57211085336;57215925818;57216502116', 'citation': 0, 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85083724716&doi=10.1007%2f978-3-030-40271-6_59&partnerID=40&md5=45e8702eccfa659357c95d33231f5d5a', 'source_title': 'Advances in Intelligent Systems and Computing', 'index_keywords': 'Interactive computer graphics; Students; Virtual reality; Evaluation tool; Metaverses; OpenSim; Statistical datas; Technological development; Virtual worlds; C (programming language)', 'funding_details': '', 'correspondence_address': 'Sánchez-Guerrero, J.; Facultad de Ciencias Humanas y de la Educación, Ecuador; email: jsanchez@uta.edu.ec', 'editors': 'Auer M.E.Hortsch H.Sethakul P.', 'funding_text_1': '', 'funding_text_2': '', 'publisher': 'Springer', 'ISSN': '21945357', 'abbreviated_source_title': 'Adv. Intell. Sys. Comput.', 'document_type': 'Conference Paper', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.5595854922279793, 'originalName': 'EDUCATIONAL INFORMATICS TECHNICAL UNIVERSITY OF AMBATO AMBATO ECUADOR;FACULTAD DE CIENCIAS HUMANAS Y DE LA EDUCACIÓN UNIVERSIDAD TÉCNICA DE AMBATO AMBATO ECUADOR;FACULTAD DE CIENCIAS HUMANAS Y DE LA EDUCACIÓN UNIVERSIDAD TÉCNICA DE AMBATO AMBATO ECUADOR;UNIVERSIDAD TÉCNICA DE AMBATO AMBATO ECUADOR;', 'mngId': '57216502116', 'site': 'SCOPUS'}
# {'_id': ObjectId('626b50cd3247eaee55f8ab7b'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85101770499', 'title': 'The machinima Entrevista de trabajo / Entretien d’embauche : a digital resource for learning French in a university context [La machinima Entrevista de trabajo / Entretien d’embauche : une ressource numérique pour l’apprentissage de la langue française en contexte universitaire', 'author': 'Baynat Monreal, Ma Elena;Santiago M.L.;', 'journal': 'GERFLINT', 'issue_inst': 'Faculté d’Économie, Département de Philologie Française et Italienne, Iulma-Universitat de València, Universitat de València; École Technique Supérieure d’Architecture, Département de Linguistique Appliquée, Universitat Politècnica de València', 'issue_year': '2020', 'issue_lang': 'French', 'start_page': '163', 'end_page': '179', 'paper_keyword': ': teaching languages; French as a Foreign Language; Machinima; Second Life', 'abstract': 'A machinima is a video made in a virtual world or metaverse, in which avatars (virtual characters who represent the users of this world) play different roles. This article presents the machinima entitled Entrevista de trabajo/Entretien d’embauche, which was created in the Second Life metaverse to simulate a professional situation in the touristic domain. This machinima was designed to be used with French students in a university context. After a brief theoretical introduction, this study presents examples of didactic exploitation which show that learning with digital resources is motivating for students because they are, in fact, closer to their daily lives, all imbued with technology. © 2020 GERFLINT. All rights reserved.', 'author_inst': 'Faculté d’Économie Département de Philologie Française et Italienne Iulma-Universitat de València Universitat de València;École Technique Supérieure d’Architecture Département de Linguistique Appliquée Universitat Politècnica de València;', 'author_id': '55560647400;57210733342', 'citation': '1', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85101770499&partnerID=40&md5=5317fc9bbcd696e94c9a6b6d24ba4af9', 'source_title': 'Synergies Europe', 'index_keywords': '', 'funding_details': '', 'correspondence_address': '', 'editors': '', 'funding_text_1': '', 'funding_text_2': '', 'publisher': 'GERFLINT', 'ISSN': '19516088', 'abbreviated_source_title': 'Synergies Eur.', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.5233160621761658, 'originalName': 'FACULTÉ D’ÉCONOMIE DÉPARTEMENT DE PHILOLOGIE FRANÇAISE ET ITALIENNE IULMA-UNIVERSITAT DE VALÈNCIA UNIVERSITAT DE VALÈNCIA;ÉCOLE TECHNIQUE SUPÉRIEURE D’ARCHITECTURE DÉPARTEMENT DE LINGUISTIQUE APPLIQUÉE UNIVERSITAT POLITÈCNICA DE VALÈNCIA;', 'mngId': '57210733342', 'site': 'SCOPUS'}
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Education', ' Evaluation', ' Metaverse', ' OpenSim', ' Sloodle'], [': teaching languages', ' French as a Foreign Language', ' Machinima', ' Second Life'] | journal1: Springer | journal2: GERFLINT
# name1: Santiago-Chávez N. | inst1: Universidad Técnica de Ambato Ambato Ecuador | title1: Application of Metaverses as an Evaluation Tool in the Baccalaureate | site1: SCOPUS
# name2: Santiago M.L. | inst2: École Technique Supérieure d’Architecture Département de Linguistique Appliquée Universitat Politècnica de València | title2: The machinima Entrevista de trabajo / Entretien d’embauche : a digital resource for learning French in a university context [La machinima Entrevista de trabajo / Entretien d’embauche : une ressource numérique pour l’apprentissage de la langue française en contexte universitaire | site1: SCOPUS
# inst: 0.5290046325810702 | title: 0.5811804854758728 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8400000000000001
# {'_id': ObjectId('626b50cd3247eaee55f8ab76'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85091779889', 'title': 'Virtual Reality Church as a New Mission Frontier in the Metaverse: Exploring Theological Controversies and Missional Potential of Virtual Reality Church', 'author': 'Jun, Guichun;', 'journal': 'SAGE Publications Ltd', 'issue_inst': 'Oxford Centre for Mission Studies, Oxford, United Kingdom', 'issue_year': '2020', 'issue_lang': 'English', 'start_page': '297', 'end_page': '305', 'paper_keyword': 'Church 4.0; Church and media; Church’s mission in the metaverse; Cybersociality and future church; Ecclesial nature of virtual reality church; Ecclesiastical practices of virtual reality church; Future mission of the church in the digital age; Mission for digital natives; Virtual reality church', 'abstract': 'The combination of COVID-19 and the Fourth Industrial Revolution has brought an unprecedented new normal, which has affected all aspects of human life, including religious activities. As a consequence, church mission and different ministries have found themselves more dependent on media. Furthermore, the convergent digital technology continually develops augmented reality and virtual reality, in which churches are planted and continue to carry out their mission and ministries. Although virtual reality churches are new mission frontiers in the digital age, there are several theological issues from the conventional perspective of church ministry and mission. This paper aims to address the controversial theological issues and reflect on them from an ecclesiological perspective to explore a theological possibility to overcome the issues and to justify their mission and ministries in virtual reality. © The Author(s) 2020.', 'author_inst': 'Oxford Centre for Mission Studies Oxford United Kingdom;', 'author_id': '57201548314', 'citation': '1', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85091779889&doi=10.1177%2f0265378820963155&partnerID=40&md5=32bf4bb1a4f9a12474a6aab2aae90eec', 'source_title': 'Transformation', 'index_keywords': '', 'funding_details': '', 'correspondence_address': 'Jun, G.; Oxford Centre for Mission StudiesUnited Kingdom; email: gjun@ocms.ac.uk', 'editors': '', 'funding_text_1': '', 'funding_text_2': '', 'publisher': 'SAGE Publications Ltd', 'ISSN': '02653788', 'abbreviated_source_title': 'Transformation', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.49740932642487046, 'originalName': 'OXFORD CENTRE FOR MISSION STUDIES OXFORD UNITED KINGDOM;', 'mngId': '57201548314', 'site': 'SCOPUS'}
# {'_id': ObjectId('626b50cd3247eaee55f8ab56'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85121115636', 'title': 'Clustering-based plane segmentation neural network for urban scene modeling', 'author': 'Lee H.;Jung J.;', 'journal': 'MDPI', 'issue_inst': 'Department of Electronic Engineering, Kyung Hee University, Yongin-si, 17104, South Korea; Department of Artificial Intelligence, University of Seoul, Seoul, 02504, South Korea', 'issue_year': '2021', 'issue_lang': 'English', 'start_page': 0, 'end_page': 0, 'paper_keyword': '3D point clustering; 3D segmentation; Point cloud plane extraction; Urban mapping', 'abstract': 'Urban scene modeling is a challenging but essential task for various applications, such as 3D map generation, city digitization, and AR/VR/metaverse applications. To model man-made structures, such as roads and buildings, which are the major components in general urban scenes, we present a clustering-based plane segmentation neural network using 3D point clouds, called hybrid K-means plane segmentation (HKPS). The proposed method segments unorganized 3D point clouds into planes by training the neural network to estimate the appropriate number of planes in the point cloud based on hybrid K-means clustering. We consider both the Euclidean distance and cosine distance to cluster nearby points in the same direction for better plane segmentation results. Our network does not require any labeled information for training. We evaluated the proposed method using the Virtual KITTI dataset and showed that our method outperforms conventional methods in plane segmentation. Our code is publicly available. © 2021 by the authors. Licensee MDPI, Basel, Switzerland.', 'author_inst': 'Department of Electronic Engineering Kyung Hee University Yongin-si 17104 South Korea;Department of Artificial Intelligence University of Seoul Seoul 02504 South Korea;', 'author_id': '57371756700;57371451200', 'citation': 0, 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85121115636&doi=10.3390%2fs21248382&partnerID=40&md5=b84caa95992c6f61b20f4925f425d3a7', 'source_title': 'Sensors', 'index_keywords': '3D modeling; K-means clustering; 3d point clustering; 3D segmentation; Clusterings; Neural-networks; Plane segmentation; Point cloud plane extraction; Point-clouds; Scene model; Urban mapping; Urban scenes; Three dimensional computer graphics; cluster analysis; human; Cluster Analysis; Humans; Neural Networks, Computer', 'funding_details': 'National Research Foundation of Korea,\xa0NRF: NRF-2020R1C1C1008726', 'correspondence_address': 'Jung, J.; Department of Artificial Intelligence, South Korea; email: jyjung@uos.ac.kr', 'editors': '', 'funding_text_1': 'Funding: This work was supported by a grant from National Research Foundation of Korea (NRF-2020R1C1C1008726).', 'funding_text_2': '', 'publisher': 'MDPI', 'ISSN': '14248220', 'abbreviated_source_title': 'Sensors', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.3316062176165803, 'originalName': 'DEPARTMENT OF ELECTRONIC ENGINEERING KYUNG HEE UNIVERSITY YONGIN-SI 17104 SOUTH KOREA;DEPARTMENT OF ARTIFICIAL INTELLIGENCE UNIVERSITY OF SEOUL SEOUL 02504 SOUTH KOREA;', 'mngId': '57371451200', 'site': 'SCOPUS'}
# joc: 0 | yop: 2020, 2021 | co_author_count: 0 | keyword: ['Church 4.0', ' Church and media', ' Church’s mission in the metaverse', ' Cybersociality and future church', ' Ecclesial nature of virtual reality church', ' Ecclesiastical practices of virtual reality church', ' Future mission of the church in the digital age', ' Mission for digital natives', ' Virtual reality church'], ['3D point clustering', ' 3D segmentation', ' Point cloud plane extraction', ' Urban mapping'] | journal1: SAGE Publications Ltd | journal2: MDPI
# name1: Jun, Guichun | inst1: Oxford Centre for Mission Studies Oxford United Kingdom | title1: Virtual Reality Church as a New Mission Frontier in the Metaverse: Exploring Theological Controversies and Missional Potential of Virtual Reality Church | site1: SCOPUS
# name2: Jung J. | inst2: Department of Artificial Intelligence University of Seoul Seoul 02504 South Korea | title2: Clustering-based plane segmentation neural network for urban scene modeling | site1: SCOPUS
# inst: 0.5820332959221849 | title: 0.6327175782593738 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8290909090909091
# {'_id': ObjectId('626b50d13247eaee55f8ab97'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85123777406', 'title': 'What is augmented reality marketing? Its definition, complexity, and future', 'author': 'Rauschnabel, Philipp A.;Babin B.J.;tom Dieck, M. Claudia;Krey N.;Jung, Timothy;', 'journal': 'Elsevier Inc.', 'issue_inst': 'Universität der Bundeswehr München, College of Business Administration, Department of Digital Marketing and Media Innovation, Werner-Heisenberg-Weg 39, Neubiberg, 85577, Germany; University of Mississippi, Department of Marketing, Morris Lewis Professor Marketing and Chair, UniversityMS  38655, United States; Manchester Metropolitan University, Faculty of Business and Law, Department of Operations, Technology, Events and Hospitality Management, All Saints Campus, Manchester, M15 6BH, United Kingdom; Rowan University, Rohrer College of Business, Department of Marketing and Business Information Systems, 201 Mullica Hill Road, Glassboro, NJ  08028, United States; MCI - Management Center Innsbruck, Universitätsstraße 15, Innsbruck, 6020, Austria; Otto-Friedrich-Universität Bamberg, Social Sciences, Economics, and Business Administration, Kapuzinerstraße 16 96047 Bamberg, Germany', 'issue_year': '2022', 'issue_lang': 'English', 'start_page': '1140', 'end_page': '1150', 'paper_keyword': 'AR Marketing; Augmented Reality; Augmented Reality Marketing; Definition; Framework; Metaverse; Special issue', 'abstract': 'Augmented Reality (AR) has received increased attention over the last years, both from managers and scholars alike. Various studies in the marketing discipline have tackled fragmented aspects of AR, such as its impact on sales or brands. Yet, a holistic approach to AR remains scarce. Therefore, the authors define “Augmented Reality Marketing” as a novel, strategic, and potentially disruptive subdiscipline in marketing. In conjunction, they discuss a nuanced customer journey model for AR Marketing strategy and propose the BICK FOUR framework (branding, inspiring, convincing, and keeping) as a tool to organize corresponding goals. Another contribution is the introduction of several fundamental differences between AR Marketing and traditional digital marketing concepts, such as redefining the reality concept (reduced reality, normal reality, and augmented reality in a metaverse context). Insights from 127 managers further enhance the current and future practices of AR Marketing. Finally, a discussion of ethical and legal considerations completes the assessment. © 2022 Elsevier Inc.', 'author_inst': 'Universität der Bundeswehr München College of Business Administration Department of Digital Marketing and Media Innovation Werner-Heisenberg-Weg 39 Neubiberg 85577 Germany MCI - Management Center Innsbruck Universitätsstraße 15 Innsbruck 6020 Austria Otto-Friedrich-Universität Bamberg Social Sciences Economics and Business Administration Kapuzinerstraße 16 96047 Bamberg Germany;University of Mississippi Department of Marketing Morris Lewis Professor Marketing and Chair UniversityMS  38655 United States;Manchester Metropolitan University Faculty of Business and Law Department of Operations Technology Events and Hospitality Management All Saints Campus Manchester M15 6BH United Kingdom;Rowan University Rohrer College of Business Department of Marketing and Business Information Systems 201 Mullica Hill Road Glassboro NJ  08028 United States;Manchester Metropolitan University Faculty of Business and Law Department of Operations Technology Events and Hospitality Management All Saints Campus Manchester M15 6BH United Kingdom;', 'author_id': '56341892200;7003971248;56764475300;57118047900;55515556300', 'citation': '4', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85123777406&doi=10.1016%2fj.jbusres.2021.12.084&partnerID=40&md5=9d7a98b29215c2958bbc84de893d6e4d', 'source_title': 'Journal of Business Research', 'index_keywords': '', 'funding_details': '', 'correspondence_address': 'R ...
# {'_id': ObjectId('626b50cd3247eaee55f8ab76'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85091779889', 'title': 'Virtual Reality Church as a New Mission Frontier in the Metaverse: Exploring Theological Controversies and Missional Potential of Virtual Reality Church', 'author': 'Jun, Guichun;', 'journal': 'SAGE Publications Ltd', 'issue_inst': 'Oxford Centre for Mission Studies, Oxford, United Kingdom', 'issue_year': '2020', 'issue_lang': 'English', 'start_page': '297', 'end_page': '305', 'paper_keyword': 'Church 4.0; Church and media; Church’s mission in the metaverse; Cybersociality and future church; Ecclesial nature of virtual reality church; Ecclesiastical practices of virtual reality church; Future mission of the church in the digital age; Mission for digital natives; Virtual reality church', 'abstract': 'The combination of COVID-19 and the Fourth Industrial Revolution has brought an unprecedented new normal, which has affected all aspects of human life, including religious activities. As a consequence, church mission and different ministries have found themselves more dependent on media. Furthermore, the convergent digital technology continually develops augmented reality and virtual reality, in which churches are planted and continue to carry out their mission and ministries. Although virtual reality churches are new mission frontiers in the digital age, there are several theological issues from the conventional perspective of church ministry and mission. This paper aims to address the controversial theological issues and reflect on them from an ecclesiological perspective to explore a theological possibility to overcome the issues and to justify their mission and ministries in virtual reality. © The Author(s) 2020.', 'author_inst': 'Oxford Centre for Mission Studies Oxford United Kingdom;', 'author_id': '57201548314', 'citation': '1', 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85091779889&doi=10.1177%2f0265378820963155&partnerID=40&md5=32bf4bb1a4f9a12474a6aab2aae90eec', 'source_title': 'Transformation', 'index_keywords': '', 'funding_details': '', 'correspondence_address': 'Jun, G.; Oxford Centre for Mission StudiesUnited Kingdom; email: gjun@ocms.ac.uk', 'editors': '', 'funding_text_1': '', 'funding_text_2': '', 'publisher': 'SAGE Publications Ltd', 'ISSN': '02653788', 'abbreviated_source_title': 'Transformation', 'document_type': 'Article', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.49740932642487046, 'originalName': 'OXFORD CENTRE FOR MISSION STUDIES OXFORD UNITED KINGDOM;', 'mngId': '57201548314', 'site': 'SCOPUS'}
# joc: 0 | yop: 2022, 2020 | co_author_count: 0 | keyword: ['AR Marketing', ' Augmented Reality', ' Augmented Reality Marketing', ' Definition', ' Framework', ' Metaverse', ' Special issue'], ['Church 4.0', ' Church and media', ' Church’s mission in the metaverse', ' Cybersociality and future church', ' Ecclesial nature of virtual reality church', ' Ecclesiastical practices of virtual reality church', ' Future mission of the church in the digital age', ' Mission for digital natives', ' Virtual reality church'] | journal1: Elsevier Inc. | journal2: SAGE Publications Ltd
# name1: Jung, Timothy | inst1: Manchester Metropolitan University Faculty of Business and Law Department of Operations Technology Events and Hospitality Management All Saints Campus Manchester M15 6BH United Kingdom | title1: What is augmented reality marketing? Its definition, complexity, and future | site1: SCOPUS
# name2: Jun, Guichun | inst2: Oxford Centre for Mission Studies Oxford United Kingdom | title2: Virtual Reality Church as a New Mission Frontier in the Metaverse: Exploring Theological Controversies and Missional Potential of Virtual Reality Church | site1: SCOPUS
# inst: 0.5320267896354852 | title: 0.6278156174750601 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8666666666666667
# ...
# 0.8630952380952381
# {'_id': ObjectId('626b50d13247eaee55f8ab9c'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85124796302', 'title': 'Optical design and pupil swim analysis of a compact, large EPD and immersive VR head mounted display', 'author': 'Cheng, Dewen;Hou Q.;Li, Yang;Zhang T.;Li D.;Huang Y.;Liu Y.;Wang, Qiwei;Hou W.;Yang T.;Feng, Zexin;Wang, Yongtian;', 'journal': 'The Optical Society', 'issue_inst': 'Beijing Engineering Research Center of Mixed Reality and Advanced Display, School of Optics and Photonics, Beijing Institute of Technology, Beijing, 100081, China; Beijing Ned ltd., Beijing, 100081, China', 'issue_year': '2022', 'issue_lang': 'English', 'start_page': '6584', 'end_page': '6602', 'paper_keyword': '', 'abstract': 'Virtual reality head-mounted displays (VR-HMDs) are crucial to Metaverse which appears to be one of the most popular terms to have been adopted over the internet recently. It provides basic infrastructure and entrance to cater for the next evolution of social interaction, and it has already been widely used in many fields. The VR-HMDs with traditional aspherical or Fresnel optics are not suitable for long-term usage because of the image quality, system size, and weight. In this study, we designed and developed a large exit pupil diameter (EPD), compact, and lightweight VR-HMD with catadioptric optics. The mathematical formula for designing the catadioptric VR optics is derived. The reason why this kind of immersive VR optics could achieve a compact size and large EPD simultaneously is answered. Various catadioptric forms are systematically proposed and compared. The design can achieve a diagonal field of view (FOV) of 96° at -1 diopter, with an EPD of 10 mm at 11 mm eye relief (ERF). The overall length (OAL) of the system was less than 20 mm. A prototype of a compact catadioptric VR-HMD system was successfully developed. © 2022 Optica Publishing Group under the terms of the Optica Open Access Publishing Agreement', 'author_inst': 'Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China Beijing Ned ltd. Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Ned ltd. Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;', 'author_id': '25649167600;56893180100;55719242100;57457175800;57410158800;57457115400;57330064800;56449634100;57202745193;57197379776;36081722700;55733996800', 'citation': 0, 'link': ' ...
# {'_id': ObjectId('626b50cd3247eaee55f8ab67'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85123179221', 'title': 'MetaHuman Creator the starting point of the metaverse', 'author': 'Fang Z.;Cai, Libai;Wang, Gang;', 'journal': 'Institute of Electrical and Electronics Engineers Inc.', 'issue_inst': 'School of Humanities and Journalism Xiamen University Tan Kah Kee College, Xiamen, China; Computer Engineering College Jimei University, Xiamen, China', 'issue_year': '2021', 'issue_lang': 'English', 'start_page': '154', 'end_page': '157', 'paper_keyword': 'component; Epic games; MetaHuman Creator; Metaverse; realtime 3D content', 'abstract': 'February 11, 2021, Epic Games revealed a first look at MetaHuman Creator, a new browser-based app that will empower anyone to create a bespoke photorealistic digital human, fully rigged and complete with hair and clothing, in a matter of minutes. Metahuman Creator makes the digital avatars through an intuitive workflow, which means the Cyborg era is on the horizon. © 2021 IEEE.', 'author_inst': 'School of Humanities and Journalism Xiamen University Tan Kah Kee College Xiamen China;Computer Engineering College Jimei University Xiamen China;Computer Engineering College Jimei University Xiamen China;', 'author_id': '57221928345;57221933558;55628590624', 'citation': 0, 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85123179221&doi=10.1109%2fISCTIS51085.2021.00040&partnerID=40&md5=937521a40d8376ce091e559bfa9b1167', 'source_title': 'Proceedings - 2021 International Symposium on Computer Technology and Information Science, ISCTIS 2021', 'index_keywords': '3D content; Component; Digital humans; Epic game; First look; Metahuman creator; Metaverses; Photo-realistic; Real- time; Realtime 3d content', 'funding_details': 'Department of Education, Fujian Province: 20XSH007,\xa0JAT200917', 'correspondence_address': '', 'editors': '', 'funding_text_1': 'The work of this paper is sponsored by Innovation Strategy Research Project of Fujian Province, (Project No.2020R0066) & Young and Middle-aged Teacher Education Research Project of Fujian Education Department (Project No. : JAT200917) & National Social Science Project in the West of China in 2020: Research on the Policy Effect and Promotion Strategy of Poverty Alleviation through Education for Rural Poor Women (Project No. 20XSH007)', 'funding_text_2': '', 'publisher': 'Institute of Electrical and Electronics Engineers Inc.', 'ISSN': '', 'abbreviated_source_title': 'Proc. - Int. Symp. Comput. Technol. Inf. Sci., ISCTIS', 'document_type': 'Conference Paper', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.41968911917098445, 'originalName': 'SCHOOL OF HUMANITIES AND JOURNALISM XIAMEN UNIVERSITY TAN KAH KEE COLLEGE XIAMEN CHINA;COMPUTER ENGINEERING COLLEGE JIMEI UNIVERSITY XIAMEN CHINA;COMPUTER ENGINEERING COLLEGE JIMEI UNIVERSITY XIAMEN CHINA;', 'mngId': '55628590624', 'site': 'SCOPUS'}
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: [''], ['component', ' Epic games', ' MetaHuman Creator', ' Metaverse', ' realtime 3D content'] | journal1: The Optical Society | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Wang, Yongtian | inst1: Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China | title1: Optical design and pupil swim analysis of a compact, large EPD and immersive VR head mounted display | site1: SCOPUS
# name2: Wang, Gang | inst2: Computer Engineering College Jimei University Xiamen China | title2: MetaHuman Creator the starting point of the metaverse | site1: SCOPUS
# inst: 0.5557111928891917 | title: 0.6256114605171209 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8833333333333334
# {'_id': ObjectId('626b50d13247eaee55f8ab9c'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85124796302', 'title': 'Optical design and pupil swim analysis of a compact, large EPD and immersive VR head mounted display', 'author': 'Cheng, Dewen;Hou Q.;Li, Yang;Zhang T.;Li D.;Huang Y.;Liu Y.;Wang, Qiwei;Hou W.;Yang T.;Feng, Zexin;Wang, Yongtian;', 'journal': 'The Optical Society', 'issue_inst': 'Beijing Engineering Research Center of Mixed Reality and Advanced Display, School of Optics and Photonics, Beijing Institute of Technology, Beijing, 100081, China; Beijing Ned ltd., Beijing, 100081, China', 'issue_year': '2022', 'issue_lang': 'English', 'start_page': '6584', 'end_page': '6602', 'paper_keyword': '', 'abstract': 'Virtual reality head-mounted displays (VR-HMDs) are crucial to Metaverse which appears to be one of the most popular terms to have been adopted over the internet recently. It provides basic infrastructure and entrance to cater for the next evolution of social interaction, and it has already been widely used in many fields. The VR-HMDs with traditional aspherical or Fresnel optics are not suitable for long-term usage because of the image quality, system size, and weight. In this study, we designed and developed a large exit pupil diameter (EPD), compact, and lightweight VR-HMD with catadioptric optics. The mathematical formula for designing the catadioptric VR optics is derived. The reason why this kind of immersive VR optics could achieve a compact size and large EPD simultaneously is answered. Various catadioptric forms are systematically proposed and compared. The design can achieve a diagonal field of view (FOV) of 96° at -1 diopter, with an EPD of 10 mm at 11 mm eye relief (ERF). The overall length (OAL) of the system was less than 20 mm. A prototype of a compact catadioptric VR-HMD system was successfully developed. © 2022 Optica Publishing Group under the terms of the Optica Open Access Publishing Agreement', 'author_inst': 'Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China Beijing Ned ltd. Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Ned ltd. Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China;', 'author_id': '25649167600;56893180100;55719242100;57457175800;57410158800;57457115400;57330064800;56449634100;57202745193;57197379776;36081722700;55733996800', 'citation': 0, 'link': ' ...
# {'_id': ObjectId('626b50d13247eaee55f8ab8a'), 'english_title': '', 'english_abstract': '', 'isPartial': 0, 'id': '85128474853', 'title': 'A Preliminary Frame of Improved TCP/IP Model for Metaverse Networks', 'author': 'Zhu, Weijun;Liang X.;Chen M.;Wang Y.;', 'journal': 'IOP Publishing Ltd', 'issue_inst': 'School of Information Engineering, Zhengzhou University, Zhengzhou, China; School of Network Engineering, Zhoukou Normal University, Zhoukou, China', 'issue_year': '2022', 'issue_lang': 'English', 'start_page': 0, 'end_page': 0, 'paper_keyword': '', 'abstract': 'It is well known that internet will play a key role to the infrastructure of metaverse, while different immerging virtual worlds communicate with each other. However, the existing TCP/IP model is not suitable enough for metaverse networks. To this end, we explore a preliminary frame of revised TCP/IP model. At first, a new layer called metaverse layer is defined. And then, this layer is placed as the top layer, i.e., the upper of the application layer in TCP/IP model. As a result, a novel network model having the six layers is obtained. Our simulated experiments indicate the feasibility of the new model. © Published under licence by IOP Publishing Ltd.', 'author_inst': 'School of Information Engineering Zhengzhou University Zhengzhou China;School of Network Engineering Zhoukou Normal University Zhoukou China;School of Network Engineering Zhoukou Normal University Zhoukou China;School of Network Engineering Zhoukou Normal University Zhoukou China;', 'author_id': '24451545700;57581083000;57580692500;57581177900', 'citation': 0, 'link': 'https://www.scopus.com/inward/record.uri?eid=2-s2.0-85128474853&doi=10.1088%2f1742-6596%2f2216%2f1%2f012109&partnerID=40&md5=c12ded604449eb590160670a98dad3f5', 'source_title': 'Journal of Physics: Conference Series', 'index_keywords': 'Virtual reality; Application layers; Internet wills; IP models; Metaverses; Network models; Simulated experiments; Top layers; Virtual worlds; Transmission control protocol', 'funding_details': 'National Natural Science Foundation of China,\xa0NSFC: U1204608', 'correspondence_address': '', 'editors': '', 'funding_text_1': 'This study has been supported by National Natural Science Foundation of China under grant No. U1204608.', 'funding_text_2': '', 'funding_text_3': '', 'funding_text_4': '', 'funding_text_5': '', 'funding_text_6': '', 'funding_text_7': '', 'funding_text_8': '', 'funding_text_9': '', 'funding_text_10': '', 'publisher': 'IOP Publishing Ltd', 'ISSN': '17426588', 'abbreviated_source_title': 'J. Phys. Conf. Ser.', 'document_type': 'Conference Paper', 'publication_stage': 'Final', 'source': 'Scopus', 'keyId': 805, 'progress': 0.6010362694300518, 'originalName': 'SCHOOL OF INFORMATION ENGINEERING ZHENGZHOU UNIVERSITY ZHENGZHOU CHINA;SCHOOL OF NETWORK ENGINEERING ZHOUKOU NORMAL UNIVERSITY ZHOUKOU CHINA;SCHOOL OF NETWORK ENGINEERING ZHOUKOU NORMAL UNIVERSITY ZHOUKOU CHINA;SCHOOL OF NETWORK ENGINEERING ZHOUKOU NORMAL UNIVERSITY ZHOUKOU CHINA;', 'mngId': '57581177900', 'site': 'SCOPUS'}
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: [''], [''] | journal1: The Optical Society | journal2: IOP Publishing Ltd
# name1: Wang, Yongtian | inst1: Beijing Engineering Research Center of Mixed Reality and Advanced Display School of Optics and Photonics Beijing Institute of Technology Beijing 100081 China | title1: Optical design and pupil swim analysis of a compact, large EPD and immersive VR head mounted display | site1: SCOPUS
# name2: Wang Y. | inst2: School of Network Engineering Zhoukou Normal University Zhoukou China | title2: A Preliminary Frame of Improved TCP/IP Model for Metaverse Networks | site1: SCOPUS
# inst: 0.5545315924250661 | title: 0.6665645456925896 | email: 0, funding: 0
# weigth: 1.6321205588285577
# ------------------------------------------------------------구분선------------------------------------------------------------
# []
# 2
# 50

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name):
    global answer, numCor, numErr, answerCounter, numInteErr # answer = json, numCor = 정답 수, numErr = 오답 수, answerCounter = 정답수, numInteErr = 통합에러
    flag = True

    numK = len(result.keys()) #Answer_dict key 개수
    if numK-5 != len(answer[name].keys()):
        flag = False
    else :
        for site in result.keys():
            if site != 'name' and site != 'fid' and site != 'keyId' and site != 'inst' and site != 'pre_name':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 5:
                        if answer[name][site] != result[site]['inst']:
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag:
        numCor += 1
        answerCounter[name] += 1
    else:
        if len(answer[name].keys()) > 1:
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {name} {answer[name]}\n - Result : {result}")
        else:
            pass
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json:

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:        
        name = Answer_dict[answer_one]['name'].split('_')[0]

        if name in answer :
            ansCheck(Answer_dict[answer_one], name)

        else :
            count = 0
            while name+'_'+str(count) in answer :
                if ansCheck(Answer_dict[answer_one], name+'_'+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

    print("토탈앤써", answercount)
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    print(keyid)
    
print(sorted(Answer_dict.items()))
# Out:
# 163
# num코렉트 163
# numEror 0
# numInteEror 0
# 토탈앤써 163
# 토탈인터그레이션 2
# --------------------------------
# 토탈에러 0
# 토탈인터그레이션에러 0
# 805
# [('abosagibrahim', {'fid': 0, 'keyId': 805, 'name': 'Abosag, Ibrahim', 'pre_name': 'abosagibrahim', 'inst': 'Manchester Business School Manchester United Kingdom', 'SCOPUS': {'inst': 'Manchester Business School Manchester United Kingdom', 'A_id': ['36080354900'], 'papers': [ObjectId('626b50c93247eaee55f8ab19')], 'oriInst': 'Manchester Business School Manchester United Kingdom'}}), ('abrashm', {'fid': 0, 'keyId': 805, 'name': 'Abrash M.', 'pre_name': 'abrashm', 'inst': 'Facebook Reality Labs Research Redmond WA United States', 'SCOPUS': {'inst': 'Facebook Reality Labs Research Redmond WA United States', 'A_id': ['7801527629'], 'papers': [ObjectId('626b50cd3247eaee55f8ab63')], 'oriInst': 'Facebook Reality Labs Research Redmond WA United States'}}), ('abriatalucianoandres', {'fid': 0, 'keyId': 805, 'name': 'Abriata, Luciano Andres', 'pre_name': 'abriatalucianoandres', 'inst': 'Laboratory for Biomolecular Modeling École Polytechnique Fédérale de Lausanne and Swiss Institute of Bioinformatics Lausanne 1015 Switzerland', 'SCOPUS': {'inst': 'Laboratory for Biomolecular Modeling École Polytechnique Fédérale de Lausanne and Swiss Institute of Bioinformatics Lausanne 1015 Switzerland', 'A_id': ['24586813800'], 'papers': [ObjectId('626b50d13247eaee55f8ab85')], 'oriInst': 'Laboratory for Biomolecular Modeling École Polytechnique Fédérale de Lausanne and Swiss Institute of Bioinformatics Lausanne 1015 Switzerland'}}), ('ahneunyoung', {'fid': 0, 'keyId': 805, 'name': 'Ahn, Eunyoung', 'pre_name': 'ahneunyoung', 'inst': 'Policy Research Division Korea Institute of Geoscience and Mineral Resources (KIGAM) Daejeon 34132 South Korea', 'SCOPUS': {'inst': 'Policy Research Division Korea Institute of Geoscience and Mineral Resources (KIGAM) Daejeon 34132 South Korea', 'A_id': ['57199279239'], 'papers': [ObjectId('626b50cd3247eaee55f8ab53')], 'oriInst': 'Policy Research Division Korea Institute of Geoscience and Mineral Resources (KIGAM) Daejeon 34132 South Korea'}}), ('ahnseongjin_0', {'fid': 0, 'keyId': 805, 'name': 'Ahn, Seongjin', 'pre_name': 'ahnseongjin', 'inst': 'Sungkyunkwan Univ, Dept Comp Educ, 25-2 Sungkyunkwan Ro, Seoul 03063, South Korea', 'WOS': {'inst': 'Sungkyunkwan Univ, Dept Comp Educ, 25-2 Sungkyunkwan Ro, Seoul 03063, South Korea', 'A_id': ['ss9437947'], 'papers': [ObjectId('626b50d6b8fbacd2f1f8aa91')], 'oriInst': 'Sungkyunkwan Univ, Dept Comp Educ, 25-2 Sungkyunkwan Ro, Seoul 03063, South Korea'}, 'SCOPUS': {'inst': 'Department of Computer Education Sungkyunkwan University 25-2 Sungkyunkwan-Ro Jongno-Gu Seoul 03063 South Korea', 'A_id': ['8976172600'], 'papers': [ObjectId('626b50d13247eaee55f8ab93')], 'oriInst': 'Department of Computer Education Sungkyunkwan University 25-2 Sungkyunkwan-Ro Jongno-Gu Seoul 03063 South Korea'}}), ('altflorian', {'fid': 0, 'keyId': 805, 'name': 'Alt, Florian', 'pre_name': 'altflorian', 'inst': 'Usable Security and Privacy Group CODE Research Institute for Cyber Defense and Smart Data Universität der Bundeswehr München Carl-Wery-Straße 18-22 München 81739 Germany', 'SCOPUS': {'inst': 'Usable Security and Privacy Group CODE Research Institute for Cyber Defense and Smart Data Universität der Bundeswehr München Carl-Wery-Straße 18-22 München 81739 Germany', 'A_id': ['27267528900'], 'papers': [ObjectId('626b50d13247eaee55f8ab84')], 'oriInst': 'Usable Security and Privacy Group CODE Research Institute for Cyber Defense and Smart Data Universität der Bundeswehr München Carl-Wery-Straße 18-22 München 81739 Germany'}}), ('ashmorem', {'fid': 0, 'keyId': 805, 'name': 'Ashmore M.', 'pre_name': 'ashmorem', 'inst': 'Dept of Computer Science and Mathematics/Screen School Liverpool John Moores University Liverpool United Kingdom', 'SCOPUS': {'inst': 'Dept of Computer Science and Mathematics/Screen School Liverpool John Moores University Liverpool United Kingdom', 'A_id': ['57410555000'], 'papers': [ObjectId('626b50d23247eaee55f8abce')], 'oriInst': 'Dept of Computer Science and Mathematics/Screen School Liverpool J ...
