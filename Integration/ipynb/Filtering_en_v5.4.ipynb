# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# v5.3: 중복논문 수정, flag 삭제
# v5.4: lang 삭제
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 1143 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }
        
        if pre_name == 'herrerafrancisco' and site == 'SCOPUS':
            print(Answer)
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

print(f'2차 통합: {savetime2}')
print(Inte_name)
print(len(Answer_dict))
# Out:
# DB 수집: WOS, 0.001903533935546875
# 전체 저자 수: 0
# DB 수집: SCOPUS, 0.12058234214782715
# 전체 저자 수: 208
# 2차 통합: 0.12248587608337402
# []
# 208

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    if site == "WOS":
        email.extend(rawdata['emails'].replace(" ", "").split(";"))
        funding_text.append(rawdata['funding text'])
        
    elif site == "SCOPUS":
        emails = rawdata['correspondence_address'].split(" ")
        for i in emails:
            if "@" in i:
                email.append(i)

        for funding in  rawdata.keys():
            if "funding_text_" in funding:
                funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
    
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2:
                funding_exact = 0
                # print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
        
        
    if paper_sim >= 0.8 or inst_sim >= 0.83 or email_exact == 1 or funding_exact == 1:
        weight = 4
        print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
        print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
        print(f'weigth: {weight}')
        print('------------------------------------------------------------구분선2------------------------------------------------------------')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    # print(f'weigth: {weight} | joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')
    # print(f'name1: {name1} | site1: {site1} | year: {year1} | coauthor: {coauthor1} | keyword: {keyword1} | journal1: {journal1}')
    # print(f'name2: {name2} | site1: {site2} | year: {year2} | coauthor: {coauthor2} | keyword: {keyword2} | journal2: {journal2}')
    # print(f'paper_sim: {paper_sim}')
    # print(f'title1: {title1}')
    # print(f'title2: {title2}')
    # print(f'inst_sim: {inst_sim}')
    # print(f'inst1: {inst1}')
    # print(f'inst2: {inst2}')
    # print(f'email_exact: {email_exact}')
    # print(f'emails1: {emails1}')
    # print(f'emails2: {emails2}')
    # print(raw_one1)
    # print(raw_one2)
    print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
    print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
    print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
    print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
    print(f'weigth: {weight}')
    print('------------------------------------------------------------구분선------------------------------------------------------------')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# []

# %%
from itertools import filterfalse


deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        
        if name_sim >= 0.82 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            flag = False
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                print(name_sim)
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# 0.882828282828283
# joc: 0 | yop: 2019, 2017 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Electric Vehicles', ' FEM', ' In-wheel Direct-drive', ' Outer-Rotor', ' PM machine'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Cheng, Ming | inst2: School of Electrical Engineering Southeast University Sipailou 2 Nanjing 210096 China | title2: Design and investigation of a new outer-rotor IPM motor for EV and HEV in-wheel propulsion | site1: SCOPUS
# inst: 0.5568947392476804 | title: 0.6715682465682465 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.890909090909091
# joc: 0 | yop: 2019, 2019 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Battery charger', ' Electromagnetic interference', ' Integrated charger', ' Pulse width modulation'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen J. | inst2: State Key Laboratory of Advanced Electromagnetic Engineering and Technology Huazhong University of Science and Technology Luoyu Road Wuhan Hubei Province 1037 China | title2: A simplified single-phase integrated on-board battery charger with low EMI emission to grid | site1: SCOPUS
# inst: 0.5242861754636355 | title: 0.6929345164639282 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# joc: 0 | yop: 2019, 2020 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Driving cycle', ' Electric vehicle', ' Energy consumption', ' Equivalent emissions', ' Markov chain', ' Monte Carlo method'] | journal1: SAE International | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen H. | inst2: School of Automobile Chang’an University Xi’an China | title2: Construction of electric vehicle driving cycle for studying electric vehicle energy consumption and equivalent emissions | site1: SCOPUS
# inst: 0.6472416472416472 | title: 0.6357864357864358 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.890909090909091
# joc: 0 | yop: 2017, 2022 | co_author_count: 0 | keyword: ['Direct yaw-moment control', ' Dynamic curvature', ' Handling', ' Stability'], ['disturbance observer (DOB)', ' four-wheel steering (4WS)', ' in-wheel motor (IWM)', ' kingpin torque', ' steer-by-wire (SbW)', ' yaw moment observer (YMO)'] | journal1: Korean Society of Automotive Engineers | journal2: MDPI
# name1: Nam, Kwanghee | inst1: Department of Electrical and Electronics POSTECH Gyeongbuk 37673 South Korea | title1: Lateral handling improvement with dynamic curvature control for an independent rear wheel drive EV | site1: SCOPUS
# name2: Nam, Kanghyun | inst2: Department of Mechanical Engineering Yeungnam University Gyeongsan 38541 South Korea | title2: Integrated Yaw Stability Control of Electric Vehicle Equipped with Front/Rear Steer-by-Wire Systems and Four In-Wheel Motors | site1: SCOPUS
# inst: 0.6837244626718312 | title: 0.7058455640320643 | email: 0, funding: 0
# weigth: 0.5
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8337662337662337
# joc: 0 | yop: 2019, 2017 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Algebraic identification method', ' Demagnetization fault diagnosis', ' Electric vehicle', ' Fault mode recognition', ' Hilbert-Huang transform', ' Permanent magnet synchronous motor drive system'] | journal1: SAE International | journal2: Chinese Machine Press
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen, Tao | inst2: School of Electrical Engineering and Automation Hefei University of Technology Hefei 230009 China | title2: Demagnetization Fault Diagnosis and Fault Mode Recognition of PMSM for EV | site1: SCOPUS
# inst: 0.5442810339717555 | title: 0.6523527842020992 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.890909090909091
# joc: 0 | yop: 2019, 2019 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Battery charger', ' Electromagnetic interference', ' Integrated charger', ' Pulse width modulation'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen J. | inst2: State Key Laboratory of Advanced Electromagnetic Engineering and Technology Huazhong University of Science and Technology Luoyu Road Wuhan Hubei Province 1037 China | title2: A simplified single-phase integrated on-board battery charger with low EMI emission to grid | site1: SCOPUS
# inst: 0.5242861754636355 | title: 0.6929345164639282 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# joc: 0 | yop: 2019, 2020 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Driving cycle', ' Electric vehicle', ' Energy consumption', ' Equivalent emissions', ' Markov chain', ' Monte Carlo method'] | journal1: SAE International | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen H. | inst2: School of Automobile Chang’an University Xi’an China | title2: Construction of electric vehicle driving cycle for studying electric vehicle energy consumption and equivalent emissions | site1: SCOPUS
# inst: 0.6472416472416472 | title: 0.6357864357864358 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8380952380952381
# joc: 0 | yop: 2020, 2017 | co_author_count: 0 | keyword: ['Electric Vehicle', ' Integrated Converter', ' Multiport Drive', ' Solar-assisted EV', ' Switched Reluctance Motor'], [''] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: SAE International
# name1: Singh, Sajjanpal | inst1: Indian Institute of Technology Roorkee Dept. of Electrical Engineering Roorkee India | title1: A wide speed operable multiport solar-assisted SRM EV drive with integrated driving/charging capabilities | site1: SCOPUS
# name2: Singh V. | inst2: ABV- IIITM Gwalior India | title2: Development of Smart PublicTransport System by Converting the Existing Conventional Vehicles to EV's in Indian Smart Cities | site1: SCOPUS
# inst: 0.4678571428571428 | title: 0.703533715140107 | email: 0, funding: 0
# weigth: 0.7
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.837037037037037
# joc: 0 | yop: 2021, 2017 | co_author_count: 0 | keyword: ['Current ripple', ' H-bridge', ' Intergrated Battery Charger', ' On Board Charger', ' PMSM'], ['EVs', ' Open winding', ' PMSM', ' V2G'] | journal1: Korean Institute of Electrical Engineers | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Gu, Bon-gwan | inst1: School of Energy Engineering Kyungpook National University Daegu South Korea | title1: Electric vehicle battery charging method using drive inverter and half-bridge | site1: SCOPUS
# name2: Gu, Cong | inst2: College of Automation Engineering Nanjing University of Aeronautics and Astronautics China | title2: Highly integrated bidirectional vehicle-to-grid (V2G) for electric vehicles based on open winding permanent magnet synchronous motor | site1: SCOPUS
# inst: 0.6951078412878072 | title: 0.6874025974025973 | email: 0, funding: 0
# weigth: 1.2321205588285578
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8518518518518519
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Current ripple', ' H-bridge', ' Intergrated Battery Charger', ' On Board Charger', ' PMSM'], ['Autonomous vehicle (AV)', ' charging management', ' long-range autonomous valet parking (LAVP)', ' trip planning'] | journal1: Korean Institute of Electrical Engineers | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Gu, Bon-gwan | inst1: School of Energy Engineering Kyungpook National University Daegu South Korea | title1: Electric vehicle battery charging method using drive inverter and half-bridge | site1: SCOPUS
# name2: Guo, W. | inst2: Centre for Autonomous and Cyber-Physical Systems Satm Cranfield University Cranfield MK43 0AL United Kingdom | title2: An Integrated Framework on Autonomous-EV Charging and Autonomous Valet Parking (AVP) Management System | site1: SCOPUS
# inst: 0.6316764132553606 | title: 0.5935913759443171 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8533333333333333
# joc: 0 | yop: 2017, 2017 | co_author_count: 0 | keyword: ['Motor drive', ' Split-wingding', ' Switched reluctance motor'], ['bandwidth constraint', ' clutchless shifting', ' dynamic sampling period scheduling', ' integrated motor-transmission (IMT)', ' speed synchronization'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Song, Zhibin | inst1: Shenzhen Institutes of Advanced Technology Chinese Academy of Sciences Shenzhen China Chinese University of Hong Kong Shatin N. T. Hong Kong | title1: Control strategy of integrated charger base on split-winding switched reluctance motor drive | site1: SCOPUS
# name2: Song, Qiang | inst2: National Engineering Laboratory for Electric Vehicles Collaborative Innovation Center of Electric Vehicles in Beijing Beijing Institute of Technology (BIT) Beijing 100081 China | title2: Speed synchronization control of electric vehicle's IMT powertrain systems over CAN with bandwidth constraint | site1: SCOPUS
# inst: 0.6412140429663794 | title: 0.7397999886033392 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8280701754385965
# joc: 0 | yop: 2019, 2017 | co_author_count: 0 | keyword: ['DC-DC/DC-AC power converter', ' Electric vehicle', ' Grid', ' Multi-input converter', ' Photovoltaic module', ' Renewable energies', ' Sliding mode control'], [''] | journal1: MDPI AG | journal2: SAE International
# name1: Herrera-Ruíz, Gilberto | inst1: Facultad de Ingeniería Universidad Autónoma de Querétaro Queretaro 76010 Mexico | title1: A novel integrated topology to interface electric vehicles and renewable energies with the grid | site1: SCOPUS
# name2: He, Rui | inst2: Jilin University ASCL China | title2: Network Scheduling for Distributed Controls of Electric Vehicles Considering Actuator Dynamic Characteristics | site1: SCOPUS
# inst: 0.483356774496015 | title: 0.6657492354740061 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.92
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['Electric vehicles', ' Energy-to-peak control', ' Integrated motor-transmission system', ' Oscillation damping', ' Polytopic inclusions'], ['AMESim', ' Coupling', ' Mechanical–electric–hydraulic', ' PID', ' Simulink'] | journal1: Elsevier Inc. | journal2: MDPI AG
# name1: Meng F. | inst1: Shanghai Maritime University Shanghai China | title1: Transmission Design and Control of EVs | site1: SCOPUS
# name2: Meng Z. | inst2: College of Mechanical and Electrical Engineering Qingdao University Qingdao 260071 China Power Integration and Energy Storage Systems Engineering Technology Center (Qingdao) Qingdao 260071 China | title2: Research on the starting acceleration characteristics of a new mechanical–electric–hydraulic power coupling electric vehicle | site1: SCOPUS
# inst: 0.5440762659465735 | title: 0.560001543448063 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8533333333333333
# joc: 0 | yop: 2017, 2017 | co_author_count: 0 | keyword: ['Motor drive', ' Split-wingding', ' Switched reluctance motor'], ['bandwidth constraint', ' clutchless shifting', ' dynamic sampling period scheduling', ' integrated motor-transmission (IMT)', ' speed synchronization'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Song, Zhibin | inst1: Shenzhen Institutes of Advanced Technology Chinese Academy of Sciences Shenzhen China Chinese University of Hong Kong Shatin N. T. Hong Kong | title1: Control strategy of integrated charger base on split-winding switched reluctance motor drive | site1: SCOPUS
# name2: Song, Qiang | inst2: National Engineering Laboratory for Electric Vehicles Collaborative Innovation Center of Electric Vehicles in Beijing Beijing Institute of Technology (BIT) Beijing 100081 China | title2: Speed synchronization control of electric vehicle's IMT powertrain systems over CAN with bandwidth constraint | site1: SCOPUS
# inst: 0.6412140429663794 | title: 0.7397999886033392 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8533333333333333
# joc: 0 | yop: 2017, 2017 | co_author_count: 0 | keyword: ['Motor drive', ' Split-wingding', ' Switched reluctance motor'], ['bandwidth constraint', ' clutchless shifting', ' dynamic sampling period scheduling', ' integrated motor-transmission (IMT)', ' speed synchronization'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Song, Zhibin | inst1: Shenzhen Institutes of Advanced Technology Chinese Academy of Sciences Shenzhen China Chinese University of Hong Kong Shatin N. T. Hong Kong | title1: Control strategy of integrated charger base on split-winding switched reluctance motor drive | site1: SCOPUS
# name2: Song, Qiang | inst2: National Engineering Laboratory for Electric Vehicles Collaborative Innovation Center of Electric Vehicles in Beijing Beijing Institute of Technology (BIT) Beijing 100081 China | title2: Speed synchronization control of electric vehicle's IMT powertrain systems over CAN with bandwidth constraint | site1: SCOPUS
# inst: 0.6412140429663794 | title: 0.7397999886033392 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8483333333333334
# joc: 0 | yop: 2019, 2018 | co_author_count: 0 | keyword: [''], ['Electric vehicles (EVs)', ' fast chargers', ' integrated battery chargers (IBCs)', ' plug-in EVs', ' synchronous machine'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Tang X. | inst1: Tongji University China | title1: Subsection coordinated control during mode transition for a compound Power-Split system | site1: SCOPUS
# name2: Tan L. | inst2: Electrical and Computer Engineering Department McGill University Montreal QC  H3A0E9 Canada | title2: Torque cancelation of integrated battery charger based on six-phase permanent magnet synchronous motor drives for electric vehicles | site1: SCOPUS
# inst: 0.4779921165790731 | title: 0.6766955846327166 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8666666666666667
# joc: 0 | yop: 2017, 2021 | co_author_count: 0 | keyword: ['component', ' formatting', ' insert (key words)', ' style', ' styling'], [''] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: SAE International
# name1: Liang Y. | inst1: Otago Polytechnic Dunedin New Zealand | title1: Suspension design for single-passenger electric vehicles | site1: SCOPUS
# name2: Li G. | inst2: GAC Motor Co Ltd. | title2: Impact of Thermal Architecture on Electric Vehicle Energy Consumption/Range: A Study with Full Vehicle Simulation | site1: SCOPUS
# inst: 0.4789348171701113 | title: 0.6217516505127124 | email: 0, funding: 0
# weigth: 0.6
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8416666666666667
# joc: 0 | yop: 2018, 2019 | co_author_count: 0 | keyword: ['Electric vehicles (EVs)', ' fast-integrated charger', ' leakage inductance filter', ' segmented PMSM windings', ' unity power factor (UPF)'], ['Electric machine', ' Electric vehicles', ' Integrated charger', ' On-board charger'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhang, Qianfan | inst1: Institute of Electromagnetic and Electronic Technology Department of Electrical Engineering Harbin Institute of Technology (HIT) Harbin China | title1: An integrated charger using segmented windings of interior permanent magnet motor based on 3 phase with 9 windings | site1: SCOPUS
# name2: Zhang, Yuanzhi | inst2: Huazhong University of Science and Technology State Key Laboratory of Advanced Electromagnetic Engineering and Technology Wuhan China | title2: Zero torque three phase integrated on-board charger by multi-elements motor torque cancellation | site1: SCOPUS
# inst: 0.7112943070800823 | title: 0.6437134502923976 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8722222222222222
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['Electric vehicles (EVs)', ' fast-integrated charger', ' leakage inductance filter', ' segmented PMSM windings', ' unity power factor (UPF)'], ['Battery capacity degradation', ' Hybrid energy storage system', ' Life-cycle cost', ' Mixed-integer multi-objective genetic algorithm', ' Uninterrupted dual input transmission'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Elsevier Ltd
# name1: Zhang, Qianfan | inst1: Institute of Electromagnetic and Electronic Technology Department of Electrical Engineering Harbin Institute of Technology (HIT) Harbin China | title1: An integrated charger using segmented windings of interior permanent magnet motor based on 3 phase with 9 windings | site1: SCOPUS
# name2: Zhang, Nong | inst2: Faculty of Engineering and IT University of Technology SydneyNSW Australia | title2: Investigation of integrated uninterrupted dual input transmission and hybrid energy storage system for electric vehicles | site1: SCOPUS
# inst: 0.6140234263089446 | title: 0.7171052631578947 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8714285714285714
# joc: 0 | yop: 2018, 2021 | co_author_count: 1 | keyword: ['Electric vehicles (EVs)', ' fast-integrated charger', ' leakage inductance filter', ' segmented PMSM windings', ' unity power factor (UPF)'], ['Electric vehicles (EVs)', ' integrated charger', ' optimized stator inductances', ' segmented three-phase machine'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhang, Qianfan | inst1: Institute of Electromagnetic and Electronic Technology Department of Electrical Engineering Harbin Institute of Technology (HIT) Harbin China | title1: An integrated charger using segmented windings of interior permanent magnet motor based on 3 phase with 9 windings | site1: SCOPUS
# name2: Zhang, Xi | inst2: Department of Electrical Engineering Harbin Institute of Technology Harbin China | title2: Design and Performance Analysis of Segmented Three-Phase IPMSM for EVs Integrated Battery Charger | site1: SCOPUS
# inst: 0.6974586288416075 | title: 0.7126523820004197 | email: 0, funding: 0
# weigth: 1.814847504909503
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8357142857142857
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['APU controller', ' Auxiliary power unit (APU)', ' Test bench'], ['Decoupled equivalent motor model', ' electrical vehicle', ' on-board integrated battery charger', ' winding multiplexing method'] | journal1: MDPI AG | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Yang, Qiangqiang | inst1: School of Mechanical Engineering Beijing Institute of Technology Beijing 100081 China | title1: Development and test application of an auxiliary power-integrated system | site1: SCOPUS
# name2: Yang, Huan | inst2: Zhejiang University College of Electrical Engineering Zhejiang Provincial Key Laboratory of Electrical Machine Systems Hangzhou China | title2: A Winding Multiplexing Method for Single-Phase and Three-Phase On-Board Integrated Battery Chargers Based on Multiphase Motor | site1: SCOPUS
# inst: 0.6341003652923157 | title: 0.677520697167756 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8387012987012987
# joc: 0 | yop: 2018, 2019 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['Electric Vehicles', ' Integral On-board Charger', ' Propulsion System', ' Unified Criterion'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang, Enlong | inst2: Zhejiang University College of Electrical Engineering Hangzhou China | title2: A Unified Criterion for Integral On-board Charger of Electric Vehicles Using Propulsion System | site1: SCOPUS
# inst: 0.6450708587754895 | title: 0.7476804163926754 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9022727272727272
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['additional copper demand', ' electric vehicles', ' passenger vehicle ownership prediction', ' pyramid tip product management', ' ripple effects'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Elsevier B.V.
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang, Peng | inst2: Institute of Urban Environment China | title2: Copper-induced ripple effects by the expanding electric vehicle fleet: A crisis or an opportunity | site1: SCOPUS
# inst: 0.6479037688715108 | title: 0.6859726303324093 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], [''] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institution of Engineering and Technology
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang N. | inst2: Dongfeng Motor Corporotion Wuhan Hubei 430058 China | title2: Model predictive control for integrated longitudinal and lateral stability of electric vehicles with in-wheel motors | site1: SCOPUS
# inst: 0.5998699233993352 | title: 0.7231865250170614 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# joc: 0 | yop: 2018, 2021 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['Air suspension', ' BP neural networks', ' HM-EV', ' model predictive control', ' rigid ring tire'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: SAGE Publications Ltd
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang C. | inst2: School of Mechanical Engineering Jiangsu University Zhenjiang China | title2: Vibration suppression of hub motor electric vehicle considering unbalanced magnetic pull | site1: SCOPUS
# inst: 0.6153701191014623 | title: 0.6923791692670411 | email: 0, funding: 0
# weigth: 0.7
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.890909090909091
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['active suspension', ' electromechanical coupling effects', ' global optimum', ' IWM-EV', ' multi-objective optimization'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang P. | inst2: China Automotive Engineering Research Institute Co. Ltd. New Energy Vehicle Center Chongqing China | title2: Comprehensive performance improvement of IWM-EVs with active suspension based on multi- objective integrated optimization | site1: SCOPUS
# inst: 0.5978148835291692 | title: 0.6680885452590509 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8424242424242424
# joc: 0 | yop: 2018, 2021 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['Battery', ' Charger', ' EVs', ' Supercapacitor', ' V2G'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: MDPI
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang, Xiuhe | inst2: School of Electrical Engineering Shandong University Jinan 250061 China | title2: A new on-board charging-driving integrated topology for v2g technology | site1: SCOPUS
# inst: 0.6221987171160471 | title: 0.6339615906332549 | email: 0, funding: 0
# weigth: 0.7
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8476190476190476
# joc: 0 | yop: 2021, 2018 | co_author_count: 0 | keyword: ['electric vehicles', ' integrated charger', ' on-board charger', ' traction motor'], ['Doubly salient electromagnetic machine (DSEM)', ' electric vehicle (EV)', ' integrated motor-drive and battery-charging (IMB) system', ' split field windings'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhou, Min | inst1: Huazhong University of Science and Technology Department of Eletrical and Electronic Engineering Wuhan China | title1: Review of Torque Cancellation Methods for Integrated Motor Drive and Charger System | site1: SCOPUS
# name2: Zhou, Bo | inst2: Nanjing University of Aeronautics and Astronautics Nanjing 211106 China | title2: An Integrated Motor-Drive and Battery-Charging System Based on Split-Field-Winding Doubly Salient Electromagnetic Machine | site1: SCOPUS
# inst: 0.6678931614377625 | title: 0.6723568109185297 | email: 0, funding: 0
# weigth: 0.7
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8222222222222222
# joc: 0 | yop: 2021, 2019 | co_author_count: 0 | keyword: ['AMESim', ' Energy management', ' HEV', ' Hybrid electric vehicle', ' MATLAB/Simulink', ' Regenerative braking'], ['Current sharing', ' electric vehicle (EV)', ' EV charger', ' interior permanent-magnet (IPM) motor', ' on-board charger', ' safe charging'] | journal1: Inderscience Publishers | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Yu, Haisheng | inst1: Corun Hybrid System Technology Co. Ltd. 2888 Wanfeng Road Fengjing Industrial Park Jinshan District Shanghai 201501 China | title1: Research on regenerative braking strategies for hybrid electric vehicle by co-simulation model | site1: SCOPUS
# name2: Yu, Feng | inst2: School of Energy and Environment City University of Hong Kong Kowloon Hong Kong School of Electrical Engineering Nantong University Nantong 226019 China | title2: An integrated on-board EV charger with safe charging operation for three-phase IPM Motor | site1: SCOPUS
# inst: 0.6181983587733463 | title: 0.6895689416966012 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8537878787878789
# joc: 0 | yop: 2019, 2019 | co_author_count: 0 | keyword: ['Electric machine', ' Electric vehicles', ' Integrated charger', ' On-board charger'], ['Electric wheel system', ' electromechanical coupling', ' four-wheel drive', ' negative vibration effect', ' vehicle dynamics'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhang, Yuanzhi | inst1: Huazhong University of Science and Technology State Key Laboratory of Advanced Electromagnetic Engineering and Technology Wuhan China | title1: Zero torque three phase integrated on-board charger by multi-elements motor torque cancellation | site1: SCOPUS
# name2: Zhan, Zhenfei | inst2: State Key Laboratory of Mechanical Transmission Department of Automotive Engineering Chongqing University Chongqing 400044 China | title2: Electromechanical coupling mechanism and control strategy for in-wheel-motor-driven electric vehicles | site1: SCOPUS
# inst: 0.6943714871957121 | title: 0.7191441411347613 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8333333333333334
# joc: 0 | yop: 2019, 2020 | co_author_count: 0 | keyword: ['Electric machine', ' Electric vehicles', ' Integrated charger', ' On-board charger'], ['Battery capacity degradation', ' Hybrid energy storage system', ' Life-cycle cost', ' Mixed-integer multi-objective genetic algorithm', ' Uninterrupted dual input transmission'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Elsevier Ltd
# name1: Zhang, Yuanzhi | inst1: Huazhong University of Science and Technology State Key Laboratory of Advanced Electromagnetic Engineering and Technology Wuhan China | title1: Zero torque three phase integrated on-board charger by multi-elements motor torque cancellation | site1: SCOPUS
# name2: Zhang, Nong | inst2: Faculty of Engineering and IT University of Technology SydneyNSW Australia | title2: Investigation of integrated uninterrupted dual input transmission and hybrid energy storage system for electric vehicles | site1: SCOPUS
# inst: 0.6532029597045077 | title: 0.6861652588260775 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8714285714285714
# joc: 0 | yop: 2019, 2021 | co_author_count: 0 | keyword: ['Electric machine', ' Electric vehicles', ' Integrated charger', ' On-board charger'], ['Electric vehicles (EVs)', ' integrated charger', ' optimized stator inductances', ' segmented three-phase machine'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhang, Yuanzhi | inst1: Huazhong University of Science and Technology State Key Laboratory of Advanced Electromagnetic Engineering and Technology Wuhan China | title1: Zero torque three phase integrated on-board charger by multi-elements motor torque cancellation | site1: SCOPUS
# name2: Zhang, Xi | inst2: Department of Electrical Engineering Harbin Institute of Technology Harbin China | title2: Design and Performance Analysis of Segmented Three-Phase IPMSM for EVs Integrated Battery Charger | site1: SCOPUS
# inst: 0.6652062519311978 | title: 0.6941248356332458 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8472222222222222
# joc: 0 | yop: 2019, 2020 | co_author_count: 0 | keyword: ['Electric machine', ' Electric vehicles', ' Integrated charger', ' On-board charger'], ['Decoupled equivalent motor model', ' electrical vehicle', ' on-board integrated battery charger', ' winding multiplexing method'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zhang, Yuanzhi | inst1: Huazhong University of Science and Technology State Key Laboratory of Advanced Electromagnetic Engineering and Technology Wuhan China | title1: Zero torque three phase integrated on-board charger by multi-elements motor torque cancellation | site1: SCOPUS
# name2: Yang, Huan | inst2: Zhejiang University College of Electrical Engineering Zhejiang Provincial Key Laboratory of Electrical Machine Systems Hangzhou China | title2: A Winding Multiplexing Method for Single-Phase and Three-Phase On-Board Integrated Battery Chargers Based on Multiphase Motor | site1: SCOPUS
# inst: 0.730166324903167 | title: 0.7211712038717483 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8666666666666666
# joc: 0 | yop: 2019, 2022 | co_author_count: 0 | keyword: ['Electric machine', ' Electric vehicles', ' Integrated charger', ' On-board charger'], ['Active safety', ' Electric vehicles', ' Energy efficiency', ' Energy management', ' In-wheel motors', ' Integrated torque distribution'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Elsevier Ltd
# name1: Zhang, Yuanzhi | inst1: Huazhong University of Science and Technology State Key Laboratory of Advanced Electromagnetic Engineering and Technology Wuhan China | title1: Zero torque three phase integrated on-board charger by multi-elements motor torque cancellation | site1: SCOPUS
# name2: Zhang, Youtong | inst2: School of Mechanical Engineering Beijing Institute of Technology Beijing China Key Lab of Low Emission Vehicle in Beijing Beijing China | title2: Modelling and experimental validation of an EV torque distribution strategy towards active safety and energy efficiency | site1: SCOPUS
# inst: 0.6807333699117614 | title: 0.6759322892449827 | email: 0, funding: 0
# weigth: 1.3321205588285576
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8592592592592593
# joc: 0 | yop: 2019, 2021 | co_author_count: 0 | keyword: ['Decentralized drive electric vehicle (EV)', ' fuzzy control', ' hardware-in-the-loop (HIL) simulation', ' wheel slip control'], ['AMESim', ' Energy management', ' HEV', ' Hybrid electric vehicle', ' MATLAB/Simulink', ' Regenerative braking'] | journal1: IEEE Computer Society | journal2: Inderscience Publishers
# name1: Hu, Jiasheng | inst1: National University of Tainan Tainan 700 Taiwan | title1: A Wheel Slip Control Approach Integrated with Electronic Stability Control for Decentralized Drive Electric Vehicles | site1: SCOPUS
# name2: Yu, Haisheng | inst2: Corun Hybrid System Technology Co. Ltd. 2888 Wanfeng Road Fengjing Industrial Park Jinshan District Shanghai 201501 China | title2: Research on regenerative braking strategies for hybrid electric vehicle by co-simulation model | site1: SCOPUS
# inst: 0.5160742545655504 | title: 0.7052741143699038 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8483333333333334
# joc: 0 | yop: 2019, 2018 | co_author_count: 0 | keyword: [''], ['Electric vehicles (EVs)', ' fast chargers', ' integrated battery chargers (IBCs)', ' plug-in EVs', ' synchronous machine'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Tang X. | inst1: Tongji University China | title1: Subsection coordinated control during mode transition for a compound Power-Split system | site1: SCOPUS
# name2: Tan L. | inst2: Electrical and Computer Engineering Department McGill University Montreal QC  H3A0E9 Canada | title2: Torque cancelation of integrated battery charger based on six-phase permanent magnet synchronous motor drives for electric vehicles | site1: SCOPUS
# inst: 0.4779921165790731 | title: 0.6766955846327166 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.882828282828283
# joc: 0 | yop: 2019, 2017 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Electric Vehicles', ' FEM', ' In-wheel Direct-drive', ' Outer-Rotor', ' PM machine'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Cheng, Ming | inst2: School of Electrical Engineering Southeast University Sipailou 2 Nanjing 210096 China | title2: Design and investigation of a new outer-rotor IPM motor for EV and HEV in-wheel propulsion | site1: SCOPUS
# inst: 0.5568947392476804 | title: 0.6715682465682465 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8337662337662337
# joc: 0 | yop: 2019, 2017 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Algebraic identification method', ' Demagnetization fault diagnosis', ' Electric vehicle', ' Fault mode recognition', ' Hilbert-Huang transform', ' Permanent magnet synchronous motor drive system'] | journal1: SAE International | journal2: Chinese Machine Press
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen, Tao | inst2: School of Electrical Engineering and Automation Hefei University of Technology Hefei 230009 China | title2: Demagnetization Fault Diagnosis and Fault Mode Recognition of PMSM for EV | site1: SCOPUS
# inst: 0.5442810339717555 | title: 0.6523527842020992 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.890909090909091
# joc: 0 | yop: 2019, 2019 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Battery charger', ' Electromagnetic interference', ' Integrated charger', ' Pulse width modulation'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen J. | inst2: State Key Laboratory of Advanced Electromagnetic Engineering and Technology Huazhong University of Science and Technology Luoyu Road Wuhan Hubei Province 1037 China | title2: A simplified single-phase integrated on-board battery charger with low EMI emission to grid | site1: SCOPUS
# inst: 0.5242861754636355 | title: 0.6929345164639282 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# joc: 0 | yop: 2019, 2020 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Driving cycle', ' Electric vehicle', ' Energy consumption', ' Equivalent emissions', ' Markov chain', ' Monte Carlo method'] | journal1: SAE International | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen H. | inst2: School of Automobile Chang’an University Xi’an China | title2: Construction of electric vehicle driving cycle for studying electric vehicle energy consumption and equivalent emissions | site1: SCOPUS
# inst: 0.6472416472416472 | title: 0.6357864357864358 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8280701754385965
# joc: 0 | yop: 2019, 2017 | co_author_count: 0 | keyword: ['DC-DC/DC-AC power converter', ' Electric vehicle', ' Grid', ' Multi-input converter', ' Photovoltaic module', ' Renewable energies', ' Sliding mode control'], [''] | journal1: MDPI AG | journal2: SAE International
# name1: Herrera-Ruíz, Gilberto | inst1: Facultad de Ingeniería Universidad Autónoma de Querétaro Queretaro 76010 Mexico | title1: A novel integrated topology to interface electric vehicles and renewable energies with the grid | site1: SCOPUS
# name2: He, Rui | inst2: Jilin University ASCL China | title2: Network Scheduling for Distributed Controls of Electric Vehicles Considering Actuator Dynamic Characteristics | site1: SCOPUS
# inst: 0.483356774496015 | title: 0.6657492354740061 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8488888888888889
# joc: 0 | yop: 2017, 2019 | co_author_count: 0 | keyword: ['Electric Vehicles', ' FEM', ' In-wheel Direct-drive', ' Outer-Rotor', ' PM machine'], ['Battery charger', ' Electromagnetic interference', ' Integrated charger', ' Pulse width modulation'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Ming | inst1: School of Electrical Engineering Southeast University Sipailou 2 Nanjing 210096 China | title1: Design and investigation of a new outer-rotor IPM motor for EV and HEV in-wheel propulsion | site1: SCOPUS
# name2: Chen J. | inst2: State Key Laboratory of Advanced Electromagnetic Engineering and Technology Huazhong University of Science and Technology Luoyu Road Wuhan Hubei Province 1037 China | title2: A simplified single-phase integrated on-board battery charger with low EMI emission to grid | site1: SCOPUS
# inst: 0.617296895370243 | title: 0.6966218966218967 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.882828282828283
# joc: 0 | yop: 2019, 2017 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Electric Vehicles', ' FEM', ' In-wheel Direct-drive', ' Outer-Rotor', ' PM machine'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Cheng, Ming | inst2: School of Electrical Engineering Southeast University Sipailou 2 Nanjing 210096 China | title2: Design and investigation of a new outer-rotor IPM motor for EV and HEV in-wheel propulsion | site1: SCOPUS
# inst: 0.5568947392476804 | title: 0.6715682465682465 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.890909090909091
# joc: 0 | yop: 2019, 2019 | co_author_count: 0 | keyword: ['Hybrid powertrain', ' Index Terms Energy management strategy', ' Power mode switch control'], ['Battery charger', ' Electromagnetic interference', ' Integrated charger', ' Pulse width modulation'] | journal1: SAE International | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Cheng, Jung-Ho | inst1: National Taiwan University Taiwan | title1: An Energy Management Strategy for Through-the-Road Type Plug-in Hybrid Electric Vehicles | site1: SCOPUS
# name2: Chen J. | inst2: State Key Laboratory of Advanced Electromagnetic Engineering and Technology Huazhong University of Science and Technology Luoyu Road Wuhan Hubei Province 1037 China | title2: A simplified single-phase integrated on-board battery charger with low EMI emission to grid | site1: SCOPUS
# inst: 0.5242861754636355 | title: 0.6929345164639282 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# ...
# name2: Singh, Bhim | inst2: Indian Institute of Technology Department of Electrical Engineering New Delhi 110016 India | title2: Enhanced QPLL Based Position Estimation of RelSync Motor Drive for Electric Vehicle with Integrated Sources | site1: SCOPUS
# inst: 0.8548705096073517 | title: 0.7224095895977246 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# 0.8424242424242424
# joc: 0 | yop: 2018, 2021 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['Battery', ' Charger', ' EVs', ' Supercapacitor', ' V2G'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: MDPI
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang, Xiuhe | inst2: School of Electrical Engineering Shandong University Jinan 250061 China | title2: A new on-board charging-driving integrated topology for v2g technology | site1: SCOPUS
# inst: 0.6221987171160471 | title: 0.6339615906332549 | email: 0, funding: 0
# weigth: 0.7
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8387012987012987
# joc: 0 | yop: 2018, 2019 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['Electric Vehicles', ' Integral On-board Charger', ' Propulsion System', ' Unified Criterion'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang, Enlong | inst2: Zhejiang University College of Electrical Engineering Hangzhou China | title2: A Unified Criterion for Integral On-board Charger of Electric Vehicles Using Propulsion System | site1: SCOPUS
# inst: 0.6450708587754895 | title: 0.7476804163926754 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9022727272727272
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['additional copper demand', ' electric vehicles', ' passenger vehicle ownership prediction', ' pyramid tip product management', ' ripple effects'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Elsevier B.V.
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang, Peng | inst2: Institute of Urban Environment China | title2: Copper-induced ripple effects by the expanding electric vehicle fleet: A crisis or an opportunity | site1: SCOPUS
# inst: 0.6479037688715108 | title: 0.6859726303324093 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], [''] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institution of Engineering and Technology
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang N. | inst2: Dongfeng Motor Corporotion Wuhan Hubei 430058 China | title2: Model predictive control for integrated longitudinal and lateral stability of electric vehicles with in-wheel motors | site1: SCOPUS
# inst: 0.5998699233993352 | title: 0.7231865250170614 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8327272727272728
# joc: 0 | yop: 2018, 2021 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['Air suspension', ' BP neural networks', ' HM-EV', ' model predictive control', ' rigid ring tire'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: SAGE Publications Ltd
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang C. | inst2: School of Mechanical Engineering Jiangsu University Zhenjiang China | title2: Vibration suppression of hub motor electric vehicle considering unbalanced magnetic pull | site1: SCOPUS
# inst: 0.6153701191014623 | title: 0.6923791692670411 | email: 0, funding: 0
# weigth: 0.7
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.890909090909091
# joc: 0 | yop: 2018, 2020 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['active suspension', ' electromechanical coupling effects', ' global optimum', ' IWM-EV', ' multi-objective optimization'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang P. | inst2: China Automotive Engineering Research Institute Co. Ltd. New Energy Vehicle Center Chongqing China | title2: Comprehensive performance improvement of IWM-EVs with active suspension based on multi- objective integrated optimization | site1: SCOPUS
# inst: 0.5978148835291692 | title: 0.6680885452590509 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8424242424242424
# joc: 0 | yop: 2018, 2021 | co_author_count: 0 | keyword: ['CCCV', ' Electric Vehicle', ' Integrated Charger', ' PFC', ' Plug-in Hybrid Electric Vehicle', ' Switched reluctance motor'], ['Battery', ' Charger', ' EVs', ' Supercapacitor', ' V2G'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: MDPI
# name1: Wang, Liuping | inst1: RMIT University Melbourne School of EngineeringVIC  3000 Australia | title1: An Integrated SRM Drive with Constant Current Constant Voltage Charging Capability for Electric Vehicle Application | site1: SCOPUS
# name2: Wang, Xiuhe | inst2: School of Electrical Engineering Shandong University Jinan 250061 China | title2: A new on-board charging-driving integrated topology for v2g technology | site1: SCOPUS
# inst: 0.6221987171160471 | title: 0.6339615906332549 | email: 0, funding: 0
# weigth: 0.7
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8552188552188553
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Active safety', ' Electric vehicles', ' Energy efficiency', ' Energy management', ' In-wheel motors', ' Integrated torque distribution'], ['Electric vehicle', ' Hybrid-excitation machine', ' Integrated on-board charger', ' Multi-phase machine'] | journal1: Elsevier Ltd | journal2: China Machine Press
# name1: Zhang, Youtong | inst1: School of Mechanical Engineering Beijing Institute of Technology Beijing China Key Lab of Low Emission Vehicle in Beijing Beijing China | title1: Modelling and experimental validation of an EV torque distribution strategy towards active safety and energy efficiency | site1: SCOPUS
# name2: Zhu, Xiaoyong | inst2: School of Electrical and Information Engineering Jiangsu University Zhenjiang 212013 China | title2: Key Issues and Solutions of Integrated on-Board Chargers for Electric Vehicles [电动汽车用车载集成式充电系统若干关键技术问题及解决方案 | site1: SCOPUS
# inst: 0.662962962962963 | title: 0.595099348150475 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8552188552188553
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Active safety', ' Electric vehicles', ' Energy efficiency', ' Energy management', ' In-wheel motors', ' Integrated torque distribution'], ['Electric vehicle', ' Hybrid-excitation machine', ' Integrated on-board charger', ' Multi-phase machine'] | journal1: Elsevier Ltd | journal2: China Machine Press
# name1: Zhang, Youtong | inst1: School of Mechanical Engineering Beijing Institute of Technology Beijing China Key Lab of Low Emission Vehicle in Beijing Beijing China | title1: Modelling and experimental validation of an EV torque distribution strategy towards active safety and energy efficiency | site1: SCOPUS
# name2: Zhu, Xiaoyong | inst2: School of Electrical and Information Engineering Jiangsu University Zhenjiang 212013 China | title2: Key Issues and Solutions of Integrated on-Board Chargers for Electric Vehicles [电动汽车用车载集成式充电系统若干关键技术问题及解决方案 | site1: SCOPUS
# inst: 0.662962962962963 | title: 0.595099348150475 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8518518518518519
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Current ripple', ' H-bridge', ' Intergrated Battery Charger', ' On Board Charger', ' PMSM'], ['Autonomous vehicle (AV)', ' charging management', ' long-range autonomous valet parking (LAVP)', ' trip planning'] | journal1: Korean Institute of Electrical Engineers | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Gu, Bon-gwan | inst1: School of Energy Engineering Kyungpook National University Daegu South Korea | title1: Electric vehicle battery charging method using drive inverter and half-bridge | site1: SCOPUS
# name2: Guo, W. | inst2: Centre for Autonomous and Cyber-Physical Systems Satm Cranfield University Cranfield MK43 0AL United Kingdom | title2: An Integrated Framework on Autonomous-EV Charging and Autonomous Valet Parking (AVP) Management System | site1: SCOPUS
# inst: 0.6316764132553606 | title: 0.5935913759443171 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8518518518518519
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Current ripple', ' H-bridge', ' Intergrated Battery Charger', ' On Board Charger', ' PMSM'], ['Autonomous vehicle (AV)', ' charging management', ' long-range autonomous valet parking (LAVP)', ' trip planning'] | journal1: Korean Institute of Electrical Engineers | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Gu, Bon-gwan | inst1: School of Energy Engineering Kyungpook National University Daegu South Korea | title1: Electric vehicle battery charging method using drive inverter and half-bridge | site1: SCOPUS
# name2: Guo, W. | inst2: Centre for Autonomous and Cyber-Physical Systems Satm Cranfield University Cranfield MK43 0AL United Kingdom | title2: An Integrated Framework on Autonomous-EV Charging and Autonomous Valet Parking (AVP) Management System | site1: SCOPUS
# inst: 0.6316764132553606 | title: 0.5935913759443171 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.8861111111111111
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['electric machines', ' finite element analysis', ' genetic algorithms', ' optimisation', ' permanent magnet motors', ' torque'], ['Electric Vehicle (EV)', ' Model reference adaptive system (MRAS)', ' Permanent magnet synchronous machine (PMSM)'] | journal1: John Wiley and Sons Inc | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Sreejeth, Mini | inst1: Electrical Engineering Department Delhi Technological University New Delhi India | title1: Integrated Taguchi method-assisted polynomial Metamodelling & Genetic Algorithm based optimisation of a surface inset permanent synchronous motor for performance improvement | site1: SCOPUS
# name2: Sreejith, R. | inst2: Indian Institute of Technology Delhi Department of Electrical Engineering Delhi New 110016 India | title2: MRAS Based Sensorless PMSM Drive with Regenerative Braking for Solar PV-Battery Powered EV | site1: SCOPUS
# inst: 0.7259259259259259 | title: 0.6462722115178763 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9
# joc: 0 | yop: 2020, 2022 | co_author_count: 0 | keyword: ['Battery/ultracapacitor', ' Bidirectional power converter', ' Dual-energy', ' Electric vehicles'], ['bidirectional AC/DC converter', ' bidirectional DC/DC converter', ' driving-charging integration', ' On-board charger'] | journal1: MDPI AG | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Liu, Yitao | inst1: College of Mechatronics and Control Engineering Shenzhen University Shenzhen 518060 China | title1: Study of a bidirectional power converter integrated with battery/ultracapacitor dual-energy storage | site1: SCOPUS
# name2: Liu Y. | inst2: Harbin University of Science and Technology Engineering Research Center of Automotive Electronics Drive Control and System Integration Ministry of Education Harbin 150080 China | title2: Driving-Charging Integrated Controller for Electric Vehicles | site1: SCOPUS
# inst: 0.6303072863466123 | title: 0.6380570409982175 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# 0.9
# joc: 0 | yop: 2020, 2022 | co_author_count: 0 | keyword: ['Battery/ultracapacitor', ' Bidirectional power converter', ' Dual-energy', ' Electric vehicles'], ['bidirectional AC/DC converter', ' bidirectional DC/DC converter', ' driving-charging integration', ' On-board charger'] | journal1: MDPI AG | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Liu, Yitao | inst1: College of Mechatronics and Control Engineering Shenzhen University Shenzhen 518060 China | title1: Study of a bidirectional power converter integrated with battery/ultracapacitor dual-energy storage | site1: SCOPUS
# name2: Liu Y. | inst2: Harbin University of Science and Technology Engineering Research Center of Automotive Electronics Drive Control and System Integration Ministry of Education Harbin 150080 China | title2: Driving-Charging Integrated Controller for Electric Vehicles | site1: SCOPUS
# inst: 0.6303072863466123 | title: 0.6380570409982175 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# ['singhbhim', 'zhangxi', 'zhangxi', 'singhbhim', 'singhbhim']
# 5
# 140

# %%
for check_name in set(Inte_name): #통합저자
    paper_check = {} #paper_id : title : co_author
    
    if check_name in Answer_dict.keys():
        for site_one in site:
            if site_one in Answer_dict[check_name]:
                for raw_one in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[check_name][site_one]['papers']}}):
                    if raw_one['title'] not in paper_check.keys(): #중복 title이 아니면
                        
                        for key_check in paper_check: #paper_chck에 있는 title과 유사도 비교
                            paper_sim = jaro.jaro_winkler_metric(key_check, raw_one['title'])

                            if paper_sim >= 0.8: #유사도가 80% 이상이면
                                if len(paper_check[key_check]['co_author']) == len(raw_one['author'].split(';')[:-1]): #공동저자 비교
                                    print(key_check)
                                    print(raw_one['title'])
                                    print(paper_check[key_check]['co_author'])
                                    print(raw_one['author'].split(';')[:-1])
                                    if raw_one['_id'] in Answer_dict[check_name][site_one]['papers']:
                                        Answer_dict[check_name][site_one]['papers'].remove(raw_one['_id'])
                                        if raw_one['_id'] in fp_dict:
                                            print('del_1')
                                            del fp_dict[raw_one['_id']]
                                        break

                        paper_check[raw_one['title']] = {'paper_id' : raw_one['_id'], 'co_author' : raw_one['author'].split(';')[:-1]}
                        
                    else: #중복 title이면
                        Answer_dict[check_name][site_one]['papers'].remove(raw_one['_id'])
                        if raw_one['_id'] in fp_dict:
                            print('del_2')
                            del fp_dict[raw_one['_id']]
                         
                if Answer_dict[check_name][site_one]['papers'] == []: #site에 papers가 비어있으면 site 삭제
                    del Answer_dict[check_name][site_one]
# Out:
# Processor-in-the-Loop Architecture Design and Experimental Validation for an Autonomous Racing Vehicle
# Processor-in-the-loop architecture design and experimental validation for an autonomous racing vehicle
# ['Tramacere, Eugenio', 'Luciani, Sara', 'Feraco, Stefano', 'Bonfitto, Angelo', 'Amati, Nicola']
# ['Tramacere E.', 'Luciani S.', 'Feraco S.', 'Bonfitto, Angelo', 'Amati, N.']
# del_1
# del_2
# Automated Data Annotation for 6-DoF AI-Based Navigation Algorithm Development
# Automated data annotation for 6-dof ai-based navigation algorithm development
# ['Baca, Javier Gibran Apud', 'Jantos, Thomas', 'Theuermann, Mario', 'Hamdad, Mohamed Amin', 'Steinbrener, Jan', 'Weiss, Stephan', 'Almer, Alexander', 'Perko, Roland']
# ['Apud Baca J.G.', 'Jantos T.', 'Theuermann M.', 'Hamdad M.A.', 'Steinbrener, Jan', 'Weiss, Stephan', 'Almer, Alexander', 'Perko, Roland']
# del_1
# del_2
# Baby, you can drive my car: Psychological antecedents that drive consumers' adoption of AI-powered autonomous vehicles
# “Baby, you can drive my car”: Psychological antecedents that drive consumers’ adoption of AI-powered autonomous vehicles
# ['Meyer-Waarden, Lars', 'Cloarec, Julien']
# ['Meyer?Waarden, Lars', 'Cloarec J.']
# del_1
# del_2
# del_2
# del_2
# del_2
# An Intelligent Actuator of an Indoor Logistics System Based on Multi-Sensor Fusion
# An intelligent actuator of an indoor logistics system based on multi-sensor fusion
# ['Wang, Pangwei', 'Wang, Yunfeng', 'Wang, Xu', 'Liu, Ying', 'Zhang, Juan']
# ['Wang, Pangwei', 'Wang, Yunfeng', 'Wang, Xu', 'Liu, Ying', 'Zhang, Juan']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# Incorporating Multi-Context Into the Traversability Map for Urban Autonomous Driving Using Deep Inverse Reinforcement Learning
# Incorporating Multi-Context into the Traversability Map for Urban Autonomous Driving Using Deep Inverse Reinforcement Learning
# ['Jung, Chanyoung', 'Shim, David Hyunchul']
# ['Jung, Chanyoung', 'Shim, David Hyunchul']
# del_1
# del_2
# Commonsense visual sensemaking for autonomous driving-On generalised neurosymbolic online abduction integrating vision and semantics
# Commonsense visual sensemaking for autonomous driving – On generalised neurosymbolic online abduction integrating vision and semantics
# ['Suchan, Jakob', 'Bhatt, Mehul', 'Varadarajan, Srikrishna']
# ['Suchan, Jakob', 'Bhatt, Mehul', 'Varadarajan S.']
# del_1
# del_2
# Autonomous Vehicles: An Analysis Both on Their Distinctiveness and the Potential Impact on Urban Transport Systems
# Autonomous vehicles: An analysis both on their distinctiveness and the potential impact on urban transport systems
# ['Severino, Alessandro', 'Curto, Salvatore', 'Barberi, Salvatore', 'Arena, Fabio', 'Pau, Giovanni']
# ['Severino, Alessandro', 'Curto, Salvatore', 'Barberi S.', 'Arena, Fabio', 'Pau, Giovanni']
# del_1
# del_2
# del_2
# del_2
# del_2
# 360 degrees real-time and power-efficient 3D DAMOT for autonomous driving applications
# 360 ∘ real-time and power-efficient 3D DAMOT for autonomous driving applications
# ['Gomez-Huelamo, Carlos', 'Del Egido, Javier', 'Miguel Bergasa, Luis', 'Barea, Rafael', 'Lopez-Guillen, Elena', 'Araluce, Javier', 'Antunes, Miguel']
# ['Gómez-Huélamo, Carlos', 'del Egido, Javier', 'Bergasa, Luis Miguel', 'Barea, R.', 'López-Guillén, Elena', 'Araluce, Javier', 'Antunes, Miguel']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# Reconfigurable Intelligent Surface Assisted Mobile Edge Computing With Heterogeneous Learning Tasks
# Reconfigurable Intelligent Surface Assisted Mobile Edge Computing with Heterogeneous Learning Tasks
# ['Huang, Shanfeng', 'Wang, Shuai', 'Wang, Rui', 'Wen, Miaowen', 'Huang, Kaibin']
# ['Huang, Shanfeng', 'Wang, Shuai', 'Wang, Rui', 'Wen, Miaowen', 'Huang, Kaibin']
# del_1
# del_2
# del_2
# Neuroscope: An Explainable AI Toolbox for Semantic Segmentation and Image Classification of Convolutional Neural Nets
# Neuroscope: An explainable ai toolbox for semantic segmentation and image classification of convolutional neural nets
# ['Schorr, Christian', 'Goodarzi, Payman', 'Chen, Fei', 'Dahmen, Tim']
# ['Schorr, Christian', 'Goodarzi P.', 'Chen F.', 'Dahmen T.']
# del_1
# del_2
# del_2
# Intelligent and efficient? An empirical analysis of human-AI collaboration for truck drivers in retail logistics
# Intelligent and efficient? An empirical analysis of human–AI collaboration for truck drivers in retail logistics
# ['Loske, Dominic', 'Klumpp, Matthias']
# ['Loske, Dominic', 'Klumpp, Matthias']
# del_1
# Implications of the BATTERY 2030+AI-Assisted Toolkit on Future Low-TRL Battery Discoveries and Chemistries
# Implications of the BATTERY 2030+ AI-Assisted Toolkit on Future Low-TRL Battery Discoveries and Chemistries
# ['Bhowmik, Arghya', 'Berecibar, Maitane', 'Casas-Cabanas, Montse', 'Csanyi, Gabor', 'Dominko, Robert', 'Hermansson, Kersti', 'Palacin, M. Rosa', 'Stein, Helge S.', 'Vegge, Tejs']
# ['Bhowmik, Arghya', 'Berecibar, Maitane', 'Casas-Cabanas, Montse', 'Csányi, Gábor', 'Dominko R.', 'Hermansson, Kersti G.', 'Palacín, Rosa', 'Stein, H. S.', 'Vegge, Tejs']
# del_1
# Design and Implementation of an Ontology for Semantic Labeling and Testing: Automotive Global Ontology (AGO)
# Design and implementation of an ontology for semantic labeling and testing: Automotive global ontology (ago
# ['Urbieta, Itziar', 'Nieto, Marcos', 'Garcia, Mikel', 'Otaegui, Oihana']
# ['Urbieta I.', 'Nieto, Marcos', 'García M.', 'Otaegui, Oihana']
# del_1
# del_2
# del_2
# A Gamified Simulator and Physical Platform for Self-Driving Algorithm Training and Validation
# A gamified simulator and physical platform for self-driving algorithm training and validation
# ['Pappas, Georgios', 'Siegel, Joshua E.', 'Politopoulos, Konstantinos', 'Sun, Yongbin']
# ['Pappas G.', 'Siegel, Joshua E.', 'Politopoulos K.', 'Sun, Yongbin']
# del_1
# Multi-Cloud Resource Management Techniques for Cyber-Physical Systems
# Multi-cloud resource management techniques for cyber-physical systems
# ['Bucur, Vlad', 'Miclea, Liviu-Cristian']
# ['Bucur, Vlad', 'Míclea, Liviu Cristian']
# del_1
# del_2
# del_2
# del_2
# del_2
# Hybrid Intelligence: to automate or not to automate, that is the question
# Hybrid intelligence: to automate or not to automate, that is the question
# ['van der Aalst, Wil M. P.']
# ['van der Aalst, Wil M.P.']
# del_1
# del_2
# AI Based Traffic Flow Prediction Model for Connected and Autonomous Electric Vehicles
# AI based traffic flow prediction model for connected and autonomous electric vehicles
# ['Thamizhazhagan, P.', 'Sujatha, M.', 'Umadevi, S.', 'Priyadarshini, K.', 'Parvathy, Velmurugan Subbiah', 'Pustokhina, Irina V.', 'Pustokhin, Denis A.']
# ['Thamizhazhagan, P.', 'Sujatha, M.', 'Umadevi, S.', 'Priyadarshini K.', 'Subbiah Parvathy, Velmurugan', 'Pustokhina, Irina Valeryevna', 'Pustokhin, Denis Alexandrovich']
# del_1
# del_2
# del_2
# Making decisions: the normal interventions of Nissan 'mobility managers'
# Making decisions: the normal interventions of Nissan ‘mobility managers
# ['Hind, Sam']
# ['Hind, Sam']
# del_1
# del_2
# del_2
# Real-time Camera and Video Streaming Through Optimized Settings of Ethernet AVB in Vehicle Network System
# Real-time camera and video streaming through optimized settings of ethernet AVB in vehicle network system
# ['An, Byoungman', 'Kim, Youngseop']
# ['An, Byoungman', 'Kim, Youngseop']
# del_1
# del_2
# What influences attitudes about artificial intelligence adoption: Evidence from US local officials
# What influences attitudes about artificial intelligence adoption: Evidence from U.S. local officials
# ['Horowitz, Michael C.', 'Kahn, Lauren']
# ['Horowitz, Michael C.', 'Kahn L.']
# del_1
# del_2
# del_2
# del_2
# del_2
# Data-Centric Architecture for Self-Driving Laboratories with Autonomous Discovery of New Nanomaterials
# Data-centric architecture for self-driving laboratories with autonomous discovery of new nanomaterials
# ['Butakova, Maria A.', 'Chernov, Andrey V.', 'Kartashov, Oleg O.', 'Soldatov, Alexander V.']
# ['Butakova, M. A.', 'Chernov Andrey, V.', 'Kartashov, Oleg O.', 'Soldatov, A. V.']
# del_1
# del_2
# del_2
# del_2
# A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles With Smart City
# A Framework for the Synergistic Integration of Fully Autonomous Ground Vehicles with Smart City
# ['Kuru, Kaya', 'Khan, Wasiq']
# ['Kuru, Kaya', 'Khan, Wasiq']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# The Unfounded Bias Against Autonomous Weapons Systems
# The Unfounded Bias against Autonomous Weapons Systems
# ['Dombrovszki, Aron']
# ['Dombrovszki A.']
# del_1
# Safety and Acceptability of a Natural Language Artificial Intelligence Assistant to Deliver Clinical Follow-up to Cataract Surgery Patients: Proposal
# Safety and acceptability of a natural language artificial intelligence assistant to deliver clinical follow-up to cataract surgery patients: Proposal
# ['de Pennington, Nick', 'Mole, Guy', 'Lim, Ernest', 'Milne-Ives, Madison', 'Normando, Eduardo', 'Xue, Kanmin', 'Meinert, Edward']
# ['De Pennington, Nicholas', 'Mole, Guy', 'Lim, Ernest', 'Milne-Ives, Madison', 'Normando, Eduardo Maria', 'Xue, K.', 'Meinert, Edward']
# del_1
# del_2
# AI4People: Ethical Guidelines for the Automotive Sector - Fundamental Requirements and Practical Recommendations
# AI4people: Ethical guidelines for the automotive sector-fundamental requirements and practical recommendations
# ['Luetge, Christoph', 'Poszler, Franziska', 'Acosta, Aida Joaquin', 'Danks, David', 'Gottehrer, Gail', 'Mihet-Popa, Lucian', 'Naseer, Aisha']
# ['Luetge, Christoph', 'Poszler F.', 'Acosta A.J.', 'Danks, David J.', 'Gottehrer G.', 'Mihet-Popa, Lucian', 'Naseer, Aisha']
# del_1
# How Does C-V2X Help Autonomous Driving to Avoid Accidents?
# How Does C-V2X Help Autonomous Driving to Avoid Accidents
# ['Miao, Lili', 'Chen, Shang-Fu', 'Hsu, Yu-Ling', 'Hua, Kai-Lung']
# ['Miao L.', 'Chen S.-F.', 'Hsu Y.-L.', 'Hua, Kailung']
# del_1
# del_2
# del_2
# del_2
# del_2
# del_2
# del_2
# del_2
# Automatic Roadway Features Detection with Oriented Object Detection
# Automatic roadway features detection with oriented object detection
# ['Eraqi, Hesham M.', 'Soliman, Karim', 'Said, Dalia', 'Elezaby, Omar R.', 'Moustafa, Mohamed N.', 'Abdelgawad, Hossam']
# ['Eraqi, Hesham M.', 'Soliman K.', 'Said D.', 'Elezaby O.R.', 'Moustafa, Mohamed N.', 'Abdelgawad, Hossam']
# del_1
# del_2
# del_2
# del_2

# %%
for fp in fp_dict:
    f_pyear = fc_simple_filter(fp_dict[fp]['year'], f_pyear)
    f_pinst = fc_simple_filter(fp_dict[fp]['inst'].replace(".", "^"), f_pinst)
    f_pjournal = fc_simple_filter(fp_dict[fp]['journal'].replace(".", "^"), f_pjournal)
    
filter_dict= {'keyId': keyid, 'fId': f_id, 'paper': { 
                'year': {'list': f_pyear, 'k': 'year', 'v': '연도' },
                'inst': {'k': 'inst', 'list': f_pinst, 'v': '소속', 'f': 'false' },
                'journal': {'list': f_pjournal, 'k': 'journal', 'v': '저널'}
            },
            'project': {
                'year': {'list': [], 'k': 'year', 'v': '연도' },
                'inst': {'list': [], 'k': 'inst', 'v': '소속' },
                'fund': {'k': 'fund', 'v': '과제수주비', 'list': []},
                'rsc': {'k': 'rsc', 'v': '참여인원', 'list': [] }
            }}

# %%
# if len(Answer_dict) != 0:
#     filters_category.insert_one(filter_dict)
#     id_international.insert_many(Answer_dict.values()) #mongodb 추가
#     analyzer = multicpu_international.run_factor_integration(keyid, f_id)
#     analyzer.run()
#     print("Integration OK", time.time() - start1)
# else:
#     print("No Data")
