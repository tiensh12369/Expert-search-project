# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 904 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []
plang = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']
            plang = fid_key_query[key]['lang']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}
f_plang = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst) and simple_filter(paper_lang, plang):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }
        
        if pre_name == 'herrerafrancisco' and site == 'SCOPUS':
            print(Answer)
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

print(f'2차 통합: {savetime2}')
print(Inte_name)
print(len(Answer_dict))
# Out:
# DB 수집: WOS, 0.11304020881652832
# 전체 저자 수: 254
# DB 수집: SCOPUS, 0.18102025985717773
# 전체 저자 수: 313
# 2차 통합: 0.29606056213378906
# []
# 567

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    if site == "WOS":
        email.extend(rawdata['emails'].replace(" ", "").split(";"))
        funding_text.append(rawdata['funding text'])
        
    elif site == "SCOPUS":
        emails = rawdata['correspondence_address'].split(" ")
        for i in emails:
            if "@" in i:
                email.append(i)

        for funding in  rawdata.keys():
            if "funding_text_" in funding:
                funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
    
    print(f'e1: {emails1}')
    print(f'e2: {emails2}')
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2:
                funding_exact = 0
                # print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
        
        
    if paper_sim >= 0.8 or inst_sim >= 0.83 or email_exact == 1 or funding_exact == 1:
        weight = 4
        print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
        print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
        print(f'weigth: {weight}')
        print('------------------------------------------------------------구분선2------------------------------------------------------------')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    # print(f'weigth: {weight} | joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')
    # print(f'name1: {name1} | site1: {site1} | year: {year1} | coauthor: {coauthor1} | keyword: {keyword1} | journal1: {journal1}')
    # print(f'name2: {name2} | site1: {site2} | year: {year2} | coauthor: {coauthor2} | keyword: {keyword2} | journal2: {journal2}')
    # print(f'paper_sim: {paper_sim}')
    # print(f'title1: {title1}')
    # print(f'title2: {title2}')
    # print(f'inst_sim: {inst_sim}')
    # print(f'inst1: {inst1}')
    # print(f'inst2: {inst2}')
    # print(f'email_exact: {email_exact}')
    # print(f'emails1: {emails1}')
    # print(f'emails2: {emails2}')
    # print(raw_one1)
    # print(raw_one2)
    print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
    print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
    print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
    print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
    print(f'weigth: {weight}')
    print('------------------------------------------------------------구분선------------------------------------------------------------')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# e1: ['rafiei@eng.au.dk']
# e2: ['me.gheisarnejad@gmail.com', 'hthfarsi@gmail.comand', 'khooban@ieee.org']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Automation & Control Systems', ' Engineering', ' Instruments & Instrumentation'] | journal1: IEEE ACCESS | journal2: IEEE T IND ELECTRON
# name1: Khooban, Mohammad-Hassan | inst1: Aarhus Univ, Dept Elect & Comp Engn, DK-8200 Aarhus, Denmark | title1: Deep Learning-Based Energy Management of an All-Electric City Bus With Wireless Power Transfer | site1: WOS
# name2: Khooban, Mohammad Hassan | inst2: Aarhus Univ, Dept Engn, DIGIT, Finlandsgade 22, DK-8200 Aarhus, Denmark | title2: A Novel Nonlinear Deep Reinforcement Learning Controller for DC-DC Power Buck Converters | site1: WOS
# inst: 0.8621198988804623 | title: 0.6944502845289153 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['rafiei@eng.au.dk']
# e2: ['rafiei@eng.au.dk']
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['and all-electric city bus', ' deep learning', ' energy management', ' Hybrid energy system', ' wireless power transfer'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Khooban, Mohammad-Hassan | inst1: Aarhus Univ, Dept Elect & Comp Engn, DK-8200 Aarhus, Denmark | title1: Deep Learning-Based Energy Management of an All-Electric City Bus With Wireless Power Transfer | site1: WOS
# name2: Khooban, Mohammad Hassan | inst2: Department of Electrical and Computer Engineering Aarhus University Aarhus Denmark | title2: Deep Learning-Based Energy Management of an All-Electric City Bus with Wireless Power Transfer | site1: SCOPUS
# inst: 0.5975486573047549 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['halhumade@kau.edu.sa', 'afali@ju.edu.sa', 'azahrani@kau.edu.sa', 'mrawa@kau.edu.sa', 'hr.hussien@psau.edu.sa']
# e2: ['hr.hussien@psau.edu.sa']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Mathematics'], ['Energy & Fuels', ' Nuclear Science & Technology'] | journal1: MATHEMATICS-BASEL | journal2: INT J ENERG RES
# name1: Rezk, Hegazy | inst1: Prince Sattam Bin Abdulaziz Univ, Coll Engn Wadi Addawaser, Al Kharj 11911, Saudi Arabia | title1: Optimal Parameter Estimation Methodology of Solid Oxide Fuel Cell Using Modern Optimization | site1: WOS
# name2: Rezk, Hegazy | inst2: Prince Sattam Bin Abdulaziz Univ, Coll Engn Wadi Addawaser, Al Kharj, Saudi Arabia | title2: An efficient modified artificial electric field algorithm for solving optimization problems and parameter estimation of fuel cell | site1: WOS
# inst: 0.9766075388026607 | title: 0.7035425738572113 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['halhumade@kau.edu.sa', 'afali@ju.edu.sa', 'azahrani@kau.edu.sa', 'mrawa@kau.edu.sa', 'hr.hussien@psau.edu.sa']
# e2: ['hr.hussien@psau.edu.sa']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Mathematics'], ['artificial electric field algorithm', " CEC'2020 test functions", ' fuel cell', ' optimization problems', ' parameter estimation'] | journal1: MATHEMATICS-BASEL | journal2: John Wiley and Sons Ltd
# name1: Rezk, Hegazy | inst1: Prince Sattam Bin Abdulaziz Univ, Coll Engn Wadi Addawaser, Al Kharj 11911, Saudi Arabia | title1: Optimal Parameter Estimation Methodology of Solid Oxide Fuel Cell Using Modern Optimization | site1: WOS
# name2: Rezk, Hegazy | inst2: College of Engineering at Wadi Addawaser Prince Sattam Bin Abdulaziz University Al-Kharj 11911 Saudi Arabia Electrical Engineering Department Faculty of Engineering Minia University Minia 61517 Egypt | title2: An efficient modified artificial electric field algorithm for solving optimization problems and parameter estimation of fuel cell | site1: SCOPUS
# inst: 0.6329757074140757 | title: 0.7035425738572113 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['jianguoliu@nju.edu.cn']
# e2: ['lijia0226@nju.edu.cn', 'jianguoliu@nju.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 7 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['Chemistry'] | journal1: J MATER CHEM A | journal2: ACS CATAL
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Applying machine learning to boost the development of high-performance membrane electrode assembly for proton exchange membrane fuel cells | site1: WOS
# name2: Liu, Jianguo | inst2: Nanjing Univ, Natl Lab Solid State Microstruct, Coll Engn & Appl Sci, Nanjing 210093, Peoples R China | title2: Machine Learning-Guided Discovery of Underlying Decisive Factors and New Mechanisms for the Design of Nonprecious Metal Electrocatalysts | site1: WOS
# inst: 0.8491344618332801 | title: 0.7140962050169212 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['jianguoliu@nju.edu.cn']
# e2: ['lijia0226@nju.edu.cn', 'jianguoliu@nju.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 4 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['Science & Technology - Other Topics', ' Materials Science'] | journal1: J MATER CHEM A | journal2: ACS APPL MATER INTER
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Applying machine learning to boost the development of high-performance membrane electrode assembly for proton exchange membrane fuel cells | site1: WOS
# name2: Liu, Jianguo | inst2: Zhejiang Tianneng Hydrogen Energy Technol Co Ltd, Hangzhou 313100, Zhejiang, Peoples R China | title2: Effectively Increasing Pt Utilization Efficiency of the Membrane Electrode Assembly in Proton Exchange Membrane Fuel Cells through Multiparameter Optimization Guided by Machine Learning | site1: WOS
# inst: 0.5803512990048755 | title: 0.7442174166379228 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['jianguoliu@nju.edu.cn']
# e2: ['lei.xing@eng.ox.ac.uk']
# joc: 0 | yop: 2021, 2022 | co_author_count: 1 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['AI', ' Machine learning', ' Multi-variable optimization', ' N2 crossover', ' PEM fuel cell'] | journal1: J MATER CHEM A | journal2: Elsevier B.V.
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Applying machine learning to boost the development of high-performance membrane electrode assembly for proton exchange membrane fuel cells | site1: WOS
# name2: Liu, Jianguo | inst2: National Laboratory of Solid State Microstructures College of Engineering and Applied Sciences Collaborative Innovation Center of Advanced Microstructures Nanjing University 22 Hankou Road Nanjing 210093 China | title2: Comparison of state-of-the-art machine learning algorithms and data-driven optimization methods for mitigating nitrogen crossover in PEM fuel cells | site1: SCOPUS
# inst: 0.7700822375214398 | title: 0.7093043166923519 | email: 0, funding: 0
# weigth: 1.2874888508428501
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['lijia0226@nju.edu.cn', 'jianguoliu@nju.edu.cn']
# e2: []
# joc: 0 | yop: 2021, 2022 | co_author_count: 3 | keyword: ['Chemistry'], ['artificial intelligence', ' data science', ' machine learning', ' membrane electrode assembly', ' proton exchange membrane electrolyzer'] | journal1: ACS CATAL | journal2: American Chemical Society
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Machine Learning-Guided Discovery of Underlying Decisive Factors and New Mechanisms for the Design of Nonprecious Metal Electrocatalysts | site1: WOS
# name2: Liu, Jianguo | inst2: National Laboratory of Solid State Microstructures College of Engineering and Applied Sciences Collaborative Innovation Center of Advanced Microstructures Nanjing University 22 Hankou Road Nanjing 210093 China | title2: Guiding the Optimization of Membrane Electrode Assembly in a Proton Exchange Membrane Water Electrolyzer by Machine Learning Modeling and Black-Box Interpretation | site1: SCOPUS
# inst: 0.7700822375214398 | title: 0.7068940566027807 | email: 0, funding: 0
# weigth: 1.5417731324827346
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['lijia0226@nju.edu.cn', 'jianguoliu@nju.edu.cn']
# e2: []
# joc: 0 | yop: 2022, 2022 | co_author_count: 5 | keyword: ['Science & Technology - Other Topics', ' Materials Science'], ['artificial intelligence', ' hydrogen energy', ' machine learning', ' membrane electrode assembly', ' proton exchange membrane fuel cells'] | journal1: ACS APPL MATER INTER | journal2: American Chemical Society
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Effectively Increasing Pt Utilization Efficiency of the Membrane Electrode Assembly in Proton Exchange Membrane Fuel Cells through Multiparameter Optimization Guided by Machine Learning | site1: WOS
# name2: Liu, Jianguo | inst2: National Laboratory of Solid State Microstructures College of Engineering and Applied Sciences Collaborative Innovation Center of Advanced Microstructures Nanjing University 22 Hankou Road Nanjing 210093 China | title2: Effectively Increasing Pt Utilization Efficiency of the Membrane Electrode Assembly in Proton Exchange Membrane Fuel Cells through Multiparameter Optimization Guided by Machine Learning | site1: SCOPUS
# inst: 0.7700822375214398 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering'], ['Energy & Fuels'] | journal1: CONTROL ENG PRACT | journal2: ENERGY REP
# name1: Yu, Tao | inst1: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title1: Optimal adaptive control for solid oxide fuel cell with operating constraints via large-scale deep reinforcement learning | site1: WOS
# name2: Yu, Tao | inst2: China Elect Power Res Inst Nanjing, Nanjing 210003, Peoples R China | title2: Multi-objective optimal control for proton exchange membrane fuel cell via large-scale deep reinforcement learning | site1: WOS
# inst: 0.6509811522980969 | title: 0.7655118593761993 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering'], ['Energy & Fuels'] | journal1: CONTROL ENG PRACT | journal2: FRONT ENERGY RES
# name1: Yu, Tao | inst1: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title1: Optimal adaptive control for solid oxide fuel cell with operating constraints via large-scale deep reinforcement learning | site1: WOS
# name2: Yu, Tao | inst2: China Elect Power Res Inst Nanjing, Nanjing, Peoples R China | title2: Temperature Control of Proton Exchange Membrane Fuel Cell Based on Machine Learning | site1: WOS
# inst: 0.648971477694882 | title: 0.7031763417305585 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['eplijiawen@mail.scut.edu.cn', 'taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering'], ['Energy & Fuels'] | journal1: CONTROL ENG PRACT | journal2: FRONT ENERGY RES
# name1: Yu, Tao | inst1: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title1: Optimal adaptive control for solid oxide fuel cell with operating constraints via large-scale deep reinforcement learning | site1: WOS
# name2: Yu, Tao | inst2: China Elect Power Res Inst, Nanjing, Peoples R China | title2: Control Method for PEMFC Using Improved Deep Deterministic Policy Gradient Algorithm | site1: WOS
# inst: 0.6824117911074432 | title: 0.7124340306158489 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering'], ['Energy & Fuels'] | journal1: CONTROL ENG PRACT | journal2: FRONT ENERGY RES
# name1: Yu, Tao | inst1: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title1: Optimal adaptive control for solid oxide fuel cell with operating constraints via large-scale deep reinforcement learning | site1: WOS
# name2: Yu, Tao | inst2: China Elect Power Res Inst Nanjing, Beijing, Peoples R China | title2: Distributed Imitation-Orientated Deep Reinforcement Learning Method for Optimal PEMFC Output Voltage Control | site1: WOS
# inst: 0.648971477694882 | title: 0.7224468536785252 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering'], ['Science & Technology - Other Topics', ' Energy & Fuels'] | journal1: CONTROL ENG PRACT | journal2: SUSTAIN ENERGY TECHN
# name1: Yu, Tao | inst1: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title1: Optimal adaptive control for solid oxide fuel cell with operating constraints via large-scale deep reinforcement learning | site1: WOS
# name2: Yu, Tao | inst2: South China Univ Technol, Guangzhou, Peoples R China | title2: Large-scale multi-agent deep reinforcement learning-based coordination strategy for energy optimization and control of proton exchange membrane fuel cell | site1: WOS
# inst: 0.9004495504495504 | title: 0.7281438975957694 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering'], ['Science & Technology - Other Topics', ' Energy & Fuels'] | journal1: CONTROL ENG PRACT | journal2: SUSTAIN ENERGY TECHN
# name1: Yu, Tao | inst1: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title1: Optimal adaptive control for solid oxide fuel cell with operating constraints via large-scale deep reinforcement learning | site1: WOS
# name2: Yu, Tao | inst2: Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650093, Yunnan, Peoples R China | title2: Distributed deep reinforcement learning-based coordination performance optimization method for proton exchange membrane fuel cell system | site1: WOS
# inst: 0.6995327374087794 | title: 0.7412388891889784 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering'], ['Coordinated control method', ' Distributed deep reinforcement learning', ' Gas supply system', ' Heat management system', ' Proton exchange membrane fuel cell'] | journal1: CONTROL ENG PRACT | journal2: Elsevier Ltd
# name1: Yu, Tao | inst1: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title1: Optimal adaptive control for solid oxide fuel cell with operating constraints via large-scale deep reinforcement learning | site1: WOS
# name2: Yu, Tao | inst2: College of Electric Power South China University of Technology Guangzhou 510640 China | title2: Data-driven coordinated control method for multiple systems in proton exchange membrane fuel cells using deep reinforcement learning | site1: SCOPUS
# inst: 0.7584924879042525 | title: 0.752898037927229 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['luis.silva@uftm.edu.hr']
# e2: ['luis.silva@uftm.edu.br']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry'], ['Chemistry'] | journal1: QUIM NOVA | journal2: REV VIRTUAL QUIM
# name1: da Silva, Luis Antonio | inst1: Univ Fed Triangulo Mineiro, Inst Ciencias Exatas Nat & Educ ICENE, Dept Quim, BR-38064200 Uberaba, MG, Brazil | title1: ELECTROLYTIC AND FUEL CELLS MADE WITH ALTERNATIVE MATERIALS FOR THE TEACHING OF ELECTROCHEMISTRY | site1: WOS
# name2: da Silva, Luis Antonio | inst2: Univ Fed Triangulo Mineiro, Inst Ciencias Exatas Nat & Educ, Dept Quim, Campus Univ, BR-38064200 Uberaba, MG, Brazil | title2: Exploring the Potentialities of Experimentation Using Electrolytic and Fuel Cells as a Teaching Resource in the High School Education | site1: WOS
# inst: 0.9355997951220981 | title: 0.7439507860560491 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyul@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Energy & Fuels', ' Engineering'] | journal1: IEEE ACCESS | journal2: APPL ENERG
# name1: Yang, Bo | inst1: Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650093, Yunnan, Peoples R China | title1: Adaptive Controller of PEMFC Output Voltage Based on Ambient Intelligence Large-Scale Deep Reinforcement Learning | site1: WOS
# name2: Yang, Bo | inst2: Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650500, Yunnan, Peoples R China | title2: A data-driven output voltage control of solid oxide fuel cell using multi-agent deep reinforcement learning | site1: WOS
# inst: 0.9910112359550561 | title: 0.7995878334997404 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyul@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 2 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Thermodynamics'] | journal1: IEEE ACCESS | journal2: CASE STUD THERM ENG
# name1: Yang, Bo | inst1: Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650093, Yunnan, Peoples R China | title1: Adaptive Controller of PEMFC Output Voltage Based on Ambient Intelligence Large-Scale Deep Reinforcement Learning | site1: WOS
# name2: Yang, Bo | inst2: Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650093, Peoples R China | title2: Large-scale multi-agent reinforcement learning-based method for coordinated output voltage control of solid oxide fuel cell | site1: WOS
# inst: 0.9647385212928283 | title: 0.7570462820713578 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyul@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 2 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['DC/DC converter', ' Fuel reformer', ' Large-scale deep reinforcement learning', ' Output voltage coordinated control', ' Pygmalion effect-based multi-agent double delay deep deterministic policy gradient algorithm (PEB-MA4DPG)', ' Solid oxide fuel cell (SOFC)'] | journal1: IEEE ACCESS | journal2: Elsevier Ltd
# name1: Yang, Bo | inst1: Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650093, Yunnan, Peoples R China | title1: Adaptive Controller of PEMFC Output Voltage Based on Ambient Intelligence Large-Scale Deep Reinforcement Learning | site1: WOS
# name2: Yang, Bo | inst2: Faculty of Electric Power Engineering Kunming University of Science and Technology Kunming China | title2: Large-scale multi-agent reinforcement learning-based method for coordinated output voltage control of solid oxide fuel cell | site1: SCOPUS
# inst: 0.6861802211521312 | title: 0.7570462820713578 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['emin1217@sina.com']
# e2: ['oyp9812@126.com']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Energy & Fuels'] | journal1: INT J HYDROGEN ENERG | journal2: ENERGY REP
# name1: Taheri, Bahman | inst1: Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran | title1: An optimal model identification for solid oxide fuel cell based on extreme learning machines optimized by improved Red Fox Optimization algorithm | site1: WOS
# name2: Taheri, Bahman | inst2: Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran | title2: Model identification of the Proton Exchange Membrane Fuel Cells by Extreme Learning Machine and a developed version of Arithmetic Optimization Algorithm | site1: WOS
# inst: 0.5648809523809524 | title: 0.7722148893655246 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['yangyi102@outlook.com']
# joc: 0 | yop: 2022, 2021 | co_author_count: 1 | keyword: ['Science & Technology - Other Topics', ' Energy & Fuels', ' Engineering'], ['Energy & Fuels', ' Engineering'] | journal1: IET RENEW POWER GEN | journal2: APPL ENERG
# name1: Zhang, Xiaoshun | inst1: Shantou Univ, Coll Engn, Shantou, Peoples R China | title1: Data-driven optimal PEMFC temperature control via curriculum guidance strategy-based large-scale deep reinforcement learning | site1: WOS
# name2: Zhang, Xiaoshun | inst2: Shantou Univ, Coll Engn, Shantou 515063, Peoples R China | title2: Extreme learning machine based meta-heuristic algorithms for parameter extraction of solid oxide fuel cells | site1: WOS
# inst: 0.9505102040816327 | title: 0.72282802754775 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Science & Technology - Other Topics', ' Energy & Fuels', ' Engineering'], [''] | journal1: IET RENEW POWER GEN | journal2: John Wiley and Sons Inc
# name1: Zhang, Xiaoshun | inst1: Shantou Univ, Coll Engn, Shantou, Peoples R China | title1: Data-driven optimal PEMFC temperature control via curriculum guidance strategy-based large-scale deep reinforcement learning | site1: WOS
# name2: Zhang, Xiaoshun | inst2: College of Engineering Shantou University Shantou 515063 China | title2: Data-driven optimal PEMFC temperature control via curriculum guidance strategy-based large-scale deep reinforcement learning | site1: SCOPUS
# inst: 0.6940604198668714 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['ajanovic@eeg.tuwien.ac.at', 'haas@eeg.tuwien.ac.at']
# e2: ['ajanovic@eeg.tuwien.ac.at']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Thermodynamics', ' Energy & Fuels'] | journal1: INT J HYDROGEN ENERG | journal2: ENERGY
# name1: Haas, R. | inst1: Tech Univ Wien, Energy Econ Grp, Vienna, Austria | title1: Prospects and impediments for hydrogen and fuel cell vehicles in the transport sector | site1: WOS
# name2: Haas, R. | inst2: Vienna Univ Technol, Energy Econ Grp, Vienna, Austria | title2: Prospects and impediments for hydrogen fuel cell buses | site1: WOS
# inst: 0.8560289263571077 | title: 0.8957147645382939 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['antguarino@unisa.it']
# e2: ['antguarino@unisa.it']
# joc: 0 | yop: 2022, 2021 | co_author_count: 1 | keyword: ['Thermodynamics', ' Energy & Fuels'], ['Chemistry', ' Electrochemistry', ' Energy & Fuels'] | journal1: ENERGY | journal2: INT J HYDROGEN ENERG
# name1: Spagnuolo, Giovanni | inst1: Politecn Turino, DET, Corso Duca degli Abruzzi 24, I-10129 Turin, TO, Italy | title1: A fast fuel cell parametric identification approach based on machine learning inverse models | site1: WOS
# name2: Spagnuolo, Giovanni | inst2: DIEM Univ Salerno, Via Giovanni Paolo II 132, I-84084 Fisciano, SA, Italy | title2: Automatic features extraction of faults in PEM fuel cells by a siamese artificial neural network | site1: WOS
# inst: 0.6319982604914112 | title: 0.7634824414715718 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['antguarino@unisa.it']
# e2: ['antguarino@unisa.it']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Thermodynamics', ' Energy & Fuels'], ['Inverse model', ' Machine learning regression', ' Parametric identification of equivalent circuit model'] | journal1: ENERGY | journal2: Elsevier Ltd
# name1: Spagnuolo, Giovanni | inst1: Politecn Turino, DET, Corso Duca degli Abruzzi 24, I-10129 Turin, TO, Italy | title1: A fast fuel cell parametric identification approach based on machine learning inverse models | site1: WOS
# name2: SPAGNUOLO, GIOVANNI | inst2: DIEM-University of Salerno Via Giovanni Paolo II 132 Fisciano SA  84084 Italy | title2: A fast fuel cell parametric identification approach based on machine learning inverse models | site1: SCOPUS
# inst: 0.6137235711148755 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['meiling.yue@femto-st.fr']
# e2: ['meiling.yue@femto-st.fr']
# joc: 0 | yop: 2021, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Automation & Control Systems', ' Engineering'] | journal1: INT J HYDROGEN ENERG | journal2: CONTROL ENG PRACT
# name1: Zerhouni, Noureddine | inst1: Beihang Univ, Sch Reliabil & Syst Engn, Beijing, Peoples R China | title1: A data-driven digital-twin prognostics method for proton exchange membrane fuel cell remaining useful life prediction | site1: WOS
# name2: Zerhouni, Noureddine | inst2: Univ Bourgogne Franche Comte, FEMTO ST Inst, FCLAB, ENSMM,CNRS, Belfort, France | title2: Degradation identification and prognostics of proton exchange membrane fuel cell under dynamic load | site1: WOS
# inst: 0.5991913821018545 | title: 0.7675247457856154 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['meiling.yue@femto-st.fr']
# e2: []
# joc: 0 | yop: 2021, 2022 | co_author_count: 1 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['PEMFC', ' Prognostics', ' RUL', ' Transfer Learning'] | journal1: INT J HYDROGEN ENERG | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Zerhouni, Noureddine | inst1: Beihang Univ, Sch Reliabil & Syst Engn, Beijing, Peoples R China | title1: A data-driven digital-twin prognostics method for proton exchange membrane fuel cell remaining useful life prediction | site1: WOS
# name2: Zerhouni, Noureddine | inst2: FEMTO-ST Institute (UMR CNRS 6174) Univ. Bourgogne Franche-Comte France FCLAB Research Federation (FR CNRS 3539) Univ. Bourgogne Franche-Comte France | title2: A Knowledge Transfer Approach for Online PEMFC Degradation prediction with Uncertainty Quantification | site1: SCOPUS
# inst: 0.5343342436574802 | title: 0.7618721212780619 | email: 0, funding: 0
# weigth: 1.3827269460809455
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['meiling.yue@femto-st.fr']
# e2: ['meiling.yue@femto-st.fr']
# joc: 0 | yop: 2022, 2022 | co_author_count: 3 | keyword: ['Automation & Control Systems', ' Engineering'], ['Dynamic load', ' Echo state network', ' Health indicator', ' PEM fuel cell', ' Prognostics'] | journal1: CONTROL ENG PRACT | journal2: Elsevier Ltd
# name1: Zerhouni, Noureddine | inst1: Beihang Univ, Sch Reliabil & Syst Engn, Beijing, Peoples R China | title1: Degradation identification and prognostics of proton exchange membrane fuel cell under dynamic load | site1: WOS
# name2: Zerhouni, Noureddine | inst2: FEMTO-ST Institute (UMR CNRS 6174) Univ. Bourgogne Franche-Comte France FCLAB Research Federation (FR CNRS 3539) Univ. Bourgogne Franche-Comte France | title2: Degradation identification and prognostics of proton exchange membrane fuel cell under dynamic load | site1: SCOPUS
# inst: 0.5343342436574802 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['heyang.yuan@temple.edu']
# e2: ['heyang.yuan@temple.edu']
# joc: 0 | yop: 2021, 2022 | co_author_count: 1 | keyword: ['Engineering', ' Environmental Sciences & Ecology', ' Water Resources'], ['Engineering', ' Environmental Sciences & Ecology', ' Water Resources'] | journal1: WATER RES | journal2: ENVIRON SCI-WAT RES
# name1: Yuan, Heyang | inst1: Temple Univ, Dept Civil & Environm Engn, 1947N 12th St, Philadelphia, PA 19122 USA | title1: Linking population dynamics to microbial kinetics for hybrid modeling of bioelectrochemical systems | site1: WOS
# name2: Yuan, Heyang | inst2: Temple Univ, Dept Civil & Environm Engn, Civil & Environm Engn, 1947 N 12th St, Philadelphia, PA 19122 USA | title2: Emerging investigator series: modeling of wastewater treatment bioprocesses: current development and future opportunities | site1: WOS
# inst: 0.9132535664979292 | title: 0.6331951786497242 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['swcha@snu.ac.kr']
# e2: ['swcha@snu.ac.kr']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Science & Technology - Other Topics', ' Engineering'] | journal1: IEEE ACCESS | journal2: INT J PR ENG MAN-GT
# name1: Cha, Suk Won | inst1: Seoul Natl Univ, Dept Mech Engn, Seoul 08826, South Korea | title1: Energy Management Strategy of Fuel Cell Electric Vehicles Using Model-Based Reinforcement Learning With Data-Driven Model Update | site1: WOS
# name2: Cha, Suk Won | inst2: Seoul Natl Univ, Sch Mech & Aerosp Engn, San 56-1, Seoul 151742, South Korea | title2: A Deep Reinforcement Learning-Based Energy Management Strategy for Fuel Cell Hybrid Buses | site1: WOS
# inst: 0.8616059379217275 | title: 0.7119281701444623 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['swcha@snu.ac.kr']
# e2: ['swcha@snu.ac.kr']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Deep reinforcement learning', ' Energy management strategy', ' Fuel cell degradation', ' Fuel cell hybrid bus', ' Reinforcement learning'] | journal1: IEEE ACCESS | journal2: Korean Society for Precision Engineeing
# name1: Cha, Suk Won | inst1: Seoul Natl Univ, Dept Mech Engn, Seoul 08826, South Korea | title1: Energy Management Strategy of Fuel Cell Electric Vehicles Using Model-Based Reinforcement Learning With Data-Driven Model Update | site1: WOS
# name2: Cha, Sukwon | inst2: Department of Mechanical Engineering Seoul National University Seoul South Korea Institute of Advanced Machines and Design Seoul National University Seoul 08826 South Korea | title2: A Deep Reinforcement Learning-Based Energy Management Strategy for Fuel Cell Hybrid Buses | site1: SCOPUS
# inst: 0.5719871383886072 | title: 0.7119281701444623 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['jose@lsu.edu', 'carges@lsu.edu']
# e2: ['chris.arges@psu.edu']
# joc: 0 | yop: 2021, 2022 | co_author_count: 2 | keyword: ['Computer Science'], ['Engineering'] | journal1: PATTERNS | journal2: IND ENG CHEM RES
# name1: Arges, Christopher G. | inst1: Louisiana State Univ, Cain Dept Chem Engn, Baton Rouge, LA 70803 USA | title1: Machine learning for guiding high-temperature PEM fuel cells with greater power density | site1: WOS
# name2: Arges, Christopher G. | inst2: Penn State Univ, Dept Chem Engn, University Pk, PA 16802 USA | title2: PemNet: A Transfer Learning-Based Modeling Approach of High-Temperature Polymer Electrolyte Membrane Electrochemical Systems | site1: WOS
# inst: 0.7184536225837853 | title: 0.6880151735546618 | email: 0, funding: 0
# weigth: 1.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['erdem.gunay@bilgi.edu.tr', 'yildirra@boun.edu.tr']
# e2: ['erdem.gunay@bilgi.edu.tr', 'yildirra@boun.edu.tr']
# joc: 0 | yop: 2021, 2022 | co_author_count: 2 | keyword: ['Science & Technology - Other Topics', ' Energy & Fuels'], ['Energy & Fuels', ' Engineering'] | journal1: RENEW ENERG | journal2: FUEL
# name1: Yildirim, Ramazan | inst1: Istanbul Bilgi Univ, Dept Energy Syst Engn, TR-34060 Eyup Istanbul, Turkey | title1: Exploring the critical factors of algal biomass and lipid production for renewable fuel production by machine learning | site1: WOS
# name2: Yildirim, Ramazan | inst2: Istanbul Bilgi Univ, Dept Energy Syst Engn, TR-34060 Eyupsultan Istanbul, Turkey | title2: <p>Analysis of lipid production from Yarrowia lipolytica for renewable fuel production by machine learning</p> | site1: WOS
# inst: 0.9714864864864865 | title: 0.7614791987673343 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['434581869@qq.com', 'lixi_wh@126.com']
# e2: ['raomumin@geg.com.cn', 'm202072698@hust.edu.cn', 'chenchuangting@geg.com.cn', 'xiongkai@geg.com.cn', 'limingfei@geg.com.cn', 'chenzhengpeng@geg.com.cn', 'dongjiangbo@geg.com.cn', 'xujunli@geg.com.cn', 'lixi_wh@126.com']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels', ' Materials Science'], ['Energy & Fuels'] | journal1: J POWER SOURCES | journal2: ENERGIES
# name1: Li, Xi | inst1: Wuhan Univ Sci & Technol, Hubei Prov Key Lab Intelligent Informat Proc & Re, Coll Comp Sci & Technol, Wuhan 430081, Hubei, Peoples R China | title1: Data-driven fault diagnosis method for the safe and stable operation of solid oxide fuel cells system | site1: WOS
# name2: Li, Xi | inst2: Guangdong Energy Grp Co Ltd, Guangzhou 510630, Peoples R China | title2: Data-Driven State Prediction and Analysis of SOFC System Based on Deep Learning Method | site1: WOS
# inst: 0.5395823593579554 | title: 0.8667388522779274 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['434581869@qq.com', 'lixi_wh@126.com']
# e2: ['m202072698@hust.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels', ' Materials Science'], ['deep learning', ' multi-step prediction', ' solid oxide fuel cell', ' state prediction'] | journal1: J POWER SOURCES | journal2: MDPI
# name1: Li, Xi | inst1: Wuhan Univ Sci & Technol, Hubei Prov Key Lab Intelligent Informat Proc & Re, Coll Comp Sci & Technol, Wuhan 430081, Hubei, Peoples R China | title1: Data-driven fault diagnosis method for the safe and stable operation of solid oxide fuel cells system | site1: WOS
# name2: Li, Xi | inst2: School of Artificial Intelligence and Automation Key Laboratory of Image Processing and Intelligent Control of Education Ministry Huazhong University of Science and Technology Wuhan Hubei  430074 China | title2: Data-Driven State Prediction and Analysis of SOFC System Based on Deep Learning Method | site1: SCOPUS
# inst: 0.649133771950814 | title: 0.8667388522779274 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['dingyu@buaa.edu.cn']
# e2: ['dingyu@buaa.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Automation & Control Systems', ' Engineering', ' Instruments & Instrumentation'], ['Deep learning', ' Prognostic and health management', ' Proton exchange membrane fuel cell', ' Remaining useful life prediction', ' Transfer learning'] | journal1: ISA T | journal2: ISA - Instrumentation, Systems, and Automation Society
# name1: Cheng, Yujie | inst1: UBFC, UFC, ENSMM, FEMTO ST Inst,CNRS,UMR 6174, 24 Rue Alain Savary, F-25000 Besancon, France | title1: Degradation prognosis for proton exchange membrane fuel cell based on hybrid transfer learning and intercell differences | site1: WOS
# name2: Cheng, Yujie | inst2: School of Reliability and Systems Engineering Beihang University China National Key Laboratory of Science and Technology on Reliability and Environmental Engineering China | title2: Degradation prognosis for proton exchange membrane fuel cell based on hybrid transfer learning and intercell differences | site1: SCOPUS
# inst: 0.46192473938469364 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['fukwun@mail.ntust.edu.tw']
# e2: ['fukwun@mail.ntust.edu.tw']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Engineering', ' Operations Research & Management Science'], ['ensemble model', ' long short-term memory', ' remaining useful life prediction'] | journal1: QUAL RELIAB ENG INT | journal2: John Wiley and Sons Ltd
# name1: Cheng, Xiao-Bin | inst1: Shanghai Elect Wind Power Grp, Intelligence Ctr, Shanghai, Peoples R China | title1: Ensemble model for the degradation prediction of proton exchange membrane fuel cell stacks | site1: WOS
# name2: Cheng, Xiaobin | inst2: Intelligence Center Shanghai Electric Wind Power Group Shanghai China | title2: Ensemble model for the degradation prediction of proton exchange membrane fuel cell stacks | site1: SCOPUS
# inst: 0.7745503655829743 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['akash@skit.ac.in', 'ashutoshsharma199566@gmail.com', 'drshalini@skit.ac.in']
# e2: ['akash@skit.ac.in']
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science'], ['IGWO algorithm', ' Parameter estimation', ' Photovoltaic module', ' Single and double diode model'] | journal1: EVOL INTELL | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Shekhawat, Shalini | inst1: Swami Keshvanand Inst Technol Management & Gramot, Dept Math, Jaipur, Rajasthan, India | title1: Parameter extraction of solar cell using intelligent grey wolf optimizer | site1: WOS
# name2: Shekhawat, Shalini | inst2: Department of Mathematics Swami Keshvanand Institute of Technology Management & Gramothan Jaipur India | title2: Parameter extraction of solar cell using intelligent grey wolf optimizer | site1: SCOPUS
# inst: 0.7324412173933377 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['lixf@email.sdu.edu.cn']
# e2: ['lixf@email.sdu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Hydrogen leak localization', ' Hydrogen safety', ' Machine learning', ' Parking garage'] | journal1: INT J HYDROGEN ENERG | journal2: Elsevier Ltd
# name1: Li, Xuefang | inst1: Tsinghua Univ, Key Lab Thermal Sci & Power Engn, Minist Educ, Beijing 100084, Peoples R China | title1: Leak localization using distributed sensors and machine learning for hydrogen releases from a fuel cell vehicle in a parking garage | site1: WOS
# name2: Li, Xuefang | inst2: Institute of Thermal Science and Technology Shandong University Jinan 250061 China | title2: Leak localization using distributed sensors and machine learning for hydrogen releases from a fuel cell vehicle in a parking garage | site1: SCOPUS
# inst: 0.6516740973861351 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['zeagon@snu.ac.kr', 'nevadielis@snu.ac.kr', 'wjd1055@gmail.com', 'minskim@snu.ac.kr']
# e2: ['minskim@snu.ac.kr']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Thermodynamics', ' Energy & Fuels'], ['Fault diagnosis', ' Polymer electrolyte membrane fuel cell (PEMFC)', ' Thermal management system'] | journal1: ENERGY | journal2: Elsevier Ltd
# name1: Kim, Min Soo | inst1: Korea Inst Machinery & Mat, Dept Clean Fuel & Power Generat, Daejon 34103, South Korea | title1: Fault diagnosis of thermal management system in a polymer electrolyte membrane fuel cell | site1: WOS
# name2: Kim, Min Soo | inst2: Department of Mechanical and Aerospace Engineering Seoul National University Seoul 08826 South Korea | title2: Fault diagnosis of thermal management system in a polymer electrolyte membrane fuel cell | site1: SCOPUS
# inst: 0.6488953488372093 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['Lvhong@tongji.edu.cn', 'yangdaijun@tongji.edu.cn']
# e2: ['Lvhong@tongji.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 7 | keyword: ['Energy & Fuels', ' Engineering'], ['Degradation prediction', ' Dynamic load cycle test', ' Gated recurrent unit', ' Long short-term memory', ' PEMFC'] | journal1: APPL ENERG | journal2: Elsevier Ltd
# name1: Zhang, Cunman | inst1: Northwestern Polytech Univ, Sch Astronaut, Xian 710072, Peoples R China | title1: Deep learning based prognostic framework towards proton exchange membrane fuel cell for automotive application | site1: WOS
# name2: Zhang, Cunman | inst2: Clean Energy Automotive Engineering Center and School of Automotive Studies Tongji University Shanghai 201804 China | title2: Deep learning based prognostic framework towards proton exchange membrane fuel cell for automotive application | site1: SCOPUS
# inst: 0.5952280510761834 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['yaron.michael@live.biu.ac.il']
# e2: ['yaron.michael@live.biu.ac.il']
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Environmental Sciences & Ecology'], ['Fire', ' Machine learning', ' Mediterranean', ' NDVI', ' Risk map', ' Time series'] | journal1: SCI TOTAL ENVIRON | journal2: Elsevier B.V.
# name1: Lensky, Itamar M. | inst1: Bar Ilan Univ, Data Sci Inst, Ramat Gan, Israel | title1: Forecasting fire risk with machine learning and dynamic information derived from satellite vegetation index time-series | site1: WOS
# name2: Lensky, Itamar M. | inst2: Department of Geography and Environment Bar-Ilan University Israel | title2: Forecasting fire risk with machine learning and dynamic information derived from satellite vegetation index time-series | site1: SCOPUS
# inst: 0.5893225117255154 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['weilu@umich.edu']
# e2: ['weilu@umich.edu']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics'], ['Applied Computing', ' Energy Storage', ' Materials Design'] | journal1: ISCIENCE | journal2: Elsevier Inc.
# name1: Lu, Wei | inst1: Univ Michigan, Dept Mech Engn, Ann Arbor, MI 48109 USA | title1: Machine learning toward advanced energy storage devices and systems | site1: WOS
# name2: Lu, Wei | inst2: Department of Mechanical Engineering University of Michigan Ann Arbor MI  48109 United States Department of Materials Science & Engineering University of Michigan Ann Arbor MI  48109 United States | title2: Machine learning toward advanced energy storage devices and systems | site1: SCOPUS
# inst: 0.5803426555807508 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['meng.ni@polyu.edu.hk', 'J.Xuan@lboro.ac.uk']
# e2: ['meng.ni@polyu.edu.hk']
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Thermodynamics', ' Energy & Fuels', ' Mechanics'], ['Artificial intelligence', ' Co-electrolysis', ' Genetic algorithm', ' Hybrid simulation', ' Renewable energy', ' Solid oxide electrolyser'] | journal1: ENERG CONVERS MANAGE | journal2: Elsevier Ltd
# name1: Xuan, Jin | inst1: Hong Kong Polytech Univ, Dept Bldg & Real Estate, Bldg Energy Res Grp, Hung Hom,Kowloon, Hong Kong, Peoples R China | title1: Enabling thermal-neutral electrolysis for CO2-to-fuel conversions with a hybrid deep learning strategy | site1: WOS
# name2: Xuan, Jin | inst2: Department of Chemical Engineering Loughborough University Loughborough United Kingdom | title2: Enabling thermal-neutral electrolysis for CO2-to-fuel conversions with a hybrid deep learning strategy | site1: SCOPUS
# inst: 0.6066889220579816 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['byxia@hust.edu.cn']
# e2: ['byxia@hust.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Chemistry'], [''] | journal1: ACCOUNTS CHEM RES | journal2: American Chemical Society
# name1: Xia, Bao Yu | inst1: Huazhong Univ Sci & Technol HUST, Key Lab Mat Chem Energy Convers & Storage, Key Lab Mat Chem & Serv Failure,Minist Educ, Wuhan Natl Lab Optoelect,Sch Chem & Chem Engn, Wuhan 430074, Peoples R China | title1: Advanced Platinum-Based Oxygen Reduction Electrocatalysts for Fuel Cells | site1: WOS
# ...
# name1: Yuan, Joshua S. | inst1: Natl Renewable Energy Lab, Renewable Resources & Enabling Sci Ctr, Golden, CO 80401 USA | title1: Machine learning-informed and synthetic biology-enabled semi-continuous algal cultivation to unleash renewable fuel productivity | site1: WOS
# name2: Yuan, Joshua S. | inst2: Department of Plant Pathology and Microbiology Texas A&M University College Station TX  77843 United States Synthetic and Systems Biology Innovation Hub (SSBiH) Texas A&M University College Station TX  77843 United States | title2: Machine learning-informed and synthetic biology-enabled semi-continuous algal cultivation to unleash renewable fuel productivity | site1: SCOPUS
# inst: 0.5542769716197709 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['gaudreau@uchicago.edu']
# e2: ['gaudreau@uchicago.edu']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Psychology'], ['Cell phones', ' Curiosity', ' Distraction', ' Media', ' Questions'] | journal1: DEV PSYCHOL | journal2: American Psychological Association
# name1: Golinkoff, Roberta Michnick | inst1: Univ Delaware, Coll Educ & Human Dev, Newark, DE USA | title1: What's in a Distraction? The Effect of Parental Cell Phone Use on Parents' and Children's Question-Asking | site1: WOS
# name2: Golinkoff, Roberta Michnick | inst2: College of Education and Human Development University of Delaware United States | title2: What’s in a Distraction? The Effect of Parental Cell Phone Use on Parents’ and Children’s Question-Asking | site1: SCOPUS
# inst: 0.6146780820291163 | title: 0.9885714285714287 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['alsaidi@pitt.edu']
# e2: ['alsaidi@pitt.edu']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Chemistry', ' Science & Technology - Other Topics', ' Materials Science', ' Physics'], [''] | journal1: J PHYS CHEM LETT | journal2: American Chemical Society
# name1: Saidi, Wissam A. | inst1: Univ Pittsburgh, Dept Mech Engn & Mat Sci, Pittsburgh, PA 15261 USA | title1: Optimizing the Catalytic Activity of Pd-Based Multinary Alloys toward Oxygen Reduction Reaction | site1: WOS
# name2: Saidi, Wissam A. | inst2: Department of Mechanical Engineering and Materials Science University of Pittsburgh Pittsburgh PA  15261 United States | title2: Optimizing the Catalytic Activity of Pd-Based Multinary Alloys toward Oxygen Reduction Reaction | site1: SCOPUS
# inst: 0.6317335416287578 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['p953678595@outlook.com']
# e2: ['p953678595@outlook.com']
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Data-driven', ' Deep learning', ' Embedded deployment', ' PEMFC system', ' Simulation datasets'] | journal1: INT J HYDROGEN ENERG | journal2: Elsevier Ltd
# name1: Hou, Zhongjun | inst1: Shanghai Hydrogen Prop Technol Co Ltd, Shanghai 201804, Peoples R China | title1: Real-time data-driven fault diagnosis of proton exchange membrane fuel cell system based on binary encoding convolutional neural network | site1: WOS
# name2: Hou, Zhongjun | inst2: Shanghai Hydrogen Propulsion Technology Co. Ltd. Shanghai 201804 China | title2: Real-time data-driven fault diagnosis of proton exchange membrane fuel cell system based on binary encoding convolutional neural network | site1: SCOPUS
# inst: 0.8871003067585843 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['chenqh@whut.edu.cn']
# e2: ['menglinli@ysu.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Air supply system', ' Auto-encoder network', ' Model reconstruction', ' Proton exchange membrane fuel cell', ' Sparse identification'], ['Energy efficiency', ' Fuel cell buses', ' Hierarchical predictive energy management', ' Launch control', ' Traffic information'] | journal1: Elsevier Ltd | journal2: Elsevier Ltd
# name1: Liu H. | inst1: State Key Laboratory of Industrial Control Technology College of Control Science and Engineering Zhejiang University Hangzhou Zhejiang  310027 China | title1: Data-driven reconstruction of interpretable model for air supply system of proton exchange membrane fuel cell | site1: SCOPUS
# name2: Liu H. | inst2: School of Vehicle and Energy Yanshan University Heibei 066004 China | title2: Hierarchical predictive energy management of fuel cell buses with launch control integrating traffic information | site1: SCOPUS
# inst: 0.6030958905379904 | title: 0.7282716858404932 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['gbjdsf@163.com']
# e2: ['gbjdsf@163.com']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Engineering'], ['Deep deterministic policy gradient', ' Electric vehicles', ' Fuel cell electric vehicles', ' Fuzzy logic controller', ' Intelligent solar parking lot'] | journal1: INT J ELEC POWER | journal2: Elsevier Ltd
# name1: Gong, Yanfeng | inst1: North China Elect Power Univ, Sch Elect & Elect Engn, Beijing 102206, Peoples R China | title1: <p>Energy management of intelligent solar parking lot with EV charging and FCEV refueling based on deep reinforcement learning</p> | site1: WOS
# name2: Gong, Yanfeng | inst2: School of Electrical & Electronic Engineering North China Electric Power University Beijing 102206 China | title2: Energy management of intelligent solar parking lot with EV charging and FCEV refueling based on deep reinforcement learning | site1: SCOPUS
# inst: 0.7310960281548516 | title: 0.8492599541380029 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['t.awotwe@aston.ac.uk', 'oluwatosin.ijaodola@uws.ac.uk', 'a.baroutaji@wlv.ac.uk', 'emmanuel.ogungbemi@uws.ac.uk', 'aolabi@sharjah.ac.ae']
# e2: ['t.awotwe@aston.ac.uk']
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Energy & Fuels'], ['Bipolar plate material', ' Fuel cell', ' Fuel consumption', ' Machine learning'] | journal1: ENERGIES | journal2: MDPI
# name1: Olabi, Abdul Ghani | inst1: Wolverhampton Univ, Sch Engn, Telford Innovat Campus, Telford TF2 9NT, Shrops, England | title1: Effect of Bipolar Plate Material on Proton Exchange Membrane Fuel Cell Performance | site1: WOS
# name2: Olabi, Abdul Ghani | inst2: Mechanical Engineering and Design School of Engineering and Applied Science Aston University Aston Triangle Birmingham B4 7ET United Kingdom Department of Sustainable and Renewable Energy Engineering University of Sharjah P.O. Box 27272 Sharjah United Arab Emirates | title2: Effect of Bipolar Plate Material on Proton Exchange Membrane Fuel Cell Performance | site1: SCOPUS
# inst: 0.540320524875154 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['francesco.ciucci@ust.hk']
# e2: ['francesco.ciucci@ust.hk']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Electrochemistry'], ['Distribution of relaxation times', ' Electrochemical impedance spectroscopy', ' Fuel cells', ' Gaussian processes', ' Lithium-ion batteries'] | journal1: ELECTROCHIM ACTA | journal2: Elsevier Ltd
# name1: Ciucci, Francesco | inst1: Oak Ridge Natl Lab, Ctr Nanophase Mat Sci, POB 2009, Oak Ridge, TN 37831 USA | title1: The deep-DRT: A deep neural network approach to deconvolve the distribution of relaxation times from multidimensional electrochemical impedance spectroscopy data | site1: WOS
# name2: Ciucci, Francesco | inst2: Department of Mechanical and Aerospace Engineering The Hong Kong University of Science and Technology Hong Kong Hong Kong Department of Chemical and Biological Engineering The Hong Kong University of Science and Technology Hong Kong Hong Kong | title2: The probabilistic deconvolution of the distribution of relaxation times with finite Gaussian processes | site1: SCOPUS
# inst: 0.47288158412560327 | title: 0.6867819591604758 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['lorenzo.malavasi@unipv.it']
# e2: ['lorenzo.malavasi@unipv.it']
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], [''] | journal1: J MATER CHEM A | journal2: Royal Society of Chemistry
# name1: Malavasi, Lorenzo | inst1: Chalmers Univ Technol, Dept Chem & Chem Engn, S-41296 Gothenburg, Sweden | title1: Structure-property correlation in oxide-ion and proton conductors for clean energy applications: recent experimental and computational advancements | site1: WOS
# name2: Malavasi, Lorenzo | inst2: Department of Chemistry University of Pavia Viale Taramelli 12 Pavia27100 Italy | title2: Structure-property correlation in oxide-ion and proton conductors for clean energy applications: Recent experimental and computational advancements | site1: SCOPUS
# inst: 0.5372948898265354 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['Guolonglu@jlu.edu.cn', 'liu_zhenning@jlu.edu.cn']
# e2: ['liu_zhenning@jlu.edu.cn\nLu,', 'Guolonglu@jlu.edu.cn']
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Channel geometry', ' Genetic algorithm', ' Machine learning', ' Proton exchange membrane fuel cell', ' Surrogate model'] | journal1: INT J HYDROGEN ENERG | journal2: Elsevier Ltd
# name1: Liu, Zhenning | inst1: Northeast Elect Power Univ, Sch Energy & Power Engn, Jilin 132012, Jilin, Peoples R China | title1: A novel surrogate model for channel geometry optimization of PEM fuel cell based on Bagging-SVM Ensemble Regression | site1: WOS
# name2: Liu, Zhenning | inst2: Key Laboratory of Bionic Engineering (Ministry of Education) College of Biological and Agricultural Engineering Jilin University Changchun 130022 China | title2: A novel surrogate model for channel geometry optimization of PEM fuel cell based on Bagging-SVM Ensemble Regression | site1: SCOPUS
# inst: 0.5580640610660516 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['']
# e2: []
# joc: 0 | yop: 2022, 2022 | co_author_count: 5 | keyword: ['Energy & Fuels', ' Engineering'], ['Carbon deposition', ' Deep learning', ' Global sensitivity analysis', ' Multi-objective optimization', ' Solid oxide fuel cell'] | journal1: APPL ENERG | journal2: Elsevier Ltd
# name1: Jiao, Kui | inst1: Tsinghua Univ, Dept Energy & Power Engn, Beijing 100084, Peoples R China | title1: Coupling deep learning and multi-objective genetic algorithms to achieve high performance and durability of direct internal reforming solid oxide fuel cell | site1: WOS
# name2: Jiao, Kui | inst2: State Key Laboratory of Engines Tianjin University 135 Yaguan Road Tianjin China | title2: Coupling deep learning and multi-objective genetic algorithms to achieve high performance and durability of direct internal reforming solid oxide fuel cell | site1: SCOPUS
# inst: 0.6027777777777777 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['giangtle@uw.edu']
# e2: ['giangtle@uw.edu']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Electrochemistry', ' Materials Science'], [''] | journal1: J ELECTROCHEM SOC | journal2: IOP Publishing Ltd
# name1: Adler, S. B. | inst1: Univ Calif Irvine, Natl Fuel Cell Res Ctr, Irvine, CA 92697 USA | title1: Simulation-Informed Machine Learning Diagnostics of Solid Oxide Fuel Cell Stack with Electrochemical Impedance Spectroscopy | site1: WOS
# name2: Adler S.B. | inst2: Department of Chemical Engineering University of Washington Seattle WA  98105 United States | title2: Simulation-Informed Machine Learning Diagnostics of Solid Oxide Fuel Cell Stack with Electrochemical Impedance Spectroscopy | site1: SCOPUS
# inst: 0.5703663996346924 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['sakthidasan.sankaran@gmail.com', 'c.bayeh@hotmail.com', 'ursula.eicker@concordia.ca']
# e2: ['sakthidasan.sankaran@gmail.com']
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Science & Technology - Other Topics', ' Environmental Sciences & Ecology'], ['electric vehicle', ' MPC controller', ' MPPT', ' multi-objective optimal energy management system', ' multi-renewable energy sources', ' reinforcement learning'] | journal1: SUSTAINABILITY-BASEL | journal2: MDPI
# name1: Eicker, Ursula | inst1: Concordia Univ, Canada Excellence Res Chair Team, Montreal, PQ H3G 1M8, Canada | title1: Design of Multi-Renewable Energy Storage and Management System Using RL-ICSO Based MPPT Scheme for Electric Vehicles | site1: WOS
# name2: Eicker, Ursula | inst2: Canada Excellence Research Chair Team Concordia University Montreal QC  H3G 1M8 Canada | title2: Design of Multi-Renewable Energy Storage and Management System Using RL-ICSO Based MPPT Scheme for Electric Vehicles | site1: SCOPUS
# inst: 0.799803955203764 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['khoobanmohammadhassan_1', 'khoobanmohammadhassan_2', 'rezkhegazy_1', 'rezkhegazy_2', 'liujianguo_1', 'liujianguo_2', 'liujianguo_3', 'yutao_1', 'yutao_2', 'yutao_3', 'yutao_4', 'yutao_5', 'yutao_6', 'yutao_7', 'dasilvaluisantonio_1', 'yangbo_1', 'yangbo_2', 'yangbo_3', 'zhangxiaoshun_1', 'zhangxiaoshun_2', 'haasr_1', 'spagnuologiovanni_1', 'spagnuologiovanni_2', 'zerhouninoureddine_1', 'zerhouninoureddine_2', 'yuanheyang_1', 'chasukwon_1', 'chasukwon_2', 'yildirimramazan_1', 'lixi_1', 'lixi_2', 'chengyujie_1', 'chengxiaobin_1', 'shekhawatshalini_1', 'lixuefang_1', 'kimminsoo_1', 'zhangcunman_1', 'lenskyitamarm_1', 'luwei_1', 'xuanjin_1', 'xiabaoyu_1', 'hwangjinha_1', 'wangyun_1', 'huming_1', 'garciamartinhector_1', 'juradofrancisco_1', 'pfeifernorbert_1', 'liuweiguo_1', 'ushas_1', 'lijia_1', 'raceanumircea_1', 'zhangzehui_1', 'lijian_1', 'liangxuedong_1', 'wangqiuwang_1', 'xuwei_1', 'lingchen_1', 'liuzhipan_1', 'zhangqi_1', 'zhongzheng_1', 'ramanvenkat_1', 'linzijing_1', 'dharbiproranjan_1', 'berbermohamedr_1', 'ribeirofabioh_1', 'samuelsenscott_1', 'linbin_1', 'liuzhixiang_1', 'muyeensm_1', 'zhengchunhua_1', 'linxianke_1', 'deepan_1', 'huanghaitao_1', 'jinnouchiryosuke_1', 'matsunofumitoshi_1', 'brusgrzegorz_1', 'lekerjens_1', 'liaoyuhui_1', 'barambonesoscar_1', 'gaoshuyan_1', 'santhanamvenugopal_1', 'hsuchanghung_1', 'zhaodongdong_1', 'raibeena_1', 'bucknallrichard_1', 'xuhongming_1', 'sunchao_1', 'suzukik_1', 'hadjidemetrioustathis_1', 'hayashiyasuhiro_1', 'jervisrhodri_1', 'hameyerkay_1', 'malekkourosh_1', 'liyunqi_1', 'nangiauma_1', 'maronefederica_1', 'grondinperezbrigitte_1', 'shenjun_1', 'fekihafef_1', 'chengchinkui_1', 'grassetlaurent_1', 'wangweishan_1', 'ghadiminoradin_1', 'wangxiaonan_1', 'nazhixiong_1', 'yuanjoshuas_1', 'golinkoffrobertamichnick_1', 'saidiwissama_1', 'houzhongjun_1', 'gongyanfeng_1', 'olabiabdulghani_1', 'ciuccifrancesco_1', 'malavasilorenzo_1', 'liuzhenning_1', 'jiaokui_1', 'adlersb_1', 'eickerursula_1']

# %%
deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        if name_sim >= 0.8 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
                
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                                
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
                    flag = True
                    break
            if flag :
                break
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# e1: ['zrahmani@nit.ac.ir']
# e2: ['zrahmani@nit.ac.ir']
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Automation & Control Systems'], ['Direct methanol fuel cell', ' frequency response', ' iterative learning control', ' model predictive control', ' norm optimal'] | journal1: P I MECH ENG I-J SYS | journal2: SAGE Publications Ltd
# name1: Zamani, Mohammadreza | inst1: Babol Noshirvani Univ Technol, Fac Elect & Comp Engn, Babol Sar 471487167, Iran | title1: Direct methanol fuel cell modeling based on the norm optimal iterative learning control | site1: WOS
# name2: Zamani M. | inst2: Faculty of Electrical and Computer Engineering Babol Noshirvani University of Technology Babol Iran | title2: Direct methanol fuel cell modeling based on the norm optimal iterative learning control | site1: SCOPUS
# inst: 0.6631291821165239 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['echristofa@engin.umass.edu']
# e2: ['Ahmed.khadhraoui@fst.utm.tn', 't.selmi@issatkr.u-kairouan.tn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Transportation'], ['Computer Science'] | journal1: TRANSPORT REV | journal2: INT J COMPUT SCI NET
# name1: Christofa, Eleni | inst1: Yale Univ, Sch Publ Hlth, Environm Hlth Sci, New Haven, CT USA | title1: Transitioning to zero-emission bus fleets: state of practice of implementations in the United States | site1: WOS
# name2: Cherif, Adnene | inst2: Tunis Al Manar Univ, Fac Sci Tunis, Anal & Treatment Elect & Energy Signals & Syst SS, Tunis 2092, Tunisia | title2: Energy Management and Performance Evaluation of Fuel Cell Battery Based Electric Vehicle | site1: WOS
# inst: 0.5803717131087529 | title: 0.6328409090909091 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['ramzibenmessaoud@gmail.com']
# e2: ['ramzibenmessaoud@gmail.com']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Engineering'], ['Moth-flame optimization', ' Parameter estimation', ' PEMFC modeling', ' Uncertainties measurements'] | journal1: CHEM ENG SCI | journal2: Elsevier Ltd
# name1: Hajji, Salah | inst1: Ctr Rech & Technol Energie, Lab Nanomat & Syst Energies Renouvelables, BP 95, Hammam Lif 2050, Tunisia | title1: PEM fuel cell model parameters extraction based on moth-flame optimization | site1: WOS
# name2: Hajji S. | inst2: Laboratoire de nanomatèriaux et des systèmes pour les énergies renouvelables Centre de Recherches et des Technologies de l'Energie BP. 95 Hammam Lif 2050 Tunisia | title2: PEM fuel cell model parameters extraction based on moth-flame optimization | site1: SCOPUS
# inst: 0.6661259195096374 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['eaholm@andrew.cmu.edu']
# e2: ['eaholm@andrew.cmu.edu']
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Materials Science', ' Metallurgy & Metallurgical Engineering', ' Mineralogy', ' Mining & Mineral Processing'], [''] | journal1: JOM-US | journal2: Springer
# name1: Holm, Elizabeth A. | inst1: US DOE, Natl Energy Technol Lab, Morgantown, WV 26505 USA | title1: Microstructure Generation via Generative Adversarial Network for Heterogeneous, Topologically Complex 3D Materials | site1: WOS
# name2: Holm E.A. | inst2: US DOE National Energy Technology Laboratory Pittsburgh PA  15236 United States Materials Science and Engineering Carnegie Mellon University Pittsburgh PA  15213 United States | title2: Microstructure Generation via Generative Adversarial Network for Heterogeneous, Topologically Complex 3D Materials | site1: SCOPUS
# inst: 0.5907673946771691 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['chenjunsheng@hnu.edu.cn', 'zhangtianxia918@163.com']
# e2: ['pmz@gxu.edu.cn', 'wangqiwei1987@hotmail.com']
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Thermodynamics', ' Energy & Fuels', ' Mechanics'], ['Energy & Fuels', ' Nuclear Science & Technology'] | journal1: ENERG CONVERS MANAGE | journal2: INT J ENERG RES
# name1: Wang, Mingrui | inst1: Dongfeng Motor Corp Technol Ctr, Wuhan, Peoples R China | title1: Data-driven flooding fault diagnosis method for proton-exchange membrane fuel cells using deep learning technologies | site1: WOS
# name2: Wang, Qiwei | inst2: Tongji Univ, Sch Automot Studies, Postdoctoral Stn Mech Engn, Shanghai, Peoples R China | title2: Exploring the direct influence of control parameters of experimental facility for fuel cells based on improved generalized regression neural network | site1: WOS
# inst: 0.6289461329941091 | title: 0.7257263769950822 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['wang.peng@buaa.edu.cn']
# e2: ['wang.peng@buaa.edu.cn', 'akeelshah@cqu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer model', ' Fuel cells', ' Gaussian process model', ' Linear model of coregionalisation', ' Machine learning', ' Multi-task'], ['Chemistry', ' Electrochemistry', ' Energy & Fuels', ' Materials Science'] | journal1: Elsevier B.V. | journal2: J POWER SOURCES
# name1: Shah, Akeel A. | inst1: Key Laboratory of Low-grade Energy Utilization Technologies and Systems MOE Chongqing University Chongqing 400030 China | title1: A new multi-task learning framework for fuel cell model outputs in high-dimensional spaces | site1: SCOPUS
# name2: Shah, A. A. | inst2: Chongqing Univ, MOE, Key Lab Low Grade Energy Utilizat Technol & Syst, Chongqing 400030, Peoples R China | title2: A new multi-task learning framework for fuel cell model outputs in high-dimensional spaces | site1: WOS
# inst: 0.7180767293953018 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['lorenzo.usai@ntnu.no']
# e2: ['lorenzo.usai@ntnu.no']
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Science & Technology - Other Topics', ' Engineering', ' Environmental Sciences & Ecology'], ['Electric vehicles', ' Fuel cell electric vehicles', ' Fuel cell system', ' Life cycle assessment', ' Transport sector'] | journal1: J CLEAN PROD | journal2: Elsevier Ltd
# name1: Stromman, Anders Hammer | inst1: Norwegian Univ Sci & Technol, Dept Energy & Proc Engn, Trondheim, Norway | title1: Life cycle assessment of fuel cell systems for light duty vehicles, current state-of-the-art and future impacts | site1: WOS
# name2: Strømman, Anders Hammer | inst2: Industrial Ecology Programme Department of Energy and Process Engineering Norwegian University of Science and Technology Høgskoleringen 5 Trondheim 7491 Norway | title2: Life cycle assessment of fuel cell systems for light duty vehicles, current state-of-the-art and future impacts | site1: SCOPUS
# inst: 0.5890590834291382 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['day01@fayoum.edu.eg']
# e2: ['day01@fayoum.edu.eg']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Thermodynamics', ' Energy & Fuels', ' Mechanics'], ['Comprehensive learning', ' Dynamic multi-swarm', ' Marine predator algorithm (MPA)', ' Parameters estimation', ' Solid oxide fuel cell'] | journal1: ENERG CONVERS MANAGE | journal2: Elsevier Ltd
# name1: Fathy, Ahmed | inst1: Jouf Univ, Fac Engn, Elect Engn Dept, Al Jouf, Saudi Arabia | title1: Parameters identification of solid oxide fuel cell for static and dynamic simulation using comprehensive learning dynamic multi-swarm marine predators algorithm | site1: WOS
# name2: Fathy A. | inst2: Electrical Engineering Department Faculty of Engineering Jouf University Al-Jouf Saudi Arabia Electrical Power Machine Department Faculty of Engineering Zagazig University Zagazig Egypt | title2: Parameters identification of solid oxide fuel cell for static and dynamic simulation using comprehensive learning dynamic multi-swarm marine predators algorithm | site1: SCOPUS
# inst: 0.5855911381335109 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['jereff@qlu.edu.cn']
# e2: ['jereff@qlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Thermodynamics', ' Energy & Fuels'], ['Hybrid energy system', ' Improved locust swarm optimization algorithm', ' Lithium-ion battery', ' Locomotive', ' PEMFC'] | journal1: ENERGY | journal2: Elsevier Ltd
# name1: Yousefi, Nasser | inst1: Islamic Azad Univ, Karaj Branch, Tehran, Iran | title1: Optimal hybrid energy system for locomotive utilizing improved Locust Swarm optimizer | site1: WOS
# name2: Yousefi N. | inst2: Islamic Azad University Karaj Branch Iran | title2: Optimal hybrid energy system for locomotive utilizing improved Locust Swarm optimizer | site1: SCOPUS
# inst: 0.8962836006738446 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['tanveer.ahmad.pk11@gmail.com']
# e2: ['chenhuicui@tongji.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Engineering', ' Environmental Sciences & Ecology'], ['Chemistry', ' Electrochemistry', ' Energy & Fuels'] | journal1: J CLEAN PROD | journal2: INT J HYDROGEN ENERG
# name1: Chen, Huanxin | inst1: Huazhong Univ Sci & Technol, Sch Energy & Power Engn, Wuhan, Peoples R China | title1: Artificial intelligence in sustainable energy industry: Status Quo, challenges and opportunities | site1: WOS
# name2: Chen, Jinrui | inst2: CHONGQING CHANGAN New Energy Automobile Technol C, Chongqing 401120, Peoples R China | title2: Online voltage consistency prediction of proton exchange membrane fuel cells using a machine learning method | site1: WOS
# inst: 0.6267270740954951 | title: 0.6953347578347578 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['ryno.laubscher@uct.ac.za']
# e2: ['ryno.laubscher@uct.ac.za']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['Combustion computational fluid dynamics', ' Deep neural networks', ' Surrogate modelling', ' Variational autoencoders'] | journal1: APPL SOFT COMPUT | journal2: Elsevier Ltd
# name1: Rousseau, Pieter | inst1: Univ Cape Town, Dept Mech Engn, Appl Thermal Fluid Proc Modelling Res Unit, Lib Rd, ZA-7701 Cape Town, South Africa | title1: An integrated approach to predict scalar fields of a simulated turbulent jet diffusion flame using multiple fully connected variational autoencoders and MLP networks | site1: WOS
# name2: Rousseau P. | inst2: Department of Mechanical Engineering Applied Thermal-Fluid Process Modelling Research Unit University of Cape Town Library Rd Rondebosch Cape Town 7701 South Africa | title2: An integrated approach to predict scalar fields of a simulated turbulent jet diffusion flame using multiple fully connected variational autoencoders and MLP networks | site1: SCOPUS
# inst: 0.6923185686706366 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['linxinyoou@fzu.edu.cn', '369728624@qq.com', 'linxyfzu@126.com']
# e2: ['linxinyoou@fzu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Automation & Control Systems', ' Engineering', ' Instruments & Instrumentation'], ['Energy management', ' forgetting factor', ' fuel cell vehicle', ' online updating'] | journal1: IEEE T IND ELECTRON | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Xia, Yutian | inst1: Fuzhou Univ, Sch Mech Engn & Automat, Fuzhou 350108, Peoples R China | title1: Online Recursive Power Management Strategy Based on the Reinforcement Learning Algorithm With Cosine Similarity and a Forgetting Factor | site1: WOS
# name2: Xia Y. | inst2: School of Mechanical Engineering and Automation Fuzhou University Fuzhou China | title2: Online Recursive Power Management Strategy Based on the Reinforcement Learning Algorithm with Cosine Similarity and a Forgetting Factor | site1: SCOPUS
# inst: 0.6140334338863752 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['antmyl@chalmers.se']
# e2: ['antmyl@chalmers.se']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Nuclear Science & Technology'], ['Core barrel vibration', ' Diffusion approximation', ' Fuel assembly vibration', " Green's function method", ' Neutron noise', ' Noise solver', ' Reactor diagnostics'] | journal1: ANN NUCL ENERGY | journal2: Elsevier Ltd
# name1: Demaziere, Christophe | inst1: Chalmers Univ Technol, Dept Phys, Div Subat High Energy & Plasma Phys, SE-41296 Gothenburg, Sweden | title1: CORE SIM plus : A flexible diffusion-based solver for neutron noise simulations | site1: WOS
# name2: Demazière, Christophe | inst2: Chalmers University of Technology Department of Physics Division of Subatomic High Energy and Plasma Physics Gothenburg SE-412 96 Sweden | title2: CORE SIM+: A flexible diffusion-based solver for neutron noise simulations | site1: SCOPUS
# inst: 0.8512918070453989 | title: 0.8971759170302607 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['lvxueqin@shiep.edu.cn']
# e2: ['smchen@jlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Energy & Fuels'], ['Polymer Science'] | journal1: RENEW ENERG | journal2: MACROMOL THEOR SIMUL
# name1: Zhang, Yangyang | inst1: Shanghai Univ Elect Power, Sch Automat Engn, Shanghai 200090, Peoples R China | title1: Energy management and optimization of PEMFC/battery mobile robot based on hybrid rule strategy and AMPSO | site1: WOS
# name2: Zhang, Tao | inst2: Jilin Univ, Coll Automot Engn, State Key Lab Automot Simulat & Control, Changchun 130022, Peoples R China | title2: The Influence of Microstructure on Sound Absorption of Polyurethane Foams through Numerical Simulation | site1: WOS
# inst: 0.6573142135642136 | title: 0.6802470405411581 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['lvxueqin@shiep.edu.cn']
# e2: ['smchen@jlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Energy & Fuels'], ['Polymer Science'] | journal1: RENEW ENERG | journal2: MACROMOL THEOR SIMUL
# name1: Zhang, Yangyang | inst1: Shanghai Univ Elect Power, Sch Automat Engn, Shanghai 200090, Peoples R China | title1: Energy management and optimization of PEMFC/battery mobile robot based on hybrid rule strategy and AMPSO | site1: WOS
# name2: Zhang, Tao | inst2: Jilin Univ, Coll Automot Engn, State Key Lab Automot Simulat & Control, Changchun 130022, Peoples R China | title2: The Influence of Microstructure on Sound Absorption of Polyurethane Foams through Numerical Simulation | site1: WOS
# inst: 0.6573142135642136 | title: 0.6802470405411581 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['lixf@email.sdu.edu.cn']
# e2: ['linxinyoou@fzu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Thermodynamics', ' Energy & Fuels'] | journal1: INT J HYDROGEN ENERG | journal2: ENERGY
# name1: Li, Xuefang | inst1: Tsinghua Univ, Key Lab Thermal Sci & Power Engn, Minist Educ, Beijing 100084, Peoples R China | title1: Leak localization using distributed sensors and machine learning for hydrogen releases from a fuel cell vehicle in a parking garage | site1: WOS
# name2: Li, Xuefan | inst2: Fuzhou Univ, Coll Mech Engn & Automat, Fuzhou 350116, Peoples R China | title2: Online correction predictive energy management strategy using the Q-learning based swarm optimization with fuzzy neural network | site1: WOS
# inst: 0.600757363253857 | title: 0.7037291084011894 | email: 0, funding: 0
# weigth: 1.6321205588285577
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['dongda.zhang@manchester.ac.uk']
# e2: ['lihongwei@neepu.edu.cn', 'Guolonglu@jlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Biotechnology & Applied Microbiology', ' Engineering'], ['Thermodynamics', ' Energy & Fuels', ' Mechanics'] | journal1: BIOCHEM ENG J | journal2: ENERG CONVERS MANAGE
# name1: Zhang, Dongda | inst1: Imperial Coll London, Dept Chem Engn, South Kensington SW7 2AZ, England | title1: Machine learning for biochemical engineering: A review | site1: WOS
# name2: Huang, Na | inst2: Jilin Univ, Coll Biol & Agr Engn, Key Lab Bion Engn, Minist Educ, Changchun 130022, Jilin, Peoples R China | title2: Multi-objective optimization of PEM fuel cell by coupled significant variables recognition, surrogate models and a multi-objective genetic algorithm | site1: WOS
# inst: 0.6085176327004655 | title: 0.6079212545879212 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['dongda.zhang@manchester.ac.uk']
# e2: ['smchen@jlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Biotechnology & Applied Microbiology', ' Engineering'], ['Polymer Science'] | journal1: BIOCHEM ENG J | journal2: MACROMOL THEOR SIMUL
# name1: Zhang, Dongda | inst1: Imperial Coll London, Dept Chem Engn, South Kensington SW7 2AZ, England | title1: Machine learning for biochemical engineering: A review | site1: WOS
# name2: Zhang, Tao | inst2: Jilin Univ, Coll Automot Engn, State Key Lab Automot Simulat & Control, Changchun 130022, Peoples R China | title2: The Influence of Microstructure on Sound Absorption of Polyurethane Foams through Numerical Simulation | site1: WOS
# inst: 0.6298445644628002 | title: 0.6026143790849673 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['1277861501@hrbeu.edu.cn']
# e2: ['smchen@jlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Robotics', ' Neurosciences & Neurology'], ['Polymer Science'] | journal1: FRONT NEUROROBOTICS | journal2: MACROMOL THEOR SIMUL
# name1: Zhang, Hongquan | inst1: Harbin Engn Univ, Sch Automat, Harbin, Peoples R China | title1: A New Hydrogen Sensor Fault Diagnosis Method Based on Transfer Learning With LeNet-5 | site1: WOS
# name2: Zhang, Tao | inst2: Jilin Univ, Coll Automot Engn, State Key Lab Automot Simulat & Control, Changchun 130022, Peoples R China | title2: The Influence of Microstructure on Sound Absorption of Polyurethane Foams through Numerical Simulation | site1: WOS
# inst: 0.6431216931216931 | title: 0.6925364348638006 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['yfwang@mail.neu.edu.cn']
# e2: ['fyan@suda.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science'], ['Chemistry', ' Energy & Fuels', ' Engineering', ' Environmental Sciences & Ecology'] | journal1: APPL SOFT COMPUT | journal2: ENERG ENVIRON SCI
# name1: Xu, Jianfeng | inst1: Huazhong Univ Sci & Technol, State Key Lab Digital Mfg Equipment & Technol, Wuhan 430074, Peoples R China | title1: Observer-based adaptive neural network control for PEMFC air-feed subsystem | site1: WOS
# name2: Yan, Feng | inst2: Soochow Univ, Coll Chem Chem Engn & Mat Sci, Suzhou 215123, Peoples R China | title2: Machine learning analysis and prediction models of alkaline anion exchange membranes for fuel cells | site1: WOS
# inst: 0.6551766513056836 | title: 0.6416663813273983 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['essam.halim@mu.edu.eg', 'bahaa_helmy@fcis.bsu.edu.eg', 'hr.hussien@psau.edu.sa', 'ahmed.nassef2004@yahoo.co.uk']
# e2: ['a.nasef@psau.edu.sa']
# joc: 0 | yop: 2021, 2022 | co_author_count: 2 | keyword: ['Automation & Control Systems', ' Computer Science', ' Engineering'], ['Adaptive guided differential evolution algorithm', ' mAGDE', ' Meta-heuristic algorithms', ' Parameter estimation', ' Solid oxide fuel cell'] | journal1: ENG APPL ARTIF INTEL | journal2: Elsevier Ltd
# name1: Nassef, Ahmed M. | inst1: Prince Sattam Bin Abdulaziz Univ, Coll Engn Wadi Addawaser, Al Kharj 11911, Saudi Arabia | title1: An enhanced Archimedes optimization algorithm based on Local escaping operator and Orthogonal learning for PEM fuel cell parameter identification | site1: WOS
# name2: Nassef A.M. | inst2: College of Engineering at Wadi Addawaser Prince Sattam Bin Abdulaziz University Al-Kharj 11911 Saudi Arabia Computers and Automatic Control Engineering Department Faculty of Engineering Tanta University Tanta 31733 Egypt | title2: A modified adaptive guided differential evolution algorithm applied to engineering applications | site1: SCOPUS
# inst: 0.6193850267379679 | title: 0.6701185011209566 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['czzhang@cqu.edu.cn', 'a.foley@qub.ac.uk']
# e2: ['czzhang@cqu.edu.cn\nFoley,', 'a.foley@qub.ac.uk']
# joc: 0 | yop: 2021, 2021 | co_author_count: 5 | keyword: ['Thermodynamics', ' Energy & Fuels'], ['Dynamic performance', ' Fuel cell', ' Hydrogen pressure', ' Intelligent control', ' Mass transfer', ' Power prediction'] | journal1: ENERGY | journal2: Elsevier Ltd
# name1: Foley, Aoife M. | inst1: Queens Univ Belfast, Sch Mech & Aerosp Engn, Belfast BT9 5AH, Antrim, North Ireland | title1: Enhancing reactant mass transfer inside fuel cells to improve dynamic performance via intelligent hydrogen pressure control | site1: WOS
# name2: Foley, Aoife | inst2: School of Mechanical and Aerospace Engineering Queen's University Belfast Belfast BT9 5AH United Kingdom Civil Structural and Environmental Engineering Trinity College Dublin The University of Dublin Ireland | title2: Enhancing reactant mass transfer inside fuel cells to improve dynamic performance via intelligent hydrogen pressure control | site1: SCOPUS
# inst: 0.5997555439147896 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['durairasan.m1026@gmail.com']
# e2: ['durairasan.m1026@gmail.com']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Engineering', ' Mathematics'], ['demand response', ' energy management', ' energy resources', ' enhanced EHOA', ' micro grid', ' predicted load requirement', ' system modeling'] | journal1: INT J NUMER MODEL EL | journal2: John Wiley and Sons Ltd
# name1: Balasubramanian, Divya | inst1: Dell EMC, Chennai, Tamil Nadu, India | title1: System modeling of micro-grid with hybrid energy sources for optimal energy management-A hybrid elephant herding optimization algorithm-adaptive neuro fuzzy inference system approach | site1: WOS
# name2: Balasubramanian D. | inst2: Networking Devtest Senior Engineer Dell EMC Chennai Tamil Nadu India | title2: System modeling of micro-grid with hybrid energy sources for optimal energy management—A hybrid elephant herding optimization algorithm-adaptive neuro fuzzy inference system approach | site1: SCOPUS
# inst: 0.6045751633986928 | title: 0.9712828607856232 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['zhoujianhao@nuaa.edu.cn']
# e2: ['zhoujianhao@nuaa.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Energy & Fuels'], ['air supply', ' deep reinforcement learning', ' fuel cells', ' fuzzy logic', ' model predictive control'] | journal1: ENERGY TECHNOL-GER | journal2: John Wiley and Sons Inc
# name1: Xue, Siwu | inst1: Nanjing Univ Aeronaut & Astronaut, Coll Energy & Power Engn, Nanjing 210016, Peoples R China | title1: Deep Reinforcement Learning Guided Cascade Control for Air Supply of Polymer Exchange Membrane Fuel Cell | site1: WOS
# name2: Xue S. | inst2: College of Energy and Power Engineering Nanjing University of Aeronautics and Astronautics Nanjing 210016 China | title2: Deep Reinforcement Learning Guided Cascade Control for Air Supply of Polymer Exchange Membrane Fuel Cell | site1: SCOPUS
# inst: 0.7266807142396456 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['lisensky@beloit.edu']
# e2: ['lisensky@beloit.edu']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Education & Educational Research'], ['Analogies/Transfer', ' Catalysis', ' Electrochemistry', ' Electrolytic/Galvanic Cells/Potentials', ' First-Year Undergraduate/General', ' Hands-on Learning/Manipulatives', ' Inquiry-Based/Discovery Learning', ' Laboratory Instruction', ' Oxidation/Reduction'] | journal1: J CHEM EDUC | journal2: American Chemical Society
# name1: Jacquez, Tess | inst1: Beloit Coll, Beloit, WI 53511 USA | title1: Inexpensive Alkaline Fuel Cell for Introductory Chemistry Classes | site1: WOS
# name2: Jacquez T. | inst2: Beloit College 700 College Street Beloit WI  53511 United States | title2: Inexpensive Alkaline Fuel Cell for Introductory Chemistry Classes | site1: SCOPUS
# inst: 0.6926136363636365 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: []
# e2: ['siepmann@umn.edu']
# joc: 0 | yop: 2021, 2021 | co_author_count: 6 | keyword: [''], ['Science & Technology - Other Topics'] | journal1: American Association for the Advancement of Science | journal2: SCI ADV
# name1: Siepmann, Joern Ilja | inst1: Department of Chemistry and Chemical Theory Center University of Minnesota 207 Pleasant Street SE Minneapolis MN  55455-0431 United States Department of Chemical Engineering and Materials Science University of Minnesota 412 Washington Avenue SE Minneapolis MN  55455-0132 United States | title1: Fingerprinting diverse nanoporous materials for optimal hydrogen storage conditions using meta-learning | site1: SCOPUS
# name2: Siepmann, J. Ilja | inst2: Friedrich Alexander Univ Erlangen Nurnberg, Inst Separat Sci & Technol, Dept Chem & Bioengn, D-91058 Erlangen, Germany | title2: Fingerprinting diverse nanoporous materials for optimal hydrogen storage conditions using meta-learning | site1: WOS
# inst: 0.5849575412492186 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['ndjilali@uvic.ca', 'metzhao@ust.hk']
# e2: ['smchen@jlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Energy & Fuels', ' Engineering'], ['Polymer Science'] | journal1: APPL ENERG | journal2: MACROMOL THEOR SIMUL
# name1: Zhao, Tianshou | inst1: Univ Victoria, Dept Mech Engn, Victoria, BC V8W 3P6, Canada | title1: A coupled machine learning and genetic algorithm approach to the design of porous electrodes for redox flow batteries | site1: WOS
# name2: Zhang, Tao | inst2: Jilin Univ, Coll Automot Engn, State Key Lab Automot Simulat & Control, Changchun 130022, Peoples R China | title2: The Influence of Microstructure on Sound Absorption of Polyurethane Foams through Numerical Simulation | site1: WOS
# inst: 0.5700882921221905 | title: 0.7160850193304554 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['hanhee.kim@hs-offenburg.de', 'niklas.hartmann@hs-offenburg.de', 'Maxime.Zeller@eifer.uni-karlsruhe.de', 'Renato.Luise@eifer.uni-karlsruhe.de', 'tamer.soylu@kit.edu']
# e2: ['hanhee.kim@hs‐offenburg.de']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Energy & Fuels'], ['City bus', ' Electric bus', ' Hydrogen bus', ' Public transport', ' Total cost of ownership (TCO)', ' Zero‐emission buses (ZEB)'] | journal1: ENERGIES | journal2: MDPI AG
# name1: Soylu, Tamer | inst1: Regionalverband Mittlerer Oberrhein, Haus Reg,Baumeisterstr 2, D-76137 Karlsruhe, Germany | title1: Comparative TCO Analysis of Battery Electric and Hydrogen Fuel Cell Buses for Public Transport System in Small to Midsize Cities | site1: WOS
# name2: Soylu T. | inst2: Regionalverband Mittlerer Oberrhein HAUS DER REGION Baumeisterstraße 2 Karlsruhe 76137 Germany | title2: Comparative tco analysis of battery electric and hydrogen fuel cell buses for public transport system in small to midsize cities | site1: SCOPUS
# inst: 0.9272024036148667 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['jrwoo@korea.ac.kr']
# e2: ['jrwoo@korea.ac.kr']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Business & Economics', ' Public Administration'], ['Hydrogen technology', ' Patent analysis', ' Research and development strategy', ' Structural topic model'] | journal1: TECHNOL FORECAST SOC | journal2: Elsevier Ltd
# name1: Woo, JongRoul | inst1: Korea Univ, Grad Sch Energy & Environm, Energy Environm Policy & Technol, KU KIST Green Sch, Seoul 02841, South Korea | title1: Staying on convention or leapfrogging to eco-innovation?: Identifying early adopters of hydrogen-powered vehicles | site1: WOS
# name2: Woo J. | inst2: Energy Environment Policy and Technology Graduate School of Energy and Environment (KU-KIST Green School) Korea University Seoul 02841 South Korea | title2: Investigating emerging hydrogen technology topics and comparing national level technological focus: Patent analysis using a structural topic model | site1: SCOPUS
# inst: 0.7332799958370736 | title: 0.7099624196872348 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['pratapc.nayak@gmail.com']
# e2: []
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Energy & Fuels', ' Engineering', ' Environmental Sciences & Ecology'], ['Fuel Cell', ' Hydrogen aqua-equalizer', ' Load Frequency Control (LFC)', ' Teaching learning-based optimization (TLBO)', ' TIDF controller'] | journal1: ENERG SOURCE PART A | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Panda, Sidhartha | inst1: VSSUT, Dept Elect Engn, Burla, India | title1: Sunflower optimization based fractional order fuzzy PID controller for frequency regulation of solar-wind integrated power system with hydrogen aqua equalizer-fuel cell unit | site1: WOS
# name2: Panda, Sidhatrha | inst2: Department of Electrical Engineering VSSUT Burla India | title2: Frequency stability of an integrated power system using TLBO based TIDF controller | site1: SCOPUS
# inst: 0.6106701940035273 | title: 0.6585125005874336 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['yanzhang_hhh@mail.nwpu.edu.cn', 'rui.ma@nwpu.edu.cn', 'zhaodong@nwpu.edu.cn', 'yigeng@nwpu.edu.cn', 'lwglll@nwpu.edu.cn']
# e2: ['heyang.yuan@temple.edu', 'wtliu@illinois.edu']
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Automation & Control Systems', ' Engineering', ' Instruments & Instrumentation'], ['Science & Technology - Other Topics'] | journal1: IEEE T IND ELECTRON | journal2: SCI REP-UK
# name1: Liu, Weiguo | inst1: Northwestern Polytech Univ, Sch Automat, Xian 710072, Peoples R China | title1: A Novel Energy Management Strategy Based on Dual Reward Function Q-learning for Fuel Cell Hybrid Electric Vehicle | site1: WOS
# name2: Liu, Wen-Tso | inst2: Univ Illinois, Dept Civil & Environm Engn, Urbana, IL 61801 USA | title2: Disentangling the syntrophic electron transfer mechanisms of Candidatus geobacter eutrophica through electrochemical stimulation and machine learning | site1: WOS
# inst: 0.5304198974275701 | title: 0.6953655639365683 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['weiweihuo@bistu.edu.cn', 'awliweier@163.com', 'chaosun@bit.edu.cn', 'renqiang@gacrnd.com', 'gonggq@126.com']
# e2: ['awliweier@163.com']
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Energy & Fuels'], ['extreme learning machine', ' fault diagnosis', ' fuel cell', ' genetic algorithm', ' support vector machine'] | journal1: ENERGIES | journal2: MDPI
# name1: Gong, Guoqing | inst1: Guangzhou Automobile Grp Co Ltd, Automot Engn Res Inst, Guangzhou 510006, Peoples R China | title1: Research on Fuel Cell Fault Diagnosis Based on Genetic Algorithm Optimization of Support Vector Machine | site1: WOS
# name2: Gong G. | inst2: School of Mechanical and Electrical Beijing Information Science and Technology University Beijing 100101 China | title2: Research on Fuel Cell Fault Diagnosis Based on Genetic Algorithm Optimization of Support Vector Machine | site1: SCOPUS
# inst: 0.5616490152859165 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['lijia0226@nju.edu.cn', 'jianguoliu@nju.edu.cn']
# e2: ['lixf@email.sdu.edu.cn']
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Materials Science'], ['Chemistry', ' Electrochemistry', ' Energy & Fuels'] | journal1: ACS APPL MATER INTER | journal2: INT J HYDROGEN ENERG
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Effectively Increasing Pt Utilization Efficiency of the Membrane Electrode Assembly in Proton Exchange Membrane Fuel Cells through Multiparameter Optimization Guided by Machine Learning | site1: WOS
# name2: Li, Xuefang | inst2: Tsinghua Univ, Key Lab Thermal Sci & Power Engn, Minist Educ, Beijing 100084, Peoples R China | title2: Leak localization using distributed sensors and machine learning for hydrogen releases from a fuel cell vehicle in a parking garage | site1: WOS
# inst: 0.6244387851348803 | title: 0.7132338824219463 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['jianguoliu@nju.edu.cn']
# e2: ['lixf@email.sdu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['Hydrogen leak localization', ' Hydrogen safety', ' Machine learning', ' Parking garage'] | journal1: J MATER CHEM A | journal2: Elsevier Ltd
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Applying machine learning to boost the development of high-performance membrane electrode assembly for proton exchange membrane fuel cells | site1: WOS
# name2: Li, Xuefang | inst2: Institute of Thermal Science and Technology Shandong University Jinan 250061 China | title2: Leak localization using distributed sensors and machine learning for hydrogen releases from a fuel cell vehicle in a parking garage | site1: SCOPUS
# inst: 0.5886279731283666 | title: 0.6985765387026589 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['sinton@mie.utoronto.ca']
# e2: ['sinton@mie.utoronto.ca']
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['carbon utilization', ' catalysis', ' CO2 electroreduction', ' computational modeling', ' machine learning', ' membrane electrode assembly'], ['Chemistry', ' Energy & Fuels', ' Materials Science', ' Physics'] | journal1: Cell Press | journal2: CELL REP PHYS SCI
# name1: Sinton, David A. | inst1: Department of Mechanical and Industrial Engineering University of Toronto Toronto ON M5S 3G8 Canada | title1: Reducing the crossover of carbonate and liquid products during carbon dioxide electroreduction | site1: SCOPUS
# name2: Sinton, David | inst2: Univ Toronto, Dept Elect & Comp Engn, Toronto, ON M5S 1A4, Canada | title2: Reducing the crossover of carbonate and liquid products during carbon dioxide electroreduction | site1: WOS
# inst: 0.5999386856529714 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['hwhebit@bit.edu.cn', '3220190334@bit.edu.cn', 'jianwei.li@bath.edu', '3120190314@bit.edu.cn', 'lianrz612@gmail.com', 'liyc17@foxmail.com']
# e2: ['clare.reimers@oregonstate.edu']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Engineering', ' Transportation'], ['Chemistry', ' Electrochemistry', ' Energy & Fuels', ' Materials Science'] | journal1: IEEE T TRANSP ELECTR | journal2: J POWER SOURCES
# name1: Li, Yuecheng | inst1: Beijing Inst Technol, Sch Mech Engn, Beijing 100081, Peoples R China | title1: An Improved Energy Management Strategy for Hybrid Electric Vehicles Integrating Multistates of Vehicle-Traffic Information | site1: WOS
# name2: Li, Cheng | inst2: Teledyne Benthos, 49 Edgerton Dr North, Falmouth, MA 02556 USA | title2: Benthic microbial fuel cell systems for marine applications | site1: WOS
# inst: 0.5552041605172535 | title: 0.6428258691387337 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['survival_zxx@sina.com']
# e2: ['survival_zxx@sina.com']
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Electrochemistry', ' Energy & Fuels'], ['Deep learning', ' Fault diagnosis', ' Information fusion', ' Proton exchange membrane fuel cell'] | journal1: INT J HYDROGEN ENERG | journal2: Elsevier Ltd
# name1: Guo, Xueqing | inst1: Southwest Jiaotong Univ, Sch Elect Engn, Chengdu 611756, Peoples R China | title1: Fault diagnosis of proton exchange membrane fuel cell system of tram based on information fusion and deep learning | site1: WOS
# name2: Guo X. | inst2: School of Electrical Engineering Southwest Jiaotong University Chengdu 611756 China National Rail Transportation Electrification and Automation Engineering Technology Research Center Southwest Jiaotong University Chengdu 611756 China | title2: Fault diagnosis of proton exchange membrane fuel cell system of tram based on information fusion and deep learning | site1: SCOPUS
# inst: 0.5934691950218332 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['shimengshu1227@foxmail.com']
# e2: ['liuh@engr.orst.edu']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Engineering', ' Environmental Sciences & Ecology'], ['Biocathode', ' Hydrogen production', ' Lignocellulosic hydrolysate', ' Microbial electrolysis cell', ' Scaling up'] | journal1: J CLEAN PROD | journal2: Elsevier Ltd
# name1: Lin, Hongyu | inst1: North China Elect Power Univ, Sch Econ & Management, Beijing, Peoples R China | title1: A two-stage planning and optimization model for water-hydrogen integrated energy system with isolated grid | site1: WOS
# name2: Liu, Hong | inst2: Department of Biological and Ecological Engineering Oregon State University Corvallis OR  97333 United States | title2: Hydrogen production from lignocellulosic hydrolysate in an up-scaled microbial electrolysis cell with stacked bio-electrodes | site1: SCOPUS
# inst: 0.6254769945550515 | title: 0.6951068813515557 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['p.shearing@ucl.ac.uk']
# e2: ['p.shearing@ucl.ac.uk']
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Accelerated stress testing', ' High-temperature polymer electrolyte fuel cell', ' Machine-learning segmentation', ' Phosphoric acid leaching', ' X-ray micro-computed tomography'], ['Chemistry', ' Electrochemistry', ' Energy & Fuels', ' Materials Science'] | journal1: Elsevier B.V. | journal2: J POWER SOURCES
# name1: Shearing, Paul Robert | inst1: Electrochemical Innovation Laboratory Department of Chemical Engineering University College LondonWC1E 7JE United Kingdom | title1: Lab-based X-ray micro-computed tomography coupled with machine-learning segmentation to investigate phosphoric acid leaching in high-temperature polymer electrolyte fuel cells | site1: SCOPUS
# name2: Shearing, Paul R. | inst2: Univ Manchester, Sch Chem Engn & Analyt Sci, Manchester M13 9PL, Lancs, England | title2: Lab-based X-ray micro-computed tomography coupled with machine-learning segmentation to investigate phosphoric acid leaching in high-temperature polymer electrolyte fuel cells | site1: WOS
# inst: 0.5979202609071345 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['taoyu1@scut.edu.cn']
# e2: ['taoyu1@scut.edu.cn']
# joc: 0 | yop: 2022, 2021 | co_author_count: 2 | keyword: ['Thermodynamics'], ['Energy & Fuels'] | journal1: CASE STUD THERM ENG | journal2: FRONT ENERGY RES
# name1: Yang, Bo | inst1: Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650093, Yunnan, Peoples R China | title1: Large-scale multi-agent reinforcement learning-based method for coordinated output voltage control of solid oxide fuel cell | site1: WOS
# name2: Yu, Tao | inst2: South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China | title2: Distributed Imitation-Orientated Deep Reinforcement Learning Method for Optimal PEMFC Output Voltage Control | site1: WOS
# inst: 0.6995327374087794 | title: 0.7370144534778681 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: []
# e2: ['alex.badgett@nrel.gov']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: [''], ['Biotechnology & Applied Microbiology', ' Engineering'] | journal1: Elsevier Ltd | journal2: CURR OPIN CHEM ENG
# name1: Pivovar, Bryan S. | inst1: National Renewable Energy Laboratory 15013 Denver W Parkway Golden CO  80401 United States | title1: Methods identifying cost reduction potential for water electrolysis systems | site1: SCOPUS
# name2: Pivovar, Bryan | inst2: Strateg Anal Inc, Arlington, VA 22203 USA | title2: Methods identifying cost reduction potential for water electrolysis systems | site1: WOS
# inst: 0.48251129177958446 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: []
# e2: ['office@mpi-muenster.mpg.de', 'jan.bruder@mpi-muenster.mpg.de']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: [''], ['Neurosciences & Neurology'] | journal1: IOP Publishing Ltd | journal2: MOVEMENT DISORD
# name1: Brouwer, Jacob | inst1: National Fuel Cell Research Center University of California Irvine CA  92697 United States | title1: Operando diagnostics of solid oxide fuel cell stack via electrochemical impedance spectroscopy simulation-informed machine learning | site1: SCOPUS
# name2: Bruder, Jan M. | inst2: Max Planck Inst Mol Biomed, Dept Cell & Dev Biol, Rontgenstr 20, D-48149 Munster, Germany | title2: Combining Automated Organoid Workflows With Artificial Intelligence-Based Analyses: Opportunities to Build a New Generation of Interdisciplinary High-Throughput Screens for Parkinson's Disease and Beyond | site1: WOS
# inst: 0.6117287601025034 | title: 0.6801656242035289 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['alessandro.brusa6@unibo.it', 'nicolo.cavina@unibo.it', 'nahuel.rojo2@unibo.it', 'jacopo.mecagni2@unibo.it', 'enrico.corti2@unibo.it', 'davide.moro@unibo.it', 'Matteo.Cucchi@ferrari.com', 'Nicola.Silvestri@ferrari.com']
# e2: ['alessandro.brusa6@unibo.it']
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Energy & Fuels'], ['Adaptive strategy', ' CO2 emissions', ' Combustion', ' Control', ' Efficiency improvement', ' Knock'] | journal1: ENERGIES | journal2: MDPI
# name1: Silvestri, Nicola | inst1: Ferrari SpA, I-41053 Maranello, MO, Italy | title1: Development and Experimental Validation of an Adaptive, Piston-Damage-Based Combustion Control System for SI Engines: Part 2-Implementation of Adaptive Strategies | site1: WOS
# name2: Silvestri N. | inst2: Ferrari S.p.A Maranello MO 41053 Italy | title2: Development and experimental validation of an adaptive, piston-damage-based combustion control system for SI engines: Part 2-implementation of adaptive strategies | site1: SCOPUS
# inst: 0.9150834403080873 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['jorge.ibanez@ibero.mx']
# e2: ['jorge.ibanez@ibero.mx']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Education & Educational Research'], ['Distance Learning/Self Instruction', ' Electrochemistry', ' Electrolytic/Galvanic Cells/Potentials', ' First-Year Undergraduate/General', ' High School/Introductory Chemistry', ' Laboratory Instruction', ' Magnetic Properties', ' Materials Science', ' Oxidation/Reduction', ' Semiconductors'] | journal1: J CHEM EDUC | journal2: American Chemical Society
# name1: Ibanez, Jorge G. | inst1: Univ Iberoamer, Dept Chem Ind & Food Engn, Mexico City 01219, DF, Mexico | title1: Light-Emitting Diodes as Voltage Generators: Demonstrating the Fuel Cell Principle with Low-Cost, Magnetically Enhanced, Homemade Solar Electrolysis | site1: WOS
# name2: Ibáñez, Jorge G. | inst2: Department of Chemical Industrial and Food Engineering Universidad Iberoamericana Prolongacion Reforma 880 Mexico City 01219 Mexico | title2: Light-Emitting Diodes as Voltage Generators: Demonstrating the Fuel Cell Principle with Low-Cost, Magnetically Enhanced, Homemade Solar Electrolysis | site1: SCOPUS
# inst: 0.650935712576934 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['luis.silva@uftm.edu.br']
# e2: ['luis.silva@uftm.edu.br']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry'], ['Chemistry teaching', ' Electrochemistry', ' Electrodic reactions', ' Electrolytic cell', ' Fuel cell'] | journal1: REV VIRTUAL QUIM | journal2: Sociedade Brasileira de Quimica
# ...
# name1: Liao, Yuhui | inst1: College of Energy and Power Engineering Nanjing University of Aeronautics and Astronautics Nanjing 210016 China | title1: Total travel costs minimization strategy of a dual-stack fuel cell logistics truck enhanced with artificial potential field and deep reinforcement learning | site1: SCOPUS
# name2: Jiao, Kui | inst2: State Key Laboratory of Engines Tianjin University 135 Yaguan Road Tianjin China | title2: Coupling deep learning and multi-objective genetic algorithms to achieve high performance and durability of direct internal reforming solid oxide fuel cell | site1: SCOPUS
# inst: 0.660066885066885 | title: 0.7441024378231963 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['zhangyh@siat.ac.cn']
# e2: ['smchen@jlu.edu.cn']
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['differential evolution', ' dynamic opposite learning', ' parameter identification', ' PEM fuel cell'], ['Polymer Science'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: MACROMOL THEOR SIMUL
# name1: Zhang, Yanhui | inst1: Shenzhen Institute of Advanced Technology Chinese Academy of Sciences Shenzhen China | title1: An improved DE algorithm for parameters identification of PEMFC | site1: SCOPUS
# name2: Zhang, Tao | inst2: Jilin Univ, Coll Automot Engn, State Key Lab Automot Simulat & Control, Changchun 130022, Peoples R China | title2: The Influence of Microstructure on Sound Absorption of Polyurethane Foams through Numerical Simulation | site1: WOS
# inst: 0.5546720575022461 | title: 0.6638266417678182 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['xupeng@uestc.edu.cn']
# e2: ['pjx@hust.edu.cn']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Artificial intelligence', ' Brain network analysis', ' EEG pattern', ' Neuroplasticity', ' Segregation and integration'], ['BP neural network', ' fault diagnosis', ' heat exchanger rupture', ' SOFC', ' the reformer carbon deposition'] | journal1: Springer Science and Business Media B.V. | journal2: MDPI
# name1: Xu, Peng | inst1: The Clinical Hospital of Chengdu Brain Science Institute MOE Key Lab for Neuroinformation University of Electronic Science and Technology of China Chengdu 611731 China School of Life Science and Technology Center for Information in BioMedicine University of Electronic Science and Technology of China Chengdu 611731 China | title1: A survey of brain network analysis by electroencephalographic signals | site1: SCOPUS
# name2: Peng J. | inst2: School of Artificial Intelligence and Automation Huazhong University of Science and Technology Wuhan 430074 China | title2: A Data-Driven Fault Diagnosis Method for Solid Oxide Fuel Cell Systems | site1: SCOPUS
# inst: 0.5997211621394899 | title: 0.6605244996549344 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['hwhebit@bit.edu.cn']
# e2: ['tanveer.ahmad.pk11@gmail.com']
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Battery energy storage', ' Battery management system', ' Battery state estimation', ' Deep transfer learning', ' Electric vehicles', ' Transportation electrification'], ['Science & Technology - Other Topics', ' Engineering', ' Environmental Sciences & Ecology'] | journal1: Elsevier Ltd | journal2: J CLEAN PROD
# name1: Cheng, Shuang | inst1: Department of Electronic and Electrical Engineering University of Bath UK Bath United Kingdom | title1: Health-Conscious vehicle battery state estimation based on deep transfer learning | site1: SCOPUS
# name2: Chen, Huanxin | inst2: Huazhong Univ Sci & Technol, Sch Energy & Power Engn, Wuhan, Peoples R China | title2: Artificial intelligence in sustainable energy industry: Status Quo, challenges and opportunities | site1: WOS
# inst: 0.598520926987788 | title: 0.7022779119699409 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['dsalahub@ucalgary.ca']
# e2: ['dsalahub@ucalgary.ca']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: [''], ['Chemistry', ' Physics'] | journal1: Royal Society of Chemistry | journal2: PHYS CHEM CHEM PHYS
# name1: Salahub, Dennis Russell | inst1: Department of Chemistry University of Calgary Quantum Alberta IQST-Institute for Quantum Science and Technology CMS-Centre for Molecular Simulation Department of Physics and Astronomy Calgary AB  T2N 1N4 Canada | title1: Multiscale molecular modelling: from electronic structure to dynamics of nanosystems and beyond | site1: SCOPUS
# name2: Salahub, Dennis R. | inst2: Univ Calgary, CMS Ctr Mol Simulat, IQST Inst Quantum Sci & Technol, Dept Chem,Dept Phys & Astron,Quantum Alberta, Calgary, AB T2N 1N4, Canada | title2: Multiscale molecular modelling: from electronic structure to dynamics of nanosystems and beyond | site1: WOS
# inst: 0.6880367859091264 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['ciwei.gao@seu.edu.cn']
# e2: []
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Energy & Fuels', ' Engineering'], ['dater driven', ' deep reinforcement learning', ' Energy management', ' energy management strategy', ' Fuel cell hybrid electric vehicle', ' Fuel cells', ' heuristic technique', ' Hybrid electric vehicles', ' Hydrogen', ' Real-time systems', ' Vehicle dynamics', ' Voltage'] | journal1: IET RENEW POWER GEN | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Song, Yutong | inst1: Southeast Univ, Sch Elect Engn, Nanjing, Peoples R China | title1: Optimal control strategy for solid oxide fuel cell-based hybrid energy system using deep reinforcement learning | site1: WOS
# name2: Song S. | inst2: Henan University of Science and Technology 74623 Luoyang Henan China | title2: Energy management strategy for fuel cell/battery/ultracapacitor hybrid electric vehicles using deep reinforcement learning with action trimming | site1: SCOPUS
# inst: 0.6028065072182719 | title: 0.7067338667338667 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['xiaoyan.yin11@gmail.com', 'r.spatschek@fz-juelich.de', 'n.h.menzler@fz-juelich.de', 'claashueter@posteo.de']
# e2: ['r.spatschek@fz-juelich.de']
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Chemistry', ' Materials Science', ' Metallurgy & Metallurgical Engineering', ' Physics'], ['artificial neural networks', ' Bayesian analysis', ' oxygen vacancy formation energy', ' solid oxide cells', ' transfer learning'] | journal1: MATERIALS | journal2: MDPI
# name1: Hueter, Claas | inst1: Forschungszentrum Julich, Inst Energy & Climate Res IEK 1, D-52425 Julich, Germany | title1: A Pragmatic Transfer Learning Approach for Oxygen Vacancy Formation Energies in Oxidic Ceramics | site1: WOS
# name2: Hüter, Claas | inst2: Institute of Energy and Climate Research IEK-2 Forschungszentrum Jülich GmbH Jülich 52425 Germany | title2: A Pragmatic Transfer Learning Approach for Oxygen Vacancy Formation Energies in Oxidic Ceramics | site1: SCOPUS
# inst: 0.7403877853211522 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# e1: ['ndjilali@uvic.ca', 'metzhao@ust.hk']
# e2: ['chhzhao@zju.edu.cn']
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Energy & Fuels', ' Engineering'], ['Attention mechanism', ' Micro-crack anomaly detection', ' Photovoltaic module cell', ' Semantic segmentation', ' Transfer learning'] | journal1: APPL ENERG | journal2: Elsevier Ltd
# name1: Zhao, Tianshou | inst1: Univ Victoria, Dept Mech Engn, Victoria, BC V8W 3P6, Canada | title1: A coupled machine learning and genetic algorithm approach to the design of porous electrodes for redox flow batteries | site1: WOS
# name2: Zhao, Chunhui | inst2: State Key Laboratory of Industrial Control Technology College of Control Science and Engineering Zhejiang University Hangzhou 310027 China | title2: Attention classification-and-segmentation network for micro-crack anomaly detection of photovoltaic module cells | site1: SCOPUS
# inst: 0.4976070580528944 | title: 0.6755335895041776 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['fjtmengnan302@sina.com']
# e2: ['ciwei.gao@seu.edu.cn']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Deep learning', ' Fuel cell stack model', ' Gate recurrent unit', ' Performance prediction', ' Proton membrane fuel cell'], ['Science & Technology - Other Topics', ' Energy & Fuels', ' Engineering'] | journal1: Elsevier Ltd | journal2: IET RENEW POWER GEN
# name1: Song, Shuzhong | inst1: Henan University of Science and Technology Luoyang Henan 471009 China | title1: Proton membrane fuel cell stack performance prediction through deep learning method | site1: SCOPUS
# name2: Song, Yutong | inst2: Southeast Univ, Sch Elect Engn, Nanjing, Peoples R China | title2: Optimal control strategy for solid oxide fuel cell-based hybrid energy system using deep reinforcement learning | site1: WOS
# inst: 0.6000358337314858 | title: 0.7088877082535928 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: []
# e2: ['smchen@jlu.edu.cn']
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['deep-learning neural network', ' distributed electrical propulsion', ' fuel-cell UAV', ' model predictive control', ' power load forecast'], ['Polymer Science'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: MACROMOL THEOR SIMUL
# name1: Zhang, Xiaobin | inst1: Northwestern Polytechnical University Automation School Electrical Engineering Department Xi'An China | title1: A Data-Driven MPC Energy Optimization Management Strategy for Fuel Cell Distributed Electric Propulsion UAV | site1: SCOPUS
# name2: Zhang, Tao | inst2: Jilin Univ, Coll Automot Engn, State Key Lab Automot Simulat & Control, Changchun 130022, Peoples R China | title2: The Influence of Microstructure on Sound Absorption of Polyurethane Foams through Numerical Simulation | site1: WOS
# inst: 0.6216680071368481 | title: 0.6898257589640218 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['rajeshkannan.mt@gmail.com']
# e2: ['wang.peng@buaa.edu.cn', 'akeelshah@cqu.edu.cn']
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['active with reactive power', ' micro grid', ' power quality enhancement'], ['Chemistry', ' Electrochemistry', ' Energy & Fuels', ' Materials Science'] | journal1: John Wiley and Sons Ltd | journal2: J POWER SOURCES
# name1: Sharma D. | inst1: Department of Electrical Engineering DCR University of Science and Technology Murthal Sonepat India | title1: An optimal hybrid control scheme to achieve power quality enhancement in micro grid connected system | site1: SCOPUS
# name2: Shah, A. A. | inst2: Chongqing Univ, MOE, Key Lab Low Grade Energy Utilizat Technol & Syst, Chongqing 400030, Peoples R China | title2: A new multi-task learning framework for fuel cell model outputs in high-dimensional spaces | site1: WOS
# inst: 0.6244124173228651 | title: 0.6783068783068783 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['lijia0226@nju.edu.cn', 'jianguoliu@nju.edu.cn']
# e2: ['373482753@qq.com']
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Materials Science'], ['bald eagle search algorithm', ' MATLAB', ' metaheuristic algorithm', ' parameter identification', ' proton exchange membrane fuel cell'] | journal1: ACS APPL MATER INTER | journal2: Frontiers Media S.A.
# name1: Liu, Jianguo | inst1: Nanjing Univ, Collaborat Innovat Ctr Adv Microstruct, Coll Engn & Appl Sci, Natl Lab Solid State Microstruct, 22 Hankou Rd, Nanjing 210093, Peoples R China | title1: Effectively Increasing Pt Utilization Efficiency of the Membrane Electrode Assembly in Proton Exchange Membrane Fuel Cells through Multiparameter Optimization Guided by Machine Learning | site1: WOS
# name2: Li J. | inst2: Key Laboratory of Modern Power System Simulation and Control and Renewable Energy Technology Ministry of Education Northeast Electric Power University Jilin China | title2: Bald Eagle Search Algorithm for Parameter Identification of Proton Exchange Membrane Fuel Cell | site1: SCOPUS
# inst: 0.6472849193279301 | title: 0.6729820417534899 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# e1: ['wujian@zafu.edu.cn']
# e2: []
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['characteristic pyramid network', ' chip defects', ' convolutional neural network', ' region of interest calibration', ' target detection'], ['ANN', ' integral separation PID', ' machine learning', ' PEMFC'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Xu R. | inst1: Taizhou Radio and Television University Taizhou China | title1: Research on Defect Recognition of Ceramic Chips for High Temperature Fuel Cells Based on Improved Faster R-CNN | site1: SCOPUS
# name2: Xu W. | inst2: Shandong University School of Control Science and Engineering Shandong 250061 China | title2: Data-driven modeling and control of proton exchange membrane fuel cell with reducing overshoot | site1: SCOPUS
# inst: 0.5955482306584831 | title: 0.7052788523533206 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# ['zamanim', 'hajjis', 'holmea', 'shahaa', 'strømmanandershammer', 'fathya', 'yousefin', 'rousseaup', 'xiay', 'demazièrechristophe', 'nassefam', 'foleyaoife', 'balasubramaniand', 'xues', 'jacquezt', 'siepmannjilja', 'soylut', 'wooj', 'gongg', 'sintondavid', 'guox', 'shearingpaulr', 'yutao_0', 'pivovarbryan', 'silvestrin', 'ibañezjorgeg', 'dasilvala', 'yutao_0', 'jafarih', 'fupf', 'haasr_0', 'huffkd', 'khoshnevisana', 'candussod', 'fultonlewis', 'eslamibidgolimohammadj', 'netzelmannu', 'ramadanha', 'ramamurthypraveenc', 'abidoma', 'taylorcornejoe', 'chenyi', 'rehtanzc', 'mal', 'slonesm', 'chouaibs', 'rajashekarakaushik', 'salahubdennisr', 'tsugey', 'yıldırımramazan', 'hüterclaas', 'sergit', 'yousrid', 'igicpetar', 'haasr_0', 'zamanim', 'hajjis', 'shahaa', 'yıldırımramazan', 'xiay', 'holmea', 'fathya', 'wangq', 'yousefin', 'rousseaup', 'yutaot', 'argescg', 'huangn', 'igicpetar', 'foleyaoife', 'taherib', 'fupf', 'nassefam', 'jafarih', 'gongg', 'balasubramaniand', 'dasilvala', 'jacquezt', 'wooj', 'yuanh', 'lixi_0', 'siepmannjilja', 'xues', 'yanf', 'soylut', 'pivovarbryan', 'guox', 'shearingpaulr', 'zhuy', 'silvestrin', 'bruderjm', 'huffkd', 'sergit', 'yut', 'khoshnevisana', 'candussod', 'fultonlewis', 'xuj', 'netzelmannu', 'sintondavid', 'ramamurthypraveenc', 'ramadanha', 'abidoma', 'rehtanzc', 'yousrid', 'slonesm', 'eslamibidgolimohammadj', 'songy', 'mal', 'taylorcornejoe', 'chouaibs', 'liuh_1', 'rajashekarakaushik', 'gongg', 'tsugey', 'leungpk', 'salahubdennisr', 'hüterclaas']
# 235
# 416

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name):
    global answer, numCor, numErr, answerCounter, numInteErr # answer = json, numCor = 정답 수, numErr = 오답 수, answerCounter = 정답수, numInteErr = 통합에러
    flag = True

    numK = len(result.keys()) #Answer_dict key 개수
    if numK-5 != len(answer[name].keys()):
        flag = False
    else :
        for site in result.keys():
            if site != 'name' and site != 'fid' and site != 'keyId' and site != 'inst' and site != 'pre_name':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 5:
                        if answer[name][site] != result[site]['inst']:
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag:
        numCor += 1
        answerCounter[name] += 1
    else:
        if len(answer[name].keys()) > 1:
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {name} {answer[name]}\n - Result : {result}")
        else:
            pass
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json:

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:        
        name = Answer_dict[answer_one]['name'].split('_')[0]

        if name in answer :
            ansCheck(Answer_dict[answer_one], name)

        else :
            count = 0
            while name+'_'+str(count) in answer :
                if ansCheck(Answer_dict[answer_one], name+'_'+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

    print("토탈앤써", answercount)
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    print(keyid)
    
print(sorted(Answer_dict.items()))
# Out:
# 385
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_0 {'SCOPUS': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'WOS': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'WOS': {'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'A_id': ['s4209881'], 'papers': [ObjectId('62943ea51649752aa1873f07')], 'oriInst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}, 'SCOPUS': {'inst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'A_id': ['57194213057'], 'papers': [ObjectId('62943eae4c7cb9455f86c724'), ObjectId('62943eaf4c7cb9455f86c754')], 'oriInst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_1 {'SCOPUS': 'Department of Electrical and Computer Engineering Semnan University Semnan Iran', 'WOS': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'WOS': {'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'A_id': ['s4209881'], 'papers': [ObjectId('62943ea51649752aa1873f07')], 'oriInst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}, 'SCOPUS': {'inst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'A_id': ['57194213057'], 'papers': [ObjectId('62943eae4c7cb9455f86c724'), ObjectId('62943eaf4c7cb9455f86c754')], 'oriInst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_0 {'SCOPUS': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'WOS': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'WOS': {'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'A_id': ['ss9679192'], 'papers': [ObjectId('62943ea41649752aa1873ebc')], 'oriInst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_1 {'SCOPUS': 'Department of Electrical and Computer Engineering Semnan University Semnan Iran', 'WOS': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'WOS': {'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'A_id': ['ss9679192'], 'papers': [ObjectId('62943ea41649752aa1873ebc')], 'oriInst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Arges, Christopher G. {'SCOPUS': 'Cain Department of Chemical Engineering Louisiana State University Baton Rouge LA  70803 United States', 'WOS': 'Louisiana State Univ, Cain Dept Chem Engn, Baton Rouge, LA 70803 USA'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Arges, Christopher G.', 'pre_name': 'argeschristopherg', 'inst': 'Penn State Univ, Dept Chem Engn, University Pk, PA 16802 USA', 'WOS': {'inst': 'Penn State Univ, Dept Chem Engn, University Pk, PA 16802 USA', 'A_id': ['ss9679463'], 'papers': [ObjectId('62943ea51649752aa1873f1e')], 'oriInst': 'Penn State Univ, Dept Chem Engn, University Pk, PA 16802 USA'}, 'SCOPUS': {'inst': 'Cain Department of Chemical Engineering Louisiana State University Baton Rouge LA  70803 United States', 'A_id': ['36774196900'], 'papers': [ObjectId('62943eb04c7cb9455f86c7a0'), ObjectId('62943eac4c7cb9455f86c6a7')], 'oriInst': 'Cain Department of Chemical Engineering Louisiana State University Baton Rouge LA  70803 United States'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Arges, Christopher G. {'SCOPUS': 'Cain Department of Chemical Engineering Louisiana State University Baton Rouge LA  70803 United States', 'WOS': 'Louisiana State Univ, Cain Dept Chem Engn, Baton Rouge, LA 70803 USA'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Arges, Christopher G.', 'pre_name': 'argeschristopherg', 'inst': 'Louisiana State Univ, Cain Dept Chem Engn, Baton Rouge, LA 70803 USA', 'WOS': {'inst': 'Louisiana State Univ, Cain Dept Chem Engn, Baton Rouge, LA 70803 USA', 'A_id': ['s7411952'], 'papers': [ObjectId('62943ea51649752aa1873f00')], 'oriInst': 'Louisiana State Univ, Cain Dept Chem Engn, Baton Rouge, LA 70803 USA'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Lim, Hankwon {'SCOPUS': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'WOS': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Lim, Hankwon', 'pre_name': 'limhankwon', 'inst': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'SCOPUS': {'inst': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'A_id': ['14019936500'], 'papers': [ObjectId('62943eaf4c7cb9455f86c772'), ObjectId('62943eae4c7cb9455f86c72e'), ObjectId('62943ead4c7cb9455f86c6f5')], 'oriInst': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Lim, Hankwon {'SCOPUS': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'WOS': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Lim, Hankwon', 'pre_name': 'limhankwon', 'inst': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea', 'WOS': {'inst': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea', 'A_id': ['ss9679197'], 'papers': [ObjectId('62943ea41649752aa1873ebf')], 'oriInst': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Panda, Sidhatrha {'SCOPUS': 'Department of Electrical Engineering VSSUT Burla India', 'WOS': 'VSSUT, Dept Elect Engn, Burla, India'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Panda, Sidhatrha', 'pre_name': 'pandasidhatrha', 'inst': 'Department of Electrical Engineering VSSUT Burla India', 'SCOPUS': {'inst': 'Department of Electrical Engineering VSSUT Burla India', 'A_id': ['15726134500'], 'papers': [ObjectId('62943eb04c7cb9455f86c7d0'), ObjectId('62943eb04c7cb9455f86c7bd')], 'oriInst': 'Department of Electrical Engineering VSSUT Burla India'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Shikazono, Naoki {'SCOPUS': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'WOS': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Shikazono, Naoki', 'pre_name': 'shikazononaoki', 'inst': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'SCOPUS': {'inst': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'A_id': ['7005214534'], 'papers': [ObjectId('62943eb04c7cb9455f86c7ca')], 'oriInst': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Shikazono, Naoki {'SCOPUS': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'WOS': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Shikazono, Naoki', 'pre_name': 'shikazononaoki', 'inst': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan', 'WOS': {'inst': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan', 'A_id': ['s7321227'], 'papers': [ObjectId('62943ea51649752aa1873f3e')], 'oriInst': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan'}}
# num코렉트 372
# numEror 13
# numInteEror 11
# answer= Arges, Christopher G. {'SCOPUS': 'Cain Department of Chemical Engineering Louisiana State University Baton Rouge LA  70803 United States', 'WOS': 'Louisiana State Univ, Cain Dept Chem Engn, Baton Rouge, LA 70803 USA'}
# answer= Chen, Yi {'WOS': 'Newcastle Univ, Sch Nat & Environm Sci, Newcastle Upon Tyne NE1 7RU, Tyne & Wear, England'}
# answer= Li, Xi_0 {'SCOPUS': 'School of Artificial Intelligence and Automation Key Laboratory of Image Processing and Intelligent Control of Education Ministry Huazhong University of Science and Technology Wuhan Hubei  430074 China'}
# answer= Li, Xi_1 {'WOS': 'Guangdong Energy Grp Co Ltd, Guangzhou 510630, Peoples R China'}
# answer= Lim, Hankwon {'SCOPUS': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'WOS': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea'}
# answer= Panda, Sidhatrha {'SCOPUS': 'Department of Electrical Engineering VSSUT Burla India', 'WOS': 'VSSUT, Dept Elect Engn, Burla, India'}
# answer= Shikazono, Naoki {'SCOPUS': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'WOS': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan'}
# answer= Taheri, Bahman_0 {'SCOPUS': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'WOS': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}
# answer= Taheri, Bahman_1 {'SCOPUS': 'Department of Electrical and Computer Engineering Semnan University Semnan Iran', 'WOS': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}
# answer= Yu, Tao_0 {'SCOPUS': 'College of Electric Power South China University of Technology Guangzhou 510640 China', 'WOS': 'South China Univ Technol, Coll Elect Power, Guangzhou 510640, Peoples R China'}
# answer= Yu, Tao_1 {'WOS': 'China Elect Power Res Inst Nanjing, Nanjing 210003, Peoples R China'}
# answer= Yu, Tao_2 {'WOS': 'Kunming Univ Sci & Technol, Fac Elect Power Engn, Kunming 650093, Yunnan, Peoples R China'}
# answer= Zhu Y. {'SCOPUS': 'School of Automation Engineering University of Electronic Science and Technology of China Chengdu China'}
# 토탈앤써 385
# 토탈인터그레이션 161
# --------------------------------
# 토탈에러 13
# 토탈인터그레이션에러 7
# 904
# [('abdelsattarmontaser', {'fid': 0, 'keyId': 904, 'name': 'Abd El Sattar, Montaser', 'pre_name': 'abdelsattarmontaser', 'inst': 'South Valley Univ, Fac Engn, Dept Elect Engn, Qena 83523, Egypt', 'WOS': {'inst': 'South Valley Univ, Fac Engn, Dept Elect Engn, Qena 83523, Egypt', 'A_id': ['ss9679529'], 'papers': [ObjectId('62943ea51649752aa1873f37')], 'oriInst': 'South Valley Univ, Fac Engn, Dept Elect Engn, Qena 83523, Egypt'}}), ('abelseabrajoaquime', {'fid': 0, 'keyId': 904, 'name': 'Abel Seabra, Joaquim E.', 'pre_name': 'abelseabrajoaquime', 'inst': 'School of Mechanical Engineering University of Campinas Campinas São Paulo Brazil', 'SCOPUS': {'inst': 'School of Mechanical Engineering University of Campinas Campinas São Paulo Brazil', 'A_id': ['23390441500'], 'papers': [ObjectId('62943eae4c7cb9455f86c70b')], 'oriInst': 'School of Mechanical Engineering University of Campinas Campinas São Paulo Brazil'}}), ('abidomohameda', {'fid': 0, 'keyId': 904, 'name': 'Abido, Mohamed A.', 'pre_name': 'abidomohameda', 'inst': 'Electrical Engineering Department King Fahd University of Petroleum and Minerals Dhahran 31261 Saudi Arabia', 'SCOPUS': {'inst': 'Electrical Engineering Department King Fahd University of Petroleum and Minerals Dhahran 31261 Saudi Arabia', 'A_id': ['56048231100'], 'papers': [ObjectId('62943ead4c7cb9455f86c6c4')], 'oriInst': 'Electrical Engineering Department King Fahd University of Petroleum and Minerals Dhahran 31261 Saudi Arabia'}, 'WOS': {'inst': 'King Fahd Univ Petr & Minerals, Elect Engn Dept, Dhahran 31261, Saudi Arabia', 'A_id': ['ss9679559'], 'papers': [ObjectId('62943ea51649752aa1873f3f')], 'oriInst': 'King Fahd Univ Petr & Minerals, Elect Engn Dept, Dhahran 31261, Saudi Arabia'}}), ('actonscottthomas', {'fid': 0, 'keyId': 904, 'name': 'Acton, Scott Thomas', 'pre_name': 'actonscottthomas', 'inst': 'University of Virginia Electrical and Computer Engineering Charlottesville United States', 'SCOPUS': {'inst': 'University of Virginia Electrical and Computer Engineering Charlottesville United States', 'A_id': ['7006577888'], 'papers': [ObjectId('62943ead4c7cb9455f86c6d1')], 'oriInst': 'University of Virginia Electrical and Computer Engineering Charlottesville United States'}}), ('adamsstefan', {'fid': 0, 'keyId': 904, 'name': 'Adams, Stefan', 'pre_name': 'adamsstefan', 'inst': 'Natl Univ Singapore, Dept Mat Sci & Engn, Singapore 117575, Singapore', 'WOS': {'inst': 'Natl Univ Singapore, Dept Mat Sci & Engn, Singapore 117575, Singapore', 'A_id': ['s7106180'], 'papers': [ObjectId('62943ea61649752aa1873f97')], 'oriInst': 'Natl Univ Singapore, Dept Mat Sci & Engn, Singapore 117575, Singapore'}}), ('adlersb_0', {'fid': 0, 'keyId': 904, 'name': 'Adler, S. B.', 'pre_name': 'adlersb', 'inst': 'Univ Calif Irvine, Natl Fuel Cell Res Ctr, Irvine, CA 92697 USA', 'WOS': {'inst': 'Univ Calif Irvine, Natl Fuel Cell Res Ctr, Irvine, CA 92697 USA', 'A_id': ['ss9679245'], 'papers': [ObjectId('62943ea51649752aa1873ed2')], 'oriInst': 'Univ Calif Irvine, Natl Fuel Cell Res Ctr, Irvine, CA 92697 USA'}, 'SCOPUS': {'inst': 'Department of Chemical Engineering University of Washington Seattle WA  98105 United States', 'A_id': ['7202093500'], 'papers': [ObjectId('62943eac4c7cb9455f86c6a9')], 'oriInst': 'Department of Chemical Engineering University of Washington Seattle WA  98105 United States'}}), ('aissabrahim', {'fid': 0, 'keyId': 904, 'name': 'Aissa, Brahim', 'pre_name': 'aissabrahim', 'inst': 'Clemson Univ, Dept Chem, Clemson, SC 29634 USA', 'WOS': {'inst': 'Clemson Univ, Dept Chem, Clemson, SC 29634 USA', 'A_id': ['ss9679661'], 'papers': [ObjectId('62943ea51649752aa1873f5a')], 'oriInst': 'Clemson Univ, Dept Chem, Clemson, SC 29634 USA'}}), ('akkoçg', {'fid': 0, 'keyId': 904, 'name': 'Akkoç G.', 'pre_name': 'akkoçg', 'inst': 'Department of Chemical Engineering Gazi University Maltepe-Ankara 06570 Turkey', 'SCOPUS': {'inst': 'Department of Chemical Engineering Gazi University Maltepe-Ankara 06570 Turkey', 'A_id': ['57340332800'], 'paper ...
