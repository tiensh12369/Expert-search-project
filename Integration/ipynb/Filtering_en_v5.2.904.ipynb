# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 904 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []
plang = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']
            plang = fid_key_query[key]['lang']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}
f_plang = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst) and simple_filter(paper_lang, plang):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }
        
        if pre_name == 'herrerafrancisco' and site == 'SCOPUS':
            print(Answer)
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

print(f'2차 통합: {savetime2}')
print(Inte_name)
print(len(Answer_dict))
# Out:
# DB 수집: WOS, 0.09971380233764648
# 전체 저자 수: 254
# DB 수집: SCOPUS, 0.17753076553344727
# 전체 저자 수: 313
# 2차 통합: 0.2782447338104248
# []
# 567

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    if site == "WOS":
        email.extend(rawdata['emails'].replace(" ", "").split(";"))
        funding_text.append(rawdata['funding text'])
        
    elif site == "SCOPUS":
        emails = rawdata['correspondence_address'].split(" ")
        for i in emails:
            if "@" in i:
                email.append(i)

        for funding in  rawdata.keys():
            if "funding_text_" in funding:
                funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
    
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2:
                funding_exact = 1
                print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
        
        
    if paper_sim >= 0.8 or inst_sim >= 0.8 or email_exact == 1 or funding_exact == 1:
        weight = 4
        # print(f'weigth: {weight} | joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count}| keyword: {keyword1}, {keyword2}')
        # print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        # print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        # print(f'inst: {inst_sim} | journal1: {journal1} | journal2: {journal2}')
        # print(f'email: {email_exact}')
        print('------------------------------------------------------------구분선2------------------------------------------------------------')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

            
    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    # print(f'weigth: {weight} | joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')
    # print(f'name1: {name1} | site1: {site1} | year: {year1} | coauthor: {coauthor1} | keyword: {keyword1} | journal1: {journal1}')
    # print(f'name2: {name2} | site1: {site2} | year: {year2} | coauthor: {coauthor2} | keyword: {keyword2} | journal2: {journal2}')
    # print(f'paper_sim: {paper_sim}')
    # print(f'title1: {title1}')
    # print(f'title2: {title2}')
    # print(f'inst_sim: {inst_sim}')
    # print(f'inst1: {inst1}')
    # print(f'inst2: {inst2}')
    # print(f'email_exact: {email_exact}')
    # print(f'emails1: {emails1}')
    # print(f'emails2: {emails2}')
    # print(raw_one1)
    # print(raw_one2)
    print('------------------------------------------------------------구분선------------------------------------------------------------')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['khoobanmohammadhassan_1', 'khoobanmohammadhassan_2', 'rezkhegazy_1', 'rezkhegazy_2', 'liujianguo_1', 'liujianguo_2', 'liujianguo_3', 'yutao_1', 'yutao_2', 'yutao_3', 'yutao_4', 'yutao_5', 'yutao_6', 'yutao_7', 'dasilvaluisantonio_1', 'yangbo_1', 'yangbo_2', 'yangbo_3', 'zhangxiaoshun_1', 'zhangxiaoshun_2', 'haasr_1', 'spagnuologiovanni_1', 'spagnuologiovanni_2', 'zerhouninoureddine_1', 'zerhouninoureddine_2', 'yuanheyang_1', 'chasukwon_1', 'chasukwon_2', 'yildirimramazan_1', 'lixi_1', 'lixi_2', 'chengyujie_1', 'chengxiaobin_1', 'shekhawatshalini_1', 'lixuefang_1', 'kimminsoo_1', 'zhangcunman_1', 'lenskyitamarm_1', 'luwei_1', 'xuanjin_1', 'xiabaoyu_1', 'hwangjinha_1', 'wangyun_1', 'huming_1', 'garciamartinhector_1', 'juradofrancisco_1', 'pfeifernorbert_1', 'liuweiguo_1', 'ushas_1', 'lijia_1', 'raceanumircea_1', 'zhangzehui_1', 'lijian_1', 'liangxuedong_1', 'wangqiuwang_1', 'xubin_1', 'xuwei_1', 'lingchen_1', 'liuzhipan_1', 'zhangqi_1', 'zhongzheng_1', 'ramanvenkat_1', 'linzijing_1', 'dharbiproranjan_1', 'berbermohamedr_1', 'ribeirofabioh_1', 'samuelsenscott_1', 'linbin_1', 'liuzhixiang_1', 'muyeensm_1', 'zhengchunhua_1', 'linxianke_1', 'deepan_1', 'huanghaitao_1', 'jinnouchiryosuke_1', 'matsunofumitoshi_1', 'lix_1', 'brusgrzegorz_1', 'lekerjens_1', 'liaoyuhui_1', 'barambonesoscar_1', 'gaoshuyan_1', 'santhanamvenugopal_1', 'hsuchanghung_1', 'zhaodongdong_1', 'raibeena_1', 'bucknallrichard_1', 'xuhongming_1', 'sunchao_1', 'suzukik_1', 'hadjidemetrioustathis_1', 'hayashiyasuhiro_1', 'jervisrhodri_1', 'hameyerkay_1', 'malekkourosh_1', 'liyunqi_1', 'nangiauma_1', 'maronefederica_1', 'grondinperezbrigitte_1', 'shenjun_1', 'fekihafef_1', 'chengchinkui_1', 'grassetlaurent_1', 'wangweishan_1', 'ghadiminoradin_1', 'wangxiaonan_1', 'nazhixiong_1', 'yuanjoshuas_1', 'golinkoffrobertamichnick_1', 'saidiwissama_1', 'houzhongjun_1', 'liuh_1', 'gongyanfeng_1', 'olabiabdulghani_1', 'ciuccifrancesco_1', 'malavasilorenzo_1', 'liuzhenning_1', 'jiaokui_1', 'adlersb_1', 'eickerursula_1']

# %%
deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        if name_sim >= 0.8 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
                    flag = True
                    break
            if flag :
                break
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ...
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# ------------------------------------------------------------구분선------------------------------------------------------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# -----------------펀딩 통합-----------------
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['zamanim', 'hajjis', 'holmea', 'shahaa', 'strømmanandershammer', 'fathya', 'yousefin', 'rousseaup', 'xiay', 'demazièrechristophe', 'nassefam', 'foleyaoife', 'balasubramaniand', 'xues', 'jacquezt', 'siepmannjilja', 'soylut', 'wooj', 'pandasidhatrha', 'gongg', 'sintondavid', 'guox', 'shearingpaulr', 'yutao_0', 'pivovarbryan', 'silvestrin', 'ibañezjorgeg', 'dasilvala', 'yutao_0', 'jafarih', 'fupf', 'haasr_0', 'huffkd', 'khoshnevisana', 'candussod', 'fultonlewis', 'yousefin', 'eslamibidgolimohammadj', 'netzelmannu', 'ramadanha', 'ramamurthypraveenc', 'abidoma', 'taylorcornejoe', 'chenyi', 'rehtanzc', 'mal', 'slonesm', 'chouaibs', 'rajashekarakaushik', 'salahubdennisr', 'tsugey', 'yıldırımramazan', 'hüterclaas', 'sergit', 'yousrid', 'lug', 'igicpetar', 'haasr_0', 'zamanim', 'hajjis', 'shahaa', 'yıldırımramazan', 'xiay', 'holmea', 'fathya', 'wangq', 'yousefin', 'luwei_0', 'rousseaup', 'yutaot', 'xubin_0', 'argescg', 'yuanh', 'huming_0', 'dangyan', 'choujh', 'raibeena_0', 'huangn', 'lixuefang_0', 'xubin_0', 'igicpetar', 'luwei_0', 'foleyaoife', 'taherib', 'fupf', 'zhangzehui_0', 'guoy', 'nassefam', 'jafarih', 'gongg', 'xues', 'balasubramaniand', 'dasilvala', 'jacquezt', 'wooj', 'yuanh', 'lixi_0', 'siepmannjilja', 'xues', 'yanf', 'soylut', 'haras', 'pivovarbryan', 'guox', 'lixuefang_0', 'xuw', 'shearingpaulr', 'zhuy', 'silvestrin', 'bruderjm', 'huffkd', 'songjian', 'sergit', 'yut', 'khoshnevisana', 'raibeena_0', 'candussod', 'nassifab', 'xuanjin_0', 'fultonlewis', 'xuj', 'xub', 'netzelmannu', 'sintondavid', 'choujh', 'ramamurthypraveenc', 'ramadanha', 'abidoma', 'rehtanzc', 'yousrid', 'xupeng', 'slonesm', 'chenhuanxin', 'eslamibidgolimohammadj', 'songy', 'mal', 'taylorcornejoe', 'houzhongjun_0', 'lius', 'chouaibs', 'liuh_0', 'rajashekarakaushik', 'kimgm', 'gongg', 'tsugey', 'guoy', 'xuw', 'lug', 'leungpk', 'xuw', 'chenw', 'leungpk', 'jiaokui_0', 'pengj', 'salahubdennisr', 'hüterclaas', 'xuw']
# 277
# 415

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name):
    global answer, numCor, numErr, answerCounter, numInteErr # answer = json, numCor = 정답 수, numErr = 오답 수, answerCounter = 정답수, numInteErr = 통합에러
    flag = True

    numK = len(result.keys()) #Answer_dict key 개수
    if numK-5 != len(answer[name].keys()):
        flag = False
    else :
        for site in result.keys():
            if site != 'name' and site != 'fid' and site != 'keyId' and site != 'inst' and site != 'pre_name':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 5:
                        if answer[name][site] != result[site]['inst']:
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag:
        numCor += 1
        answerCounter[name] += 1
    else:
        if len(answer[name].keys()) > 1:
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {name} {answer[name]}\n - Result : {result}")
        else:
            pass
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json:

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:        
        name = Answer_dict[answer_one]['name'].split('_')[0]

        if name in answer :
            ansCheck(Answer_dict[answer_one], name)

        else :
            count = 0
            while name+'_'+str(count) in answer :
                if ansCheck(Answer_dict[answer_one], name+'_'+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

    print("토탈앤써", answercount)
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    print(keyid)
    
print(sorted(Answer_dict.items()))
# Out:
# 462
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_0 {'SCOPUS': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'WOS': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'WOS': {'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'A_id': ['s4209881'], 'papers': [ObjectId('62943ea51649752aa1873f07')], 'oriInst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}, 'SCOPUS': {'inst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'A_id': ['57194213057'], 'papers': [ObjectId('62943eae4c7cb9455f86c724'), ObjectId('62943eaf4c7cb9455f86c754')], 'oriInst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_1 {'SCOPUS': 'Department of Electrical and Computer Engineering Semnan University Semnan Iran', 'WOS': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'WOS': {'inst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran', 'A_id': ['s4209881'], 'papers': [ObjectId('62943ea51649752aa1873f07')], 'oriInst': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}, 'SCOPUS': {'inst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'A_id': ['57194213057'], 'papers': [ObjectId('62943eae4c7cb9455f86c724'), ObjectId('62943eaf4c7cb9455f86c754')], 'oriInst': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_0 {'SCOPUS': 'Young Researchers and Elite Club Ardabil Branch Islamic Azad University Ardabil Iran', 'WOS': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'WOS': {'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'A_id': ['ss9679192'], 'papers': [ObjectId('62943ea41649752aa1873ebc')], 'oriInst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Taheri, Bahman_1 {'SCOPUS': 'Department of Electrical and Computer Engineering Semnan University Semnan Iran', 'WOS': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Taheri, Bahman', 'pre_name': 'taheribahman', 'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'WOS': {'inst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran', 'A_id': ['ss9679192'], 'papers': [ObjectId('62943ea41649752aa1873ebc')], 'oriInst': 'Semnan Univ, Dept Elect & Comp Engn, Semnan, Iran'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Spagnuolo, Giovanni_0 {'SCOPUS': 'DIEM-University of Salerno Via Giovanni Paolo II 132 Fisciano SA  84084 Italy', 'WOS': 'DIEM Univ Salerno, Via Giovanni Paolo II 132, I-84084 Fisciano, SA, Italy'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Spagnuolo, Giovanni', 'pre_name': 'spagnuologiovanni', 'inst': 'Politecn Turino, DET, Corso Duca degli Abruzzi 24, I-10129 Turin, TO, Italy', 'WOS': {'inst': 'Politecn Turino, DET, Corso Duca degli Abruzzi 24, I-10129 Turin, TO, Italy', 'A_id': ['ss9679211', 'ss9679173'], 'papers': [ObjectId('62943ea41649752aa1873ec5'), ObjectId('62943ea41649752aa1873eb7')], 'oriInst': 'Politecn Turino, DET, Corso Duca degli Abruzzi 24, I-10129 Turin, TO, Italy'}, 'SCOPUS': {'inst': 'DIEM-University of Salerno Via Giovanni Paolo II 132 Fisciano SA  84084 Italy', 'A_id': ['7003679851'], 'papers': [ObjectId('62943eae4c7cb9455f86c72c'), ObjectId('62943ead4c7cb9455f86c6ca')], 'oriInst': 'DIEM-University of Salerno Via Giovanni Paolo II 132 Fisciano SA  84084 Italy'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Zerhouni, Noureddine_0 {'SCOPUS': 'FEMTO-ST Institute (UMR CNRS 6174) Univ. Bourgogne Franche-Comte France FCLAB Research Federation (FR CNRS 3539) Univ. Bourgogne Franche-Comte France', 'WOS': 'Univ Bourgogne Franche Comte, FEMTO ST Inst, FCLAB, ENSMM,CNRS, Belfort, France'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Zerhouni, Noureddine', 'pre_name': 'zerhouninoureddine', 'inst': 'Beihang Univ, Sch Reliabil & Syst Engn, Beijing, Peoples R China', 'WOS': {'inst': 'Beihang Univ, Sch Reliabil & Syst Engn, Beijing, Peoples R China', 'A_id': ['ss9679225', 's7323909'], 'papers': [ObjectId('62943ea51649752aa1873ee7'), ObjectId('62943ea51649752aa1873ecb')], 'oriInst': 'Beihang Univ, Sch Reliabil & Syst Engn, Beijing, Peoples R China'}, 'SCOPUS': {'inst': 'FEMTO-ST Institute (UMR CNRS 6174) Univ. Bourgogne Franche-Comte France FCLAB Research Federation (FR CNRS 3539) Univ. Bourgogne Franche-Comte France', 'A_id': ['7003536461'], 'papers': [ObjectId('62943eb04c7cb9455f86c7b0'), ObjectId('62943ead4c7cb9455f86c6ea'), ObjectId('62943ead4c7cb9455f86c6d6')], 'oriInst': 'FEMTO-ST Institute (UMR CNRS 6174) Univ. Bourgogne Franche-Comte France FCLAB Research Federation (FR CNRS 3539) Univ. Bourgogne Franche-Comte France'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Sergi, Thomas {'SCOPUS': 'Department of Mechanical Engineering and Energy Technology HSLU Lucerne University of Applied Sciences Horw 6048 Switzerland', 'WOS': 'Lucerne Univ Appl Sci, HSLU, Dept Mech Engn & Energy Technol, CH-6048 Horw, Switzerland'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Sergi, Thomas', 'pre_name': 'sergithomas', 'inst': 'Lucerne Univ Appl Sci, HSLU, Dept Mech Engn & Energy Technol, CH-6048 Horw, Switzerland', 'WOS': {'inst': 'Lucerne Univ Appl Sci, HSLU, Dept Mech Engn & Energy Technol, CH-6048 Horw, Switzerland', 'A_id': ['ss9679699'], 'papers': [ObjectId('62943ea51649752aa1873f68')], 'oriInst': 'Lucerne Univ Appl Sci, HSLU, Dept Mech Engn & Energy Technol, CH-6048 Horw, Switzerland'}, 'SCOPUS': {'inst': 'Lucerne University of Applied Sciences Horw Switzerland', 'A_id': ['57212227593'], 'papers': [ObjectId('62943eac4c7cb9455f86c695'), ObjectId('62943eb04c7cb9455f86c7c3')], 'oriInst': 'Lucerne University of Applied Sciences Horw Switzerland'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Lim, Hankwon {'SCOPUS': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'WOS': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Lim, Hankwon', 'pre_name': 'limhankwon', 'inst': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'SCOPUS': {'inst': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'A_id': ['14019936500'], 'papers': [ObjectId('62943eaf4c7cb9455f86c772'), ObjectId('62943eae4c7cb9455f86c72e'), ObjectId('62943ead4c7cb9455f86c6f5')], 'oriInst': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Lim, Hankwon {'SCOPUS': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea Department of Energy Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Korea', 'WOS': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Lim, Hankwon', 'pre_name': 'limhankwon', 'inst': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea', 'WOS': {'inst': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea', 'A_id': ['ss9679197'], 'papers': [ObjectId('62943ea41649752aa1873ebf')], 'oriInst': 'Ulsan Natl Inst Sci & Technol, Sch Energy & Chem Engn, 50 UNIST Gil, Ulsan 44919, South Korea'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Shikazono, Naoki {'SCOPUS': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'WOS': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Shikazono, Naoki', 'pre_name': 'shikazononaoki', 'inst': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'SCOPUS': {'inst': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'A_id': ['7005214534'], 'papers': [ObjectId('62943eb04c7cb9455f86c7ca')], 'oriInst': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Shikazono, Naoki {'SCOPUS': 'Institute of Industrial Science The University of Tokyo Tokyo 153-8505 Japan', 'WOS': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan'}
#  - Result : {'fid': 0, 'keyId': 904, 'name': 'Shikazono, Naoki', 'pre_name': 'shikazononaoki', 'inst': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan', 'WOS': {'inst': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan', 'A_id': ['s7321227'], 'papers': [ObjectId('62943ea51649752aa1873f3e')], 'oriInst': 'Univ Tokyo, Inst Ind Sci, Tokyo 1538505, Japan'}}
# num코렉트 264
# numEror 107
# numInteEror 11
# answer= ﻿Abd El Sattar, Montaser {'WOS': 'South Valley Univ, Fac Engn, Dept Elect Engn, Qena 83523, Egypt'}
# answer= Ibáñez, Jorge G. {'SCOPUS': 'Department of Chemical Industrial and Food Engineering Universidad Iberoamericana Prolongacion Reforma 880 Mexico City 01219 Mexico', 'WOS': 'Univ Iberoamer, Dept Chem Ind & Food Engn, Mexico City 01219, DF, Mexico'}
# answer= Jacquez T. {'SCOPUS': 'Beloit College 700 College Street Beloit WI  53511 United States'}
# answer= Jacquez, Tess {'WOS': 'Beloit Coll, Beloit, WI 53511 USA'}
# answer= Jafari H. {'SCOPUS': 'Young Researchers and Elite Club Islamic Azad University Ardabil Branch Ardabil Iran'}
# answer= Jafari, Hasan {'WOS': 'Islamic Azad Univ, Ardabil Branch, Young Researchers & Elite Club, Ardebil, Iran'}
# answer= Jiao, Kui_0 {'SCOPUS': 'State Key Laboratory of Engines Tianjin University 135 Yaguan Road Tianjin China'}
# answer= Jiao, Kui_1 {'WOS': 'Tsinghua Univ, Dept Energy & Power Engn, Beijing 100084, Peoples R China'}
# answer= Jurado, Francisco_0 {'SCOPUS': 'Departament of Electrical Engineering University of Jaen Las Lagunillas Jaen Andalucía  23009 Spain'}
# answer= Jurado, Francisco_1 {'WOS': 'Univ Malaga, Dept Elect Engn, Bulevar Louis Pasteur, Malaga 29010, Andalucia, Spain'}
# answer= Khooban, Mohammad Hassan {'SCOPUS': 'Department of Electrical and Computer Engineering Aarhus University Aarhus Denmark', 'WOS': 'Aarhus Univ, Dept Engn, DIGIT, Finlandsgade 22, DK-8200 Aarhus, Denmark'}
# answer= Khoshnevisan A. {'SCOPUS': 'School of Mechanical Engineering Faculty of Engineering University of Tehran P.O. Box 11155-4563 Tehran Iran'}
# answer= Khoshnevisan, Alireza {'WOS': 'Univ Tehran, Sch Mech Engn, Fac Engn, POB 11155-4563, Tehran, Iran'}
# answer= Kim G.M. {'SCOPUS': 'School of Mechanical Engineering Kyungpook National University Daegu 41566 South Korea'}
# answer= Kim, Min Soo_0 {'SCOPUS': 'Department of Mechanical and Aerospace Engineering Seoul National University Seoul 08826 South Korea'}
# answer= Kim, Min Soo_1 {'WOS': 'Korea Inst Machinery & Mat, Dept Clean Fuel & Power Generat, Daejon 34103, South Korea'}
# answer= Leung, P. K. {'WOS': 'Beijing Univ Aeronaut & Astronaut, Sch Microelect, 37 Xueyuan Rd, Beijing 100191, Peoples R China'}
# answer= Leung, Puiki {'SCOPUS': 'Key Laboratory of Low-grade Energy Utilization Technologies and Systems MOE Chongqing University Chongqing 400030 China'}
# answer= Li X._1 {'SCOPUS': 'John A. Paulson School of Engineering and Applied Sciences Harvard University Cambridge MA  02138 United States'}
# answer= Li, Xi_0 {'SCOPUS': 'School of Artificial Intelligence and Automation Key Laboratory of Image Processing and Intelligent Control of Education Ministry Huazhong University of Science and Technology Wuhan Hubei  430074 China'}
# answer= Li, Xi_1 {'WOS': 'Wuhan Univ Sci & Technol, Hubei Prov Key Lab Intelligent Informat Proc & Re, Coll Comp Sci & Technol, Wuhan 430081, Hubei, Peoples R China'}
# answer= Li, Xi_2 {'WOS': 'Guangdong Energy Grp Co Ltd, Guangzhou 510630, Peoples R China'}
# answer= Li, Xuefang_0 {'SCOPUS': 'Institute of Thermal Science and Technology Shandong University Jinan 250061 China'}
# answer= Li, Xuefang_1 {'WOS': 'Tsinghua Univ, Key Lab Thermal Sci & Power Engn, Minist Educ, Beijing 100084, Peoples R China'}
# answer= Lim, Hankwon {'SCOPUS': 'School of Energy and Chemical Engineering Ulsan National Institute of Science and Technology 50 UNIST-gil Eonyang-eup Ulju-gun Ulsan 44919 South Kor
# answer= Zhang, Qi_1 {'WOS': 'Chinese Acad Sci, Natl Sci Lib, Beijing, Peoples R China'}
# answer= Zhang, Zehui {'SCOPUS': 'College of Software Nankai University Tianjin 300071 China', 'WOS': 'Nankai Univ, Coll Software, Tianjin 300071, Peoples R China'}
# answer= Zhao, Dongdong_0 {'SCOPUS': "School of Automation Northwestern Polytechnical University Xi'an 710072 China"}
# answer= Zhao, Dongdong_1 {'WOS': 'Aix Marseille Univ, LIS Lab, UMR CNRS 7020, F-13397 Marseille, France'}
# answer= Zheng, Chunhua_0 {'SCOPUS': 'Shenzhen Institutes of Advanced Technology Chinese Academy of Sciences 1068 Xueyuan Avenue Shenzhen University Town Shenzhen 518055 China'}
# answer= Zheng, Chunhua_1 {'WOS': 'Seoul Natl Univ, Sch Mech & Aerosp Engn, San 56-1, Seoul 151742, South Korea'}
# answer= Zhu Y. {'SCOPUS': 'School of Automation Engineering University of Electronic Science and Technology of China Chengdu China'}
# 토탈앤써 462
# 토탈인터그레이션 93
# --------------------------------
# 토탈에러 198
# 토탈인터그레이션에러 26
# 904
# [('abdelsattarmontaser', {'fid': 0, 'keyId': 904, 'name': 'Abd El Sattar, Montaser', 'pre_name': 'abdelsattarmontaser', 'inst': 'South Valley Univ, Fac Engn, Dept Elect Engn, Qena 83523, Egypt', 'WOS': {'inst': 'South Valley Univ, Fac Engn, Dept Elect Engn, Qena 83523, Egypt', 'A_id': ['ss9679529'], 'papers': [ObjectId('62943ea51649752aa1873f37')], 'oriInst': 'South Valley Univ, Fac Engn, Dept Elect Engn, Qena 83523, Egypt'}}), ('abelseabrajoaquime', {'fid': 0, 'keyId': 904, 'name': 'Abel Seabra, Joaquim E.', 'pre_name': 'abelseabrajoaquime', 'inst': 'School of Mechanical Engineering University of Campinas Campinas São Paulo Brazil', 'SCOPUS': {'inst': 'School of Mechanical Engineering University of Campinas Campinas São Paulo Brazil', 'A_id': ['23390441500'], 'papers': [ObjectId('62943eae4c7cb9455f86c70b')], 'oriInst': 'School of Mechanical Engineering University of Campinas Campinas São Paulo Brazil'}}), ('abidomohameda', {'fid': 0, 'keyId': 904, 'name': 'Abido, Mohamed A.', 'pre_name': 'abidomohameda', 'inst': 'Electrical Engineering Department King Fahd University of Petroleum and Minerals Dhahran 31261 Saudi Arabia', 'SCOPUS': {'inst': 'Electrical Engineering Department King Fahd University of Petroleum and Minerals Dhahran 31261 Saudi Arabia', 'A_id': ['56048231100'], 'papers': [ObjectId('62943ead4c7cb9455f86c6c4')], 'oriInst': 'Electrical Engineering Department King Fahd University of Petroleum and Minerals Dhahran 31261 Saudi Arabia'}, 'WOS': {'inst': 'King Fahd Univ Petr & Minerals, Elect Engn Dept, Dhahran 31261, Saudi Arabia', 'A_id': ['ss9679559'], 'papers': [ObjectId('62943ea51649752aa1873f3f')], 'oriInst': 'King Fahd Univ Petr & Minerals, Elect Engn Dept, Dhahran 31261, Saudi Arabia'}}), ('actonscottthomas', {'fid': 0, 'keyId': 904, 'name': 'Acton, Scott Thomas', 'pre_name': 'actonscottthomas', 'inst': 'University of Virginia Electrical and Computer Engineering Charlottesville United States', 'SCOPUS': {'inst': 'University of Virginia Electrical and Computer Engineering Charlottesville United States', 'A_id': ['7006577888'], 'papers': [ObjectId('62943ead4c7cb9455f86c6d1')], 'oriInst': 'University of Virginia Electrical and Computer Engineering Charlottesville United States'}}), ('adamsstefan', {'fid': 0, 'keyId': 904, 'name': 'Adams, Stefan', 'pre_name': 'adamsstefan', 'inst': 'Natl Univ Singapore, Dept Mat Sci & Engn, Singapore 117575, Singapore', 'WOS': {'inst': 'Natl Univ Singapore, Dept Mat Sci & Engn, Singapore 117575, Singapore', 'A_id': ['s7106180'], 'papers': [ObjectId('62943ea61649752aa1873f97')], 'oriInst': 'Natl Univ Singapore, Dept Mat Sci & Engn, Singapore 117575, Singapore'}}), ('adlersb_0', {'fid': 0, 'keyId': 904, 'name': 'Adler, S. B.', 'pre_name': 'adlersb', 'inst': 'Univ Calif Irvine, Natl Fuel Cell Res Ctr, Irvine, CA 92697 USA', 'WOS': {'inst': 'Univ Calif Irvine, Natl Fuel Cell Res Ctr, Irvine, CA 92697 USA', 'A_id': ['ss9679245'], 'papers': [ObjectId('62943ea51649752aa1873ed2')], 'oriInst': 'Univ Calif Irvine, Natl Fuel Cell Res Ctr, Irvine, CA 92697 USA'}, 'SCOPUS': {'inst': 'Department of Chemical Engineering University of Washington Seattle WA  98105 United States', 'A_id': ['7202093500'], 'papers': [ObjectId('62943eac4c7cb9455f86c6a9')], 'oriInst': 'Department of Chemical Engineering University of Washington Seattle WA  98105 United States'}}), ('aissabrahim', {'fid': 0, 'keyId': 904, 'name': 'Aissa, Brahim', 'pre_name': 'aissabrahim', 'inst': 'Clemson Univ, Dept Chem, Clemson, SC 29634 USA', 'WOS': {'inst': 'Clemson Univ, Dept Chem, Clemson, SC 29634 USA', 'A_id': ['ss9679661'], 'papers': [ObjectId('62943ea51649752aa1873f5a')], 'oriInst': 'Clemson Univ, Dept Chem, Clemson, SC 29634 USA'}}), ('akkoçg', {'fid': 0, 'keyId': 904, 'name': 'Akkoç G.', 'pre_name': 'akkoçg', 'inst': 'Department of Chemical Engineering Gazi University Maltepe-Ankara 06570 Turkey', 'SCOPUS': {'inst': 'Department of Chemical Engineering Gazi University Maltepe-Ankara 06570 Turkey', 'A_id': ['57340332800'], 'paper ...

# %%
pair_test = ['biswasrajib', 'biswasr']
  
getRaw(pair_test[0])
getRaw(pair_test[1])

raws1 = Answer_dict[pair_test[0]]['raws']
raws2 = Answer_dict[pair_test[1]]['raws']

name1 = Answer_dict[pair_test[0]]['name']
name2 = Answer_dict[pair_test[1]]['name']

for ra1, ra2 in zip(raws1, raws2):
    site1 = ra1['site']
    site2 = ra2['site']
    inst1 = Answer_dict[pair_test[0]][site1]['oriInst']
    inst2 = Answer_dict[pair_test[1]][site2]['oriInst']
    Secondary_filter2(name1, name2, site1, inst1, ra1, site2, inst2, ra2)
# Out:
# weigth: 4 | joc: 0 | yop: 2021, 2021 | co_author_count: 0| keyword: [['T']], [['T']]
# name: Biswas, Rajib | inst1: Department of Physics Tezpur University Tezpur 784028 India | title1: Outlining Big Data Analytics in Health Sector with Special Reference to Covid-19 | site1: SCOPUS
# name: Biswas, R. | inst2: Tezpur Univ, Dept Phys, Tezpur 784028, Assam, India | title2: Outlining Big Data Analytics in Health Sector with Special Reference to Covid-19 | site1: WOS
# inst: 0.7179874517860559 | journal1: Springer | journal2: WIRELESS PERS COMMUN
# ------------------------------------------------------------구분선2------------------------------------------------------------

# %%
pair_test = ['shoshaniarie', 'shoshania'] 
pair_test = ['gagliardopablo', 'gagliardop'] 
pair_test = ['huangqian', 'huangq'] 
pair_test = ['venegasmartinezfrancisco', 'venegasmartínezf'] 
pair_test = ['alzahranifahad', 'alzahranifahda']
pair_test = ['sim´eonjérôme', 'simeonjerome']
pair_test = ['grothpault', 'grothpaul']
pair_test = ['szymańskił', 'szymanskil']
pair_test = ['burinskienėaurelija', 'burinskieneaurelija']
pair_test = ['herrerafrancisco_0', 'herrerafrancisco_1'] 
pair_test = ['pakzadshamimn_0', 'pakzadshamimn_2'] 
pair_test = ['chungyehching_0', 'chungyehching_1']
pair_test = ['huangmaolin_0', 'huangmaolin_1']
pair_test = ['dhavachelvanp_0', 'dhavachelvanp_1']
pair_test = ['bajwahassan_0', 'bajwahassan_1']
pair_test = ['gugulothunarsimha_0', 'gugulothunarsimha_1']
pair_test = ['kimjeongjoon_0', 'kimjeongjoon_1']
pair_test = ['elsayedayman_0', 'elsayedayman_1']
pair_test = ['heshunmin_0', 'heshunmin_1']
pair_test = ['arunachalamar_0', 'arunachalamar_1']
pair_test = ['sharmasanjiv_0', 'sharmasanjiv_1']
pair_test = ['bouamranekarim_0', 'bouamranekarim_2']
pair_test = ['jeyanthin_0', 'jeyanthin_2']
pair_test = ['liguoming', 'ligm']
pair_test = ['chiucarter', 'chiuc'] 
pair_test = ['kwonjiwoong', 'kwonjw'] 
pair_test = ['stepanovalexanderv', 'stepanovav'] 
pair_test = ['balasubramanianmahendran', 'balasubramanianm'] 
pair_test = ['wittebolexavier', 'wittebolex'] 
pair_test = ['nikolaevichtisenkovictor', 'nikolaevichtv'] 
pair_test = ['elsoudanimagdyms', 'elsoudanimms'] 
pair_test = ['chenwei_0', 'chenwei_2']
pair_test = ['sokolenkoliudmyla', 'sokolenkol']
pair_test = ['igarashiyasuhiko', 'igarashiy']
pair_test = ['youkhyun', 'youkh']
pair_test = ['tomásjesúsgarcía', 'tomasjesus']
pair_test = ['rajcpethuru', 'rajpethuru']
pair_test = ['cristeavalentingabriel', 'cristeavalentin']
pair_test = ['sáfilipe', 'safilipe']
pair_test = ['gräbelstefan', 'graebelstefan']
pair_test = ['ionescusorincristian', 'ionescusorin']
pair_test = ['kaliappanm', 'kahappanm']
pair_test = ['jadiamrmohsen', 'jadiamr']
pair_test = ['rashidmohammadanmir', 'rashidmohammeda']
pair_test = ['biswasrajib', 'biswasr']
