# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 990 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []
plang = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']
            plang = fid_key_query[key]['lang']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}
f_plang = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst) and simple_filter(paper_lang, plang):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

print(f'2차 통합: {savetime2}')
print(Inte_name)
print(len(Answer_dict))
# Out:
# DB 수집: WOS, 0.012897491455078125
# 전체 저자 수: 30
# DB 수집: SCOPUS, 0.02765798568725586
# 전체 저자 수: 54
# 2차 통합: 0.040555477142333984
# []
# 84

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    if site == "WOS":
        email.extend(rawdata['emails'].replace(" ", "").split(";"))
        funding_text.append(rawdata['funding text'])
        
    elif site == "SCOPUS":
        emails = rawdata['correspondence_address'].split(" ")
        for i in emails:
            if "@" in i:
                email.append(i)

        for funding in  rawdata.keys():
            if "funding_text_" in funding:
                funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
    
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2:
                funding_exact = 0
                # print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
        
        
    if paper_sim >= 0.8 or inst_sim >= 0.83 or email_exact == 1 or funding_exact == 1:
        weight = 4
        print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
        print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
        print(f'weigth: {weight}')
        print('------------------------------------------------------------구분선2------------------------------------------------------------')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    # print(f'weigth: {weight} | joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')
    # print(f'name1: {name1} | site1: {site1} | year: {year1} | coauthor: {coauthor1} | keyword: {keyword1} | journal1: {journal1}')
    # print(f'name2: {name2} | site1: {site2} | year: {year2} | coauthor: {coauthor2} | keyword: {keyword2} | journal2: {journal2}')
    # print(f'paper_sim: {paper_sim}')
    # print(f'title1: {title1}')
    # print(f'title2: {title2}')
    # print(f'inst_sim: {inst_sim}')
    # print(f'inst1: {inst1}')
    # print(f'inst2: {inst2}')
    # print(f'email_exact: {email_exact}')
    # print(f'emails1: {emails1}')
    # print(f'emails2: {emails2}')
    # print(raw_one1)
    # print(raw_one2)
    print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
    print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
    print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
    print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
    print(f'weigth: {weight}')
    print('------------------------------------------------------------구분선------------------------------------------------------------')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['Electrochemistry'] | journal1: ACS APPL ENERG MATER | journal2: J SOLID STATE ELECTR
# name1: Adyam, Venimadhav | inst1: Indian Inst Technol Kharagpur, Cryogen Engn Ctr, Kharagpur 721302, W Bengal, India | title1: Biphasic alpha/beta-Type NaMn0.89Fe0.11O2 as a Cathode for Sodium-Ion Batteries: Structural Insight and High-Performance Relation | site1: WOS
# name2: Adyam, Venimadhav | inst2: Indian Inst Technol, Cryogen Engn Ctr, Kharagpur 721302, W Bengal, India | title2: Superior diffusion kinetics and electrochemical properties of alpha/beta-type NaMn0.89Co0.11O2 as cathode for sodium-ion batteries | site1: WOS
# inst: 0.9089430894308943 | title: 0.7616742567761295 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Chemistry', ' Science & Technology - Other Topics'], [''] | journal1: GREEN CHEM | journal2: Royal Society of Chemistry
# name1: Guo, Xiaodong | inst1: Qufu Normal Univ, Sch Chem & Chem Engn, Key Lab Pharmaceut Intermediates & Anal Nat Med, Key Lab Life Organ Anal, Qufu 273165, Shandong, Peoples R China | title1: The direct application of spent graphite as a functional interlayer with enhanced polysulfide trapping and catalytic performance for Li-S batteries | site1: WOS
# name2: Guo, Xiaodong | inst2: School of Chemical Engineering Sichuan University Chengdu 610065 China | title2: The direct application of spent graphite as a functional interlayer with enhanced polysulfide trapping and catalytic performance for Li-S batteries | site1: SCOPUS
# inst: 0.5718671679197995 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry'], [''] | journal1: RSC ADV | journal2: Royal Society of Chemistry
# name1: Xie, Guoming | inst1: Chongqing Med Univ, Affiliated Hosp 1, Dept Lab Med, Chongqing 400016, Peoples R China | title1: A nanoprobe for fluorescent monitoring of microRNA and targeted delivery of drugs | site1: WOS
# name2: Xie, Guoming | inst2: Key Laboratory of Laboratory Medical Diagnostics Ministry of Education Department of Laboratory Medicine Chongqing Medical University Chongqing 400016 China | title2: A nanoprobe for fluorescent monitoring of microRNA and targeted delivery of drugs | site1: SCOPUS
# inst: 0.5586956110211924 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Chemistry'], ['Abundant hierarchical pore structure', ' Alkaline zinc-carbon hybrid supercapacitors', ' B, N dual doped carbon', ' Suitable defect construction'] | journal1: J COLLOID INTERF SCI | journal2: Academic Press Inc.
# name1: Pan, Likun | inst1: China Jiliang Univ, Coll Opt & Elect Technol, Inst Optoelect Mat & Devices, Hangzhou 310018, Peoples R China | title1: Enhanced energy storage of aqueous zinc-carbon hybrid supercapacitors via employing alkaline medium and B, N dual doped carbon cathode | site1: WOS
# name2: Pan, Likun | inst2: School of Physics and Electronic Science & Shanghai Key Laboratory of Magnetic Resonance East China Normal University Shanghai 200241 China | title2: Enhanced energy storage of aqueous zinc-carbon hybrid supercapacitors via employing alkaline medium and B, N dual doped carbon cathode | site1: SCOPUS
# inst: 0.6115517842136547 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry', ' Energy & Fuels', ' Engineering', ' Environmental Sciences & Ecology'], [''] | journal1: ENERG ENVIRON SCI | journal2: Royal Society of Chemistry
# name1: Tang, Yuxin | inst1: Univ Wollongong, Australian Inst Innovat Mat, Inst Superconducting & Elect Mat, Innovat Campus,Squires Way, North Wollongong, NSW 2522, Australia | title1: Electrochemical energy storage devices working in extreme conditions | site1: WOS
# name2: Tang, Yuxin | inst2: College of Chemical Engineering Fuzhou University Fuzhou 350116 China | title2: Electrochemical energy storage devices working in extreme conditions | site1: SCOPUS
# inst: 0.5124040816471197 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Science & Technology - Other Topics', ' Materials Science'], ['biomass', ' energy storage mechanis', ' hard carbon', ' nitrogen-doped', ' potassium-ion batteries'] | journal1: ADV NANO RES | journal2: Techno-Press
# name1: Issakhov, Alibek | inst1: Al Farabi Kazakh Natl Univ, Alma Ata, Kazakhstan | title1: The economic and management use of rhododendron petals in potas-sium-ion nano batteries anode via efficient computer simulation | site1: WOS
# name2: Issakhov, Alibek | inst2: Al-Farabi Kazakh National University Almaty Kazakhstan Kazakh-British Technical University Almaty Kazakhstan | title2: The economic and management use of rhododendron petals in potassium-ion nano batteries anode via efficient computer simulation | site1: SCOPUS
# inst: 0.6291666666666668 | title: 0.994459025955089 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['adsorption kinetics', ' charge-transfer conductivity', ' hybrid nanostructure', ' isotherms', ' solvothermal synthesis'] | journal1: ACS APPL ENERG MATER | journal2: American Chemical Society
# name1: Siril, Prem Felix | inst1: Semi Conductor Lab, Dept Space, Sas Nagar 160071, Punjab, India | title1: Intermediate Organic-Inorganic Hybrid with Highly Accessible Pore Structure and Proton Conductivity: Journey from Inorganic Oxide to Metal-Organic Framework | site1: WOS
# name2: Siril, Prem Felix | inst2: School of Basic Sciences Indian Institute of Technology Mandi Himachal Pradesh Mandi 175005 India | title2: Intermediate Organic-Inorganic Hybrid with Highly Accessible Pore Structure and Proton Conductivity: Journey from Inorganic Oxide to Metal-Organic Framework | site1: SCOPUS
# inst: 0.5582494061875505 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Energy & Fuels', ' Engineering'], [''] | journal1: ENERG FUEL | journal2: American Chemical Society
# name1: Guo, Li | inst1: Chinese Acad Sci, Inst Proc Engn, State Key Lab Multiphase Complex Syst, Beijing 100190, Peoples R China | title1: ReaxFF Molecular Dynamics Simulations of Thermal Reactivity of Various Fuels in Pyrolysis and Combustion | site1: WOS
# name2: Guo, Li | inst2: State Key Laboratory of Multiphase Complex Systems Institute of Process Engineering Chinese Academy of Sciences Beijing 100190 China Innovation Academy for Green Manufacture Chinese Academy of Sciences Beijing 100190 China School of Chemical Engineering University of Chinese Academy of Sciences Beijing 100049 China | title2: ReaxFF Molecular Dynamics Simulations of Thermal Reactivity of Various Fuels in Pyrolysis and Combustion | site1: SCOPUS
# inst: 0.588475842961684 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Transportation'], ['Hybrid vehicles', ' Optimal control strategy', ' Three-way catalyst thermal control', ' Vehicle efficiency', ' Vehicle emissions'] | journal1: SAE INT J ELECTR VEH | journal2: SAE International
# name1: Valletta, Andrea | inst1: Univ Roma Tor Vergata, Rome, Italy | title1: Effect of Incorporating the Thermal Management of the Three-Way Catalyst on Energy Effciency and Tailpipe Emissions for a P2 Parallel Hybrid Vehicle | site1: WOS
# name2: Valletta, Andrea | inst2: Università Del Salento Italy | title2: Effect of Incorporating the Thermal Management of the Three-Way Catalyst on Energy Efficiency and Tailpipe Emissions for a P2 Parallel Hybrid Vehicle | site1: SCOPUS
# inst: 0.6314970432617492 | title: 0.9608198802829676 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry', ' Science & Technology - Other Topics', ' Materials Science'], [''] | journal1: NANOSCALE ADV | journal2: Royal Society of Chemistry
# name1: Wang, Hao | inst1: Hubei Univ, Sch Microelect, Hubei Yangtze Memory Labs, Wuhan 430000, Peoples R China | title1: High-rate transition metal-based cathode materials for battery-supercapacitor hybrid devices | site1: WOS
# name2: Wang, Hao | inst2: Hubei Yangtze Memory Labs School of Microelectronics Hubei University Wuhan 430000 China | title2: High-rate transition metal-based cathode materials for battery-supercapacitor hybrid devices | site1: SCOPUS
# inst: 0.8520473818419024 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], [''] | journal1: J MATER CHEM A | journal2: Royal Society of Chemistry
# name1: Huang, Zheng-Hong | inst1: Tsinghua Univ, Grad Sch Shenzhen, Engn Lab Functionalized Carbon Mat, Shenzhen Key Lab Graphene Based Mat, Shenzhen 518055, Guangdong, Peoples R China | title1: Pseudocapacitive porous hard carbon anode with controllable pyridinic nitrogen and thiophene sulfur co-doping for high-power dual-carbon sodium ion hybrid capacitors | site1: WOS
# name2: Huang, Zhenghong | inst2: State Key Laboratory of New Ceramics and Fine Processing School of Materials Science and Engineering Tsinghua University Beijing 100084 China Key Laboratory of Advanced Materials (MOE) School of Materials Science and Engineering Tsinghua University Beijing 100084 China | title2: Pseudocapacitive porous hard carbon anode with controllable pyridinic nitrogen and thiophene sulfur co-doping for high-power dual-carbon sodium ion hybrid capacitors | site1: SCOPUS
# inst: 0.6140057827344073 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['bifunctional catalysts', ' IrO2-covered Ir', ' nanophase-separated structure', ' PtCoW alloy', ' regenerative fuel cells'] | journal1: ACS APPL ENERG MATER | journal2: American Chemical Society
# name1: Liu, Jingjun | inst1: China Acad Space Technol, Beijing Spacecrafts, Beijing 100094, Peoples R China | title1: Nanophase-Engineered Bifunctional Catalysts for Oxygen Electrodes in High-Performance Unitized Regenerative Fuel Cells | site1: WOS
# name2: Liu, Jingjun | inst2: State Key Laboratory of Chemical Resource Engineering Beijing Key Laboratory of Electrochemical Process and Technology for Materials Beijing University of Chemical Technology Beijing 100029 China | title2: Nanophase-Engineered Bifunctional Catalysts for Oxygen Electrodes in High-Performance Unitized Regenerative Fuel Cells | site1: SCOPUS
# inst: 0.5568172568172568 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 6 | keyword: ['Chemistry'], [''] | journal1: J AM CHEM SOC | journal2: American Chemical Society
# name1: Kong, Biao | inst1: Univ New South Wales, Sch Chem Engn, Grad Sch Biomed Engn, Sydney, NSW 2052, Australia | title1: Kinetics-Controlled Super-Assembly of Asymmetric Porous and Hollow Carbon Nanoparticles as Light-Sensitive Smart Nanovehicles | site1: WOS
# name2: Kong, Biao | inst2: Department of Chemistry Shanghai Key Lab of Molecular Catalysis and Innovative Materials Collaborative Innovation Center of Chemistry for Energy Materials Fudan University Shanghai 200438 China | title2: Kinetics-Controlled Super-Assembly of Asymmetric Porous and Hollow Carbon Nanoparticles as Light-Sensitive Smart Nanovehicles | site1: SCOPUS
# inst: 0.5195184158733984 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Chemistry', ' Materials Science'], ['Extreme fast charging', ' Freeze tape casting', ' Graphite anode', ' Layered electrodes', ' Tortuosity'] | journal1: CARBON | journal2: Elsevier Ltd
# name1: Li, Jianlin | inst1: Oak Ridge Natl Lab, Electrificat & Energy Infrastruct Div, Oak Ridge, TN 37831 USA | title1: Bilayer hybrid graphite anodes via freeze tape casting for extreme fast charging applications | site1: WOS
# name2: Li, Jianlin | inst2: Electrification and Energy Infrastructures Division Oak Ridge National Laboratory Oak Ridge TN  37831 United States | title2: Bilayer hybrid graphite anodes via freeze tape casting for extreme fast charging applications | site1: SCOPUS
# inst: 0.7310017306835971 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['adyamvenimadhav_1', 'guoxiaodong_1', 'xieguoming_1', 'panlikun_1', 'tangyuxin_1', 'issakhovalibek_1', 'sirilpremfelix_1', 'guoli_1', 'vallettaandrea_1', 'wanghao_1', 'huangzhenghong_1', 'liujingjun_1', 'kongbiao_1', 'lijianlin_1']

# %%
deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        if name_sim >= 0.8 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
                    flag = True
                    break
            if flag :
                break
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Pharmacology & Pharmacy', ' Toxicology'], ['Energy & Fuels', ' Engineering'] | journal1: J PHARMACOL TOX MET | journal2: FUEL
# name1: Liu, Chang-Ning | inst1: Pfizer Worldwide R&D & Med, Drug Safety Res & Dev, Groton, CT 06340 USA | title1: Novel in vivo and ex vivo hybrid in vivo imaging system (IVIS) imaging offers a convenient and precise way to measure the glomerular filtration rate in conscious mice | site1: WOS
# name2: Liu, Jingping | inst2: Jiangsu Univ, Inst Energy Res, Zhenjiang 212013, Jiangsu, Peoples R China | title2: A review of controlling strategies of the ignition timing and combustion phase in homogeneous charge compression ignition (HCCI) engine | site1: WOS
# inst: 0.5011500645019729 | title: 0.7233712628290941 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Pharmacology & Pharmacy', ' Toxicology'], ['FMT', ' GFR', ' GFR-Vivo 680', ' IVIS', ' Optical imaging', ' Renal function'] | journal1: J PHARMACOL TOX MET | journal2: Elsevier Inc.
# name1: Liu, Chang-Ning | inst1: Pfizer Worldwide R&D & Med, Drug Safety Res & Dev, Groton, CT 06340 USA | title1: Novel in vivo and ex vivo hybrid in vivo imaging system (IVIS) imaging offers a convenient and precise way to measure the glomerular filtration rate in conscious mice | site1: WOS
# name2: Liu C.-N. | inst2: Comparative Medicine Pfizer Worldwide R&D and Medical Groton CT  06340 United States | title2: Novel in vivo and ex vivo hybrid in vivo imaging system (IVIS) imaging offers a convenient and precise way to measure the glomerular filtration rate in conscious mice | site1: SCOPUS
# inst: 0.6637044489157166 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Chemistry'], [''] | journal1: RSC ADV | journal2: Royal Society of Chemistry
# name1: Burghard, Zaklina | inst1: Univ Stuttgart, Inst Mat Sci, Stuttgart, Germany | title1: Self-supporting V2O5 nanofiber-based electrodes for magnesium-lithium-ion hybrid batteries | site1: WOS
# name2: Burghard, Žaklina | inst2: Institute for Materials Science University of Stuttgart Stuttgart Germany | title2: Self-supporting V2O5nanofiber-based electrodes for magnesium-lithium-ion hybrid batteries | site1: SCOPUS
# inst: 0.6958627369586274 | title: 0.9303620474406992 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Materials Science', ' Physics'], ['Energy & Fuels', ' Nuclear Science & Technology'] | journal1: NANOTECHNOLOGY | journal2: INT J ENERG RES
# name1: Wang, You | inst1: Northwestern Univ, Theoret & Appl Mech Program, 2145 Sheridan Rd, Evanston, IL 60208 USA | title1: Engineering SnO2 nanorods/ethylenediamine-modified graphene heterojunctions with selective adsorption and electronic structure modulation for ultrasensitive room-temperature NO2 detection | site1: WOS
# name2: Wang, Bao | inst2: Chinese Acad Sci, Inst Proc Engn, State Key Lab Biochem Engn, Beijing 100190, Peoples R China | title2: Review of low-temperature lithium-ion battery progress: New battery system design imperative | site1: WOS
# inst: 0.5956487626691361 | title: 0.6326518749792407 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Esculin', ' Hesperidin', ' Kinetic model', ' pH-dependent release', ' Polysaccharide particle', ' Thyme oil'], ['Polymer Science'] | journal1: Elsevier Ltd | journal2: EUR POLYM J
# name1: Wilk, Kazimiera Anna | inst1: Department of Engineering and Technology of Chemical Processes Wrocław University of Science and Technology Wybrzeże Wyspiańskiego 27 Wrocław 50-370 Poland | title1: Tailoring the composition of hydrogel particles for the controlled delivery of phytopharmaceuticals | site1: SCOPUS
# name2: Wilk, Kazimiera A. | inst2: Wroclaw Univ Sci & Technol, Dept Geotechnol Hydrotechnol & Underground & Hydr, Wybrzeze Wyspianskiego 27, PL-50370 Wroclaw, Poland | title2: Tailoring the composition of hydrogel particles for the controlled delivery of phytopharmaceuticals | site1: WOS
# inst: 0.7006587498522983 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Pharmacology & Pharmacy', ' Toxicology'], ['Energy & Fuels', ' Engineering'] | journal1: J PHARMACOL TOX MET | journal2: FUEL
# name1: Liu, Chang-Ning | inst1: Pfizer Worldwide R&D & Med, Drug Safety Res & Dev, Groton, CT 06340 USA | title1: Novel in vivo and ex vivo hybrid in vivo imaging system (IVIS) imaging offers a convenient and precise way to measure the glomerular filtration rate in conscious mice | site1: WOS
# name2: Liu, Jingping | inst2: Jiangsu Univ, Inst Energy Res, Zhenjiang 212013, Jiangsu, Peoples R China | title2: A review of controlling strategies of the ignition timing and combustion phase in homogeneous charge compression ignition (HCCI) engine | site1: WOS
# inst: 0.5011500645019729 | title: 0.7233712628290941 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Engineering'], ['Compressible Navier–Stokes equations', ' Large-eddy simulation', ' Reacting jet in crossflow', ' Turbulent combustion'] | journal1: INT J AERONAUT SPACE | journal2: Korean Society for Aeronautical and Space Sciences
# name1: Er-raiy, Aimad | inst1: King Abdullah Univ Sci & Technol KAUST, ECRC, Thuwal 23955, Saudi Arabia | title1: LES of Reacting Flow in a Hydrogen Jet into Supersonic Crossflow Combustor Using a New Turbulent Combustion Model | site1: WOS
# name2: Er-raiy A. | inst2: King Abdullah University of Science and Technology (KAUST) ECRC Thuwal 23955 Saudi Arabia | title2: LES of Reacting Flow in a Hydrogen Jet into Supersonic Crossflow Combustor Using a New Turbulent Combustion Model | site1: SCOPUS
# inst: 0.8711096423588162 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Bifunctional oxygen catalyst', ' Electrolyte', ' Hybrid Zn battery', ' Quasi-neutral electrolyte', ' Quasi-solid-state battery', ' Zinc-air battery'], ['Science & Technology - Other Topics', ' Energy & Fuels'] | journal1: Elsevier Ltd | journal2: RENEW SUST ENERG REV
# name1: Leung, Dennis Yiu Cheong | inst1: Department of Mechanical Engineering The University of Hong Kong Pokfulam Road Hong Kong | title1: Rechargeable Zn-air batteries: Recent trends and future perspectives | site1: SCOPUS
# name2: Leung, Dennis Y. C. | inst2: Hong Kong Polytech Univ, Hung Hom, Dept Bldg & Real Estate, 11 Yuk Choi Rd, Hong Kong, Peoples R China | title2: Rechargeable Zn-air batteries: Recent trends and future perspectives | site1: WOS
# inst: 0.6611705288175876 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Energy & Fuels', ' Nuclear Science & Technology'], ['Dynamic programming', ' Equivalent fuel consumption', ' Genetic algorithm', ' Hybrid electric vehicle', ' Instantaneous control strategy', ' Vehicle engineering'] | journal1: INT J ENERG RES | journal2: Zhejiang University
# name1: Wang, Bao | inst1: Chinese Acad Sci, Inst Proc Engn, State Key Lab Biochem Engn, Beijing 100190, Peoples R China | title1: Review of low-temperature lithium-ion battery progress: New battery system design imperative | site1: WOS
# name2: Wang Q. | inst2: School of Mechanical Engineering Nanjing University of Science and Technology Nanjing 210094 China | title2: Velocity planning strategy for economic cruise of hybrid electric vehicles [混合动力汽车经济型巡航的车速规划策略 | site1: SCOPUS
# inst: 0.6241610891668495 | title: 0.6231188992179878 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Additive manufacturing', ' CBR defence', ' Chemical warfare agents', ' Protection of ERA', ' Radar absorbent material', ' Vehicle decontamination'], ['Batteries', ' electrochemical processes', ' energy storage', ' hybrid power systems'] | journal1: China Ordnance Industry Corporation | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Pirszel, Jacek | inst1: Military Institute of Chemistry and Radiometry al. gen. Antoniego Chrusciela “Montera” 105 Warszawa 00-910 Poland | title1: Protection of armoured vehicles against chemical, biological and radiological contamination | site1: SCOPUS
# name2: Eliasz, Jacek | inst2: Department of Automotive Engineering Faculty of Mechanical Engineering and Mechatronics West Pomeranian University of Technology in Szczecin Szczecin 70-310 Poland | title2: Road Test of Selected Electrical Parameters of the Hybrid Vehicle Accumulation System | site1: SCOPUS
# inst: 0.6604749291111486 | title: 0.6630132394838277 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Additive manufacturing', ' CBR defence', ' Chemical warfare agents', ' Protection of ERA', ' Radar absorbent material', ' Vehicle decontamination'], ['Batteries', ' electrochemical processes', ' energy storage', ' hybrid power systems'] | journal1: China Ordnance Industry Corporation | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Pirszel, Jacek | inst1: Military Institute of Chemistry and Radiometry al. gen. Antoniego Chrusciela “Montera” 105 Warszawa 00-910 Poland | title1: Protection of armoured vehicles against chemical, biological and radiological contamination | site1: SCOPUS
# name2: Eliasz, Jacek | inst2: Department of Automotive Engineering Faculty of Mechanical Engineering and Mechatronics West Pomeranian University of Technology in Szczecin Szczecin 70-310 Poland | title2: Road Test of Selected Electrical Parameters of the Hybrid Vehicle Accumulation System | site1: SCOPUS
# inst: 0.6604749291111486 | title: 0.6630132394838277 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Esculin', ' Hesperidin', ' Kinetic model', ' pH-dependent release', ' Polysaccharide particle', ' Thyme oil'], ['Polymer Science'] | journal1: Elsevier Ltd | journal2: EUR POLYM J
# name1: Wilk, Kazimiera Anna | inst1: Department of Engineering and Technology of Chemical Processes Wrocław University of Science and Technology Wybrzeże Wyspiańskiego 27 Wrocław 50-370 Poland | title1: Tailoring the composition of hydrogel particles for the controlled delivery of phytopharmaceuticals | site1: SCOPUS
# name2: Wilk, Kazimiera A. | inst2: Wroclaw Univ Sci & Technol, Dept Geotechnol Hydrotechnol & Underground & Hydr, Wybrzeze Wyspianskiego 27, PL-50370 Wroclaw, Poland | title2: Tailoring the composition of hydrogel particles for the controlled delivery of phytopharmaceuticals | site1: WOS
# inst: 0.7006587498522983 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Energy & Fuels', ' Engineering'], ['FMT', ' GFR', ' GFR-Vivo 680', ' IVIS', ' Optical imaging', ' Renal function'] | journal1: FUEL | journal2: Elsevier Inc.
# name1: Liu, Jingping | inst1: Jiangsu Univ, Inst Energy Res, Zhenjiang 212013, Jiangsu, Peoples R China | title1: A review of controlling strategies of the ignition timing and combustion phase in homogeneous charge compression ignition (HCCI) engine | site1: WOS
# name2: Liu C.-N. | inst2: Comparative Medicine Pfizer Worldwide R&D and Medical Groton CT  06340 United States | title2: Novel in vivo and ex vivo hybrid in vivo imaging system (IVIS) imaging offers a convenient and precise way to measure the glomerular filtration rate in conscious mice | site1: SCOPUS
# inst: 0.5208782845769148 | title: 0.7233712628290941 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Materials Science', ' Physics'], ['Dynamic programming', ' Equivalent fuel consumption', ' Genetic algorithm', ' Hybrid electric vehicle', ' Instantaneous control strategy', ' Vehicle engineering'] | journal1: NANOTECHNOLOGY | journal2: Zhejiang University
# name1: Wang, You | inst1: Northwestern Univ, Theoret & Appl Mech Program, 2145 Sheridan Rd, Evanston, IL 60208 USA | title1: Engineering SnO2 nanorods/ethylenediamine-modified graphene heterojunctions with selective adsorption and electronic structure modulation for ultrasensitive room-temperature NO2 detection | site1: WOS
# name2: Wang Q. | inst2: School of Mechanical Engineering Nanjing University of Science and Technology Nanjing 210094 China | title2: Velocity planning strategy for economic cruise of hybrid electric vehicles [混合动力汽车经济型巡航的车速规划策略 | site1: SCOPUS
# inst: 0.5871212121212122 | title: 0.5587184196696087 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Science & Technology - Other Topics', ' Materials Science'], ['Science & Technology - Other Topics', ' Materials Science', ' Physics'] | journal1: NANOSCALE ADV | journal2: NANOTECHNOLOGY
# name1: Wang, Hao | inst1: Hubei Univ, Sch Microelect, Hubei Yangtze Memory Labs, Wuhan 430000, Peoples R China | title1: High-rate transition metal-based cathode materials for battery-supercapacitor hybrid devices | site1: WOS
# name2: Wang, You | inst2: Northwestern Univ, Theoret & Appl Mech Program, 2145 Sheridan Rd, Evanston, IL 60208 USA | title2: Engineering SnO2 nanorods/ethylenediamine-modified graphene heterojunctions with selective adsorption and electronic structure modulation for ultrasensitive room-temperature NO2 detection | site1: WOS
# inst: 0.6233861168071694 | title: 0.6253815541169562 | email: 0, funding: 0
# weigth: 1.6321205588285577
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Engineering'], ['Compressible Navier–Stokes equations', ' Large-eddy simulation', ' Reacting jet in crossflow', ' Turbulent combustion'] | journal1: INT J AERONAUT SPACE | journal2: Korean Society for Aeronautical and Space Sciences
# name1: Er-raiy, Aimad | inst1: King Abdullah Univ Sci & Technol KAUST, ECRC, Thuwal 23955, Saudi Arabia | title1: LES of Reacting Flow in a Hydrogen Jet into Supersonic Crossflow Combustor Using a New Turbulent Combustion Model | site1: WOS
# name2: Er-raiy A. | inst2: King Abdullah University of Science and Technology (KAUST) ECRC Thuwal 23955 Saudi Arabia | title2: LES of Reacting Flow in a Hydrogen Jet into Supersonic Crossflow Combustor Using a New Turbulent Combustion Model | site1: SCOPUS
# inst: 0.8711096423588162 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Bifunctional oxygen catalyst', ' Electrolyte', ' Hybrid Zn battery', ' Quasi-neutral electrolyte', ' Quasi-solid-state battery', ' Zinc-air battery'], ['Science & Technology - Other Topics', ' Energy & Fuels'] | journal1: Elsevier Ltd | journal2: RENEW SUST ENERG REV
# name1: Leung, Dennis Yiu Cheong | inst1: Department of Mechanical Engineering The University of Hong Kong Pokfulam Road Hong Kong | title1: Rechargeable Zn-air batteries: Recent trends and future perspectives | site1: SCOPUS
# name2: Leung, Dennis Y. C. | inst2: Hong Kong Polytech Univ, Hung Hom, Dept Bldg & Real Estate, 11 Yuk Choi Rd, Hong Kong, Peoples R China | title2: Rechargeable Zn-air batteries: Recent trends and future perspectives | site1: WOS
# inst: 0.6611705288175876 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Energy & Fuels', ' Materials Science'], ['Energy & Fuels', ' Engineering'] | journal1: ACS APPL ENERG MATER | journal2: FUEL
# name1: Liu, Jingjun | inst1: China Acad Space Technol, Beijing Spacecrafts, Beijing 100094, Peoples R China | title1: Nanophase-Engineered Bifunctional Catalysts for Oxygen Electrodes in High-Performance Unitized Regenerative Fuel Cells | site1: WOS
# name2: Liu, Jingping | inst2: Jiangsu Univ, Inst Energy Res, Zhenjiang 212013, Jiangsu, Peoples R China | title2: A review of controlling strategies of the ignition timing and combustion phase in homogeneous charge compression ignition (HCCI) engine | site1: WOS
# inst: 0.6168194710269074 | title: 0.6539146770785189 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Materials Science'], ['Energy & Fuels', ' Engineering'] | journal1: CARBON | journal2: FUEL
# name1: Li, Jianlin | inst1: Oak Ridge Natl Lab, Electrificat & Energy Infrastruct Div, Oak Ridge, TN 37831 USA | title1: Bilayer hybrid graphite anodes via freeze tape casting for extreme fast charging applications | site1: WOS
# name2: Liu, Jingping | inst2: Jiangsu Univ, Inst Energy Res, Zhenjiang 212013, Jiangsu, Peoples R China | title2: A review of controlling strategies of the ignition timing and combustion phase in homogeneous charge compression ignition (HCCI) engine | site1: WOS
# inst: 0.5529887197110719 | title: 0.6435982973617382 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2022 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Materials Science', ' Physics'], ['electrode', ' electrolyte', ' lithium-ion battery', ' low temperature', ' separator'] | journal1: NANOTECHNOLOGY | journal2: John Wiley and Sons Ltd
# name1: Wang, You | inst1: Northwestern Univ, Theoret & Appl Mech Program, 2145 Sheridan Rd, Evanston, IL 60208 USA | title1: Engineering SnO2 nanorods/ethylenediamine-modified graphene heterojunctions with selective adsorption and electronic structure modulation for ultrasensitive room-temperature NO2 detection | site1: WOS
# name2: Wang B. | inst2: State Key Laboratory of Biochemical Engineering Institute of Process Engineering Chinese Academy of Sciences Beijing China | title2: Review of low-temperature lithium-ion battery progress: New battery system design imperative | site1: SCOPUS
# inst: 0.5587812987511003 | title: 0.6326518749792407 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# ['liucn', 'burghardžaklina', 'wilkkazimieraa', 'erraiya', 'leungdennisyc', 'wilkkazimieraa', 'erraiya', 'leungdennisyc']
# 22
# 34

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name):
    global answer, numCor, numErr, answerCounter, numInteErr # answer = json, numCor = 정답 수, numErr = 오답 수, answerCounter = 정답수, numInteErr = 통합에러
    flag = True

    numK = len(result.keys()) #Answer_dict key 개수
    if numK-5 != len(answer[name].keys()):
        flag = False
    else :
        for site in result.keys():
            if site != 'name' and site != 'fid' and site != 'keyId' and site != 'inst' and site != 'pre_name':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 5:
                        if answer[name][site] != result[site]['inst']:
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag:
        numCor += 1
        answerCounter[name] += 1
    else:
        if len(answer[name].keys()) > 1:
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {name} {answer[name]}\n - Result : {result}")
        else:
            pass
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json:

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:        
        name = Answer_dict[answer_one]['name'].split('_')[0]

        if name in answer :
            ansCheck(Answer_dict[answer_one], name)

        else :
            count = 0
            while name+'_'+str(count) in answer :
                if ansCheck(Answer_dict[answer_one], name+'_'+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

    print("토탈앤써", answercount)
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    print(keyid)
    
print(sorted(Answer_dict.items()))
# Out:
# 65
# num코렉트 65
# numEror 0
# numInteEror 0
# 토탈앤써 65
# 토탈인터그레이션 18
# --------------------------------
# 토탈에러 0
# 토탈인터그레이션에러 0
# 990
# [('adyamvenimadhav_0', {'fid': 0, 'keyId': 990, 'name': 'Adyam, Venimadhav', 'pre_name': 'adyamvenimadhav', 'inst': 'Indian Inst Technol Kharagpur, Cryogen Engn Ctr, Kharagpur 721302, W Bengal, India', 'WOS': {'inst': 'Indian Inst Technol Kharagpur, Cryogen Engn Ctr, Kharagpur 721302, W Bengal, India', 'A_id': ['s8376974', 'ss9684947'], 'papers': [ObjectId('62c2c7eb083aec74b0256655'), ObjectId('62c2c7eb083aec74b0256662')], 'oriInst': 'Indian Inst Technol Kharagpur, Cryogen Engn Ctr, Kharagpur 721302, W Bengal, India'}}), ('andriopoulospanagiotis', {'fid': 0, 'keyId': 990, 'name': 'Andriopoulos, Panagiotis', 'pre_name': 'andriopoulospanagiotis', 'inst': 'NATO/STO Centre for Maritime Research and Experimentation (CMRE) La Spezia Italy', 'SCOPUS': {'inst': 'NATO/STO Centre for Maritime Research and Experimentation (CMRE) La Spezia Italy', 'A_id': ['57222083066'], 'papers': [ObjectId('62c2c7db3c10ddfdb32567ac')], 'oriInst': 'NATO/STO Centre for Maritime Research and Experimentation (CMRE) La Spezia Italy'}}), ('anils', {'fid': 0, 'keyId': 990, 'name': 'Anil S.', 'pre_name': 'anils', 'inst': 'CUSAT Kochi', 'SCOPUS': {'inst': 'CUSAT Kochi', 'A_id': ['57224112583'], 'papers': [ObjectId('62c2c7db3c10ddfdb32567ba')], 'oriInst': 'CUSAT Kochi'}}), ('basusuddhasatwa', {'fid': 0, 'keyId': 990, 'name': 'Basu, Suddhasatwa', 'pre_name': 'basusuddhasatwa', 'inst': 'Univ Southern Denmark, Dept Green Technol IGT, SDU Chem Engn, Odense M, Denmark', 'WOS': {'inst': 'Univ Southern Denmark, Dept Green Technol IGT, SDU Chem Engn, Odense M, Denmark', 'A_id': ['ss9684602'], 'papers': [ObjectId('62c2c7eb083aec74b025665d')], 'oriInst': 'Univ Southern Denmark, Dept Green Technol IGT, SDU Chem Engn, Odense M, Denmark'}}), ('benabdelkadera', {'fid': 0, 'keyId': 990, 'name': 'Benabdelkader A.', 'pre_name': 'benabdelkadera', 'inst': 'Laboratory of Smart Grids and Renewable Energies Tahri Mohamed University B.P 417 Bechar 08000 Algeria', 'SCOPUS': {'inst': 'Laboratory of Smart Grids and Renewable Energies Tahri Mohamed University B.P 417 Bechar 08000 Algeria', 'A_id': ['57225196282'], 'papers': [ObjectId('62c2c7db3c10ddfdb32567a3')], 'oriInst': 'Laboratory of Smart Grids and Renewable Energies Tahri Mohamed University B.P 417 Bechar 08000 Algeria'}}), ('bhattacharyyatk', {'fid': 0, 'keyId': 990, 'name': 'Bhattacharyya, T. K.', 'pre_name': 'bhattacharyyatk', 'inst': 'Department of Electronics and Electrical Communication Engineering IIT Kharagpur West Bengal Kharagpur 721302 India', 'SCOPUS': {'inst': 'Department of Electronics and Electrical Communication Engineering IIT Kharagpur West Bengal Kharagpur 721302 India', 'A_id': ['35736906500'], 'papers': [ObjectId('62c2c7d93c10ddfdb3256797')], 'oriInst': 'Department of Electronics and Electrical Communication Engineering IIT Kharagpur West Bengal Kharagpur 721302 India'}}), ('burghardzaklina', {'fid': 0, 'keyId': 990, 'name': 'Burghard, Zaklina', 'pre_name': 'burghardzaklina', 'inst': 'Univ Stuttgart, Inst Mat Sci, Stuttgart, Germany', 'WOS': {'inst': 'Univ Stuttgart, Inst Mat Sci, Stuttgart, Germany', 'A_id': ['s8542018'], 'papers': [ObjectId('62c2c7eb083aec74b0256652')], 'oriInst': 'Univ Stuttgart, Inst Mat Sci, Stuttgart, Germany'}, 'SCOPUS': {'inst': 'Institute for Materials Science University of Stuttgart Stuttgart Germany', 'A_id': ['6506514085'], 'papers': [ObjectId('62c2c7db3c10ddfdb32567b1')], 'oriInst': 'Institute for Materials Science University of Stuttgart Stuttgart Germany'}}), ('catalãojoãops', {'fid': 0, 'keyId': 990, 'name': 'Catalão, João P.S.', 'pre_name': 'catalãojoãops', 'inst': 'Faculty of Engineering University of Porto Porto 4099-002 Portugal', 'SCOPUS': {'inst': 'Faculty of Engineering University of Porto Porto 4099-002 Portugal', 'A_id': ['57204848031'], 'papers': [ObjectId('62c2c7d93c10ddfdb325678e')], 'oriInst': 'Faculty of Engineering University of Porto Porto 4099-002 Portugal'}}), ('chakrabortychandan', {'fid': 0, 'keyId': 990, 'name': 'Chakraborty, Chandan', 'pre_name': 'chakrabort ...
