# %% [markdown]
# '''
# v1: Scienceon, DBPIA, NTIS AuthorPapers 접근하여 Rawdata에서 필터링된 papers를 추가
# v2: Answer 변경 및 f_id 수정 중
# v3: time, tqdm 추가하여 속도 확인
# v4: Scienceon, DBPIA에 mng로 검색 추가
# v5: DBPIA 삭제하고 KCI 추가 & Rawdata 먼저 접급으로 변경, answer check 추가
# '''

# %%
from pymongo import MongoClient
import numpy as np


client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근

f_id = 0 #input
keyid = 676 #keyid

fid_key_query = filter_info.find_one({'fId' : f_id }) #f_id serach

if  f_id > 0 and fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key ==  'nFilter':
            nyear = fid_key_query[key]['year']
        elif key == 'pFilter' :
            pyear = fid_key_query[key]['year']

scion_aut = client['SCIENCEON']['Author']
ntis_aut = client['NTIS']['Author']
kci_aut = client['KCI']['Author']

scion_raw = client['SCIENCEON']['Rawdata']
ntis_raw = client['NTIS']['Rawdata']
kci_raw = client['KCI']['Rawdata']

scion_key_query = scion_raw.find({ 'keyId' : keyid })
ntis_key_query = ntis_raw.find({ 'keyId' : keyid })
kci_key_query = kci_raw.find({ 'keyId' : keyid })

auts = [scion_aut, ntis_aut, kci_aut] #Author
key_querys = [scion_key_query, ntis_key_query, kci_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

A_id = [] # Author id
all_name = [] # Author name
all_inst = [] # Author inst
Answer_dict = {} # Answer result
site = ['SCIENCEON', 'NTIS', 'KCI']

for i in range(len(key_querys)):
    mngid_dict = {} #mngid, paper value dict / site마다

    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if f_id < 1 and fid_key_query == None:
            if key_query['mngId'] not in mngid_dict:
                mngid_dict[key_query['mngId']] = []
            mngid_dict[key_query['mngId']].append(key_query['_id'])

        elif site[i] == 'NTIS' : 
            if key_query['prdEnd'][:4] in nyear or key_query['prdStart'][:4] in nyear : #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

        else:
            if (key_query['issue_year'][:4]) in pyear: #필터링
                if key_query['mngId'] not in mngid_dict:
                    mngid_dict[key_query['mngId']] = []
                mngid_dict[key_query['mngId']].append(key_query['_id'])

    paper = []
    aut_querys = auts[i].find({'_id': { '$in' : list(mngid_dict.keys())}})
    for aut_query in aut_querys :
        A_id = aut_query['_id']
        paper = mngid_dict[A_id]
        all_name.append(aut_query['name'])
        all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_inst.append(aut_query['inst'])
        A_id = [A_id]
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper} }

        if all_name[-1] not in Answer_dict and all_name[-1]+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[all_name[-1]] = Answer
        else :
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]

                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    
                    tempName = all_name[-1]+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                  
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                                Answer_dict[tempName][site[i]]['A_id'].extend(A_id)
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]
                                flag = False
                                break

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt):  # 소속 같을때
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': A_id, 'papers' : paper}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[all_name[-1]+'_'+str(count+1)] = Answer

                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'_0'] = temp
                                    del Answer_dict[all_name[-1]]
                                flag = False
                                break
                count += 1

import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter, numInteErr
    flag = True

    numK = len(result.keys())    
    if numK-3 != len(answer[name].keys()) :
        flag = False
    else :
        for site in result.keys() :        
            if site != 'name' and site != 'fid' and site != 'keyId':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 4:
                        if answer[name][site] != result[site]['inst'] :
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and  answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
    else :
       
        if len(answer[name].keys()) > 1 :
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        else :
            pass
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json :

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        
        name = Answer_dict[test]['name'].split('_')[0]
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            while name+str(count) in answer :
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

    print("토탈앤써", answercount) 
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    
    print(keyid)

#print(Answer_dict)
# Out:
# 위: 정회경
# 위: 이장명
# 위: 박준구
# 위: 이장명
# 이장명_0
# 위: 이장명
# 이장명_1
# 위: 이장명
# 이장명_2
# 위: 이장명
# 이장명_0
# 위: 이장명
# 이장명_1
# 위: 이장명
# 이장명_2
# 위: 이장명
# 이장명_3
# 위: 김영식
# 위: 이장명
# 이장명_0
# 위: 한성익
# 위: 이동현
# 위: 정길도
# 위: 권상주
# {'fid': 0, 'keyId': 676, 'name': '권상주', 'SCIENCEON': {'inst': '한국항공대학교 항공우주기계공학부', 'A_id': ['s979193'], 'papers': [ObjectId('61e1348d5ccde32d6767c87b')]}} 권상주
# 위: 이상문
# 위: 홍현기
# 위: 정명진
# 위: 이대현
# 위: 이재창
# 위: 김경준
# 위: 황헌
# 위: 박광현
# 위: 박석호
# 위: 문형필
# 위: 김재훈
# 위: 최병재
# 위: 권상주
# {'fid': 0, 'keyId': 676, 'name': '권상주', 'SCIENCEON': {'inst': '한국항공대학교 항공우주기계공학부', 'A_id': ['s979193'], 'papers': [ObjectId('61e1348d5ccde32d6767c87b')]}, 'NTIS': {'inst': '한국항공대학교', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjQ0NjExNDAyNjg5MA=='], 'papers': [ObjectId('61e13496e4987315b567ca84'), ObjectId('61e13496e4987315b567ca6d'), ObjectId('61e13494e4987315b567ca47'), ObjectId('61e13493e4987315b567ca26'), ObjectId('61e13491e4987315b567c9fd'), ObjectId('61e13491e4987315b567c9e2'), ObjectId('61e1348fe4987315b567c9ab'), ObjectId('61e1348de4987315b567c97a'), ObjectId('61e1348be4987315b567c93c'), ObjectId('61e13487e4987315b567c90c')]}} 권상주
# {'이상용': {'fid': 0, 'keyId': 676, 'name': '이상용', 'SCIENCEON': {'inst': '경남대학교 컴퓨터공학과', 'A_id': ['s100139'], 'papers': [ObjectId('61e134845ccde32d6767c86d'), ObjectId('61e1348d5ccde32d6767c87d')]}}, '이준환': {'fid': 0, 'keyId': 676, 'name': '이준환', 'SCIENCEON': {'inst': '극동대학교 스마트모바일학과', 'A_id': ['s100362'], 'papers': [ObjectId('61e134845ccde32d6767c870')]}}, '박정민': {'fid': 0, 'keyId': 676, 'name': '박정민', 'SCIENCEON': {'inst': '한국산업기술대학교 컴퓨터공학과', 'A_id': ['s101579'], 'papers': [ObjectId('61e134b15ccde32d6767c8a0')]}}, '서범주': {'fid': 0, 'keyId': 676, 'name': '서범주', 'SCIENCEON': {'inst': '홍익대학교 일반대학원 게임학부', 'A_id': ['s1348623'], 'papers': [ObjectId('61e134935ccde32d6767c891')]}}, '홍현기': {'fid': 0, 'keyId': 676, 'name': '홍현기', 'SCIENCEON': {'inst': '중앙대학교 첨단영상대학원 영상학과', 'A_id': ['s136787'], 'papers': [ObjectId('61e134845ccde32d6767c86b')]}, 'NTIS': {'inst': '중앙대학교', 'A_id': ['bnRpczpCNTUxMTg2LUI1NTExODY+SE1PLjYwODEzMDIxNjgxMw=='], 'papers': [ObjectId('61e13495e4987315b567ca4b'), ObjectId('61e13494e4987315b567ca30'), ObjectId('61e13496e4987315b567ca7b')]}}, '정회경_1': {'fid': 0, 'keyId': 676, 'name': '정회경', 'SCIENCEON': {'inst': 'Department of Computer Engineering, Paichai University', 'A_id': ['s177264'], 'papers': [ObjectId('61e134905ccde32d6767c88a')]}}, '정회경_0': {'fid': 0, 'keyId': 676, 'name': '정회경', 'SCIENCEON': {'inst': '배재대학교', 'A_id': ['s137487'], 'papers': [ObjectId('61e134905ccde32d6767c882'), ObjectId('61e1348d5ccde32d6767c880')]}}, '박인만': {'fid': 0, 'keyId': 676, 'name': '박인만', 'SCIENCEON': {'inst': '(주)인템', 'A_id': ['s249'], 'papers': [ObjectId('61e134935ccde32d6767c88e')]}}, '한성현': {'fid': 0, 'keyId': 676, 'name': '한성현', 'SCIENCEON': {'inst': '경남대학교 기계공학부', 'A_id': ['s253'], 'papers': [ObjectId('61e134865ccde32d6767c875'), ObjectId('61e1349f5ccde32d6767c89c'), ObjectId('61e1349c5ccde32d6767c89a')]}}, '권오석': {'fid': 0, 'keyId': 676, 'name': '권오석', 'SCIENCEON': {'inst': '충남대학교 컴퓨터공학과', 'A_id': ['s265614'], 'papers': [ObjectId('61e1348d5ccde32d6767c876')]}}, '이강희': {'fid': 0, 'keyId': 676, 'name': '이강희', 'SCIENCEON': {'inst': '숭실대학교 글로벌미디어학부', 'A_id': ['s266322'], 'papers': [ObjectId('61e134865ccde32d6767c871')]}}, '정광욱': {'fid': 0, 'keyId': 676, 'name': '정광욱', 'SCIENCEON': {'inst': '구미1대학 정보통신공학과, (주)맨엔텔', 'A_id': ['s271964'], 'papers': [ObjectId('61e134905ccde32d6767c889')]}}, '정길도': {'fid': 0, 'keyId': 676, 'name': '정길도', 'SCIENCEON': {'inst': '전북대학교 전자공학부', 'A_id': ['s275945'], 'papers': [ObjectId('61e134845ccde32d6767c869')]}, 'NTIS': {'inst': '전북대학교', 'A_id': ['850112416765'], 'papers': [ObjectId('61e13496e4987315b567ca83')]}}, '김현태': {'fid': 0, 'keyId': 676, 'name': '김현태', 'SCIENCEON': {'inst': '한밭대학교 전자제어공학과', 'A_id': ['s276386'], 'papers': [ObjectId('61e134935ccde32d6767c892')]}}, '박형배': {'fid': 0, 'keyId': 676, 'name': '박형배', 'SCIENCEON': {'inst': '경기과학기술대학교 자동차과', 'A_id': ['s295877'], 'papers': [ObjectId('61e134845ccde32d6767c86e')]}}, '이장명_1': {'fid': 0, 'keyId': 676, 'name': '이장명', 'SCIENCEON': {'inst': '부산대학교 전자전기공학부', 'A_id': ['s297123'], 'papers': [ObjectId('61e134865ccde32d6767c874')]}}, '이장명_0': {'fid': 0, 'keyId': 676, 'name': '이장명', 'SCIENCEON': {'inst': '부산대학교 전자전기공학과', 'A_id': ['s275959'], 'papers': [ObjectId('61e1348d5ccde32d6767c877')]}, 'NTIS': {'inst': '부산대학교', 'A_id': ['122311105170'], 'papers': [ObjectId('61e13496e4987315b567ca91'), ObjectId('61e13496e4987315b567ca5d'), ObjectId('61e13494e4987315b567ca41'), ObjectId('61e13495e4987315b567ca51'), ObjectId('61e13494e4987315b567ca37'), ObjectId('61e13496e4987315b567ca76')]}}, '윤동환': {'fid': 0, 'keyId': 676, 'name': '윤동환', 'SCIENCEON': {'inst': '한밭대학교 기계공학과', 'A_id': ['s299074'], 'papers': [ObjectId('61e134935ccde32d6767c890')]}}, '최영규': {'fid': 0, 'keyId': 676, 'name': '최영규', 'SCIENCEON': {'inst': 'Department of Electrical Engineering, Pusan National University', 'A_id': ['s325340'], 'papers': [ObjectId('61e1349a5ccde32d6767c896')]}}, 'Lee, Sangmoon': {'fid': 0, 'keyId': 676, 'name': 'Lee, Sangmoon', 'SCIENCEON': {'inst': 'School of Electronic Engineer ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-0a02f9b3be43> in <module>()
#     114                                 if tempName == '권상주':
#     115                                     print(Answer_dict)
# --> 116                                 Answer_dict[tempName][site[i]]['A_id'].extend(A_id)
#     117                                 Answer_dict[tempName][site[i]]['papers'].extend(paper)
#     118                                 flag = False
#
# KeyError: '권상주'
