# %%
from pymongo import MongoClient

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
scion_exfa = client['SCIENCEON']['ExpertFactor']
scion_aut = client['SCIENCEON']['Author']

ntis_exfa = client['NTIS']['ExpertFactor']
ntis_aut = client['NTIS']['Author']
ntis_raw = client['NTIS']['Rawdata']

dbpia_exfa = client['DBPIA']['ExpertFactor']
dbpia_aut = client['DBPIA']['Author']

id_domestic = client['ID']['Domestic']

keyid = 588 #input

scion_key_query = scion_exfa.find({ 'keyId' : keyid })
ntis_key_query = ntis_exfa.find({ 'keyId' : keyid })
dbpia_key_query = dbpia_exfa.find({ 'keyId' : keyid })

key_querys = [scion_key_query, ntis_key_query, dbpia_key_query]
#key_querys = [ntis_key_query]
auts = [scion_aut, ntis_aut, dbpia_aut]
site = ['Scienceon', 'NTIS', 'DBPIA']

Aid = []
a_id = []
all_name_inst = []
all_name = []
all_inst = []
all_site = []
reCopy = []
reCopy_site = []
reCopy_aid = []
Answer_list = []
Answer_dict = {}

for i in range(len(key_querys)):
    #print(key_querys[i])
    for key_query in key_querys[i]:
        Aid = []

        a_id.append(key_query['A_ID'])

        if site[i] == 'NTIS' : 
            # if "11638621" == a_id[-1] :
            #print("check")
            ntis_key_query1 = ntis_raw.find_one({'$and':[{'keyId':keyid},{'mngId':a_id[-1]}]})
            #print(ntis_key_query1)

            if ntis_key_query1 == None :
            #print("check2")
                continue
            else :
                Aid = key_query['A_ID']
        elif site[i] == 'Scienceon' :
            Aid.append(key_query['A_ID'])
        elif site[i] == 'DBPIA' :
            Aid.append(key_query['A_ID'])

        aut_query = auts[i].find_one({'_id':key_query['A_ID']})
        #print(aut_query)

        #all_name_inst.append(aut_query['name'] + '/' + aut_query['inst'])
        all_name.append(aut_query['name'])
        all_inst.append(aut_query['inst'].replace("(주) ", "").replace("(주)", "").split(' ')[0])
        all_site.append(site[i])
        
        Answer = {'name' : all_name[-1], site[i] : {'inst' : all_inst[-1], 'A_id': Aid} }
   
        if all_name[-1] not in Answer_dict and all_name[-1]+'0' not in Answer_dict :
            Answer_dict[all_name[-1]] = Answer
         #   print("insert")
        else :
            
            count = 0
            flag = True
            while flag :
                temp = None 
                tempName = all_name[-1]

              
                if tempName in Answer_dict :        # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = all_name[-1]+str(count)  # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                       # print(tempName)
                        break
                    temp = Answer_dict[tempName]
                      
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' : 
                        src = ""
                        tgt = ""

                        if len(all_inst[-1]) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = all_inst[-1]

                        elif len(all_inst[-1]) < len(temp[key]['inst']):
                            src = all_inst[-1]
                            tgt = temp[key]['inst']
                        # if tempName == '김영미' :
                        #     print(all_inst[-1], temp[key])
                        #     print(ssrc, ttgt)

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt) :  # 소속 같을때
                                flag = False
                                break
                            elif all_name[-1]+str(count+1) not in Answer_dict :
                                Answer_dict[all_name[-1]+str(count+1)] = Answer
                                #if tempName != all_name[-1] :
                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'0'] = temp
                                    del Answer_dict[all_name[-1]]

                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == all_inst[-1] or (src != "" and src in tgt):  # 소속 같을때
                                #if len(src) == 0:
                                 #   flag = False
                                #else:
                                    #print(tempName, site[i], all_inst[-1])
                                    Answer_dict[tempName][site[i]] =  {'inst' : all_inst[-1], 'A_id': Aid}
                                    flag = False
                                    break
                            
                            elif all_name[-1]+str(count+1) not in Answer_dict :
                                Answer_dict[all_name[-1]+str(count+1)] = Answer
                                #if tempName != all_name[-1] :
                                if tempName == all_name[-1]:
                                    Answer_dict[all_name[-1]+'0'] = temp
                                    del Answer_dict[all_name[-1]]   

                count += 1

        # Answer_list.append(Answer)

print(len(Aid), len(all_name), len(all_inst) )
#Answer_dict.sort()
#print(len(Answer_dict))
print(Answer_dict)
#print(sorted(Answer_dict.items()))
# Out:
# 1 1883 1883
# {'천탠이': {'name': '천탠이', 'Scienceon': {'inst': '한양대학교', 'A_id': ['s1087973']}}, '이규혜': {'name': '이규혜', 'Scienceon': {'inst': '한양대학교', 'A_id': ['s1087974']}}, '김기현': {'name': '김기현', 'Scienceon': {'inst': '성신여자대학교', 'A_id': ['s1087976']}}, '변혜원': {'name': '변혜원', 'Scienceon': {'inst': '성신여자대학교', 'A_id': ['s1087977']}}, '양재식': {'name': '양재식', 'Scienceon': {'inst': '서원대학교', 'A_id': ['s1087979']}}, '륙치금': {'name': '륙치금', 'Scienceon': {'inst': '부경대학교', 'A_id': ['s1087980']}}, '남인용': {'name': '남인용', 'Scienceon': {'inst': '부경대학교', 'A_id': ['s1087981']}}, '한정섭': {'name': '한정섭', 'Scienceon': {'inst': '남서울대학교', 'A_id': ['s1087982']}}, '권두순': {'name': '권두순', 'Scienceon': {'inst': '청운대학교', 'A_id': ['s1087983']}}, '김성준': {'name': '김성준', 'Scienceon': {'inst': '남서울대학교', 'A_id': ['s1087984']}}, '권혜민': {'name': '권혜민', 'Scienceon': {'inst': '서울여자대학교', 'A_id': ['s1087986']}}, '이인수': {'name': '이인수', 'Scienceon': {'inst': '대검찰청', 'A_id': ['s1087987']}}, '이승훈': {'name': '이승훈', 'Scienceon': {'inst': '대검찰청', 'A_id': ['s1087988']}}, '노영희': {'name': '노영희', 'Scienceon': {'inst': '건국대학교', 'A_id': ['s122643']}}, '진찬용': {'name': '진찬용', 'Scienceon': {'inst': 'Wonkwang', 'A_id': ['s143722']}}, '남수태': {'name': '남수태', 'Scienceon': {'inst': 'Wonkwang', 'A_id': ['s143724']}}, '박재열': {'name': '박재열', 'Scienceon': {'inst': '충북대학교', 'A_id': ['s258762']}, 'DBPIA': {'inst': '충북대학교', 'A_id': ['1668232']}}, '이준기': {'name': '이준기', 'Scienceon': {'inst': '연세대학교', 'A_id': ['s259510']}}, '최도진': {'name': '최도진', 'Scienceon': {'inst': '충북대학교', 'A_id': ['s259546']}, 'DBPIA': {'inst': '충북대학교', 'A_id': ['4367093']}}, '우경숙': {'name': '우경숙', 'Scienceon': {'inst': '경희대학교', 'A_id': ['s259681']}}, 'Shin, Seong-Yoon': {'name': 'Shin, Seong-Yoon', 'Scienceon': {'inst': 'School', 'A_id': ['s259765']}}, '서동민': {'name': '서동민', 'Scienceon': {'inst': '한국과학기술정보연구원', 'A_id': ['s259999']}, 'DBPIA': {'inst': '한국과학기술정보연구원', 'A_id': ['3468534']}}, '최은정': {'name': '최은정', 'Scienceon': {'inst': '서울여자대학교', 'A_id': ['s260237']}}, '김명주': {'name': '김명주', 'Scienceon': {'inst': '서울여자대학교', 'A_id': ['s260240']}}, '정영섭': {'name': '정영섭', 'Scienceon': {'inst': '순천향대학교', 'A_id': ['s260849']}}, '문재영': {'name': '문재영', 'Scienceon': {'inst': '동서대학교', 'A_id': ['s261536']}}, '설상훈': {'name': '설상훈', 'Scienceon': {'inst': 'Interdisciplinary', 'A_id': ['s261613']}}, '성기훈': {'name': '성기훈', 'Scienceon': {'inst': 'Department', 'A_id': ['s261614']}}, '박수빈': {'name': '박수빈', 'Scienceon': {'inst': '충북대학교', 'A_id': ['s261641']}, 'DBPIA': {'inst': '충북대학교', 'A_id': ['2172833']}}, '송재오': {'name': '송재오', 'Scienceon': {'inst': '제오시스', 'A_id': ['s261642']}, 'DBPIA': {'inst': '제오시스', 'A_id': ['1706098']}}, '남윤재': {'name': '남윤재', 'Scienceon': {'inst': '경희대학교', 'A_id': ['s261699']}}, '박진홍': {'name': '박진홍', 'Scienceon': {'inst': '경희대학교', 'A_id': ['s261700']}, 'DBPIA': {'inst': '경희대학교', 'A_id': ['1275508']}}, '김홍광': {'name': '김홍광', 'Scienceon': {'inst': '건국대학교', 'A_id': ['s261718']}}, '안종욱': {'name': '안종욱', 'Scienceon': {'inst': '안양대학교', 'A_id': ['s261719']}}, '김태연': {'name': '김태연', 'Scienceon': {'inst': '건국대학교', 'A_id': ['s261731']}}, '정대근': {'name': '정대근', 'Scienceon': {'inst': '전남대학교', 'A_id': ['s261732']}}, '이광희': {'name': '이광희', 'Scienceon': {'inst': '한국연구재단', 'A_id': ['s261733']}}, '신현보': {'name': '신현보', 'Scienceon': {'inst': '연세대학교', 'A_id': ['s261869']}}, '선형주': {'name': '선형주', 'Scienceon': {'inst': '연세대학교', 'A_id': ['s261870']}}, '복경수1': {'name': '복경수', 'Scienceon': {'inst': '원광대학교', 'A_id': ['s261881']}, 'DBPIA': {'inst': '원광대학교', 'A_id': ['4366954']}}, '복경수0': {'name': '복경수', 'Scienceon': {'inst': '충북대학교', 'A_id': ['s258056']}, 'DBPIA': {'inst': '충북대학교', 'A_id': ['253221']}}, '홍주현': {'name': '홍주현', 'Scienceon': {'inst': '국민대학교', 'A_id': ['s261882']}, 'DBPIA': {'inst': '국민대학교', 'A_id': ['899411']}}, '김경희': {'name': '김경희', 'Scienceon': {'inst': '한림대학교', 'A_id': ['s261883']}}, '김아연': {'name': '김아연', 'Scienceon': {'inst': '서울시립대학교', 'A_id': ['s261890']}, 'DBPIA': {'inst': '서울시립대학교', 'A_id': ['2297674']}}, '김한나': {'name': '김한나', 'Scienceo ...

# %%
import json

answer = None
numCor = 0
numErr = 0
answerCounter = {}


def ansCheck(result, name) :
    global answer, numCor, numErr, answerCounter
    flag = True

    numK = len(result.keys())   
    if numK-1 != len(answer[name].keys()) : #site 개수 다르면 false
        flag = False
    else :
        for site in result.keys() :
            if site != 'name' : # site name이 다르면
                if site not in answer[name].keys() or result[site] not in answer[name][site] : #answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]): # result key와 answer key가 다르면
                    flag = False
                # elif answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]: 
                #     flag = False
                    # if numK > 2: # site가 2개 이상이면(name 포함 3개이상이면)
                    # if answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0] :
                    #         flag = False
                    # else :
                    #     if answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]:
                    #         flag = False
    if flag :
        numCor += 1
        answerCounter[name] += 1
        #print(f"Correct \n - Answer : {answer[name]}\n - Result : {result}")
    else :
        print(f"Not Correct \n - Answer : {answer[name]}\n - Result : {result}")
        if len(answer[name].keys()) > 1 :
            numErr += 1
    return flag

with open('answer.json', 'r',encoding='UTF8') as a_json :


    answer = json.load(a_json)
    numAns = print(len(answer))
    
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:
        test = answer_one
        #print(test)

        name = Answer_dict[test]['name']
        
        if name in answer :
            ansCheck(Answer_dict[test], name)

        else :
            count = 0
            while name+str(count) in answer :
                # if name+count in answer :
                print(f"Check {name+str(count)}")
                if ansCheck(Answer_dict[test], name+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")

    tempCount = 0
    for key in answerCounter.keys() :
        if answerCounter[key] == 0 :
            tempCount += 1
            print(key)
            print(answer[key])
    print(tempCount)
# Out:
# 1802
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-ef8fb10189e9> in <module>()
#      54
#      55         if name in answer :
# ---> 56             ansCheck(Answer_dict[test], name)
#      57
#      58         else :
#
# <ipython-input-10-ef8fb10189e9> in ansCheck(result, name)
#      18         for site in result.keys() :
#      19             if site != 'name' : # site name이 다르면
# ---> 20                 if site not in answer[name].keys() or result[site] not in answer[name][site] : #answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]): # result key와 answer key가 다르면
#      21                     flag = False
#      22                 # elif answer[name][site] != result[site] and answer[name][site] != result[site].split(' ')[0]:
#
# TypeError: 'in <string>' requires string as left operand, not dict
