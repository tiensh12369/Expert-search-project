# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 993 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []
plang = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']
            plang = fid_key_query[key]['lang']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}
f_plang = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst) and simple_filter(paper_lang, plang):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

print(f'2차 통합: {savetime2}')
print(Inte_name)
print(len(Answer_dict))
# Out:
# DB 수집: WOS, 0.009083271026611328
# 전체 저자 수: 22
# DB 수집: SCOPUS, 0.030779361724853516
# 전체 저자 수: 65
# 2차 통합: 0.039862632751464844
# []
# 87

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    if site == "WOS":
        email.extend(rawdata['emails'].replace(" ", "").split(";"))
        funding_text.append(rawdata['funding text'])
        
    elif site == "SCOPUS":
        emails = rawdata['correspondence_address'].split(" ")
        for i in emails:
            if "@" in i:
                email.append(i)

        for funding in  rawdata.keys():
            if "funding_text_" in funding:
                funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
    
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2:
                funding_exact = 0
                # print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
        
        
    if paper_sim >= 0.8 or inst_sim >= 0.83 or email_exact == 1 or funding_exact == 1:
        weight = 4
        print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
        print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
        print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
        print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
        print(f'weigth: {weight}')
        print('------------------------------------------------------------구분선2------------------------------------------------------------')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    # print(f'weigth: {weight} | joc: {joc} | yop: {yop} | co_authorship: {co_authorship} | keyword: {keyword}')
    # print(f'name1: {name1} | site1: {site1} | year: {year1} | coauthor: {coauthor1} | keyword: {keyword1} | journal1: {journal1}')
    # print(f'name2: {name2} | site1: {site2} | year: {year2} | coauthor: {coauthor2} | keyword: {keyword2} | journal2: {journal2}')
    # print(f'paper_sim: {paper_sim}')
    # print(f'title1: {title1}')
    # print(f'title2: {title2}')
    # print(f'inst_sim: {inst_sim}')
    # print(f'inst1: {inst1}')
    # print(f'inst2: {inst2}')
    # print(f'email_exact: {email_exact}')
    # print(f'emails1: {emails1}')
    # print(f'emails2: {emails2}')
    # print(raw_one1)
    # print(raw_one2)
    print(f'joc: {joc} | yop: {year1}, {year2} | co_author_count: {co_author_count} | keyword: {keyword1}, {keyword2} | journal1: {journal1} | journal2: {journal2}')
    print(f'name1: {name1} | inst1: {inst1} | title1: {title1} | site1: {site1}')
    print(f'name2: {name2} | inst2: {inst2} | title2: {title2} | site1: {site2}')
    print(f'inst: {inst_sim} | title: {paper_sim} | email: {email_exact}, funding: {funding_exact}')
    print(f'weigth: {weight}')
    print('------------------------------------------------------------구분선------------------------------------------------------------')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Communication'], ['Attention', ' interface', ' interface design', ' phatic communication', ' sound', ' voice assistants'] | journal1: NEW MEDIA SOC | journal2: SAGE Publications Ltd
# name1: Levy-Landesberg, Hadar | inst1: Hebrew Univ Jerusalem, Dept Commun & Journalism, IL-9190501 Jerusalem, Israel | title1: Listen up! Phatic thresholds and sound interface design | site1: WOS
# name2: Levy-Landesberg, Hadar | inst2: The Hebrew University of Jerusalem Israel | title2: Listen up! Phatic thresholds and sound interface design | site1: SCOPUS
# inst: 0.6411663484834217 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Psychology'], ['case study', ' COVID-19', ' pandemic', ' perception and cognition', ' social response', ' soundscape', ' urbanism'] | journal1: FRONT PSYCHOL | journal2: Frontiers Media S.A.
# name1: Lindborg, PerMagnus | inst1: City Univ Hong Kong, Sch Creat Media, Kowloon, Hong Kong, Peoples R China | title1: Soundscape in Times of Change: Case Study of a City Neighbourhood During the COVID-19 Lockdown | site1: WOS
# name2: Lindborg, Per Magnus | inst2: School of Creative Media City University of Hong Kong Kowloon Hong Kong | title2: Soundscape in Times of Change: Case Study of a City Neighbourhood During the COVID-19 Lockdown | site1: SCOPUS
# inst: 0.7215429407962363 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Binaural sound', ' Bone-conducted sound', ' Navigation system', ' Semantic differential method', ' Warning sound design'] | journal1: APPL SCI-BASEL | journal2: MDPI AG
# name1: Asakura, Takumi | inst1: Tokyo Univ Sci, Fac Sci & Technol, Dept Mech Engn, Tokyo 1628601, Japan | title1: Bone Conduction Auditory Navigation Device for Blind People | site1: WOS
# name2: Asakura, Takumi | inst2: Department of Mechanical Engineering Faculty of Science and Technology Tokyo University of Science Tokyo 162-8601 Japan | title2: Bone conduction auditory navigation device for blind people | site1: SCOPUS
# inst: 0.6321167118428992 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Science & Technology - Other Topics'], ['Driverless vehicle', ' External interface', ' Human–machine interaction', ' Multimodal', ' Virtual reality'] | journal1: SYMMETRY-BASEL | journal2: MDPI AG
# name1: Xue, Chengqi | inst1: Donghua Univ, Coll Mech Engn, Shanghai 201620, Peoples R China | title1: Evaluation of Multimodal External Human-Machine Interface for Driverless Vehicles in Virtual Reality | site1: WOS
# name2: Xue, Chengqi | inst2: School of Mechanical Engineering Southeast University Nanjing 211189 China | title2: Evaluation of multimodal external human–machine interface for driverless vehicles in virtual reality | site1: SCOPUS
# inst: 0.6417048482937295 | title: 0.996 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering'], ['Blind separation', ' Convolutive BSS', ' Reduction of DOA variance', ' Time-frequency mask', ' VLSI Design'] | journal1: INTEGRATION | journal2: Elsevier B.V.
# name1: Chiou, Yu-He | inst1: Natl Cent Univ, Dept Elect Engn, Taoyuan, Taiwan | title1: Hardware design for blind source separation using fast time-frequency mask technique | site1: WOS
# name2: Chiou, Yuhe | inst2: Department of Electrical Engineering National Central University Taiwan | title2: Hardware design for blind source separation using fast time-frequency mask technique | site1: SCOPUS
# inst: 0.6419661129168172 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Engineering'], ['Acoustic intensimetry', ' Microphone array', ' Omnidirectional compact probe', ' Sound camera', ' Source localization'] | journal1: MECH SYST SIGNAL PR | journal2: Academic Press
# name1: Ih, Jeong-Guon | inst1: Korea Adv Inst Sci & Technol KAIST, Ctr Noise & Vibrat Control, Dept Mech Engn, Daejeon 34141, South Korea | title1: Design of a compact omnidirectional sound camera using the three-dimensional acoustic intensimetry | site1: WOS
# name2: Ih, Jeong Guon | inst2: Center for Noise and Vibration Control Department of Mechanical Engineering Korea Advanced Institute of Science and Technology (KAIST) Daejeon 34141 South Korea | title2: Design of a compact omnidirectional sound camera using the three-dimensional acoustic intensimetry | site1: SCOPUS
# inst: 0.6687357821490699 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['levylandesberghadar_1', 'lindborgpermagnus_1', 'asakuratakumi_1', 'xuechengqi_1', 'chiouyuhe_1', 'ihjeongguon_1']

# %%
deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        if name_sim >= 0.8 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
                    flag = True
                    break
            if flag :
                break
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Neurosciences & Neurology', ' Radiology, Nuclear Medicine & Medical Imaging'], ['auditory-frontal network', ' DCM', ' decision-making', ' fMRI', ' voice'] | journal1: HUM BRAIN MAPP | journal2: John Wiley and Sons Inc
# name1: Fruehholz, Sascha | inst1: Univ Zurich, Dept Psychol, CH-8050 Zurich, Switzerland | title1: Categorizing human vocal signals depends on an integrated auditory-frontal cortical network | site1: WOS
# name2: Frühholz, Sascha | inst2: Department of Psychology University of Zurich Zurich Switzerland Neuroscience Center Zurich University of Zurich and ETH Zurich Zurich Switzerland Center for Integrative Human Physiology (ZIHP) University of Zurich Zurich Switzerland | title2: Categorizing human vocal signals depends on an integrated auditory-frontal cortical network | site1: SCOPUS
# inst: 0.5236719583301657 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['behavioral and psychological symptoms of dementia (BPSD)', ' nursing homes'], ['Psychology', ' Geriatrics & Gerontology', ' Psychiatry'] | journal1: Cambridge University Press | journal2: INT PSYCHOGERIATR
# name1: Luijendijk, Hendrika J.Dika | inst1: Department of General Practice and Elderly Care Medicine University of Groningen University Medical Centre Groningen Groningen Netherlands | title1: Sounds in nursing homes and their effect on health in dementia: A systematic review | site1: SCOPUS
# name2: Luijendijk, Hendrika J. | inst2: Univ Groningen, Dept Youth Studies, Groningen, Netherlands | title2: Sounds in nursing homes and their effect on health in dementia: a systematic review | site1: WOS
# inst: 0.5609464771160518 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['CMU ARCTIC databases', ' DSP digital filter', ' DSP-based'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Guo, Cheng-Yan | inst1: Natl Taiwan Univ, Coll Med, Taipei 10617, Taiwan | title1: A Novel Dentary Bone Conduction Device Equipped with Laser Communication in DSP | site1: WOS
# name2: Guo C.-Y. | inst2: College of Medicine National Taiwan University Taipei 10617 Taiwan | title2: A novel dentary bone conduction device equipped with laser communication in DSP | site1: SCOPUS
# inst: 0.7249579124579123 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Hidden Markov model', ' Human-robot interaction', ' Robotic face', ' Social robotic', ' Voice command'], ['Robotics'] | journal1: Cambridge University Press | journal2: ROBOTICA
# name1: Tabibian, Shima | inst1: Department of Mechanical and Mechatronics Engineering Cyberspace Research Institute Shahid Beheshti University Tehran Iran | title1: Design and Implementation of the Voice Command Recognition and the Sound Source Localization System for Human-Robot Interaction | site1: SCOPUS
# name2: Tabibian, Sh. | inst2: Shahid Beheshti Univ, Cyberspace Res Inst, Dept Mech & Mechatron Engn, Tehran, Iran | title2: Design and Implementation of the Voice Command Recognition and the Sound Source Localization System for Human-Robot Interaction | site1: WOS
# inst: 0.6661422244107803 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['data', ' interaction design', ' narrative', ' radio', ' Retrospection', ' sonification', ' sound', ' voice user interfaces'] | journal1: ACM T COMPUT-HUM INT | journal2: Association for Computing Machinery
# name1: Keegan, Brian | inst1: Univ Colorado, ATLAS Inst, 320 UCB,1125 18th St, Boulder, CO 80309 USA | title1: Examining Narrative Sonification: Using First-Person Retrospection Methods to Translate Radio Production to Interaction Design | site1: WOS
# name2: Keegan B. | inst2: Department of Information Science University of Colorado Boulder Boulder CO United States | title2: Examining Narrative Sonification: Using First-Person Retrospection Methods to Translate Radio Production to Interaction Design | site1: SCOPUS
# inst: 0.5398430533261994 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Education & Educational Research', ' Rehabilitation'], ['Beatalk', ' human beatboxing', ' intellectual disability', ' speech impairments', ' speech intelligibility'] | journal1: INT J DEV DISABIL | journal2: Taylor and Francis Ltd.
# name1: Carl, Micalle | inst1: Ariel Univ, Dept Commun Disorders, IL-40700 Ariel, Israel | title1: Points of view: positive effects of the Beatalk technique on speech characteristics of young adults with intellectual disability | site1: WOS
# name2: Carl M. | inst2: Department of Communication Disorders Ariel University Ariel Israel | title2: Points of view: positive effects of the Beatalk technique on speech characteristics of young adults with intellectual disability | site1: SCOPUS
# inst: 0.6529819573810148 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 3 | keyword: ['Computer Science', ' Health Care Sciences & Services', ' Medical Informatics'], ['Caregiver', ' Chatbot', ' Communication', ' Machine learning', ' Quality of life'] | journal1: INT J MED INFORM | journal2: Elsevier Ireland Ltd
# name1: Naylor, Mary D. | inst1: Live Circle Inc, Ridgewood, NJ USA | title1: Examining spoken words and acoustic features of therapy sessions to understand family caregivers' anxiety and quality of life | site1: WOS
# name2: Naylor M.D. | inst2: School of Nursing University of Pennsylvania Philadelphia PA United States | title2: Examining spoken words and acoustic features of therapy sessions to understand family caregivers’ anxiety and quality of life | site1: SCOPUS
# inst: 0.5378466701996114 | title: 0.9968 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['behavioral and psychological symptoms of dementia (BPSD)', ' nursing homes'], ['Psychology', ' Geriatrics & Gerontology', ' Psychiatry'] | journal1: Cambridge University Press | journal2: INT PSYCHOGERIATR
# name1: Luijendijk, Hendrika J.Dika | inst1: Department of General Practice and Elderly Care Medicine University of Groningen University Medical Centre Groningen Groningen Netherlands | title1: Sounds in nursing homes and their effect on health in dementia: A systematic review | site1: SCOPUS
# name2: Luijendijk, Hendrika J. | inst2: Univ Groningen, Dept Youth Studies, Groningen, Netherlands | title2: Sounds in nursing homes and their effect on health in dementia: a systematic review | site1: WOS
# inst: 0.5609464771160518 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Neurosciences & Neurology', ' Radiology, Nuclear Medicine & Medical Imaging'], ['auditory-frontal network', ' DCM', ' decision-making', ' fMRI', ' voice'] | journal1: HUM BRAIN MAPP | journal2: John Wiley and Sons Inc
# name1: Fruehholz, Sascha | inst1: Univ Zurich, Dept Psychol, CH-8050 Zurich, Switzerland | title1: Categorizing human vocal signals depends on an integrated auditory-frontal cortical network | site1: WOS
# name2: Frühholz, Sascha | inst2: Department of Psychology University of Zurich Zurich Switzerland Neuroscience Center Zurich University of Zurich and ETH Zurich Zurich Switzerland Center for Integrative Human Physiology (ZIHP) University of Zurich Zurich Switzerland | title2: Categorizing human vocal signals depends on an integrated auditory-frontal cortical network | site1: SCOPUS
# inst: 0.5236719583301657 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['acute respiratory infection', ' asthma', ' cough', ' pediatrics', ' sound recording'], [''] | journal1: Elsevier Inc. | journal2: Academy of Managed Care Pharmacy (AMCP)
# name1: McCallum, Gabrielle B. | inst1: Child Health Division Menzies School of Health Research Charles Darwin University Darwin NT Australia | title1: Can Acute Cough Characteristics From Sound Recordings Differentiate Common Respiratory Illnesses in Children?: A Comparative Prospective Study | site1: SCOPUS
# name2: McClellan, Mark B. | inst2: Duke-Margolis Center for Health Policy Durham NC United States | title2: Improving patient-reported measures in oncology: A payer call to action | site1: SCOPUS
# inst: 0.642253665415233 | title: 0.6415564091620429 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['acute respiratory infection', ' asthma', ' cough', ' pediatrics', ' sound recording'], [''] | journal1: Elsevier Inc. | journal2: Academy of Managed Care Pharmacy (AMCP)
# name1: McCallum, Gabrielle B. | inst1: Child Health Division Menzies School of Health Research Charles Darwin University Darwin NT Australia | title1: Can Acute Cough Characteristics From Sound Recordings Differentiate Common Respiratory Illnesses in Children?: A Comparative Prospective Study | site1: SCOPUS
# name2: McClellan, Mark B. | inst2: Duke-Margolis Center for Health Policy Durham NC United States | title2: Improving patient-reported measures in oncology: A payer call to action | site1: SCOPUS
# inst: 0.642253665415233 | title: 0.6415564091620429 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Hidden Markov model', ' Human-robot interaction', ' Robotic face', ' Social robotic', ' Voice command'], ['Robotics'] | journal1: Cambridge University Press | journal2: ROBOTICA
# name1: Tabibian, Shima | inst1: Department of Mechanical and Mechatronics Engineering Cyberspace Research Institute Shahid Beheshti University Tehran Iran | title1: Design and Implementation of the Voice Command Recognition and the Sound Source Localization System for Human-Robot Interaction | site1: SCOPUS
# name2: Tabibian, Sh. | inst2: Shahid Beheshti Univ, Cyberspace Res Inst, Dept Mech & Mechatron Engn, Tehran, Iran | title2: Design and Implementation of the Voice Command Recognition and the Sound Source Localization System for Human-Robot Interaction | site1: WOS
# inst: 0.6661422244107803 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['CMU ARCTIC databases', ' DSP digital filter', ' DSP-based'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Guo, Cheng-Yan | inst1: Natl Taiwan Univ, Coll Med, Taipei 10617, Taiwan | title1: A Novel Dentary Bone Conduction Device Equipped with Laser Communication in DSP | site1: WOS
# name2: Guo C.-Y. | inst2: College of Medicine National Taiwan University Taipei 10617 Taiwan | title2: A novel dentary bone conduction device equipped with laser communication in DSP | site1: SCOPUS
# inst: 0.7249579124579123 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Computer Science'], ['data', ' interaction design', ' narrative', ' radio', ' Retrospection', ' sonification', ' sound', ' voice user interfaces'] | journal1: ACM T COMPUT-HUM INT | journal2: Association for Computing Machinery
# name1: Keegan, Brian | inst1: Univ Colorado, ATLAS Inst, 320 UCB,1125 18th St, Boulder, CO 80309 USA | title1: Examining Narrative Sonification: Using First-Person Retrospection Methods to Translate Radio Production to Interaction Design | site1: WOS
# name2: Keegan B. | inst2: Department of Information Science University of Colorado Boulder Boulder CO United States | title2: Examining Narrative Sonification: Using First-Person Retrospection Methods to Translate Radio Production to Interaction Design | site1: SCOPUS
# inst: 0.5398430533261994 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 3 | keyword: ['Computer Science', ' Health Care Sciences & Services', ' Medical Informatics'], ['Caregiver', ' Chatbot', ' Communication', ' Machine learning', ' Quality of life'] | journal1: INT J MED INFORM | journal2: Elsevier Ireland Ltd
# name1: Naylor, Mary D. | inst1: Live Circle Inc, Ridgewood, NJ USA | title1: Examining spoken words and acoustic features of therapy sessions to understand family caregivers' anxiety and quality of life | site1: WOS
# name2: Naylor M.D. | inst2: School of Nursing University of Pennsylvania Philadelphia PA United States | title2: Examining spoken words and acoustic features of therapy sessions to understand family caregivers’ anxiety and quality of life | site1: SCOPUS
# inst: 0.5378466701996114 | title: 0.9968 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Education & Educational Research', ' Rehabilitation'], ['Beatalk', ' human beatboxing', ' intellectual disability', ' speech impairments', ' speech intelligibility'] | journal1: INT J DEV DISABIL | journal2: Taylor and Francis Ltd.
# name1: Carl, Micalle | inst1: Ariel Univ, Dept Commun Disorders, IL-40700 Ariel, Israel | title1: Points of view: positive effects of the Beatalk technique on speech characteristics of young adults with intellectual disability | site1: WOS
# name2: Carl M. | inst2: Department of Communication Disorders Ariel University Ariel Israel | title2: Points of view: positive effects of the Beatalk technique on speech characteristics of young adults with intellectual disability | site1: SCOPUS
# inst: 0.6529819573810148 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['frühholzsascha', 'luijendijkhendrikaj', 'guocy', 'tabibiansh', 'keeganb', 'carlm', 'naylormd', 'luijendijkhendrikaj', 'frühholzsascha', 'tabibiansh', 'guocy', 'keeganb', 'naylormd', 'carlm']
# 20
# 22

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name):
    global answer, numCor, numErr, answerCounter, numInteErr # answer = json, numCor = 정답 수, numErr = 오답 수, answerCounter = 정답수, numInteErr = 통합에러
    flag = True

    numK = len(result.keys()) #Answer_dict key 개수
    if numK-5 != len(answer[name].keys()):
        flag = False
    else :
        for site in result.keys():
            if site != 'name' and site != 'fid' and site != 'keyId' and site != 'inst' and site != 'pre_name':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 5:
                        if answer[name][site] != result[site]['inst']:
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag:
        numCor += 1
        answerCounter[name] += 1
    else:
        if len(answer[name].keys()) > 1:
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {name} {answer[name]}\n - Result : {result}")
        else:
            pass
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json:

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:        
        name = Answer_dict[answer_one]['name'].split('_')[0]

        if name in answer :
            ansCheck(Answer_dict[answer_one], name)

        else :
            count = 0
            while name+'_'+str(count) in answer :
                if ansCheck(Answer_dict[answer_one], name+'_'+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

    print("토탈앤써", answercount)
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    print(keyid)
    
print(sorted(Answer_dict.items()))
# Out:
# 74
# num코렉트 74
# numEror 0
# numInteEror 0
# 토탈앤써 74
# 토탈인터그레이션 13
# --------------------------------
# 토탈에러 0
# 토탈인터그레이션에러 0
# 993
# [('asakuratakumi_0', {'fid': 0, 'keyId': 993, 'name': 'Asakura, Takumi', 'pre_name': 'asakuratakumi', 'inst': 'Tokyo Univ Sci, Fac Sci & Technol, Dept Mech Engn, Tokyo 1628601, Japan', 'WOS': {'inst': 'Tokyo Univ Sci, Fac Sci & Technol, Dept Mech Engn, Tokyo 1628601, Japan', 'A_id': ['ss9693006'], 'papers': [ObjectId('62c2cc1f083aec74b0256749')], 'oriInst': 'Tokyo Univ Sci, Fac Sci & Technol, Dept Mech Engn, Tokyo 1628601, Japan'}, 'SCOPUS': {'inst': 'Department of Mechanical Engineering Faculty of Science and Technology Tokyo University of Science Tokyo 162-8601 Japan', 'A_id': ['54885016200'], 'papers': [ObjectId('62c2cc0f3c10ddfdb3256929')], 'oriInst': 'Department of Mechanical Engineering Faculty of Science and Technology Tokyo University of Science Tokyo 162-8601 Japan'}}), ('baiq', {'fid': 0, 'keyId': 993, 'name': 'Bai Q.', 'pre_name': 'baiq', 'inst': 'School Of Physical Education And Music Qilu University Of Technology (Shandong Academy Of Sciences) Shandong Jinan China', 'SCOPUS': {'inst': 'School Of Physical Education And Music Qilu University Of Technology (Shandong Academy Of Sciences) Shandong Jinan China', 'A_id': ['57659294700'], 'papers': [ObjectId('62c2cc103c10ddfdb325694d')], 'oriInst': 'School Of Physical Education And Music Qilu University Of Technology (Shandong Academy Of Sciences) Shandong Jinan China'}}), ('blakejohn', {'fid': 0, 'keyId': 993, 'name': 'Blake, John', 'pre_name': 'blakejohn', 'inst': 'Univ Aizu, Ctr Language Res, Sch Comp Sci & Engn, Aizu Wakamatsu, Fukushima 9658580, Japan', 'WOS': {'inst': 'Univ Aizu, Ctr Language Res, Sch Comp Sci & Engn, Aizu Wakamatsu, Fukushima 9658580, Japan', 'A_id': ['ss9692995'], 'papers': [ObjectId('62c2cc1f083aec74b0256757')], 'oriInst': 'Univ Aizu, Ctr Language Res, Sch Comp Sci & Engn, Aizu Wakamatsu, Fukushima 9658580, Japan'}}), ('boschl', {'fid': 0, 'keyId': 993, 'name': 'Bosch L.', 'pre_name': 'boschl', 'inst': 'Department of Cognition Development and Educational Psychology University of Barcelona Barcelona Spain Institut de Recerca Sant Joan de Déu Barcelona Spain Institute of Neurosciences (UBNeuro) University of Barcelona Barcelona Spain', 'SCOPUS': {'inst': 'Department of Cognition Development and Educational Psychology University of Barcelona Barcelona Spain Institut de Recerca Sant Joan de Déu Barcelona Spain Institute of Neurosciences (UBNeuro) University of Barcelona Barcelona Spain', 'A_id': ['7004972632'], 'papers': [ObjectId('62c2cc0f3c10ddfdb3256942')], 'oriInst': 'Department of Cognition Development and Educational Psychology University of Barcelona Barcelona Spain Institut de Recerca Sant Joan de Déu Barcelona Spain Institute of Neurosciences (UBNeuro) University of Barcelona Barcelona Spain'}}), ('brockmannbauserm', {'fid': 0, 'keyId': 993, 'name': 'Brockmann-Bauser, M.', 'pre_name': 'brockmannbauserm', 'inst': 'Department of Phoniatrics and Speech Pathology Clinic for Otorhinolaryngology Head and Neck Surgery University Hospital Zurich Zurich Switzerland University of Zurich Zurich Switzerland', 'SCOPUS': {'inst': 'Department of Phoniatrics and Speech Pathology Clinic for Otorhinolaryngology Head and Neck Surgery University Hospital Zurich Zurich Switzerland University of Zurich Zurich Switzerland', 'A_id': ['37094910800'], 'papers': [ObjectId('62c2cc0f3c10ddfdb3256927')], 'oriInst': 'Department of Phoniatrics and Speech Pathology Clinic for Otorhinolaryngology Head and Neck Surgery University Hospital Zurich Zurich Switzerland University of Zurich Zurich Switzerland'}}), ('carlmicalle', {'fid': 0, 'keyId': 993, 'name': 'Carl, Micalle', 'pre_name': 'carlmicalle', 'inst': 'Ariel Univ, Dept Commun Disorders, IL-40700 Ariel, Israel', 'WOS': {'inst': 'Ariel Univ, Dept Commun Disorders, IL-40700 Ariel, Israel', 'A_id': ['ss9693007'], 'papers': [ObjectId('62c2cc1f083aec74b025674b')], 'oriInst': 'Ariel Univ, Dept Commun Disorders, IL-40700 Ariel, Israel'}, 'SCOPUS': {'inst': 'Department of Communication Disorders Ariel University Ariel Israel', ' ...
