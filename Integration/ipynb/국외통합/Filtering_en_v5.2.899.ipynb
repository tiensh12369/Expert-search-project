# %% [markdown]
# '''
# v0: 국내 통합코드 적용
# v1: title 전처리
# v2: name 전처리
# v3: 통합 안되는 친구들 필터 테스트, name 다국어 변환
# v4: name 유사도 비교
# v5: email 비교
# v5.1: email에 @기준으로 뒤를 비교
# v5.2: funding 비교
# '''

# %%
from pymongo import MongoClient
import itertools
import numpy as np
import jaro
import time
#import multicpu

client = MongoClient('mongodb://203.255.92.141:27017', authSource='admin')
filter_info = client['PUBLIC']['FilterInfo'] #필터접근
filters_category = client['PUBLIC']['FilterCategory']

f_id = 0 #input
keyid = 899 #keyid

fid_key_query = filter_info.find_one({ '$and': [{ 'fId': f_id }, { 'keyId': keyid }]}) #f_id serach

pinst = []
pyear = []
pjournal = []
plang = []

if  fid_key_query != None: #f_id check
    for key in fid_key_query.keys() :
        if key == 'pFilter':
            pinst = fid_key_query[key]['inst']
            pyear = fid_key_query[key]['year']
            pjournal = fid_key_query[key]['journal']
            plang = fid_key_query[key]['lang']

wos_raw = client['WOS']['Rawdata']
scopus_raw = client['SCOPUS']['Rawdata']

wos_key_query = wos_raw.find({ 'keyId' : keyid })
scopus_key_query = scopus_raw.find({ 'keyId' : keyid })

key_querys = [wos_key_query, scopus_key_query] #Rawdata
id_domestic = client['ID']['Domestic'] #Domestic

mng_id = [] # Author id
paper = []

Answer_dict = {} # Answer result
fp_dict = {} #filter papaer result
site = ['WOS', 'SCOPUS']

savetime1 = 0
savetime2 = 0
end1 = 0

f_pyear = {}
f_pinst = {}
f_pjournal = {}
f_plang = {}

Inte_name = []

def different_lang(name):
    # Conversion_list = ['í', 'é', 'ô', 'ń', 'ł', 'á', 'ú', 'ä']
    Conversion_list = ['i', 'e', 'o', 'n', 'l', 'a', 'u', 'a']
    Conversion_index = [237, 233, 244, 324, 322, 225, 250, 228]
    list_name = list(name)
    
    for i in range(len(list_name)):        
        if ord(list_name[i]) in Conversion_index:
            list_name[i] = Conversion_list[Conversion_index.index(ord(list_name[i]))]
            
    name = "".join(list_name)
    return name

def simple_filter(value, filters):
    if value in filters or filters == []:
        return True
    return False
        
def fc_simple_filter(category, fc_dict):
    if category not in fc_dict:
        fc_dict[category] = 0
    fc_dict[category] += 1
    return fc_dict

for i in range(len(key_querys)):
    mng_dict = {}
    start1 = time.time()
    for key_query in key_querys[i]: #rawdata(magid, paper) insert

        if key_query['author_inst'] not in "":
            paper_year =  str(key_query['issue_year'])
            paper_journal = key_query['journal']
            # ori_inst = key_query['originalName'].split(';')[-2]
            ori_inst = key_query['author_inst'].split(';')[-2]
            paper_lang = key_query['issue_lang']
            exi_inst = key_query['author_inst'].split(';')[-2]
            mng_name = key_query['author'].split(';')[-2]
            mng_id = key_query['author_id'].split(';')[-1]
            paper = key_query['_id']
            
        if simple_filter(paper_year, pyear) and simple_filter(paper_journal, pjournal) and simple_filter(ori_inst, pinst) and simple_filter(paper_lang, plang):
            if mng_id not in mng_dict:
                mng_dict[mng_id] = {'name' : mng_name, 'inst' : exi_inst, 'papers' : [], 'oriInst' : ori_inst}
            mng_dict[mng_id]['papers'].append(paper)
            fp_dict[paper] = {'year' : paper_year, 'inst' : ori_inst, 'journal' : paper_journal, 'lang' : paper_lang}
            
    end2 = time.time()
    db_time = end2-start1
    # print(f'DB 수집: {site[i]}, {db_time}')
    savetime1 += db_time
    len_mng_dict = len(mng_dict)
    # print(f'전체 저자 수: {len_mng_dict}')
    
    for mng_one in mng_dict :
        oriinst = mng_dict[mng_one]['oriInst']
        exiinst = mng_dict[mng_one]['inst']
        mng_name = mng_dict[mng_one]['name']
        paper = mng_dict[mng_one]['papers']
        pre_name = different_lang(mng_name.lower().replace(" ", "").replace(",", "").replace(".", "").replace("-", "").replace("´", ""))
        Answer = {'fid': f_id, 'keyId': keyid, 'name' : mng_name, 'pre_name' : pre_name, 'inst': oriinst, site[i] : {'inst' :exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst} }

        if pre_name == 'herrerafrancisco' and site == 'SCOPUS':
            print(Answer)
        
        if pre_name not in Answer_dict and pre_name+'_0' not in Answer_dict : #동명이인이 없을 때
            Answer_dict[pre_name] = Answer

        else:
            count = 0
            flag = True
            while flag :
                temp = None
                tempName = pre_name
                
                if tempName in Answer_dict : # 이름 으로만 key가ㅣ 존재         
                    temp = Answer_dict[tempName]
                    flag = False
                else :
                    tempName = pre_name+'_'+str(count) # 이름 + 숫자로 key가ㅣ 존재
                    if tempName not in Answer_dict :
                        flag = False 
                        break
                    temp = Answer_dict[tempName]
                        
                for key in temp.keys() : # 사이트 돌면서
                    if key != 'name' and key != 'keyId' and key != 'fid' and key != 'inst' and key != 'pre_name': 
                        src = ""
                        tgt = ""

                        if len(exiinst) >= len(temp[key]['inst']):
                            src = temp[key]['inst']
                            tgt = exiinst

                        elif len(exiinst) < len(temp[key]['inst']):
                            src = exiinst
                            tgt = temp[key]['inst']

                        if key == site[i] :# 사이트가 동일할때
                            if temp[key]['inst'] == exiinst or (src != "" and src in tgt) :  # 소속 같을때
                                Inte_name.append(tempName)
                                Answer_dict[tempName][site[i]]['A_id'].extend([mng_one])
                                Answer_dict[tempName][site[i]]['papers'].extend(paper)
                                flag = False
                                break

                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break
                            
                        else :# 사이트가 다를때 
                            if temp[key]['inst'] == exiinst  or (src != "" and src in tgt):  # 소속 같을때
                                Answer_dict[tempName][site[i]] =  {'inst' : exiinst, 'A_id': [mng_one], 'papers' : paper, 'oriInst' : oriinst}
                                Inte_name.append(tempName)
                                if  Answer_dict[tempName]['inst'] == "" or Answer_dict[tempName]['inst'] == " ":
                                    Answer_dict[tempName]['inst'] = Answer_dict[tempName][site[i]]['oriInst']
                                flag = False
                                break
                            
                            elif pre_name+'_'+str(count+1) not in Answer_dict : #소속이 다를 때
                                Answer_dict[pre_name+'_'+str(count+1)] = Answer
                                if tempName == pre_name:
                                    Answer_dict[pre_name+'_0'] = temp
                                    del Answer_dict[pre_name]
                                flag = False
                                break

                count += 1
                
end3 = time.time()
savetime2 = end3-end2+savetime1

# print(f'2차 통합: {savetime2}')
# print(Inte_name)
# print(len(Answer_dict))

# %%
def filter(rawdata, site):
    coauthor = rawdata['author'].split(";")[:-1]
    year = int(rawdata['issue_year'])
    paper_keyword = rawdata['paper_keyword']
    
    if paper_keyword == [] or paper_keyword is None:
        keyword = []
    else:
        keyword = paper_keyword.split(";")

    journal = rawdata['journal']
    conference = rawdata['issue_inst']
    title = rawdata['title']
    
    funding_text = []
    email = []
    if site == "WOS":
        email.extend(rawdata['emails'].replace(" ", "").split(";"))
        funding_text.append(rawdata['funding text'])
        
    elif site == "SCOPUS":
        emails = rawdata['correspondence_address'].split(" ")
        for i in emails:
            if "@" in i:
                email.append(i)

        for funding in  rawdata.keys():
            if "funding_text_" in funding:
                funding_text.append(rawdata[funding])  

    return coauthor, year, keyword, journal, conference, title, email, funding_text

def Secondary_filter2(name1, name2, site1, inst1, raw_one1, site2, inst2, raw_one2):
    inst_sim = 0
    weight = 0
    joc = 0
    email_exact = 0
    funding_exact = 0
    coauthor1, year1, keyword1, journal1, conference1, title1, emails1, funding_text1 = filter(raw_one1, site1)
    coauthor2, year2, keyword2, journal2, conference2, title2, emails2, funding_text2 = filter(raw_one2, site2)
        
    for email1 in emails1:
        for email2 in emails2:
            if email1 == email2:
                email_exact = 1

            if "@" in email1 and "@" in email2:
                email_back1 = email1.split("@")[1]
                email_back2 = email2.split("@")[1]
                if ".com" not in email_back1 and ".com" not in email_back2:
                    if email_back1 == email_back2:
                        # print(f'email1: {email1}, email2: {email2}')
                        # print(f'email1_b:  {email_back1}, email2_b: {email_back2}')
                        email_exact = 1

    for funding1 in funding_text1:
        for funding2 in funding_text2:
            if funding1 == funding2 and funding1 != "":
                funding_exact = 1
                # print('-----------------펀딩 통합-----------------')
                
    
    if inst1 == inst2:
        inst_sim = 1
    else:
        inst_sim = jaro.jaro_winkler_metric(inst1, inst2)

    if name1 in coauthor1:
        coauthor1.remove(name1)

    if name2 in coauthor2:
        coauthor2.remove(name2)
    
    co_author_count = len([i for i in coauthor1 if i in coauthor2])
    
    paper_sim = jaro.jaro_winkler_metric(title1.lower(), title2.lower())
    # if paper_sim >= 0.8:
    #     print('-----------------논문 통합-----------------')
    # if  inst_sim >= 0.8:
    #     print('-----------------소속 통합-----------------')
    
        
    if paper_sim >= 0.8 or inst_sim >= 0.83 or email_exact == 1 or funding_exact == 1:
        weight = 4
        print(f'{name1} | {title1}')
        print(f'{name2} | {title2}')
        return weight

    else:
        joc = 1 if journal1 == journal2 and conference1 == conference2 else 0

    yop = -(2*(abs(year1-year2)/20)-1)
            
    if len(coauthor1) == 0 or len(coauthor2) == 0:
        co_author_ratio = 0
    elif len(coauthor1) < len(coauthor2):
        co_author_ratio = co_author_count/len(coauthor1)
    else:
        co_author_ratio = co_author_count/len(coauthor2)
    
    if co_author_ratio == 1:
        co_authorship = 1
    else:
        co_authorship = (1 - np.exp(-co_author_count))/2 + (co_author_ratio/2)
        
    keyword = 1 - np.exp(-len([i for i in keyword1 if i in keyword2]))

    weight = joc + yop + co_authorship + keyword
    print(f'{name1} | {title1}')
    print(f'{name2} | {title2}')
    
    return weight

# %%
raw_dbs = {'WOS' : wos_raw, 'SCOPUS' : scopus_raw}
savetime1 = 0
savetime2 = 0
def getRaw(name):
    if 'raws' not in Answer_dict[name]:
        raws = []
        for site_one in site:
            if site_one in Answer_dict[name]:
                for c in raw_dbs[site_one].find({"_id": {"$in": Answer_dict[name][site_one]['papers']}}):
                    c['site'] = site_one
                    raws.append(c)
        Answer_dict[name]['raws'] = raws

processedList = []
deleteList = []
count_rule = 0

for Answer_one in Answer_dict:
    if '_' in Answer_one :
        start1 = time.time()
        name = Answer_one.split("_")
        if name[0] in processedList :
            continue
        preprocessedList = []
        c = 0
        while True :
            pname = name[0]+"_"+str(c)
            if pname in Answer_dict :            
                preprocessedList.append(pname)
                getRaw(pname)
                c += 1
            else :
                break
        end1 = time.time()
        savetime1 += end1 - start1
        processedList.append(name[0])
        flag = True
        while flag :
            flag = False
            pairs =list(itertools.combinations(preprocessedList, 2))
            for pair in pairs:
                pair = list(pair)
                raws1 = Answer_dict[pair[0]]['raws']
                raws2 = Answer_dict[pair[1]]['raws']
                for ra1, ra2 in zip(raws1, raws2):
                    site1 = ra1['site']
                    site2 = ra2['site']
                    inst1 = Answer_dict[pair[0]][site1]['oriInst']
                    inst2 = Answer_dict[pair[1]][site2]['oriInst']
                    count_rule += 1
                    real_name1 = Answer_dict[pair[0]]['name']
                    real_name2 = Answer_dict[pair[1]]['name']
                    # print(f'input: {real_name1}, {real_name2}')
                    if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                        Inte_name.append(pair[0])
                        deleteList.append(pair[1])
                        for site_one in site:
                            if site_one in Answer_dict[pair[1]]:
                                if site_one in Answer_dict[pair[0]].keys() :                            
                                    Answer_dict[pair[0]][site_one]['A_id'].extend(Answer_dict[pair[1]][site_one]['A_id'])
                                    Answer_dict[pair[0]][site_one]['papers'].extend(Answer_dict[pair[1]][site_one]['papers'])
                                    Answer_dict[pair[0]]['raws'].extend(Answer_dict[pair[1]]['raws'])                        
                                    Answer_dict[pair[0]][site_one]['A_id'] = list(set(Answer_dict[pair[0]][site_one]['A_id']))
                                    Answer_dict[pair[0]][site_one]['papers'] = list(set(Answer_dict[pair[0]][site_one]['papers']))
                                else:
                                    Answer_dict[pair[0]][site_one] = Answer_dict[pair[1]][site_one]
                            if Answer_dict[pair[0]]['inst'] == "" or Answer_dict[pair[0]]['inst'] == " ":
                                Answer_dict[pair[0]]['inst'] = Answer_dict[pair[0]][site_one]['oriInst']
                        flag = True
                        preprocessedList.remove(pair[1])
                        break
                if flag :
                    break

print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
# Out:
# joc: 0 | yop: 2020, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Computer Science', ' Engineering', ' Physics'] | journal1: SENSORS-BASEL | journal2: ELECTRONICS-SWITZ
# name1: Skarmeta, Antonio F. | inst1: Odin Solut SL, Poligono Ind Oeste C Peru 5,3,Oficina 12, Alcantarilla 30820, Murcia, Spain | title1: Digital Transformation of Agriculture through the Use of an Interoperable Platform | site1: WOS
# name2: Skarmeta, Antonio F. | inst2: Odin Solut SL, Poligono Ind Oeste C Peru 5,3,Oficina 12, Murcia 30820, Spain | title2: Improving Energy Efficiency of Irrigation Wells by Using an IoT-Based Platform | site1: WOS
# inst: 0.9557309941520468 | title: 0.6780904732124244 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2021 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Chemistry', ' Engineering', ' Instruments & Instrumentation'] | journal1: SENSORS-BASEL | journal2: SENSORS-BASEL
# name1: Skarmeta, Antonio F. | inst1: Odin Solut SL, Poligono Ind Oeste C Peru 5,3,Oficina 12, Alcantarilla 30820, Murcia, Spain | title1: Digital Transformation of Agriculture through the Use of an Interoperable Platform | site1: WOS
# name2: Skarmeta, Antonio F. | inst2: Inst Agr & Food Res & Dev Murcia IMIDA, Mayor St, La Alberca 30150, Spain | title2: Climate-Aware and IoT-Enabled Selection of the Most Suitable Stone Fruit Tree Variety | site1: WOS
# inst: 0.636663438033301 | title: 0.7037449876761211 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Data model', ' FIWARE', ' Interoperability', ' IoT platform', ' Irrigation water', ' NGSI-LD', ' Precision irrigation', ' Smart agriculture'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Skarmeta, Antonio F. | inst1: Odin Solut SL, Poligono Ind Oeste C Peru 5,3,Oficina 12, Alcantarilla 30820, Murcia, Spain | title1: Digital Transformation of Agriculture through the Use of an Interoperable Platform | site1: WOS
# name2: Skarmeta, Antonio F. | inst2: Department of Information and Communications Engineering Computer Science Faculty University of Murcia Murcia 30100 Spain | title2: Digital transformation of agriculture through the use of an interoperable platform | site1: SCOPUS
# inst: 0.6181818181818182 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science'], ['Telecommunications'] | journal1: J NETW COMPUT APPL | journal2: WIRELESS PERS COMMUN
# name1: Jain, Sanjeev | inst1: Indian Inst Informat Technol Design & Mfg, Jabalpur, India | title1: Adaptive Small Cell position algorithm (ASPA) for green farming using NB-IoT | site1: WOS
# name2: Jain, Sanjeev | inst2: Indian Inst Informat Technol Design & Management, Dept Comp Sci & Engn, Jabalpur 482005, India | title2: Automated Plant Leaf Disease Detection and Classification Using Fuzzy Based Function Network | site1: WOS
# inst: 0.8862493725141909 | title: 0.658980723732692 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Agriculture', ' Computer Science'] | journal1: IEEE INTERNET THINGS | journal2: COMPUT ELECTRON AGR
# name1: Carlos Corrales, Juan | inst1: Univ Cauca, DTM, Popayan 190003, Colombia | title1: A Conceptual Data Model and Its Automatic Implementation for IoT-Based Business Intelligence Applications | site1: WOS
# name2: Carlos Corrales, Juan | inst2: Parque Tecnol Innovat Cafe TECNICAFE, Popayan 190002, Colombia | title2: IoT-Agro: A smart farming system to Colombian coffee farms | site1: WOS
# inst: 0.6441534599677794 | title: 0.5915589824135551 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2020 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Internet of things', ' Smart monitoring', ' Solar power'] | journal1: WIREL NETW | journal2: Springer
# name1: Zualkernan, Imran A. | inst1: Amer Univ Sharjah, Sharjah, U Arab Emirates | title1: Using IoT and smart monitoring devices to optimize the efficiency of large-scale distributed solar farms | site1: WOS
# name2: Zualkernan, Imran A. | inst2: American University of Sharjah Sharjah United Arab Emirates | title2: Designing an Edge Layer for Smart Management of Large-Scale and Distributed Solar Farms | site1: SCOPUS
# inst: 0.8516319447782574 | title: 0.7279612150301805 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 2 | keyword: ['Computer Science', ' Telecommunications'], ['Distributed ledger technologies', ' Edge computing', ' Internet of things', ' Livestock monitoring', ' Precision agriculture', ' Smart farming'] | journal1: AD HOC NETW | journal2: Elsevier B.V.
# name1: Rodriguez-Gonzalez, Sara | inst1: Univ Salamanca, BISITE Res Grp, Salamanca, Spain | title1: An intelligent Edge-IoT platform for monitoring livestock and crops in a dairy farming scenario | site1: WOS
# name2: Rodríguez-González, Sara | inst2: BISITE Research Group University of Salamanca Salamanca Spain | title2: An intelligent Edge-IoT platform for monitoring livestock and crops in a dairy farming scenario | site1: SCOPUS
# inst: 0.7116510538641686 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering'], ['DFIG', ' Grid Side Converter', ' Offshore Wind Power', ' Rotor Side Converter', ' Substantial Transformative Optimization Algorithm'] | journal1: MICROPROCESS MICROSY | journal2: Elsevier B.V.
# name1: Selvakumaran, S. | inst1: PSNA Coll Engn & Technol, Dept Elect & Elect Engn, Dindigul, India | title1: Application of Machine Learning and Big Data in Doubly Fed Induction Generator based Stability Analysis of Multi Machine System using Substantial Transformative Optimization Algorithm | site1: WOS
# name2: Selvakumaran S. | inst2: Department of Electrical and Electronics Engineering PSNA College of Engineering and Technology Dindigul India | title2: Application of Machine Learning and Big Data in Doubly Fed Induction Generator based Stability Analysis of Multi Machine System using Substantial Transformative Optimization Algorithm | site1: SCOPUS
# inst: 0.6519089197055298 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 3 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Blockchain', ' incentive mechanism', ' IoT', ' lightweight clients', ' PoA', ' secure service provisioning'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Shafiq, Muhammad | inst1: Yeungnam Univ, Dept Informat & Commun Engn, Gyongsan 38541, South Korea | title1: Secure Service Provisioning Scheme for Lightweight IoT Devices With a Fair Payment System and an Incentive Mechanism Based on Blockchain | site1: WOS
# name2: Shafiq, Muhammad | inst2: Department of Information and Communication Engineering Yeungnam University Gyeongsan 38541 South Korea | title2: Secure Service Provisioning Scheme for Lightweight IoT Devices with a Fair Payment System and an Incentive Mechanism Based on Blockchain | site1: SCOPUS
# inst: 0.6950892246683987 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Convolution operation', ' EMD', ' GRU', ' IoT', ' Smart sensing', ' �sensing data prediction'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Kong, Jian-Lei | inst1: Beijing Technol & Business Univ, Sch Comp & Informat Engn, Beijing 100048, Peoples R China | title1: Hybrid Deep Learning Predictor for Smart Agriculture Sensing Based on Empirical Mode Decomposition and Gated Recurrent Unit Group Model | site1: WOS
# name2: Kong, Jianlei | inst2: School of Computer and Information Engineering Beijing Technology and Business University Beijing 100048 China China Light Industry Key Laboratory of Industrial Internet and Big Data Beijing Technology and Business University Beijing 100048 China Beijing Key Laboratory of Big Data Technology for Food Safety Beijing Technology and Business University Beijing 100048 China | title2: Hybrid deep learning predictor for smart agriculture sensing based on empirical mode decomposition and gated recurrent unit group model | site1: SCOPUS
# inst: 0.5519771541801439 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Agriculture', ' Plant Sciences'], ['Agriculture 4.0', ' AI', ' Big data', ' Farm management information system (FMIS)', ' IoT', ' Robotics', ' Variable-rate technology (VRT)'] | journal1: AGRONOMY-BASEL | journal2: MDPI AG
# name1: Rovira-Mas, Francisco | inst1: Univ Politecn Valencia, ARL, Camino Vera S-N, E-46022 Valencia, Spain | title1: From Smart Farming towards Agriculture 5.0: A Review on Crop Data Management | site1: WOS
# name2: Rovira-Más, Francisco | inst2: Agricultural Robotics Laboratory (ARL) Universitat Politècnica de València Camino de Vera s/n Valencia 46022 Spain | title2: From smart farming towards agriculture 5.0: A review on crop data management | site1: SCOPUS
# inst: 0.6486270022883295 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 3 | keyword: ['Agriculture', ' Food Science & Technology'], [''] | journal1: J DAIRY RES | journal2: Cambridge University Press
# name1: Gilroy, Michael | inst1: Afimilk, Glasgow, Lanark, Scotland | title1: The Internet of Things enhancing animal welfare and farm operational efficiency | site1: WOS
# name2: Gilroy, Michael | inst2: Afimilk Glasgow United Kingdom | title2: The Internet of Things enhancing animal welfare and farm operational efficiency | site1: SCOPUS
# inst: 0.8578966131907309 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Agriculture', ' Computer Science'], ['Adaptive mechanism', ' Internet of Things', ' Reliable network', ' Smart farm system'] | journal1: COMPUT ELECTRON AGR | journal2: Elsevier B.V.
# name1: Lee, Jae Min | inst1: Inst Teknol Telkom Surabaya, Dept Informat Technol, Surabaya, Indonesia | title1: IoT-based adaptive network mechanism for reliable smart farm system | site1: WOS
# name2: Lee, Jae-min | inst2: Department of IT Convergence Engineering Kumoh National Institute of Technology Gumi South Korea | title2: IoT-based adaptive network mechanism for reliable smart farm system | site1: SCOPUS
# inst: 0.6215333141406089 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Computer Science'], ['Blockchain', ' Internet of things', ' Precision agriculture', ' Safe farming', ' Wireless sensor networks', ' ZigBee'] | journal1: CLUSTER COMPUT | journal2: Springer
# name1: Butt, Talal Ashraf | inst1: Higher Coll Technol, CIS, Fujairah Campus, Fujairah, U Arab Emirates | title1: Safe farming as a service of blockchain-based supply chain management for improved transparency | site1: WOS
# name2: Butt, Talal Ashraf | inst2: Computer Information Science (CIS) Higher Colleges of Technology Fujairah Campus Fujairah United Arab Emirates | title2: Safe farming as a service of blockchain-based supply chain management for improved transparency | site1: SCOPUS
# inst: 0.6795398841354724 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Actuator', ' Interactive art', ' IoT', ' Physics experiments', ' Sensor', ' Simulation', ' Smart farm'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Yen, Tai-Hsiang | inst1: Natl Chiao Tung Univ NCTU, Dept Comp Sci, Hsinchu 300, Taiwan | title1: SimTalk: Simulation of IoT Applications | site1: WOS
# name2: Yen, Taihsiang | inst2: Department of Computer Science National Chiao Tung University (NCTU) Hsinchu 300 Taiwan | title2: Simtalk: Simulation of iot applications | site1: SCOPUS
# inst: 0.7173230324728346 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 7 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Food quality', ' Marine data crowdsourcing', ' Mussel farm', ' The Internet of Floating Things'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Montella, Raffaele | inst1: Aalborg Univ, Dept Elect Syst, CMI, DK-9100 Copenhagen, Denmark | title1: Coastal Marine Data Crowdsourcing Using the Internet of Floating Things: Improving the Results of a Water Quality Model | site1: WOS
# name2: Montella, Raffaele | inst2: Department of Science and Technology University of Naples Parthenope Naples 80133 Italy | title2: Coastal Marine Data Crowdsourcing Using the Internet of Floating Things: Improving the Results of a Water Quality Model | site1: SCOPUS
# inst: 0.5705587590110445 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['BLE sensor tag', ' Decision support systems', ' IoT devices', ' Node power consumption', ' On-cloud software platform', ' Precision agriculture', ' Solar energy harvesting'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Giannoccaro, Nicola Ivan | inst1: Univ Panamericana, Fac Ingn, Alvaro Del Portillo 49, Zapopan 45010, Jalisco, Mexico | title1: Development of Sensors-Based Agri-Food Traceability System Remotely Managed by a Software Platform for Optimized Farm Management | site1: WOS
# name2: Giannoccaro, Nicola Ivan | inst2: Department of Innovation Engineering University of Salento Lecce 73100 Italy | title2: Development of sensors-based agri-food traceability system remotely managed by a software platform for optimized farm management | site1: SCOPUS
# inst: 0.6180459712948803 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Environmental Sciences & Ecology', ' Water Resources'], ['Automatic wastewater treatment system', ' Internet of things (IoT)', ' Piggery wastewater', ' Remote monitoring and control', ' Sensor'] | journal1: WATER-SUI | journal2: MDPI AG
# name1: Chung, Hsin-Cheng | inst1: Natl Taiwan Univ, Dept Anim Sci & Technol, Taipei 10673, Taiwan | title1: Establishing a Smart Farm-Scale Piggery Wastewater Treatment System with the Internet of Things (IoT) Applications | site1: WOS
# name2: Chung, Hsincheng | inst2: Department of Animal Science and Technology National Taiwan University Taipei 10673 Taiwan | title2: Establishing a smart farm-scale piggery wastewater treatment system with the internet of things (IoT) applications | site1: SCOPUS
# inst: 0.6763227513227513 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 2 | keyword: ['Agriculture', ' Water Resources'], ['IOT application', ' precise irrigation', ' smart irrigation', ' water-saving irrigation'] | journal1: IRRIG DRAIN | journal2: John Wiley and Sons Ltd
# name1: Gao, Zhanyi | inst1: China Inst Water Resources & Hydropower Res, State Key Lab Simulat & Regulat Water Cycle River, Chegongzhuang West Rd, Beijing 100048, Peoples R China | title1: Research and development of smart irrigation in China | site1: WOS
# name2: Gao, Zhanyi | inst2: State Key Laboratory of Simulation and Regulation of Water Cycle in River Basin China Institute of Water Resources and Hydropower Research Beijing China | title2: Research and development of smart irrigation in China | site1: SCOPUS
# inst: 0.6934765836159026 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science'], ['Artificial neural network (ANN)', ' Decentralized detection', ' Deep learning', ' Error type I', ' Error type II', ' Internet of things (IoT)', ' Source localization', ' Target tracking', ' Wireless sensor networks (WSN)'] | journal1: NEURAL COMPUT APPL | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Mouazen, Abdul M. | inst1: Univ Ghent, Fac Biosci Engn, Dept Environm, B-9000 Ghent, Belgium | title1: Source localization in resource-constrained sensor networks based on deep learning | site1: WOS
# name2: Mouazen, Abdul M. | inst2: Department of Environment Faculty of Bioscience Engineering Ghent University Gent 9000 Belgium | title2: Source localization in resource-constrained sensor networks based on deep learning | site1: SCOPUS
# inst: 0.6643324760346037 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Artificial intelligence', ' cloud computing', ' Internet of Things', ' precision agriculture', ' wireless sensor networks'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Arora, Sakshi | inst1: Shri Mata Vaishno Devi Univ, Sch Comp Sci & Engn, Katra 182320, India | title1: Recent Developments of the Internet of Things in Agriculture: A Survey | site1: WOS
# name2: Arora, Sakshi | inst2: School of Computer Science and Engineering Shri Mata Vaishno Devi University Katra India | title2: Recent Developments of the Internet of Things in Agriculture: A Survey | site1: SCOPUS
# inst: 0.6949496810403222 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 8 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['agricultural applications', ' Blockchain technology', ' data integrity', ' food supply chains management', ' traceability'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Yau, Laihung | inst1: Asia Pacific Appl Nano Technol Res Ctr, Hong Kong, Peoples R China | title1: Blockchain Technology in Current Agricultural Systems: From Techniques to Applications | site1: WOS
# name2: Yau, Laihung | inst2: Asia Pacific Applied Nano Technology Research Centre Hong Kong | title2: Blockchain Technology in Current Agricultural Systems: From Techniques to Applications | site1: SCOPUS
# inst: 0.8711632453567938 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Agriculture', ' Computer Science'], ['Blockchain technology', ' Challenges and solutions', ' Internet of things', ' Precision agriculture'] | journal1: COMPUT ELECTRON AGR | journal2: Elsevier B.V.
# name1: Hassanein, Aboul Ella | inst1: Cairo Univ, Fac Comp & Artificial Intelligence, Giza, Egypt | title1: Integrating blockchain and the internet of things in precision agriculture: Analysis, opportunities, and challenges | site1: WOS
# name2: Hassanein, Aboul Ella | inst2: Faculty of Computers and Artificial Intelligence-Cairo University Egypt Scientific Research Group in Egypt (SRGE) Egypt | title2: Integrating blockchain and the internet of things in precision agriculture: Analysis, opportunities, and challenges | site1: SCOPUS
# inst: 0.6538761141619234 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Big data analytics', ' Computational offloading', ' Content delivery network', ' Fogging', ' Internet of things', ' IoT—Fog—Cloud ecosystems', ' Simulation tools', ' Smart city applications', ' Smart farm applications', ' Web performance'] | journal1: INTERNET THINGS-NETH | journal2: Elsevier B.V.
# name1: Alam, Muhammad Mahbub | inst1: Islamic Univ Technol, Org Islamic Cooperat OIC, Gazipur 1704, Bangladesh | title1: The fog cloud of things: A survey on concepts, architecture, standards, tools, and applications | site1: WOS
# name2: Alam, Muhammad Mahbub | inst2: Islamic University of Technology (IUT) Organization of Islamic Cooperation (OIC) Board Bazar Gazipur Bangladesh | title2: The fog cloud of things: A survey on concepts, architecture, standards, tools, and applications | site1: SCOPUS
# inst: 0.826903441903442 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 3 | keyword: ['Engineering'], ['Agricultural production', ' Crop storage and processing', ' Food distribution', ' Food quality', ' Food security', ' Industry 4.0', ' Refrigeration', ' Smart digital technology'] | journal1: PROCESSES | journal2: MDPI AG
# name1: Sturm, Barbara | inst1: Univ Kassel, Dept Agr & Biosyst Engn, Proc & Syst Engn Agr Grp, DE-37213 Witzenhausen, Germany | title1: Recent Advances in Reducing Food Losses in the Supply Chain of Fresh Agricultural Produce | site1: WOS
# name2: Sturm, Barbara | inst2: Process and Systems Engineering in Agriculture Group Department of Agricultural and Biosystems Engineering University of Kassel Witzenhausen DE-37213 Germany | title2: Recent advances in reducing food losses in the supply chain of fresh agricultural produce | site1: SCOPUS
# inst: 0.662277687874174 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Telecommunications'], [''] | journal1: T EMERG TELECOMMUN T | journal2: John Wiley and Sons Inc
# name1: Ahmed, Muqeem | inst1: Maulana Azad Natl Urdu Univ, Dept CS & IT, Hyderabad, India | title1: Importance of semantic interoperability in smart agriculture systems | site1: WOS
# name2: Ahmed, Muqeem | inst2: Maulana Azad National Urdu University Hyderabad India | title2: Importance of semantic interoperability in smart agriculture systems | site1: SCOPUS
# inst: 0.8690203603027395 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2020 | co_author_count: 0 | keyword: ['Agriculture', ' Computer Science'], ['Data fusion', ' Farm machinery', ' GNSS', ' IoT', ' Management platform', ' Sensing technology'] | journal1: COMPUT ELECTRON AGR | journal2: Agricultural Information Institute, Chinese Academy of Agricultural Sciences
# name1: He, Yong | inst1: Zhejiang Univ, Coll Biosyst Engn & Food Sci, Hangzhou 310058, Peoples R China | title1: A survey on the 5G network and its impact on agriculture: Challenges and opportunities | site1: WOS
# name2: He, Yong | inst2: College of Biosystems Engineering and Food Science Zhejiang University Hangzhou 310058 China | title2: Development and application of an intelligent remote management platform for agricultural machinery [农机远程智能管理平台研发及其应用 | site1: SCOPUS
# inst: 0.6808823221866701 | title: 0.6644389261464764 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['agriculture 4.0', ' IoT platform', ' irrigated crops', ' microservice', ' smart agriculture'] | journal1: SENSORS-BASEL | journal2: NLM (Medline)
# name1: Hornbuckle, John | inst1: Deakin Univ, Ctr Reg & Rural Future, Hanwood 2680, Australia | title1: IRRISENS: An IoT Platform Based on Microservices Applied in Commercial-Scale Crops Working in a Multi-Cloud Environment | site1: WOS
# name2: Hornbuckle, John | inst2: Centre of Regional and Rural Future Deakin University Hanwood 2680 Australia | title2: IRRISENS: An IoT Platform Based on Microservices Applied in Commercial-Scale Crops Working in a Multi-Cloud Environment | site1: SCOPUS
# inst: 0.7352965747702589 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Computer Science'], ['Architecture', ' Information flow diagram', ' IoT', ' Smart agriculture', ' Smart farming kit'] | journal1: TEM J | journal2: UIKTEN - Association for Information Communication Technology Education and Science
# name1: Netinant, Paniti | inst1: Rangsit Univ, Coll Digital Innovat & Informat Technol, Pathum Thani, Thailand | title1: IoT Architecture based on Information Flow Diagram for Vermiculture Smart Farming Kit | site1: WOS
# name2: Netinant, Paniti | inst2: College of Digital Innovation and Information Technology Rangsit University Pathumthani Thailand | title2: IoT Architecture based on Information Flow Diagram for Vermiculture Smart Farming Kit | site1: SCOPUS
# inst: 0.7266904291360813 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Computer Science'], ['Cellular IOT', ' cloud', ' coverage', ' latency', ' MQTT', ' net-work availability', ' system capacity', ' throughput'] | journal1: INT J ONLINE BIOMED | journal2: Kassel University Press GmbH
# name1: Vishnubhatla, Arvind | inst1: Gokaraju Rangaraju Inst Engn & Technol, Hyderabad, India | title1: Cellular IOT using nRF9160kit | site1: WOS
# name2: Vishnubhatla, Arvind | inst2: Gokaraju Rangaraju institute of engineering and Technology Hyderabad India | title2: Cellular IOT using nRF9160kit | site1: SCOPUS
# inst: 0.8611571655689303 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Science & Technology - Other Topics', ' Environmental Sciences & Ecology'], ['Eco-efficiency', ' Edge computing', ' Environmental performance', ' Internet of things', ' Profitability', ' Smart farming'] | journal1: SUSTAINABILITY-BASEL | journal2: MDPI
# name1: Prieto, Javier | inst1: Univ Salamanca, BISITE Res Grp, Edificio Multiusos I D i,Calle Espejo 2, Salamanca 37007, Spain | title1: Increasing Profitability and Monitoring Environmental Performance: A Case Study in the Agri-Food Industry through an Edge-IoT Platform | site1: WOS
# name2: Prieto, Javier | inst2: BISITE Research Group University of Salamanca Edificio Multiusos I+D+i Calle Espejo 2 Salamanca 37007 Spain AIR Institute IoT Digital Innovation Hub Edificio Parque Científico Módulo 305 Paseo de Belén 11 Campus Miguel Delibes Valladolid 47011 Spain | title2: Increasing profitability and monitoring environmental performance: a case study in the agri-food industry through an edge-iot platform | site1: SCOPUS
# inst: 0.6103454754691279 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Agricultural engineering', ' intelligent irrigation', ' IoT', ' machine learning', ' prediction'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Chowdary, Vinay | inst1: Univ Petr & Energy Studies UPES, Sch Comp Sci, Dept Syst, Dehra Dun 248007, Uttarakhand, India | title1: Machine Learning Applications for Precision Agriculture: A Comprehensive Review | site1: WOS
# name2: Chowdary, Vinay | inst2: Department of Electrical and Electronics Engineering School of Engineering University of Petroleum and Energy Studies (UPES) Dehradun India | title2: Machine Learning Applications for Precision Agriculture: A Comprehensive Review | site1: SCOPUS
# inst: 0.6018069435029484 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 5 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Communications', ' digital agriculture', ' Internet of Things (IoT)', ' LoRa', ' mesh network', ' smart city', ' time-division multiple access (TDMA)', ' wireless sensor network (WSN)'] | journal1: IEEE INTERNET THINGS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Bagchi, Saurabh | inst1: Purdue Univ, Sch Agr & Biol Engn, W Lafayette, IN 47906 USA | title1: Hybrid Low-Power Wide-Area Mesh Network for IoT Applications | site1: WOS
# name2: Bagchi, Saurabh | inst2: School of Electrical and Computer Engineering Purdue University West Lafayette IN  47906 United States | title2: Hybrid Low-Power Wide-Area Mesh Network for IoT Applications | site1: SCOPUS
# inst: 0.6496173871547749 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 2 | keyword: ['Computer Science'], ['Prediction Algorithms', ' Smart Cities', ' Smart Service'] | journal1: J INF PROCESS SYST | journal2: Korea Information Processing Society
# name1: Lee, KyuTae | inst1: Kongju Natl Univ, Div Informat & Commun Engn, Gongju, South Korea | title1: Heuristic and Statistical Prediction Algorithms Survey or Smart Environments | site1: WOS
# name2: Lee, Kyutae | inst2: Current affiliation for author Sehrish is Division of Information and Communication Engineering Kongju National University Gongju Korea | title2: Heuristic and Statistical Prediction Algorithms Survey for Smart Environments | site1: SCOPUS
# inst: 0.5892687559354227 | title: 0.9974025974025974 | email: 0, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 1 | keyword: 0.0 | journal1: AGRIENGINEERING | journal2: MDPI AG
# name1: Bartzanas, Thomas | inst1: Agr Univ Athens, Dept Nat Resources & Agr Engn, Farm Struct Lab, Athens 11855, Greece | title1: Application of Internet of Things (IoT) for Optimized Greenhouse Environments | site1: WOS
# name2: Bartzanas, Thomas | inst2: Department of Natural Resources and Agricultural Engineering Agricultural University of Athens Athens 11855 Greece | title2: Sensors for structural health monitoring of agricultural structures | site1: SCOPUS
# inst: 0.6688051828918701 | title: 0.6216912123549152 | email: 0, funding: 0
# weigth: 2.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Science & Technology - Other Topics', ' Environmental Sciences & Ecology'], ['Agriculture', ' Internet of Things (IoT)', ' Smart farming', ' Sustainable future', ' Sustainable smart farming', ' Unmanned Aerial Vehicles (UAVs)'] | journal1: SUSTAINABILITY-BASEL | journal2: MDPI AG
# name1: Kadel, Rajan | inst1: Melbourne Inst Technol, Sch IT & Engn SITE, Melbourne 4000, Australia | title1: A Review of Applications and Communication Technologies for Internet of Things (IoT) and Unmanned Aerial Vehicle (UAV) Based Sustainable Smart Farming | site1: WOS
# name2: Kadel, Rajan | inst2: School of IT and Engineering (SITE) Melbourne Institute of Technology Melbourne 4000 Australia | title2: A review of applications and communication technologies for internet of things (Iot) and unmanned aerial vehicle (uav) based sustainable smart farming | site1: SCOPUS
# inst: 0.7188650900954324 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Instruments & Instrumentation', ' Materials Science'], ['Arduino', ' Control panel', ' Internet of Things', ' Remote monitoring', ' Soil moisture sensor'] | journal1: SENSOR MATER | journal2: M Y U Scientific Publishing Division
# name1: Lopez, Dylan Josh Domingo | inst1: Adamson Univ, Comp Engn Dept, 900 San Marcelino Ermita, Manila, Philippines | title1: Application of Internet of Things in Smart Farm Watering System | site1: WOS
# name2: Lopez, Dylan Josh Domingo | inst2: Computer Engineering Department Adamson University 900 San Marcelino Ermita Manila Philippines | title2: Application of internet of things in smart farm watering system | site1: SCOPUS
# inst: 0.7410375253887391 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Computing in agriculture', ' Context awareness in agriculture', ' Context histories in agriculture', ' Indoor agriculture', ' Prediction in agriculture'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Leithardt, Valderi Reis Quietinho | inst1: Inst Politecn Portalegre, Res Ctr Endogenous Resources Valorizat, VALORIZA, P-7300555 Portalegre, Portugal | title1: IndoorPlant: A Model for Intelligent Services in Indoor Agriculture Based on Context Histories | site1: WOS
# name2: Leithardt, Valderi Reis Quietinho | inst2: VALORIZA Research Center for Endogenous Resources Valorization Instituto Politécnico Portalegre Portalegre 7300-555 Portugal | title2: Indoorplant: A model for intelligent services in indoor agriculture based on context histories | site1: SCOPUS
# inst: 0.7479147189053633 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Engineering', ' Telecommunications'], ['ant colony optimization', ' connectivity', ' coverage', ' device deployment', ' Internet of Things', ' particle swarm optimization', ' relay device'] | journal1: INT J COMMUN SYST | journal2: John Wiley and Sons Ltd
# name1: Al-Turjman, Fadi | inst1: Near East Univ, Res Ctr AI&IoT, Artificial Intelligence Dept, Nicosia, Turkey | title1: Swarm intelligence-based optimal device deployment in heterogeneous Internet of Things networks for wind farm application | site1: WOS
# name2: Al-Turjman, Fadi | inst2: Artificial Intelligence Department Research Centre AI and IoT Near East University Nicosia Turkey | title2: Swarm intelligence-based optimal device deployment in heterogeneous Internet of Things networks for wind farm application | site1: SCOPUS
# inst: 0.6944131931052996 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Information Science & Library Science'], ['Agriculture 4.0', ' Artificial intelligence', ' Data sharing', ' Design science', ' Role-based access control'] | journal1: INT J INFORM MANAGE | journal2: Elsevier Ltd
# name1: Despoudi, Stella | inst1: Univ Western Macedonia, Sch Econ Sci, Grevena, Greece | title1: AI applications of data sharing in agriculture 4.0: A framework for role-based data access control | site1: WOS
# name2: Despoudi, Stella | inst2: School of Economic Sciences University of Western Macedonia Grevena Greece Aston Business School Aston University Birmingham United Kingdom | title2: AI applications of data sharing in agriculture 4.0: A framework for role-based data access control | site1: SCOPUS
# inst: 0.6210361522103073 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Agriculture'], ['Agricultural mechanization', ' Artificial intelligence', ' Digital agriculture', ' Mobile app', ' Precision agriculture'] | journal1: AMA-AGR MECH ASIA AF | journal2: Farm Machinery Industrial Research Corp.
# name1: Rajwade, Y. A. | inst1: ICAR Cent Inst Agr Engn, Bhopal 462038, Madhya Pradesh, India | title1: Smart Farm Mechanization for Sustainable Indian Agriculture | site1: WOS
# name2: Rajwade Y.A. | inst2: ICAR-Central Institute of Agricultural Engineering Bhopal Madhya Pradesh 462038 India | title2: Smart farm mechanization for sustainable indian agriculture | site1: SCOPUS
# inst: 0.8369793502477306 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Best sensor selection', ' Deep reinforcement learning', ' Energy consumption', ' Internet of things', ' Target tracking'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Um, Tai-Won | inst1: Duksung Womens Univ, Coll Sci & Technol, Dept Cyber Secur, Seoul 01369, South Korea | title1: Energy Conservation for Internet of Things Tracking Applications Using Deep Reinforcement Learning | site1: WOS
# name2: Um, Taiwon | inst2: Department of Cyber Security College of Science and Technology Duksung Women’s University Seoul 01369 South Korea | title2: Energy conservation for internet of things tracking applications using deep reinforcement learning | site1: SCOPUS
# inst: 0.6821015625925532 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Energy & Fuels'], ['IoT energies', ' LED energies', ' Lettuce', ' Particulate pollutant', ' Plant factory', ' Smart farm', ' Smart LED farm', ' Smart LED farm algorithm', ' Wavelength'] | journal1: ENERGIES | journal2: MDPI AG
# name1: Ko, Han-Jong | inst1: Korea Natl Open Univ, Dept Agr Sci, Seoul 03087, South Korea | title1: Research on Crop Growing Factory: Focusing on Lighting and Environmental Control with Technological Proposal | site1: WOS
# name2: Ko, Han-jong | inst2: Department of Agricultural Sciences Korea National Open University Seoul 03087 South Korea | title2: Research on crop growing factory: Focusing on lighting and environmental control with technological proposal | site1: SCOPUS
# inst: 0.6973684210526315 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Science & Technology - Other Topics', ' Environmental Sciences & Ecology'], ['Environmental parameters', ' Internet of Things', ' LoRa', ' Smart farming', ' Unmanned Aerial Vehicles'] | journal1: SUSTAINABILITY-BASEL | journal2: MDPI AG
# name1: Sakli, Hedi | inst1: Gabes Univ, Natl Engn Sch Gabes, MACS Res Lab, Gabes 6029, Tunisia | title1: A Low-Cost Platform for Environmental Smart Farming Monitoring System Based on IoT and UAVs | site1: WOS
# name2: Sakli, Hedi | inst2: MACS Research Laboratory National Engineering School of Gabes Gabes University Gabes 6029 Tunisia EITA Consulting 5 Rue du Chant des Oiseaux Montesson 78360 France | title2: A low-cost platform for environmental smart farming monitoring system based on iot and uavs | site1: SCOPUS
# inst: 0.6173400340231926 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Energy & Fuels', ' Nuclear Science & Technology'], ['Energy 4.0', ' IoT', ' smart energy', ' sustainable energy', ' wind farm'] | journal1: INT J ENERG RES | journal2: John Wiley and Sons Ltd
# name1: Adekanbi, Michael Lanre | inst1: Univ Ibadan, Fac Technol, Dept Mech Engn, Ibadan, Oyo State, Nigeria | title1: Optimization and digitization of wind farms using internet of things: A review | site1: WOS
# name2: Adekanbi, Michael Lanre | inst2: Department of Mechanical Engineering Faculty of Technology University of Ibadan Ibadan Nigeria | title2: Optimization and digitization of wind farms using internet of things: A review | site1: SCOPUS
# inst: 0.6576151737290661 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Crop coefficient', ' Decision support system', ' Internet of things', ' Penman–Monteith equation', ' Smart irrigation'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Khurram, Muhammad | inst1: Univ Southampton, Elect & Comp Sci, Southampton SO17 1BJ, Hants, England | title1: An Experimental Comparison of IoT-Based and Traditional Irrigation Scheduling on a Flood-Irrigated Subtropical Lemon Farm | site1: WOS
# name2: Khurram, Muhammad | inst2: Smart City Lab NCAI NED University of Engineering and Technology Karachi 75270 Pakistan | title2: An experimental comparison of iot‐based and traditional irrigation scheduling on a flood‐irrigated subtropical lemon farm | site1: SCOPUS
# inst: 0.5659323116219668 | title: 0.9911845730027549 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Drone', ' Internet of Things', ' IoT', ' Long range', ' LoRa', ' Path planning', ' Remote sensing', ' Smart farming', ' UAV', ' Unmanned aircraft vehicle', ' Wireless sensor network'] | journal1: SENSORS-BASEL | journal2: MDPI AG
# name1: Abdullah, Nor Fadzilah | inst1: Univ Kebangsaan Malaysia, Fac Engn & Built Environm, Dept Elect Elect & Syst Engn, Bangi 43600, Selangor, Malaysia | title1: LoRa Communications as an Enabler for Internet of Drones towards Large-Scale Livestock Monitoring in Rural Farms | site1: WOS
# name2: Abdullah, Nor Fadzilah | inst2: Department of Electrical Electronics and Systems Engineering Faculty of Engineering and Built Environment Universiti Kebangsaan Malaysia Bangi Selangor 43600 Malaysia | title2: Lora communications as an enabler for internet of drones towards large-scale livestock monitoring in rural farms | site1: SCOPUS
# inst: 0.6665342070034525 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 3 | keyword: ['Computer Science', ' Telecommunications'], ['distance evaluation', ' IoT', ' precision agriculture', ' Privacy-preserving data analysis'] | journal1: ACM T SENSOR NETWORK | journal2: Association for Computing Machinery
# name1: Irmak, Suat | inst1: Penn State Univ, Dept Agr & Biol Engn, 105 Agr Engn Bldg,Shortlidge Rd, University Pk, PA 16802 USA | title1: Scalable Privacy-preserving Geo-distance Evaluation for Precision Agriculture IoT Systems | site1: WOS
# name2: Irmak, Suat | inst2: Michigan State University United States | title2: Scalable Privacy-preserving Geo-distance Evaluation for Precision Agriculture IoT Systems | site1: SCOPUS
# inst: 0.5351981351981352 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 1 | keyword: ['Telecommunications'], ['Bacterial foraging optimization', ' Clustering', ' Cross-layer parameters', ' Industry 4.0', ' Internet-of-things', ' Routing optimization', ' Smart farming'] | journal1: WIRELESS PERS COMMUN | journal2: Springer
# name1: Badarla, Anil | inst1: Univ Technol, Comp Sci & Engn Dept, Jaipur, Rajasthan, India | title1: Cross-Layer Protocol for WSN-Assisted IoT Smart Farming Applications Using Nature Inspired Algorithm | site1: WOS
# name2: Badarla, Anil | inst2: Computer Science and Engineering Department University of Technology Jaipur India | title2: Cross-Layer Protocol for WSN-Assisted IoT Smart Farming Applications Using Nature Inspired Algorithm | site1: SCOPUS
# inst: 0.6260153873680444 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Computer Science', ' Engineering', ' Physics'], ['Gateway', ' Intellectual property', ' IoT', ' Precision agriculture', ' SDN', ' Smart control'] | journal1: ELECTRONICS-SWITZ | journal2: MDPI AG
# name1: Cho, Gi Hwan | inst1: Kongju Natl Univ, Dept Convergence Sci, Gongju 32588, South Korea | title1: Intellectual Property Theft Protection in IoT Based Precision Agriculture Using SDN | site1: WOS
# ...
# inst: 0.7230462519936204 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 4 | keyword: ['Agriculture', ' Computer Science'], ['Agriculture', ' Blockchain', ' Greenhouse', ' Internet of things', ' Smart contract'] | journal1: COMPUT ELECTRON AGR | journal2: Elsevier B.V.
# name1: Kim, Do-Hyeun | inst1: Korea Univ, Dept Elect & Informat Engn, Sejong 30019, South Korea | title1: Optimal smart contract for autonomous greenhouse environment based on IoT blockchain network in agriculture | site1: WOS
# name2: Kim, Dohyeun | inst2: Department of Computer Engineering(and Research Center of Advance Technology) Jeju National University Jeju-si Jeju Special Self-Governing Province  63243 South Korea | title2: Optimal smart contract for autonomous greenhouse environment based on IoT blockchain network in agriculture | site1: SCOPUS
# inst: 0.5600265314652274 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['Clustering', ' Fog computing', ' IoT', ' Sensors', ' Smart farming', ' Swarm UAVs'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Hayawi, Kadhim | inst1: Zayed Univ, Coll Technol Innovat, POB 144534, Abu Dhabi, U Arab Emirates | title1: Trajectory Design for UAV-Based Data Collection Using Clustering Model in Smart Farming | site1: WOS
# name2: Hayawi, Kadhim | inst2: College of Technological Innovation Zayed University P.O. Box 144534 Abu Dhabi United Arab Emirates | title2: Trajectory design for uav-based data collection using clustering model in smart farming | site1: SCOPUS
# inst: 0.7251435927906517 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 3 | keyword: ['Computer Science'], [''] | journal1: IEEE MICRO | journal2: IEEE Computer Society
# name1: Ranjan, Rajiv | inst1: Newcastle Univ, Sch Comp, Internet Things Res, Newcastle Upon Tyne NE1 7RU, Tyne & Wear, England | title1: Evaluating Sensor Data Quality in Internet of Things Smart Agriculture Applications | site1: WOS
# name2: Ranjan, Rajiv | inst2: Newcastle University Newcastle upon Tyne NE1 7RU United Kingdom | title2: Evaluating Sensor Data Quality in Internet of Things Smart Agriculture Applications | site1: SCOPUS
# inst: 0.8359948002189381 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Physics'], ['Agricultural big data', ' IoT smart farm', ' Machine learning', ' Peak energy usage'] | journal1: ELECTRONICS-SWITZ | journal2: MDPI
# name1: Cho, Yongyun | inst1: Chungbuk Natl Univ, Res Inst Comp & Informat Commun RICIC, Chungdae Ro 1, Cheongju 28644, South Korea | title1: A Machine Learning Based Model for Energy Usage Peak Prediction in Smart Farms | site1: WOS
# name2: Cho, Yongyun | inst2: Department of Information and Communications Engineering Sunchon National University Jeollanam-do Suncheon-si 57922 South Korea | title2: A Machine Learning Based Model for Energy Usage Peak Prediction in Smart Farms | site1: SCOPUS
# inst: 0.5827381779602131 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Science & Technology - Other Topics'], ['Cloud data center', ' Fog computing', ' Internet of things (IoT)', ' Latency', ' Network congestion'] | journal1: APPL NANOSCI | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Prabhu, C. S. R. | inst1: Keshav Mem Inst Technol, Hyderabad, Telangana, India | title1: A novel application framework for resource optimization, service migration, and load balancing in fog computing environment | site1: WOS
# name2: Prabhu, C. S.R. | inst2: Keshav Memorial Institute of Technology Telangana Hyderabad India | title2: A novel application framework for resource optimization, service migration, and load balancing in fog computing environment | site1: SCOPUS
# inst: 0.861679748822606 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Engineering'], ['IoT', ' RFID', ' WiFi', ' WSN', ' ZigBee-Pro'] | journal1: PRZ ELEKTROTECHNICZN | journal2: Wydawnictwo SIGMA-NOT
# name1: Boonsong, Wasana | inst1: Rajamangala Univ Technol Srivijaya, Fac Ind Educ, Dept Elect Educ, Songkhla, Thailand | title1: Animal Identification and Performance Analysis Based on RFID- IoT Smart Farming Applications | site1: WOS
# name2: Boonsong, Wasana | inst2: Department of Electrical Education Faculty of Industrial Education Rajamangala University of Technology Srivijaya Songkhla Thailand | title2: Animal Identification and Performance Analysis Based on RFIDIoT Smart Farming Applications | site1: SCOPUS
# inst: 0.650107337717059 | title: 0.9756521739130435 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Biotechnology & Applied Microbiology'], ['Artificial intelligence', ' Internet of things', ' Machine learning', ' Microalgae', ' Smart farming'] | journal1: BIOTECHNOL ADV | journal2: Elsevier Inc.
# name1: Show, Pau Loke | inst1: Xiamen Univ Malaysia, Sch Energy & Chem Engn, Sepang 43900, Selangor, Malaysia | title1: Smart microalgae farming with internet-of-things for sustainable agriculture | site1: WOS
# name2: Show, Pau Loke | inst2: Department of Chemical and Environmental Engineering Faculty of Science and Engineering University of Nottingham Malaysia Jalan Broga Selangor Darul Ehsan Semenyih 43500 Malaysia | title2: Smart microalgae farming with internet-of-things for sustainable agriculture | site1: SCOPUS
# inst: 0.58411600883511 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science'], ['Big data', ' Data analysis', ' Digital farming', ' Farming industry', ' Machine learning', ' Predictive farming', ' Smart farming'] | journal1: COMPUT IND | journal2: Elsevier B.V.
# name1: Sajjanhar, Atul | inst1: Chonnam Natl Univ, Dept Math & Stat, Gwangju, South Korea | title1: A survey on smart farming data, applications and techniques | site1: WOS
# name2: Sajjanhar, Atul | inst2: School of Information Technology Deakin University Burwood Victoria 3125 Australia | title2: A survey on smart farming data, applications and techniques | site1: SCOPUS
# inst: 0.601554699757524 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics', ' Environmental Sciences & Ecology'], ['Smart farming technology', ' Sustainability', ' Swine production'] | journal1: SUSTAINABILITY-BASEL | journal2: MDPI
# name1: Yang, Chul-Ju | inst1: Sunchon Natl Univ, Dept Anim Sci & Technol, Anim Nutr & Feed Sci Lab, Sunchon 57922, South Korea | title1: Applications of Smart Technology as a Sustainable Strategy in Modern Swine Farming | site1: WOS
# name2: Yang, Chulju | inst2: Animal Nutrition and Feed Science Laboratory Department of Animal Science and Technology Sunchon National University Suncheon 57922 South Korea Interdisciplinary Program in IT‐Bio Convergence System (BK21 plus) Sunchon National University Suncheon 57922 South Korea | title2: Applications of Smart Technology as a Sustainable Strategy in Modern Swine Farming | site1: SCOPUS
# inst: 0.603485324947589 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science'], ['Oil layer detection', ' PH sensor', ' Random Forest Regression (RFR)', ' Support Vector Regression (SVR)'] | journal1: COMPUT SCI J MOLD | journal2: Institute of Mathematics and Computer Science
# name1: Masum, Abdul Kadar Muhammad | inst1: Int Islamic Univ Chittagong IIUC, Dept Comp Sci & Engn CSE, Sitakunda 4318, Chittagong, Bangladesh | title1: Implementation of Internet of Things (IoT)-based Aquaculture System Using Machine Learning Approaches | site1: WOS
# name2: Masum, Abdul Kadar Muhammad | inst2: Department of Computer Science & Engineering (CSE) International Islamic University Chittagong (IIUC) Kumira Sitakunda Chittagong 4318 Bangladesh | title2: Implementation of Internet of Things (IoT)-based Aquaculture System Using Machine Learning Approaches | site1: SCOPUS
# inst: 0.7095787104276781 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.6321205588285577 | journal1: Emerald Group Holdings Ltd. | journal2: Emerald Group Holdings Ltd.
# name1: Kumar R. | inst1: Asian Institute of Technology Thailand | title1: Overview of iot in the agroecosystem | site1: SCOPUS
# name2: Kumar R. | inst2: Gruwitz LLP India | title2: Modeling the challenges for agri-food supply chain 4.0: Tism approach | site1: SCOPUS
# inst: 0.44060314184153193 | title: 0.6449275362318841 | email: 0, funding: 0
# weigth: 1.6321205588285577
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['blockchain', ' DApp', ' gourmet cocoa', ' Internet of Things', ' middleware', ' remote monitoring', ' smart agriculture', ' smart contracts', ' web systems'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Greve, Fabiola | inst1: Univ Quebec Outaouais, Comp Sci & Engn Dept, Gatineau, PQ J8Y 3G5, Canada | title1: Improving Data Security with Blockchain and Internet of Things in the Gourmet Cocoa Bean Fermentation Process | site1: WOS
# name2: Greve, Fabíola | inst2: Computer Science Institute Federal University of Bahia Bahia Salvador 40170-110 Brazil | title2: Improving Data Security with Blockchain and Internet of Things in the Gourmet Cocoa Bean Fermentation Process | site1: SCOPUS
# inst: 0.5724906492985499 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['affordable digital data infrastructure', ' Internet of Things', ' smart agriculture', ' technology assist in smallholder data acquisition', ' wireless sensor network'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: de By, Rolf A. | inst1: Addis Ababa Univ, Coll Nat & Computat Sci, Dept Comp Sci, POB 1176, Addis Ababa, Ethiopia | title1: Utilization of Internet of Things and Wireless Sensor Networks for Sustainable Smallholder Agriculture | site1: WOS
# name2: de By, Rolf A. | inst2: Department of Geo-Information Processing Faculty of Geo-Information Science and Earth Observation (ITC) University of Twente P.O. Box 217 Enschede 7500 AA Netherlands | title2: Utilization of Internet of Things and Wireless Sensor Networks for Sustainable Smallholder Agriculture | site1: SCOPUS
# inst: 0.5609227640900681 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Agriculture', ' Plant Sciences'], ['GPS', ' RFID', ' single tree traceability'] | journal1: AGRONOMY-BASEL | journal2: MDPI
# name1: Li, Ming | inst1: Beijing Vocat Coll Agr, Dept Informat Technol, Beijing 102442, Peoples R China | title1: Streamlining Traceability Data Generation in Apple Production Using Integral Management with Machine-to-Machine Connections | site1: WOS
# name2: Li, Ming | inst2: Information Technology Research Center Beijing Academy of Agriculture and Forestry Sciences National Engineering Research Center for Information Technology in Agriculture National Engineering Laboratory for Agri‐Product Quality Traceability Beijing 100097 China | title2: Streamlining Traceability Data Generation in Apple Production Using Integral Management with Machine‐to‐Machine Connections | site1: SCOPUS
# inst: 0.526935594788765 | title: 0.9934959349593496 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['aquaponic', ' closed loop', ' ExtraTreesClassifier', ' median', ' pairwise correlation matrix', ' Recursive Feature Elimination', ' XGBoost'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Kalafatis, Stavros | inst1: Texas A&M Univ, Dept Soil & Crop Sci, College Stn, TX 79016 USA | title1: A Machine-Learning-Based IoT System for Optimizing Nutrient Supply in Commercial Aquaponic Operations | site1: WOS
# name2: Kalafatis, Stavros | inst2: Department of Electrical and Computer Engineering Texas A&M University College Station TX  79016 United States | title2: A Machine-Learning-Based IoT System for Optimizing Nutrient Supply in Commercial Aquaponic Operations | site1: SCOPUS
# inst: 0.6564694564694564 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# ['skarmetaantoniof_1', 'skarmetaantoniof_2', 'skarmetaantoniof_3', 'jainsanjeev_1', 'carloscorralesjuan_1', 'zualkernanimrana_1', 'rodriguezgonzalezsara_1', 'selvakumarans_1', 'shafiqmuhammad_1', 'kongjianlei_1', 'roviramasfrancisco_1', 'gilroymichael_1', 'leejaemin_1', 'butttalalashraf_1', 'yentaihsiang_1', 'montellaraffaele_1', 'giannoccaronicolaivan_1', 'chunghsincheng_1', 'gaozhanyi_1', 'mouazenabdulm_1', 'arorasakshi_1', 'yaulaihung_1', 'hassaneinaboulella_1', 'alammuhammadmahbub_1', 'sturmbarbara_1', 'ahmedmuqeem_1', 'heyong_1', 'hornbucklejohn_1', 'netinantpaniti_1', 'vishnubhatlaarvind_1', 'prietojavier_1', 'chowdaryvinay_1', 'bagchisaurabh_1', 'leekyutae_1', 'kadelrajan_1', 'lopezdylanjoshdomingo_1', 'leithardtvalderireisquietinho_1', 'alturjmanfadi_1', 'despoudistella_1', 'rajwadeya_1', 'umtaiwon_1', 'kohanjong_1', 'saklihedi_1', 'adekanbimichaellanre_1', 'khurrammuhammad_1', 'abdullahnorfadzilah_1', 'irmaksuat_1', 'badarlaanil_1', 'chogihwan_1', 'sunxiaohe_1', 'tyasithobelalouis_1', 'babotgaspadaniel_1', 'albertiantoniomarcos_1', 'lidaoliang_1', 'shruthir_1', 'falconefrancisco_1', 'liufanglin_1', 'kimdohyeun_1', 'hayawikadhim_1', 'ranjanrajiv_1', 'choyongyun_1', 'prabhucsr_1', 'boonsongwasana_1', 'showpauloke_1', 'sajjanharatul_1', 'yangchulju_1', 'masumabdulkadarmuhammad_1', 'grevefabiola_1', 'debyrolfa_1', 'liming_1', 'kalafatisstavros_1']

# %%
deleteList = []
sameLen_list = {}

for Answer_one in Answer_dict:
    for Answer_two in Answer_dict:
        name_sim = jaro.jaro_winkler_metric(Answer_one, Answer_two)
        if name_sim >= 0.8 and Answer_one != Answer_two:
            getRaw(Answer_one)
            getRaw(Answer_two)

            if len(Answer_one) < len(Answer_two):
                temp = Answer_one
                Answer_one = Answer_two
                Answer_two = temp
            elif len(Answer_one) == len(Answer_two):                
                if '_' in Answer_one and '_' in Answer_two:
                    numSame1 = Answer_one.split("_")[1]
                    numSame2 = Answer_two.split("_")[1]
                    if numSame1 > numSame2:
                        temp = Answer_one
                        Answer_one = Answer_two
                        Answer_two = temp

                else:
                    sameLen_list[Answer_one] = Answer_two
                    if Answer_two in sameLen_list: 
                        if Answer_one in sameLen_list[Answer_two]:
                            continue
            
            raws1 = Answer_dict[Answer_one]['raws']
            raws2 = Answer_dict[Answer_two]['raws']
            for ra1, ra2 in zip(raws1, raws2):
                site1 = ra1['site']
                site2 = ra2['site']
                inst1 = Answer_dict[Answer_one][site1]['oriInst']
                inst2 = Answer_dict[Answer_two][site2]['oriInst']
                count_rule += 1
                real_name1 = Answer_dict[Answer_one]['name']
                real_name2 = Answer_dict[Answer_two]['name']
                # print(f'input: {real_name1}, {real_name2}')
                # if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                if Secondary_filter2(real_name1, real_name2, site1, inst1, ra1, site2, inst2, ra2) >= 3:
                    Inte_name.append(Answer_one)
                    deleteList.append(Answer_two)
                    for site_one in site:
                        if site_one in Answer_dict[Answer_two]:
                            
                            if site_one in Answer_dict[Answer_one].keys() :                            
                                Answer_dict[Answer_one][site_one]['A_id'].extend(Answer_dict[Answer_two][site_one]['A_id'])
                                Answer_dict[Answer_one][site_one]['papers'].extend(Answer_dict[Answer_two][site_one]['papers'])
                                Answer_dict[Answer_one]['raws'].extend(Answer_dict[Answer_two]['raws'])
                                Answer_dict[Answer_one][site_one]['A_id'] = list(set(Answer_dict[Answer_one][site_one]['A_id']))
                                Answer_dict[Answer_one][site_one]['papers'] = list(set(Answer_dict[Answer_one][site_one]['papers']))
                            else:
                                Answer_dict[Answer_one][site_one] = Answer_dict[Answer_two][site_one]
                            if Answer_dict[Answer_one]['inst'] == "" or Answer_dict[Answer_one]['inst'] == " ":
                                Answer_dict[Answer_one]['inst'] = Answer_dict[Answer_one][site_one]['oriInst']
                    flag = True
                    break
            if flag :
                break
            
print(deleteList)

for del_name in deleteList:
    if del_name in Answer_dict:
        del Answer_dict[del_name]
for del_raw in Answer_dict : 
    if 'raws' in Answer_dict[del_raw] :
        del Answer_dict[del_raw]['raws']
        
print(len(Inte_name))
print(count_rule)
# Out:
# joc: 0 | yop: 2020, 2020 | co_author_count: 5 | keyword: ['Classification', ' Cloud computing', ' Clustering', ' Data analytics', ' Data-driven', ' Fog computing', ' Internet of Things (IoT)', ' Machine learning', ' Microservices', ' Smart dairy farming', ' Smart farm'], ['Agriculture', ' Computer Science'] | journal1: Elsevier B.V. | journal2: COMPUT ELECTRON AGR
# name1: Malone, Paul J. | inst1: Emerging Networks Laboratory Telecommunications Software and Systems Group Department of Computing and Mathematics School of Science and Computing Waterford Institute of Technology Waterford Ireland | title1: Machine learning based fog computing assisted data-driven approach for early lameness detection in dairy cattle | site1: SCOPUS
# name2: Malone, Paul | inst2: IBM Corp, Innovat Exchange, Dublin, Ireland | title2: Machine learning based fog computing assisted data-driven approach for early lameness detection in dairy cattle | site1: WOS
# inst: 0.4931876908621094 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: IEEE ACCESS | journal2: Association for Computing Machinery
# name1: Pearson, Simon | inst1: Univ Lincoln, Lincoln Inst Agrifood Technol, Lincoln LN6 7TS, England | title1: Photovoltaic Agricultural Internet of Things Towards Realizing the Next Generation of Smart Farming | site1: WOS
# name2: Paris M. | inst2: Bioceanor Sophia Antipolis France | title2: Planetary Digital Twin: A Case Study in Aquaculture | site1: SCOPUS
# inst: 0.5318401405357926 | title: 0.6099722717369777 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.6321205588285577 | journal1: AGRICULTURE-BASEL | journal2: IEEE Computer Society
# name1: Hung Nguyen | inst1: Ho Chi Minh City Univ Technol HUTECH, HUTECH Inst Engn, Ho Chi Minh City 700000, Vietnam | title1: Research on a Low-Cost, Open-Source, and Remote Monitoring Data Collector to Predict Livestock's Habits Based on Location and Auditory Information: A Case Study from Vietnam | site1: WOS
# name2: Huang, Nenfu | inst2: National Tsing Hua University Department of Computer Science Hsinchu Taiwan | title2: Design and Implementation of Anomaly Condition Detection in Agricultural IoT Platform System | site1: SCOPUS
# inst: 0.5784085536213196 | title: 0.6664277228175193 | email: 0, funding: 0
# weigth: 1.6321205588285577
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: INT J DISTRIB SENS N | journal2: SUSTAINABILITY-BASEL
# name1: Ismail, Mahmoud | inst1: Zagazig Univ, Fac Comp & Informat, Dept Operat Res, Sharqiyah, Egypt | title1: Internet of Green Things with autonomous wireless wheel robots against green houses and farms | site1: WOS
# name2: Ismail, Sohaib | inst2: Sichuan Agr Univ, Dept Plant Pathol, Chengdu 611130, Peoples R China | title2: Current Progress and Future Prospects of Agriculture Technology: Gateway to Sustainable Agriculture | site1: WOS
# inst: 0.6283422459893049 | title: 0.6675386739902868 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: T EMERG TELECOMMUN T | journal2: INT J ADV APPL SCI
# name1: Ahmed, Muqeem | inst1: Maulana Azad Natl Urdu Univ, Dept CS & IT, Hyderabad, India | title1: Importance of semantic interoperability in smart agriculture systems | site1: WOS
# name2: Ahmad, Mumtaz | inst2: Univ Management & Technol Lahore, Sch Syst & Technol, Lahore, Pakistan | title2: E-cultivation using the IoT with Adafruit cloud | site1: WOS
# inst: 0.6061679622785777 | title: 0.6487605120435632 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Agriculture', ' Data science', ' Economics', ' Internet of things', ' IoT', ' Semantics', ' Survey'], ['Geography'] | journal1: University of Maine | journal2: J SPAT INT SCI
# name1: Amidy, Martin R. | inst1: Fenner School of Environment and Society Australian National University Australia Centre for Entrepreneurial Agri-Technology Australian National University Australia | title1: Data-driven agriculture for rural smallholdings | site1: SCOPUS
# name2: Amidy, Martin | inst2: Australian Natl Univ, Fenner Sch Environm & Soc, Canberra, ACT, Australia | title2: Data-driven agriculture for rural smallholdings | site1: WOS
# inst: 0.6114708731147087 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: IEEE ACCESS
# name1: Al Azad, Abul Kalam | inst1: ULAB Dept. of CSE Dhaka Bangladesh | title1: IoT based smart weather monitoring system for poultry farm | site1: SCOPUS
# name2: Alazab, Mamoun | inst2: Charles Darwin Univ, Coll Engn IT & Environm, Casuarina, NT 0810, Australia | title2: Blockchain for Industry 4.0: A Comprehensive Review | site1: WOS
# inst: 0.48496732026143796 | title: 0.5805583727743971 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Biotechnology & Applied Microbiology'], ['Agribusiness', ' Agriculture', ' IoT', ' Sensors', ' Smart systems'] | journal1: HELIX | journal2: Springer
# name1: Kumar, V. D. Satish | inst1: Dr KV Subbareddy Coll Engn Women, Dept Comp Sci & Engn, Kurnool, India | title1: Internet of Things: A Product Development Cycle for the Entrepreneurs | site1: WOS
# name2: Kumar, Nagesh | inst2: School of Electrical and Computer Science Shoolini University of Biotechnology and Management Sciences Solan Himachal Pradesh India | title2: Internet of things-based hardware and software for smart agriculture: A review | site1: SCOPUS
# inst: 0.569630940378456 | title: 0.829143265812667 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 7 | keyword: ['Agriculture', ' Plant Sciences'], ['Data analytics', ' Internet-of-things', ' Precision agriculture', ' Red palm weevil detection'] | journal1: AGRONOMY-BASEL | journal2: MDPI AG
# name1: Alkanhal, Mohamed | inst1: King Saud Univ, Coll Food & Agr Sci, Dept Plant Protect, Riyadh 11451, Saudi Arabia | title1: Smart Palm: An IoT Framework for Red Palm Weevil Early Detection | site1: WOS
# name2: Alkanhal M. | inst2: Department of Computer Science College of Computer and Information Sciences Prince Sultan University Riyadh 11586 Saudi Arabia | title2: Smart palm: An IoT framework for red palm weevil early detection | site1: SCOPUS
# inst: 0.6441630199603268 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Clustering', ' Cross-layer', ' Intelligent manufacturing', ' Internet of Things', ' Nature-inspired algorithm', ' Smart farming'], ['Computer Science', ' Telecommunications'] | journal1: Springer Science and Business Media Deutschland GmbH | journal2: J AMB INTEL HUM COMP
# name1: Junnarkar, Aparna Atul | inst1: PES Modern College of Engineering Pune India | title1: CL-IoT: cross-layer Internet of Things protocol for intelligent manufacturing of smart farming | site1: SCOPUS
# name2: Junnarkar, Aparna A. | inst2: PES Modern Coll Engn, Pune, Maharashtra, India | title2: CL-IoT: cross-layer Internet of Things protocol for intelligent manufacturing of smart farming | site1: WOS
# inst: 0.819158981115503 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Crop coefficients', ' Crop evapotranspiration', ' Dual Kc approach', ' Real time irrigation management', ' SIMDualKc model', ' Water use assessment'], ['Agriculture', ' Water Resources'] | journal1: Elsevier B.V. | journal2: AGR WATER MANAGE
# name1: Jovanović, Nebojša Z. | inst1: CSIR Water Centre Stellenbosch South Africa | title1: Soil water balance models for determining crop water and irrigation requirements and irrigation scheduling focusing on the FAO56 method and the dual Kc approach | site1: SCOPUS
# name2: Jovanovic, N. | inst2: CSIR, Water Ctr, Stellenbosch, South Africa | title2: Soil water balance models for determining crop water and irrigation requirements and irrigation scheduling focusing on the FAO56 method and the dual K-c approach | site1: WOS
# inst: 0.9470930232558139 | title: 0.9987577639751554 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 4 | keyword: ['ArtifiCial Intelligence', ' Cooperative Smart Farming', ' Cyber-Physical Systems', ' Ontology.', ' Precision Agriculture'], ['Computer Science', ' Engineering', ' Telecommunications'] | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: IEEE ACCESS
# name1: Joshi, Karuna Pande | inst1: Department of Computer Science University of Maryland Baltimore County Baltimore MD  21250 United States | title1: Ontologies and artificial intelligence systems for the cooperative smart farming ecosystem | site1: SCOPUS
# name2: Joshi, Karuna | inst2: Univ Maryland Baltimore Cty, Dept Informat Syst, Baltimore, MD 21250 USA | title2: Ontologies and Artificial Intelligence Systems for the Cooperative Smart Farming Ecosystem | site1: WOS
# inst: 0.7090083769188248 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: ADV METEOROL | journal2: IEEE T INSTRUM MEAS
# name1: Liu, Chenchen | inst1: Jiangsu Univ, Sch Mech Engn, Zhenjiang, Jiangsu, Peoples R China | title1: Review of Sensor Network-Based Irrigation Systems Using IoT and Remote Sensing | site1: WOS
# name2: Liu, Zheng | inst2: Natl Res Council Canada, Adv Elect & Photon Res Ctr, Ottawa, ON K1A 0R6, Canada | title2: Printed Sensor Technologies for Monitoring Applications in Smart Farming: A Review | site1: WOS
# inst: 0.5424647457250722 | title: 0.6997854842071994 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: REMOTE SENS-BASEL | journal2: INDIAN J AGR SCI
# name1: Singh, Sudhir K. | inst1: Univ Allahabad, K Banerjee Ctr Atmospher & Ocean Studies, IIDS, Nehru Sci Ctr, Prayagraj 211002, India | title1: Applications of Remote Sensing in Precision Agriculture: A Review | site1: WOS
# name2: Singh, K. G. | inst2: Punjab Agr Univ, Dept Soil & Water Engn, Ludhiana 141004, Punjab, India | title2: Development of an IoT based weighing type micro-lysimeter for soilless cultivation | site1: WOS
# inst: 0.6562464406467607 | title: 0.7111495123048396 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: REMOTE SENS-BASEL | journal2: INDIAN J AGR SCI
# name1: Singh, Sudhir K. | inst1: Univ Allahabad, K Banerjee Ctr Atmospher & Ocean Studies, IIDS, Nehru Sci Ctr, Prayagraj 211002, India | title1: Applications of Remote Sensing in Precision Agriculture: A Review | site1: WOS
# name2: Singh, K. G. | inst2: Punjab Agr Univ, Dept Soil & Water Engn, Ludhiana 141004, Punjab, India | title2: Development of an IoT based weighing type micro-lysimeter for soilless cultivation | site1: WOS
# inst: 0.6562464406467607 | title: 0.7111495123048396 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Chemistry', ' Engineering', ' Materials Science', ' Physics'], ['Fog computing', ' Internet of things', ' Outliers', ' Reliability', ' Smart Farming'] | journal1: APPL SCI-BASEL | journal2: MDPI AG
# name1: Caicedo Rendon, Oscar Mauricio | inst1: Univ Cauca, Dept Telemat, Cauca 190002, Colombia | title1: An Approach Based on Fog Computing for Providing Reliability in IoT Data Collection: A Case Study in a Colombian Coffee Smart Farm | site1: WOS
# name2: Caicedo, O. | inst2: Departamento de Telemática Universidad del Cauca Popayán Cauca  190002 Colombia | title2: An approach based on fog computing for providing reliability in iot data collection: A case study in a colombian coffee smart farm | site1: SCOPUS
# inst: 0.6727437880918893 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Ahmad, Ir Khairul Azman | inst1: Univ Teknol MARA, Fac Elect Engn, Permatang Pauh 14000, Malaysia | title1: Towards Smart Agriculture Monitoring Using Fuzzy Systems | site1: WOS
# name2: Ahmadinia, Ali | inst2: California State University San Marcos Deptatment of Computer Science and Information Systesm San Marcos CA United States | title2: Sensor data visualization on google maps using AWS, and IoT Discovery Board | site1: SCOPUS
# inst: 0.5134811949875697 | title: 0.6271428571428571 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: J INF ASSUR SECUR | journal2: Springer
# name1: Nair, Meghna Manoj | inst1: Vellore Inst Technol, Sch Comp Sci & Engn, Chennai Campus, Chennai 600127, Tamil Nadu, India | title1: Internet of Everything (IoE) and Internet of Things (IoTs): Threat Analyses, Possible Opportunities for Future | site1: WOS
# name2: Naz, Ammerha | inst2: University of Sialkot Sialkot Pakistan | title2: IoT and AI in Precision Agriculture: Designing Smart System to Support Illiterate Farmers | site1: SCOPUS
# inst: 0.5145807662970134 | title: 0.6905851714840479 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering'], ['Agriculture market equilibrium', ' Economic analysis', ' FPGA', ' Internet of Things (IoT)', ' Market agencies'] | journal1: MICROPROCESS MICROSY | journal2: Elsevier B.V.
# name1: Li Xiaofeng | inst1: China Agr Univ, Coll Econ & Management, Beijing 100083, Peoples R China | title1: Agricultural labor market equilibrium based on FPGA platform and IoT communication | site1: WOS
# name2: Xiaofeng L. | inst2: College of Economics and Management China Agricultural University Beijing 100083 China | title2: Agricultural labor market equilibrium based on FPGA platform and IoT communication | site1: SCOPUS
# inst: 0.6975816137132874 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Internet of Things (IoT)', ' LoRa', ' LoRaWAN', ' Modeling', ' Network Simulator 3 (NS-3)', ' Performance', ' Simulation', ' Smart agriculture'] | journal1: COMPUT COMMUN | journal2: Elsevier B.V.
# name1: Chikhi, Salim | inst1: Univ Constantine 2, MISC Lab, Constantine 25000, Algeria | title1: A study of LoRaWAN protocol performance for IoT applications in smart agriculture | site1: WOS
# name2: Chikhi, S. | inst2: MISC Laboratory University of Constantine 2 Constantine 25000 Algeria | title2: A study of LoRaWAN protocol performance for IoT applications in smart agriculture | site1: SCOPUS
# inst: 0.7476154667500032 | title: 1.0 | email: 1, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 1 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.950212931632136 | journal1: IEEE INTERNET THINGS | journal2: IEEE INTERNET THINGS
# name1: Kumar, Chiranjeev | inst1: Indian Inst Technol Indian Sch Mines Dhanbad, Dept Comp Sci & Engn, Dhanbad 826004, Bihar, India | title1: IoT-Enabled IEEE 802.15.4 WSN Monitoring Infrastructure-Driven Fuzzy-Logic-Based Crop Pest Prediction | site1: WOS
# name2: Kumar, Neeraj | inst2: Thapar Inst Engn & Technol Deemed Univ, Dept Comp Sci & Engn, Patiala 147004, Punjab, India | title2: Secure Multifactor Authenticated Key Agreement Scheme for Industrial IoT | site1: WOS
# inst: 0.6943944650810848 | title: 0.6640554082730677 | email: 0, funding: 0
# weigth: 2.850212931632136
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: IEEE-CAA J AUTOMATIC | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Wang, Xiaochan | inst1: Nanjing Agr Univ, Dept Elect Engn, Nanjing 210095, Peoples R China | title1: Internet of Things for the Future of Smart Agriculture: A Comprehensive Survey of Emerging Technologies | site1: WOS
# name2: Wang, Tianlei | inst2: Wuyi University Faculty of SmartManufacturing Jiangmen China | title2: Smart Farm Based on Six-Domain Model | site1: SCOPUS
# inst: 0.541919191919192 | title: 0.5349095049742298 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: CMC-COMPUT MATER CON
# name1: Sharmila K P. | inst1: CMR Institute of Technology Dept. of ECE Bengaluru India | title1: LoRa Technology Based Hydroponic Farm Monitoring System | site1: SCOPUS
# name2: Shankar, K. | inst2: Alagappa Univ, Dept Comp Applicat, Karaikkudi 630001, Tamil Nadu, India | title2: An Optimal Classification Model for Rice Plant Disease Detection | site1: WOS
# inst: 0.5083053878828526 | title: 0.6558351370851371 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: INT J DISTRIB SENS N | journal2: SUSTAINABILITY-BASEL
# name1: Ismail, Mahmoud | inst1: Zagazig Univ, Fac Comp & Informat, Dept Operat Res, Sharqiyah, Egypt | title1: Internet of Green Things with autonomous wireless wheel robots against green houses and farms | site1: WOS
# name2: Ismail, Sohaib | inst2: Sichuan Agr Univ, Dept Plant Pathol, Chengdu 611130, Peoples R China | title2: Current Progress and Future Prospects of Agriculture Technology: Gateway to Sustainable Agriculture | site1: WOS
# inst: 0.6283422459893049 | title: 0.6675386739902868 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: IEEE INTERNET THINGS | journal2: REMOTE SENS-BASEL
# name1: Singh, Harendra | inst1: Hindustan Coll Sci & Technol, Dept Math, Mathura 281122, India | title1: SCBS: A Short Certificate-Based Signature Scheme With Efficient Aggregation for Industrial-Internet-of-Things Environment | site1: WOS
# name2: Singh, Sudhir K. | inst2: Univ Allahabad, K Banerjee Ctr Atmospher & Ocean Studies, IIDS, Nehru Sci Ctr, Prayagraj 211002, India | title2: Applications of Remote Sensing in Precision Agriculture: A Review | site1: WOS
# inst: 0.6396326750532949 | title: 0.6563148972239882 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: Springer Science and Business Media Deutschland GmbH | journal2: NEURAL COMPUT APPL
# name1: Maheshwari, Piyush | inst1: Department of Computer Science and Engineering Amity University Dubai Dubai United Arab Emirates | title1: IoT-Based Smart Tree Management Solution for Green Cities | site1: SCOPUS
# name2: Maheswari, B. Uma | inst2: Anna Univ, Comp Sci & Engn, St Josephs Coll Engn, Chennai, Tamil Nadu, India | title2: Health monitoring and fault prediction using a lightweight deep convolutional neural network optimized by Levy flight optimization algorithm | site1: WOS
# inst: 0.5903100275197798 | title: 0.5914452798663324 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: PROCESSES | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Miao, Shen-Yun | inst1: Natl Chi Nan Univ, Dept Elect Engn, Nantou 545, Taiwan | title1: A LoRa-Based Multisensor IoT Platform for Agriculture Monitoring and Submersible Pump Control in a Water Bamboo Field | site1: WOS
# name2: Misha E. | inst2: ENGS Systems Israel | title2: Methodical Analysis of a Fog Computing Assisted Animal-Welfare Software System in a Real-World Smart Dairy Farm IoT Deployment | site1: SCOPUS
# inst: 0.398635477582846 | title: 0.7294505494505494 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: PERTANIKA J SCI TECH | journal2: INT J DISTRIB SENS N
# name1: Ismail, Mohd Razi | inst1: Univ Putra Malaysia, Fac Agr, Dept Crop Sci, Serdang 43400, Selangor, Malaysia | title1: Smartphone Application Development for Rice Field Management Through Aerial Imagery and Normalised Difference Vegetation Index (NDVI) Analysis | site1: WOS
# name2: Ismail, Mahmoud | inst2: Zagazig Univ, Fac Comp & Informat, Dept Operat Res, Sharqiyah, Egypt | title2: Internet of Green Things with autonomous wireless wheel robots against green houses and farms | site1: WOS
# inst: 0.6264685361324017 | title: 0.665648610900769 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: CONCURR COMP-PRACT E
# name1: Sundararajan S. | inst1: Scad College of Engineering and Technology Department of Mechanical Engineering Tirunelveli India | title1: Intelligent Itinerant Robot [IIR] for Agricultural Farm Monitoring using IoT | site1: SCOPUS
# name2: Sundar, Ramesh | inst2: VIGNANs Fdn Sci Technol & Res Deemed Univ, Dept Elect & Commun Engn, Guntur, Andhra Pradesh, India | title2: Cardiac disease diagnosis using feature extraction and machine learning based classification with Internet of Things(IoT) | site1: WOS
# inst: 0.6013621278241925 | title: 0.6288852943308685 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: ADV METEOROL | journal2: IEEE T INSTRUM MEAS
# name1: Liu, Chenchen | inst1: Jiangsu Univ, Sch Mech Engn, Zhenjiang, Jiangsu, Peoples R China | title1: Review of Sensor Network-Based Irrigation Systems Using IoT and Remote Sensing | site1: WOS
# name2: Liu, Zheng | inst2: Natl Res Council Canada, Adv Elect & Photon Res Ctr, Ottawa, ON K1A 0R6, Canada | title2: Printed Sensor Technologies for Monitoring Applications in Smart Farming: A Review | site1: WOS
# inst: 0.5424647457250722 | title: 0.6997854842071994 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: IEEE Computer Society | journal2: INTEL SERV ROBOT
# name1: Kim, Jonghoek | inst1: Hongik University Department of Electrical Engineering Sejong 30016 South Korea | title1: Light control smart farm monitoring system with reflector control | site1: SCOPUS
# name2: Kim, Jai-Hoon | inst2: Ajou Univ, Suwon, South Korea | title2: UAV path planning method for avoiding restricted areas | site1: WOS
# inst: 0.4632106880290309 | title: 0.6584647812290089 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2020, 2021 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['BPMN', ' Coffee Farm', ' Data Analytics', ' Internet of Things', ' Outlier Detection', ' Smart Farming'] | journal1: IEEE INTERNET THINGS | journal2: Elsevier B.V.
# name1: Carlos Corrales, Juan | inst1: Univ Cauca, DTM, Popayan 190003, Colombia | title1: A Conceptual Data Model and Its Automatic Implementation for IoT-Based Business Intelligence Applications | site1: WOS
# name2: Corrales, Juan Carlos | inst2: Department of Telematics Engineering Engineering Telematics Group Universidad del Cauca Popayán 190002 Colombia | title2: IoT-Agro: A smart farming system to Colombian coffee farms | site1: SCOPUS
# inst: 0.46163846773602873 | title: 0.5915589824135551 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: INTELL AUTOM SOFT CO | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Al-Amri, Jehad F. | inst1: Taif Univ, Coll Comp & Informat Technol, Dept Informat Technol, At Taif 21944, Saudi Arabia | title1: Development of IoT Based Fish Monitoring System for Aquaculture | site1: WOS
# name2: Ali, Maaruf | inst2: Epoka University Department of Computer Engineering Tirana Albania | title2: Wireless Technology for Autonomous Albanian Farming and Crop Monitoring | site1: SCOPUS
# inst: 0.6242408385265529 | title: 0.6857484777948738 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: WIRELESS PERS COMMUN | journal2: Springer Verlag
# name1: Reddy, P. Ramana | inst1: G Pulla Reddy Engn Coll Autonomous, Elect & Commun Engn Dept, Kurnool 518007, Andhra Pradesh, India | title1: Indoor Tracking by Adding IMU and UWB Using Unscented Kalman Filter | site1: WOS
# name2: Reddy, S. Raji N. | inst2: Department of Computer Science and Engineering Indira Gandhi Delhi Technical University for Women Delhi India | title2: Design and development of IoT-based framework for indian aquaculture | site1: SCOPUS
# inst: 0.593498536589133 | title: 0.673854258121159 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: SENSOR MATER | journal2: IEEE INTERNET THINGS
# name1: Lopez, Dylan Josh Domingo | inst1: Adamson Univ, Comp Engn Dept, 900 San Marcelino Ermita, Manila, Philippines | title1: Application of Internet of Things in Smart Farm Watering System | site1: WOS
# name2: Lopez, Juan Carlos | inst2: Univ Castilla La Mancha, Sch Comp Sci, Ciudad Real 13071, Spain | title2: Collection of Data With Drones in Precision Agriculture: Analytical Model and LoRa Case Study | site1: WOS
# inst: 0.5969189122677495 | title: 0.681536951698242 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 4 | keyword: ['Agriculture 4.0', ' Internet of Things', ' Multi-spectral analysis', ' Normalized difference vegetation index', ' Precision farming', ' Smart agriculture', ' Unmanned aerial vehicle', ' Wireless sensors network', ' ZigBee'], ['Agriculture', ' Plant Sciences'] | journal1: MDPI | journal2: AGRONOMY-BASEL
# name1: Casavola, Alessandro Fiorentino | inst1: Dipartimento di Ingegneria Informatica Modellistica Elettronica e Sistemistica (DIMES) Università della Calabria Via P. Bucci Cubo 42/c CS Rende 87036 Italy | title1: An internet of things solution for smart agriculture | site1: SCOPUS
# name2: Casavola, Alessandro | inst2: WeSmart Srl, Via A Monaco 20, I-87100 Cosenza, Italy | title2: An Internet of Things Solution for Smart Agriculture | site1: WOS
# inst: 0.4928774928774929 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: IEEE ACCESS | journal2: Inderscience Publishers
# name1: O'Hare, Gregory M. P. | inst1: Trinity Coll Dublin, Sch Comp Sci & Stat, Dublin D02 PN40 2, Ireland | title1: Automated Zone Identification for Variable-Rate Services in Precision Agriculture | site1: WOS
# name2: O’Hare, Gregory M.P. | inst2: School of Computer Science University College Dublin (UCD) Belfield Dublin 4 Ireland | title2: A farmland-microclimate monitoring system based on the internet of things | site1: SCOPUS
# inst: 0.6462220108169053 | title: 0.6873459895413822 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: INT J ADV COMPUT SC | journal2: Institute of Advanced Scientific Research, Inc.
# name1: Sangeetha, J. | inst1: MS Ramaiah Inst Technol, Dept Comp Sci & Engn, Bengaluru, India | title1: Smart Irrigation and Precision Farming of Paddy Field using Unmanned Ground Vehicle and Internet of Things System | site1: WOS
# name2: Saveetha P. | inst2: Department of Information Technology Nandha College of Technology India | title2: Precision agriculture using IOT varied sensors: A gateway management system | site1: SCOPUS
# inst: 0.6345480289142261 | title: 0.6985531675797162 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Digital audio signal processing', ' Internet of Things', ' Mesh network', ' Smart Farm', ' WSN'] | journal1: INTERNET THINGS-NETH | journal2: Elsevier B.V.
# name1: Oliveira, Lucas de Araujo | inst1: Unesp Univ Estadual Paulista Sao Paulo State Univ, Inst Biociencias Letras & Ciencias Exatas, Rua Cristovao Colombo 2265, BR-15054000 Sao Jose Do Rio Preto, SP, Brazil | title1: A mesh network case study for digital audio signal processing in Smart Farm | site1: WOS
# name2: Oliveira L.D.A. | inst2: Instituto Federal São Paulo Av. C-1 250 SP Barretos 14781-502 Brazil | title2: A mesh network case study for digital audio signal processing in Smart Farm | site1: SCOPUS
# inst: 0.5672670701377993 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 1 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.950212931632136 | journal1: IEEE INTERNET THINGS | journal2: IEEE INTERNET THINGS
# name1: Kumar, Chiranjeev | inst1: Indian Inst Technol Indian Sch Mines Dhanbad, Dept Comp Sci & Engn, Dhanbad 826004, Bihar, India | title1: IoT-Enabled IEEE 802.15.4 WSN Monitoring Infrastructure-Driven Fuzzy-Logic-Based Crop Pest Prediction | site1: WOS
# name2: Kumar, Neeraj | inst2: Thapar Inst Engn & Technol Deemed Univ, Dept Comp Sci & Engn, Patiala 147004, Punjab, India | title2: Secure Multifactor Authenticated Key Agreement Scheme for Industrial IoT | site1: WOS
# inst: 0.6943944650810848 | title: 0.6640554082730677 | email: 0, funding: 0
# weigth: 2.850212931632136
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Artificial intelligence', ' Internet of things', ' Irrigation scheduling', ' Multi-agent', ' Precision irrigation'], ['Agriculture', ' Computer Science'] | journal1: Elsevier B.V. | journal2: COMPUT ELECTRON AGR
# name1: Jiménez López, Fabián R. | inst1: Universidad Pedagógica y Tecnológica de Colombia Avenida Central del Norte 39-115 Tunja Boyacá Colombia | title1: Intelligent IoT-multiagent precision irrigation approach for improving water use efficiency in irrigation systems at farm and district scales | site1: SCOPUS
# name2: Jimenez, Fabian | inst2: Univ Pedag & Tecnol Colombia, Ave Cent Norte 39-115, Tunja, Boyaca, Colombia | title2: Intelligent IoT-multiagent precision irrigation approach for improving water use efficiency in irrigation systems at farm and district scales | site1: WOS
# inst: 0.8430160420879904 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Agriculture', ' Food Science & Technology'], ['Agri-food system', ' Collaboration-based business model', ' Ecosystem', ' Internet of things', ' Open innovation'] | journal1: BRIT FOOD J | journal2: Emerald Group Holdings Ltd.
# name1: Dolfsma, Wilfred | inst1: Wageningen Univ & Res, Wageningen Econ Res, Wageningen, Netherlands | title1: A smart web of firms, farms and internet of things (IOT): enabling collaboration-based business models in the agri-food industry | site1: WOS
# name2: Dolfsma W. | inst2: Business Management and Organization Group Department of Social Sciences Wageningen University and Research Wageningen Netherlands | title2: A smart web of firms, farms and internet of things (IOT): enabling collaboration-based business models in the agri-food industry | site1: SCOPUS
# inst: 0.6326774614988717 | title: 0.9362573818897638 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: J FOOD QUALITY | journal2: Ecological Society of India
# name1: Rahmani, Abdul Wahab | inst1: Isteqlal Inst Higher Educ, Kabul, Afghanistan | title1: Application of IoT and Cloud Computing in Automation of Agriculture Irrigation | site1: WOS
# name2: Rahmawati | inst2: Muhammadiyah University Palapo 91922 Indonesia | title2: Agriculture 4.0 and smart farming: Imperatives of scaling up innovation and farmer capabilities for sustainable business | site1: SCOPUS
# inst: 0.5042014346362172 | title: 0.6837396171903215 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Agriculture', ' Plant Sciences'], ['Agriculture 5.0', ' Artificial intelligence', ' Biomass', ' Chlorophyll', ' IoT', ' Leaf area index', ' Nitrogen', ' Robot', ' Sensors'] | journal1: AGRONOMY-BASEL | journal2: MDPI
# name1: Marino, Stefano | inst1: Univ Kassel, Dept Agr & Biosyst Engn, D-37213 Witzenhausen, Germany | title1: Technology and Data Fusion Methods to Enhance Site-Specific Crop Monitoring | site1: WOS
# name2: Marino, S. | inst2: Department of Agricultural Environmental and Food Sciences University of Molise Campobasso 86100 Italy | title2: Technology and Data Fusion Methods to Enhance Site-Specific Crop Monitoring | site1: SCOPUS
# inst: 0.5762242708028484 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: MICROPROCESS MICROSY | journal2: Association for Computing Machinery
# name1: Tn, Padmini | inst1: Vellore Inst Technol, Sch Elect Engn, Dept Embedded Technol, Vellore 632014, Tamil Nadu, India | title1: AgriWealth: IoT based farming system | site1: WOS
# name2: Tan, Ming | inst2: College of Artificial Intelligence and Big Data Hefei University 99 Jinxiu Avenue Hefei City Anhui Province China | title2: Design and Implementation of Intelligent Ear Tag for Dairy Cows in Farms | site1: SCOPUS
# inst: 0.5632517086351729 | title: 0.5944444444444444 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics'], ['API', ' Data Envelopment Analysis', ' IoT', ' Performance', ' Single Board Computer', ' Web Service'] | journal1: SURANAREE J SCI TECH | journal2: Suranaree University of Technology
# name1: On-rit, Surajate | inst1: Ubon Ratchathani Raj Abhat Univ, Dept Comp Network Engn, Fac Ind Technol, 2 Ratchathani Rd, Ubon Ratchathani 34000, Thailand | title1: WEB SERVICES PERFORMANCE EVALUATION ON SINGLE BOARD COMPUTERS FOR MOBILE APPLICATIONS AND IoT DEVICES | site1: WOS
# name2: On-rit S. | inst2: Department of Computer Network Engineering Faculty of Industrial Technology Ubon Ratchathani Rajabhat University 2 Ratchathani RoadNai Mueang Sub-District Mueang District Ubon Ratchathani 34000 Thailand | title2: WEB SERVICES PERFORMANCE EVALUATION ON SINGLE BOARD COMPUTERS FOR MOBILE APPLICATIONS AND IoT DEVICES | site1: SCOPUS
# inst: 0.6983644509885653 | title: 1.0 | email: 0, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2021, 2021 | co_author_count: 2 | keyword: ['Environmental Sciences & Ecology', ' Remote Sensing'], ['5G', ' Decision support systems', ' IoT', ' Smart Agriculture', ' Smart sensing'] | journal1: EGYPT J REMOTE SENS | journal2: Elsevier B.V.
# name1: Zahran, Mohamed B. | inst1: Natl Res Ctr, Soils & Water Use Dept, Agr & Biol Res Div, Cairo 12622, Egypt | title1: Smart farming for improving agricultural management | site1: WOS
# name2: Zahran M.B. | inst2: National Authority for Remote Sensing and Space Sciences (NARSS) Cairo 11843 Egypt | title2: Smart farming for improving agricultural management | site1: SCOPUS
# inst: 0.6425502781343604 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.6321205588285577 | journal1: AD HOC NETW | journal2: CLUSTER COMPUT
# name1: Rodriguez-Gonzalez, Sara | inst1: Univ Salamanca, BISITE Res Grp, Salamanca, Spain | title1: An intelligent Edge-IoT platform for monitoring livestock and crops in a dairy farming scenario | site1: WOS
# name2: Rodrigues, Joel J. P. C. | inst2: ITMO Univ, St Petersburg, Russia | title2: Security in IoT-enabled smart agriculture: architecture, security solutions and challenges | site1: WOS
# inst: 0.522843567251462 | title: 0.6477405635300372 | email: 0, funding: 0
# weigth: 1.4321205588285577
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['communication networks', ' Internet of Things (IoT)', ' large-scale farms', ' LoRa technology', ' remote monitoring', ' smart farming'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Carvajal, Rodrigo | inst1: Pontificia Univ Catolica Valparaiso, Escuela Ingn Elect, Valparaiso 2362804, Chile | title1: LoRa Based IoT Platform for Remote Monitoring of Large-Scale Agriculture Farms in Chile | site1: WOS
# name2: Carvajal R. | inst2: Escuela de Ingeniería Eléctrica Pontificia Universidad Católica de Valparaíso Valparaíso 2362804 Chile | title2: LoRa Based IoT Platform for Remote Monitoring of Large-Scale Agriculture Farms in Chile | site1: SCOPUS
# inst: 0.7514623110032005 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Agriculture', ' Animals', ' Autonomous aerial vehicles', ' Cattle', ' Cows', ' Drones', ' Livestock Agriculture', ' Livestock Management', ' Monitoring', ' Sensors', ' Unmanned Aerial Vehicle'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Bouchekara, Houssem R. E. H. | inst1: Islamic Univ Technol, Dept Comp Sci & Engn, Gazipur 1704, Bangladesh | title1: Livestock Management With Unmanned Aerial Vehicles: A Review | site1: WOS
# name2: Bouchekara, Houssem | inst2: Department of Electrical Engineering University of Hafr Al Batin Hafr Al Batin 31991 | title2: Livestock Management with Unmanned Aerial Vehicles: A Review | site1: SCOPUS
# inst: 0.589189298907969 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['agriculture', ' communicative ecology', ' data inequalities', ' Digital divide', ' digital farming', ' precision agriculture'], ['Communication', ' Sociology'] | journal1: Routledge | journal2: INFORM COMMUN SOC
# name1: Dezuanni, Michael L. | inst1: Queensland University of Technology Brisbane Australia | title1: Critical factors of digital AgTech adoption on Australian farms: from digital to data divide | site1: SCOPUS
# name2: Dezuanni, Michael | inst2: Queensland Univ Technol, Digital Media Res Ctr, Digital Inclus & Participat, Brisbane, Qld, Australia | title2: Critical factors of digital AgTech adoption on Australian farms: from digital to data divide | site1: WOS
# inst: 0.6954778244264336 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Computer Science', ' Engineering', ' Operations Research & Management Science'], ['Blockchain', ' Chaotic map', ' Cloud computing environment', ' Cloud server', ' Internet of things', ' Paillier map'] | journal1: EXPERT SYST APPL | journal2: Elsevier Ltd
# name1: Sunitha, C. Adline | inst1: Manonmaniam Sundaranar Univ, Tirunelveli 627012, Tamil Nadu, India | title1: Chaotic and Paillier secure image data sharing based on blockchain and cloud security | site1: WOS
# name2: Sunitha C.A. | inst2: Assistant Professor St.Teresa Arts and Science College for Women Mangalakuntu Kanyakumari District affiliated to Manonmaniam Sundaranar University Abishekapatti Tamilnadu Tirunelveli 627012 India | title2: Chaotic and Paillier secure image data sharing based on blockchain and cloud security | site1: SCOPUS
# inst: 0.5342977284153755 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Blockchain', ' Digital', ' Gene sequencing', ' Internet', ' Precision agriculture (PA)', ' Robotics', ' Sensors', ' Social media'] | journal1: IEEE INTERNET THINGS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Martynenko, Alex | inst1: Nestle Res & Dev Ctr, Gurgaon 122050, India | title1: IoT, Big Data, and Artificial Intelligence in Agriculture and Food Industry | site1: WOS
# name2: Martynenko, A. | inst2: Department of Engineering Faculty of Agriculture Dalhousie University Truro NS  B2N 5E6 Canada | title2: IoT, Big Data, and Artificial Intelligence in Agriculture and Food Industry | site1: SCOPUS
# inst: 0.4988771742853881 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: WIRELESS PERS COMMUN | journal2: Springer Verlag
# name1: Reddy, P. Ramana | inst1: G Pulla Reddy Engn Coll Autonomous, Elect & Commun Engn Dept, Kurnool 518007, Andhra Pradesh, India | title1: Indoor Tracking by Adding IMU and UWB Using Unscented Kalman Filter | site1: WOS
# name2: Reddy, S. Raji N. | inst2: Department of Computer Science and Engineering Indira Gandhi Delhi Technical University for Women Delhi India | title2: Design and development of IoT-based framework for indian aquaculture | site1: SCOPUS
# inst: 0.593498536589133 | title: 0.673854258121159 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.6321205588285577 | journal1: AD HOC NETW | journal2: CLUSTER COMPUT
# name1: Rodriguez-Gonzalez, Sara | inst1: Univ Salamanca, BISITE Res Grp, Salamanca, Spain | title1: An intelligent Edge-IoT platform for monitoring livestock and crops in a dairy farming scenario | site1: WOS
# name2: Rodrigues, Joel J. P. C. | inst2: ITMO Univ, St Petersburg, Russia | title2: Security in IoT-enabled smart agriculture: architecture, security solutions and challenges | site1: WOS
# inst: 0.522843567251462 | title: 0.6477405635300372 | email: 0, funding: 0
# weigth: 1.4321205588285577
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2020, 2020 | co_author_count: 0 | keyword: ['Biotechnology & Applied Microbiology'], ['Agribusiness', ' Agriculture', ' IoT', ' Sensors', ' Smart systems'] | journal1: HELIX | journal2: Springer
# name1: Kumar, V. D. Satish | inst1: Dr KV Subbareddy Coll Engn Women, Dept Comp Sci & Engn, Kurnool, India | title1: Internet of Things: A Product Development Cycle for the Entrepreneurs | site1: WOS
# name2: Kumar, Nagesh | inst2: School of Electrical and Computer Science Shoolini University of Biotechnology and Management Sciences Solan Himachal Pradesh India | title2: Internet of things-based hardware and software for smart agriculture: A review | site1: SCOPUS
# inst: 0.569630940378456 | title: 0.829143265812667 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: MICROPROCESS MICROSY | journal2: IOP Publishing Ltd
# ...
# name2: Kim, Taioun | inst2: Department of Industrial and Management Engineering Kyungsung University 309 Suyeong-ro Nam-gu Busan 48434 South Korea | title2: SMART FARM REALIZATION BASED ON DIGITAL TWIN | site1: SCOPUS
# inst: 0.4650455771222328 | title: 0.6812008978675644 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: Taiwan Academic Network Management Committee | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Chen, Yungyao | inst1: Department of Electronic and Computer Engineering National Taiwan University of Science and Technology Taiwan | title1: The Challenge of Aqua Creatures Specie Classification in the Aquarium Innovation Theme | site1: SCOPUS
# name2: Chen, Hong | inst2: Daiichi Institute of Technology Department of Information and Electronics System Engineering Tokyo Japan | title2: Decentralized Personal Cloud Data Model and its Application in Campus Health Information System | site1: SCOPUS
# inst: 0.7559283211252525 | title: 0.7076272723151549 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 2 | keyword: ['Chemistry', ' Engineering', ' Instruments & Instrumentation'], ['communication networks', ' Internet of Things (IoT)', ' large-scale farms', ' LoRa technology', ' remote monitoring', ' smart farming'] | journal1: SENSORS-BASEL | journal2: MDPI
# name1: Carvajal, Rodrigo | inst1: Pontificia Univ Catolica Valparaiso, Escuela Ingn Elect, Valparaiso 2362804, Chile | title1: LoRa Based IoT Platform for Remote Monitoring of Large-Scale Agriculture Farms in Chile | site1: WOS
# name2: Carvajal R. | inst2: Escuela de Ingeniería Eléctrica Pontificia Universidad Católica de Valparaíso Valparaíso 2362804 Chile | title2: LoRa Based IoT Platform for Remote Monitoring of Large-Scale Agriculture Farms in Chile | site1: SCOPUS
# inst: 0.7514623110032005 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: Institute of Advanced Scientific Research, Inc. | journal2: IGI Global
# name1: Sri Bhargav Sai, G. | inst1: Department of ECE Lakireddy Balireddy College of Engineering Mylavaram India | title1: Smart agricult ure and home automation using google assistance | site1: SCOPUS
# name2: Srivastava K. | inst2: Institute of Information Technology and Management GGSIP University Delhi India | title2: Farming automation | site1: SCOPUS
# inst: 0.6333768940364543 | title: 0.6022910956497295 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: CONCURR COMP-PRACT E
# name1: Sundararajan S. | inst1: Scad College of Engineering and Technology Department of Mechanical Engineering Tirunelveli India | title1: Intelligent Itinerant Robot [IIR] for Agricultural Farm Monitoring using IoT | site1: SCOPUS
# name2: Sundar, Ramesh | inst2: VIGNANs Fdn Sci Technol & Res Deemed Univ, Dept Elect & Commun Engn, Guntur, Andhra Pradesh, India | title2: Cardiac disease diagnosis using feature extraction and machine learning based classification with Internet of Things(IoT) | site1: WOS
# inst: 0.6013621278241925 | title: 0.6288852943308685 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: Elsevier Ltd | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Sunitha C.A. | inst1: Assistant Professor St.Teresa Arts and Science College for Women Mangalakuntu Kanyakumari District affiliated to Manonmaniam Sundaranar University Abishekapatti Tamilnadu Tirunelveli 627012 India | title1: Chaotic and Paillier secure image data sharing based on blockchain and cloud security | site1: SCOPUS
# name2: Sutham T. | inst2: Rajamangala University of Technology Thanyaburi (RMUTT) Electronics and Telecommunication Engineering Faculty of Engineering Pathum Thani Thailand | title2: IoT-based Automatic Brightness and Soil Moisture Control System for Gerbera Smart Greenhouse | site1: SCOPUS
# inst: 0.6470388269160116 | title: 0.6599477834612105 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: IGI Global | journal2: INDIAN J AGR SCI
# name1: Sinha, Keshav | inst1: Birla institute of technology Mesra Ranchi India | title1: IoT and its real-time application in agriculture | site1: SCOPUS
# name2: Singh, K. G. | inst2: Punjab Agr Univ, Dept Soil & Water Engn, Ludhiana 141004, Punjab, India | title2: Development of an IoT based weighing type micro-lysimeter for soilless cultivation | site1: WOS
# inst: 0.5436133828057953 | title: 0.6880194218608852 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: HELIX | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Kumar, V. D. Satish | inst1: Dr KV Subbareddy Coll Engn Women, Dept Comp Sci & Engn, Kurnool, India | title1: Internet of Things: A Product Development Cycle for the Entrepreneurs | site1: WOS
# name2: Kumar G.B.A. | inst2: Kongu Engineering College Department of Computer Applications Erode India | title2: Sensor Based Smart Agriculture with IoT Technologies: A Review | site1: SCOPUS
# inst: 0.6397390737116765 | title: 0.6641384752601965 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: AQUACULT INT | journal2: AGRONOMY-BASEL
# name1: Li, Daoliang | inst1: China Agr Univ, Coll Engn, Beijing 100083, Peoples R China | title1: Intelligent fish farm-the future of aquaculture | site1: WOS
# name2: Li, Ming | inst2: Beijing Vocat Coll Agr, Dept Informat Technol, Beijing 102442, Peoples R China | title2: Streamlining Traceability Data Generation in Apple Production Using Integral Management with Machine-to-Machine Connections | site1: WOS
# inst: 0.6615458296492779 | title: 0.5380653097311116 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: Springer Science and Business Media Deutschland GmbH | journal2: MDPI
# name1: Li, Daoliang | inst1: National Innovation Center for Digital Fishery China Agricultural University Beijing China Beijing Engineering and Technology Research Centre for Internet of Things in Agriculture China Agriculture University Beijing 100083 China College of Information and Electrical Engineering China Agricultural University Beijing 100083 China | title1: Intelligent fish farm—the future of aquaculture | site1: SCOPUS
# name2: Li, Ming | inst2: Information Technology Research Center Beijing Academy of Agriculture and Forestry Sciences National Engineering Research Center for Information Technology in Agriculture National Engineering Laboratory for Agri‐Product Quality Traceability Beijing 100097 China | title2: Streamlining Traceability Data Generation in Apple Production Using Integral Management with Machine‐to‐Machine Connections | site1: SCOPUS
# inst: 0.7149299344506826 | title: 0.5380653097311116 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['Computer Science', ' Engineering', ' Telecommunications'], ['Agriculture', ' Animals', ' Autonomous aerial vehicles', ' Cattle', ' Cows', ' Drones', ' Livestock Agriculture', ' Livestock Management', ' Monitoring', ' Sensors', ' Unmanned Aerial Vehicle'] | journal1: IEEE ACCESS | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Bouchekara, Houssem R. E. H. | inst1: Islamic Univ Technol, Dept Comp Sci & Engn, Gazipur 1704, Bangladesh | title1: Livestock Management With Unmanned Aerial Vehicles: A Review | site1: WOS
# name2: Bouchekara, Houssem | inst2: Department of Electrical Engineering University of Hafr Al Batin Hafr Al Batin 31991 | title2: Livestock Management with Unmanned Aerial Vehicles: A Review | site1: SCOPUS
# inst: 0.589189298907969 | title: 1.0 | email: 0, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 1.0 | co_authorship: 0.0 | keyword: 0.0 | journal1: AGRONOMY-BASEL | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Marino, Stefano | inst1: Univ Kassel, Dept Agr & Biosyst Engn, D-37213 Witzenhausen, Germany | title1: Technology and Data Fusion Methods to Enhance Site-Specific Crop Monitoring | site1: WOS
# name2: Martynenko, A. | inst2: Department of Engineering Faculty of Agriculture Dalhousie University Truro NS  B2N 5E6 Canada | title2: IoT, Big Data, and Artificial Intelligence in Agriculture and Food Industry | site1: SCOPUS
# inst: 0.5848946755583784 | title: 0.6472117400419287 | email: 0, funding: 0
# weigth: 1.0
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 0 | keyword: ['Science & Technology - Other Topics'], ['API', ' Data Envelopment Analysis', ' IoT', ' Performance', ' Single Board Computer', ' Web Service'] | journal1: SURANAREE J SCI TECH | journal2: Suranaree University of Technology
# name1: On-rit, Surajate | inst1: Ubon Ratchathani Raj Abhat Univ, Dept Comp Network Engn, Fac Ind Technol, 2 Ratchathani Rd, Ubon Ratchathani 34000, Thailand | title1: WEB SERVICES PERFORMANCE EVALUATION ON SINGLE BOARD COMPUTERS FOR MOBILE APPLICATIONS AND IoT DEVICES | site1: WOS
# name2: On-rit S. | inst2: Department of Computer Network Engineering Faculty of Industrial Technology Ubon Ratchathani Rajabhat University 2 Ratchathani RoadNai Mueang Sub-District Mueang District Ubon Ratchathani 34000 Thailand | title2: WEB SERVICES PERFORMANCE EVALUATION ON SINGLE BOARD COMPUTERS FOR MOBILE APPLICATIONS AND IoT DEVICES | site1: SCOPUS
# inst: 0.6983644509885653 | title: 1.0 | email: 0, funding: 1
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 2022, 2022 | co_author_count: 1 | keyword: ['agriculture', ' communicative ecology', ' data inequalities', ' Digital divide', ' digital farming', ' precision agriculture'], ['Communication', ' Sociology'] | journal1: Routledge | journal2: INFORM COMMUN SOC
# name1: Dezuanni, Michael L. | inst1: Queensland University of Technology Brisbane Australia | title1: Critical factors of digital AgTech adoption on Australian farms: from digital to data divide | site1: SCOPUS
# name2: Dezuanni, Michael | inst2: Queensland Univ Technol, Digital Media Res Ctr, Digital Inclus & Participat, Brisbane, Qld, Australia | title2: Critical factors of digital AgTech adoption on Australian farms: from digital to data divide | site1: WOS
# inst: 0.6954778244264336 | title: 1.0 | email: 1, funding: 0
# weigth: 4
# ------------------------------------------------------------구분선2------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: Institute of Electrical and Electronics Engineers Inc. | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Soundhaaryha B.S. | inst1: Information Science and Engineering New Horizon College of Engineering Bangalore India | title1: Survey on IoT based E-Farming Technology Enabled Farming | site1: SCOPUS
# name2: Saranya S. | inst2: Computer Science and Engineering Sri Manakula Vinayagar Engineering College (Accredited by Naac with 'a' Grade) Puducherry India | title2: A Study of Smart Farming Based on IOT | site1: SCOPUS
# inst: 0.6511320948815972 | title: 0.6654430404430404 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: MICROPROCESS MICROSY | journal2: Institute of Electrical and Electronics Engineers Inc.
# name1: Selvakumaran, S. | inst1: PSNA Coll Engn & Technol, Dept Elect & Elect Engn, Dindigul, India | title1: Application of Machine Learning and Big Data in Doubly Fed Induction Generator based Stability Analysis of Multi Machine System using Substantial Transformative Optimization Algorithm | site1: WOS
# name2: Aslekar A. | inst2: Symbiosis Institute of Digital and Telecom Management Constituent of Symbiosis International-Deemed University Pune India | title2: Role of ICT & Fintech in Indian Agriculture | site1: SCOPUS
# inst: 0.5546971693216753 | title: 0.5925603180654648 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.9 | co_authorship: 0.0 | keyword: 0.0 | journal1: Springer Science and Business Media Deutschland GmbH | journal2: Springer Science and Business Media Deutschland GmbH
# name1: Shacham-Diamand, Yosef Y. | inst1: School of Electrical Engineering Tel Aviv Israel | title1: Green Energy-Based Efficient IoT Sensor Network for Small Farms | site1: SCOPUS
# name2: Sharma, Manish | inst2: Jaypee Institute of Information Technology Noida India | title2: Smart Agriculture Using IoD: Insights, Trends and Road Ahead | site1: SCOPUS
# inst: 0.5601851851851852 | title: 0.6255291005291005 | email: 0, funding: 0
# weigth: 0.9
# ------------------------------------------------------------구분선------------------------------------------------------------
# joc: 0 | yop: 0.8 | co_authorship: 0.0 | keyword: 0.0 | journal1: IEEE ACCESS | journal2: Association for Computing Machinery
# name1: Pearson, Simon | inst1: Univ Lincoln, Lincoln Inst Agrifood Technol, Lincoln LN6 7TS, England | title1: Photovoltaic Agricultural Internet of Things Towards Realizing the Next Generation of Smart Farming | site1: WOS
# name2: Paris M. | inst2: Bioceanor Sophia Antipolis France | title2: Planetary Digital Twin: A Case Study in Aquaculture | site1: SCOPUS
# inst: 0.5318401405357926 | title: 0.6099722717369777 | email: 0, funding: 0
# weigth: 0.8
# ------------------------------------------------------------구분선------------------------------------------------------------
# ['malonepaul', 'amidymartin', 'kumarnagesh', 'alkanhalm', 'junnarkaraparnaa', 'jovanovicn', 'joshikaruna', 'caicedoo', 'xiaofengl', 'chikhis', 'corralesjuancarlos', 'casavolaalessandro', 'oliveiralda', 'jimenezfabian', 'dolfsmaw', 'marinos', 'onrits', 'zahranmb', 'carvajalr', 'bouchekarahoussem', 'dezuannimichael', 'sunithaca', 'martynenkoa', 'kumarnagesh', 'malonepaul', 'huangnenfu', 'jovanovicn', 'amidymartin', 'alkanhalm', 'junnarkaraparnaa', 'chikhis', 'xiaofengl', 'joshikaruna', 'caicedoo', 'huangnenfu', 'zahranmb', 'corralesjuancarlos', 'casavolaalessandro', 'jimenezfabian', 'oliveiralda', 'kumaripv', 'tnp', 'marinos', 'dolfsmaw', 'sunithaca', 'carvajalr', 'bouchekarahoussem', 'onrits', 'dezuannimichael']
# 121
# 234

# %%
import json

answer = None
numCor = 0
numErr = 0
numInteErr = 0
answerCounter = {}

def ansCheck(result, name):
    global answer, numCor, numErr, answerCounter, numInteErr # answer = json, numCor = 정답 수, numErr = 오답 수, answerCounter = 정답수, numInteErr = 통합에러
    flag = True

    numK = len(result.keys()) #Answer_dict key 개수
    if numK-5 != len(answer[name].keys()):
        flag = False
    else :
        for site in result.keys():
            if site != 'name' and site != 'fid' and site != 'keyId' and site != 'inst' and site != 'pre_name':
                if site not in answer[name].keys() :
                    flag = False
                else: 
                    if numK > 5:
                        if answer[name][site] != result[site]['inst']:
                            flag = False
                    else :
                        if answer[name][site] != result[site]['inst'] and answer[name][site] != result[site]['inst'].split(' ')[0]:
                            flag = False
    if flag:
        numCor += 1
        answerCounter[name] += 1
    else:
        if len(answer[name].keys()) > 1:
            numInteErr += 1
            print(f"IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct \n - Answer : {name} {answer[name]}\n - Result : {result}")
        else:
            pass
        numErr += 1
    return flag

with open(f'answer{keyid}.json', 'r',encoding='utf-8-sig') as a_json:

    answer = json.load(a_json)
    numAns = print(len(answer))
    for key in answer.keys() :
        answerCounter[key] = 0

    for answer_one in Answer_dict:        
        name = Answer_dict[answer_one]['name'].split('_')[0]

        if name in answer :
            ansCheck(Answer_dict[answer_one], name)

        else :
            count = 0
            while name+'_'+str(count) in answer :
                if ansCheck(Answer_dict[answer_one], name+'_'+str(count)) :
                    break
                count += 1

    print(f"num코렉트 {numCor}")
    print(f"numEror {numErr}")
    print(f"numInteEror {numInteErr}")
    totalError = 0
    totalInteError1 = 0
    totalInteError2 = 0
    answercount = 0
    totalInte = 0

    for key in answerCounter.keys() :
        answercount += 1
        if answerCounter[key] == 0 :
            totalError += 1
            print("answer=",key, answer[key])
            if len(answer[key].keys()) > 1 :
                totalInteError1 += 1

        else:
            if len(answer[key].keys()) > 1 :
                totalInteError2 += 1

    print("토탈앤써", answercount)
    print("토탈인터그레이션", totalInteError1 + totalInteError2)
    print("--------------------------------")
    print("토탈에러", totalError) 
    print("토탈인터그레이션에러", totalInteError1)
    print(keyid)
    
print(sorted(Answer_dict.items()))
# Out:
# 418
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Bartzanas, Thomas {'SCOPUS': 'Department of Natural Resources and Agricultural Engineering Agricultural University of Athens Athens 11855 Greece', 'WOS': 'Agr Univ Athens, Dept Nat Resources & Agr Engn, Farm Struct Lab, Athens 11855, Greece'}
#  - Result : {'fid': 0, 'keyId': 899, 'name': 'Bartzanas, Thomas', 'pre_name': 'bartzanasthomas', 'inst': 'Department of Natural Resources and Agricultural Engineering Agricultural University of Athens Athens 11855 Greece', 'SCOPUS': {'inst': 'Department of Natural Resources and Agricultural Engineering Agricultural University of Athens Athens 11855 Greece', 'A_id': ['8669579200'], 'papers': [ObjectId('6294377a4c7cb9455f86c142')], 'oriInst': 'Department of Natural Resources and Agricultural Engineering Agricultural University of Athens Athens 11855 Greece'}}
# IIIIIIIIIIIIIIIIIIIIIIIIIIII Not Correct
#  - Answer : Bartzanas, Thomas {'SCOPUS': 'Department of Natural Resources and Agricultural Engineering Agricultural University of Athens Athens 11855 Greece', 'WOS': 'Agr Univ Athens, Dept Nat Resources & Agr Engn, Farm Struct Lab, Athens 11855, Greece'}
#  - Result : {'fid': 0, 'keyId': 899, 'name': 'Bartzanas, Thomas', 'pre_name': 'bartzanasthomas', 'inst': 'Agr Univ Athens, Dept Nat Resources & Agr Engn, Farm Struct Lab, Athens 11855, Greece', 'WOS': {'inst': 'Agr Univ Athens, Dept Nat Resources & Agr Engn, Farm Struct Lab, Athens 11855, Greece', 'A_id': ['ss9682069'], 'papers': [ObjectId('629437761649752aa1870cda')], 'oriInst': 'Agr Univ Athens, Dept Nat Resources & Agr Engn, Farm Struct Lab, Athens 11855, Greece'}}
# num코렉트 413
# numEror 4
# numInteEror 2
# answer= Bartzanas, Thomas {'SCOPUS': 'Department of Natural Resources and Agricultural Engineering Agricultural University of Athens Athens 11855 Greece', 'WOS': 'Agr Univ Athens, Dept Nat Resources & Agr Engn, Farm Struct Lab, Athens 11855, Greece'}
# answer= Huang, Nenfu {'SCOPUS': 'National Tsing Hua University Department of Computer Science Hsinchu Taiwan'}
# answer= Kumar, Nagesh {'SCOPUS': 'School of Electrical and Computer Science Shoolini University of Biotechnology and Management Sciences Solan Himachal Pradesh India'}
# answer= Kumar, V. D. Satish {'WOS': 'Dr KV Subbareddy Coll Engn Women, Dept Comp Sci & Engn, Kurnool, India'}
# answer= Kumari P.V. {'SCOPUS': 'Dayananda Sagar University Department of Computer Applications Bangalore India'}
# 토탈앤써 418
# 토탈인터그레이션 91
# --------------------------------
# 토탈에러 5
# 토탈인터그레이션에러 1
# 899
# [('abdelsalammahmoud', {'fid': 0, 'keyId': 899, 'name': 'Abdelsalam, Mahmoud', 'pre_name': 'abdelsalammahmoud', 'inst': 'North Carolina A&T State University Dept. of Computer Science Greensboro NC United States', 'SCOPUS': {'inst': 'North Carolina A&T State University Dept. of Computer Science Greensboro NC United States', 'A_id': ['57196190230'], 'papers': [ObjectId('629437794c7cb9455f86c119')], 'oriInst': 'North Carolina A&T State University Dept. of Computer Science Greensboro NC United States'}}), ('abdullahnorfadzilah_0', {'fid': 0, 'keyId': 899, 'name': 'Abdullah, Nor Fadzilah', 'pre_name': 'abdullahnorfadzilah', 'inst': 'Univ Kebangsaan Malaysia, Fac Engn & Built Environm, Dept Elect Elect & Syst Engn, Bangi 43600, Selangor, Malaysia', 'WOS': {'inst': 'Univ Kebangsaan Malaysia, Fac Engn & Built Environm, Dept Elect Elect & Syst Engn, Bangi 43600, Selangor, Malaysia', 'A_id': ['s8314240'], 'papers': [ObjectId('629437751649752aa1870c85')], 'oriInst': 'Univ Kebangsaan Malaysia, Fac Engn & Built Environm, Dept Elect Elect & Syst Engn, Bangi 43600, Selangor, Malaysia'}, 'SCOPUS': {'inst': 'Department of Electrical Electronics and Systems Engineering Faculty of Engineering and Built Environment Universiti Kebangsaan Malaysia Bangi Selangor 43600 Malaysia', 'A_id': ['36185012000'], 'papers': [ObjectId('629437774c7cb9455f86c0d6')], 'oriInst': 'Department of Electrical Electronics and Systems Engineering Faculty of Engineering and Built Environment Universiti Kebangsaan Malaysia Bangi Selangor 43600 Malaysia'}}), ('abidadnan', {'fid': 0, 'keyId': 899, 'name': 'Abid, Adnan', 'pre_name': 'abidadnan', 'inst': 'Department of Computer Science University of Management and Technology Lahore 54000 Pakistan', 'SCOPUS': {'inst': 'Department of Computer Science University of Management and Technology Lahore 54000 Pakistan', 'A_id': ['36614939400'], 'papers': [ObjectId('629437754c7cb9455f86c0a4')], 'oriInst': 'Department of Computer Science University of Management and Technology Lahore 54000 Pakistan'}}), ('abouelattaebrahimmohamed', {'fid': 0, 'keyId': 899, 'name': 'Abouelatta-Ebrahim, Mohamed', 'pre_name': 'abouelattaebrahimmohamed', 'inst': 'Faculty of Engineering Electronics and Electrical Communication Ain Shams University (ASU) Cairo 39827 Egypt', 'SCOPUS': {'inst': 'Faculty of Engineering Electronics and Electrical Communication Ain Shams University (ASU) Cairo 39827 Egypt', 'A_id': ['57193564546'], 'papers': [ObjectId('629437734c7cb9455f86c01a')], 'oriInst': 'Faculty of Engineering Electronics and Electrical Communication Ain Shams University (ASU) Cairo 39827 Egypt'}}), ('abumahfouzadnanm', {'fid': 0, 'keyId': 899, 'name': 'Abu-Mahfouz, Adnan M.', 'pre_name': 'abumahfouzadnanm', 'inst': 'Univ Johannesburg, Council Sci & Ind Res, ZA-2006 Johannesburg, South Africa', 'WOS': {'inst': 'Univ Johannesburg, Council Sci & Ind Res, ZA-2006 Johannesburg, South Africa', 'A_id': ['ss9518985'], 'papers': [ObjectId('629437771649752aa1870d53')], 'oriInst': 'Univ Johannesburg, Council Sci & Ind Res, ZA-2006 Johannesburg, South Africa'}}), ('adekanbimichaellanre_0', {'fid': 0, 'keyId': 899, 'name': 'Adekanbi, Michael Lanre', 'pre_name': 'adekanbimichaellanre', 'inst': 'Univ Ibadan, Fac Technol, Dept Mech Engn, Ibadan, Oyo State, Nigeria', 'WOS': {'inst': 'Univ Ibadan, Fac Technol, Dept Mech Engn, Ibadan, Oyo State, Nigeria', 'A_id': ['ss9681887'], 'papers': [ObjectId('629437751649752aa1870c2a')], 'oriInst': 'Univ Ibadan, Fac Technol, Dept Mech Engn, Ibadan, Oyo State, Nigeria'}, 'SCOPUS': {'inst': 'Department of Mechanical Engineering Faculty of Technology University of Ibadan Ibadan Nigeria', 'A_id': ['57224453397'], 'papers': [ObjectId('629437774c7cb9455f86c0d2')], 'oriInst': 'Department of Mechanical Engineering Faculty of Technology University of Ibadan Ibadan Nigeria'}}), ('agrawalr', {'fid': 0, 'keyId': 899, 'name': 'Agrawal R.', 'pre_name': 'agrawalr', 'inst': 'Sandip University Department of Electrical Engineering School of Engineering and ...
